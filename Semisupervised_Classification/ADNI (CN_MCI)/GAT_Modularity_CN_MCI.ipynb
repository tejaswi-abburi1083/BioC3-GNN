# %%
import torch
import torch.nn as nn
import torch.nn.functional as nnFn
import torch.optim as optim
import numpy as np
import random
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from torch_geometric.data import Data
from torch_geometric.nn import GCNConv
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, roc_auc_score, log_loss
)

# %%
fa_feature_path = "/home/snu/Downloads/Histogram_CN_FA_20bin_updated.npy"
Histogram_feature_CN_FA_array = np.load(fa_feature_path, allow_pickle=True)

fa_feature_path = "/home/snu/Downloads/Histogram_MCI_FA_20bin_updated.npy"
Histogram_feature_MCI_FA_array = np.load(fa_feature_path, allow_pickle=True)

X = np.vstack([Histogram_feature_CN_FA_array, Histogram_feature_MCI_FA_array])
y = np.hstack([
    np.zeros(Histogram_feature_CN_FA_array.shape[0], dtype=np.int64),
    np.ones(Histogram_feature_MCI_FA_array.shape[0], dtype=np.int64)
])

num_nodes, num_feats = X.shape
print(f"Features: {X.shape}, Labels: {y.shape}")
# Out:
# Features: (300, 180), Labels: (300,)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as nnFn
from torch_geometric.nn import GATConv


class GAT_SemiSupervised(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, device, heads=2, activ="SELU", dropout=0.25):
        super(GAT_SemiSupervised, self).__init__()
        self.device = device

        # GAT layer
        self.conv1 = GATConv(input_dim, hidden_dim, heads=heads, concat=True, dropout=dropout)
        self.bn1 = nn.BatchNorm1d(hidden_dim * heads)  # heads multiply feature dimension if concat=True
        self.dropout = nn.Dropout(dropout)
        self.fc = nn.Linear(hidden_dim * heads, output_dim)

        # Activation mapping
        activations = {
            "SELU": nnFn.selu,
            "SiLU": nnFn.silu,
            "GELU": nnFn.gelu,
            "RELU": nnFn.relu,
            "ELU": nnFn.elu
        }
        self.act = activations.get(activ, nnFn.elu)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index

        # GAT layer
        x = self.conv1(x, edge_index)
        x = self.bn1(x)
        x = self.act(x)
        x = self.dropout(x)

        logits = self.fc(x)
        return logits

    def modularity_loss(self, A, logits):
        S = nnFn.softmax(logits, dim=1)
        d = torch.sum(A, dim=1)
        m = torch.sum(A)
        B = A - torch.outer(d, d) / (2 * m + 1e-12)

        modularity_term = (-1 / (2 * m + 1e-12)) * torch.trace(S.T @ B @ S)
        # Collapse regularization
        I_S = torch.eye(S.shape[1], device=self.device)
        k = torch.norm(I_S)
        n = S.shape[0]
        collapse_reg = (torch.sqrt(k) / n) * torch.norm(torch.sum(S, dim=0), p='fro') - 1
        entropy_reg = -torch.mean(torch.sum(S * torch.log(S + 1e-9), dim=1))
        return modularity_term + 0.1 * collapse_reg + 0.01 * entropy_reg

# %%
def create_adj(F, alpha=1):
    F_norm = F / np.linalg.norm(F, axis=1, keepdims=True)
    W = np.dot(F_norm, F_norm.T)
    W = np.where(W >= alpha, 1, 0).astype(np.float32)
    W = W / W.max()
    return W

def load_data(adj, node_feats):
    node_feats = torch.from_numpy(node_feats).float()
    edge_index = torch.from_numpy(np.array(np.nonzero((adj > 0))))
    return Data(x=node_feats, edge_index=edge_index)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
alpha = 0.92
feats_dim = num_feats
hidden_dim = 512
num_classes = 2
num_epochs = 2000
lr = 0.0001
weight_decay = 1e-4
batch_print_freq = 100
lambda_mod = 0.9 #0.01  # weight for modularity loss
# lambda_sup = 5

# %%
W = create_adj(X, alpha)
data = load_data(W, X).to(device)
A_tensor = torch.from_numpy(W).float().to(device)
print(data)
# Out:
# Data(x=[300, 180], edge_index=[2, 13604])

# %%
sss = StratifiedShuffleSplit(n_splits=20, test_size=0.9, random_state=42)

accuracies, precisions, recalls, f1_scores, aucs, ce_losses = [], [], [], [], [], []

for fold, (train_val_idx, test_idx_global) in enumerate(sss.split(X, y), start=1):
    print(f"\n=== Fold {fold} ===")


    cn_idx = np.where(y == 0)[0]
    mci_idx = np.where(y == 1)[0]

    sss_class = StratifiedShuffleSplit(n_splits=20, test_size=0.9, random_state=fold)
    cn_train_idx, _ = next(sss_class.split(X[cn_idx], y[cn_idx]))
    mci_train_idx, _ = next(sss_class.split(X[mci_idx], y[mci_idx]))
    cn_train = cn_idx[cn_train_idx]
    mci_train = mci_idx[mci_train_idx]
    train_idx_final = np.concatenate([cn_train, mci_train])
    np.random.shuffle(train_idx_final)

    print(f"Train CN: {len(cn_train)}, Train MCI: {len(mci_train)}")

    train_idx_t = torch.from_numpy(train_idx_final).long().to(device)
    y_train_tensor = torch.from_numpy(y[train_idx_final]).long().to(device)


    model = GAT_SemiSupervised(feats_dim, hidden_dim, num_classes, device, activ="SELU").to(device)
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    ce_loss = nn.CrossEntropyLoss()


    for epoch in range(1, num_epochs + 1):
        model.train()
        optimizer.zero_grad()

        logits = model(data)
        loss_sup = ce_loss(logits[train_idx_t], y_train_tensor)
        loss_unsup = model.modularity_loss(A_tensor, logits)
        total_loss = loss_sup + lambda_mod * loss_unsup

        total_loss.backward()
        optimizer.step()

        if epoch % batch_print_freq == 0 or epoch == 1:
            model.eval()
            with torch.no_grad():
                preds_train = logits[train_idx_t].argmax(dim=1)
                acc_train = accuracy_score(y_train_tensor.cpu(), preds_train.cpu())
            print(f"Fold {fold} Epoch {epoch}: "
                  f"TotalLoss={total_loss.item():.6f} | Sup={loss_sup.item():.6f} | "
                  f"Unsup={loss_unsup.item():.6f} | TrainAcc={acc_train:.4f}")


    model.eval()
    with torch.no_grad():
        out = model(data)
        preds = out.argmax(dim=1).cpu().numpy()
        probs = torch.softmax(out, dim=1)[:, 1].cpu().numpy()  # Probability for class 1

    y_test = y[test_idx_global]
    y_pred_test = preds[test_idx_global]
    y_prob_test = probs[test_idx_global]

    acc = accuracy_score(y_test, y_pred_test)
    prec = precision_score(y_test, y_pred_test, zero_division=0)
    rec = recall_score(y_test, y_pred_test, zero_division=0)
    f1 = f1_score(y_test, y_pred_test, zero_division=0)
    auc = roc_auc_score(y_test, y_prob_test)
    ce = log_loss(y_test, y_prob_test)

    accuracies.append(acc)
    precisions.append(prec)
    recalls.append(rec)
    f1_scores.append(f1)
    aucs.append(auc)
    ce_losses.append(ce)

    print(f"Fold {fold} → "
          f"Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | "
          f"F1={f1:.4f} | AUC={auc:.4f} | CE Loss={ce:.4f}")


print("\n=== Average Results Across 20 Folds ===")
print(f"Accuracy:  {np.mean(accuracies):.4f} ± {np.std(accuracies):.4f}")
print(f"Precision: {np.mean(precisions):.4f} ± {np.std(precisions):.4f}")
print(f"Recall:    {np.mean(recalls):.4f} ± {np.std(recalls):.4f}")
print(f"F1-score:  {np.mean(f1_scores):.4f} ± {np.std(f1_scores):.4f}")
print(f"AUC:       {np.mean(aucs):.4f} ± {np.std(aucs):.4f}")
print(f"CE Loss:   {np.mean(ce_losses):.4f} ± {np.std(ce_losses):.4f}")
# Out:
# === Fold 1 ===
# Train CN: 13, Train MCI: 16
# Fold 1 Epoch 1: TotalLoss=0.834220 | Sup=0.961298 | Unsup=-0.141198 | TrainAcc=0.3103
# Fold 1 Epoch 100: TotalLoss=0.078428 | Sup=0.274433 | Unsup=-0.217784 | TrainAcc=0.8276
# Fold 1 Epoch 200: TotalLoss=-0.046316 | Sup=0.154543 | Unsup=-0.223176 | TrainAcc=0.9655
# Fold 1 Epoch 300: TotalLoss=-0.102416 | Sup=0.100417 | Unsup=-0.225370 | TrainAcc=0.9655
# Fold 1 Epoch 400: TotalLoss=-0.141846 | Sup=0.064957 | Unsup=-0.229781 | TrainAcc=1.0000
# Fold 1 Epoch 500: TotalLoss=-0.152636 | Sup=0.059134 | Unsup=-0.235300 | TrainAcc=1.0000
# Fold 1 Epoch 600: TotalLoss=-0.173402 | Sup=0.039058 | Unsup=-0.236067 | TrainAcc=1.0000
# Fold 1 Epoch 700: TotalLoss=-0.179201 | Sup=0.027908 | Unsup=-0.230121 | TrainAcc=1.0000
# Fold 1 Epoch 800: TotalLoss=-0.195035 | Sup=0.026557 | Unsup=-0.246214 | TrainAcc=1.0000
# Fold 1 Epoch 900: TotalLoss=-0.202330 | Sup=0.015334 | Unsup=-0.241849 | TrainAcc=1.0000
# Fold 1 Epoch 1000: TotalLoss=-0.204470 | Sup=0.012743 | Unsup=-0.241348 | TrainAcc=1.0000
# Fold 1 Epoch 1100: TotalLoss=-0.207073 | Sup=0.016170 | Unsup=-0.248048 | TrainAcc=1.0000
# Fold 1 Epoch 1200: TotalLoss=-0.218291 | Sup=0.013764 | Unsup=-0.257840 | TrainAcc=1.0000
# Fold 1 Epoch 1300: TotalLoss=-0.217342 | Sup=0.009410 | Unsup=-0.251947 | TrainAcc=1.0000
# Fold 1 Epoch 1400: TotalLoss=-0.220827 | Sup=0.010578 | Unsup=-0.257117 | TrainAcc=1.0000
# Fold 1 Epoch 1500: TotalLoss=-0.226469 | Sup=0.004937 | Unsup=-0.257118 | TrainAcc=1.0000
# Fold 1 Epoch 1600: TotalLoss=-0.230335 | Sup=0.004132 | Unsup=-0.260520 | TrainAcc=1.0000
# Fold 1 Epoch 1700: TotalLoss=-0.226446 | Sup=0.004768 | Unsup=-0.256904 | TrainAcc=1.0000
# Fold 1 Epoch 1800: TotalLoss=-0.225177 | Sup=0.004806 | Unsup=-0.255536 | TrainAcc=1.0000
# Fold 1 Epoch 1900: TotalLoss=-0.230801 | Sup=0.003523 | Unsup=-0.260360 | TrainAcc=1.0000
# Fold 1 Epoch 2000: TotalLoss=-0.234364 | Sup=0.005944 | Unsup=-0.267009 | TrainAcc=1.0000
# Fold 1 → Acc=0.7778 | Prec=0.8169 | Rec=0.7733 | F1=0.7945 | AUC=0.8269 | CE Loss=1.9395
#
# === Fold 2 ===
# Train CN: 13, Train MCI: 16
# Fold 2 Epoch 1: TotalLoss=0.888524 | Sup=1.014287 | Unsup=-0.139736 | TrainAcc=0.1724
# Fold 2 Epoch 100: TotalLoss=0.168271 | Sup=0.353174 | Unsup=-0.205448 | TrainAcc=0.8276
# Fold 2 Epoch 200: TotalLoss=0.083655 | Sup=0.271312 | Unsup=-0.208508 | TrainAcc=0.8621
# Fold 2 Epoch 300: TotalLoss=0.030569 | Sup=0.220046 | Unsup=-0.210530 | TrainAcc=0.9310
# Fold 2 Epoch 400: TotalLoss=-0.016588 | Sup=0.171338 | Unsup=-0.208807 | TrainAcc=0.8966
# Fold 2 Epoch 500: TotalLoss=-0.070302 | Sup=0.128351 | Unsup=-0.220726 | TrainAcc=0.9310
# Fold 2 Epoch 600: TotalLoss=-0.116359 | Sup=0.085356 | Unsup=-0.224127 | TrainAcc=1.0000
# Fold 2 Epoch 700: TotalLoss=-0.121285 | Sup=0.072566 | Unsup=-0.215390 | TrainAcc=1.0000
# Fold 2 Epoch 800: TotalLoss=-0.146861 | Sup=0.054362 | Unsup=-0.223581 | TrainAcc=1.0000
# Fold 2 Epoch 900: TotalLoss=-0.102754 | Sup=0.103014 | Unsup=-0.228632 | TrainAcc=0.9655
# Fold 2 Epoch 1000: TotalLoss=-0.148120 | Sup=0.061419 | Unsup=-0.232822 | TrainAcc=0.9655
# Fold 2 Epoch 1100: TotalLoss=-0.197742 | Sup=0.016529 | Unsup=-0.238079 | TrainAcc=1.0000
# Fold 2 Epoch 1200: TotalLoss=-0.184018 | Sup=0.027883 | Unsup=-0.235446 | TrainAcc=1.0000
# Fold 2 Epoch 1300: TotalLoss=-0.188109 | Sup=0.025114 | Unsup=-0.236914 | TrainAcc=1.0000
# Fold 2 Epoch 1400: TotalLoss=-0.196367 | Sup=0.026862 | Unsup=-0.248032 | TrainAcc=1.0000
# Fold 2 Epoch 1500: TotalLoss=-0.170687 | Sup=0.051497 | Unsup=-0.246871 | TrainAcc=0.9655
# Fold 2 Epoch 1600: TotalLoss=-0.210276 | Sup=0.010764 | Unsup=-0.245600 | TrainAcc=1.0000
# Fold 2 Epoch 1700: TotalLoss=-0.223466 | Sup=0.007853 | Unsup=-0.257021 | TrainAcc=1.0000
# Fold 2 Epoch 1800: TotalLoss=-0.209484 | Sup=0.016086 | Unsup=-0.250633 | TrainAcc=1.0000
# Fold 2 Epoch 1900: TotalLoss=-0.199804 | Sup=0.031856 | Unsup=-0.257400 | TrainAcc=1.0000
# Fold 2 Epoch 2000: TotalLoss=-0.226169 | Sup=0.005267 | Unsup=-0.257151 | TrainAcc=1.0000
# Fold 2 → Acc=0.7852 | Prec=0.7987 | Rec=0.8200 | F1=0.8092 | AUC=0.8362 | CE Loss=1.7276
#
# === Fold 3 ===
# Train CN: 13, Train MCI: 16
# Fold 3 Epoch 1: TotalLoss=0.615846 | Sup=0.748513 | Unsup=-0.147408 | TrainAcc=0.5517
# Fold 3 Epoch 100: TotalLoss=0.100086 | Sup=0.302174 | Unsup=-0.224542 | TrainAcc=0.7931
# Fold 3 Epoch 200: TotalLoss=0.050926 | Sup=0.257897 | Unsup=-0.229968 | TrainAcc=0.8621
# Fold 3 Epoch 300: TotalLoss=-0.028711 | Sup=0.186464 | Unsup=-0.239084 | TrainAcc=0.8966
# Fold 3 Epoch 400: TotalLoss=-0.058223 | Sup=0.159351 | Unsup=-0.241749 | TrainAcc=0.9310
# Fold 3 Epoch 500: TotalLoss=-0.095622 | Sup=0.120409 | Unsup=-0.240033 | TrainAcc=0.9655
# Fold 3 Epoch 600: TotalLoss=-0.095586 | Sup=0.126279 | Unsup=-0.246517 | TrainAcc=0.9310
# Fold 3 Epoch 700: TotalLoss=-0.142156 | Sup=0.088294 | Unsup=-0.256055 | TrainAcc=0.9655
# Fold 3 Epoch 800: TotalLoss=-0.148498 | Sup=0.080874 | Unsup=-0.254858 | TrainAcc=0.9655
# Fold 3 Epoch 900: TotalLoss=-0.206747 | Sup=0.030995 | Unsup=-0.264158 | TrainAcc=1.0000
# Fold 3 Epoch 1000: TotalLoss=-0.203235 | Sup=0.026523 | Unsup=-0.255286 | TrainAcc=1.0000
# Fold 3 Epoch 1100: TotalLoss=-0.220396 | Sup=0.011448 | Unsup=-0.257604 | TrainAcc=1.0000
# Fold 3 Epoch 1200: TotalLoss=-0.208782 | Sup=0.017968 | Unsup=-0.251944 | TrainAcc=1.0000
# Fold 3 Epoch 1300: TotalLoss=-0.214852 | Sup=0.026978 | Unsup=-0.268700 | TrainAcc=1.0000
# Fold 3 Epoch 1400: TotalLoss=-0.222413 | Sup=0.016368 | Unsup=-0.265312 | TrainAcc=1.0000
# Fold 3 Epoch 1500: TotalLoss=-0.237781 | Sup=0.009204 | Unsup=-0.274427 | TrainAcc=1.0000
# Fold 3 Epoch 1600: TotalLoss=-0.232373 | Sup=0.007640 | Unsup=-0.266681 | TrainAcc=1.0000
# Fold 3 Epoch 1700: TotalLoss=-0.240691 | Sup=0.009716 | Unsup=-0.278231 | TrainAcc=1.0000
# Fold 3 Epoch 1800: TotalLoss=-0.239165 | Sup=0.009868 | Unsup=-0.276703 | TrainAcc=1.0000
# Fold 3 Epoch 1900: TotalLoss=-0.205685 | Sup=0.046750 | Unsup=-0.280483 | TrainAcc=1.0000
# Fold 3 Epoch 2000: TotalLoss=-0.243979 | Sup=0.003482 | Unsup=-0.274957 | TrainAcc=1.0000
# Fold 3 → Acc=0.7926 | Prec=0.8852 | Rec=0.7200 | F1=0.7941 | AUC=0.8578 | CE Loss=2.0112
#
# === Fold 4 ===
# Train CN: 13, Train MCI: 16
# Fold 4 Epoch 1: TotalLoss=0.753101 | Sup=0.879154 | Unsup=-0.140059 | TrainAcc=0.3793
# Fold 4 Epoch 100: TotalLoss=0.139721 | Sup=0.322866 | Unsup=-0.203495 | TrainAcc=0.8276
# Fold 4 Epoch 200: TotalLoss=0.028730 | Sup=0.226821 | Unsup=-0.220101 | TrainAcc=0.8621
# Fold 4 Epoch 300: TotalLoss=-0.034064 | Sup=0.169868 | Unsup=-0.226591 | TrainAcc=0.9310
# Fold 4 Epoch 400: TotalLoss=-0.068251 | Sup=0.135897 | Unsup=-0.226831 | TrainAcc=0.9310
# Fold 4 Epoch 500: TotalLoss=-0.047309 | Sup=0.159119 | Unsup=-0.229365 | TrainAcc=0.9310
# Fold 4 Epoch 600: TotalLoss=-0.085030 | Sup=0.123878 | Unsup=-0.232120 | TrainAcc=0.9310
# Fold 4 Epoch 700: TotalLoss=-0.157284 | Sup=0.051995 | Unsup=-0.232532 | TrainAcc=1.0000
# Fold 4 Epoch 800: TotalLoss=-0.102378 | Sup=0.109181 | Unsup=-0.235066 | TrainAcc=0.9310
# Fold 4 Epoch 900: TotalLoss=-0.150709 | Sup=0.059644 | Unsup=-0.233726 | TrainAcc=1.0000
# Fold 4 Epoch 1000: TotalLoss=-0.166082 | Sup=0.047043 | Unsup=-0.236805 | TrainAcc=1.0000
# Fold 4 Epoch 1100: TotalLoss=-0.153239 | Sup=0.063168 | Unsup=-0.240453 | TrainAcc=0.9655
# Fold 4 Epoch 1200: TotalLoss=-0.178743 | Sup=0.035984 | Unsup=-0.238586 | TrainAcc=1.0000
# Fold 4 Epoch 1300: TotalLoss=-0.186949 | Sup=0.029217 | Unsup=-0.240185 | TrainAcc=1.0000
# Fold 4 Epoch 1400: TotalLoss=-0.183846 | Sup=0.030543 | Unsup=-0.238210 | TrainAcc=1.0000
# Fold 4 Epoch 1500: TotalLoss=-0.196992 | Sup=0.016670 | Unsup=-0.237403 | TrainAcc=1.0000
# Fold 4 Epoch 1600: TotalLoss=-0.164083 | Sup=0.051249 | Unsup=-0.239258 | TrainAcc=0.9655
# Fold 4 Epoch 1700: TotalLoss=-0.191716 | Sup=0.021373 | Unsup=-0.236766 | TrainAcc=1.0000
# Fold 4 Epoch 1800: TotalLoss=-0.199960 | Sup=0.013977 | Unsup=-0.237708 | TrainAcc=1.0000
# Fold 4 Epoch 1900: TotalLoss=-0.203307 | Sup=0.010152 | Unsup=-0.237177 | TrainAcc=1.0000
# Fold 4 Epoch 2000: TotalLoss=-0.201709 | Sup=0.014388 | Unsup=-0.240108 | TrainAcc=1.0000
# Fold 4 → Acc=0.7704 | Prec=0.7391 | Rec=0.9067 | F1=0.8144 | AUC=0.8171 | CE Loss=2.0986
#
# === Fold 5 ===
# Train CN: 13, Train MCI: 16
# Fold 5 Epoch 1: TotalLoss=0.626471 | Sup=0.747838 | Unsup=-0.134852 | TrainAcc=0.3793
# Fold 5 Epoch 100: TotalLoss=-0.158093 | Sup=0.088996 | Unsup=-0.274542 | TrainAcc=0.9655
# Fold 5 Epoch 200: TotalLoss=-0.222629 | Sup=0.033201 | Unsup=-0.284255 | TrainAcc=1.0000
# Fold 5 Epoch 300: TotalLoss=-0.247877 | Sup=0.011562 | Unsup=-0.288266 | TrainAcc=1.0000
# Fold 5 Epoch 400: TotalLoss=-0.255326 | Sup=0.005948 | Unsup=-0.290304 | TrainAcc=1.0000
# Fold 5 Epoch 500: TotalLoss=-0.257628 | Sup=0.005938 | Unsup=-0.292851 | TrainAcc=1.0000
# Fold 5 Epoch 600: TotalLoss=-0.258596 | Sup=0.004283 | Unsup=-0.292087 | TrainAcc=1.0000
# Fold 5 Epoch 700: TotalLoss=-0.262134 | Sup=0.002067 | Unsup=-0.293557 | TrainAcc=1.0000
# Fold 5 Epoch 800: TotalLoss=-0.262490 | Sup=0.001731 | Unsup=-0.293579 | TrainAcc=1.0000
# Fold 5 Epoch 900: TotalLoss=-0.261345 | Sup=0.003161 | Unsup=-0.293895 | TrainAcc=1.0000
# Fold 5 Epoch 1000: TotalLoss=-0.266344 | Sup=0.000670 | Unsup=-0.296682 | TrainAcc=1.0000
# Fold 5 Epoch 1100: TotalLoss=-0.262281 | Sup=0.003864 | Unsup=-0.295717 | TrainAcc=1.0000
# Fold 5 Epoch 1200: TotalLoss=-0.258640 | Sup=0.008768 | Unsup=-0.297120 | TrainAcc=1.0000
# Fold 5 Epoch 1300: TotalLoss=-0.262225 | Sup=0.005414 | Unsup=-0.297377 | TrainAcc=1.0000
# Fold 5 Epoch 1400: TotalLoss=-0.264201 | Sup=0.003752 | Unsup=-0.297726 | TrainAcc=1.0000
# Fold 5 Epoch 1500: TotalLoss=-0.247638 | Sup=0.019173 | Unsup=-0.296456 | TrainAcc=1.0000
# Fold 5 Epoch 1600: TotalLoss=-0.264040 | Sup=0.004380 | Unsup=-0.298245 | TrainAcc=1.0000
# Fold 5 Epoch 1700: TotalLoss=-0.264029 | Sup=0.005094 | Unsup=-0.299025 | TrainAcc=1.0000
# Fold 5 Epoch 1800: TotalLoss=-0.264491 | Sup=0.005192 | Unsup=-0.299648 | TrainAcc=1.0000
# Fold 5 Epoch 1900: TotalLoss=-0.269152 | Sup=0.000722 | Unsup=-0.299860 | TrainAcc=1.0000
# Fold 5 Epoch 2000: TotalLoss=-0.267110 | Sup=0.002709 | Unsup=-0.299799 | TrainAcc=1.0000
# Fold 5 → Acc=0.8074 | Prec=0.8889 | Rec=0.7467 | F1=0.8116 | AUC=0.8601 | CE Loss=2.1207
#
# === Fold 6 ===
# Train CN: 13, Train MCI: 16
# Fold 6 Epoch 1: TotalLoss=0.564073 | Sup=0.721644 | Unsup=-0.175078 | TrainAcc=0.6207
# Fold 6 Epoch 100: TotalLoss=-0.041662 | Sup=0.184099 | Unsup=-0.250845 | TrainAcc=0.9310
# Fold 6 Epoch 200: TotalLoss=-0.090346 | Sup=0.138175 | Unsup=-0.253912 | TrainAcc=0.9310
# Fold 6 Epoch 300: TotalLoss=-0.104812 | Sup=0.123030 | Unsup=-0.253157 | TrainAcc=0.9310
# Fold 6 Epoch 400: TotalLoss=-0.157094 | Sup=0.072818 | Unsup=-0.255458 | TrainAcc=0.9655
# Fold 6 Epoch 500: TotalLoss=-0.149010 | Sup=0.077418 | Unsup=-0.251587 | TrainAcc=0.9655
# Fold 6 Epoch 600: TotalLoss=-0.195756 | Sup=0.037903 | Unsup=-0.259621 | TrainAcc=1.0000
# Fold 6 Epoch 700: TotalLoss=-0.205741 | Sup=0.027409 | Unsup=-0.259056 | TrainAcc=1.0000
# Fold 6 Epoch 800: TotalLoss=-0.191023 | Sup=0.048901 | Unsup=-0.266582 | TrainAcc=0.9655
# Fold 6 Epoch 900: TotalLoss=-0.215895 | Sup=0.020930 | Unsup=-0.263139 | TrainAcc=1.0000
# Fold 6 Epoch 1000: TotalLoss=-0.233761 | Sup=0.006018 | Unsup=-0.266422 | TrainAcc=1.0000
# Fold 6 Epoch 1100: TotalLoss=-0.224023 | Sup=0.012963 | Unsup=-0.263318 | TrainAcc=1.0000
# Fold 6 Epoch 1200: TotalLoss=-0.238293 | Sup=0.002678 | Unsup=-0.267745 | TrainAcc=1.0000
# Fold 6 Epoch 1300: TotalLoss=-0.219942 | Sup=0.017892 | Unsup=-0.264260 | TrainAcc=1.0000
# Fold 6 Epoch 1400: TotalLoss=-0.226321 | Sup=0.018098 | Unsup=-0.271576 | TrainAcc=1.0000
# Fold 6 Epoch 1500: TotalLoss=-0.238400 | Sup=0.003253 | Unsup=-0.268503 | TrainAcc=1.0000
# Fold 6 Epoch 1600: TotalLoss=-0.234315 | Sup=0.012274 | Unsup=-0.273988 | TrainAcc=1.0000
# Fold 6 Epoch 1700: TotalLoss=-0.239429 | Sup=0.006889 | Unsup=-0.273686 | TrainAcc=1.0000
# Fold 6 Epoch 1800: TotalLoss=-0.238237 | Sup=0.006113 | Unsup=-0.271499 | TrainAcc=1.0000
# Fold 6 Epoch 1900: TotalLoss=-0.238210 | Sup=0.009291 | Unsup=-0.275000 | TrainAcc=1.0000
# Fold 6 Epoch 2000: TotalLoss=-0.242199 | Sup=0.001817 | Unsup=-0.271129 | TrainAcc=1.0000
# Fold 6 → Acc=0.8074 | Prec=0.8356 | Rec=0.8133 | F1=0.8243 | AUC=0.8501 | CE Loss=1.9630
#
# === Fold 7 ===
# Train CN: 13, Train MCI: 16
# Fold 7 Epoch 1: TotalLoss=0.776314 | Sup=0.908163 | Unsup=-0.146499 | TrainAcc=0.3793
# Fold 7 Epoch 100: TotalLoss=0.020050 | Sup=0.233237 | Unsup=-0.236874 | TrainAcc=0.9310
# Fold 7 Epoch 200: TotalLoss=-0.096236 | Sup=0.123048 | Unsup=-0.243649 | TrainAcc=0.9310
# Fold 7 Epoch 300: TotalLoss=-0.108389 | Sup=0.113476 | Unsup=-0.246517 | TrainAcc=0.9310
# Fold 7 Epoch 400: TotalLoss=-0.106189 | Sup=0.118193 | Unsup=-0.249314 | TrainAcc=0.9655
# Fold 7 Epoch 500: TotalLoss=-0.145336 | Sup=0.081689 | Unsup=-0.252251 | TrainAcc=0.9655
# Fold 7 Epoch 600: TotalLoss=-0.152459 | Sup=0.072269 | Unsup=-0.249698 | TrainAcc=0.9655
# Fold 7 Epoch 700: TotalLoss=-0.125273 | Sup=0.097913 | Unsup=-0.247984 | TrainAcc=0.9655
# Fold 7 Epoch 800: TotalLoss=-0.141072 | Sup=0.083459 | Unsup=-0.249478 | TrainAcc=0.9655
# Fold 7 Epoch 900: TotalLoss=-0.193564 | Sup=0.031625 | Unsup=-0.250210 | TrainAcc=1.0000
# Fold 7 Epoch 1000: TotalLoss=-0.184427 | Sup=0.041651 | Unsup=-0.251198 | TrainAcc=1.0000
# Fold 7 Epoch 1100: TotalLoss=-0.205051 | Sup=0.022013 | Unsup=-0.252293 | TrainAcc=1.0000
# Fold 7 Epoch 1200: TotalLoss=-0.214822 | Sup=0.013360 | Unsup=-0.253535 | TrainAcc=1.0000
# Fold 7 Epoch 1300: TotalLoss=-0.221178 | Sup=0.006271 | Unsup=-0.252721 | TrainAcc=1.0000
# Fold 7 Epoch 1400: TotalLoss=-0.214204 | Sup=0.014877 | Unsup=-0.254534 | TrainAcc=1.0000
# Fold 7 Epoch 1500: TotalLoss=-0.209631 | Sup=0.018991 | Unsup=-0.254025 | TrainAcc=1.0000
# Fold 7 Epoch 1600: TotalLoss=-0.219371 | Sup=0.010855 | Unsup=-0.255806 | TrainAcc=1.0000
# Fold 7 Epoch 1700: TotalLoss=-0.226253 | Sup=0.004389 | Unsup=-0.256270 | TrainAcc=1.0000
# Fold 7 Epoch 1800: TotalLoss=-0.194314 | Sup=0.039699 | Unsup=-0.260014 | TrainAcc=0.9655
# Fold 7 Epoch 1900: TotalLoss=-0.178057 | Sup=0.053540 | Unsup=-0.257330 | TrainAcc=0.9310
# Fold 7 Epoch 2000: TotalLoss=-0.225248 | Sup=0.004298 | Unsup=-0.255052 | TrainAcc=1.0000
# Fold 7 → Acc=0.7667 | Prec=0.7514 | Rec=0.8667 | F1=0.8050 | AUC=0.8419 | CE Loss=2.2135
#
# === Fold 8 ===
# Train CN: 13, Train MCI: 16
# Fold 8 Epoch 1: TotalLoss=0.647678 | Sup=0.770829 | Unsup=-0.136835 | TrainAcc=0.4828
# Fold 8 Epoch 100: TotalLoss=-0.022279 | Sup=0.162420 | Unsup=-0.205222 | TrainAcc=0.9655
# Fold 8 Epoch 200: TotalLoss=-0.070442 | Sup=0.123847 | Unsup=-0.215876 | TrainAcc=0.9310
# Fold 8 Epoch 300: TotalLoss=-0.104463 | Sup=0.095883 | Unsup=-0.222607 | TrainAcc=0.9310
# Fold 8 Epoch 400: TotalLoss=-0.157799 | Sup=0.044259 | Unsup=-0.224509 | TrainAcc=1.0000
# Fold 8 Epoch 500: TotalLoss=-0.130578 | Sup=0.080061 | Unsup=-0.234044 | TrainAcc=0.9655
# Fold 8 Epoch 600: TotalLoss=-0.176515 | Sup=0.034340 | Unsup=-0.234283 | TrainAcc=1.0000
# Fold 8 Epoch 700: TotalLoss=-0.169571 | Sup=0.045818 | Unsup=-0.239321 | TrainAcc=0.9655
# Fold 8 Epoch 800: TotalLoss=-0.191404 | Sup=0.018610 | Unsup=-0.233349 | TrainAcc=1.0000
# Fold 8 Epoch 900: TotalLoss=-0.192774 | Sup=0.023794 | Unsup=-0.240631 | TrainAcc=1.0000
# Fold 8 Epoch 1000: TotalLoss=-0.144101 | Sup=0.071391 | Unsup=-0.239436 | TrainAcc=0.9655
# Fold 8 Epoch 1100: TotalLoss=-0.211875 | Sup=0.004250 | Unsup=-0.240139 | TrainAcc=1.0000
# Fold 8 Epoch 1200: TotalLoss=-0.201600 | Sup=0.013246 | Unsup=-0.238717 | TrainAcc=1.0000
# Fold 8 Epoch 1300: TotalLoss=-0.206838 | Sup=0.009410 | Unsup=-0.240275 | TrainAcc=1.0000
# Fold 8 Epoch 1400: TotalLoss=-0.220518 | Sup=0.002151 | Unsup=-0.247410 | TrainAcc=1.0000
# Fold 8 Epoch 1500: TotalLoss=-0.201507 | Sup=0.016970 | Unsup=-0.242752 | TrainAcc=1.0000
# Fold 8 Epoch 1600: TotalLoss=-0.213502 | Sup=0.006012 | Unsup=-0.243905 | TrainAcc=1.0000
# Fold 8 Epoch 1700: TotalLoss=-0.213581 | Sup=0.005779 | Unsup=-0.243734 | TrainAcc=1.0000
# Fold 8 Epoch 1800: TotalLoss=-0.219441 | Sup=0.002818 | Unsup=-0.246955 | TrainAcc=1.0000
# Fold 8 Epoch 1900: TotalLoss=-0.219422 | Sup=0.001233 | Unsup=-0.245172 | TrainAcc=1.0000
# Fold 8 Epoch 2000: TotalLoss=-0.219180 | Sup=0.003182 | Unsup=-0.247069 | TrainAcc=1.0000
# Fold 8 → Acc=0.7296 | Prec=0.6974 | Rec=0.9067 | F1=0.7884 | AUC=0.7834 | CE Loss=2.4311
#
# === Fold 9 ===
# Train CN: 13, Train MCI: 16
# Fold 9 Epoch 1: TotalLoss=0.808410 | Sup=0.933694 | Unsup=-0.139204 | TrainAcc=0.2759
# Fold 9 Epoch 100: TotalLoss=0.035450 | Sup=0.220460 | Unsup=-0.205566 | TrainAcc=0.9310
# Fold 9 Epoch 200: TotalLoss=-0.024303 | Sup=0.176573 | Unsup=-0.223196 | TrainAcc=0.8966
# Fold 9 Epoch 300: TotalLoss=-0.084623 | Sup=0.120947 | Unsup=-0.228412 | TrainAcc=0.9655
# Fold 9 Epoch 400: TotalLoss=-0.124079 | Sup=0.080840 | Unsup=-0.227688 | TrainAcc=0.9655
# Fold 9 Epoch 500: TotalLoss=-0.141509 | Sup=0.066530 | Unsup=-0.231155 | TrainAcc=0.9655
# Fold 9 Epoch 600: TotalLoss=-0.137603 | Sup=0.067868 | Unsup=-0.228301 | TrainAcc=0.9655
# Fold 9 Epoch 700: TotalLoss=-0.144488 | Sup=0.062072 | Unsup=-0.229511 | TrainAcc=1.0000
# Fold 9 Epoch 800: TotalLoss=-0.175970 | Sup=0.030337 | Unsup=-0.229231 | TrainAcc=1.0000
# Fold 9 Epoch 900: TotalLoss=-0.181089 | Sup=0.029596 | Unsup=-0.234094 | TrainAcc=1.0000
# Fold 9 Epoch 1000: TotalLoss=-0.188212 | Sup=0.024394 | Unsup=-0.236229 | TrainAcc=1.0000
# Fold 9 Epoch 1100: TotalLoss=-0.174155 | Sup=0.036531 | Unsup=-0.234096 | TrainAcc=1.0000
# Fold 9 Epoch 1200: TotalLoss=-0.185566 | Sup=0.028294 | Unsup=-0.237622 | TrainAcc=1.0000
# Fold 9 Epoch 1300: TotalLoss=-0.170167 | Sup=0.045204 | Unsup=-0.239301 | TrainAcc=0.9655
# Fold 9 Epoch 1400: TotalLoss=-0.207220 | Sup=0.006867 | Unsup=-0.237874 | TrainAcc=1.0000
# Fold 9 Epoch 1500: TotalLoss=-0.196960 | Sup=0.017911 | Unsup=-0.238745 | TrainAcc=1.0000
# Fold 9 Epoch 1600: TotalLoss=-0.204563 | Sup=0.011842 | Unsup=-0.240449 | TrainAcc=1.0000
# Fold 9 Epoch 1700: TotalLoss=-0.207620 | Sup=0.007780 | Unsup=-0.239333 | TrainAcc=1.0000
# Fold 9 Epoch 1800: TotalLoss=-0.208010 | Sup=0.007739 | Unsup=-0.239721 | TrainAcc=1.0000
# Fold 9 Epoch 1900: TotalLoss=-0.208030 | Sup=0.010688 | Unsup=-0.243020 | TrainAcc=1.0000
# Fold 9 Epoch 2000: TotalLoss=-0.208089 | Sup=0.008263 | Unsup=-0.240391 | TrainAcc=1.0000
# Fold 9 → Acc=0.6778 | Prec=0.9315 | Rec=0.4533 | F1=0.6099 | AUC=0.8712 | CE Loss=1.6092
#
# === Fold 10 ===
# Train CN: 13, Train MCI: 16
# Fold 10 Epoch 1: TotalLoss=0.482747 | Sup=0.612923 | Unsup=-0.144640 | TrainAcc=0.6897
# Fold 10 Epoch 100: TotalLoss=0.057154 | Sup=0.293893 | Unsup=-0.263043 | TrainAcc=0.8276
# Fold 10 Epoch 200: TotalLoss=-0.035153 | Sup=0.204134 | Unsup=-0.265874 | TrainAcc=0.9310
# Fold 10 Epoch 300: TotalLoss=-0.084954 | Sup=0.155382 | Unsup=-0.267039 | TrainAcc=0.9310
# Fold 10 Epoch 400: TotalLoss=-0.141191 | Sup=0.100282 | Unsup=-0.268304 | TrainAcc=0.9655
# Fold 10 Epoch 500: TotalLoss=-0.177495 | Sup=0.067003 | Unsup=-0.271665 | TrainAcc=1.0000
# Fold 10 Epoch 600: TotalLoss=-0.178586 | Sup=0.068813 | Unsup=-0.274888 | TrainAcc=0.9655
# Fold 10 Epoch 700: TotalLoss=-0.216595 | Sup=0.031992 | Unsup=-0.276207 | TrainAcc=1.0000
# Fold 10 Epoch 800: TotalLoss=-0.220991 | Sup=0.029028 | Unsup=-0.277799 | TrainAcc=1.0000
# Fold 10 Epoch 900: TotalLoss=-0.216668 | Sup=0.031781 | Unsup=-0.276055 | TrainAcc=1.0000
# Fold 10 Epoch 1000: TotalLoss=-0.234208 | Sup=0.015890 | Unsup=-0.277887 | TrainAcc=1.0000
# Fold 10 Epoch 1100: TotalLoss=-0.234097 | Sup=0.015336 | Unsup=-0.277148 | TrainAcc=1.0000
# Fold 10 Epoch 1200: TotalLoss=-0.244778 | Sup=0.007772 | Unsup=-0.280612 | TrainAcc=1.0000
# Fold 10 Epoch 1300: TotalLoss=-0.239024 | Sup=0.010820 | Unsup=-0.277604 | TrainAcc=1.0000
# Fold 10 Epoch 1400: TotalLoss=-0.212101 | Sup=0.043510 | Unsup=-0.284011 | TrainAcc=0.9655
# Fold 10 Epoch 1500: TotalLoss=-0.239298 | Sup=0.013651 | Unsup=-0.281055 | TrainAcc=1.0000
# Fold 10 Epoch 1600: TotalLoss=-0.248115 | Sup=0.006024 | Unsup=-0.282377 | TrainAcc=1.0000
# Fold 10 Epoch 1700: TotalLoss=-0.248401 | Sup=0.004273 | Unsup=-0.280749 | TrainAcc=1.0000
# Fold 10 Epoch 1800: TotalLoss=-0.249585 | Sup=0.004834 | Unsup=-0.282688 | TrainAcc=1.0000
# Fold 10 Epoch 1900: TotalLoss=-0.252119 | Sup=0.002839 | Unsup=-0.283287 | TrainAcc=1.0000
# Fold 10 Epoch 2000: TotalLoss=-0.254235 | Sup=0.003621 | Unsup=-0.286507 | TrainAcc=1.0000
# Fold 10 → Acc=0.8111 | Prec=0.8414 | Rec=0.8133 | F1=0.8271 | AUC=0.8407 | CE Loss=1.9538
#
# === Fold 11 ===
# Train CN: 13, Train MCI: 16
# Fold 11 Epoch 1: TotalLoss=0.778265 | Sup=0.913702 | Unsup=-0.150485 | TrainAcc=0.4138
# Fold 11 Epoch 100: TotalLoss=0.061163 | Sup=0.245440 | Unsup=-0.204752 | TrainAcc=0.8621
# Fold 11 Epoch 200: TotalLoss=-0.023372 | Sup=0.163710 | Unsup=-0.207869 | TrainAcc=0.9655
# Fold 11 Epoch 300: TotalLoss=-0.062221 | Sup=0.130831 | Unsup=-0.214503 | TrainAcc=0.9655
# Fold 11 Epoch 400: TotalLoss=-0.152450 | Sup=0.043899 | Unsup=-0.218165 | TrainAcc=1.0000
# Fold 11 Epoch 500: TotalLoss=-0.123043 | Sup=0.077327 | Unsup=-0.222633 | TrainAcc=0.9655
# Fold 11 Epoch 600: TotalLoss=-0.168639 | Sup=0.032043 | Unsup=-0.222980 | TrainAcc=1.0000
# Fold 11 Epoch 700: TotalLoss=-0.182725 | Sup=0.018943 | Unsup=-0.224075 | TrainAcc=1.0000
# Fold 11 Epoch 800: TotalLoss=-0.188843 | Sup=0.012667 | Unsup=-0.223899 | TrainAcc=1.0000
# Fold 11 Epoch 900: TotalLoss=-0.198767 | Sup=0.005392 | Unsup=-0.226844 | TrainAcc=1.0000
# Fold 11 Epoch 1000: TotalLoss=-0.188079 | Sup=0.016158 | Unsup=-0.226930 | TrainAcc=1.0000
# Fold 11 Epoch 1100: TotalLoss=-0.191110 | Sup=0.013528 | Unsup=-0.227376 | TrainAcc=1.0000
# Fold 11 Epoch 1200: TotalLoss=-0.198089 | Sup=0.008589 | Unsup=-0.229641 | TrainAcc=1.0000
# Fold 11 Epoch 1300: TotalLoss=-0.197700 | Sup=0.009820 | Unsup=-0.230577 | TrainAcc=1.0000
# Fold 11 Epoch 1400: TotalLoss=-0.199097 | Sup=0.007135 | Unsup=-0.229146 | TrainAcc=1.0000
# Fold 11 Epoch 1500: TotalLoss=-0.206584 | Sup=0.004032 | Unsup=-0.234018 | TrainAcc=1.0000
# Fold 11 Epoch 1600: TotalLoss=-0.210616 | Sup=0.001427 | Unsup=-0.235604 | TrainAcc=1.0000
# Fold 11 Epoch 1700: TotalLoss=-0.209690 | Sup=0.004369 | Unsup=-0.237844 | TrainAcc=1.0000
# Fold 11 Epoch 1800: TotalLoss=-0.208273 | Sup=0.002094 | Unsup=-0.233741 | TrainAcc=1.0000
# Fold 11 Epoch 1900: TotalLoss=-0.209044 | Sup=0.002448 | Unsup=-0.234991 | TrainAcc=1.0000
# Fold 11 Epoch 2000: TotalLoss=-0.209644 | Sup=0.006272 | Unsup=-0.239907 | TrainAcc=1.0000
# Fold 11 → Acc=0.7222 | Prec=0.6984 | Rec=0.8800 | F1=0.7788 | AUC=0.7711 | CE Loss=2.5949
#
# === Fold 12 ===
# Train CN: 13, Train MCI: 16
# Fold 12 Epoch 1: TotalLoss=0.784690 | Sup=0.919102 | Unsup=-0.149347 | TrainAcc=0.3448
# Fold 12 Epoch 100: TotalLoss=-0.032204 | Sup=0.197815 | Unsup=-0.255576 | TrainAcc=0.9655
# Fold 12 Epoch 200: TotalLoss=-0.089431 | Sup=0.145947 | Unsup=-0.261531 | TrainAcc=0.9310
# Fold 12 Epoch 300: TotalLoss=-0.136520 | Sup=0.097978 | Unsup=-0.260554 | TrainAcc=0.9655
# Fold 12 Epoch 400: TotalLoss=-0.154380 | Sup=0.090193 | Unsup=-0.271748 | TrainAcc=0.9310
# Fold 12 Epoch 500: TotalLoss=-0.180503 | Sup=0.058026 | Unsup=-0.265033 | TrainAcc=0.9655
# Fold 12 Epoch 600: TotalLoss=-0.203011 | Sup=0.038093 | Unsup=-0.267894 | TrainAcc=1.0000
# Fold 12 Epoch 700: TotalLoss=-0.232524 | Sup=0.013748 | Unsup=-0.273636 | TrainAcc=1.0000
# Fold 12 Epoch 800: TotalLoss=-0.223264 | Sup=0.023866 | Unsup=-0.274589 | TrainAcc=1.0000
# Fold 12 Epoch 900: TotalLoss=-0.233365 | Sup=0.013467 | Unsup=-0.274258 | TrainAcc=1.0000
# Fold 12 Epoch 1000: TotalLoss=-0.232914 | Sup=0.015804 | Unsup=-0.276354 | TrainAcc=1.0000
# Fold 12 Epoch 1100: TotalLoss=-0.246573 | Sup=0.004987 | Unsup=-0.279510 | TrainAcc=1.0000
# Fold 12 Epoch 1200: TotalLoss=-0.239227 | Sup=0.012842 | Unsup=-0.280077 | TrainAcc=1.0000
# Fold 12 Epoch 1300: TotalLoss=-0.249659 | Sup=0.005333 | Unsup=-0.283324 | TrainAcc=1.0000
# Fold 12 Epoch 1400: TotalLoss=-0.252356 | Sup=0.002823 | Unsup=-0.283533 | TrainAcc=1.0000
# Fold 12 Epoch 1500: TotalLoss=-0.249589 | Sup=0.005825 | Unsup=-0.283793 | TrainAcc=1.0000
# Fold 12 Epoch 1600: TotalLoss=-0.242574 | Sup=0.010970 | Unsup=-0.281716 | TrainAcc=1.0000
# Fold 12 Epoch 1700: TotalLoss=-0.251135 | Sup=0.001225 | Unsup=-0.280399 | TrainAcc=1.0000
# Fold 12 Epoch 1800: TotalLoss=-0.250191 | Sup=0.001976 | Unsup=-0.280186 | TrainAcc=1.0000
# Fold 12 Epoch 1900: TotalLoss=-0.254696 | Sup=0.000605 | Unsup=-0.283668 | TrainAcc=1.0000
# Fold 12 Epoch 2000: TotalLoss=-0.253757 | Sup=0.001870 | Unsup=-0.284030 | TrainAcc=1.0000
# Fold 12 → Acc=0.8222 | Prec=0.8592 | Rec=0.8133 | F1=0.8356 | AUC=0.8472 | CE Loss=1.8828
#
# === Fold 13 ===
# Train CN: 13, Train MCI: 16
# Fold 13 Epoch 1: TotalLoss=0.593716 | Sup=0.720253 | Unsup=-0.140596 | TrainAcc=0.5517
# Fold 13 Epoch 100: TotalLoss=-0.014330 | Sup=0.207261 | Unsup=-0.246213 | TrainAcc=0.8966
# Fold 13 Epoch 200: TotalLoss=-0.056819 | Sup=0.165760 | Unsup=-0.247310 | TrainAcc=0.9310
# Fold 13 Epoch 300: TotalLoss=-0.119358 | Sup=0.105478 | Unsup=-0.249817 | TrainAcc=0.9310
# Fold 13 Epoch 400: TotalLoss=-0.134056 | Sup=0.098873 | Unsup=-0.258810 | TrainAcc=0.9655
# Fold 13 Epoch 500: TotalLoss=-0.183296 | Sup=0.055003 | Unsup=-0.264777 | TrainAcc=0.9655
# Fold 13 Epoch 600: TotalLoss=-0.164220 | Sup=0.064373 | Unsup=-0.253992 | TrainAcc=0.9655
# Fold 13 Epoch 700: TotalLoss=-0.196172 | Sup=0.043397 | Unsup=-0.266188 | TrainAcc=1.0000
# Fold 13 Epoch 800: TotalLoss=-0.203429 | Sup=0.030668 | Unsup=-0.260107 | TrainAcc=1.0000
# Fold 13 Epoch 900: TotalLoss=-0.217286 | Sup=0.026821 | Unsup=-0.271230 | TrainAcc=1.0000
# Fold 13 Epoch 1000: TotalLoss=-0.219997 | Sup=0.023269 | Unsup=-0.270295 | TrainAcc=1.0000
# Fold 13 Epoch 1100: TotalLoss=-0.236503 | Sup=0.012540 | Unsup=-0.276714 | TrainAcc=1.0000
# Fold 13 Epoch 1200: TotalLoss=-0.222166 | Sup=0.026534 | Unsup=-0.276333 | TrainAcc=1.0000
# Fold 13 Epoch 1300: TotalLoss=-0.243110 | Sup=0.005491 | Unsup=-0.276223 | TrainAcc=1.0000
# Fold 13 Epoch 1400: TotalLoss=-0.248365 | Sup=0.008387 | Unsup=-0.285280 | TrainAcc=1.0000
# Fold 13 Epoch 1500: TotalLoss=-0.242464 | Sup=0.014625 | Unsup=-0.285654 | TrainAcc=1.0000
# Fold 13 Epoch 1600: TotalLoss=-0.252419 | Sup=0.006096 | Unsup=-0.287240 | TrainAcc=1.0000
# Fold 13 Epoch 1700: TotalLoss=-0.249064 | Sup=0.010029 | Unsup=-0.287881 | TrainAcc=1.0000
# Fold 13 Epoch 1800: TotalLoss=-0.238471 | Sup=0.015235 | Unsup=-0.281895 | TrainAcc=1.0000
# Fold 13 Epoch 1900: TotalLoss=-0.261476 | Sup=0.001345 | Unsup=-0.292024 | TrainAcc=1.0000
# Fold 13 Epoch 2000: TotalLoss=-0.254460 | Sup=0.007459 | Unsup=-0.291021 | TrainAcc=1.0000
# Fold 13 → Acc=0.7963 | Prec=0.8682 | Rec=0.7467 | F1=0.8029 | AUC=0.8603 | CE Loss=1.7008
#
# === Fold 14 ===
# Train CN: 13, Train MCI: 16
# Fold 14 Epoch 1: TotalLoss=0.547991 | Sup=0.676608 | Unsup=-0.142907 | TrainAcc=0.6207
# Fold 14 Epoch 100: TotalLoss=0.071966 | Sup=0.257047 | Unsup=-0.205646 | TrainAcc=0.8621
# Fold 14 Epoch 200: TotalLoss=0.016485 | Sup=0.211867 | Unsup=-0.217091 | TrainAcc=0.8966
# Fold 14 Epoch 300: TotalLoss=-0.047924 | Sup=0.150420 | Unsup=-0.220382 | TrainAcc=1.0000
# Fold 14 Epoch 400: TotalLoss=-0.064479 | Sup=0.134916 | Unsup=-0.221550 | TrainAcc=0.9310
# Fold 14 Epoch 500: TotalLoss=-0.125769 | Sup=0.073008 | Unsup=-0.220864 | TrainAcc=0.9655
# Fold 14 Epoch 600: TotalLoss=-0.118398 | Sup=0.085373 | Unsup=-0.226412 | TrainAcc=0.9655
# Fold 14 Epoch 700: TotalLoss=-0.138654 | Sup=0.064503 | Unsup=-0.225731 | TrainAcc=1.0000
# Fold 14 Epoch 800: TotalLoss=-0.189951 | Sup=0.014719 | Unsup=-0.227411 | TrainAcc=1.0000
# Fold 14 Epoch 900: TotalLoss=-0.184641 | Sup=0.022543 | Unsup=-0.230204 | TrainAcc=1.0000
# Fold 14 Epoch 1000: TotalLoss=-0.190803 | Sup=0.014993 | Unsup=-0.228662 | TrainAcc=1.0000
# Fold 14 Epoch 1100: TotalLoss=-0.179976 | Sup=0.027400 | Unsup=-0.230418 | TrainAcc=1.0000
# Fold 14 Epoch 1200: TotalLoss=-0.201831 | Sup=0.009630 | Unsup=-0.234957 | TrainAcc=1.0000
# Fold 14 Epoch 1300: TotalLoss=-0.189848 | Sup=0.017536 | Unsup=-0.230427 | TrainAcc=1.0000
# Fold 14 Epoch 1400: TotalLoss=-0.207332 | Sup=0.003900 | Unsup=-0.234702 | TrainAcc=1.0000
# Fold 14 Epoch 1500: TotalLoss=-0.203948 | Sup=0.003077 | Unsup=-0.230027 | TrainAcc=1.0000
# Fold 14 Epoch 1600: TotalLoss=-0.205404 | Sup=0.007157 | Unsup=-0.236179 | TrainAcc=1.0000
# Fold 14 Epoch 1700: TotalLoss=-0.203231 | Sup=0.005124 | Unsup=-0.231505 | TrainAcc=1.0000
# Fold 14 Epoch 1800: TotalLoss=-0.208126 | Sup=0.004630 | Unsup=-0.236396 | TrainAcc=1.0000
# Fold 14 Epoch 1900: TotalLoss=-0.209169 | Sup=0.002429 | Unsup=-0.235108 | TrainAcc=1.0000
# Fold 14 Epoch 2000: TotalLoss=-0.200346 | Sup=0.010921 | Unsup=-0.234742 | TrainAcc=1.0000
# Fold 14 → Acc=0.7778 | Prec=0.7446 | Rec=0.9133 | F1=0.8204 | AUC=0.8703 | CE Loss=2.0881
#
# === Fold 15 ===
# Train CN: 13, Train MCI: 16
# Fold 15 Epoch 1: TotalLoss=0.690982 | Sup=0.816613 | Unsup=-0.139591 | TrainAcc=0.3103
# Fold 15 Epoch 100: TotalLoss=0.000742 | Sup=0.218783 | Unsup=-0.242268 | TrainAcc=0.8621
# Fold 15 Epoch 200: TotalLoss=-0.013632 | Sup=0.204583 | Unsup=-0.242461 | TrainAcc=0.8621
# Fold 15 Epoch 300: TotalLoss=-0.072152 | Sup=0.145874 | Unsup=-0.242251 | TrainAcc=0.9310
# Fold 15 Epoch 400: TotalLoss=-0.092207 | Sup=0.127934 | Unsup=-0.244601 | TrainAcc=0.9655
# Fold 15 Epoch 500: TotalLoss=-0.143790 | Sup=0.070736 | Unsup=-0.238363 | TrainAcc=1.0000
# Fold 15 Epoch 600: TotalLoss=-0.186195 | Sup=0.034061 | Unsup=-0.244729 | TrainAcc=1.0000
# Fold 15 Epoch 700: TotalLoss=-0.194543 | Sup=0.024745 | Unsup=-0.243654 | TrainAcc=1.0000
# Fold 15 Epoch 800: TotalLoss=-0.179951 | Sup=0.046212 | Unsup=-0.251292 | TrainAcc=1.0000
# Fold 15 Epoch 900: TotalLoss=-0.213499 | Sup=0.010383 | Unsup=-0.248757 | TrainAcc=1.0000
# Fold 15 Epoch 1000: TotalLoss=-0.169440 | Sup=0.063599 | Unsup=-0.258932 | TrainAcc=0.9655
# Fold 15 Epoch 1100: TotalLoss=-0.200025 | Sup=0.033419 | Unsup=-0.259382 | TrainAcc=0.9655
# Fold 15 Epoch 1200: TotalLoss=-0.220456 | Sup=0.016432 | Unsup=-0.263209 | TrainAcc=1.0000
# Fold 15 Epoch 1300: TotalLoss=-0.228187 | Sup=0.009125 | Unsup=-0.263679 | TrainAcc=1.0000
# Fold 15 Epoch 1400: TotalLoss=-0.228770 | Sup=0.007768 | Unsup=-0.262821 | TrainAcc=1.0000
# Fold 15 Epoch 1500: TotalLoss=-0.207601 | Sup=0.036000 | Unsup=-0.270668 | TrainAcc=0.9655
# Fold 15 Epoch 1600: TotalLoss=-0.240558 | Sup=0.003530 | Unsup=-0.271209 | TrainAcc=1.0000
# Fold 15 Epoch 1700: TotalLoss=-0.240242 | Sup=0.002595 | Unsup=-0.269819 | TrainAcc=1.0000
# Fold 15 Epoch 1800: TotalLoss=-0.243409 | Sup=0.003116 | Unsup=-0.273917 | TrainAcc=1.0000
# Fold 15 Epoch 1900: TotalLoss=-0.239209 | Sup=0.001524 | Unsup=-0.267480 | TrainAcc=1.0000
# Fold 15 Epoch 2000: TotalLoss=-0.247273 | Sup=0.002122 | Unsup=-0.277106 | TrainAcc=1.0000
# Fold 15 → Acc=0.7889 | Prec=0.8298 | Rec=0.7800 | F1=0.8041 | AUC=0.8620 | CE Loss=1.9585
#
# === Fold 16 ===
# Train CN: 13, Train MCI: 16
# Fold 16 Epoch 1: TotalLoss=0.665596 | Sup=0.788423 | Unsup=-0.136475 | TrainAcc=0.5517
# Fold 16 Epoch 100: TotalLoss=0.083122 | Sup=0.273804 | Unsup=-0.211869 | TrainAcc=0.8966
# Fold 16 Epoch 200: TotalLoss=-0.018402 | Sup=0.172876 | Unsup=-0.212531 | TrainAcc=0.9655
# Fold 16 Epoch 300: TotalLoss=-0.083590 | Sup=0.115746 | Unsup=-0.221485 | TrainAcc=0.9655
# Fold 16 Epoch 400: TotalLoss=-0.119698 | Sup=0.091231 | Unsup=-0.234366 | TrainAcc=0.9310
# Fold 16 Epoch 500: TotalLoss=-0.168890 | Sup=0.056543 | Unsup=-0.250481 | TrainAcc=1.0000
# Fold 16 Epoch 600: TotalLoss=-0.200972 | Sup=0.023784 | Unsup=-0.249729 | TrainAcc=1.0000
# Fold 16 Epoch 700: TotalLoss=-0.204945 | Sup=0.022999 | Unsup=-0.253271 | TrainAcc=1.0000
# Fold 16 Epoch 800: TotalLoss=-0.212215 | Sup=0.025173 | Unsup=-0.263764 | TrainAcc=1.0000
# Fold 16 Epoch 900: TotalLoss=-0.229630 | Sup=0.006071 | Unsup=-0.261890 | TrainAcc=1.0000
# Fold 16 Epoch 1000: TotalLoss=-0.226762 | Sup=0.009274 | Unsup=-0.262262 | TrainAcc=1.0000
# Fold 16 Epoch 1100: TotalLoss=-0.238863 | Sup=0.003493 | Unsup=-0.269285 | TrainAcc=1.0000
# Fold 16 Epoch 1200: TotalLoss=-0.237578 | Sup=0.003075 | Unsup=-0.267392 | TrainAcc=1.0000
# Fold 16 Epoch 1300: TotalLoss=-0.241238 | Sup=0.007621 | Unsup=-0.276510 | TrainAcc=1.0000
# Fold 16 Epoch 1400: TotalLoss=-0.245687 | Sup=0.002403 | Unsup=-0.275655 | TrainAcc=1.0000
# Fold 16 Epoch 1500: TotalLoss=-0.182786 | Sup=0.068907 | Unsup=-0.279658 | TrainAcc=0.9655
# Fold 16 Epoch 1600: TotalLoss=-0.246283 | Sup=0.003086 | Unsup=-0.277077 | TrainAcc=1.0000
# Fold 16 Epoch 1700: TotalLoss=-0.250304 | Sup=0.000509 | Unsup=-0.278681 | TrainAcc=1.0000
# Fold 16 Epoch 1800: TotalLoss=-0.248016 | Sup=0.003927 | Unsup=-0.279936 | TrainAcc=1.0000
# Fold 16 Epoch 1900: TotalLoss=-0.246324 | Sup=0.004545 | Unsup=-0.278744 | TrainAcc=1.0000
# Fold 16 Epoch 2000: TotalLoss=-0.244389 | Sup=0.006846 | Unsup=-0.279150 | TrainAcc=1.0000
# Fold 16 → Acc=0.8111 | Prec=0.8613 | Rec=0.7867 | F1=0.8223 | AUC=0.8680 | CE Loss=1.3860
#
# === Fold 17 ===
# Train CN: 13, Train MCI: 16
# Fold 17 Epoch 1: TotalLoss=0.591513 | Sup=0.719471 | Unsup=-0.142175 | TrainAcc=0.6207
# Fold 17 Epoch 100: TotalLoss=0.069453 | Sup=0.276605 | Unsup=-0.230169 | TrainAcc=0.8621
# Fold 17 Epoch 200: TotalLoss=-0.025242 | Sup=0.177740 | Unsup=-0.225535 | TrainAcc=0.9310
# Fold 17 Epoch 300: TotalLoss=-0.008164 | Sup=0.197964 | Unsup=-0.229031 | TrainAcc=0.9310
# Fold 17 Epoch 400: TotalLoss=-0.112651 | Sup=0.082001 | Unsup=-0.216280 | TrainAcc=1.0000
# Fold 17 Epoch 500: TotalLoss=-0.127271 | Sup=0.072471 | Unsup=-0.221936 | TrainAcc=1.0000
# Fold 17 Epoch 600: TotalLoss=-0.148930 | Sup=0.060552 | Unsup=-0.232757 | TrainAcc=1.0000
# Fold 17 Epoch 700: TotalLoss=-0.170488 | Sup=0.041393 | Unsup=-0.235424 | TrainAcc=1.0000
# Fold 17 Epoch 800: TotalLoss=-0.178841 | Sup=0.037116 | Unsup=-0.239952 | TrainAcc=1.0000
# Fold 17 Epoch 900: TotalLoss=-0.200242 | Sup=0.013892 | Unsup=-0.237927 | TrainAcc=1.0000
# Fold 17 Epoch 1000: TotalLoss=-0.209397 | Sup=0.008282 | Unsup=-0.241866 | TrainAcc=1.0000
# Fold 17 Epoch 1100: TotalLoss=-0.180933 | Sup=0.037849 | Unsup=-0.243090 | TrainAcc=1.0000
# Fold 17 Epoch 1200: TotalLoss=-0.189073 | Sup=0.029405 | Unsup=-0.242754 | TrainAcc=1.0000
# Fold 17 Epoch 1300: TotalLoss=-0.199408 | Sup=0.019386 | Unsup=-0.243105 | TrainAcc=1.0000
# Fold 17 Epoch 1400: TotalLoss=-0.189578 | Sup=0.028093 | Unsup=-0.241857 | TrainAcc=1.0000
# Fold 17 Epoch 1500: TotalLoss=-0.206427 | Sup=0.014065 | Unsup=-0.244991 | TrainAcc=1.0000
# Fold 17 Epoch 1600: TotalLoss=-0.206234 | Sup=0.013742 | Unsup=-0.244418 | TrainAcc=1.0000
# Fold 17 Epoch 1700: TotalLoss=-0.211004 | Sup=0.010779 | Unsup=-0.246425 | TrainAcc=1.0000
# Fold 17 Epoch 1800: TotalLoss=-0.217115 | Sup=0.003006 | Unsup=-0.244580 | TrainAcc=1.0000
# Fold 17 Epoch 1900: TotalLoss=-0.213817 | Sup=0.007631 | Unsup=-0.246053 | TrainAcc=1.0000
# Fold 17 Epoch 2000: TotalLoss=-0.214896 | Sup=0.004877 | Unsup=-0.244192 | TrainAcc=1.0000
# Fold 17 → Acc=0.7741 | Prec=0.7380 | Rec=0.9200 | F1=0.8190 | AUC=0.8203 | CE Loss=1.7224
#
# === Fold 18 ===
# Train CN: 13, Train MCI: 16
# Fold 18 Epoch 1: TotalLoss=0.518471 | Sup=0.642831 | Unsup=-0.138179 | TrainAcc=0.6552
# Fold 18 Epoch 100: TotalLoss=0.031911 | Sup=0.245508 | Unsup=-0.237330 | TrainAcc=0.8966
# Fold 18 Epoch 200: TotalLoss=-0.055131 | Sup=0.158579 | Unsup=-0.237456 | TrainAcc=0.8966
# Fold 18 Epoch 300: TotalLoss=-0.102989 | Sup=0.109264 | Unsup=-0.235837 | TrainAcc=1.0000
# Fold 18 Epoch 400: TotalLoss=-0.120702 | Sup=0.092563 | Unsup=-0.236962 | TrainAcc=1.0000
# Fold 18 Epoch 500: TotalLoss=-0.139520 | Sup=0.074997 | Unsup=-0.238352 | TrainAcc=1.0000
# Fold 18 Epoch 600: TotalLoss=-0.173762 | Sup=0.047997 | Unsup=-0.246399 | TrainAcc=1.0000
# Fold 18 Epoch 700: TotalLoss=-0.198283 | Sup=0.021190 | Unsup=-0.243860 | TrainAcc=1.0000
# Fold 18 Epoch 800: TotalLoss=-0.196253 | Sup=0.029220 | Unsup=-0.250525 | TrainAcc=1.0000
# Fold 18 Epoch 900: TotalLoss=-0.210536 | Sup=0.019424 | Unsup=-0.255510 | TrainAcc=1.0000
# Fold 18 Epoch 1000: TotalLoss=-0.199767 | Sup=0.035894 | Unsup=-0.261845 | TrainAcc=1.0000
# Fold 18 Epoch 1100: TotalLoss=-0.219577 | Sup=0.010162 | Unsup=-0.255266 | TrainAcc=1.0000
# Fold 18 Epoch 1200: TotalLoss=-0.229112 | Sup=0.004999 | Unsup=-0.260124 | TrainAcc=1.0000
# Fold 18 Epoch 1300: TotalLoss=-0.213942 | Sup=0.019753 | Unsup=-0.259661 | TrainAcc=1.0000
# Fold 18 Epoch 1400: TotalLoss=-0.231138 | Sup=0.009746 | Unsup=-0.267649 | TrainAcc=1.0000
# Fold 18 Epoch 1500: TotalLoss=-0.229344 | Sup=0.005254 | Unsup=-0.260664 | TrainAcc=1.0000
# Fold 18 Epoch 1600: TotalLoss=-0.231840 | Sup=0.004102 | Unsup=-0.262158 | TrainAcc=1.0000
# Fold 18 Epoch 1700: TotalLoss=-0.182401 | Sup=0.058095 | Unsup=-0.267218 | TrainAcc=0.9655
# Fold 18 Epoch 1800: TotalLoss=-0.232674 | Sup=0.010041 | Unsup=-0.269683 | TrainAcc=1.0000
# Fold 18 Epoch 1900: TotalLoss=-0.236160 | Sup=0.009123 | Unsup=-0.272536 | TrainAcc=1.0000
# Fold 18 Epoch 2000: TotalLoss=-0.239148 | Sup=0.007649 | Unsup=-0.274219 | TrainAcc=1.0000
# Fold 18 → Acc=0.8259 | Prec=0.8552 | Rec=0.8267 | F1=0.8407 | AUC=0.8818 | CE Loss=1.3579
#
# === Fold 19 ===
# Train CN: 13, Train MCI: 16
# Fold 19 Epoch 1: TotalLoss=0.778231 | Sup=0.901073 | Unsup=-0.136491 | TrainAcc=0.4138
# Fold 19 Epoch 100: TotalLoss=-0.101418 | Sup=0.132399 | Unsup=-0.259797 | TrainAcc=0.9310
# Fold 19 Epoch 200: TotalLoss=-0.131873 | Sup=0.105184 | Unsup=-0.263397 | TrainAcc=0.9655
# Fold 19 Epoch 300: TotalLoss=-0.160533 | Sup=0.076578 | Unsup=-0.263457 | TrainAcc=0.9655
# Fold 19 Epoch 400: TotalLoss=-0.205765 | Sup=0.036918 | Unsup=-0.269648 | TrainAcc=1.0000
# Fold 19 Epoch 500: TotalLoss=-0.221646 | Sup=0.021685 | Unsup=-0.270368 | TrainAcc=1.0000
# Fold 19 Epoch 600: TotalLoss=-0.230302 | Sup=0.017993 | Unsup=-0.275884 | TrainAcc=1.0000
# Fold 19 Epoch 700: TotalLoss=-0.224375 | Sup=0.021376 | Unsup=-0.273056 | TrainAcc=1.0000
# Fold 19 Epoch 800: TotalLoss=-0.240124 | Sup=0.006615 | Unsup=-0.274154 | TrainAcc=1.0000
# Fold 19 Epoch 900: TotalLoss=-0.238344 | Sup=0.008968 | Unsup=-0.274792 | TrainAcc=1.0000
# Fold 19 Epoch 1000: TotalLoss=-0.243318 | Sup=0.004225 | Unsup=-0.275048 | TrainAcc=1.0000
# Fold 19 Epoch 1100: TotalLoss=-0.243482 | Sup=0.004244 | Unsup=-0.275251 | TrainAcc=1.0000
# Fold 19 Epoch 1200: TotalLoss=-0.235689 | Sup=0.015662 | Unsup=-0.279279 | TrainAcc=1.0000
# Fold 19 Epoch 1300: TotalLoss=-0.237980 | Sup=0.008862 | Unsup=-0.274268 | TrainAcc=1.0000
# Fold 19 Epoch 1400: TotalLoss=-0.245640 | Sup=0.002426 | Unsup=-0.275628 | TrainAcc=1.0000
# Fold 19 Epoch 1500: TotalLoss=-0.246674 | Sup=0.004270 | Unsup=-0.278826 | TrainAcc=1.0000
# Fold 19 Epoch 1600: TotalLoss=-0.249753 | Sup=0.003734 | Unsup=-0.281652 | TrainAcc=1.0000
# Fold 19 Epoch 1700: TotalLoss=-0.245475 | Sup=0.003560 | Unsup=-0.276705 | TrainAcc=1.0000
# Fold 19 Epoch 1800: TotalLoss=-0.251540 | Sup=0.001549 | Unsup=-0.281210 | TrainAcc=1.0000
# Fold 19 Epoch 1900: TotalLoss=-0.251164 | Sup=0.002676 | Unsup=-0.282045 | TrainAcc=1.0000
# Fold 19 Epoch 2000: TotalLoss=-0.243976 | Sup=0.001358 | Unsup=-0.272593 | TrainAcc=1.0000
# Fold 19 → Acc=0.7963 | Prec=0.8322 | Rec=0.7933 | F1=0.8123 | AUC=0.8728 | CE Loss=1.8302
#
# === Fold 20 ===
# Train CN: 13, Train MCI: 16
# Fold 20 Epoch 1: TotalLoss=0.536639 | Sup=0.677508 | Unsup=-0.156522 | TrainAcc=0.5862
# Fold 20 Epoch 100: TotalLoss=0.145173 | Sup=0.347031 | Unsup=-0.224287 | TrainAcc=0.7586
# Fold 20 Epoch 200: TotalLoss=0.028008 | Sup=0.230392 | Unsup=-0.224871 | TrainAcc=0.8621
# Fold 20 Epoch 300: TotalLoss=-0.003298 | Sup=0.192945 | Unsup=-0.218048 | TrainAcc=0.8621
# Fold 20 Epoch 400: TotalLoss=-0.050283 | Sup=0.151864 | Unsup=-0.224607 | TrainAcc=0.9310
# Fold 20 Epoch 500: TotalLoss=-0.067500 | Sup=0.137931 | Unsup=-0.228256 | TrainAcc=0.9310
# Fold 20 Epoch 600: TotalLoss=-0.138710 | Sup=0.066603 | Unsup=-0.228125 | TrainAcc=0.9655
# Fold 20 Epoch 700: TotalLoss=-0.115928 | Sup=0.091769 | Unsup=-0.230774 | TrainAcc=1.0000
# Fold 20 Epoch 800: TotalLoss=-0.135523 | Sup=0.077217 | Unsup=-0.236378 | TrainAcc=0.9655
# Fold 20 Epoch 900: TotalLoss=-0.167422 | Sup=0.045800 | Unsup=-0.236913 | TrainAcc=1.0000
# Fold 20 Epoch 1000: TotalLoss=-0.154821 | Sup=0.063162 | Unsup=-0.242204 | TrainAcc=1.0000
# Fold 20 Epoch 1100: TotalLoss=-0.176297 | Sup=0.042494 | Unsup=-0.243102 | TrainAcc=1.0000
# Fold 20 Epoch 1200: TotalLoss=-0.205766 | Sup=0.013493 | Unsup=-0.243622 | TrainAcc=1.0000
# Fold 20 Epoch 1300: TotalLoss=-0.211302 | Sup=0.008406 | Unsup=-0.244120 | TrainAcc=1.0000
# Fold 20 Epoch 1400: TotalLoss=-0.180961 | Sup=0.055159 | Unsup=-0.262356 | TrainAcc=0.9655
# Fold 20 Epoch 1500: TotalLoss=-0.192012 | Sup=0.026562 | Unsup=-0.242859 | TrainAcc=1.0000
# Fold 20 Epoch 1600: TotalLoss=-0.213838 | Sup=0.011125 | Unsup=-0.249960 | TrainAcc=1.0000
# Fold 20 Epoch 1700: TotalLoss=-0.213314 | Sup=0.016977 | Unsup=-0.255879 | TrainAcc=1.0000
# Fold 20 Epoch 1800: TotalLoss=-0.221631 | Sup=0.004757 | Unsup=-0.251542 | TrainAcc=1.0000
# Fold 20 Epoch 1900: TotalLoss=-0.223445 | Sup=0.003652 | Unsup=-0.252331 | TrainAcc=1.0000
# Fold 20 Epoch 2000: TotalLoss=-0.230995 | Sup=0.003905 | Unsup=-0.261001 | TrainAcc=1.0000
# Fold 20 → Acc=0.7852 | Prec=0.7987 | Rec=0.8200 | F1=0.8092 | AUC=0.8387 | CE Loss=1.6914
#
# === Average Results Across 20 Folds ===
# Accuracy:  0.7813 ± 0.0352
# Precision: 0.8136 ± 0.0643
# Recall:    0.8050 ± 0.0990
# F1-score:  0.8012 ± 0.0464
# AUC:       0.8439 ± 0.0283
# CE Loss:   1.9140 ± 0.2999

# %%
# import torch
# import torch.nn as nn
# import torch.optim as optim
# import numpy as np
# import pandas as pd
# from sklearn.model_selection import StratifiedShuffleSplit
# from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, log_loss
# from torch_geometric.data import Data
# from torch_geometric.nn import ChebConv
# import torch.nn.functional as nnFn
# SEED = 42
# np.random.seed(SEED)
# torch.manual_seed(SEED)
# if torch.cuda.is_available():
#     torch.cuda.manual_seed_all(SEED)

# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# hidden_dim = 512
# num_epochs = 2000
# lr = 1e-4
# weight_decay = 1e-4
# batch_print_freq = 500  # print every 500 epochs

# # Use same λ list as before
# lambda_mod_list = [0.001, 0.005, 0.009, 0.01, 0.05, 0.09, 0.1, 0.3, 0.5, 0.9, 1, 2, 5, 8]


# results_summary = []

# # ==========================================
# # Run for each λ_mod
# # ==========================================
# for lambda_mod in lambda_mod_list:
#     print(f"\n==============================")
#     print(f" Running with λ_mod = {lambda_mod}")
#     print(f"==============================")

#     accuracies, precisions, recalls, f1_scores, aucs, ce_losses = [], [], [], [], [], []

#     sss = StratifiedShuffleSplit(n_splits=20, test_size=0.5, random_state=SEED)

#     for fold, (train_val_idx, test_idx_global) in enumerate(sss.split(X, y), start=1):
#         print(f"\n=== Fold {fold} ===")

#         cn_idx = np.where(y == 0)[0]
#         mci_idx = np.where(y == 1)[0] # Changed 'ad_idx' to 'mci_idx'

#         sss_class = StratifiedShuffleSplit(n_splits=20, test_size=0.5, random_state=fold)
#         cn_train_idx, _ = next(sss_class.split(X[cn_idx], y[cn_idx]))
#         mci_train_idx, _ = next(sss_class.split(X[mci_idx], y[mci_idx])) # Changed 'ad_train_idx' to 'mci_train_idx'

#         cn_train = cn_idx[cn_train_idx]
#         mci_train = mci_idx[mci_train_idx] # Changed 'ad_train' to 'mci_train'
#         train_idx_final = np.concatenate([cn_train, mci_train]) # Changed 'ad_train' to 'mci_train'
#         np.random.shuffle(train_idx_final)

#         print(f"Train CN: {len(cn_train)}, Train MCI: {len(mci_train)}") # Changed 'AD' to 'MCI'

#         train_idx_t = torch.from_numpy(train_idx_final).long().to(device)
#         y_train_tensor = torch.from_numpy(y[train_idx_final]).long().to(device)

#         # Initialize model
#         model = GCN_SemiSupervised(feats_dim, hidden_dim, num_classes, device, activ="RELU").to(device)
#         optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
#         ce_loss = nn.CrossEntropyLoss()

#         # Training loop
#         for epoch in range(1, num_epochs + 1):
#             model.train()
#             optimizer.zero_grad()

#             logits = model(data)
#             loss_sup = ce_loss(logits[train_idx_t], y_train_tensor)
#             loss_unsup = model.modularity_loss(A_tensor, logits)
#             total_loss = loss_sup + lambda_mod * loss_unsup

#             total_loss.backward()
#             optimizer.step()

#             if epoch % batch_print_freq == 0 or epoch == 1:
#                 model.eval()
#                 with torch.no_grad():
#                     logits_eval = model(data)
#                     preds_train = logits_eval[train_idx_t].argmax(dim=1).cpu().numpy()
#                     acc_train = accuracy_score(y_train_tensor.cpu().numpy(), preds_train)
#                 print(f"Fold {fold} Epoch {epoch}: "
#                       f"TotalLoss={total_loss.item():.6f} | Sup={loss_sup.item():.6f} | "
#                       f"Unsup={loss_unsup.item():.6f} | TrainAcc={acc_train:.4f}")

#         # Evaluation
#         model.eval()
#         with torch.no_grad():
#             out = model(data)
#             preds = out.argmax(dim=1).cpu().numpy()
#             probs = torch.softmax(out, dim=1)[:, 1].cpu().numpy()  # probability for "MCI" # Changed 'AD' to 'MCI'

#         y_test = y[test_idx_global]
#         y_pred_test = preds[test_idx_global]
#         y_prob_test = probs[test_idx_global]

#         acc = accuracy_score(y_test, y_pred_test)
#         prec = precision_score(y_test, y_pred_test, zero_division=0)
#         rec = recall_score(y_test, y_pred_test, zero_division=0)
#         f1 = f1_score(y_test, y_pred_test, zero_division=0)
#         auc = roc_auc_score(y_test, y_prob_test)
#         ce = log_loss(y_test, y_prob_test)

#         accuracies.append(acc)
#         precisions.append(prec)
#         recalls.append(rec)
#         f1_scores.append(f1)
#         aucs.append(auc)
#         ce_losses.append(ce)

#         print(f"Fold {fold} → "
#               f"Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | "
#               f"F1={f1:.4f} | AUC={auc:.4f} | CE Loss={ce:.4f}")

#     # Average results per λ_mod
#     mean_acc, std_acc = np.mean(accuracies), np.std(accuracies)
#     mean_prec, std_prec = np.mean(precisions), np.std(precisions)
#     mean_rec, std_rec = np.mean(recalls), np.std(recalls)
#     mean_f1, std_f1 = np.mean(f1_scores), np.std(f1_scores)
#     mean_auc, std_auc = np.mean(aucs), np.std(aucs)
#     mean_ce, std_ce = np.mean(ce_losses), np.std(ce_losses)

#     results_summary.append({
#         "λ_mod": lambda_mod,
#         "Accuracy": f"{mean_acc:.4f} ± {std_acc:.4f}",
#         "Precision": f"{mean_prec:.4f} ± {std_prec:.4f}",
#         "Recall": f"{mean_rec:.4f} ± {std_rec:.4f}",
#         "F1": f"{mean_f1:.4f} ± {std_f1:.4f}",
#         "AUC": f"{mean_auc:.4f} ± {std_auc:.4f}",
#         "CE Loss": f"{mean_ce:.4f} ± {std_ce:.4f}",
#     })

#     print(f"\n=== λ_mod = {lambda_mod} → Average Results ===")
#     print(f"Accuracy:  {mean_acc:.4f} ± {std_acc:.4f}")
#     print(f"Precision: {mean_prec:.4f} ± {std_prec:.4f}")
#     print(f"Recall:    {mean_rec:.4f} ± {std_rec:.4f}")
#     print(f"F1-score:  {mean_f1:.4f} ± {std_f1:.4f}")
#     print(f"AUC:       {np.mean(aucs):.4f} ± {np.std(aucs):.4f}")
#     print(f"CE Loss:   {np.mean(ce_losses):.4f} ± {np.std(ce_losses):.4f}")

# print("\n\n========== FINAL SUMMARY TABLE (CN vs MCI) ==========") # Changed 'AD' to 'MCI'
# results_df = pd.DataFrame(results_summary)
# print(results_df.to_string(index=False))
