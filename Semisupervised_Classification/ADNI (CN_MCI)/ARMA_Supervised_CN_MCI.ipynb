# %%
import torch
import torch.nn as nn
import torch.nn.functional as nnFn
import torch.optim as optim
import numpy as np
import random
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from torch_geometric.data import Data
from torch_geometric.nn import ARMAConv
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, roc_auc_score, log_loss
)

# %%
fa_feature_path = "/home/snu/Downloads/Histogram_CN_FA_20bin_updated.npy"
Histogram_feature_CN_FA_array = np.load(fa_feature_path, allow_pickle=True)

fa_feature_path = "/home/snu/Downloads/Histogram_MCI_FA_20bin_updated.npy"
Histogram_feature_MCI_FA_array = np.load(fa_feature_path, allow_pickle=True)

X = np.vstack([Histogram_feature_CN_FA_array, Histogram_feature_MCI_FA_array])
y = np.hstack([
    np.zeros(Histogram_feature_CN_FA_array.shape[0], dtype=np.int64),
    np.ones(Histogram_feature_MCI_FA_array.shape[0], dtype=np.int64)
])

num_nodes, num_feats = X.shape
print(f"Features: {X.shape}, Labels: {y.shape}")
# Out:
# Features: (300, 180), Labels: (300,)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import ARMAConv

class ARMA_Supervised(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, activ="SELU"):
        super(ARMA_Supervised, self).__init__()
        self.conv1 = ARMAConv(input_dim, hidden_dim, num_stacks=1, num_layers=1)
        self.bn1 = nn.BatchNorm1d(hidden_dim)
        self.dropout = nn.Dropout(0.2)
        self.fc = nn.Linear(hidden_dim, output_dim)
        activations = {
            "SELU": F.selu,
            "SiLU": F.silu,
            "GELU": F.gelu,
            "RELU": F.relu,
            "ELU": F.elu
        }
        self.act = activations.get(activ, F.elu)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = self.conv1(x, edge_index)
        x = self.bn1(x)
        x = self.act(x)
        x = self.dropout(x)
        logits = self.fc(x)
        return logits

# %%
def create_adj(F, alpha=1):
    F_norm = F / np.linalg.norm(F, axis=1, keepdims=True)
    W = np.dot(F_norm, F_norm.T)
    W = np.where(W >= alpha, 1, 0).astype(np.float32)
    W = W / W.max()
    return W

def load_data(adj, node_feats):
    node_feats = torch.from_numpy(node_feats).float()
    edge_index = torch.from_numpy(np.array(np.nonzero((adj > 0))))
    return Data(x=node_feats, edge_index=edge_index)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
alpha = 0.92
feats_dim = num_feats
hidden_dim = 512
num_classes = 2
num_epochs = 2000
lr = 0.0001
weight_decay = 1e-4
batch_print_freq = 100

# %%
W = create_adj(X, alpha)
data = load_data(W, X).to(device)
A_tensor = torch.from_numpy(W).float().to(device)
print(data)
# Out:
# Data(x=[300, 180], edge_index=[2, 13604])

# %%
sss = StratifiedShuffleSplit(n_splits=20, test_size=0.9, random_state=42)

accuracies, precisions, recalls, f1_scores, aucs, ce_losses = [], [], [], [], [], []

for fold, (train_idx, test_idx) in enumerate(sss.split(X, y), start=1):
    print(f"\n=== Fold {fold} ===")

    train_idx_t = torch.from_numpy(train_idx).long().to(device)
    y_train_tensor = torch.from_numpy(y[train_idx]).long().to(device)

    model = ARMA_Supervised(feats_dim, hidden_dim, num_classes, "SELU").to(device)
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    ce_loss = nn.CrossEntropyLoss()


    for epoch in range(1, num_epochs + 1):
        model.train()
        optimizer.zero_grad()

        logits = model(data)
        loss = ce_loss(logits[train_idx_t], y_train_tensor)
        loss.backward()
        optimizer.step()

        if epoch % batch_print_freq == 0 or epoch == 1:
            model.eval()
            with torch.no_grad():
                preds_train = logits[train_idx_t].argmax(dim=1)
                acc_train = accuracy_score(y_train_tensor.cpu(), preds_train.cpu())
            print(f"Fold {fold} Epoch {epoch}: "
                  f"Loss={loss.item():.6f} | TrainAcc={acc_train:.4f}")


    model.eval()
    with torch.no_grad():
        out = model(data)
        preds = out.argmax(dim=1).cpu().numpy()
        probs = torch.softmax(out, dim=1)[:, 1].cpu().numpy()  # Probability for class 1

    y_test = y[test_idx]
    y_pred_test = preds[test_idx]
    y_prob_test = probs[test_idx]


    acc = accuracy_score(y_test, y_pred_test)
    prec = precision_score(y_test, y_pred_test, zero_division=0)
    rec = recall_score(y_test, y_pred_test, zero_division=0)
    f1 = f1_score(y_test, y_pred_test, zero_division=0)
    auc = roc_auc_score(y_test, y_prob_test)
    ce = log_loss(y_test, y_prob_test)

    accuracies.append(acc)
    precisions.append(prec)
    recalls.append(rec)
    f1_scores.append(f1)
    aucs.append(auc)
    ce_losses.append(ce)

    print(f"Fold {fold} → "
          f"Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | "
          f"F1={f1:.4f} | AUC={auc:.4f} | CE Loss={ce:.4f}")


print("\n=== Average Results Across 20 Folds ===")
print(f"Accuracy:  {np.mean(accuracies):.4f} ± {np.std(accuracies):.4f}")
print(f"Precision: {np.mean(precisions):.4f} ± {np.std(precisions):.4f}")
print(f"Recall:    {np.mean(recalls):.4f} ± {np.std(recalls):.4f}")
print(f"F1-score:  {np.mean(f1_scores):.4f} ± {np.std(f1_scores):.4f}")
print(f"CE Loss:   {np.mean(ce_losses):.4f} ± {np.std(ce_losses):.4f}")
print(f"AUC:       {np.mean(aucs):.4f} ± {np.std(aucs):.4f}")
# Out:
# === Fold 1 ===
# Fold 1 Epoch 1: Loss=0.660547 | TrainAcc=0.5000
# Fold 1 Epoch 100: Loss=0.034776 | TrainAcc=1.0000
# Fold 1 Epoch 200: Loss=0.009433 | TrainAcc=1.0000
# Fold 1 Epoch 300: Loss=0.004378 | TrainAcc=1.0000
# Fold 1 Epoch 400: Loss=0.002042 | TrainAcc=1.0000
# Fold 1 Epoch 500: Loss=0.001499 | TrainAcc=1.0000
# Fold 1 Epoch 600: Loss=0.000970 | TrainAcc=1.0000
# Fold 1 Epoch 700: Loss=0.000725 | TrainAcc=1.0000
# Fold 1 Epoch 800: Loss=0.000825 | TrainAcc=1.0000
# Fold 1 Epoch 900: Loss=0.000314 | TrainAcc=1.0000
# Fold 1 Epoch 1000: Loss=0.000268 | TrainAcc=1.0000
# Fold 1 Epoch 1100: Loss=0.000226 | TrainAcc=1.0000
# Fold 1 Epoch 1200: Loss=0.000249 | TrainAcc=1.0000
# Fold 1 Epoch 1300: Loss=0.000159 | TrainAcc=1.0000
# Fold 1 Epoch 1400: Loss=0.000109 | TrainAcc=1.0000
# Fold 1 Epoch 1500: Loss=0.000142 | TrainAcc=1.0000
# Fold 1 Epoch 1600: Loss=0.000104 | TrainAcc=1.0000
# Fold 1 Epoch 1700: Loss=0.000114 | TrainAcc=1.0000
# Fold 1 Epoch 1800: Loss=0.000089 | TrainAcc=1.0000
# Fold 1 Epoch 1900: Loss=0.000070 | TrainAcc=1.0000
# Fold 1 Epoch 2000: Loss=0.000048 | TrainAcc=1.0000
# Fold 1 → Acc=0.8074 | Prec=0.8224 | Rec=0.8333 | F1=0.8278 | AUC=0.8491 | CE Loss=0.9992
#
# === Fold 2 ===
# Fold 2 Epoch 1: Loss=0.736272 | TrainAcc=0.4333
# Fold 2 Epoch 100: Loss=0.040365 | TrainAcc=1.0000
# Fold 2 Epoch 200: Loss=0.008743 | TrainAcc=1.0000
# Fold 2 Epoch 300: Loss=0.004771 | TrainAcc=1.0000
# Fold 2 Epoch 400: Loss=0.002141 | TrainAcc=1.0000
# Fold 2 Epoch 500: Loss=0.001445 | TrainAcc=1.0000
# Fold 2 Epoch 600: Loss=0.000827 | TrainAcc=1.0000
# Fold 2 Epoch 700: Loss=0.000550 | TrainAcc=1.0000
# Fold 2 Epoch 800: Loss=0.000376 | TrainAcc=1.0000
# Fold 2 Epoch 900: Loss=0.000240 | TrainAcc=1.0000
# Fold 2 Epoch 1000: Loss=0.000181 | TrainAcc=1.0000
# Fold 2 Epoch 1100: Loss=0.000110 | TrainAcc=1.0000
# Fold 2 Epoch 1200: Loss=0.000105 | TrainAcc=1.0000
# Fold 2 Epoch 1300: Loss=0.000087 | TrainAcc=1.0000
# Fold 2 Epoch 1400: Loss=0.000076 | TrainAcc=1.0000
# Fold 2 Epoch 1500: Loss=0.000048 | TrainAcc=1.0000
# Fold 2 Epoch 1600: Loss=0.000048 | TrainAcc=1.0000
# Fold 2 Epoch 1700: Loss=0.000028 | TrainAcc=1.0000
# Fold 2 Epoch 1800: Loss=0.000027 | TrainAcc=1.0000
# Fold 2 Epoch 1900: Loss=0.000020 | TrainAcc=1.0000
# Fold 2 Epoch 2000: Loss=0.000021 | TrainAcc=1.0000
# Fold 2 → Acc=0.7963 | Prec=0.8519 | Rec=0.7667 | F1=0.8070 | AUC=0.8562 | CE Loss=0.8688
#
# === Fold 3 ===
# Fold 3 Epoch 1: Loss=0.720425 | TrainAcc=0.5000
# Fold 3 Epoch 100: Loss=0.049645 | TrainAcc=1.0000
# Fold 3 Epoch 200: Loss=0.012456 | TrainAcc=1.0000
# Fold 3 Epoch 300: Loss=0.005048 | TrainAcc=1.0000
# Fold 3 Epoch 400: Loss=0.004692 | TrainAcc=1.0000
# Fold 3 Epoch 500: Loss=0.001551 | TrainAcc=1.0000
# Fold 3 Epoch 600: Loss=0.000860 | TrainAcc=1.0000
# Fold 3 Epoch 700: Loss=0.000745 | TrainAcc=1.0000
# Fold 3 Epoch 800: Loss=0.000845 | TrainAcc=1.0000
# Fold 3 Epoch 900: Loss=0.000413 | TrainAcc=1.0000
# Fold 3 Epoch 1000: Loss=0.000269 | TrainAcc=1.0000
# Fold 3 Epoch 1100: Loss=0.000143 | TrainAcc=1.0000
# Fold 3 Epoch 1200: Loss=0.000101 | TrainAcc=1.0000
# Fold 3 Epoch 1300: Loss=0.000075 | TrainAcc=1.0000
# Fold 3 Epoch 1400: Loss=0.000059 | TrainAcc=1.0000
# Fold 3 Epoch 1500: Loss=0.000053 | TrainAcc=1.0000
# Fold 3 Epoch 1600: Loss=0.000056 | TrainAcc=1.0000
# Fold 3 Epoch 1700: Loss=0.000045 | TrainAcc=1.0000
# Fold 3 Epoch 1800: Loss=0.000034 | TrainAcc=1.0000
# Fold 3 Epoch 1900: Loss=0.000029 | TrainAcc=1.0000
# Fold 3 Epoch 2000: Loss=0.000036 | TrainAcc=1.0000
# Fold 3 → Acc=0.7037 | Prec=0.7397 | Rec=0.7200 | F1=0.7297 | AUC=0.7294 | CE Loss=1.5987
#
# === Fold 4 ===
# Fold 4 Epoch 1: Loss=0.840996 | TrainAcc=0.3667
# Fold 4 Epoch 100: Loss=0.043265 | TrainAcc=1.0000
# Fold 4 Epoch 200: Loss=0.009592 | TrainAcc=1.0000
# Fold 4 Epoch 300: Loss=0.004389 | TrainAcc=1.0000
# Fold 4 Epoch 400: Loss=0.003216 | TrainAcc=1.0000
# Fold 4 Epoch 500: Loss=0.001554 | TrainAcc=1.0000
# Fold 4 Epoch 600: Loss=0.000903 | TrainAcc=1.0000
# Fold 4 Epoch 700: Loss=0.000672 | TrainAcc=1.0000
# Fold 4 Epoch 800: Loss=0.000361 | TrainAcc=1.0000
# Fold 4 Epoch 900: Loss=0.000258 | TrainAcc=1.0000
# Fold 4 Epoch 1000: Loss=0.000129 | TrainAcc=1.0000
# Fold 4 Epoch 1100: Loss=0.000086 | TrainAcc=1.0000
# Fold 4 Epoch 1200: Loss=0.000076 | TrainAcc=1.0000
# Fold 4 Epoch 1300: Loss=0.000049 | TrainAcc=1.0000
# Fold 4 Epoch 1400: Loss=0.000039 | TrainAcc=1.0000
# Fold 4 Epoch 1500: Loss=0.000031 | TrainAcc=1.0000
# Fold 4 Epoch 1600: Loss=0.000054 | TrainAcc=1.0000
# Fold 4 Epoch 1700: Loss=0.000027 | TrainAcc=1.0000
# Fold 4 Epoch 1800: Loss=0.000045 | TrainAcc=1.0000
# Fold 4 Epoch 1900: Loss=0.000020 | TrainAcc=1.0000
# Fold 4 Epoch 2000: Loss=0.000023 | TrainAcc=1.0000
# Fold 4 → Acc=0.7593 | Prec=0.7742 | Rec=0.8000 | F1=0.7869 | AUC=0.8042 | CE Loss=1.1213
#
# === Fold 5 ===
# Fold 5 Epoch 1: Loss=0.762329 | TrainAcc=0.4333
# Fold 5 Epoch 100: Loss=0.038862 | TrainAcc=1.0000
# Fold 5 Epoch 200: Loss=0.009016 | TrainAcc=1.0000
# Fold 5 Epoch 300: Loss=0.004526 | TrainAcc=1.0000
# Fold 5 Epoch 400: Loss=0.002548 | TrainAcc=1.0000
# Fold 5 Epoch 500: Loss=0.001630 | TrainAcc=1.0000
# Fold 5 Epoch 600: Loss=0.001059 | TrainAcc=1.0000
# Fold 5 Epoch 700: Loss=0.000841 | TrainAcc=1.0000
# Fold 5 Epoch 800: Loss=0.000525 | TrainAcc=1.0000
# Fold 5 Epoch 900: Loss=0.000307 | TrainAcc=1.0000
# Fold 5 Epoch 1000: Loss=0.000224 | TrainAcc=1.0000
# Fold 5 Epoch 1100: Loss=0.000172 | TrainAcc=1.0000
# Fold 5 Epoch 1200: Loss=0.000169 | TrainAcc=1.0000
# Fold 5 Epoch 1300: Loss=0.000088 | TrainAcc=1.0000
# Fold 5 Epoch 1400: Loss=0.000066 | TrainAcc=1.0000
# Fold 5 Epoch 1500: Loss=0.000067 | TrainAcc=1.0000
# Fold 5 Epoch 1600: Loss=0.000052 | TrainAcc=1.0000
# Fold 5 Epoch 1700: Loss=0.000061 | TrainAcc=1.0000
# Fold 5 Epoch 1800: Loss=0.000058 | TrainAcc=1.0000
# Fold 5 Epoch 1900: Loss=0.000031 | TrainAcc=1.0000
# Fold 5 Epoch 2000: Loss=0.000022 | TrainAcc=1.0000
# Fold 5 → Acc=0.7741 | Prec=0.7799 | Rec=0.8267 | F1=0.8026 | AUC=0.8552 | CE Loss=0.8153
#
# === Fold 6 ===
# Fold 6 Epoch 1: Loss=0.714581 | TrainAcc=0.5333
# Fold 6 Epoch 100: Loss=0.040003 | TrainAcc=1.0000
# Fold 6 Epoch 200: Loss=0.010703 | TrainAcc=1.0000
# Fold 6 Epoch 300: Loss=0.004150 | TrainAcc=1.0000
# Fold 6 Epoch 400: Loss=0.001961 | TrainAcc=1.0000
# Fold 6 Epoch 500: Loss=0.001488 | TrainAcc=1.0000
# Fold 6 Epoch 600: Loss=0.000797 | TrainAcc=1.0000
# Fold 6 Epoch 700: Loss=0.000526 | TrainAcc=1.0000
# Fold 6 Epoch 800: Loss=0.000425 | TrainAcc=1.0000
# Fold 6 Epoch 900: Loss=0.000277 | TrainAcc=1.0000
# Fold 6 Epoch 1000: Loss=0.000302 | TrainAcc=1.0000
# Fold 6 Epoch 1100: Loss=0.000175 | TrainAcc=1.0000
# Fold 6 Epoch 1200: Loss=0.000167 | TrainAcc=1.0000
# Fold 6 Epoch 1300: Loss=0.000087 | TrainAcc=1.0000
# Fold 6 Epoch 1400: Loss=0.000068 | TrainAcc=1.0000
# Fold 6 Epoch 1500: Loss=0.000068 | TrainAcc=1.0000
# Fold 6 Epoch 1600: Loss=0.000046 | TrainAcc=1.0000
# Fold 6 Epoch 1700: Loss=0.000043 | TrainAcc=1.0000
# Fold 6 Epoch 1800: Loss=0.000043 | TrainAcc=1.0000
# Fold 6 Epoch 1900: Loss=0.000034 | TrainAcc=1.0000
# Fold 6 Epoch 2000: Loss=0.000043 | TrainAcc=1.0000
# Fold 6 → Acc=0.7704 | Prec=0.7750 | Rec=0.8267 | F1=0.8000 | AUC=0.8171 | CE Loss=0.8871
#
# === Fold 7 ===
# Fold 7 Epoch 1: Loss=0.634222 | TrainAcc=0.6333
# Fold 7 Epoch 100: Loss=0.027604 | TrainAcc=1.0000
# Fold 7 Epoch 200: Loss=0.008525 | TrainAcc=1.0000
# Fold 7 Epoch 300: Loss=0.003846 | TrainAcc=1.0000
# Fold 7 Epoch 400: Loss=0.002095 | TrainAcc=1.0000
# Fold 7 Epoch 500: Loss=0.001059 | TrainAcc=1.0000
# Fold 7 Epoch 600: Loss=0.000732 | TrainAcc=1.0000
# Fold 7 Epoch 700: Loss=0.000511 | TrainAcc=1.0000
# Fold 7 Epoch 800: Loss=0.000279 | TrainAcc=1.0000
# Fold 7 Epoch 900: Loss=0.000246 | TrainAcc=1.0000
# Fold 7 Epoch 1000: Loss=0.000133 | TrainAcc=1.0000
# Fold 7 Epoch 1100: Loss=0.000079 | TrainAcc=1.0000
# Fold 7 Epoch 1200: Loss=0.000049 | TrainAcc=1.0000
# Fold 7 Epoch 1300: Loss=0.000030 | TrainAcc=1.0000
# Fold 7 Epoch 1400: Loss=0.000026 | TrainAcc=1.0000
# Fold 7 Epoch 1500: Loss=0.000023 | TrainAcc=1.0000
# Fold 7 Epoch 1600: Loss=0.000022 | TrainAcc=1.0000
# Fold 7 Epoch 1700: Loss=0.000016 | TrainAcc=1.0000
# Fold 7 Epoch 1800: Loss=0.000018 | TrainAcc=1.0000
# Fold 7 Epoch 1900: Loss=0.000012 | TrainAcc=1.0000
# Fold 7 Epoch 2000: Loss=0.000015 | TrainAcc=1.0000
# Fold 7 → Acc=0.7481 | Prec=0.7808 | Rec=0.7600 | F1=0.7703 | AUC=0.7844 | CE Loss=1.4580
#
# === Fold 8 ===
# Fold 8 Epoch 1: Loss=0.897629 | TrainAcc=0.3333
# Fold 8 Epoch 100: Loss=0.059682 | TrainAcc=1.0000
# Fold 8 Epoch 200: Loss=0.014290 | TrainAcc=1.0000
# Fold 8 Epoch 300: Loss=0.005429 | TrainAcc=1.0000
# Fold 8 Epoch 400: Loss=0.002975 | TrainAcc=1.0000
# Fold 8 Epoch 500: Loss=0.002250 | TrainAcc=1.0000
# Fold 8 Epoch 600: Loss=0.001472 | TrainAcc=1.0000
# Fold 8 Epoch 700: Loss=0.000859 | TrainAcc=1.0000
# Fold 8 Epoch 800: Loss=0.000585 | TrainAcc=1.0000
# Fold 8 Epoch 900: Loss=0.000385 | TrainAcc=1.0000
# Fold 8 Epoch 1000: Loss=0.000264 | TrainAcc=1.0000
# Fold 8 Epoch 1100: Loss=0.000132 | TrainAcc=1.0000
# Fold 8 Epoch 1200: Loss=0.000107 | TrainAcc=1.0000
# Fold 8 Epoch 1300: Loss=0.000062 | TrainAcc=1.0000
# Fold 8 Epoch 1400: Loss=0.000064 | TrainAcc=1.0000
# Fold 8 Epoch 1500: Loss=0.000043 | TrainAcc=1.0000
# Fold 8 Epoch 1600: Loss=0.000025 | TrainAcc=1.0000
# Fold 8 Epoch 1700: Loss=0.000039 | TrainAcc=1.0000
# Fold 8 Epoch 1800: Loss=0.000020 | TrainAcc=1.0000
# Fold 8 Epoch 1900: Loss=0.000017 | TrainAcc=1.0000
# Fold 8 Epoch 2000: Loss=0.000018 | TrainAcc=1.0000
# Fold 8 → Acc=0.7630 | Prec=0.8116 | Rec=0.7467 | F1=0.7778 | AUC=0.8265 | CE Loss=1.1700
#
# === Fold 9 ===
# Fold 9 Epoch 1: Loss=0.926239 | TrainAcc=0.3000
# Fold 9 Epoch 100: Loss=0.040622 | TrainAcc=1.0000
# Fold 9 Epoch 200: Loss=0.008923 | TrainAcc=1.0000
# Fold 9 Epoch 300: Loss=0.004550 | TrainAcc=1.0000
# Fold 9 Epoch 400: Loss=0.002016 | TrainAcc=1.0000
# Fold 9 Epoch 500: Loss=0.001174 | TrainAcc=1.0000
# Fold 9 Epoch 600: Loss=0.000714 | TrainAcc=1.0000
# Fold 9 Epoch 700: Loss=0.000542 | TrainAcc=1.0000
# Fold 9 Epoch 800: Loss=0.000239 | TrainAcc=1.0000
# Fold 9 Epoch 900: Loss=0.000182 | TrainAcc=1.0000
# Fold 9 Epoch 1000: Loss=0.000139 | TrainAcc=1.0000
# Fold 9 Epoch 1100: Loss=0.000142 | TrainAcc=1.0000
# Fold 9 Epoch 1200: Loss=0.000089 | TrainAcc=1.0000
# Fold 9 Epoch 1300: Loss=0.000112 | TrainAcc=1.0000
# Fold 9 Epoch 1400: Loss=0.000093 | TrainAcc=1.0000
# Fold 9 Epoch 1500: Loss=0.000057 | TrainAcc=1.0000
# Fold 9 Epoch 1600: Loss=0.000042 | TrainAcc=1.0000
# Fold 9 Epoch 1700: Loss=0.000033 | TrainAcc=1.0000
# Fold 9 Epoch 1800: Loss=0.000031 | TrainAcc=1.0000
# Fold 9 Epoch 1900: Loss=0.000043 | TrainAcc=1.0000
# Fold 9 Epoch 2000: Loss=0.000032 | TrainAcc=1.0000
# Fold 9 → Acc=0.7704 | Prec=0.8333 | Rec=0.7333 | F1=0.7801 | AUC=0.8440 | CE Loss=0.9248
#
# === Fold 10 ===
# Fold 10 Epoch 1: Loss=0.728312 | TrainAcc=0.4333
# Fold 10 Epoch 100: Loss=0.051974 | TrainAcc=1.0000
# Fold 10 Epoch 200: Loss=0.013658 | TrainAcc=1.0000
# Fold 10 Epoch 300: Loss=0.006716 | TrainAcc=1.0000
# Fold 10 Epoch 400: Loss=0.003495 | TrainAcc=1.0000
# Fold 10 Epoch 500: Loss=0.002001 | TrainAcc=1.0000
# Fold 10 Epoch 600: Loss=0.001184 | TrainAcc=1.0000
# Fold 10 Epoch 700: Loss=0.001064 | TrainAcc=1.0000
# Fold 10 Epoch 800: Loss=0.000863 | TrainAcc=1.0000
# Fold 10 Epoch 900: Loss=0.000616 | TrainAcc=1.0000
# Fold 10 Epoch 1000: Loss=0.000436 | TrainAcc=1.0000
# Fold 10 Epoch 1100: Loss=0.000261 | TrainAcc=1.0000
# Fold 10 Epoch 1200: Loss=0.000152 | TrainAcc=1.0000
# Fold 10 Epoch 1300: Loss=0.000145 | TrainAcc=1.0000
# Fold 10 Epoch 1400: Loss=0.000091 | TrainAcc=1.0000
# Fold 10 Epoch 1500: Loss=0.000108 | TrainAcc=1.0000
# Fold 10 Epoch 1600: Loss=0.000065 | TrainAcc=1.0000
# Fold 10 Epoch 1700: Loss=0.000055 | TrainAcc=1.0000
# Fold 10 Epoch 1800: Loss=0.000051 | TrainAcc=1.0000
# Fold 10 Epoch 1900: Loss=0.000053 | TrainAcc=1.0000
# Fold 10 Epoch 2000: Loss=0.000036 | TrainAcc=1.0000
# Fold 10 → Acc=0.7630 | Prec=0.7867 | Rec=0.7867 | F1=0.7867 | AUC=0.8252 | CE Loss=0.8841
#
# === Fold 11 ===
# Fold 11 Epoch 1: Loss=0.740551 | TrainAcc=0.5333
# Fold 11 Epoch 100: Loss=0.036431 | TrainAcc=1.0000
# Fold 11 Epoch 200: Loss=0.013839 | TrainAcc=1.0000
# Fold 11 Epoch 300: Loss=0.004346 | TrainAcc=1.0000
# Fold 11 Epoch 400: Loss=0.002633 | TrainAcc=1.0000
# Fold 11 Epoch 500: Loss=0.001641 | TrainAcc=1.0000
# Fold 11 Epoch 600: Loss=0.000910 | TrainAcc=1.0000
# Fold 11 Epoch 700: Loss=0.000649 | TrainAcc=1.0000
# Fold 11 Epoch 800: Loss=0.000610 | TrainAcc=1.0000
# Fold 11 Epoch 900: Loss=0.000405 | TrainAcc=1.0000
# Fold 11 Epoch 1000: Loss=0.000307 | TrainAcc=1.0000
# Fold 11 Epoch 1100: Loss=0.000253 | TrainAcc=1.0000
# Fold 11 Epoch 1200: Loss=0.000182 | TrainAcc=1.0000
# Fold 11 Epoch 1300: Loss=0.000172 | TrainAcc=1.0000
# Fold 11 Epoch 1400: Loss=0.000170 | TrainAcc=1.0000
# Fold 11 Epoch 1500: Loss=0.000099 | TrainAcc=1.0000
# Fold 11 Epoch 1600: Loss=0.000092 | TrainAcc=1.0000
# Fold 11 Epoch 1700: Loss=0.000064 | TrainAcc=1.0000
# Fold 11 Epoch 1800: Loss=0.000048 | TrainAcc=1.0000
# Fold 11 Epoch 1900: Loss=0.000037 | TrainAcc=1.0000
# Fold 11 Epoch 2000: Loss=0.000055 | TrainAcc=1.0000
# Fold 11 → Acc=0.7815 | Prec=0.8013 | Rec=0.8067 | F1=0.8040 | AUC=0.8547 | CE Loss=0.9219
#
# === Fold 12 ===
# Fold 12 Epoch 1: Loss=0.687161 | TrainAcc=0.7000
# Fold 12 Epoch 100: Loss=0.037395 | TrainAcc=1.0000
# Fold 12 Epoch 200: Loss=0.010202 | TrainAcc=1.0000
# Fold 12 Epoch 300: Loss=0.004040 | TrainAcc=1.0000
# Fold 12 Epoch 400: Loss=0.002354 | TrainAcc=1.0000
# Fold 12 Epoch 500: Loss=0.001140 | TrainAcc=1.0000
# Fold 12 Epoch 600: Loss=0.000825 | TrainAcc=1.0000
# Fold 12 Epoch 700: Loss=0.000567 | TrainAcc=1.0000
# Fold 12 Epoch 800: Loss=0.000365 | TrainAcc=1.0000
# Fold 12 Epoch 900: Loss=0.000195 | TrainAcc=1.0000
# Fold 12 Epoch 1000: Loss=0.000178 | TrainAcc=1.0000
# Fold 12 Epoch 1100: Loss=0.000113 | TrainAcc=1.0000
# Fold 12 Epoch 1200: Loss=0.000105 | TrainAcc=1.0000
# Fold 12 Epoch 1300: Loss=0.000073 | TrainAcc=1.0000
# Fold 12 Epoch 1400: Loss=0.000064 | TrainAcc=1.0000
# Fold 12 Epoch 1500: Loss=0.000055 | TrainAcc=1.0000
# Fold 12 Epoch 1600: Loss=0.000040 | TrainAcc=1.0000
# Fold 12 Epoch 1700: Loss=0.000027 | TrainAcc=1.0000
# Fold 12 Epoch 1800: Loss=0.000021 | TrainAcc=1.0000
# Fold 12 Epoch 1900: Loss=0.000017 | TrainAcc=1.0000
# Fold 12 Epoch 2000: Loss=0.000027 | TrainAcc=1.0000
# Fold 12 → Acc=0.7222 | Prec=0.7419 | Rec=0.7667 | F1=0.7541 | AUC=0.7544 | CE Loss=1.4638
#
# === Fold 13 ===
# Fold 13 Epoch 1: Loss=0.659803 | TrainAcc=0.5667
# Fold 13 Epoch 100: Loss=0.037468 | TrainAcc=1.0000
# Fold 13 Epoch 200: Loss=0.009453 | TrainAcc=1.0000
# Fold 13 Epoch 300: Loss=0.004942 | TrainAcc=1.0000
# Fold 13 Epoch 400: Loss=0.002391 | TrainAcc=1.0000
# Fold 13 Epoch 500: Loss=0.001039 | TrainAcc=1.0000
# Fold 13 Epoch 600: Loss=0.000562 | TrainAcc=1.0000
# Fold 13 Epoch 700: Loss=0.000427 | TrainAcc=1.0000
# Fold 13 Epoch 800: Loss=0.000331 | TrainAcc=1.0000
# Fold 13 Epoch 900: Loss=0.000265 | TrainAcc=1.0000
# Fold 13 Epoch 1000: Loss=0.000243 | TrainAcc=1.0000
# Fold 13 Epoch 1100: Loss=0.000133 | TrainAcc=1.0000
# Fold 13 Epoch 1200: Loss=0.000133 | TrainAcc=1.0000
# Fold 13 Epoch 1300: Loss=0.000099 | TrainAcc=1.0000
# Fold 13 Epoch 1400: Loss=0.000078 | TrainAcc=1.0000
# Fold 13 Epoch 1500: Loss=0.000067 | TrainAcc=1.0000
# Fold 13 Epoch 1600: Loss=0.000065 | TrainAcc=1.0000
# Fold 13 Epoch 1700: Loss=0.000047 | TrainAcc=1.0000
# Fold 13 Epoch 1800: Loss=0.000043 | TrainAcc=1.0000
# Fold 13 Epoch 1900: Loss=0.000037 | TrainAcc=1.0000
# Fold 13 Epoch 2000: Loss=0.000056 | TrainAcc=1.0000
# Fold 13 → Acc=0.7630 | Prec=0.7792 | Rec=0.8000 | F1=0.7895 | AUC=0.8297 | CE Loss=0.9255
#
# === Fold 14 ===
# Fold 14 Epoch 1: Loss=0.744355 | TrainAcc=0.4667
# Fold 14 Epoch 100: Loss=0.047134 | TrainAcc=1.0000
# Fold 14 Epoch 200: Loss=0.009725 | TrainAcc=1.0000
# Fold 14 Epoch 300: Loss=0.005996 | TrainAcc=1.0000
# Fold 14 Epoch 400: Loss=0.003110 | TrainAcc=1.0000
# Fold 14 Epoch 500: Loss=0.001557 | TrainAcc=1.0000
# Fold 14 Epoch 600: Loss=0.000944 | TrainAcc=1.0000
# Fold 14 Epoch 700: Loss=0.000560 | TrainAcc=1.0000
# Fold 14 Epoch 800: Loss=0.000516 | TrainAcc=1.0000
# Fold 14 Epoch 900: Loss=0.000266 | TrainAcc=1.0000
# Fold 14 Epoch 1000: Loss=0.000181 | TrainAcc=1.0000
# Fold 14 Epoch 1100: Loss=0.000129 | TrainAcc=1.0000
# Fold 14 Epoch 1200: Loss=0.000077 | TrainAcc=1.0000
# Fold 14 Epoch 1300: Loss=0.000076 | TrainAcc=1.0000
# Fold 14 Epoch 1400: Loss=0.000036 | TrainAcc=1.0000
# Fold 14 Epoch 1500: Loss=0.000035 | TrainAcc=1.0000
# Fold 14 Epoch 1600: Loss=0.000038 | TrainAcc=1.0000
# Fold 14 Epoch 1700: Loss=0.000018 | TrainAcc=1.0000
# Fold 14 Epoch 1800: Loss=0.000023 | TrainAcc=1.0000
# Fold 14 Epoch 1900: Loss=0.000015 | TrainAcc=1.0000
# Fold 14 Epoch 2000: Loss=0.000019 | TrainAcc=1.0000
# Fold 14 → Acc=0.7333 | Prec=0.7708 | Rec=0.7400 | F1=0.7551 | AUC=0.7821 | CE Loss=1.0250
#
# === Fold 15 ===
# Fold 15 Epoch 1: Loss=0.689366 | TrainAcc=0.6333
# Fold 15 Epoch 100: Loss=0.034034 | TrainAcc=1.0000
# Fold 15 Epoch 200: Loss=0.009719 | TrainAcc=1.0000
# Fold 15 Epoch 300: Loss=0.005323 | TrainAcc=1.0000
# Fold 15 Epoch 400: Loss=0.002528 | TrainAcc=1.0000
# Fold 15 Epoch 500: Loss=0.001928 | TrainAcc=1.0000
# Fold 15 Epoch 600: Loss=0.001009 | TrainAcc=1.0000
# Fold 15 Epoch 700: Loss=0.000427 | TrainAcc=1.0000
# Fold 15 Epoch 800: Loss=0.000417 | TrainAcc=1.0000
# Fold 15 Epoch 900: Loss=0.000314 | TrainAcc=1.0000
# Fold 15 Epoch 1000: Loss=0.000188 | TrainAcc=1.0000
# Fold 15 Epoch 1100: Loss=0.000157 | TrainAcc=1.0000
# Fold 15 Epoch 1200: Loss=0.000147 | TrainAcc=1.0000
# Fold 15 Epoch 1300: Loss=0.000160 | TrainAcc=1.0000
# Fold 15 Epoch 1400: Loss=0.000076 | TrainAcc=1.0000
# Fold 15 Epoch 1500: Loss=0.000066 | TrainAcc=1.0000
# Fold 15 Epoch 1600: Loss=0.000069 | TrainAcc=1.0000
# Fold 15 Epoch 1700: Loss=0.000063 | TrainAcc=1.0000
# Fold 15 Epoch 1800: Loss=0.000068 | TrainAcc=1.0000
# Fold 15 Epoch 1900: Loss=0.000052 | TrainAcc=1.0000
# Fold 15 Epoch 2000: Loss=0.000028 | TrainAcc=1.0000
# Fold 15 → Acc=0.7185 | Prec=0.7761 | Rec=0.6933 | F1=0.7324 | AUC=0.7841 | CE Loss=1.1983
#
# === Fold 16 ===
# Fold 16 Epoch 1: Loss=0.663019 | TrainAcc=0.6000
# Fold 16 Epoch 100: Loss=0.046241 | TrainAcc=1.0000
# Fold 16 Epoch 200: Loss=0.010514 | TrainAcc=1.0000
# Fold 16 Epoch 300: Loss=0.003941 | TrainAcc=1.0000
# Fold 16 Epoch 400: Loss=0.002189 | TrainAcc=1.0000
# Fold 16 Epoch 500: Loss=0.001362 | TrainAcc=1.0000
# Fold 16 Epoch 600: Loss=0.000828 | TrainAcc=1.0000
# Fold 16 Epoch 700: Loss=0.000576 | TrainAcc=1.0000
# Fold 16 Epoch 800: Loss=0.000501 | TrainAcc=1.0000
# Fold 16 Epoch 900: Loss=0.000358 | TrainAcc=1.0000
# Fold 16 Epoch 1000: Loss=0.000289 | TrainAcc=1.0000
# Fold 16 Epoch 1100: Loss=0.000132 | TrainAcc=1.0000
# Fold 16 Epoch 1200: Loss=0.000128 | TrainAcc=1.0000
# Fold 16 Epoch 1300: Loss=0.000151 | TrainAcc=1.0000
# Fold 16 Epoch 1400: Loss=0.000126 | TrainAcc=1.0000
# Fold 16 Epoch 1500: Loss=0.000084 | TrainAcc=1.0000
# Fold 16 Epoch 1600: Loss=0.000059 | TrainAcc=1.0000
# Fold 16 Epoch 1700: Loss=0.000072 | TrainAcc=1.0000
# Fold 16 Epoch 1800: Loss=0.000044 | TrainAcc=1.0000
# Fold 16 Epoch 1900: Loss=0.000064 | TrainAcc=1.0000
# Fold 16 Epoch 2000: Loss=0.000039 | TrainAcc=1.0000
# Fold 16 → Acc=0.7852 | Prec=0.7805 | Rec=0.8533 | F1=0.8153 | AUC=0.8330 | CE Loss=1.0406
#
# === Fold 17 ===
# Fold 17 Epoch 1: Loss=0.771433 | TrainAcc=0.3667
# Fold 17 Epoch 100: Loss=0.048636 | TrainAcc=1.0000
# Fold 17 Epoch 200: Loss=0.013028 | TrainAcc=1.0000
# Fold 17 Epoch 300: Loss=0.006103 | TrainAcc=1.0000
# Fold 17 Epoch 400: Loss=0.002720 | TrainAcc=1.0000
# Fold 17 Epoch 500: Loss=0.001848 | TrainAcc=1.0000
# Fold 17 Epoch 600: Loss=0.001305 | TrainAcc=1.0000
# Fold 17 Epoch 700: Loss=0.000757 | TrainAcc=1.0000
# Fold 17 Epoch 800: Loss=0.000391 | TrainAcc=1.0000
# Fold 17 Epoch 900: Loss=0.000266 | TrainAcc=1.0000
# Fold 17 Epoch 1000: Loss=0.000221 | TrainAcc=1.0000
# Fold 17 Epoch 1100: Loss=0.000203 | TrainAcc=1.0000
# Fold 17 Epoch 1200: Loss=0.000181 | TrainAcc=1.0000
# Fold 17 Epoch 1300: Loss=0.000154 | TrainAcc=1.0000
# Fold 17 Epoch 1400: Loss=0.000150 | TrainAcc=1.0000
# Fold 17 Epoch 1500: Loss=0.000074 | TrainAcc=1.0000
# Fold 17 Epoch 1600: Loss=0.000064 | TrainAcc=1.0000
# Fold 17 Epoch 1700: Loss=0.000051 | TrainAcc=1.0000
# Fold 17 Epoch 1800: Loss=0.000050 | TrainAcc=1.0000
# Fold 17 Epoch 1900: Loss=0.000032 | TrainAcc=1.0000
# Fold 17 Epoch 2000: Loss=0.000036 | TrainAcc=1.0000
# Fold 17 → Acc=0.7481 | Prec=0.7470 | Rec=0.8267 | F1=0.7848 | AUC=0.7743 | CE Loss=0.9643
#
# === Fold 18 ===
# Fold 18 Epoch 1: Loss=0.739672 | TrainAcc=0.4667
# Fold 18 Epoch 100: Loss=0.047976 | TrainAcc=1.0000
# Fold 18 Epoch 200: Loss=0.010085 | TrainAcc=1.0000
# Fold 18 Epoch 300: Loss=0.004348 | TrainAcc=1.0000
# Fold 18 Epoch 400: Loss=0.002374 | TrainAcc=1.0000
# Fold 18 Epoch 500: Loss=0.001532 | TrainAcc=1.0000
# Fold 18 Epoch 600: Loss=0.000916 | TrainAcc=1.0000
# Fold 18 Epoch 700: Loss=0.000752 | TrainAcc=1.0000
# Fold 18 Epoch 800: Loss=0.000589 | TrainAcc=1.0000
# Fold 18 Epoch 900: Loss=0.000315 | TrainAcc=1.0000
# Fold 18 Epoch 1000: Loss=0.000400 | TrainAcc=1.0000
# Fold 18 Epoch 1100: Loss=0.000148 | TrainAcc=1.0000
# Fold 18 Epoch 1200: Loss=0.000144 | TrainAcc=1.0000
# Fold 18 Epoch 1300: Loss=0.000105 | TrainAcc=1.0000
# Fold 18 Epoch 1400: Loss=0.000074 | TrainAcc=1.0000
# Fold 18 Epoch 1500: Loss=0.000050 | TrainAcc=1.0000
# Fold 18 Epoch 1600: Loss=0.000031 | TrainAcc=1.0000
# Fold 18 Epoch 1700: Loss=0.000036 | TrainAcc=1.0000
# Fold 18 Epoch 1800: Loss=0.000031 | TrainAcc=1.0000
# Fold 18 Epoch 1900: Loss=0.000026 | TrainAcc=1.0000
# Fold 18 Epoch 2000: Loss=0.000026 | TrainAcc=1.0000
# Fold 18 → Acc=0.7815 | Prec=0.8182 | Rec=0.7800 | F1=0.7986 | AUC=0.8499 | CE Loss=0.8247
#
# === Fold 19 ===
# Fold 19 Epoch 1: Loss=0.792162 | TrainAcc=0.6000
# Fold 19 Epoch 100: Loss=0.047094 | TrainAcc=1.0000
# Fold 19 Epoch 200: Loss=0.010506 | TrainAcc=1.0000
# Fold 19 Epoch 300: Loss=0.004881 | TrainAcc=1.0000
# Fold 19 Epoch 400: Loss=0.002248 | TrainAcc=1.0000
# Fold 19 Epoch 500: Loss=0.001580 | TrainAcc=1.0000
# Fold 19 Epoch 600: Loss=0.000832 | TrainAcc=1.0000
# Fold 19 Epoch 700: Loss=0.000424 | TrainAcc=1.0000
# Fold 19 Epoch 800: Loss=0.000392 | TrainAcc=1.0000
# Fold 19 Epoch 900: Loss=0.000226 | TrainAcc=1.0000
# Fold 19 Epoch 1000: Loss=0.000213 | TrainAcc=1.0000
# Fold 19 Epoch 1100: Loss=0.000099 | TrainAcc=1.0000
# Fold 19 Epoch 1200: Loss=0.000082 | TrainAcc=1.0000
# Fold 19 Epoch 1300: Loss=0.000077 | TrainAcc=1.0000
# Fold 19 Epoch 1400: Loss=0.000065 | TrainAcc=1.0000
# Fold 19 Epoch 1500: Loss=0.000031 | TrainAcc=1.0000
# Fold 19 Epoch 1600: Loss=0.000035 | TrainAcc=1.0000
# Fold 19 Epoch 1700: Loss=0.000039 | TrainAcc=1.0000
# Fold 19 Epoch 1800: Loss=0.000031 | TrainAcc=1.0000
# Fold 19 Epoch 1900: Loss=0.000026 | TrainAcc=1.0000
# Fold 19 Epoch 2000: Loss=0.000027 | TrainAcc=1.0000
# Fold 19 → Acc=0.6778 | Prec=0.7172 | Rec=0.6933 | F1=0.7051 | AUC=0.7752 | CE Loss=1.0974
#
# === Fold 20 ===
# Fold 20 Epoch 1: Loss=0.793194 | TrainAcc=0.4667
# Fold 20 Epoch 100: Loss=0.048679 | TrainAcc=1.0000
# Fold 20 Epoch 200: Loss=0.009227 | TrainAcc=1.0000
# Fold 20 Epoch 300: Loss=0.003992 | TrainAcc=1.0000
# Fold 20 Epoch 400: Loss=0.002228 | TrainAcc=1.0000
# Fold 20 Epoch 500: Loss=0.001277 | TrainAcc=1.0000
# Fold 20 Epoch 600: Loss=0.001049 | TrainAcc=1.0000
# Fold 20 Epoch 700: Loss=0.000862 | TrainAcc=1.0000
# Fold 20 Epoch 800: Loss=0.000695 | TrainAcc=1.0000
# Fold 20 Epoch 900: Loss=0.000459 | TrainAcc=1.0000
# Fold 20 Epoch 1000: Loss=0.000407 | TrainAcc=1.0000
# Fold 20 Epoch 1100: Loss=0.000217 | TrainAcc=1.0000
# Fold 20 Epoch 1200: Loss=0.000243 | TrainAcc=1.0000
# Fold 20 Epoch 1300: Loss=0.000198 | TrainAcc=1.0000
# Fold 20 Epoch 1400: Loss=0.000182 | TrainAcc=1.0000
# Fold 20 Epoch 1500: Loss=0.000202 | TrainAcc=1.0000
# Fold 20 Epoch 1600: Loss=0.000141 | TrainAcc=1.0000
# Fold 20 Epoch 1700: Loss=0.000120 | TrainAcc=1.0000
# Fold 20 Epoch 1800: Loss=0.000123 | TrainAcc=1.0000
# Fold 20 Epoch 1900: Loss=0.000061 | TrainAcc=1.0000
# Fold 20 Epoch 2000: Loss=0.000052 | TrainAcc=1.0000
# Fold 20 → Acc=0.7889 | Prec=0.8079 | Rec=0.8133 | F1=0.8106 | AUC=0.8522 | CE Loss=0.8194
#
# === Average Results Across 20 Folds ===
# Accuracy:  0.7578 ± 0.0319
# Precision: 0.7848 ± 0.0327
# Recall:    0.7787 ± 0.0456
# F1-score:  0.7809 ± 0.0308
# CE Loss:   1.0504 ± 0.2221
# AUC:       0.8140 ± 0.0371
