# %%
# !pip install -q torch_geometric
# !pip install -q class_resolver
# !pip3 install pymatting

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import torch
import torch.nn as nn
import torch.nn.functional as nnFn
import torch.optim as optim
import numpy as np
import random
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from torch_geometric.data import Data
from torch_geometric.nn import ARMAConv
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, roc_auc_score, log_loss
)
from torch.utils.data import TensorDataset, DataLoader, Subset
from torch_geometric.data import Data
from torch_geometric.nn import ARMAConv
from torch.utils.data import TensorDataset, DataLoader, Subset
from torchvision import models

# %%
import torch
print("CUDA available:", torch.cuda.is_available())
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("GPU Name:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU")
# Out:
# CUDA available: True
# GPU Name: NVIDIA RTX A4000

# %%
data = np.load('/home/snu/Downloads/breastmnist_224.npz', allow_pickle=True)
all_images = np.concatenate([data['train_images'], data['val_images'], data['test_images']], axis=0)
all_labels = np.concatenate([data['train_labels'], data['val_labels'], data['test_labels']], axis=0).squeeze()

# Convert to 3-channel RGB
images = all_images.astype(np.float32) / 255.0
images = np.repeat(images[:, None, :, :], 3, axis=1)  # (N, 3, 224, 224)
X_torch = torch.tensor(images)
y_torch = torch.tensor(all_labels).long()
print(f"Raw images: {X_torch.shape}, Labels: {y_torch.shape}")
# Out:
# Raw images: torch.Size([780, 3, 224, 224]), Labels: torch.Size([780])

# %%
class0_idx = [i for i in range(len(y_torch)) if y_torch[i] == 0]
class1_idx = [i for i in range(len(y_torch)) if y_torch[i] == 1]

random.seed(42)
sampled_class0 = random.sample(class0_idx, min(1000, len(class0_idx)))
sampled_class1 = random.sample(class1_idx, min(1000, len(class1_idx)))

selected_indices = sampled_class0 + sampled_class1
random.shuffle(selected_indices)

subset_dataset = Subset(TensorDataset(X_torch, y_torch), selected_indices)
subset_loader = DataLoader(subset_dataset, batch_size=64, shuffle=False)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
vit = torch.hub.load('facebookresearch/dino:main', 'dino_vitb16')
vit.eval().to(device)

vit_feats, y_list = [], []

with torch.no_grad():
    for imgs, lbls in subset_loader:
        imgs = imgs.to(device)
        feats = vit(imgs)
        vit_feats.append(feats.cpu())
        y_list.extend(lbls.cpu().tolist())

F = torch.cat(vit_feats, dim=0).numpy().astype(np.float32)
y = np.array(y_list).astype(np.int64)

num_nodes, num_feats = F.shape
print(f"Extracted ViT-DINO Features: {F.shape}, Labels: {y.shape}")
# Out:
# Using cache found in /home/snu/.cache/torch/hub/facebookresearch_dino_main
# Extracted ViT-DINO Features: (780, 768), Labels: (780,)

# %%
# resnet = models.resnet18(pretrained=True)
# resnet.fc = nn.Identity()
# resnet = resnet.to(device)
# resnet.eval()

# resnet_feats = []
# y_list = []
# with torch.no_grad():
#     for imgs, labels in subset_loader:
#         imgs = imgs.to(device)
#         feats = resnet(imgs)
#         resnet_feats.append(feats.cpu())
#         y_list.extend(labels.cpu().tolist())

# features = torch.cat(resnet_feats, dim=0).numpy().astype(np.float32)  # shape (N, feat_dim)
# y_labels = np.array(y_list).astype(np.float32)
# print("Feature shape:", features.shape, "Label shape:", y_labels.shape)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as nnFn
from torch_geometric.nn import GATConv


class GAT_SemiSupervised(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, device, heads=2, activ="RELU", dropout=0.25):
        super(GAT_SemiSupervised, self).__init__()
        self.device = device

        # GAT layer
        self.conv1 = GATConv(input_dim, hidden_dim, heads=heads, concat=True, dropout=dropout)
        self.bn1 = nn.BatchNorm1d(hidden_dim * heads)  # heads multiply feature dimension if concat=True
        self.dropout = nn.Dropout(dropout)
        self.fc = nn.Linear(hidden_dim * heads, output_dim)

        # Activation mapping
        activations = {
            "SELU": nnFn.selu,
            "SiLU": nnFn.silu,
            "GELU": nnFn.gelu,
            "RELU": nnFn.relu,
            "ELU": nnFn.elu
        }
        self.act = activations.get(activ, nnFn.elu)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index

        # GAT layer
        x = self.conv1(x, edge_index)
        x = self.bn1(x)
        x = self.act(x)
        x = self.dropout(x)

        logits = self.fc(x)
        return logits

    def modularity_loss(self, A, logits):
        S = nnFn.softmax(logits, dim=1)
        d = torch.sum(A, dim=1)
        m = torch.sum(A)
        B = A - torch.outer(d, d) / (2 * m + 1e-12)

        modularity_term = (-1 / (2 * m + 1e-12)) * torch.trace(S.T @ B @ S)
        # Collapse regularization
        I_S = torch.eye(S.shape[1], device=self.device)
        k = torch.norm(I_S)
        n = S.shape[0]
        collapse_reg = (torch.sqrt(k) / n) * torch.norm(torch.sum(S, dim=0), p='fro') - 1
        entropy_reg = -torch.mean(torch.sum(S * torch.log(S + 1e-9), dim=1))
        return modularity_term + 0.1 * collapse_reg + 0.01 * entropy_reg

# %%
def create_adj(F, alpha=1):
    F_norm = F / np.linalg.norm(F, axis=1, keepdims=True)
    W = np.dot(F_norm, F_norm.T)
    W = np.where(W >= alpha, 1, 0).astype(np.float32)
    W = W / W.max()
    return W

def load_data(adj, node_feats):
    node_feats = torch.from_numpy(node_feats).float()
    edge_index = torch.from_numpy(np.array(np.nonzero((adj > 0))))
    return Data(x=node_feats, edge_index=edge_index)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
alpha = 0.73
feats_dim = num_feats
hidden_dim = 256
num_classes = 2
num_epochs = 2000
lr = 0.0001
weight_decay = 1e-4
batch_print_freq = 100
lambda_mod =  0.001  #0.2 #0.001  # weight for modularity loss
# lambda_sup = 1.0

# %%
W = create_adj(F, alpha)
data = load_data(W, F).to(device)
print(data)
# Out:
# Data(x=[780, 768], edge_index=[2, 266936])

# %%
sss = StratifiedShuffleSplit(n_splits=20, test_size=0.9, random_state=42)

accuracies, precisions, recalls, f1_scores, aucs, ce_losses = [], [], [], [], [], []

A_tensor = torch.from_numpy(W).float().to(device)

for fold, (train_idx, test_idx) in enumerate(sss.split(F, y), start=1):
    print(f"\n=== Fold {fold} ===")

    train_idx_t = torch.from_numpy(train_idx).long().to(device)
    y_train_tensor = torch.from_numpy(y[train_idx]).long().to(device)

    model = GAT_SemiSupervised(feats_dim, hidden_dim, num_classes, device, activ="RELU").to(device)
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    ce_loss = nn.CrossEntropyLoss()

    # Training
    for epoch in range(1, num_epochs + 1):
        model.train()
        optimizer.zero_grad()

        logits = model(data)
        loss_sup = ce_loss(logits[train_idx_t], y_train_tensor)
        loss_unsup = model.modularity_loss(A_tensor, logits)
        total_loss = loss_sup + lambda_mod * loss_unsup

        total_loss.backward()
        optimizer.step()

        if epoch % batch_print_freq == 0 or epoch == 1:
            model.eval()
            with torch.no_grad():
                preds_train = logits[train_idx_t].argmax(dim=1)
                acc_train = accuracy_score(y_train_tensor.cpu(), preds_train.cpu())
            print(f"Fold {fold} Epoch {epoch}: "
                  f"TotalLoss={total_loss.item():.6f} | Sup={loss_sup.item():.6f} | "
                  f"Unsup={loss_unsup.item():.6f} | TrainAcc={acc_train:.4f}")

    # Evaluation
    model.eval()
    with torch.no_grad():
        out = model(data)
        preds = out.argmax(dim=1).cpu().numpy()
        probs = torch.softmax(out, dim=1)[:, 1].cpu().numpy()  # Probability for class 1

    y_test = y[test_idx]
    y_pred_test = preds[test_idx]
    y_prob_test = probs[test_idx]

    acc = accuracy_score(y_test, y_pred_test)
    prec = precision_score(y_test, y_pred_test, zero_division=0)
    rec = recall_score(y_test, y_pred_test, zero_division=0)
    f1 = f1_score(y_test, y_pred_test, zero_division=0)
    auc = roc_auc_score(y_test, y_prob_test)
    ce = log_loss(y_test, y_prob_test)

    accuracies.append(acc)
    precisions.append(prec)
    recalls.append(rec)
    f1_scores.append(f1)
    aucs.append(auc)
    ce_losses.append(ce)

    print(f"Fold {fold} → "
          f"Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | "
          f"F1={f1:.4f} | AUC={auc:.4f} | CE Loss={ce:.4f}")


# Final summary
print("\n=== Average Results Across 20 Folds ===")
print(f"Accuracy:  {np.mean(accuracies):.4f} ± {np.std(accuracies):.4f}")
print(f"Precision: {np.mean(precisions):.4f} ± {np.std(precisions):.4f}")
print(f"Recall:    {np.mean(recalls):.4f} ± {np.std(recalls):.4f}")
print(f"F1-score:  {np.mean(f1_scores):.4f} ± {np.std(f1_scores):.4f}")
print(f"AUC:       {np.mean(aucs):.4f} ± {np.std(aucs):.4f}")
print(f"CE Loss:   {np.mean(ce_losses):.4f} ± {np.std(ce_losses):.4f}")
# Out:
# === Fold 1 ===
# Fold 1 Epoch 1: TotalLoss=0.786328 | Sup=0.786463 | Unsup=-0.134479 | TrainAcc=0.4615
# Fold 1 Epoch 100: TotalLoss=0.056989 | Sup=0.057160 | Unsup=-0.171513 | TrainAcc=1.0000
# Fold 1 Epoch 200: TotalLoss=0.012017 | Sup=0.012188 | Unsup=-0.171326 | TrainAcc=1.0000
# Fold 1 Epoch 300: TotalLoss=0.006064 | Sup=0.006237 | Unsup=-0.172618 | TrainAcc=1.0000
# Fold 1 Epoch 400: TotalLoss=0.005737 | Sup=0.005907 | Unsup=-0.169930 | TrainAcc=1.0000
# Fold 1 Epoch 500: TotalLoss=0.002289 | Sup=0.002459 | Unsup=-0.169624 | TrainAcc=1.0000
# Fold 1 Epoch 600: TotalLoss=0.001449 | Sup=0.001616 | Unsup=-0.167045 | TrainAcc=1.0000
# Fold 1 Epoch 700: TotalLoss=0.003398 | Sup=0.003564 | Unsup=-0.166404 | TrainAcc=1.0000
# Fold 1 Epoch 800: TotalLoss=0.001319 | Sup=0.001487 | Unsup=-0.168936 | TrainAcc=1.0000
# Fold 1 Epoch 900: TotalLoss=0.000473 | Sup=0.000642 | Unsup=-0.168578 | TrainAcc=1.0000
# Fold 1 Epoch 1000: TotalLoss=0.001339 | Sup=0.001510 | Unsup=-0.170411 | TrainAcc=1.0000
# Fold 1 Epoch 1100: TotalLoss=0.000604 | Sup=0.000775 | Unsup=-0.171513 | TrainAcc=1.0000
# Fold 1 Epoch 1200: TotalLoss=0.000151 | Sup=0.000320 | Unsup=-0.168440 | TrainAcc=1.0000
# Fold 1 Epoch 1300: TotalLoss=0.000306 | Sup=0.000476 | Unsup=-0.170363 | TrainAcc=1.0000
# Fold 1 Epoch 1400: TotalLoss=0.000347 | Sup=0.000515 | Unsup=-0.168098 | TrainAcc=1.0000
# Fold 1 Epoch 1500: TotalLoss=0.000445 | Sup=0.000617 | Unsup=-0.171337 | TrainAcc=1.0000
# Fold 1 Epoch 1600: TotalLoss=0.000302 | Sup=0.000471 | Unsup=-0.169573 | TrainAcc=1.0000
# Fold 1 Epoch 1700: TotalLoss=0.000144 | Sup=0.000314 | Unsup=-0.169455 | TrainAcc=1.0000
# Fold 1 Epoch 1800: TotalLoss=-0.000031 | Sup=0.000139 | Unsup=-0.169377 | TrainAcc=1.0000
# Fold 1 Epoch 1900: TotalLoss=0.000010 | Sup=0.000179 | Unsup=-0.168840 | TrainAcc=1.0000
# Fold 1 Epoch 2000: TotalLoss=0.000267 | Sup=0.000436 | Unsup=-0.168801 | TrainAcc=1.0000
# Fold 1 → Acc=0.7165 | Prec=0.8369 | Rec=0.7602 | F1=0.7967 | AUC=0.7452 | CE Loss=1.1138
#
# === Fold 2 ===
# Fold 2 Epoch 1: TotalLoss=0.778774 | Sup=0.778909 | Unsup=-0.134997 | TrainAcc=0.4359
# Fold 2 Epoch 100: TotalLoss=0.084426 | Sup=0.084597 | Unsup=-0.171247 | TrainAcc=0.9744
# Fold 2 Epoch 200: TotalLoss=0.007807 | Sup=0.007979 | Unsup=-0.172001 | TrainAcc=1.0000
# Fold 2 Epoch 300: TotalLoss=0.003118 | Sup=0.003288 | Unsup=-0.170452 | TrainAcc=1.0000
# Fold 2 Epoch 400: TotalLoss=0.001591 | Sup=0.001760 | Unsup=-0.169067 | TrainAcc=1.0000
# Fold 2 Epoch 500: TotalLoss=0.000932 | Sup=0.001100 | Unsup=-0.168458 | TrainAcc=1.0000
# Fold 2 Epoch 600: TotalLoss=0.000886 | Sup=0.001053 | Unsup=-0.167146 | TrainAcc=1.0000
# Fold 2 Epoch 700: TotalLoss=0.000739 | Sup=0.000905 | Unsup=-0.166841 | TrainAcc=1.0000
# Fold 2 Epoch 800: TotalLoss=0.000348 | Sup=0.000514 | Unsup=-0.166087 | TrainAcc=1.0000
# Fold 2 Epoch 900: TotalLoss=0.000350 | Sup=0.000514 | Unsup=-0.164514 | TrainAcc=1.0000
# Fold 2 Epoch 1000: TotalLoss=0.000264 | Sup=0.000428 | Unsup=-0.164511 | TrainAcc=1.0000
# Fold 2 Epoch 1100: TotalLoss=0.000297 | Sup=0.000462 | Unsup=-0.164788 | TrainAcc=1.0000
# Fold 2 Epoch 1200: TotalLoss=0.000128 | Sup=0.000292 | Unsup=-0.164433 | TrainAcc=1.0000
# Fold 2 Epoch 1300: TotalLoss=0.000140 | Sup=0.000307 | Unsup=-0.167341 | TrainAcc=1.0000
# Fold 2 Epoch 1400: TotalLoss=0.000055 | Sup=0.000220 | Unsup=-0.164573 | TrainAcc=1.0000
# Fold 2 Epoch 1500: TotalLoss=0.000110 | Sup=0.000273 | Unsup=-0.163508 | TrainAcc=1.0000
# Fold 2 Epoch 1600: TotalLoss=0.000063 | Sup=0.000228 | Unsup=-0.164011 | TrainAcc=1.0000
# Fold 2 Epoch 1700: TotalLoss=0.000011 | Sup=0.000174 | Unsup=-0.163738 | TrainAcc=1.0000
# Fold 2 Epoch 1800: TotalLoss=0.000019 | Sup=0.000182 | Unsup=-0.163418 | TrainAcc=1.0000
# Fold 2 Epoch 1900: TotalLoss=0.000122 | Sup=0.000286 | Unsup=-0.163861 | TrainAcc=1.0000
# Fold 2 Epoch 2000: TotalLoss=-0.000027 | Sup=0.000136 | Unsup=-0.163258 | TrainAcc=1.0000
# Fold 2 → Acc=0.7578 | Prec=0.8736 | Rec=0.7817 | F1=0.8251 | AUC=0.8381 | CE Loss=0.8229
#
# === Fold 3 ===
# Fold 3 Epoch 1: TotalLoss=0.766044 | Sup=0.766179 | Unsup=-0.134987 | TrainAcc=0.4744
# Fold 3 Epoch 100: TotalLoss=0.041941 | Sup=0.042112 | Unsup=-0.170616 | TrainAcc=1.0000
# Fold 3 Epoch 200: TotalLoss=0.011254 | Sup=0.011427 | Unsup=-0.173220 | TrainAcc=1.0000
# Fold 3 Epoch 300: TotalLoss=0.005815 | Sup=0.005986 | Unsup=-0.170966 | TrainAcc=1.0000
# Fold 3 Epoch 400: TotalLoss=0.003141 | Sup=0.003314 | Unsup=-0.172880 | TrainAcc=1.0000
# Fold 3 Epoch 500: TotalLoss=0.002309 | Sup=0.002482 | Unsup=-0.173205 | TrainAcc=1.0000
# Fold 3 Epoch 600: TotalLoss=0.002935 | Sup=0.003119 | Unsup=-0.184156 | TrainAcc=1.0000
# Fold 3 Epoch 700: TotalLoss=0.001244 | Sup=0.001419 | Unsup=-0.174690 | TrainAcc=1.0000
# Fold 3 Epoch 800: TotalLoss=0.000657 | Sup=0.000827 | Unsup=-0.170215 | TrainAcc=1.0000
# Fold 3 Epoch 900: TotalLoss=0.000799 | Sup=0.000970 | Unsup=-0.170316 | TrainAcc=1.0000
# Fold 3 Epoch 1000: TotalLoss=0.000661 | Sup=0.000836 | Unsup=-0.174182 | TrainAcc=1.0000
# Fold 3 Epoch 1100: TotalLoss=0.000674 | Sup=0.000852 | Unsup=-0.178644 | TrainAcc=1.0000
# Fold 3 Epoch 1200: TotalLoss=0.000369 | Sup=0.000542 | Unsup=-0.172195 | TrainAcc=1.0000
# Fold 3 Epoch 1300: TotalLoss=0.000397 | Sup=0.000572 | Unsup=-0.175555 | TrainAcc=1.0000
# Fold 3 Epoch 1400: TotalLoss=0.000257 | Sup=0.000428 | Unsup=-0.171737 | TrainAcc=1.0000
# Fold 3 Epoch 1500: TotalLoss=0.000333 | Sup=0.000502 | Unsup=-0.168499 | TrainAcc=1.0000
# Fold 3 Epoch 1600: TotalLoss=0.000265 | Sup=0.000444 | Unsup=-0.178427 | TrainAcc=1.0000
# Fold 3 Epoch 1700: TotalLoss=0.010311 | Sup=0.010488 | Unsup=-0.177778 | TrainAcc=1.0000
# Fold 3 Epoch 1800: TotalLoss=0.001192 | Sup=0.001372 | Unsup=-0.180155 | TrainAcc=1.0000
# Fold 3 Epoch 1900: TotalLoss=0.000922 | Sup=0.001103 | Unsup=-0.180927 | TrainAcc=1.0000
# Fold 3 Epoch 2000: TotalLoss=0.000475 | Sup=0.000657 | Unsup=-0.181482 | TrainAcc=1.0000
# Fold 3 → Acc=0.7650 | Prec=0.8625 | Rec=0.8070 | F1=0.8338 | AUC=0.7835 | CE Loss=1.2117
#
# === Fold 4 ===
# Fold 4 Epoch 1: TotalLoss=0.820541 | Sup=0.820676 | Unsup=-0.135495 | TrainAcc=0.3077
# Fold 4 Epoch 100: TotalLoss=0.148232 | Sup=0.148395 | Unsup=-0.163561 | TrainAcc=0.9487
# Fold 4 Epoch 200: TotalLoss=0.055724 | Sup=0.055892 | Unsup=-0.168048 | TrainAcc=0.9872
# Fold 4 Epoch 300: TotalLoss=0.041396 | Sup=0.041563 | Unsup=-0.167642 | TrainAcc=0.9872
# Fold 4 Epoch 400: TotalLoss=0.043431 | Sup=0.043600 | Unsup=-0.168761 | TrainAcc=0.9744
# Fold 4 Epoch 500: TotalLoss=0.073644 | Sup=0.073813 | Unsup=-0.169042 | TrainAcc=0.9744
# Fold 4 Epoch 600: TotalLoss=0.021205 | Sup=0.021370 | Unsup=-0.165277 | TrainAcc=0.9872
# Fold 4 Epoch 700: TotalLoss=0.023142 | Sup=0.023309 | Unsup=-0.167260 | TrainAcc=0.9872
# Fold 4 Epoch 800: TotalLoss=0.041245 | Sup=0.041415 | Unsup=-0.169984 | TrainAcc=0.9744
# Fold 4 Epoch 900: TotalLoss=0.038312 | Sup=0.038482 | Unsup=-0.169962 | TrainAcc=0.9872
# Fold 4 Epoch 1000: TotalLoss=0.010687 | Sup=0.010858 | Unsup=-0.171446 | TrainAcc=1.0000
# Fold 4 Epoch 1100: TotalLoss=0.006270 | Sup=0.006441 | Unsup=-0.171664 | TrainAcc=1.0000
# Fold 4 Epoch 1200: TotalLoss=0.003267 | Sup=0.003440 | Unsup=-0.172618 | TrainAcc=1.0000
# Fold 4 Epoch 1300: TotalLoss=0.003819 | Sup=0.003990 | Unsup=-0.171216 | TrainAcc=1.0000
# Fold 4 Epoch 1400: TotalLoss=0.002423 | Sup=0.002594 | Unsup=-0.171175 | TrainAcc=1.0000
# Fold 4 Epoch 1500: TotalLoss=0.002185 | Sup=0.002356 | Unsup=-0.170327 | TrainAcc=1.0000
# Fold 4 Epoch 1600: TotalLoss=0.001339 | Sup=0.001510 | Unsup=-0.171273 | TrainAcc=1.0000
# Fold 4 Epoch 1700: TotalLoss=0.004639 | Sup=0.004811 | Unsup=-0.171347 | TrainAcc=1.0000
# Fold 4 Epoch 1800: TotalLoss=0.002795 | Sup=0.002969 | Unsup=-0.173644 | TrainAcc=1.0000
# Fold 4 Epoch 1900: TotalLoss=0.002433 | Sup=0.002602 | Unsup=-0.169042 | TrainAcc=1.0000
# Fold 4 Epoch 2000: TotalLoss=0.012179 | Sup=0.012351 | Unsup=-0.172129 | TrainAcc=0.9872
# Fold 4 → Acc=0.7892 | Prec=0.8544 | Rec=0.8577 | F1=0.8560 | AUC=0.8088 | CE Loss=0.7948
#
# === Fold 5 ===
# Fold 5 Epoch 1: TotalLoss=0.781949 | Sup=0.782085 | Unsup=-0.135332 | TrainAcc=0.3462
# Fold 5 Epoch 100: TotalLoss=0.021935 | Sup=0.022099 | Unsup=-0.163901 | TrainAcc=1.0000
# Fold 5 Epoch 200: TotalLoss=0.007002 | Sup=0.007165 | Unsup=-0.162928 | TrainAcc=1.0000
# Fold 5 Epoch 300: TotalLoss=0.004662 | Sup=0.004821 | Unsup=-0.158659 | TrainAcc=1.0000
# Fold 5 Epoch 400: TotalLoss=0.002881 | Sup=0.003040 | Unsup=-0.158881 | TrainAcc=1.0000
# Fold 5 Epoch 500: TotalLoss=0.001509 | Sup=0.001668 | Unsup=-0.159012 | TrainAcc=1.0000
# Fold 5 Epoch 600: TotalLoss=0.000826 | Sup=0.000984 | Unsup=-0.158192 | TrainAcc=1.0000
# Fold 5 Epoch 700: TotalLoss=0.000986 | Sup=0.001144 | Unsup=-0.158326 | TrainAcc=1.0000
# Fold 5 Epoch 800: TotalLoss=0.000616 | Sup=0.000775 | Unsup=-0.159103 | TrainAcc=1.0000
# Fold 5 Epoch 900: TotalLoss=0.000547 | Sup=0.000710 | Unsup=-0.163546 | TrainAcc=1.0000
# Fold 5 Epoch 1000: TotalLoss=0.000317 | Sup=0.000475 | Unsup=-0.158159 | TrainAcc=1.0000
# Fold 5 Epoch 1100: TotalLoss=0.000370 | Sup=0.000527 | Unsup=-0.157319 | TrainAcc=1.0000
# Fold 5 Epoch 1200: TotalLoss=0.000263 | Sup=0.000419 | Unsup=-0.156704 | TrainAcc=1.0000
# Fold 5 Epoch 1300: TotalLoss=0.000172 | Sup=0.000329 | Unsup=-0.157014 | TrainAcc=1.0000
# Fold 5 Epoch 1400: TotalLoss=0.000088 | Sup=0.000245 | Unsup=-0.157129 | TrainAcc=1.0000
# Fold 5 Epoch 1500: TotalLoss=0.000083 | Sup=0.000239 | Unsup=-0.155949 | TrainAcc=1.0000
# Fold 5 Epoch 1600: TotalLoss=0.000077 | Sup=0.000234 | Unsup=-0.156953 | TrainAcc=1.0000
# Fold 5 Epoch 1700: TotalLoss=0.000121 | Sup=0.000277 | Unsup=-0.156502 | TrainAcc=1.0000
# Fold 5 Epoch 1800: TotalLoss=0.000064 | Sup=0.000220 | Unsup=-0.155866 | TrainAcc=1.0000
# Fold 5 Epoch 1900: TotalLoss=0.000037 | Sup=0.000194 | Unsup=-0.156378 | TrainAcc=1.0000
# Fold 5 Epoch 2000: TotalLoss=0.000018 | Sup=0.000175 | Unsup=-0.156963 | TrainAcc=1.0000
# Fold 5 → Acc=0.7179 | Prec=0.8689 | Rec=0.7232 | F1=0.7894 | AUC=0.7883 | CE Loss=1.0151
#
# === Fold 6 ===
# Fold 6 Epoch 1: TotalLoss=0.768036 | Sup=0.768172 | Unsup=-0.136101 | TrainAcc=0.5000
# Fold 6 Epoch 100: TotalLoss=0.106722 | Sup=0.106885 | Unsup=-0.163130 | TrainAcc=0.9744
# Fold 6 Epoch 200: TotalLoss=0.045073 | Sup=0.045235 | Unsup=-0.162314 | TrainAcc=0.9872
# Fold 6 Epoch 300: TotalLoss=0.026348 | Sup=0.026506 | Unsup=-0.157672 | TrainAcc=0.9872
# Fold 6 Epoch 400: TotalLoss=0.009441 | Sup=0.009600 | Unsup=-0.158627 | TrainAcc=1.0000
# Fold 6 Epoch 500: TotalLoss=0.004791 | Sup=0.004948 | Unsup=-0.156660 | TrainAcc=1.0000
# Fold 6 Epoch 600: TotalLoss=0.009150 | Sup=0.009308 | Unsup=-0.157881 | TrainAcc=1.0000
# Fold 6 Epoch 700: TotalLoss=0.001944 | Sup=0.002100 | Unsup=-0.156314 | TrainAcc=1.0000
# Fold 6 Epoch 800: TotalLoss=0.001404 | Sup=0.001559 | Unsup=-0.155519 | TrainAcc=1.0000
# Fold 6 Epoch 900: TotalLoss=0.000695 | Sup=0.000850 | Unsup=-0.155051 | TrainAcc=1.0000
# Fold 6 Epoch 1000: TotalLoss=0.000758 | Sup=0.000913 | Unsup=-0.154825 | TrainAcc=1.0000
# Fold 6 Epoch 1100: TotalLoss=0.000429 | Sup=0.000584 | Unsup=-0.154720 | TrainAcc=1.0000
# Fold 6 Epoch 1200: TotalLoss=0.000303 | Sup=0.000457 | Unsup=-0.154145 | TrainAcc=1.0000
# Fold 6 Epoch 1300: TotalLoss=0.000214 | Sup=0.000368 | Unsup=-0.154086 | TrainAcc=1.0000
# Fold 6 Epoch 1400: TotalLoss=0.000223 | Sup=0.000377 | Unsup=-0.153728 | TrainAcc=1.0000
# Fold 6 Epoch 1500: TotalLoss=0.000127 | Sup=0.000282 | Unsup=-0.155389 | TrainAcc=1.0000
# Fold 6 Epoch 1600: TotalLoss=0.000242 | Sup=0.000396 | Unsup=-0.153816 | TrainAcc=1.0000
# Fold 6 Epoch 1700: TotalLoss=0.000175 | Sup=0.000329 | Unsup=-0.153961 | TrainAcc=1.0000
# Fold 6 Epoch 1800: TotalLoss=0.000051 | Sup=0.000204 | Unsup=-0.152800 | TrainAcc=1.0000
# Fold 6 Epoch 1900: TotalLoss=0.000067 | Sup=0.000221 | Unsup=-0.153585 | TrainAcc=1.0000
# Fold 6 Epoch 2000: TotalLoss=0.000135 | Sup=0.000288 | Unsup=-0.153309 | TrainAcc=1.0000
# Fold 6 → Acc=0.7393 | Prec=0.8855 | Rec=0.7388 | F1=0.8055 | AUC=0.8430 | CE Loss=0.9399
#
# === Fold 7 ===
# Fold 7 Epoch 1: TotalLoss=0.740693 | Sup=0.740828 | Unsup=-0.135466 | TrainAcc=0.4103
# Fold 7 Epoch 100: TotalLoss=0.104011 | Sup=0.104174 | Unsup=-0.163604 | TrainAcc=0.9744
# Fold 7 Epoch 200: TotalLoss=0.017310 | Sup=0.017475 | Unsup=-0.165096 | TrainAcc=1.0000
# Fold 7 Epoch 300: TotalLoss=0.010657 | Sup=0.010824 | Unsup=-0.166765 | TrainAcc=1.0000
# Fold 7 Epoch 400: TotalLoss=0.008884 | Sup=0.009049 | Unsup=-0.165246 | TrainAcc=1.0000
# Fold 7 Epoch 500: TotalLoss=0.002428 | Sup=0.002593 | Unsup=-0.165294 | TrainAcc=1.0000
# Fold 7 Epoch 600: TotalLoss=0.001627 | Sup=0.001792 | Unsup=-0.164807 | TrainAcc=1.0000
# Fold 7 Epoch 700: TotalLoss=0.001039 | Sup=0.001204 | Unsup=-0.164659 | TrainAcc=1.0000
# Fold 7 Epoch 800: TotalLoss=0.000779 | Sup=0.000943 | Unsup=-0.164315 | TrainAcc=1.0000
# Fold 7 Epoch 900: TotalLoss=0.000619 | Sup=0.000784 | Unsup=-0.164750 | TrainAcc=1.0000
# Fold 7 Epoch 1000: TotalLoss=0.001201 | Sup=0.001366 | Unsup=-0.164987 | TrainAcc=1.0000
# Fold 7 Epoch 1100: TotalLoss=0.000431 | Sup=0.000596 | Unsup=-0.164428 | TrainAcc=1.0000
# Fold 7 Epoch 1200: TotalLoss=0.000281 | Sup=0.000446 | Unsup=-0.165197 | TrainAcc=1.0000
# Fold 7 Epoch 1300: TotalLoss=0.000269 | Sup=0.000434 | Unsup=-0.164744 | TrainAcc=1.0000
# Fold 7 Epoch 1400: TotalLoss=0.000235 | Sup=0.000400 | Unsup=-0.164937 | TrainAcc=1.0000
# Fold 7 Epoch 1500: TotalLoss=0.000117 | Sup=0.000282 | Unsup=-0.164816 | TrainAcc=1.0000
# Fold 7 Epoch 1600: TotalLoss=0.000075 | Sup=0.000240 | Unsup=-0.164754 | TrainAcc=1.0000
# Fold 7 Epoch 1700: TotalLoss=0.000171 | Sup=0.000335 | Unsup=-0.164198 | TrainAcc=1.0000
# Fold 7 Epoch 1800: TotalLoss=0.000075 | Sup=0.000239 | Unsup=-0.164737 | TrainAcc=1.0000
# Fold 7 Epoch 1900: TotalLoss=0.000110 | Sup=0.000274 | Unsup=-0.164907 | TrainAcc=1.0000
# Fold 7 Epoch 2000: TotalLoss=0.000018 | Sup=0.000183 | Unsup=-0.164858 | TrainAcc=1.0000
# Fold 7 → Acc=0.7521 | Prec=0.9084 | Rec=0.7349 | F1=0.8125 | AUC=0.8465 | CE Loss=1.0483
#
# === Fold 8 ===
# Fold 8 Epoch 1: TotalLoss=0.875599 | Sup=0.875735 | Unsup=-0.135301 | TrainAcc=0.3590
# Fold 8 Epoch 100: TotalLoss=0.073582 | Sup=0.073737 | Unsup=-0.154901 | TrainAcc=0.9744
# Fold 8 Epoch 200: TotalLoss=0.025490 | Sup=0.025646 | Unsup=-0.156404 | TrainAcc=1.0000
# Fold 8 Epoch 300: TotalLoss=0.007076 | Sup=0.007232 | Unsup=-0.156107 | TrainAcc=1.0000
# Fold 8 Epoch 400: TotalLoss=0.004754 | Sup=0.004911 | Unsup=-0.157416 | TrainAcc=1.0000
# Fold 8 Epoch 500: TotalLoss=0.002603 | Sup=0.002760 | Unsup=-0.157236 | TrainAcc=1.0000
# Fold 8 Epoch 600: TotalLoss=0.001459 | Sup=0.001616 | Unsup=-0.157379 | TrainAcc=1.0000
# Fold 8 Epoch 700: TotalLoss=0.001649 | Sup=0.001807 | Unsup=-0.157934 | TrainAcc=1.0000
# Fold 8 Epoch 800: TotalLoss=0.000647 | Sup=0.000805 | Unsup=-0.158322 | TrainAcc=1.0000
# Fold 8 Epoch 900: TotalLoss=0.000582 | Sup=0.000740 | Unsup=-0.158280 | TrainAcc=1.0000
# Fold 8 Epoch 1000: TotalLoss=0.000885 | Sup=0.001043 | Unsup=-0.158817 | TrainAcc=1.0000
# Fold 8 Epoch 1100: TotalLoss=0.000423 | Sup=0.000582 | Unsup=-0.158812 | TrainAcc=1.0000
# Fold 8 Epoch 1200: TotalLoss=0.000242 | Sup=0.000401 | Unsup=-0.159031 | TrainAcc=1.0000
# Fold 8 Epoch 1300: TotalLoss=0.000160 | Sup=0.000319 | Unsup=-0.158951 | TrainAcc=1.0000
# Fold 8 Epoch 1400: TotalLoss=0.000276 | Sup=0.000436 | Unsup=-0.159563 | TrainAcc=1.0000
# Fold 8 Epoch 1500: TotalLoss=0.000110 | Sup=0.000269 | Unsup=-0.159164 | TrainAcc=1.0000
# Fold 8 Epoch 1600: TotalLoss=0.000183 | Sup=0.000342 | Unsup=-0.159342 | TrainAcc=1.0000
# Fold 8 Epoch 1700: TotalLoss=0.000124 | Sup=0.000283 | Unsup=-0.159054 | TrainAcc=1.0000
# Fold 8 Epoch 1800: TotalLoss=0.000053 | Sup=0.000212 | Unsup=-0.159321 | TrainAcc=1.0000
# Fold 8 Epoch 1900: TotalLoss=0.000101 | Sup=0.000260 | Unsup=-0.159503 | TrainAcc=1.0000
# Fold 8 Epoch 2000: TotalLoss=0.000218 | Sup=0.000377 | Unsup=-0.159012 | TrainAcc=1.0000
# Fold 8 → Acc=0.7578 | Prec=0.9277 | Rec=0.7251 | F1=0.8140 | AUC=0.8562 | CE Loss=0.7312
#
# === Fold 9 ===
# Fold 9 Epoch 1: TotalLoss=0.715386 | Sup=0.715520 | Unsup=-0.134611 | TrainAcc=0.4872
# Fold 9 Epoch 100: TotalLoss=0.141102 | Sup=0.141271 | Unsup=-0.168937 | TrainAcc=0.9487
# Fold 9 Epoch 200: TotalLoss=0.034643 | Sup=0.034812 | Unsup=-0.169047 | TrainAcc=1.0000
# Fold 9 Epoch 300: TotalLoss=0.008692 | Sup=0.008857 | Unsup=-0.165571 | TrainAcc=1.0000
# Fold 9 Epoch 400: TotalLoss=0.003634 | Sup=0.003797 | Unsup=-0.162971 | TrainAcc=1.0000
# Fold 9 Epoch 500: TotalLoss=0.001702 | Sup=0.001862 | Unsup=-0.160176 | TrainAcc=1.0000
# Fold 9 Epoch 600: TotalLoss=0.000934 | Sup=0.001095 | Unsup=-0.160765 | TrainAcc=1.0000
# Fold 9 Epoch 700: TotalLoss=0.000635 | Sup=0.000795 | Unsup=-0.159850 | TrainAcc=1.0000
# Fold 9 Epoch 800: TotalLoss=0.000615 | Sup=0.000776 | Unsup=-0.160237 | TrainAcc=1.0000
# Fold 9 Epoch 900: TotalLoss=0.000533 | Sup=0.000692 | Unsup=-0.159264 | TrainAcc=1.0000
# Fold 9 Epoch 1000: TotalLoss=0.000233 | Sup=0.000393 | Unsup=-0.159336 | TrainAcc=1.0000
# Fold 9 Epoch 1100: TotalLoss=0.000186 | Sup=0.000346 | Unsup=-0.159978 | TrainAcc=1.0000
# Fold 9 Epoch 1200: TotalLoss=0.000258 | Sup=0.000416 | Unsup=-0.158776 | TrainAcc=1.0000
# Fold 9 Epoch 1300: TotalLoss=0.000172 | Sup=0.000331 | Unsup=-0.159315 | TrainAcc=1.0000
# Fold 9 Epoch 1400: TotalLoss=0.000107 | Sup=0.000266 | Unsup=-0.159103 | TrainAcc=1.0000
# Fold 9 Epoch 1500: TotalLoss=0.000087 | Sup=0.000246 | Unsup=-0.159061 | TrainAcc=1.0000
# Fold 9 Epoch 1600: TotalLoss=0.000066 | Sup=0.000225 | Unsup=-0.158272 | TrainAcc=1.0000
# Fold 9 Epoch 1700: TotalLoss=0.000013 | Sup=0.000172 | Unsup=-0.158957 | TrainAcc=1.0000
# Fold 9 Epoch 1800: TotalLoss=0.000064 | Sup=0.000222 | Unsup=-0.157886 | TrainAcc=1.0000
# Fold 9 Epoch 1900: TotalLoss=-0.000006 | Sup=0.000153 | Unsup=-0.159052 | TrainAcc=1.0000
# Fold 9 Epoch 2000: TotalLoss=0.000024 | Sup=0.000183 | Unsup=-0.159313 | TrainAcc=1.0000
# Fold 9 → Acc=0.7023 | Prec=0.8519 | Rec=0.7173 | F1=0.7788 | AUC=0.7656 | CE Loss=1.0110
#
# === Fold 10 ===
# Fold 10 Epoch 1: TotalLoss=0.861389 | Sup=0.861527 | Unsup=-0.137952 | TrainAcc=0.2949
# Fold 10 Epoch 100: TotalLoss=0.031693 | Sup=0.031852 | Unsup=-0.159569 | TrainAcc=1.0000
# Fold 10 Epoch 200: TotalLoss=0.006778 | Sup=0.006934 | Unsup=-0.156596 | TrainAcc=1.0000
# Fold 10 Epoch 300: TotalLoss=0.002886 | Sup=0.003042 | Unsup=-0.156296 | TrainAcc=1.0000
# Fold 10 Epoch 400: TotalLoss=0.001367 | Sup=0.001523 | Unsup=-0.156609 | TrainAcc=1.0000
# Fold 10 Epoch 500: TotalLoss=0.001361 | Sup=0.001516 | Unsup=-0.155416 | TrainAcc=1.0000
# Fold 10 Epoch 600: TotalLoss=0.001032 | Sup=0.001187 | Unsup=-0.155665 | TrainAcc=1.0000
# Fold 10 Epoch 700: TotalLoss=0.000738 | Sup=0.000893 | Unsup=-0.154950 | TrainAcc=1.0000
# Fold 10 Epoch 800: TotalLoss=0.000434 | Sup=0.000590 | Unsup=-0.155889 | TrainAcc=1.0000
# Fold 10 Epoch 900: TotalLoss=0.000276 | Sup=0.000431 | Unsup=-0.155341 | TrainAcc=1.0000
# Fold 10 Epoch 1000: TotalLoss=0.002303 | Sup=0.002469 | Unsup=-0.165261 | TrainAcc=1.0000
# Fold 10 Epoch 1100: TotalLoss=0.000196 | Sup=0.000353 | Unsup=-0.157364 | TrainAcc=1.0000
# Fold 10 Epoch 1200: TotalLoss=0.000175 | Sup=0.000331 | Unsup=-0.156362 | TrainAcc=1.0000
# Fold 10 Epoch 1300: TotalLoss=0.000026 | Sup=0.000182 | Unsup=-0.156718 | TrainAcc=1.0000
# Fold 10 Epoch 1400: TotalLoss=0.000033 | Sup=0.000189 | Unsup=-0.156288 | TrainAcc=1.0000
# Fold 10 Epoch 1500: TotalLoss=0.000060 | Sup=0.000216 | Unsup=-0.156284 | TrainAcc=1.0000
# Fold 10 Epoch 1600: TotalLoss=0.000432 | Sup=0.000587 | Unsup=-0.154771 | TrainAcc=1.0000
# Fold 10 Epoch 1700: TotalLoss=0.000021 | Sup=0.000179 | Unsup=-0.157445 | TrainAcc=1.0000
# Fold 10 Epoch 1800: TotalLoss=0.000000 | Sup=0.000157 | Unsup=-0.157286 | TrainAcc=1.0000
# Fold 10 Epoch 1900: TotalLoss=0.000108 | Sup=0.000264 | Unsup=-0.156234 | TrainAcc=1.0000
# Fold 10 Epoch 2000: TotalLoss=-0.000025 | Sup=0.000133 | Unsup=-0.157429 | TrainAcc=1.0000
# Fold 10 → Acc=0.7735 | Prec=0.8865 | Rec=0.7914 | F1=0.8363 | AUC=0.8134 | CE Loss=0.7283
#
# === Fold 11 ===
# Fold 11 Epoch 1: TotalLoss=0.684265 | Sup=0.684402 | Unsup=-0.137322 | TrainAcc=0.5385
# Fold 11 Epoch 100: TotalLoss=0.058117 | Sup=0.058289 | Unsup=-0.172168 | TrainAcc=0.9872
# Fold 11 Epoch 200: TotalLoss=0.015412 | Sup=0.015583 | Unsup=-0.170670 | TrainAcc=1.0000
# Fold 11 Epoch 300: TotalLoss=0.008421 | Sup=0.008596 | Unsup=-0.175313 | TrainAcc=1.0000
# Fold 11 Epoch 400: TotalLoss=0.003450 | Sup=0.003619 | Unsup=-0.168705 | TrainAcc=1.0000
# Fold 11 Epoch 500: TotalLoss=0.002042 | Sup=0.002213 | Unsup=-0.170915 | TrainAcc=1.0000
# Fold 11 Epoch 600: TotalLoss=0.001187 | Sup=0.001359 | Unsup=-0.171897 | TrainAcc=1.0000
# Fold 11 Epoch 700: TotalLoss=0.001843 | Sup=0.002015 | Unsup=-0.171488 | TrainAcc=1.0000
# Fold 11 Epoch 800: TotalLoss=0.000504 | Sup=0.000677 | Unsup=-0.173084 | TrainAcc=1.0000
# Fold 11 Epoch 900: TotalLoss=0.000467 | Sup=0.000641 | Unsup=-0.173489 | TrainAcc=1.0000
# Fold 11 Epoch 1000: TotalLoss=0.001085 | Sup=0.001253 | Unsup=-0.168706 | TrainAcc=1.0000
# Fold 11 Epoch 1100: TotalLoss=0.006513 | Sup=0.006698 | Unsup=-0.185681 | TrainAcc=1.0000
# Fold 11 Epoch 1200: TotalLoss=0.000591 | Sup=0.000760 | Unsup=-0.168200 | TrainAcc=1.0000
# Fold 11 Epoch 1300: TotalLoss=0.000316 | Sup=0.000483 | Unsup=-0.166593 | TrainAcc=1.0000
# Fold 11 Epoch 1400: TotalLoss=0.000197 | Sup=0.000364 | Unsup=-0.166556 | TrainAcc=1.0000
# Fold 11 Epoch 1500: TotalLoss=0.000035 | Sup=0.000200 | Unsup=-0.164941 | TrainAcc=1.0000
# Fold 11 Epoch 1600: TotalLoss=0.000137 | Sup=0.000301 | Unsup=-0.164910 | TrainAcc=1.0000
# Fold 11 Epoch 1700: TotalLoss=-0.000002 | Sup=0.000163 | Unsup=-0.164499 | TrainAcc=1.0000
# Fold 11 Epoch 1800: TotalLoss=0.000025 | Sup=0.000190 | Unsup=-0.164547 | TrainAcc=1.0000
# Fold 11 Epoch 1900: TotalLoss=-0.000003 | Sup=0.000160 | Unsup=-0.163456 | TrainAcc=1.0000
# Fold 11 Epoch 2000: TotalLoss=-0.000041 | Sup=0.000122 | Unsup=-0.163612 | TrainAcc=1.0000
# Fold 11 → Acc=0.7578 | Prec=0.8820 | Rec=0.7719 | F1=0.8233 | AUC=0.8096 | CE Loss=0.9388
#
# === Fold 12 ===
# Fold 12 Epoch 1: TotalLoss=0.819234 | Sup=0.819371 | Unsup=-0.137130 | TrainAcc=0.4487
# Fold 12 Epoch 100: TotalLoss=0.028996 | Sup=0.029163 | Unsup=-0.167216 | TrainAcc=1.0000
# Fold 12 Epoch 200: TotalLoss=0.008923 | Sup=0.009087 | Unsup=-0.163867 | TrainAcc=1.0000
# Fold 12 Epoch 300: TotalLoss=0.004867 | Sup=0.005030 | Unsup=-0.162901 | TrainAcc=1.0000
# Fold 12 Epoch 400: TotalLoss=0.002639 | Sup=0.002801 | Unsup=-0.161836 | TrainAcc=1.0000
# Fold 12 Epoch 500: TotalLoss=0.001465 | Sup=0.001626 | Unsup=-0.160896 | TrainAcc=1.0000
# Fold 12 Epoch 600: TotalLoss=0.001241 | Sup=0.001400 | Unsup=-0.158840 | TrainAcc=1.0000
# Fold 12 Epoch 700: TotalLoss=0.000998 | Sup=0.001157 | Unsup=-0.158840 | TrainAcc=1.0000
# Fold 12 Epoch 800: TotalLoss=0.000646 | Sup=0.000804 | Unsup=-0.158466 | TrainAcc=1.0000
# Fold 12 Epoch 900: TotalLoss=0.000543 | Sup=0.000701 | Unsup=-0.158295 | TrainAcc=1.0000
# Fold 12 Epoch 1000: TotalLoss=0.000283 | Sup=0.000439 | Unsup=-0.155368 | TrainAcc=1.0000
# Fold 12 Epoch 1100: TotalLoss=0.000280 | Sup=0.000436 | Unsup=-0.155949 | TrainAcc=1.0000
# Fold 12 Epoch 1200: TotalLoss=0.000266 | Sup=0.000423 | Unsup=-0.157110 | TrainAcc=1.0000
# Fold 12 Epoch 1300: TotalLoss=0.000218 | Sup=0.000375 | Unsup=-0.157090 | TrainAcc=1.0000
# Fold 12 Epoch 1400: TotalLoss=0.000106 | Sup=0.000262 | Unsup=-0.156300 | TrainAcc=1.0000
# Fold 12 Epoch 1500: TotalLoss=0.000084 | Sup=0.000240 | Unsup=-0.155967 | TrainAcc=1.0000
# Fold 12 Epoch 1600: TotalLoss=0.000073 | Sup=0.000230 | Unsup=-0.157783 | TrainAcc=1.0000
# Fold 12 Epoch 1700: TotalLoss=0.000057 | Sup=0.000214 | Unsup=-0.156885 | TrainAcc=1.0000
# Fold 12 Epoch 1800: TotalLoss=0.000029 | Sup=0.000187 | Unsup=-0.158156 | TrainAcc=1.0000
# Fold 12 Epoch 1900: TotalLoss=0.000008 | Sup=0.000166 | Unsup=-0.158223 | TrainAcc=1.0000
# Fold 12 Epoch 2000: TotalLoss=0.000008 | Sup=0.000166 | Unsup=-0.157196 | TrainAcc=1.0000
# Fold 12 → Acc=0.6724 | Prec=0.8773 | Rec=0.6413 | F1=0.7410 | AUC=0.7673 | CE Loss=1.3739
#
# === Fold 13 ===
# Fold 13 Epoch 1: TotalLoss=0.765086 | Sup=0.765222 | Unsup=-0.135221 | TrainAcc=0.4231
# Fold 13 Epoch 100: TotalLoss=0.158534 | Sup=0.158710 | Unsup=-0.175592 | TrainAcc=0.9359
# Fold 13 Epoch 200: TotalLoss=0.081216 | Sup=0.081397 | Unsup=-0.181177 | TrainAcc=0.9615
# Fold 13 Epoch 300: TotalLoss=0.023097 | Sup=0.023279 | Unsup=-0.181244 | TrainAcc=1.0000
# Fold 13 Epoch 400: TotalLoss=0.008070 | Sup=0.008255 | Unsup=-0.184833 | TrainAcc=1.0000
# Fold 13 Epoch 500: TotalLoss=0.014153 | Sup=0.014342 | Unsup=-0.188285 | TrainAcc=1.0000
# Fold 13 Epoch 600: TotalLoss=0.030546 | Sup=0.030735 | Unsup=-0.189184 | TrainAcc=0.9872
# Fold 13 Epoch 700: TotalLoss=0.002669 | Sup=0.002856 | Unsup=-0.187535 | TrainAcc=1.0000
# Fold 13 Epoch 800: TotalLoss=0.004156 | Sup=0.004339 | Unsup=-0.182784 | TrainAcc=1.0000
# Fold 13 Epoch 900: TotalLoss=0.002870 | Sup=0.003058 | Unsup=-0.187532 | TrainAcc=1.0000
# Fold 13 Epoch 1000: TotalLoss=0.001857 | Sup=0.002045 | Unsup=-0.188189 | TrainAcc=1.0000
# Fold 13 Epoch 1100: TotalLoss=0.015868 | Sup=0.016054 | Unsup=-0.185261 | TrainAcc=0.9872
# Fold 13 Epoch 1200: TotalLoss=0.002860 | Sup=0.003044 | Unsup=-0.183397 | TrainAcc=1.0000
# Fold 13 Epoch 1300: TotalLoss=0.005402 | Sup=0.005587 | Unsup=-0.184617 | TrainAcc=1.0000
# Fold 13 Epoch 1400: TotalLoss=0.000579 | Sup=0.000763 | Unsup=-0.183745 | TrainAcc=1.0000
# Fold 13 Epoch 1500: TotalLoss=0.000380 | Sup=0.000565 | Unsup=-0.184607 | TrainAcc=1.0000
# Fold 13 Epoch 1600: TotalLoss=0.000394 | Sup=0.000579 | Unsup=-0.184572 | TrainAcc=1.0000
# Fold 13 Epoch 1700: TotalLoss=0.000523 | Sup=0.000705 | Unsup=-0.182887 | TrainAcc=1.0000
# Fold 13 Epoch 1800: TotalLoss=0.000434 | Sup=0.000617 | Unsup=-0.183379 | TrainAcc=1.0000
# Fold 13 Epoch 1900: TotalLoss=0.000302 | Sup=0.000485 | Unsup=-0.183156 | TrainAcc=1.0000
# Fold 13 Epoch 2000: TotalLoss=0.000070 | Sup=0.000251 | Unsup=-0.181002 | TrainAcc=1.0000
# Fold 13 → Acc=0.7322 | Prec=0.8702 | Rec=0.7446 | F1=0.8025 | AUC=0.7911 | CE Loss=1.2480
#
# === Fold 14 ===
# Fold 14 Epoch 1: TotalLoss=0.696233 | Sup=0.696368 | Unsup=-0.135131 | TrainAcc=0.7051
# Fold 14 Epoch 100: TotalLoss=0.024950 | Sup=0.025115 | Unsup=-0.164661 | TrainAcc=1.0000
# Fold 14 Epoch 200: TotalLoss=0.005722 | Sup=0.005884 | Unsup=-0.162043 | TrainAcc=1.0000
# Fold 14 Epoch 300: TotalLoss=0.004032 | Sup=0.004191 | Unsup=-0.159612 | TrainAcc=1.0000
# Fold 14 Epoch 400: TotalLoss=0.001179 | Sup=0.001341 | Unsup=-0.162096 | TrainAcc=1.0000
# Fold 14 Epoch 500: TotalLoss=0.000902 | Sup=0.001065 | Unsup=-0.162637 | TrainAcc=1.0000
# Fold 14 Epoch 600: TotalLoss=0.000577 | Sup=0.000740 | Unsup=-0.162629 | TrainAcc=1.0000
# Fold 14 Epoch 700: TotalLoss=0.000595 | Sup=0.000758 | Unsup=-0.163018 | TrainAcc=1.0000
# Fold 14 Epoch 800: TotalLoss=0.000689 | Sup=0.000852 | Unsup=-0.162351 | TrainAcc=1.0000
# Fold 14 Epoch 900: TotalLoss=0.038829 | Sup=0.039002 | Unsup=-0.172969 | TrainAcc=0.9872
# Fold 14 Epoch 1000: TotalLoss=0.001380 | Sup=0.001548 | Unsup=-0.168574 | TrainAcc=1.0000
# Fold 14 Epoch 1100: TotalLoss=0.000624 | Sup=0.000793 | Unsup=-0.168619 | TrainAcc=1.0000
# Fold 14 Epoch 1200: TotalLoss=0.000625 | Sup=0.000792 | Unsup=-0.167394 | TrainAcc=1.0000
# Fold 14 Epoch 1300: TotalLoss=0.000520 | Sup=0.000689 | Unsup=-0.169110 | TrainAcc=1.0000
# Fold 14 Epoch 1400: TotalLoss=0.000256 | Sup=0.000422 | Unsup=-0.166727 | TrainAcc=1.0000
# Fold 14 Epoch 1500: TotalLoss=0.000236 | Sup=0.000403 | Unsup=-0.167484 | TrainAcc=1.0000
# Fold 14 Epoch 1600: TotalLoss=0.000195 | Sup=0.000361 | Unsup=-0.165482 | TrainAcc=1.0000
# Fold 14 Epoch 1700: TotalLoss=0.000210 | Sup=0.000378 | Unsup=-0.167799 | TrainAcc=1.0000
# Fold 14 Epoch 1800: TotalLoss=0.002019 | Sup=0.002189 | Unsup=-0.170477 | TrainAcc=1.0000
# Fold 14 Epoch 1900: TotalLoss=0.000702 | Sup=0.000869 | Unsup=-0.166286 | TrainAcc=1.0000
# Fold 14 Epoch 2000: TotalLoss=0.000563 | Sup=0.000733 | Unsup=-0.169694 | TrainAcc=1.0000
# Fold 14 → Acc=0.7977 | Prec=0.8747 | Rec=0.8441 | F1=0.8591 | AUC=0.8349 | CE Loss=0.8732
#
# === Fold 15 ===
# Fold 15 Epoch 1: TotalLoss=0.667272 | Sup=0.667408 | Unsup=-0.136010 | TrainAcc=0.5000
# Fold 15 Epoch 100: TotalLoss=0.023906 | Sup=0.024062 | Unsup=-0.156171 | TrainAcc=1.0000
# Fold 15 Epoch 200: TotalLoss=0.005996 | Sup=0.006149 | Unsup=-0.153036 | TrainAcc=1.0000
# Fold 15 Epoch 300: TotalLoss=0.005238 | Sup=0.005392 | Unsup=-0.154066 | TrainAcc=1.0000
# Fold 15 Epoch 400: TotalLoss=0.002026 | Sup=0.002183 | Unsup=-0.156415 | TrainAcc=1.0000
# Fold 15 Epoch 500: TotalLoss=0.002308 | Sup=0.002462 | Unsup=-0.153228 | TrainAcc=1.0000
# Fold 15 Epoch 600: TotalLoss=0.001038 | Sup=0.001192 | Unsup=-0.153338 | TrainAcc=1.0000
# Fold 15 Epoch 700: TotalLoss=0.000424 | Sup=0.000577 | Unsup=-0.152879 | TrainAcc=1.0000
# Fold 15 Epoch 800: TotalLoss=0.000154 | Sup=0.000307 | Unsup=-0.152984 | TrainAcc=1.0000
# Fold 15 Epoch 900: TotalLoss=0.000467 | Sup=0.000620 | Unsup=-0.153954 | TrainAcc=1.0000
# Fold 15 Epoch 1000: TotalLoss=0.000114 | Sup=0.000267 | Unsup=-0.152886 | TrainAcc=1.0000
# Fold 15 Epoch 1100: TotalLoss=0.000133 | Sup=0.000285 | Unsup=-0.152288 | TrainAcc=1.0000
# Fold 15 Epoch 1200: TotalLoss=0.000087 | Sup=0.000239 | Unsup=-0.152695 | TrainAcc=1.0000
# Fold 15 Epoch 1300: TotalLoss=0.000038 | Sup=0.000192 | Unsup=-0.153116 | TrainAcc=1.0000
# Fold 15 Epoch 1400: TotalLoss=0.000327 | Sup=0.000484 | Unsup=-0.157072 | TrainAcc=1.0000
# Fold 15 Epoch 1500: TotalLoss=-0.000001 | Sup=0.000152 | Unsup=-0.152631 | TrainAcc=1.0000
# Fold 15 Epoch 1600: TotalLoss=-0.000054 | Sup=0.000099 | Unsup=-0.152986 | TrainAcc=1.0000
# Fold 15 Epoch 1700: TotalLoss=0.000004 | Sup=0.000157 | Unsup=-0.152995 | TrainAcc=1.0000
# Fold 15 Epoch 1800: TotalLoss=-0.000052 | Sup=0.000101 | Unsup=-0.153498 | TrainAcc=1.0000
# Fold 15 Epoch 1900: TotalLoss=-0.000030 | Sup=0.000123 | Unsup=-0.153436 | TrainAcc=1.0000
# Fold 15 Epoch 2000: TotalLoss=0.007137 | Sup=0.007332 | Unsup=-0.194211 | TrainAcc=1.0000
# Fold 15 → Acc=0.7735 | Prec=0.8127 | Rec=0.8967 | F1=0.8526 | AUC=0.7634 | CE Loss=0.8397
#
# === Fold 16 ===
# Fold 16 Epoch 1: TotalLoss=0.752119 | Sup=0.752256 | Unsup=-0.136779 | TrainAcc=0.4744
# Fold 16 Epoch 100: TotalLoss=0.078717 | Sup=0.078896 | Unsup=-0.178947 | TrainAcc=1.0000
# Fold 16 Epoch 200: TotalLoss=0.020873 | Sup=0.021056 | Unsup=-0.183267 | TrainAcc=1.0000
# Fold 16 Epoch 300: TotalLoss=0.015255 | Sup=0.015441 | Unsup=-0.185819 | TrainAcc=1.0000
# Fold 16 Epoch 400: TotalLoss=0.007924 | Sup=0.008111 | Unsup=-0.186671 | TrainAcc=1.0000
# Fold 16 Epoch 500: TotalLoss=0.004593 | Sup=0.004782 | Unsup=-0.188793 | TrainAcc=1.0000
# Fold 16 Epoch 600: TotalLoss=0.004611 | Sup=0.004800 | Unsup=-0.188433 | TrainAcc=1.0000
# Fold 16 Epoch 700: TotalLoss=0.004802 | Sup=0.004991 | Unsup=-0.189427 | TrainAcc=1.0000
# Fold 16 Epoch 800: TotalLoss=0.002352 | Sup=0.002539 | Unsup=-0.187720 | TrainAcc=1.0000
# Fold 16 Epoch 900: TotalLoss=0.001420 | Sup=0.001608 | Unsup=-0.187666 | TrainAcc=1.0000
# Fold 16 Epoch 1000: TotalLoss=0.001211 | Sup=0.001400 | Unsup=-0.188228 | TrainAcc=1.0000
# Fold 16 Epoch 1100: TotalLoss=0.001843 | Sup=0.002030 | Unsup=-0.187166 | TrainAcc=1.0000
# Fold 16 Epoch 1200: TotalLoss=0.001331 | Sup=0.001518 | Unsup=-0.187501 | TrainAcc=1.0000
# Fold 16 Epoch 1300: TotalLoss=0.000521 | Sup=0.000710 | Unsup=-0.188475 | TrainAcc=1.0000
# Fold 16 Epoch 1400: TotalLoss=0.001595 | Sup=0.001781 | Unsup=-0.186328 | TrainAcc=1.0000
# Fold 16 Epoch 1500: TotalLoss=0.000201 | Sup=0.000387 | Unsup=-0.186438 | TrainAcc=1.0000
# Fold 16 Epoch 1600: TotalLoss=0.000145 | Sup=0.000334 | Unsup=-0.188976 | TrainAcc=1.0000
# Fold 16 Epoch 1700: TotalLoss=0.000260 | Sup=0.000449 | Unsup=-0.188393 | TrainAcc=1.0000
# Fold 16 Epoch 1800: TotalLoss=0.000532 | Sup=0.000722 | Unsup=-0.189642 | TrainAcc=1.0000
# Fold 16 Epoch 1900: TotalLoss=0.000550 | Sup=0.000737 | Unsup=-0.187179 | TrainAcc=1.0000
# Fold 16 Epoch 2000: TotalLoss=0.000722 | Sup=0.000911 | Unsup=-0.188806 | TrainAcc=1.0000
# Fold 16 → Acc=0.7821 | Prec=0.8383 | Rec=0.8694 | F1=0.8536 | AUC=0.7751 | CE Loss=1.1046
#
# === Fold 17 ===
# Fold 17 Epoch 1: TotalLoss=0.700415 | Sup=0.700550 | Unsup=-0.134522 | TrainAcc=0.5513
# Fold 17 Epoch 100: TotalLoss=0.010536 | Sup=0.010712 | Unsup=-0.175741 | TrainAcc=1.0000
# Fold 17 Epoch 200: TotalLoss=0.003433 | Sup=0.003611 | Unsup=-0.177305 | TrainAcc=1.0000
# Fold 17 Epoch 300: TotalLoss=0.001608 | Sup=0.001784 | Unsup=-0.175882 | TrainAcc=1.0000
# Fold 17 Epoch 400: TotalLoss=0.000850 | Sup=0.001028 | Unsup=-0.178085 | TrainAcc=1.0000
# Fold 17 Epoch 500: TotalLoss=0.000446 | Sup=0.000624 | Unsup=-0.177391 | TrainAcc=1.0000
# Fold 17 Epoch 600: TotalLoss=0.000479 | Sup=0.000659 | Unsup=-0.179385 | TrainAcc=1.0000
# Fold 17 Epoch 700: TotalLoss=0.000163 | Sup=0.000341 | Unsup=-0.178587 | TrainAcc=1.0000
# Fold 17 Epoch 800: TotalLoss=0.000120 | Sup=0.000298 | Unsup=-0.177433 | TrainAcc=1.0000
# Fold 17 Epoch 900: TotalLoss=0.000152 | Sup=0.000327 | Unsup=-0.175154 | TrainAcc=1.0000
# Fold 17 Epoch 1000: TotalLoss=0.000027 | Sup=0.000206 | Unsup=-0.178844 | TrainAcc=1.0000
# Fold 17 Epoch 1100: TotalLoss=0.000021 | Sup=0.000200 | Unsup=-0.179454 | TrainAcc=1.0000
# Fold 17 Epoch 1200: TotalLoss=-0.000024 | Sup=0.000155 | Unsup=-0.179438 | TrainAcc=1.0000
# Fold 17 Epoch 1300: TotalLoss=-0.000017 | Sup=0.000162 | Unsup=-0.178840 | TrainAcc=1.0000
# Fold 17 Epoch 1400: TotalLoss=0.000000 | Sup=0.000179 | Unsup=-0.178902 | TrainAcc=1.0000
# Fold 17 Epoch 1500: TotalLoss=-0.000067 | Sup=0.000113 | Unsup=-0.180504 | TrainAcc=1.0000
# Fold 17 Epoch 1600: TotalLoss=-0.000068 | Sup=0.000113 | Unsup=-0.180418 | TrainAcc=1.0000
# Fold 17 Epoch 1700: TotalLoss=-0.000052 | Sup=0.000125 | Unsup=-0.177067 | TrainAcc=1.0000
# Fold 17 Epoch 1800: TotalLoss=-0.000088 | Sup=0.000093 | Unsup=-0.181432 | TrainAcc=1.0000
# Fold 17 Epoch 1900: TotalLoss=-0.000077 | Sup=0.000105 | Unsup=-0.182553 | TrainAcc=1.0000
# Fold 17 Epoch 2000: TotalLoss=-0.000092 | Sup=0.000092 | Unsup=-0.184051 | TrainAcc=1.0000
# Fold 17 → Acc=0.7934 | Prec=0.8710 | Rec=0.8421 | F1=0.8563 | AUC=0.8278 | CE Loss=0.7849
#
# === Fold 18 ===
# Fold 18 Epoch 1: TotalLoss=0.658023 | Sup=0.658159 | Unsup=-0.135247 | TrainAcc=0.6154
# Fold 18 Epoch 100: TotalLoss=0.036788 | Sup=0.036951 | Unsup=-0.162809 | TrainAcc=1.0000
# Fold 18 Epoch 200: TotalLoss=0.009919 | Sup=0.010085 | Unsup=-0.165839 | TrainAcc=1.0000
# Fold 18 Epoch 300: TotalLoss=0.006510 | Sup=0.006672 | Unsup=-0.162053 | TrainAcc=1.0000
# Fold 18 Epoch 400: TotalLoss=0.005588 | Sup=0.005751 | Unsup=-0.162830 | TrainAcc=1.0000
# Fold 18 Epoch 500: TotalLoss=0.002304 | Sup=0.002465 | Unsup=-0.160833 | TrainAcc=1.0000
# Fold 18 Epoch 600: TotalLoss=0.002145 | Sup=0.002308 | Unsup=-0.162783 | TrainAcc=1.0000
# Fold 18 Epoch 700: TotalLoss=0.002435 | Sup=0.002599 | Unsup=-0.163682 | TrainAcc=1.0000
# Fold 18 Epoch 800: TotalLoss=0.001114 | Sup=0.001278 | Unsup=-0.163171 | TrainAcc=1.0000
# Fold 18 Epoch 900: TotalLoss=0.002199 | Sup=0.002359 | Unsup=-0.160377 | TrainAcc=1.0000
# Fold 18 Epoch 1000: TotalLoss=0.001583 | Sup=0.001744 | Unsup=-0.160891 | TrainAcc=1.0000
# Fold 18 Epoch 1100: TotalLoss=0.001292 | Sup=0.001452 | Unsup=-0.160038 | TrainAcc=1.0000
# Fold 18 Epoch 1200: TotalLoss=0.000994 | Sup=0.001154 | Unsup=-0.159703 | TrainAcc=1.0000
# Fold 18 Epoch 1300: TotalLoss=0.000408 | Sup=0.000570 | Unsup=-0.161636 | TrainAcc=1.0000
# Fold 18 Epoch 1400: TotalLoss=0.001411 | Sup=0.001572 | Unsup=-0.161152 | TrainAcc=1.0000
# Fold 18 Epoch 1500: TotalLoss=0.001479 | Sup=0.001642 | Unsup=-0.163298 | TrainAcc=1.0000
# Fold 18 Epoch 1600: TotalLoss=0.000960 | Sup=0.001120 | Unsup=-0.160313 | TrainAcc=1.0000
# Fold 18 Epoch 1700: TotalLoss=0.001221 | Sup=0.001382 | Unsup=-0.161142 | TrainAcc=1.0000
# Fold 18 Epoch 1800: TotalLoss=0.000466 | Sup=0.000626 | Unsup=-0.160796 | TrainAcc=1.0000
# Fold 18 Epoch 1900: TotalLoss=0.000592 | Sup=0.000752 | Unsup=-0.160641 | TrainAcc=1.0000
# Fold 18 Epoch 2000: TotalLoss=0.000613 | Sup=0.000774 | Unsup=-0.161480 | TrainAcc=1.0000
# Fold 18 → Acc=0.7792 | Prec=0.8698 | Rec=0.8207 | F1=0.8445 | AUC=0.8136 | CE Loss=1.1717
#
# === Fold 19 ===
# Fold 19 Epoch 1: TotalLoss=0.679696 | Sup=0.679830 | Unsup=-0.134562 | TrainAcc=0.6538
# Fold 19 Epoch 100: TotalLoss=0.139115 | Sup=0.139281 | Unsup=-0.166333 | TrainAcc=0.9615
# Fold 19 Epoch 200: TotalLoss=0.020516 | Sup=0.020687 | Unsup=-0.170955 | TrainAcc=1.0000
# Fold 19 Epoch 300: TotalLoss=0.008209 | Sup=0.008382 | Unsup=-0.173219 | TrainAcc=1.0000
# Fold 19 Epoch 400: TotalLoss=0.005107 | Sup=0.005278 | Unsup=-0.170418 | TrainAcc=1.0000
# Fold 19 Epoch 500: TotalLoss=0.003374 | Sup=0.003545 | Unsup=-0.171206 | TrainAcc=1.0000
# Fold 19 Epoch 600: TotalLoss=0.002436 | Sup=0.002609 | Unsup=-0.173421 | TrainAcc=1.0000
# Fold 19 Epoch 700: TotalLoss=0.001967 | Sup=0.002139 | Unsup=-0.172283 | TrainAcc=1.0000
# Fold 19 Epoch 800: TotalLoss=0.001097 | Sup=0.001271 | Unsup=-0.173311 | TrainAcc=1.0000
# Fold 19 Epoch 900: TotalLoss=0.003104 | Sup=0.003281 | Unsup=-0.176805 | TrainAcc=1.0000
# Fold 19 Epoch 1000: TotalLoss=0.000912 | Sup=0.001083 | Unsup=-0.171274 | TrainAcc=1.0000
# Fold 19 Epoch 1100: TotalLoss=0.000630 | Sup=0.000809 | Unsup=-0.179228 | TrainAcc=1.0000
# Fold 19 Epoch 1200: TotalLoss=0.000989 | Sup=0.001160 | Unsup=-0.171050 | TrainAcc=1.0000
# Fold 19 Epoch 1300: TotalLoss=0.000584 | Sup=0.000759 | Unsup=-0.175493 | TrainAcc=1.0000
# Fold 19 Epoch 1400: TotalLoss=0.000360 | Sup=0.000528 | Unsup=-0.168354 | TrainAcc=1.0000
# Fold 19 Epoch 1500: TotalLoss=0.000045 | Sup=0.000219 | Unsup=-0.174814 | TrainAcc=1.0000
# Fold 19 Epoch 1600: TotalLoss=0.000061 | Sup=0.000235 | Unsup=-0.173261 | TrainAcc=1.0000
# Fold 19 Epoch 1700: TotalLoss=0.000040 | Sup=0.000214 | Unsup=-0.173847 | TrainAcc=1.0000
# Fold 19 Epoch 1800: TotalLoss=0.000016 | Sup=0.000190 | Unsup=-0.174171 | TrainAcc=1.0000
# Fold 19 Epoch 1900: TotalLoss=-0.000025 | Sup=0.000148 | Unsup=-0.173065 | TrainAcc=1.0000
# Fold 19 Epoch 2000: TotalLoss=0.000003 | Sup=0.000178 | Unsup=-0.174584 | TrainAcc=1.0000
# Fold 19 → Acc=0.7564 | Prec=0.8519 | Rec=0.8070 | F1=0.8288 | AUC=0.8319 | CE Loss=0.8835
#
# === Fold 20 ===
# Fold 20 Epoch 1: TotalLoss=0.795407 | Sup=0.795544 | Unsup=-0.136951 | TrainAcc=0.4744
# Fold 20 Epoch 100: TotalLoss=0.088008 | Sup=0.088173 | Unsup=-0.164508 | TrainAcc=1.0000
# Fold 20 Epoch 200: TotalLoss=0.043422 | Sup=0.043591 | Unsup=-0.168950 | TrainAcc=1.0000
# Fold 20 Epoch 300: TotalLoss=0.018475 | Sup=0.018645 | Unsup=-0.170432 | TrainAcc=1.0000
# Fold 20 Epoch 400: TotalLoss=0.006763 | Sup=0.006935 | Unsup=-0.171285 | TrainAcc=1.0000
# Fold 20 Epoch 500: TotalLoss=0.004452 | Sup=0.004621 | Unsup=-0.168392 | TrainAcc=1.0000
# Fold 20 Epoch 600: TotalLoss=0.001933 | Sup=0.002104 | Unsup=-0.170862 | TrainAcc=1.0000
# Fold 20 Epoch 700: TotalLoss=0.002396 | Sup=0.002569 | Unsup=-0.172752 | TrainAcc=1.0000
# Fold 20 Epoch 800: TotalLoss=0.002057 | Sup=0.002225 | Unsup=-0.168086 | TrainAcc=1.0000
# Fold 20 Epoch 900: TotalLoss=0.001594 | Sup=0.001770 | Unsup=-0.175417 | TrainAcc=1.0000
# Fold 20 Epoch 1000: TotalLoss=0.001200 | Sup=0.001372 | Unsup=-0.171952 | TrainAcc=1.0000
# Fold 20 Epoch 1100: TotalLoss=0.002087 | Sup=0.002257 | Unsup=-0.169994 | TrainAcc=1.0000
# Fold 20 Epoch 1200: TotalLoss=0.001443 | Sup=0.001621 | Unsup=-0.177794 | TrainAcc=1.0000
# Fold 20 Epoch 1300: TotalLoss=0.000788 | Sup=0.000965 | Unsup=-0.177230 | TrainAcc=1.0000
# Fold 20 Epoch 1400: TotalLoss=0.002859 | Sup=0.003041 | Unsup=-0.181740 | TrainAcc=1.0000
# Fold 20 Epoch 1500: TotalLoss=0.001296 | Sup=0.001465 | Unsup=-0.168837 | TrainAcc=1.0000
# Fold 20 Epoch 1600: TotalLoss=0.000675 | Sup=0.000856 | Unsup=-0.180986 | TrainAcc=1.0000
# Fold 20 Epoch 1700: TotalLoss=0.003235 | Sup=0.003414 | Unsup=-0.179419 | TrainAcc=1.0000
# Fold 20 Epoch 1800: TotalLoss=0.000984 | Sup=0.001161 | Unsup=-0.177378 | TrainAcc=1.0000
# Fold 20 Epoch 1900: TotalLoss=0.000157 | Sup=0.000335 | Unsup=-0.177698 | TrainAcc=1.0000
# Fold 20 Epoch 2000: TotalLoss=0.001882 | Sup=0.002063 | Unsup=-0.181171 | TrainAcc=1.0000
# Fold 20 → Acc=0.7621 | Prec=0.8078 | Rec=0.8850 | F1=0.8447 | AUC=0.7752 | CE Loss=1.0836
#
# === Average Results Across 20 Folds ===
# Accuracy:  0.7539 ± 0.0315
# Precision: 0.8656 ± 0.0277
# Recall:    0.7880 ± 0.0646
# F1-score:  0.8227 ± 0.0300
# AUC:       0.8039 ± 0.0318
# CE Loss:   0.9859 ± 0.1780
