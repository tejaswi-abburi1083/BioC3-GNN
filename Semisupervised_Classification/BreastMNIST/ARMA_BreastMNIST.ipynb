# %%
# !pip install -q torch_geometric
# !pip install -q class_resolver
# !pip3 install pymatting
# Out:
# Requirement already satisfied: pymatting in ./.local/lib/python3.10/site-packages (1.1.14)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -q torch_geometric
# !pip install -q class_resolver
# !pip3 install pymatting
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 22.7 MB/s eta 0:00:00
# Collecting pymatting
#   Downloading pymatting-1.1.14-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from pymatting) (2.0.2)
# Requirement already satisfied: pillow>=5.2.0 in /usr/local/lib/python3.12/dist-packages (from pymatting) (11.3.0)
# Requirement already satisfied: numba!=0.49.0 in /usr/local/lib/python3.12/dist-packages (from pymatting) (0.60.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from pymatting) (1.16.3)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba!=0.49.0->pymatting) (0.43.0)
# Downloading pymatting-1.1.14-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.7/54.7 kB 3.2 MB/s eta 0:00:00
# Installing collected packages: pymatting
# Successfully installed pymatting-1.1.14

# %%
import torch
import torch.nn as nn
import torch.nn.functional as nnFn
import torch.optim as optim
import numpy as np
import random
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from torch_geometric.data import Data
from torch_geometric.nn import ChebConv
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, roc_auc_score, log_loss
)
from torch.utils.data import TensorDataset, DataLoader, Subset
from torch_geometric.data import Data
from torch_geometric.nn import ARMAConv

# %%
data = np.load('/content/drive/MyDrive/TejaswiAbburi_va797/Dataset/Medmnist_data/breastmnist_224.npz', allow_pickle=True)
all_images = np.concatenate([data['train_images'], data['val_images'], data['test_images']], axis=0)
all_labels = np.concatenate([data['train_labels'], data['val_labels'], data['test_labels']], axis=0).squeeze()

# Convert to 3-channel RGB
images = all_images.astype(np.float32) / 255.0
images = np.repeat(images[:, None, :, :], 3, axis=1)  # (N, 3, 224, 224)
X_torch = torch.tensor(images)
y_torch = torch.tensor(all_labels).long()
print(f"Raw images: {X_torch.shape}, Labels: {y_torch.shape}")
# Out:
# Raw images: torch.Size([780, 3, 224, 224]), Labels: torch.Size([780])

# %%
class0_idx = [i for i in range(len(y_torch)) if y_torch[i] == 0]
class1_idx = [i for i in range(len(y_torch)) if y_torch[i] == 1]

random.seed(42)
sampled_class0 = random.sample(class0_idx, min(1000, len(class0_idx)))
sampled_class1 = random.sample(class1_idx, min(1000, len(class1_idx)))

selected_indices = sampled_class0 + sampled_class1
random.shuffle(selected_indices)

subset_dataset = Subset(TensorDataset(X_torch, y_torch), selected_indices)
subset_loader = DataLoader(subset_dataset, batch_size=64, shuffle=False)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
vit = torch.hub.load('facebookresearch/dino:main', 'dino_vitb16')
vit.eval().to(device)

vit_feats, y_list = [], []

with torch.no_grad():
    for imgs, lbls in subset_loader:
        imgs = imgs.to(device)
        feats = vit(imgs)
        vit_feats.append(feats.cpu())
        y_list.extend(lbls.cpu().tolist())

F = torch.cat(vit_feats, dim=0).numpy().astype(np.float32)
y = np.array(y_list).astype(np.int64)

num_nodes, num_feats = F.shape
print(f"Extracted ViT-DINO Features: {F.shape}, Labels: {y.shape}")
# Out:
# Downloading: "https://github.com/facebookresearch/dino/zipball/main" to /root/.cache/torch/hub/main.zip
# Downloading: "https://dl.fbaipublicfiles.com/dino/dino_vitbase16_pretrain/dino_vitbase16_pretrain.pth" to /root/.cache/torch/hub/checkpoints/dino_vitbase16_pretrain.pth
# 100%|██████████| 327M/327M [00:03<00:00, 113MB/s]
# Extracted ViT-DINO Features: (780, 768), Labels: (780,)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as nnFn
from torch_geometric.nn import ARMAConv

class ARMA_Supervised(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, device, num_stacks=1, num_layers=1):
        super(ARMA_Supervised, self).__init__()
        self.device = device

        self.conv1 = ARMAConv(input_dim, hidden_dim, num_stacks=num_stacks, num_layers=num_layers,
                              shared_weights=True, dropout=0.3)
        self.conv2 = ARMAConv(hidden_dim, hidden_dim, num_stacks=num_stacks, num_layers=num_layers,
                              shared_weights=True, dropout=0.3)
        self.conv3 = ARMAConv(hidden_dim, hidden_dim, num_stacks=num_stacks, num_layers=num_layers,
                              shared_weights=True, dropout=0.3)

        self.dropout = nn.Dropout(0.25)
        self.fc = nn.Linear(hidden_dim, output_dim)

        activations = {
            "SELU": nnFn.selu,
            "SiLU": nnFn.silu,
            "GELU": nnFn.gelu,
            "RELU": nnFn.relu,
            "ELU": nnFn.elu,
            "PReLU": nnFn.prelu,
            "LeakyReLU": nnFn.leaky_relu
        }
        self.act = activations.get("RELU", nnFn.relu)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index

        # --- Layer 1 ---
        x = self.conv1(x, edge_index)
        x = self.act(x)
        x = self.dropout(x)

        # --- Layer 2 ---
        x = self.conv2(x, edge_index)
        x = self.act(x)
        x = self.dropout(x)

        # --- Layer 3 ---
        x = self.conv3(x, edge_index)
        x = self.act(x)
        x = self.dropout(x)

        logits = self.fc(x)
        return logits

# %%
def create_adj(F, alpha=1):
    F_norm = F / np.linalg.norm(F, axis=1, keepdims=True)
    W = np.dot(F_norm, F_norm.T)
    W = np.where(W >= alpha, 1, 0).astype(np.float32)
    W = W / W.max()
    return W

def load_data(adj, node_feats):
    node_feats = torch.from_numpy(node_feats).float()
    edge_index = torch.from_numpy(np.array(np.nonzero((adj > 0))))
    return Data(x=node_feats, edge_index=edge_index)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
alpha = 0.73
feats_dim = num_feats
hidden_dim = 256
num_classes = 2
num_epochs = 2000
lr = 0.0001
weight_decay = 1e-4
batch_print_freq = 100

# %%
W = create_adj(F, alpha)
data = load_data(W, F).to(device)
print(data)
# Out:
# Data(x=[780, 768], edge_index=[2, 266936])

# %%
sss = StratifiedShuffleSplit(n_splits=20, test_size=0.9, random_state=42)

accuracies, precisions, recalls, f1_scores, aucs, ce_losses = [], [], [], [], [], []

for fold, (train_idx, test_idx) in enumerate(sss.split(F, y), start=1):
    print(f"\n=== Fold {fold} ===")

    train_idx_t = torch.from_numpy(train_idx).long().to(device)
    y_train_tensor = torch.from_numpy(y[train_idx]).long().to(device)

    model = ARMA_Supervised(feats_dim, hidden_dim, num_classes, device).to(device)
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    ce_loss = nn.CrossEntropyLoss()

    for epoch in range(1, num_epochs + 1):
        model.train()
        optimizer.zero_grad()

        logits = model(data)
        loss = ce_loss(logits[train_idx_t], y_train_tensor)

        loss.backward()
        optimizer.step()

        if epoch % batch_print_freq == 0 or epoch == 1:
            model.eval()
            with torch.no_grad():
                preds_train = logits[train_idx_t].argmax(dim=1)
                acc_train = accuracy_score(y_train_tensor.cpu(), preds_train.cpu())
            print(f"Fold {fold} Epoch {epoch}: Loss={loss.item():.6f} | TrainAcc={acc_train:.4f}")

    model.eval()
    with torch.no_grad():
        out = model(data)
        preds = out.argmax(dim=1).cpu().numpy()
        probs = torch.softmax(out, dim=1)[:, 1].cpu().numpy()

    y_test = y[test_idx]
    y_pred_test = preds[test_idx]
    y_pred_test = preds[test_idx]
    y_prob_test = probs[test_idx]

    acc = accuracy_score(y_test, y_pred_test)
    prec = precision_score(y_test, y_pred_test, zero_division=0)
    rec = recall_score(y_test, y_pred_test, zero_division=0)
    f1 = f1_score(y_test, y_pred_test, zero_division=0)
    auc = roc_auc_score(y_test, y_prob_test)
    ce = log_loss(y_test, y_prob_test)

    accuracies.append(acc)
    precisions.append(prec)
    recalls.append(rec)
    f1_scores.append(f1)
    aucs.append(auc)
    ce_losses.append(ce)

    print(f"Fold {fold} → "
          f"Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | "
          f"F1={f1:.4f} | AUC={auc:.4f} | CE Loss={ce:.4f}")


# Final summary
print("\n=== Average Results Across 20 Folds ===")
print(f"Accuracy:  {np.mean(accuracies):.4f} \u00b1 {np.std(accuracies):.4f}")
print(f"Precision: {np.mean(precisions):.4f} \u00b1 {np.std(precisions):.4f}")
print(f"Recall:    {np.mean(recalls):.4f} \u00b1 {np.std(recalls):.4f}")
print(f"F1-score:  {np.mean(f1_scores):.4f} \u00b1 {np.std(f1_scores):.4f}")
print(f"AUC:       {np.mean(aucs):.4f} \u00b1 {np.std(aucs):.4f}")
print(f"CE Loss:   {np.mean(ce_losses):.4f} \u00b1 {np.std(ce_losses):.4f}")
# Out:
# === Fold 1 ===
# Fold 1 Epoch 1: Loss=3.185966 | TrainAcc=0.3333
# Fold 1 Epoch 100: Loss=0.446560 | TrainAcc=0.8462
# Fold 1 Epoch 200: Loss=0.260555 | TrainAcc=0.8846
# Fold 1 Epoch 300: Loss=0.162109 | TrainAcc=0.9359
# Fold 1 Epoch 400: Loss=0.092893 | TrainAcc=0.9487
# Fold 1 Epoch 500: Loss=0.080335 | TrainAcc=0.9487
# Fold 1 Epoch 600: Loss=0.026150 | TrainAcc=0.9872
# Fold 1 Epoch 700: Loss=0.083332 | TrainAcc=0.9744
# Fold 1 Epoch 800: Loss=0.072559 | TrainAcc=0.9744
# Fold 1 Epoch 900: Loss=0.056942 | TrainAcc=0.9872
# Fold 1 Epoch 1000: Loss=0.027408 | TrainAcc=0.9872
# Fold 1 Epoch 1100: Loss=0.060267 | TrainAcc=0.9744
# Fold 1 Epoch 1200: Loss=0.017447 | TrainAcc=1.0000
# Fold 1 Epoch 1300: Loss=0.042152 | TrainAcc=0.9872
# Fold 1 Epoch 1400: Loss=0.023882 | TrainAcc=0.9872
# Fold 1 Epoch 1500: Loss=0.031889 | TrainAcc=0.9872
# Fold 1 Epoch 1600: Loss=0.006268 | TrainAcc=1.0000
# Fold 1 Epoch 1700: Loss=0.026706 | TrainAcc=0.9744
# Fold 1 Epoch 1800: Loss=0.019759 | TrainAcc=0.9872
# Fold 1 Epoch 1900: Loss=0.020629 | TrainAcc=1.0000
# Fold 1 Epoch 2000: Loss=0.013816 | TrainAcc=1.0000
# Fold 1 → Acc=0.8048 | Prec=0.8602 | Rec=0.8752 | F1=0.8676 | AUC=0.8479 | CE Loss=1.0483
#
# === Fold 2 ===
# Fold 2 Epoch 1: Loss=1.064196 | TrainAcc=0.5641
# Fold 2 Epoch 100: Loss=0.367141 | TrainAcc=0.8077
# Fold 2 Epoch 200: Loss=0.169822 | TrainAcc=0.9103
# Fold 2 Epoch 300: Loss=0.103431 | TrainAcc=0.9615
# Fold 2 Epoch 400: Loss=0.031995 | TrainAcc=1.0000
# Fold 2 Epoch 500: Loss=0.044575 | TrainAcc=1.0000
# Fold 2 Epoch 600: Loss=0.018905 | TrainAcc=1.0000
# Fold 2 Epoch 700: Loss=0.012408 | TrainAcc=1.0000
# Fold 2 Epoch 800: Loss=0.002704 | TrainAcc=1.0000
# Fold 2 Epoch 900: Loss=0.004039 | TrainAcc=1.0000
# Fold 2 Epoch 1000: Loss=0.001122 | TrainAcc=1.0000
# Fold 2 Epoch 1100: Loss=0.000798 | TrainAcc=1.0000
# Fold 2 Epoch 1200: Loss=0.001205 | TrainAcc=1.0000
# Fold 2 Epoch 1300: Loss=0.003943 | TrainAcc=1.0000
# Fold 2 Epoch 1400: Loss=0.001265 | TrainAcc=1.0000
# Fold 2 Epoch 1500: Loss=0.000409 | TrainAcc=1.0000
# Fold 2 Epoch 1600: Loss=0.001259 | TrainAcc=1.0000
# Fold 2 Epoch 1700: Loss=0.000595 | TrainAcc=1.0000
# Fold 2 Epoch 1800: Loss=0.011519 | TrainAcc=0.9872
# Fold 2 Epoch 1900: Loss=0.000049 | TrainAcc=1.0000
# Fold 2 Epoch 2000: Loss=0.003804 | TrainAcc=1.0000
# Fold 2 → Acc=0.8590 | Prec=0.8833 | Rec=0.9298 | F1=0.9060 | AUC=0.8941 | CE Loss=1.0081
#
# === Fold 3 ===
# Fold 3 Epoch 1: Loss=1.377200 | TrainAcc=0.4487
# Fold 3 Epoch 100: Loss=0.515209 | TrainAcc=0.7436
# Fold 3 Epoch 200: Loss=0.290170 | TrainAcc=0.8846
# Fold 3 Epoch 300: Loss=0.183932 | TrainAcc=0.9359
# Fold 3 Epoch 400: Loss=0.102083 | TrainAcc=0.9487
# Fold 3 Epoch 500: Loss=0.103174 | TrainAcc=0.9615
# Fold 3 Epoch 600: Loss=0.020468 | TrainAcc=1.0000
# Fold 3 Epoch 700: Loss=0.035406 | TrainAcc=0.9872
# Fold 3 Epoch 800: Loss=0.025658 | TrainAcc=1.0000
# Fold 3 Epoch 900: Loss=0.015491 | TrainAcc=1.0000
# Fold 3 Epoch 1000: Loss=0.005056 | TrainAcc=1.0000
# Fold 3 Epoch 1100: Loss=0.003794 | TrainAcc=1.0000
# Fold 3 Epoch 1200: Loss=0.004659 | TrainAcc=1.0000
# Fold 3 Epoch 1300: Loss=0.017076 | TrainAcc=0.9872
# Fold 3 Epoch 1400: Loss=0.017063 | TrainAcc=0.9872
# Fold 3 Epoch 1500: Loss=0.015590 | TrainAcc=0.9872
# Fold 3 Epoch 1600: Loss=0.008236 | TrainAcc=1.0000
# Fold 3 Epoch 1700: Loss=0.001423 | TrainAcc=1.0000
# Fold 3 Epoch 1800: Loss=0.005755 | TrainAcc=1.0000
# Fold 3 Epoch 1900: Loss=0.000865 | TrainAcc=1.0000
# Fold 3 Epoch 2000: Loss=0.001325 | TrainAcc=1.0000
# Fold 3 → Acc=0.8134 | Prec=0.8851 | Rec=0.8558 | F1=0.8702 | AUC=0.8649 | CE Loss=1.0140
#
# === Fold 4 ===
# Fold 4 Epoch 1: Loss=1.113891 | TrainAcc=0.5256
# Fold 4 Epoch 100: Loss=0.465546 | TrainAcc=0.7692
# Fold 4 Epoch 200: Loss=0.337127 | TrainAcc=0.8077
# Fold 4 Epoch 300: Loss=0.152072 | TrainAcc=0.9359
# Fold 4 Epoch 400: Loss=0.115211 | TrainAcc=0.9487
# Fold 4 Epoch 500: Loss=0.119534 | TrainAcc=0.9359
# Fold 4 Epoch 600: Loss=0.084932 | TrainAcc=0.9615
# Fold 4 Epoch 700: Loss=0.025734 | TrainAcc=1.0000
# Fold 4 Epoch 800: Loss=0.045602 | TrainAcc=0.9872
# Fold 4 Epoch 900: Loss=0.005399 | TrainAcc=1.0000
# Fold 4 Epoch 1000: Loss=0.025600 | TrainAcc=0.9744
# Fold 4 Epoch 1100: Loss=0.082124 | TrainAcc=0.9615
# Fold 4 Epoch 1200: Loss=0.001997 | TrainAcc=1.0000
# Fold 4 Epoch 1300: Loss=0.006565 | TrainAcc=1.0000
# Fold 4 Epoch 1400: Loss=0.008935 | TrainAcc=1.0000
# Fold 4 Epoch 1500: Loss=0.006035 | TrainAcc=1.0000
# Fold 4 Epoch 1600: Loss=0.003340 | TrainAcc=1.0000
# Fold 4 Epoch 1700: Loss=0.000664 | TrainAcc=1.0000
# Fold 4 Epoch 1800: Loss=0.004368 | TrainAcc=1.0000
# Fold 4 Epoch 1900: Loss=0.000245 | TrainAcc=1.0000
# Fold 4 Epoch 2000: Loss=0.002171 | TrainAcc=1.0000
# Fold 4 → Acc=0.8177 | Prec=0.8235 | Rec=0.9552 | F1=0.8845 | AUC=0.8210 | CE Loss=1.4967
#
# === Fold 5 ===
# Fold 5 Epoch 1: Loss=1.799042 | TrainAcc=0.4103
# Fold 5 Epoch 100: Loss=0.430336 | TrainAcc=0.8333
# Fold 5 Epoch 200: Loss=0.271690 | TrainAcc=0.8846
# Fold 5 Epoch 300: Loss=0.116969 | TrainAcc=0.9744
# Fold 5 Epoch 400: Loss=0.094718 | TrainAcc=0.9487
# Fold 5 Epoch 500: Loss=0.095640 | TrainAcc=0.9744
# Fold 5 Epoch 600: Loss=0.014305 | TrainAcc=1.0000
# Fold 5 Epoch 700: Loss=0.039244 | TrainAcc=0.9744
# Fold 5 Epoch 800: Loss=0.012709 | TrainAcc=1.0000
# Fold 5 Epoch 900: Loss=0.012310 | TrainAcc=0.9872
# Fold 5 Epoch 1000: Loss=0.016193 | TrainAcc=0.9872
# Fold 5 Epoch 1100: Loss=0.000817 | TrainAcc=1.0000
# Fold 5 Epoch 1200: Loss=0.001461 | TrainAcc=1.0000
# Fold 5 Epoch 1300: Loss=0.011228 | TrainAcc=0.9872
# Fold 5 Epoch 1400: Loss=0.003374 | TrainAcc=1.0000
# Fold 5 Epoch 1500: Loss=0.002324 | TrainAcc=1.0000
# Fold 5 Epoch 1600: Loss=0.002223 | TrainAcc=1.0000
# Fold 5 Epoch 1700: Loss=0.004433 | TrainAcc=1.0000
# Fold 5 Epoch 1800: Loss=0.000237 | TrainAcc=1.0000
# Fold 5 Epoch 1900: Loss=0.000551 | TrainAcc=1.0000
# Fold 5 Epoch 2000: Loss=0.000458 | TrainAcc=1.0000
# Fold 5 → Acc=0.8376 | Prec=0.8715 | Rec=0.9123 | F1=0.8914 | AUC=0.8413 | CE Loss=1.3530
#
# === Fold 6 ===
# Fold 6 Epoch 1: Loss=1.010049 | TrainAcc=0.6154
# Fold 6 Epoch 100: Loss=0.355563 | TrainAcc=0.7949
# Fold 6 Epoch 200: Loss=0.273548 | TrainAcc=0.8974
# Fold 6 Epoch 300: Loss=0.142754 | TrainAcc=0.9615
# Fold 6 Epoch 400: Loss=0.104004 | TrainAcc=0.9487
# Fold 6 Epoch 500: Loss=0.085477 | TrainAcc=0.9615
# Fold 6 Epoch 600: Loss=0.026827 | TrainAcc=0.9872
# Fold 6 Epoch 700: Loss=0.051406 | TrainAcc=0.9744
# Fold 6 Epoch 800: Loss=0.051507 | TrainAcc=0.9872
# Fold 6 Epoch 900: Loss=0.007119 | TrainAcc=1.0000
# Fold 6 Epoch 1000: Loss=0.021329 | TrainAcc=0.9872
# Fold 6 Epoch 1100: Loss=0.011168 | TrainAcc=1.0000
# Fold 6 Epoch 1200: Loss=0.005497 | TrainAcc=1.0000
# Fold 6 Epoch 1300: Loss=0.038844 | TrainAcc=0.9744
# Fold 6 Epoch 1400: Loss=0.065085 | TrainAcc=0.9744
# Fold 6 Epoch 1500: Loss=0.003764 | TrainAcc=1.0000
# Fold 6 Epoch 1600: Loss=0.001306 | TrainAcc=1.0000
# Fold 6 Epoch 1700: Loss=0.000788 | TrainAcc=1.0000
# Fold 6 Epoch 1800: Loss=0.002456 | TrainAcc=1.0000
# Fold 6 Epoch 1900: Loss=0.001256 | TrainAcc=1.0000
# Fold 6 Epoch 2000: Loss=0.000611 | TrainAcc=1.0000
# Fold 6 → Acc=0.8519 | Prec=0.8752 | Rec=0.9298 | F1=0.9017 | AUC=0.8859 | CE Loss=0.9590
#
# === Fold 7 ===
# Fold 7 Epoch 1: Loss=1.613100 | TrainAcc=0.4615
# Fold 7 Epoch 100: Loss=0.396825 | TrainAcc=0.8205
# Fold 7 Epoch 200: Loss=0.256305 | TrainAcc=0.9103
# Fold 7 Epoch 300: Loss=0.108624 | TrainAcc=0.9615
# Fold 7 Epoch 400: Loss=0.104095 | TrainAcc=0.9615
# Fold 7 Epoch 500: Loss=0.136404 | TrainAcc=0.9615
# Fold 7 Epoch 600: Loss=0.200958 | TrainAcc=0.9103
# Fold 7 Epoch 700: Loss=0.029918 | TrainAcc=0.9872
# Fold 7 Epoch 800: Loss=0.020858 | TrainAcc=1.0000
# Fold 7 Epoch 900: Loss=0.024536 | TrainAcc=1.0000
# Fold 7 Epoch 1000: Loss=0.041490 | TrainAcc=0.9744
# Fold 7 Epoch 1100: Loss=0.005938 | TrainAcc=1.0000
# Fold 7 Epoch 1200: Loss=0.005440 | TrainAcc=1.0000
# Fold 7 Epoch 1300: Loss=0.002061 | TrainAcc=1.0000
# Fold 7 Epoch 1400: Loss=0.002997 | TrainAcc=1.0000
# Fold 7 Epoch 1500: Loss=0.004423 | TrainAcc=1.0000
# Fold 7 Epoch 1600: Loss=0.000948 | TrainAcc=1.0000
# Fold 7 Epoch 1700: Loss=0.001179 | TrainAcc=1.0000
# Fold 7 Epoch 1800: Loss=0.014847 | TrainAcc=0.9872
# Fold 7 Epoch 1900: Loss=0.008321 | TrainAcc=1.0000
# Fold 7 Epoch 2000: Loss=0.006084 | TrainAcc=1.0000
# Fold 7 → Acc=0.8191 | Prec=0.8784 | Rec=0.8733 | F1=0.8759 | AUC=0.8782 | CE Loss=1.2257
#
# === Fold 8 ===
# Fold 8 Epoch 1: Loss=1.349560 | TrainAcc=0.5385
# Fold 8 Epoch 100: Loss=0.480821 | TrainAcc=0.7564
# Fold 8 Epoch 200: Loss=0.223597 | TrainAcc=0.8974
# Fold 8 Epoch 300: Loss=0.193790 | TrainAcc=0.9103
# Fold 8 Epoch 400: Loss=0.125711 | TrainAcc=0.9615
# Fold 8 Epoch 500: Loss=0.221869 | TrainAcc=0.8846
# Fold 8 Epoch 600: Loss=0.064562 | TrainAcc=0.9744
# Fold 8 Epoch 700: Loss=0.019089 | TrainAcc=1.0000
# Fold 8 Epoch 800: Loss=0.038934 | TrainAcc=0.9872
# Fold 8 Epoch 900: Loss=0.009732 | TrainAcc=1.0000
# Fold 8 Epoch 1000: Loss=0.125410 | TrainAcc=0.9872
# Fold 8 Epoch 1100: Loss=0.018984 | TrainAcc=0.9872
# Fold 8 Epoch 1200: Loss=0.005828 | TrainAcc=1.0000
# Fold 8 Epoch 1300: Loss=0.016210 | TrainAcc=1.0000
# Fold 8 Epoch 1400: Loss=0.003369 | TrainAcc=1.0000
# Fold 8 Epoch 1500: Loss=0.002207 | TrainAcc=1.0000
# Fold 8 Epoch 1600: Loss=0.003905 | TrainAcc=1.0000
# Fold 8 Epoch 1700: Loss=0.002550 | TrainAcc=1.0000
# Fold 8 Epoch 1800: Loss=0.001732 | TrainAcc=1.0000
# Fold 8 Epoch 1900: Loss=0.008003 | TrainAcc=1.0000
# Fold 8 Epoch 2000: Loss=0.001708 | TrainAcc=1.0000
# Fold 8 → Acc=0.8504 | Prec=0.8893 | Rec=0.9084 | F1=0.8987 | AUC=0.9052 | CE Loss=0.7853
#
# === Fold 9 ===
# Fold 9 Epoch 1: Loss=1.570653 | TrainAcc=0.7179
# Fold 9 Epoch 100: Loss=0.513324 | TrainAcc=0.7821
# Fold 9 Epoch 200: Loss=0.305945 | TrainAcc=0.8462
# Fold 9 Epoch 300: Loss=0.150172 | TrainAcc=0.9615
# Fold 9 Epoch 400: Loss=0.131351 | TrainAcc=0.9487
# Fold 9 Epoch 500: Loss=0.110170 | TrainAcc=0.9615
# Fold 9 Epoch 600: Loss=0.103462 | TrainAcc=0.9615
# Fold 9 Epoch 700: Loss=0.036510 | TrainAcc=0.9744
# Fold 9 Epoch 800: Loss=0.044496 | TrainAcc=0.9872
# Fold 9 Epoch 900: Loss=0.048673 | TrainAcc=0.9744
# Fold 9 Epoch 1000: Loss=0.017743 | TrainAcc=1.0000
# Fold 9 Epoch 1100: Loss=0.003042 | TrainAcc=1.0000
# Fold 9 Epoch 1200: Loss=0.035155 | TrainAcc=0.9744
# Fold 9 Epoch 1300: Loss=0.002379 | TrainAcc=1.0000
# Fold 9 Epoch 1400: Loss=0.024824 | TrainAcc=0.9872
# Fold 9 Epoch 1500: Loss=0.010443 | TrainAcc=0.9872
# Fold 9 Epoch 1600: Loss=0.011748 | TrainAcc=1.0000
# Fold 9 Epoch 1700: Loss=0.016928 | TrainAcc=0.9872
# Fold 9 Epoch 1800: Loss=0.000492 | TrainAcc=1.0000
# Fold 9 Epoch 1900: Loss=0.003733 | TrainAcc=1.0000
# Fold 9 Epoch 2000: Loss=0.044809 | TrainAcc=0.9872
# Fold 9 → Acc=0.8447 | Prec=0.8755 | Rec=0.9181 | F1=0.8963 | AUC=0.9038 | CE Loss=0.8931
#
# === Fold 10 ===
# Fold 10 Epoch 1: Loss=2.998161 | TrainAcc=0.2692
# Fold 10 Epoch 100: Loss=0.536877 | TrainAcc=0.7692
# Fold 10 Epoch 200: Loss=0.325580 | TrainAcc=0.8718
# Fold 10 Epoch 300: Loss=0.127914 | TrainAcc=0.9487
# Fold 10 Epoch 400: Loss=0.103725 | TrainAcc=0.9615
# Fold 10 Epoch 500: Loss=0.060290 | TrainAcc=1.0000
# Fold 10 Epoch 600: Loss=0.039975 | TrainAcc=0.9872
# Fold 10 Epoch 700: Loss=0.074827 | TrainAcc=0.9872
# Fold 10 Epoch 800: Loss=0.019041 | TrainAcc=1.0000
# Fold 10 Epoch 900: Loss=0.057291 | TrainAcc=0.9744
# Fold 10 Epoch 1000: Loss=0.048518 | TrainAcc=0.9615
# Fold 10 Epoch 1100: Loss=0.004826 | TrainAcc=1.0000
# Fold 10 Epoch 1200: Loss=0.010425 | TrainAcc=1.0000
# Fold 10 Epoch 1300: Loss=0.016771 | TrainAcc=0.9872
# Fold 10 Epoch 1400: Loss=0.003899 | TrainAcc=1.0000
# Fold 10 Epoch 1500: Loss=0.001766 | TrainAcc=1.0000
# Fold 10 Epoch 1600: Loss=0.005794 | TrainAcc=1.0000
# Fold 10 Epoch 1700: Loss=0.000974 | TrainAcc=1.0000
# Fold 10 Epoch 1800: Loss=0.003015 | TrainAcc=1.0000
# Fold 10 Epoch 1900: Loss=0.005736 | TrainAcc=1.0000
# Fold 10 Epoch 2000: Loss=0.004104 | TrainAcc=1.0000
# Fold 10 → Acc=0.8177 | Prec=0.8738 | Rec=0.8772 | F1=0.8755 | AUC=0.8717 | CE Loss=1.1141
#
# === Fold 11 ===
# Fold 11 Epoch 1: Loss=1.308083 | TrainAcc=0.3974
# Fold 11 Epoch 100: Loss=0.450392 | TrainAcc=0.7821
# Fold 11 Epoch 200: Loss=0.371696 | TrainAcc=0.8846
# Fold 11 Epoch 300: Loss=0.266869 | TrainAcc=0.8718
# Fold 11 Epoch 400: Loss=0.161801 | TrainAcc=0.9231
# Fold 11 Epoch 500: Loss=0.078057 | TrainAcc=0.9872
# Fold 11 Epoch 600: Loss=0.029682 | TrainAcc=1.0000
# Fold 11 Epoch 700: Loss=0.044334 | TrainAcc=0.9872
# Fold 11 Epoch 800: Loss=0.080428 | TrainAcc=0.9615
# Fold 11 Epoch 900: Loss=0.013407 | TrainAcc=1.0000
# Fold 11 Epoch 1000: Loss=0.019624 | TrainAcc=0.9872
# Fold 11 Epoch 1100: Loss=0.056762 | TrainAcc=0.9872
# Fold 11 Epoch 1200: Loss=0.001439 | TrainAcc=1.0000
# Fold 11 Epoch 1300: Loss=0.007218 | TrainAcc=1.0000
# Fold 11 Epoch 1400: Loss=0.006525 | TrainAcc=1.0000
# Fold 11 Epoch 1500: Loss=0.005158 | TrainAcc=1.0000
# Fold 11 Epoch 1600: Loss=0.001231 | TrainAcc=1.0000
# Fold 11 Epoch 1700: Loss=0.001086 | TrainAcc=1.0000
# Fold 11 Epoch 1800: Loss=0.000722 | TrainAcc=1.0000
# Fold 11 Epoch 1900: Loss=0.003725 | TrainAcc=1.0000
# Fold 11 Epoch 2000: Loss=0.006825 | TrainAcc=1.0000
# Fold 11 → Acc=0.8362 | Prec=0.8769 | Rec=0.9025 | F1=0.8895 | AUC=0.8734 | CE Loss=1.1826
#
# === Fold 12 ===
# Fold 12 Epoch 1: Loss=1.614617 | TrainAcc=0.4487
# Fold 12 Epoch 100: Loss=0.459948 | TrainAcc=0.7564
# Fold 12 Epoch 200: Loss=0.327028 | TrainAcc=0.8718
# Fold 12 Epoch 300: Loss=0.149530 | TrainAcc=0.9359
# Fold 12 Epoch 400: Loss=0.127254 | TrainAcc=0.9615
# Fold 12 Epoch 500: Loss=0.085107 | TrainAcc=0.9744
# Fold 12 Epoch 600: Loss=0.071908 | TrainAcc=0.9872
# Fold 12 Epoch 700: Loss=0.089030 | TrainAcc=0.9872
# Fold 12 Epoch 800: Loss=0.013776 | TrainAcc=1.0000
# Fold 12 Epoch 900: Loss=0.015077 | TrainAcc=1.0000
# Fold 12 Epoch 1000: Loss=0.067317 | TrainAcc=0.9744
# Fold 12 Epoch 1100: Loss=0.012727 | TrainAcc=1.0000
# Fold 12 Epoch 1200: Loss=0.006087 | TrainAcc=1.0000
# Fold 12 Epoch 1300: Loss=0.015376 | TrainAcc=0.9872
# Fold 12 Epoch 1400: Loss=0.054637 | TrainAcc=0.9872
# Fold 12 Epoch 1500: Loss=0.002652 | TrainAcc=1.0000
# Fold 12 Epoch 1600: Loss=0.002075 | TrainAcc=1.0000
# Fold 12 Epoch 1700: Loss=0.002817 | TrainAcc=1.0000
# Fold 12 Epoch 1800: Loss=0.013749 | TrainAcc=1.0000
# Fold 12 Epoch 1900: Loss=0.002826 | TrainAcc=1.0000
# Fold 12 Epoch 2000: Loss=0.003110 | TrainAcc=1.0000
# Fold 12 → Acc=0.8675 | Prec=0.8947 | Rec=0.9279 | F1=0.9110 | AUC=0.9061 | CE Loss=0.8147
#
# === Fold 13 ===
# Fold 13 Epoch 1: Loss=3.461532 | TrainAcc=0.2821
# Fold 13 Epoch 100: Loss=0.454759 | TrainAcc=0.8333
# Fold 13 Epoch 200: Loss=0.311778 | TrainAcc=0.8718
# Fold 13 Epoch 300: Loss=0.196289 | TrainAcc=0.9359
# Fold 13 Epoch 400: Loss=0.182435 | TrainAcc=0.9359
# Fold 13 Epoch 500: Loss=0.090308 | TrainAcc=0.9744
# Fold 13 Epoch 600: Loss=0.051169 | TrainAcc=1.0000
# Fold 13 Epoch 700: Loss=0.083603 | TrainAcc=0.9615
# Fold 13 Epoch 800: Loss=0.074577 | TrainAcc=0.9615
# Fold 13 Epoch 900: Loss=0.054435 | TrainAcc=0.9744
# Fold 13 Epoch 1000: Loss=0.021410 | TrainAcc=1.0000
# Fold 13 Epoch 1100: Loss=0.011460 | TrainAcc=1.0000
# Fold 13 Epoch 1200: Loss=0.086081 | TrainAcc=0.9487
# Fold 13 Epoch 1300: Loss=0.025714 | TrainAcc=0.9872
# Fold 13 Epoch 1400: Loss=0.013614 | TrainAcc=1.0000
# Fold 13 Epoch 1500: Loss=0.056187 | TrainAcc=0.9744
# Fold 13 Epoch 1600: Loss=0.051188 | TrainAcc=0.9744
# Fold 13 Epoch 1700: Loss=0.030103 | TrainAcc=0.9872
# Fold 13 Epoch 1800: Loss=0.015814 | TrainAcc=1.0000
# Fold 13 Epoch 1900: Loss=0.045476 | TrainAcc=0.9872
# Fold 13 Epoch 2000: Loss=0.019506 | TrainAcc=0.9872
# Fold 13 → Acc=0.8405 | Prec=0.8475 | Rec=0.9532 | F1=0.8972 | AUC=0.8734 | CE Loss=0.8449
#
# === Fold 14 ===
# Fold 14 Epoch 1: Loss=1.180081 | TrainAcc=0.5385
# Fold 14 Epoch 100: Loss=0.410327 | TrainAcc=0.8205
# Fold 14 Epoch 200: Loss=0.310788 | TrainAcc=0.8846
# Fold 14 Epoch 300: Loss=0.202607 | TrainAcc=0.9359
# Fold 14 Epoch 400: Loss=0.111632 | TrainAcc=0.9615
# Fold 14 Epoch 500: Loss=0.030400 | TrainAcc=1.0000
# Fold 14 Epoch 600: Loss=0.040920 | TrainAcc=0.9872
# Fold 14 Epoch 700: Loss=0.062942 | TrainAcc=0.9744
# Fold 14 Epoch 800: Loss=0.062566 | TrainAcc=0.9872
# Fold 14 Epoch 900: Loss=0.006800 | TrainAcc=1.0000
# Fold 14 Epoch 1000: Loss=0.007500 | TrainAcc=1.0000
# Fold 14 Epoch 1100: Loss=0.053446 | TrainAcc=0.9744
# Fold 14 Epoch 1200: Loss=0.046779 | TrainAcc=0.9744
# Fold 14 Epoch 1300: Loss=0.004061 | TrainAcc=1.0000
# Fold 14 Epoch 1400: Loss=0.027477 | TrainAcc=0.9872
# Fold 14 Epoch 1500: Loss=0.009349 | TrainAcc=1.0000
# Fold 14 Epoch 1600: Loss=0.003314 | TrainAcc=1.0000
# Fold 14 Epoch 1700: Loss=0.002786 | TrainAcc=1.0000
# Fold 14 Epoch 1800: Loss=0.005335 | TrainAcc=1.0000
# Fold 14 Epoch 1900: Loss=0.000172 | TrainAcc=1.0000
# Fold 14 Epoch 2000: Loss=0.001663 | TrainAcc=1.0000
# Fold 14 → Acc=0.8818 | Prec=0.9041 | Rec=0.9376 | F1=0.9206 | AUC=0.9117 | CE Loss=0.7321
#
# === Fold 15 ===
# Fold 15 Epoch 1: Loss=0.928182 | TrainAcc=0.5897
# Fold 15 Epoch 100: Loss=0.422708 | TrainAcc=0.8205
# Fold 15 Epoch 200: Loss=0.228169 | TrainAcc=0.9487
# Fold 15 Epoch 300: Loss=0.156535 | TrainAcc=0.9359
# Fold 15 Epoch 400: Loss=0.166451 | TrainAcc=0.9359
# Fold 15 Epoch 500: Loss=0.073266 | TrainAcc=0.9487
# Fold 15 Epoch 600: Loss=0.027207 | TrainAcc=1.0000
# Fold 15 Epoch 700: Loss=0.013889 | TrainAcc=1.0000
# Fold 15 Epoch 800: Loss=0.035637 | TrainAcc=0.9872
# Fold 15 Epoch 900: Loss=0.018500 | TrainAcc=0.9872
# Fold 15 Epoch 1000: Loss=0.026301 | TrainAcc=0.9744
# Fold 15 Epoch 1100: Loss=0.005048 | TrainAcc=1.0000
# Fold 15 Epoch 1200: Loss=0.014326 | TrainAcc=0.9872
# Fold 15 Epoch 1300: Loss=0.003508 | TrainAcc=1.0000
# Fold 15 Epoch 1400: Loss=0.002396 | TrainAcc=1.0000
# Fold 15 Epoch 1500: Loss=0.002197 | TrainAcc=1.0000
# Fold 15 Epoch 1600: Loss=0.011734 | TrainAcc=1.0000
# Fold 15 Epoch 1700: Loss=0.025981 | TrainAcc=0.9872
# Fold 15 Epoch 1800: Loss=0.008789 | TrainAcc=1.0000
# Fold 15 Epoch 1900: Loss=0.002062 | TrainAcc=1.0000
# Fold 15 Epoch 2000: Loss=0.097339 | TrainAcc=0.9744
# Fold 15 → Acc=0.8504 | Prec=0.8864 | Rec=0.9123 | F1=0.8991 | AUC=0.9041 | CE Loss=0.8428
#
# === Fold 16 ===
# Fold 16 Epoch 1: Loss=1.392576 | TrainAcc=0.5000
# Fold 16 Epoch 100: Loss=0.482157 | TrainAcc=0.7436
# Fold 16 Epoch 200: Loss=0.262720 | TrainAcc=0.8718
# Fold 16 Epoch 300: Loss=0.103493 | TrainAcc=0.9744
# Fold 16 Epoch 400: Loss=0.069647 | TrainAcc=0.9872
# Fold 16 Epoch 500: Loss=0.084365 | TrainAcc=0.9744
# Fold 16 Epoch 600: Loss=0.054784 | TrainAcc=0.9744
# Fold 16 Epoch 700: Loss=0.023766 | TrainAcc=0.9872
# Fold 16 Epoch 800: Loss=0.010417 | TrainAcc=1.0000
# Fold 16 Epoch 900: Loss=0.014219 | TrainAcc=1.0000
# Fold 16 Epoch 1000: Loss=0.006470 | TrainAcc=1.0000
# Fold 16 Epoch 1100: Loss=0.014606 | TrainAcc=0.9872
# Fold 16 Epoch 1200: Loss=0.017220 | TrainAcc=0.9872
# Fold 16 Epoch 1300: Loss=0.013076 | TrainAcc=0.9872
# Fold 16 Epoch 1400: Loss=0.005359 | TrainAcc=1.0000
# Fold 16 Epoch 1500: Loss=0.004108 | TrainAcc=1.0000
# Fold 16 Epoch 1600: Loss=0.000768 | TrainAcc=1.0000
# Fold 16 Epoch 1700: Loss=0.001433 | TrainAcc=1.0000
# Fold 16 Epoch 1800: Loss=0.000801 | TrainAcc=1.0000
# Fold 16 Epoch 1900: Loss=0.016914 | TrainAcc=0.9872
# Fold 16 Epoch 2000: Loss=0.032507 | TrainAcc=0.9872
# Fold 16 → Acc=0.8205 | Prec=0.8550 | Rec=0.9084 | F1=0.8809 | AUC=0.8517 | CE Loss=1.2726
#
# === Fold 17 ===
# Fold 17 Epoch 1: Loss=1.068073 | TrainAcc=0.7051
# Fold 17 Epoch 100: Loss=0.365013 | TrainAcc=0.8462
# Fold 17 Epoch 200: Loss=0.164316 | TrainAcc=0.9359
# Fold 17 Epoch 300: Loss=0.056482 | TrainAcc=0.9615
# Fold 17 Epoch 400: Loss=0.082828 | TrainAcc=0.9615
# Fold 17 Epoch 500: Loss=0.014791 | TrainAcc=1.0000
# Fold 17 Epoch 600: Loss=0.012644 | TrainAcc=1.0000
# Fold 17 Epoch 700: Loss=0.019510 | TrainAcc=0.9872
# Fold 17 Epoch 800: Loss=0.049435 | TrainAcc=0.9744
# Fold 17 Epoch 900: Loss=0.045991 | TrainAcc=0.9872
# Fold 17 Epoch 1000: Loss=0.007028 | TrainAcc=1.0000
# Fold 17 Epoch 1100: Loss=0.002853 | TrainAcc=1.0000
# Fold 17 Epoch 1200: Loss=0.000945 | TrainAcc=1.0000
# Fold 17 Epoch 1300: Loss=0.001296 | TrainAcc=1.0000
# Fold 17 Epoch 1400: Loss=0.001606 | TrainAcc=1.0000
# Fold 17 Epoch 1500: Loss=0.001105 | TrainAcc=1.0000
# Fold 17 Epoch 1600: Loss=0.022699 | TrainAcc=0.9872
# Fold 17 Epoch 1700: Loss=0.001679 | TrainAcc=1.0000
# Fold 17 Epoch 1800: Loss=0.014451 | TrainAcc=0.9872
# Fold 17 Epoch 1900: Loss=0.000401 | TrainAcc=1.0000
# Fold 17 Epoch 2000: Loss=0.000442 | TrainAcc=1.0000
# Fold 17 → Acc=0.8575 | Prec=0.8721 | Rec=0.9435 | F1=0.9064 | AUC=0.8668 | CE Loss=1.3735
#
# === Fold 18 ===
# Fold 18 Epoch 1: Loss=1.144159 | TrainAcc=0.5513
# Fold 18 Epoch 100: Loss=0.386051 | TrainAcc=0.8205
# Fold 18 Epoch 200: Loss=0.190014 | TrainAcc=0.9231
# Fold 18 Epoch 300: Loss=0.156837 | TrainAcc=0.9359
# Fold 18 Epoch 400: Loss=0.146009 | TrainAcc=0.9615
# Fold 18 Epoch 500: Loss=0.073695 | TrainAcc=0.9744
# Fold 18 Epoch 600: Loss=0.038478 | TrainAcc=1.0000
# Fold 18 Epoch 700: Loss=0.042245 | TrainAcc=0.9744
# Fold 18 Epoch 800: Loss=0.011307 | TrainAcc=1.0000
# Fold 18 Epoch 900: Loss=0.053559 | TrainAcc=0.9872
# Fold 18 Epoch 1000: Loss=0.019951 | TrainAcc=1.0000
# Fold 18 Epoch 1100: Loss=0.002062 | TrainAcc=1.0000
# Fold 18 Epoch 1200: Loss=0.014893 | TrainAcc=1.0000
# Fold 18 Epoch 1300: Loss=0.001667 | TrainAcc=1.0000
# Fold 18 Epoch 1400: Loss=0.006525 | TrainAcc=1.0000
# Fold 18 Epoch 1500: Loss=0.002409 | TrainAcc=1.0000
# Fold 18 Epoch 1600: Loss=0.033679 | TrainAcc=0.9872
# Fold 18 Epoch 1700: Loss=0.005831 | TrainAcc=1.0000
# Fold 18 Epoch 1800: Loss=0.008406 | TrainAcc=1.0000
# Fold 18 Epoch 1900: Loss=0.004752 | TrainAcc=1.0000
# Fold 18 Epoch 2000: Loss=0.051852 | TrainAcc=0.9872
# Fold 18 → Acc=0.8647 | Prec=0.8814 | Rec=0.9415 | F1=0.9105 | AUC=0.8867 | CE Loss=0.9424
#
# === Fold 19 ===
# Fold 19 Epoch 1: Loss=1.696852 | TrainAcc=0.3590
# Fold 19 Epoch 100: Loss=0.472923 | TrainAcc=0.8205
# Fold 19 Epoch 200: Loss=0.352933 | TrainAcc=0.8205
# Fold 19 Epoch 300: Loss=0.251651 | TrainAcc=0.8718
# Fold 19 Epoch 400: Loss=0.146206 | TrainAcc=0.9359
# Fold 19 Epoch 500: Loss=0.046016 | TrainAcc=0.9872
# Fold 19 Epoch 600: Loss=0.028296 | TrainAcc=1.0000
# Fold 19 Epoch 700: Loss=0.086380 | TrainAcc=0.9615
# Fold 19 Epoch 800: Loss=0.054705 | TrainAcc=0.9744
# Fold 19 Epoch 900: Loss=0.021549 | TrainAcc=0.9872
# Fold 19 Epoch 1000: Loss=0.077807 | TrainAcc=0.9744
# Fold 19 Epoch 1100: Loss=0.039518 | TrainAcc=0.9872
# Fold 19 Epoch 1200: Loss=0.004878 | TrainAcc=1.0000
# Fold 19 Epoch 1300: Loss=0.025716 | TrainAcc=0.9872
# Fold 19 Epoch 1400: Loss=0.004973 | TrainAcc=1.0000
# Fold 19 Epoch 1500: Loss=0.007564 | TrainAcc=1.0000
# Fold 19 Epoch 1600: Loss=0.005445 | TrainAcc=1.0000
# Fold 19 Epoch 1700: Loss=0.000593 | TrainAcc=1.0000
# Fold 19 Epoch 1800: Loss=0.056379 | TrainAcc=0.9872
# Fold 19 Epoch 1900: Loss=0.001200 | TrainAcc=1.0000
# Fold 19 Epoch 2000: Loss=0.003687 | TrainAcc=1.0000
# Fold 19 → Acc=0.8661 | Prec=0.9037 | Rec=0.9142 | F1=0.9089 | AUC=0.9168 | CE Loss=0.6366
#
# === Fold 20 ===
# Fold 20 Epoch 1: Loss=1.482687 | TrainAcc=0.4744
# Fold 20 Epoch 100: Loss=0.574662 | TrainAcc=0.6795
# Fold 20 Epoch 200: Loss=0.410847 | TrainAcc=0.7949
# Fold 20 Epoch 300: Loss=0.192423 | TrainAcc=0.9103
# Fold 20 Epoch 400: Loss=0.121933 | TrainAcc=0.9487
# Fold 20 Epoch 500: Loss=0.104341 | TrainAcc=0.9487
# Fold 20 Epoch 600: Loss=0.026063 | TrainAcc=1.0000
# Fold 20 Epoch 700: Loss=0.013894 | TrainAcc=1.0000
# Fold 20 Epoch 800: Loss=0.016038 | TrainAcc=1.0000
# Fold 20 Epoch 900: Loss=0.021669 | TrainAcc=1.0000
# Fold 20 Epoch 1000: Loss=0.014024 | TrainAcc=1.0000
# Fold 20 Epoch 1100: Loss=0.035225 | TrainAcc=0.9872
# Fold 20 Epoch 1200: Loss=0.001057 | TrainAcc=1.0000
# Fold 20 Epoch 1300: Loss=0.003333 | TrainAcc=1.0000
# Fold 20 Epoch 1400: Loss=0.004005 | TrainAcc=1.0000
# Fold 20 Epoch 1500: Loss=0.004857 | TrainAcc=1.0000
# Fold 20 Epoch 1600: Loss=0.064416 | TrainAcc=0.9872
# Fold 20 Epoch 1700: Loss=0.018526 | TrainAcc=0.9872
# Fold 20 Epoch 1800: Loss=0.003446 | TrainAcc=1.0000
# Fold 20 Epoch 1900: Loss=0.012663 | TrainAcc=0.9872
# Fold 20 Epoch 2000: Loss=0.001102 | TrainAcc=1.0000
# Fold 20 → Acc=0.8661 | Prec=0.8802 | Rec=0.9454 | F1=0.9117 | AUC=0.9125 | CE Loss=0.7179
#
# === Average Results Across 20 Folds ===
# Accuracy:  0.8434 ± 0.0213
# Precision: 0.8759 ± 0.0183
# Recall:    0.9161 ± 0.0275
# F1-score:  0.8952 ± 0.0149
# AUC:       0.8809 ± 0.0260
# CE Loss:   1.0129 ± 0.2357
