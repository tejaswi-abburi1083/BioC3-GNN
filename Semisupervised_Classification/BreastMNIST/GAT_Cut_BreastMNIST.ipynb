# %%
# !pip install -q torch_geometric
# !pip install -q class_resolver
# !pip3 install pymatting

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import torch
import torch.nn as nn
import torch.nn.functional as nnFn
import torch.optim as optim
import numpy as np
import random
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from torch_geometric.data import Data
from torch_geometric.nn import ARMAConv
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, roc_auc_score, log_loss
)
from torch.utils.data import TensorDataset, DataLoader, Subset
from torch_geometric.data import Data
from torch_geometric.nn import ARMAConv
from torch.utils.data import TensorDataset, DataLoader, Subset
from torchvision import models

# %%
import torch
print("CUDA available:", torch.cuda.is_available())
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("GPU Name:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU")
# Out:
# CUDA available: True
# GPU Name: NVIDIA RTX A4000

# %%
data = np.load('/home/snu/Downloads/breastmnist_224.npz', allow_pickle=True)
all_images = np.concatenate([data['train_images'], data['val_images'], data['test_images']], axis=0)
all_labels = np.concatenate([data['train_labels'], data['val_labels'], data['test_labels']], axis=0).squeeze()

# Convert to 3-channel RGB
images = all_images.astype(np.float32) / 255.0
images = np.repeat(images[:, None, :, :], 3, axis=1)  # (N, 3, 224, 224)
X_torch = torch.tensor(images)
y_torch = torch.tensor(all_labels).long()
print(f"Raw images: {X_torch.shape}, Labels: {y_torch.shape}")
# Out:
# Raw images: torch.Size([780, 3, 224, 224]), Labels: torch.Size([780])

# %%
class0_idx = [i for i in range(len(y_torch)) if y_torch[i] == 0]
class1_idx = [i for i in range(len(y_torch)) if y_torch[i] == 1]

random.seed(42)
sampled_class0 = random.sample(class0_idx, min(1000, len(class0_idx)))
sampled_class1 = random.sample(class1_idx, min(1000, len(class1_idx)))

selected_indices = sampled_class0 + sampled_class1
random.shuffle(selected_indices)

subset_dataset = Subset(TensorDataset(X_torch, y_torch), selected_indices)
subset_loader = DataLoader(subset_dataset, batch_size=64, shuffle=False)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
vit = torch.hub.load('facebookresearch/dino:main', 'dino_vitb16')
vit.eval().to(device)

vit_feats, y_list = [], []

with torch.no_grad():
    for imgs, lbls in subset_loader:
        imgs = imgs.to(device)
        feats = vit(imgs)
        vit_feats.append(feats.cpu())
        y_list.extend(lbls.cpu().tolist())

F = torch.cat(vit_feats, dim=0).numpy().astype(np.float32)
y = np.array(y_list).astype(np.int64)

num_nodes, num_feats = F.shape
print(f"Extracted ViT-DINO Features: {F.shape}, Labels: {y.shape}")
# Out:
# Using cache found in /home/snu/.cache/torch/hub/facebookresearch_dino_main
# Extracted ViT-DINO Features: (780, 768), Labels: (780,)

# %%
# resnet = models.resnet18(pretrained=True)
# resnet.fc = nn.Identity()
# resnet = resnet.to(device)
# resnet.eval()

# resnet_feats = []
# y_list = []
# with torch.no_grad():
#     for imgs, labels in subset_loader:
#         imgs = imgs.to(device)
#         feats = resnet(imgs)
#         resnet_feats.append(feats.cpu())
#         y_list.extend(labels.cpu().tolist())

# features = torch.cat(resnet_feats, dim=0).numpy().astype(np.float32)  # shape (N, feat_dim)
# y_labels = np.array(y_list).astype(np.float32)
# print("Feature shape:", features.shape, "Label shape:", y_labels.shape)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as nnFn
from torch_geometric.nn import GATConv


class GAT_SemiSupervised(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, device, heads=2, activ="RELU", dropout=0.25):
        super(GAT_SemiSupervised, self).__init__()
        self.device = device

        # GAT layer
        self.conv1 = GATConv(input_dim, hidden_dim, heads=heads, concat=True, dropout=dropout)
        self.bn1 = nn.BatchNorm1d(hidden_dim * heads)  # heads multiply feature dimension if concat=True
        self.dropout = nn.Dropout(dropout)
        self.fc = nn.Linear(hidden_dim * heads, output_dim)
        self.num_clusters = output_dim

        # Activation mapping
        activations = {
            "SELU": nnFn.selu,
            "SiLU": nnFn.silu,
            "GELU": nnFn.gelu,
            "RELU": nnFn.relu,
            "ELU": nnFn.elu
        }
        self.act = activations.get(activ, nnFn.elu)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index

        # GAT layer
        x = self.conv1(x, edge_index)
        x = self.bn1(x)
        x = self.act(x)
        x = self.dropout(x)

        logits = self.fc(x)
        return logits

    def cut_loss(self, A, S):
        S = nnFn.softmax(S, dim=1)
        A_pool = torch.matmul(torch.matmul(A, S).t(), S)
        num = torch.trace(A_pool)

        D = torch.diag(torch.sum(A, dim=-1))
        D_pooled = torch.matmul(torch.matmul(D, S).t(), S)
        den = torch.trace(D_pooled)
        mincut_loss = -(num / den)

        St_S = torch.matmul(S.t(), S)
        I_S = torch.eye(self.num_clusters, device=self.device)
        ortho_loss = torch.norm(St_S / torch.norm(St_S) - I_S / torch.norm(I_S))

        return mincut_loss + ortho_loss

# %%
def create_adj(F, alpha=1):
    F_norm = F / np.linalg.norm(F, axis=1, keepdims=True)
    W = np.dot(F_norm, F_norm.T)
    W = np.where(W >= alpha, 1, 0).astype(np.float32)
    W = W / W.max()
    return W

def load_data(adj, node_feats):
    node_feats = torch.from_numpy(node_feats).float()
    edge_index = torch.from_numpy(np.array(np.nonzero((adj > 0))))
    return Data(x=node_feats, edge_index=edge_index)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
alpha = 0.73
feats_dim = num_feats
hidden_dim = 256
num_classes = 2
num_epochs = 2000
lr = 0.0001
weight_decay = 1e-4
batch_print_freq = 100
lambda_mod =  0.0001  #0.2 #0.001  # weight for modularity loss
# lambda_sup = 1.0

# %%
W = create_adj(F, alpha)
data = load_data(W, F).to(device)
print(data)
# Out:
# Data(x=[780, 768], edge_index=[2, 266936])

# %%
sss = StratifiedShuffleSplit(n_splits=20, test_size=0.9, random_state=42)

accuracies, precisions, recalls, f1_scores, aucs, ce_losses = [], [], [], [], [], []

A_tensor = torch.from_numpy(W).float().to(device)

for fold, (train_idx, test_idx) in enumerate(sss.split(F, y), start=1):
    print(f"\n=== Fold {fold} ===")

    train_idx_t = torch.from_numpy(train_idx).long().to(device)
    y_train_tensor = torch.from_numpy(y[train_idx]).long().to(device)

    model = GAT_SemiSupervised(feats_dim, hidden_dim, num_classes, device, activ="RELU").to(device)
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    ce_loss = nn.CrossEntropyLoss()

    # Training
    for epoch in range(1, num_epochs + 1):
        model.train()
        optimizer.zero_grad()

        logits = model(data)
        loss_sup = ce_loss(logits[train_idx_t], y_train_tensor)
        loss_unsup = model.cut_loss(A_tensor, logits)
        total_loss = loss_sup + lambda_mod * loss_unsup

        total_loss.backward()
        optimizer.step()

        if epoch % batch_print_freq == 0 or epoch == 1:
            model.eval()
            with torch.no_grad():
                preds_train = logits[train_idx_t].argmax(dim=1)
                acc_train = accuracy_score(y_train_tensor.cpu(), preds_train.cpu())
            print(f"Fold {fold} Epoch {epoch}: "
                  f"TotalLoss={total_loss.item():.6f} | Sup={loss_sup.item():.6f} | "
                  f"Unsup={loss_unsup.item():.6f} | TrainAcc={acc_train:.4f}")

    # Evaluation
    model.eval()
    with torch.no_grad():
        out = model(data)
        preds = out.argmax(dim=1).cpu().numpy()
        probs = torch.softmax(out, dim=1)[:, 1].cpu().numpy()  # Probability for class 1

    y_test = y[test_idx]
    y_pred_test = preds[test_idx]
    y_prob_test = probs[test_idx]

    acc = accuracy_score(y_test, y_pred_test)
    prec = precision_score(y_test, y_pred_test, zero_division=0)
    rec = recall_score(y_test, y_pred_test, zero_division=0)
    f1 = f1_score(y_test, y_pred_test, zero_division=0)
    auc = roc_auc_score(y_test, y_prob_test)
    ce = log_loss(y_test, y_prob_test)

    accuracies.append(acc)
    precisions.append(prec)
    recalls.append(rec)
    f1_scores.append(f1)
    aucs.append(auc)
    ce_losses.append(ce)

    print(f"Fold {fold} → "
          f"Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | "
          f"F1={f1:.4f} | AUC={auc:.4f} | CE Loss={ce:.4f}")


# Final summary
print("\n=== Average Results Across 20 Folds ===")
print(f"Accuracy:  {np.mean(accuracies):.4f} ± {np.std(accuracies):.4f}")
print(f"Precision: {np.mean(precisions):.4f} ± {np.std(precisions):.4f}")
print(f"Recall:    {np.mean(recalls):.4f} ± {np.std(recalls):.4f}")
print(f"F1-score:  {np.mean(f1_scores):.4f} ± {np.std(f1_scores):.4f}")
print(f"AUC:       {np.mean(aucs):.4f} ± {np.std(aucs):.4f}")
print(f"CE Loss:   {np.mean(ce_losses):.4f} ± {np.std(ce_losses):.4f}")
# Out:
# === Fold 1 ===
# Fold 1 Epoch 1: TotalLoss=0.641424 | Sup=0.641450 | Unsup=-0.256802 | TrainAcc=0.6538
# Fold 1 Epoch 100: TotalLoss=0.037173 | Sup=0.037201 | Unsup=-0.279457 | TrainAcc=1.0000
# Fold 1 Epoch 200: TotalLoss=0.008644 | Sup=0.008670 | Unsup=-0.257584 | TrainAcc=1.0000
# Fold 1 Epoch 300: TotalLoss=0.007991 | Sup=0.008017 | Unsup=-0.255765 | TrainAcc=1.0000
# Fold 1 Epoch 400: TotalLoss=0.001256 | Sup=0.001284 | Unsup=-0.277975 | TrainAcc=1.0000
# Fold 1 Epoch 500: TotalLoss=0.000854 | Sup=0.000882 | Unsup=-0.279189 | TrainAcc=1.0000
# Fold 1 Epoch 600: TotalLoss=0.000711 | Sup=0.000741 | Unsup=-0.300083 | TrainAcc=1.0000
# Fold 1 Epoch 700: TotalLoss=0.003352 | Sup=0.003376 | Unsup=-0.243851 | TrainAcc=1.0000
# Fold 1 Epoch 800: TotalLoss=0.001793 | Sup=0.001818 | Unsup=-0.250071 | TrainAcc=1.0000
# Fold 1 Epoch 900: TotalLoss=0.001220 | Sup=0.001244 | Unsup=-0.242290 | TrainAcc=1.0000
# Fold 1 Epoch 1000: TotalLoss=0.000844 | Sup=0.000868 | Unsup=-0.240737 | TrainAcc=1.0000
# Fold 1 Epoch 1100: TotalLoss=0.000936 | Sup=0.000960 | Unsup=-0.236464 | TrainAcc=1.0000
# Fold 1 Epoch 1200: TotalLoss=0.000538 | Sup=0.000562 | Unsup=-0.241944 | TrainAcc=1.0000
# Fold 1 Epoch 1300: TotalLoss=0.000421 | Sup=0.000446 | Unsup=-0.242929 | TrainAcc=1.0000
# Fold 1 Epoch 1400: TotalLoss=0.000922 | Sup=0.000946 | Unsup=-0.241541 | TrainAcc=1.0000
# Fold 1 Epoch 1500: TotalLoss=0.000253 | Sup=0.000278 | Unsup=-0.245769 | TrainAcc=1.0000
# Fold 1 Epoch 1600: TotalLoss=0.000272 | Sup=0.000296 | Unsup=-0.237615 | TrainAcc=1.0000
# Fold 1 Epoch 1700: TotalLoss=0.001286 | Sup=0.001310 | Unsup=-0.247155 | TrainAcc=1.0000
# Fold 1 Epoch 1800: TotalLoss=0.001112 | Sup=0.001136 | Unsup=-0.240566 | TrainAcc=1.0000
# Fold 1 Epoch 1900: TotalLoss=0.000497 | Sup=0.000521 | Unsup=-0.238739 | TrainAcc=1.0000
# Fold 1 Epoch 2000: TotalLoss=0.000247 | Sup=0.000271 | Unsup=-0.243030 | TrainAcc=1.0000
# Fold 1 → Acc=0.7279 | Prec=0.8426 | Rec=0.7719 | F1=0.8057 | AUC=0.7746 | CE Loss=1.1397
#
# === Fold 2 ===
# Fold 2 Epoch 1: TotalLoss=0.700800 | Sup=0.700827 | Unsup=-0.267111 | TrainAcc=0.5385
# Fold 2 Epoch 100: TotalLoss=0.023532 | Sup=0.023561 | Unsup=-0.296411 | TrainAcc=1.0000
# Fold 2 Epoch 200: TotalLoss=0.006633 | Sup=0.006665 | Unsup=-0.320296 | TrainAcc=1.0000
# Fold 2 Epoch 300: TotalLoss=0.004459 | Sup=0.004491 | Unsup=-0.324241 | TrainAcc=1.0000
# Fold 2 Epoch 400: TotalLoss=0.002991 | Sup=0.003026 | Unsup=-0.349185 | TrainAcc=1.0000
# Fold 2 Epoch 500: TotalLoss=0.001570 | Sup=0.001603 | Unsup=-0.335148 | TrainAcc=1.0000
# Fold 2 Epoch 600: TotalLoss=0.000998 | Sup=0.001033 | Unsup=-0.351597 | TrainAcc=1.0000
# Fold 2 Epoch 700: TotalLoss=0.001023 | Sup=0.001055 | Unsup=-0.324996 | TrainAcc=1.0000
# Fold 2 Epoch 800: TotalLoss=0.000590 | Sup=0.000624 | Unsup=-0.340798 | TrainAcc=1.0000
# Fold 2 Epoch 900: TotalLoss=0.000612 | Sup=0.000646 | Unsup=-0.340373 | TrainAcc=1.0000
# Fold 2 Epoch 1000: TotalLoss=0.000511 | Sup=0.000547 | Unsup=-0.356989 | TrainAcc=1.0000
# Fold 2 Epoch 1100: TotalLoss=0.000298 | Sup=0.000334 | Unsup=-0.354085 | TrainAcc=1.0000
# Fold 2 Epoch 1200: TotalLoss=0.000476 | Sup=0.000510 | Unsup=-0.340220 | TrainAcc=1.0000
# Fold 2 Epoch 1300: TotalLoss=0.000363 | Sup=0.000399 | Unsup=-0.356457 | TrainAcc=1.0000
# Fold 2 Epoch 1400: TotalLoss=0.000675 | Sup=0.000707 | Unsup=-0.328756 | TrainAcc=1.0000
# Fold 2 Epoch 1500: TotalLoss=0.000304 | Sup=0.000339 | Unsup=-0.356955 | TrainAcc=1.0000
# Fold 2 Epoch 1600: TotalLoss=0.000175 | Sup=0.000211 | Unsup=-0.359711 | TrainAcc=1.0000
# Fold 2 Epoch 1700: TotalLoss=0.000224 | Sup=0.000260 | Unsup=-0.357711 | TrainAcc=1.0000
# Fold 2 Epoch 1800: TotalLoss=0.000211 | Sup=0.000248 | Unsup=-0.370055 | TrainAcc=1.0000
# Fold 2 Epoch 1900: TotalLoss=0.000176 | Sup=0.000211 | Unsup=-0.355240 | TrainAcc=1.0000
# Fold 2 Epoch 2000: TotalLoss=0.000808 | Sup=0.000839 | Unsup=-0.309461 | TrainAcc=1.0000
# Fold 2 → Acc=0.7564 | Prec=0.8886 | Rec=0.7622 | F1=0.8206 | AUC=0.8553 | CE Loss=0.8127
#
# === Fold 3 ===
# Fold 3 Epoch 1: TotalLoss=0.677104 | Sup=0.677130 | Unsup=-0.250827 | TrainAcc=0.5769
# Fold 3 Epoch 100: TotalLoss=0.067737 | Sup=0.067774 | Unsup=-0.367487 | TrainAcc=1.0000
# Fold 3 Epoch 200: TotalLoss=0.014125 | Sup=0.014164 | Unsup=-0.395527 | TrainAcc=1.0000
# Fold 3 Epoch 300: TotalLoss=0.006597 | Sup=0.006638 | Unsup=-0.415627 | TrainAcc=1.0000
# Fold 3 Epoch 400: TotalLoss=0.002860 | Sup=0.002902 | Unsup=-0.422530 | TrainAcc=1.0000
# Fold 3 Epoch 500: TotalLoss=0.002047 | Sup=0.002089 | Unsup=-0.418606 | TrainAcc=1.0000
# Fold 3 Epoch 600: TotalLoss=0.001117 | Sup=0.001161 | Unsup=-0.430426 | TrainAcc=1.0000
# Fold 3 Epoch 700: TotalLoss=0.000908 | Sup=0.000952 | Unsup=-0.437253 | TrainAcc=1.0000
# Fold 3 Epoch 800: TotalLoss=0.000927 | Sup=0.000970 | Unsup=-0.434868 | TrainAcc=1.0000
# Fold 3 Epoch 900: TotalLoss=0.000508 | Sup=0.000550 | Unsup=-0.415115 | TrainAcc=1.0000
# Fold 3 Epoch 1000: TotalLoss=0.000372 | Sup=0.000415 | Unsup=-0.433632 | TrainAcc=1.0000
# Fold 3 Epoch 1100: TotalLoss=0.000350 | Sup=0.000394 | Unsup=-0.441913 | TrainAcc=1.0000
# Fold 3 Epoch 1200: TotalLoss=0.000283 | Sup=0.000328 | Unsup=-0.444963 | TrainAcc=1.0000
# Fold 3 Epoch 1300: TotalLoss=0.000275 | Sup=0.000319 | Unsup=-0.444270 | TrainAcc=1.0000
# Fold 3 Epoch 1400: TotalLoss=0.000195 | Sup=0.000241 | Unsup=-0.451666 | TrainAcc=1.0000
# Fold 3 Epoch 1500: TotalLoss=0.000204 | Sup=0.000249 | Unsup=-0.448972 | TrainAcc=1.0000
# Fold 3 Epoch 1600: TotalLoss=0.000203 | Sup=0.000247 | Unsup=-0.444197 | TrainAcc=1.0000
# Fold 3 Epoch 1700: TotalLoss=0.000206 | Sup=0.000250 | Unsup=-0.444689 | TrainAcc=1.0000
# Fold 3 Epoch 1800: TotalLoss=0.000135 | Sup=0.000180 | Unsup=-0.450674 | TrainAcc=1.0000
# Fold 3 Epoch 1900: TotalLoss=0.000116 | Sup=0.000161 | Unsup=-0.450752 | TrainAcc=1.0000
# Fold 3 Epoch 2000: TotalLoss=0.000109 | Sup=0.000155 | Unsup=-0.453727 | TrainAcc=1.0000
# Fold 3 → Acc=0.6880 | Prec=0.9016 | Rec=0.6433 | F1=0.7509 | AUC=0.8078 | CE Loss=1.4797
#
# === Fold 4 ===
# Fold 4 Epoch 1: TotalLoss=0.684733 | Sup=0.684759 | Unsup=-0.263808 | TrainAcc=0.6154
# Fold 4 Epoch 100: TotalLoss=0.037698 | Sup=0.037730 | Unsup=-0.319547 | TrainAcc=1.0000
# Fold 4 Epoch 200: TotalLoss=0.011088 | Sup=0.011123 | Unsup=-0.342529 | TrainAcc=1.0000
# Fold 4 Epoch 300: TotalLoss=0.005582 | Sup=0.005615 | Unsup=-0.332790 | TrainAcc=1.0000
# Fold 4 Epoch 400: TotalLoss=0.007560 | Sup=0.007592 | Unsup=-0.314400 | TrainAcc=1.0000
# Fold 4 Epoch 500: TotalLoss=0.004418 | Sup=0.004450 | Unsup=-0.321320 | TrainAcc=1.0000
# Fold 4 Epoch 600: TotalLoss=0.001635 | Sup=0.001668 | Unsup=-0.336059 | TrainAcc=1.0000
# Fold 4 Epoch 700: TotalLoss=0.005716 | Sup=0.005746 | Unsup=-0.300055 | TrainAcc=1.0000
# Fold 4 Epoch 800: TotalLoss=0.001401 | Sup=0.001431 | Unsup=-0.305098 | TrainAcc=1.0000
# Fold 4 Epoch 900: TotalLoss=0.000922 | Sup=0.000953 | Unsup=-0.309526 | TrainAcc=1.0000
# Fold 4 Epoch 1000: TotalLoss=0.000727 | Sup=0.000758 | Unsup=-0.304456 | TrainAcc=1.0000
# Fold 4 Epoch 1100: TotalLoss=0.000513 | Sup=0.000544 | Unsup=-0.311067 | TrainAcc=1.0000
# Fold 4 Epoch 1200: TotalLoss=0.063348 | Sup=0.063371 | Unsup=-0.229917 | TrainAcc=0.9872
# Fold 4 Epoch 1300: TotalLoss=0.028959 | Sup=0.028981 | Unsup=-0.216789 | TrainAcc=0.9872
# Fold 4 Epoch 1400: TotalLoss=0.023755 | Sup=0.023777 | Unsup=-0.217169 | TrainAcc=1.0000
# Fold 4 Epoch 1500: TotalLoss=0.010415 | Sup=0.010435 | Unsup=-0.199975 | TrainAcc=1.0000
# Fold 4 Epoch 1600: TotalLoss=0.033599 | Sup=0.033619 | Unsup=-0.204096 | TrainAcc=0.9872
# Fold 4 Epoch 1700: TotalLoss=0.010963 | Sup=0.010983 | Unsup=-0.197062 | TrainAcc=1.0000
# Fold 4 Epoch 1800: TotalLoss=0.008841 | Sup=0.008861 | Unsup=-0.202832 | TrainAcc=1.0000
# Fold 4 Epoch 1900: TotalLoss=0.005190 | Sup=0.005209 | Unsup=-0.191492 | TrainAcc=1.0000
# Fold 4 Epoch 2000: TotalLoss=0.002871 | Sup=0.002890 | Unsup=-0.194539 | TrainAcc=1.0000
# Fold 4 → Acc=0.7578 | Prec=0.8230 | Rec=0.8519 | F1=0.8372 | AUC=0.7621 | CE Loss=1.2662
#
# === Fold 5 ===
# Fold 5 Epoch 1: TotalLoss=0.701510 | Sup=0.701538 | Unsup=-0.274355 | TrainAcc=0.5385
# Fold 5 Epoch 100: TotalLoss=0.068044 | Sup=0.068071 | Unsup=-0.273705 | TrainAcc=0.9744
# Fold 5 Epoch 200: TotalLoss=0.042280 | Sup=0.042307 | Unsup=-0.274891 | TrainAcc=1.0000
# Fold 5 Epoch 300: TotalLoss=0.015041 | Sup=0.015067 | Unsup=-0.262381 | TrainAcc=1.0000
# Fold 5 Epoch 400: TotalLoss=0.022716 | Sup=0.022742 | Unsup=-0.253078 | TrainAcc=0.9872
# Fold 5 Epoch 500: TotalLoss=0.005120 | Sup=0.005146 | Unsup=-0.254002 | TrainAcc=1.0000
# Fold 5 Epoch 600: TotalLoss=0.004481 | Sup=0.004508 | Unsup=-0.268127 | TrainAcc=1.0000
# Fold 5 Epoch 700: TotalLoss=0.003700 | Sup=0.003726 | Unsup=-0.263749 | TrainAcc=1.0000
# Fold 5 Epoch 800: TotalLoss=0.005705 | Sup=0.005733 | Unsup=-0.284130 | TrainAcc=1.0000
# Fold 5 Epoch 900: TotalLoss=0.002963 | Sup=0.002991 | Unsup=-0.279266 | TrainAcc=1.0000
# Fold 5 Epoch 1000: TotalLoss=0.002103 | Sup=0.002131 | Unsup=-0.282815 | TrainAcc=1.0000
# Fold 5 Epoch 1100: TotalLoss=0.002450 | Sup=0.002479 | Unsup=-0.285788 | TrainAcc=1.0000
# Fold 5 Epoch 1200: TotalLoss=0.001254 | Sup=0.001283 | Unsup=-0.289550 | TrainAcc=1.0000
# Fold 5 Epoch 1300: TotalLoss=0.000996 | Sup=0.001025 | Unsup=-0.291223 | TrainAcc=1.0000
# Fold 5 Epoch 1400: TotalLoss=0.001005 | Sup=0.001034 | Unsup=-0.293561 | TrainAcc=1.0000
# Fold 5 Epoch 1500: TotalLoss=0.000637 | Sup=0.000667 | Unsup=-0.294181 | TrainAcc=1.0000
# Fold 5 Epoch 1600: TotalLoss=0.000271 | Sup=0.000301 | Unsup=-0.299112 | TrainAcc=1.0000
# Fold 5 Epoch 1700: TotalLoss=0.000631 | Sup=0.000662 | Unsup=-0.309271 | TrainAcc=1.0000
# Fold 5 Epoch 1800: TotalLoss=0.000587 | Sup=0.000616 | Unsup=-0.294999 | TrainAcc=1.0000
# Fold 5 Epoch 1900: TotalLoss=0.000471 | Sup=0.000501 | Unsup=-0.299164 | TrainAcc=1.0000
# Fold 5 Epoch 2000: TotalLoss=0.000439 | Sup=0.000469 | Unsup=-0.302001 | TrainAcc=1.0000
# Fold 5 → Acc=0.7934 | Prec=0.8866 | Rec=0.8226 | F1=0.8534 | AUC=0.8157 | CE Loss=0.8227
#
# === Fold 6 ===
# Fold 6 Epoch 1: TotalLoss=1.050081 | Sup=1.050108 | Unsup=-0.268012 | TrainAcc=0.3333
# Fold 6 Epoch 100: TotalLoss=0.185957 | Sup=0.185987 | Unsup=-0.298637 | TrainAcc=0.9615
# Fold 6 Epoch 200: TotalLoss=0.049058 | Sup=0.049087 | Unsup=-0.282131 | TrainAcc=0.9872
# Fold 6 Epoch 300: TotalLoss=0.034287 | Sup=0.034316 | Unsup=-0.290349 | TrainAcc=1.0000
# Fold 6 Epoch 400: TotalLoss=0.039606 | Sup=0.039635 | Unsup=-0.291423 | TrainAcc=1.0000
# Fold 6 Epoch 500: TotalLoss=0.020253 | Sup=0.020281 | Unsup=-0.284554 | TrainAcc=1.0000
# Fold 6 Epoch 600: TotalLoss=0.053569 | Sup=0.053598 | Unsup=-0.292797 | TrainAcc=0.9872
# Fold 6 Epoch 700: TotalLoss=0.012656 | Sup=0.012685 | Unsup=-0.291525 | TrainAcc=1.0000
# Fold 6 Epoch 800: TotalLoss=0.021612 | Sup=0.021642 | Unsup=-0.296115 | TrainAcc=0.9872
# Fold 6 Epoch 900: TotalLoss=0.014563 | Sup=0.014591 | Unsup=-0.277498 | TrainAcc=1.0000
# Fold 6 Epoch 1000: TotalLoss=0.008309 | Sup=0.008338 | Unsup=-0.297833 | TrainAcc=1.0000
# Fold 6 Epoch 1100: TotalLoss=0.020176 | Sup=0.020207 | Unsup=-0.305413 | TrainAcc=0.9872
# Fold 6 Epoch 1200: TotalLoss=0.014826 | Sup=0.014857 | Unsup=-0.314490 | TrainAcc=1.0000
# Fold 6 Epoch 1300: TotalLoss=0.002334 | Sup=0.002365 | Unsup=-0.310098 | TrainAcc=1.0000
# Fold 6 Epoch 1400: TotalLoss=0.001614 | Sup=0.001645 | Unsup=-0.310420 | TrainAcc=1.0000
# Fold 6 Epoch 1500: TotalLoss=0.002222 | Sup=0.002253 | Unsup=-0.316065 | TrainAcc=1.0000
# Fold 6 Epoch 1600: TotalLoss=0.001146 | Sup=0.001178 | Unsup=-0.322546 | TrainAcc=1.0000
# Fold 6 Epoch 1700: TotalLoss=0.000893 | Sup=0.000925 | Unsup=-0.320407 | TrainAcc=1.0000
# Fold 6 Epoch 1800: TotalLoss=0.000764 | Sup=0.000796 | Unsup=-0.313657 | TrainAcc=1.0000
# Fold 6 Epoch 1900: TotalLoss=0.000521 | Sup=0.000554 | Unsup=-0.324607 | TrainAcc=1.0000
# Fold 6 Epoch 2000: TotalLoss=0.000477 | Sup=0.000509 | Unsup=-0.318352 | TrainAcc=1.0000
# Fold 6 → Acc=0.7507 | Prec=0.8876 | Rec=0.7544 | F1=0.8156 | AUC=0.8189 | CE Loss=1.0944
#
# === Fold 7 ===
# Fold 7 Epoch 1: TotalLoss=0.752566 | Sup=0.752592 | Unsup=-0.261762 | TrainAcc=0.3974
# Fold 7 Epoch 100: TotalLoss=0.019912 | Sup=0.019946 | Unsup=-0.340627 | TrainAcc=1.0000
# Fold 7 Epoch 200: TotalLoss=0.007314 | Sup=0.007355 | Unsup=-0.403041 | TrainAcc=1.0000
# Fold 7 Epoch 300: TotalLoss=0.002381 | Sup=0.002416 | Unsup=-0.353487 | TrainAcc=1.0000
# Fold 7 Epoch 400: TotalLoss=0.002406 | Sup=0.002441 | Unsup=-0.354660 | TrainAcc=1.0000
# Fold 7 Epoch 500: TotalLoss=0.000882 | Sup=0.000918 | Unsup=-0.359948 | TrainAcc=1.0000
# Fold 7 Epoch 600: TotalLoss=0.000978 | Sup=0.001013 | Unsup=-0.356848 | TrainAcc=1.0000
# Fold 7 Epoch 700: TotalLoss=0.000477 | Sup=0.000513 | Unsup=-0.362004 | TrainAcc=1.0000
# Fold 7 Epoch 800: TotalLoss=0.000674 | Sup=0.000711 | Unsup=-0.369416 | TrainAcc=1.0000
# Fold 7 Epoch 900: TotalLoss=0.000374 | Sup=0.000410 | Unsup=-0.356593 | TrainAcc=1.0000
# Fold 7 Epoch 1000: TotalLoss=0.001216 | Sup=0.001251 | Unsup=-0.352737 | TrainAcc=1.0000
# Fold 7 Epoch 1100: TotalLoss=0.000332 | Sup=0.000366 | Unsup=-0.333282 | TrainAcc=1.0000
# Fold 7 Epoch 1200: TotalLoss=0.000241 | Sup=0.000276 | Unsup=-0.343742 | TrainAcc=1.0000
# Fold 7 Epoch 1300: TotalLoss=0.000221 | Sup=0.000255 | Unsup=-0.348461 | TrainAcc=1.0000
# Fold 7 Epoch 1400: TotalLoss=0.000235 | Sup=0.000269 | Unsup=-0.348454 | TrainAcc=1.0000
# Fold 7 Epoch 1500: TotalLoss=0.002469 | Sup=0.002494 | Unsup=-0.255225 | TrainAcc=1.0000
# Fold 7 Epoch 1600: TotalLoss=0.002950 | Sup=0.002976 | Unsup=-0.262027 | TrainAcc=1.0000
# Fold 7 Epoch 1700: TotalLoss=0.001393 | Sup=0.001416 | Unsup=-0.229104 | TrainAcc=1.0000
# Fold 7 Epoch 1800: TotalLoss=0.000828 | Sup=0.000851 | Unsup=-0.229491 | TrainAcc=1.0000
# Fold 7 Epoch 1900: TotalLoss=0.000861 | Sup=0.000885 | Unsup=-0.233257 | TrainAcc=1.0000
# Fold 7 Epoch 2000: TotalLoss=0.000723 | Sup=0.000746 | Unsup=-0.236107 | TrainAcc=1.0000
# Fold 7 → Acc=0.7806 | Prec=0.8294 | Rec=0.8811 | F1=0.8544 | AUC=0.7608 | CE Loss=1.0558
#
# === Fold 8 ===
# Fold 8 Epoch 1: TotalLoss=0.810708 | Sup=0.810734 | Unsup=-0.262458 | TrainAcc=0.3974
# Fold 8 Epoch 100: TotalLoss=0.111225 | Sup=0.111254 | Unsup=-0.285234 | TrainAcc=0.9744
# Fold 8 Epoch 200: TotalLoss=0.052555 | Sup=0.052584 | Unsup=-0.282353 | TrainAcc=0.9872
# Fold 8 Epoch 300: TotalLoss=0.034341 | Sup=0.034371 | Unsup=-0.301408 | TrainAcc=0.9872
# Fold 8 Epoch 400: TotalLoss=0.024699 | Sup=0.024730 | Unsup=-0.312509 | TrainAcc=0.9872
# Fold 8 Epoch 500: TotalLoss=0.024994 | Sup=0.025025 | Unsup=-0.307241 | TrainAcc=0.9872
# Fold 8 Epoch 600: TotalLoss=0.010084 | Sup=0.010117 | Unsup=-0.326034 | TrainAcc=1.0000
# Fold 8 Epoch 700: TotalLoss=0.010864 | Sup=0.010896 | Unsup=-0.324480 | TrainAcc=1.0000
# Fold 8 Epoch 800: TotalLoss=0.012988 | Sup=0.013021 | Unsup=-0.327125 | TrainAcc=1.0000
# Fold 8 Epoch 900: TotalLoss=0.006609 | Sup=0.006640 | Unsup=-0.318240 | TrainAcc=1.0000
# Fold 8 Epoch 1000: TotalLoss=0.005350 | Sup=0.005383 | Unsup=-0.333265 | TrainAcc=1.0000
# Fold 8 Epoch 1100: TotalLoss=0.004022 | Sup=0.004055 | Unsup=-0.332076 | TrainAcc=1.0000
# Fold 8 Epoch 1200: TotalLoss=0.004070 | Sup=0.004103 | Unsup=-0.335865 | TrainAcc=1.0000
# Fold 8 Epoch 1300: TotalLoss=0.008139 | Sup=0.008172 | Unsup=-0.335113 | TrainAcc=1.0000
# Fold 8 Epoch 1400: TotalLoss=0.007641 | Sup=0.007678 | Unsup=-0.361901 | TrainAcc=1.0000
# Fold 8 Epoch 1500: TotalLoss=0.002033 | Sup=0.002066 | Unsup=-0.326050 | TrainAcc=1.0000
# Fold 8 Epoch 1600: TotalLoss=0.001396 | Sup=0.001431 | Unsup=-0.356371 | TrainAcc=1.0000
# Fold 8 Epoch 1700: TotalLoss=0.002288 | Sup=0.002323 | Unsup=-0.357312 | TrainAcc=1.0000
# Fold 8 Epoch 1800: TotalLoss=0.000731 | Sup=0.000768 | Unsup=-0.370501 | TrainAcc=1.0000
# Fold 8 Epoch 1900: TotalLoss=0.000402 | Sup=0.000440 | Unsup=-0.377504 | TrainAcc=1.0000
# Fold 8 Epoch 2000: TotalLoss=0.000498 | Sup=0.000535 | Unsup=-0.369384 | TrainAcc=1.0000
# Fold 8 → Acc=0.7123 | Prec=0.8747 | Rec=0.7076 | F1=0.7823 | AUC=0.7830 | CE Loss=1.2866
#
# === Fold 9 ===
# Fold 9 Epoch 1: TotalLoss=0.755442 | Sup=0.755468 | Unsup=-0.267191 | TrainAcc=0.4487
# Fold 9 Epoch 100: TotalLoss=0.119464 | Sup=0.119492 | Unsup=-0.278221 | TrainAcc=0.9744
# Fold 9 Epoch 200: TotalLoss=0.014154 | Sup=0.014186 | Unsup=-0.316779 | TrainAcc=1.0000
# Fold 9 Epoch 300: TotalLoss=0.004962 | Sup=0.004995 | Unsup=-0.332921 | TrainAcc=1.0000
# Fold 9 Epoch 400: TotalLoss=0.003046 | Sup=0.003081 | Unsup=-0.354480 | TrainAcc=1.0000
# Fold 9 Epoch 500: TotalLoss=0.002334 | Sup=0.002372 | Unsup=-0.377349 | TrainAcc=1.0000
# Fold 9 Epoch 600: TotalLoss=0.001986 | Sup=0.002021 | Unsup=-0.351274 | TrainAcc=1.0000
# Fold 9 Epoch 700: TotalLoss=0.001432 | Sup=0.001470 | Unsup=-0.375005 | TrainAcc=1.0000
# Fold 9 Epoch 800: TotalLoss=0.001444 | Sup=0.001482 | Unsup=-0.374718 | TrainAcc=1.0000
# Fold 9 Epoch 900: TotalLoss=0.000621 | Sup=0.000659 | Unsup=-0.382533 | TrainAcc=1.0000
# Fold 9 Epoch 1000: TotalLoss=0.000932 | Sup=0.000972 | Unsup=-0.397248 | TrainAcc=1.0000
# Fold 9 Epoch 1100: TotalLoss=0.000654 | Sup=0.000692 | Unsup=-0.384278 | TrainAcc=1.0000
# Fold 9 Epoch 1200: TotalLoss=0.000513 | Sup=0.000553 | Unsup=-0.395008 | TrainAcc=1.0000
# Fold 9 Epoch 1300: TotalLoss=0.000433 | Sup=0.000473 | Unsup=-0.398864 | TrainAcc=1.0000
# Fold 9 Epoch 1400: TotalLoss=0.000490 | Sup=0.000530 | Unsup=-0.400146 | TrainAcc=1.0000
# Fold 9 Epoch 1500: TotalLoss=0.000304 | Sup=0.000344 | Unsup=-0.401764 | TrainAcc=1.0000
# Fold 9 Epoch 1600: TotalLoss=0.000350 | Sup=0.000390 | Unsup=-0.402852 | TrainAcc=1.0000
# Fold 9 Epoch 1700: TotalLoss=0.000211 | Sup=0.000251 | Unsup=-0.394363 | TrainAcc=1.0000
# Fold 9 Epoch 1800: TotalLoss=0.000301 | Sup=0.000342 | Unsup=-0.412641 | TrainAcc=1.0000
# Fold 9 Epoch 1900: TotalLoss=0.000187 | Sup=0.000229 | Unsup=-0.425781 | TrainAcc=1.0000
# Fold 9 Epoch 2000: TotalLoss=0.000123 | Sup=0.000165 | Unsup=-0.418500 | TrainAcc=1.0000
# Fold 9 → Acc=0.7194 | Prec=0.9136 | Rec=0.6803 | F1=0.7799 | AUC=0.8328 | CE Loss=1.0474
#
# === Fold 10 ===
# Fold 10 Epoch 1: TotalLoss=0.751924 | Sup=0.751951 | Unsup=-0.273260 | TrainAcc=0.4615
# Fold 10 Epoch 100: TotalLoss=0.041015 | Sup=0.041053 | Unsup=-0.380467 | TrainAcc=1.0000
# Fold 10 Epoch 200: TotalLoss=0.019842 | Sup=0.019884 | Unsup=-0.427107 | TrainAcc=1.0000
# Fold 10 Epoch 300: TotalLoss=0.012885 | Sup=0.012931 | Unsup=-0.466608 | TrainAcc=1.0000
# Fold 10 Epoch 400: TotalLoss=0.006709 | Sup=0.006758 | Unsup=-0.491107 | TrainAcc=1.0000
# Fold 10 Epoch 500: TotalLoss=0.002971 | Sup=0.003020 | Unsup=-0.489587 | TrainAcc=1.0000
# Fold 10 Epoch 600: TotalLoss=0.002835 | Sup=0.002885 | Unsup=-0.502746 | TrainAcc=1.0000
# Fold 10 Epoch 700: TotalLoss=0.001177 | Sup=0.001226 | Unsup=-0.487359 | TrainAcc=1.0000
# Fold 10 Epoch 800: TotalLoss=0.001060 | Sup=0.001109 | Unsup=-0.493818 | TrainAcc=1.0000
# Fold 10 Epoch 900: TotalLoss=0.000872 | Sup=0.000921 | Unsup=-0.485373 | TrainAcc=1.0000
# Fold 10 Epoch 1000: TotalLoss=0.000631 | Sup=0.000680 | Unsup=-0.496262 | TrainAcc=1.0000
# Fold 10 Epoch 1100: TotalLoss=0.001090 | Sup=0.001140 | Unsup=-0.494742 | TrainAcc=1.0000
# Fold 10 Epoch 1200: TotalLoss=0.000675 | Sup=0.000724 | Unsup=-0.494042 | TrainAcc=1.0000
# Fold 10 Epoch 1300: TotalLoss=0.000993 | Sup=0.001042 | Unsup=-0.491386 | TrainAcc=1.0000
# Fold 10 Epoch 1400: TotalLoss=0.000572 | Sup=0.000621 | Unsup=-0.488486 | TrainAcc=1.0000
# Fold 10 Epoch 1500: TotalLoss=0.000477 | Sup=0.000527 | Unsup=-0.496569 | TrainAcc=1.0000
# Fold 10 Epoch 1600: TotalLoss=0.000238 | Sup=0.000286 | Unsup=-0.482270 | TrainAcc=1.0000
# Fold 10 Epoch 1700: TotalLoss=0.000245 | Sup=0.000294 | Unsup=-0.496372 | TrainAcc=1.0000
# Fold 10 Epoch 1800: TotalLoss=0.000172 | Sup=0.000220 | Unsup=-0.481114 | TrainAcc=1.0000
# Fold 10 Epoch 1900: TotalLoss=0.000181 | Sup=0.000230 | Unsup=-0.494462 | TrainAcc=1.0000
# Fold 10 Epoch 2000: TotalLoss=0.000834 | Sup=0.000880 | Unsup=-0.464614 | TrainAcc=1.0000
# Fold 10 → Acc=0.4487 | Prec=0.9922 | Rec=0.2476 | F1=0.3963 | AUC=0.8343 | CE Loss=3.2074
#
# === Fold 11 ===
# Fold 11 Epoch 1: TotalLoss=0.768803 | Sup=0.768829 | Unsup=-0.257233 | TrainAcc=0.5385
# Fold 11 Epoch 100: TotalLoss=0.109027 | Sup=0.109060 | Unsup=-0.324770 | TrainAcc=0.9359
# Fold 11 Epoch 200: TotalLoss=0.027045 | Sup=0.027077 | Unsup=-0.316974 | TrainAcc=1.0000
# Fold 11 Epoch 300: TotalLoss=0.013805 | Sup=0.013837 | Unsup=-0.321513 | TrainAcc=1.0000
# Fold 11 Epoch 400: TotalLoss=0.003759 | Sup=0.003793 | Unsup=-0.339610 | TrainAcc=1.0000
# Fold 11 Epoch 500: TotalLoss=0.001984 | Sup=0.002018 | Unsup=-0.338214 | TrainAcc=1.0000
# Fold 11 Epoch 600: TotalLoss=0.002373 | Sup=0.002409 | Unsup=-0.363335 | TrainAcc=1.0000
# Fold 11 Epoch 700: TotalLoss=0.001563 | Sup=0.001597 | Unsup=-0.341247 | TrainAcc=1.0000
# Fold 11 Epoch 800: TotalLoss=0.000674 | Sup=0.000711 | Unsup=-0.368205 | TrainAcc=1.0000
# Fold 11 Epoch 900: TotalLoss=0.000526 | Sup=0.000562 | Unsup=-0.364096 | TrainAcc=1.0000
# Fold 11 Epoch 1000: TotalLoss=0.001044 | Sup=0.001080 | Unsup=-0.366910 | TrainAcc=1.0000
# Fold 11 Epoch 1100: TotalLoss=0.000399 | Sup=0.000436 | Unsup=-0.369592 | TrainAcc=1.0000
# Fold 11 Epoch 1200: TotalLoss=0.000313 | Sup=0.000349 | Unsup=-0.365019 | TrainAcc=1.0000
# Fold 11 Epoch 1300: TotalLoss=0.000241 | Sup=0.000276 | Unsup=-0.354371 | TrainAcc=1.0000
# Fold 11 Epoch 1400: TotalLoss=0.000239 | Sup=0.000275 | Unsup=-0.361247 | TrainAcc=1.0000
# Fold 11 Epoch 1500: TotalLoss=0.000225 | Sup=0.000263 | Unsup=-0.372565 | TrainAcc=1.0000
# Fold 11 Epoch 1600: TotalLoss=0.000205 | Sup=0.000243 | Unsup=-0.376493 | TrainAcc=1.0000
# Fold 11 Epoch 1700: TotalLoss=0.000160 | Sup=0.000198 | Unsup=-0.383953 | TrainAcc=1.0000
# Fold 11 Epoch 1800: TotalLoss=0.000166 | Sup=0.000204 | Unsup=-0.379249 | TrainAcc=1.0000
# Fold 11 Epoch 1900: TotalLoss=0.000142 | Sup=0.000181 | Unsup=-0.389891 | TrainAcc=1.0000
# Fold 11 Epoch 2000: TotalLoss=0.000166 | Sup=0.000203 | Unsup=-0.370127 | TrainAcc=1.0000
# Fold 11 → Acc=0.7536 | Prec=0.9048 | Rec=0.7407 | F1=0.8146 | AUC=0.8321 | CE Loss=1.2445
#
# === Fold 12 ===
# Fold 12 Epoch 1: TotalLoss=0.629982 | Sup=0.630008 | Unsup=-0.257293 | TrainAcc=0.6410
# Fold 12 Epoch 100: TotalLoss=0.029516 | Sup=0.029546 | Unsup=-0.302749 | TrainAcc=0.9872
# Fold 12 Epoch 200: TotalLoss=0.011475 | Sup=0.011505 | Unsup=-0.300722 | TrainAcc=1.0000
# Fold 12 Epoch 300: TotalLoss=0.005030 | Sup=0.005062 | Unsup=-0.311833 | TrainAcc=1.0000
# Fold 12 Epoch 400: TotalLoss=0.003331 | Sup=0.003362 | Unsup=-0.316648 | TrainAcc=1.0000
# Fold 12 Epoch 500: TotalLoss=0.002164 | Sup=0.002196 | Unsup=-0.322524 | TrainAcc=1.0000
# Fold 12 Epoch 600: TotalLoss=0.001539 | Sup=0.001572 | Unsup=-0.328634 | TrainAcc=1.0000
# Fold 12 Epoch 700: TotalLoss=0.001551 | Sup=0.001584 | Unsup=-0.328308 | TrainAcc=1.0000
# Fold 12 Epoch 800: TotalLoss=0.001607 | Sup=0.001639 | Unsup=-0.319244 | TrainAcc=1.0000
# Fold 12 Epoch 900: TotalLoss=0.000898 | Sup=0.000930 | Unsup=-0.328606 | TrainAcc=1.0000
# Fold 12 Epoch 1000: TotalLoss=0.000849 | Sup=0.000881 | Unsup=-0.323568 | TrainAcc=1.0000
# Fold 12 Epoch 1100: TotalLoss=0.000740 | Sup=0.000774 | Unsup=-0.335042 | TrainAcc=1.0000
# Fold 12 Epoch 1200: TotalLoss=0.000473 | Sup=0.000506 | Unsup=-0.331926 | TrainAcc=1.0000
# Fold 12 Epoch 1300: TotalLoss=0.000519 | Sup=0.000553 | Unsup=-0.340919 | TrainAcc=1.0000
# Fold 12 Epoch 1400: TotalLoss=0.000307 | Sup=0.000340 | Unsup=-0.330834 | TrainAcc=1.0000
# Fold 12 Epoch 1500: TotalLoss=0.054668 | Sup=0.054699 | Unsup=-0.311058 | TrainAcc=0.9872
# Fold 12 Epoch 1600: TotalLoss=0.039079 | Sup=0.039105 | Unsup=-0.263184 | TrainAcc=0.9872
# Fold 12 Epoch 1700: TotalLoss=0.023305 | Sup=0.023333 | Unsup=-0.273895 | TrainAcc=0.9872
# Fold 12 Epoch 1800: TotalLoss=0.013672 | Sup=0.013697 | Unsup=-0.255333 | TrainAcc=1.0000
# Fold 12 Epoch 1900: TotalLoss=0.007920 | Sup=0.007946 | Unsup=-0.256462 | TrainAcc=1.0000
# Fold 12 Epoch 2000: TotalLoss=0.003592 | Sup=0.003616 | Unsup=-0.244067 | TrainAcc=1.0000
# Fold 12 → Acc=0.7322 | Prec=0.8603 | Rec=0.7563 | F1=0.8050 | AUC=0.7793 | CE Loss=0.9432
#
# === Fold 13 ===
# Fold 13 Epoch 1: TotalLoss=0.644415 | Sup=0.644442 | Unsup=-0.268350 | TrainAcc=0.6795
# Fold 13 Epoch 100: TotalLoss=0.145685 | Sup=0.145711 | Unsup=-0.252261 | TrainAcc=0.9487
# Fold 13 Epoch 200: TotalLoss=0.055833 | Sup=0.055859 | Unsup=-0.256590 | TrainAcc=0.9872
# Fold 13 Epoch 300: TotalLoss=0.069599 | Sup=0.069623 | Unsup=-0.243502 | TrainAcc=0.9744
# Fold 13 Epoch 400: TotalLoss=0.058666 | Sup=0.058691 | Unsup=-0.242020 | TrainAcc=0.9744
# Fold 13 Epoch 500: TotalLoss=0.055145 | Sup=0.055170 | Unsup=-0.253174 | TrainAcc=0.9615
# Fold 13 Epoch 600: TotalLoss=0.013329 | Sup=0.013353 | Unsup=-0.247055 | TrainAcc=1.0000
# Fold 13 Epoch 700: TotalLoss=0.025408 | Sup=0.025432 | Unsup=-0.243166 | TrainAcc=0.9872
# Fold 13 Epoch 800: TotalLoss=0.033478 | Sup=0.033503 | Unsup=-0.255869 | TrainAcc=0.9872
# Fold 13 Epoch 900: TotalLoss=0.030022 | Sup=0.030047 | Unsup=-0.250154 | TrainAcc=0.9872
# Fold 13 Epoch 1000: TotalLoss=0.018407 | Sup=0.018431 | Unsup=-0.238571 | TrainAcc=0.9872
# Fold 13 Epoch 1100: TotalLoss=0.038904 | Sup=0.038929 | Unsup=-0.247978 | TrainAcc=0.9872
# Fold 13 Epoch 1200: TotalLoss=0.041110 | Sup=0.041134 | Unsup=-0.239475 | TrainAcc=0.9872
# Fold 13 Epoch 1300: TotalLoss=0.015385 | Sup=0.015409 | Unsup=-0.247883 | TrainAcc=1.0000
# Fold 13 Epoch 1400: TotalLoss=0.020101 | Sup=0.020125 | Unsup=-0.238713 | TrainAcc=0.9872
# Fold 13 Epoch 1500: TotalLoss=0.018316 | Sup=0.018341 | Unsup=-0.248770 | TrainAcc=0.9872
# Fold 13 Epoch 1600: TotalLoss=0.008617 | Sup=0.008641 | Unsup=-0.247615 | TrainAcc=1.0000
# Fold 13 Epoch 1700: TotalLoss=0.013761 | Sup=0.013786 | Unsup=-0.249697 | TrainAcc=1.0000
# Fold 13 Epoch 1800: TotalLoss=0.030372 | Sup=0.030397 | Unsup=-0.243785 | TrainAcc=0.9744
# Fold 13 Epoch 1900: TotalLoss=0.001872 | Sup=0.001897 | Unsup=-0.245535 | TrainAcc=1.0000
# Fold 13 Epoch 2000: TotalLoss=0.008746 | Sup=0.008772 | Unsup=-0.265004 | TrainAcc=1.0000
# Fold 13 → Acc=0.7607 | Prec=0.8402 | Rec=0.8304 | F1=0.8353 | AUC=0.7883 | CE Loss=1.3552
#
# === Fold 14 ===
# Fold 14 Epoch 1: TotalLoss=0.726240 | Sup=0.726265 | Unsup=-0.258357 | TrainAcc=0.7051
# Fold 14 Epoch 100: TotalLoss=0.043751 | Sup=0.043780 | Unsup=-0.292552 | TrainAcc=1.0000
# Fold 14 Epoch 200: TotalLoss=0.011577 | Sup=0.011610 | Unsup=-0.329026 | TrainAcc=1.0000
# Fold 14 Epoch 300: TotalLoss=0.006507 | Sup=0.006538 | Unsup=-0.308666 | TrainAcc=1.0000
# Fold 14 Epoch 400: TotalLoss=0.001372 | Sup=0.001403 | Unsup=-0.309726 | TrainAcc=1.0000
# Fold 14 Epoch 500: TotalLoss=0.000847 | Sup=0.000878 | Unsup=-0.310111 | TrainAcc=1.0000
# Fold 14 Epoch 600: TotalLoss=0.000670 | Sup=0.000701 | Unsup=-0.314651 | TrainAcc=1.0000
# Fold 14 Epoch 700: TotalLoss=0.000424 | Sup=0.000455 | Unsup=-0.309449 | TrainAcc=1.0000
# Fold 14 Epoch 800: TotalLoss=0.000343 | Sup=0.000374 | Unsup=-0.307126 | TrainAcc=1.0000
# Fold 14 Epoch 900: TotalLoss=0.000263 | Sup=0.000294 | Unsup=-0.311873 | TrainAcc=1.0000
# Fold 14 Epoch 1000: TotalLoss=0.000140 | Sup=0.000172 | Unsup=-0.314912 | TrainAcc=1.0000
# Fold 14 Epoch 1100: TotalLoss=0.001973 | Sup=0.001998 | Unsup=-0.243665 | TrainAcc=1.0000
# Fold 14 Epoch 1200: TotalLoss=0.000301 | Sup=0.000329 | Unsup=-0.281073 | TrainAcc=1.0000
# Fold 14 Epoch 1300: TotalLoss=0.000284 | Sup=0.000312 | Unsup=-0.284776 | TrainAcc=1.0000
# Fold 14 Epoch 1400: TotalLoss=0.000288 | Sup=0.000317 | Unsup=-0.283398 | TrainAcc=1.0000
# Fold 14 Epoch 1500: TotalLoss=0.013376 | Sup=0.013406 | Unsup=-0.293412 | TrainAcc=1.0000
# Fold 14 Epoch 1600: TotalLoss=0.002802 | Sup=0.002826 | Unsup=-0.241428 | TrainAcc=1.0000
# Fold 14 Epoch 1700: TotalLoss=0.001111 | Sup=0.001136 | Unsup=-0.256627 | TrainAcc=1.0000
# Fold 14 Epoch 1800: TotalLoss=0.000110 | Sup=0.000140 | Unsup=-0.301581 | TrainAcc=1.0000
# Fold 14 Epoch 1900: TotalLoss=0.000034 | Sup=0.000064 | Unsup=-0.300364 | TrainAcc=1.0000
# Fold 14 Epoch 2000: TotalLoss=0.000057 | Sup=0.000088 | Unsup=-0.306109 | TrainAcc=1.0000
# Fold 14 → Acc=0.7635 | Prec=0.8970 | Rec=0.7641 | F1=0.8253 | AUC=0.8294 | CE Loss=0.9506
#
# === Fold 15 ===
# Fold 15 Epoch 1: TotalLoss=0.726405 | Sup=0.726430 | Unsup=-0.252685 | TrainAcc=0.4359
# Fold 15 Epoch 100: TotalLoss=0.035627 | Sup=0.035667 | Unsup=-0.395584 | TrainAcc=1.0000
# Fold 15 Epoch 200: TotalLoss=0.011101 | Sup=0.011140 | Unsup=-0.395273 | TrainAcc=1.0000
# Fold 15 Epoch 300: TotalLoss=0.003321 | Sup=0.003362 | Unsup=-0.414734 | TrainAcc=1.0000
# Fold 15 Epoch 400: TotalLoss=0.002883 | Sup=0.002923 | Unsup=-0.398925 | TrainAcc=1.0000
# Fold 15 Epoch 500: TotalLoss=0.001950 | Sup=0.001991 | Unsup=-0.416740 | TrainAcc=1.0000
# Fold 15 Epoch 600: TotalLoss=0.001048 | Sup=0.001089 | Unsup=-0.411645 | TrainAcc=1.0000
# Fold 15 Epoch 700: TotalLoss=0.000995 | Sup=0.001038 | Unsup=-0.421572 | TrainAcc=1.0000
# Fold 15 Epoch 800: TotalLoss=0.000535 | Sup=0.000577 | Unsup=-0.422454 | TrainAcc=1.0000
# Fold 15 Epoch 900: TotalLoss=0.000548 | Sup=0.000591 | Unsup=-0.425665 | TrainAcc=1.0000
# Fold 15 Epoch 1000: TotalLoss=0.000435 | Sup=0.000477 | Unsup=-0.423299 | TrainAcc=1.0000
# Fold 15 Epoch 1100: TotalLoss=0.000488 | Sup=0.000530 | Unsup=-0.421084 | TrainAcc=1.0000
# Fold 15 Epoch 1200: TotalLoss=0.000410 | Sup=0.000453 | Unsup=-0.425496 | TrainAcc=1.0000
# Fold 15 Epoch 1300: TotalLoss=0.000301 | Sup=0.000343 | Unsup=-0.425311 | TrainAcc=1.0000
# Fold 15 Epoch 1400: TotalLoss=0.000298 | Sup=0.000341 | Unsup=-0.425656 | TrainAcc=1.0000
# Fold 15 Epoch 1500: TotalLoss=0.000234 | Sup=0.000277 | Unsup=-0.425481 | TrainAcc=1.0000
# Fold 15 Epoch 1600: TotalLoss=0.000220 | Sup=0.000262 | Unsup=-0.417195 | TrainAcc=1.0000
# Fold 15 Epoch 1700: TotalLoss=0.000145 | Sup=0.000188 | Unsup=-0.428701 | TrainAcc=1.0000
# Fold 15 Epoch 1800: TotalLoss=0.000125 | Sup=0.000167 | Unsup=-0.422610 | TrainAcc=1.0000
# Fold 15 Epoch 1900: TotalLoss=0.000139 | Sup=0.000182 | Unsup=-0.423930 | TrainAcc=1.0000
