# %%
# !pip install -q torch_geometric
# !pip install -q class_resolver
# !pip3 install pymatting

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import torch
import torch.nn as nn
import torch.nn.functional as nnFn
import torch.optim as optim
import numpy as np
import random
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from torch_geometric.data import Data
from torch_geometric.nn import ARMAConv
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, roc_auc_score, log_loss
)
from torch.utils.data import TensorDataset, DataLoader, Subset
from torch_geometric.data import Data
from torch_geometric.nn import ARMAConv
from torch.utils.data import TensorDataset, DataLoader, Subset
from torchvision import models

# %%
import torch
print("CUDA available:", torch.cuda.is_available())
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("GPU Name:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU")
# Out:
# CUDA available: True
# GPU Name: NVIDIA RTX A4000

# %%
data = np.load('/home/snu/Downloads/breastmnist_224.npz', allow_pickle=True)
all_images = np.concatenate([data['train_images'], data['val_images'], data['test_images']], axis=0)
all_labels = np.concatenate([data['train_labels'], data['val_labels'], data['test_labels']], axis=0).squeeze()

# Convert to 3-channel RGB
images = all_images.astype(np.float32) / 255.0
images = np.repeat(images[:, None, :, :], 3, axis=1)  # (N, 3, 224, 224)
X_torch = torch.tensor(images)
y_torch = torch.tensor(all_labels).long()
print(f"Raw images: {X_torch.shape}, Labels: {y_torch.shape}")
# Out:
# Raw images: torch.Size([780, 3, 224, 224]), Labels: torch.Size([780])

# %%
class0_idx = [i for i in range(len(y_torch)) if y_torch[i] == 0]
class1_idx = [i for i in range(len(y_torch)) if y_torch[i] == 1]

random.seed(42)
sampled_class0 = random.sample(class0_idx, min(1000, len(class0_idx)))
sampled_class1 = random.sample(class1_idx, min(1000, len(class1_idx)))

selected_indices = sampled_class0 + sampled_class1
random.shuffle(selected_indices)

subset_dataset = Subset(TensorDataset(X_torch, y_torch), selected_indices)
subset_loader = DataLoader(subset_dataset, batch_size=64, shuffle=False)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
vit = torch.hub.load('facebookresearch/dino:main', 'dino_vitb16')
vit.eval().to(device)

vit_feats, y_list = [], []

with torch.no_grad():
    for imgs, lbls in subset_loader:
        imgs = imgs.to(device)
        feats = vit(imgs)
        vit_feats.append(feats.cpu())
        y_list.extend(lbls.cpu().tolist())

F = torch.cat(vit_feats, dim=0).numpy().astype(np.float32)
y = np.array(y_list).astype(np.int64)

num_nodes, num_feats = F.shape
print(f"Extracted ViT-DINO Features: {F.shape}, Labels: {y.shape}")
# Out:
# Using cache found in /home/snu/.cache/torch/hub/facebookresearch_dino_main
# Extracted ViT-DINO Features: (780, 768), Labels: (780,)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as nnFn
from torch_geometric.nn import ARMAConv

class ARMA_SemiSupervised(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, device, num_stacks=1, num_layers=1):
        super(ARMA_SemiSupervised, self).__init__()
        self.device = device

        self.conv1 = ARMAConv(input_dim, hidden_dim, num_stacks=num_stacks, num_layers=num_layers,
                              shared_weights=True, dropout=0.3)
        self.conv2 = ARMAConv(hidden_dim, hidden_dim, num_stacks=num_stacks, num_layers=num_layers,
                              shared_weights=True, dropout=0.3)
        self.conv3 = ARMAConv(hidden_dim, hidden_dim, num_stacks=num_stacks, num_layers=num_layers,
                              shared_weights=True, dropout=0.3)

        self.dropout = nn.Dropout(0.25)
        self.fc = nn.Linear(hidden_dim, output_dim)
        self.num_clusters = output_dim

        activations = {
            "SELU": nnFn.selu,
            "SiLU": nnFn.silu,
            "GELU": nnFn.gelu,
            "RELU": nnFn.relu,
            "ELU": nnFn.elu,
            "PReLU": nnFn.prelu,
            "LeakyReLU": nnFn.leaky_relu
        }
        self.act = activations.get("RELU", nnFn.relu)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index

        # --- Layer 1 ---
        x = self.conv1(x, edge_index)
        x = self.act(x)

        x = self.dropout(x)

        # --- Layer 2 ---
        x = self.conv2(x, edge_index)
        x = self.act(x)
        x = self.dropout(x)

        # --- Layer 3 ---
        x = self.conv3(x, edge_index)
        x = self.act(x)
        x = self.dropout(x)

        logits = self.fc(x)
        return logits

    def cut_loss(self, A, S):
        S = nnFn.softmax(S, dim=1)
        A_pool = torch.matmul(torch.matmul(A, S).t(), S)
        num = torch.trace(A_pool)

        D = torch.diag(torch.sum(A, dim=-1))
        D_pooled = torch.matmul(torch.matmul(D, S).t(), S)
        den = torch.trace(D_pooled)
        mincut_loss = -(num / den)

        St_S = torch.matmul(S.t(), S)
        I_S = torch.eye(self.num_clusters, device=self.device)
        ortho_loss = torch.norm(St_S / torch.norm(St_S) - I_S / torch.norm(I_S))

        return mincut_loss + ortho_loss

# %%
def create_adj(F, alpha=1):
    F_norm = F / np.linalg.norm(F, axis=1, keepdims=True)
    W = np.dot(F_norm, F_norm.T)
    W = np.where(W >= alpha, 1, 0).astype(np.float32)
    W = W / W.max()
    return W

def load_data(adj, node_feats):
    node_feats = torch.from_numpy(node_feats).float()
    edge_index = torch.from_numpy(np.array(np.nonzero((adj > 0))))
    return Data(x=node_feats, edge_index=edge_index)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
alpha = 0.73
feats_dim = num_feats
hidden_dim = 256
num_classes = 2
num_epochs = 2000
lr = 0.0001
weight_decay = 1e-4
batch_print_freq = 100
lambda_mod =  0.001  #0.2 #0.001  # weight for modularity loss
# lambda_sup = 1.0

# %%
W = create_adj(F, alpha)
data = load_data(W, F).to(device)
print(data)
# Out:
# Data(x=[780, 768], edge_index=[2, 266936])

# %%
sss = StratifiedShuffleSplit(n_splits=20, test_size=0.9, random_state=42)

accuracies, precisions, recalls, f1_scores, aucs, ce_losses = [], [], [], [], [], []

A_tensor = torch.from_numpy(W).float().to(device)

for fold, (train_idx, test_idx) in enumerate(sss.split(F, y), start=1):
    print(f"\n=== Fold {fold} ===")

    train_idx_t = torch.from_numpy(train_idx).long().to(device)
    y_train_tensor = torch.from_numpy(y[train_idx]).long().to(device)

    model = ARMA_SemiSupervised(feats_dim, hidden_dim, num_classes, device).to(device)
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    ce_loss = nn.CrossEntropyLoss()

    # Training
    for epoch in range(1, num_epochs + 1):
        model.train()
        optimizer.zero_grad()

        logits = model(data)
        loss_sup = ce_loss(logits[train_idx_t], y_train_tensor)
        loss_unsup = model.cut_loss(A_tensor, logits)
        total_loss = loss_sup + lambda_mod * loss_unsup

        total_loss.backward()
        optimizer.step()

        if epoch % batch_print_freq == 0 or epoch == 1:
            model.eval()
            with torch.no_grad():
                preds_train = logits[train_idx_t].argmax(dim=1)
                acc_train = accuracy_score(y_train_tensor.cpu(), preds_train.cpu())
            print(f"Fold {fold} Epoch {epoch}: "
                  f"TotalLoss={total_loss.item():.6f} | Sup={loss_sup.item():.6f} | "
                  f"Unsup={loss_unsup.item():.6f} | TrainAcc={acc_train:.4f}")

    # Evaluation
    model.eval()
    with torch.no_grad():
        out = model(data)
        preds = out.argmax(dim=1).cpu().numpy()
        probs = torch.softmax(out, dim=1)[:, 1].cpu().numpy()  # Probability for class 1

    y_test = y[test_idx]
    y_pred_test = preds[test_idx]
    y_prob_test = probs[test_idx]

    acc = accuracy_score(y_test, y_pred_test)
    prec = precision_score(y_test, y_pred_test, zero_division=0)
    rec = recall_score(y_test, y_pred_test, zero_division=0)
    f1 = f1_score(y_test, y_pred_test, zero_division=0)
    auc = roc_auc_score(y_test, y_prob_test)
    ce = log_loss(y_test, y_prob_test)

    accuracies.append(acc)
    precisions.append(prec)
    recalls.append(rec)
    f1_scores.append(f1)
    aucs.append(auc)
    ce_losses.append(ce)

    print(f"Fold {fold} → "
          f"Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | "
          f"F1={f1:.4f} | AUC={auc:.4f} | CE Loss={ce:.4f}")


# Final summary
print("\n=== Average Results Across 20 Folds ===")
print(f"Accuracy:  {np.mean(accuracies):.4f} ± {np.std(accuracies):.4f}")
print(f"Precision: {np.mean(precisions):.4f} ± {np.std(precisions):.4f}")
print(f"Recall:    {np.mean(recalls):.4f} ± {np.std(recalls):.4f}")
print(f"F1-score:  {np.mean(f1_scores):.4f} ± {np.std(f1_scores):.4f}")
print(f"AUC:       {np.mean(aucs):.4f} ± {np.std(aucs):.4f}")
print(f"CE Loss:   {np.mean(ce_losses):.4f} ± {np.std(ce_losses):.4f}")
# Out:
# === Fold 1 ===
# Fold 1 Epoch 1: TotalLoss=1.078998 | Sup=1.079279 | Unsup=-0.280900 | TrainAcc=0.5513
# Fold 1 Epoch 100: TotalLoss=0.256166 | Sup=0.256414 | Unsup=-0.248335 | TrainAcc=0.8846
# Fold 1 Epoch 200: TotalLoss=0.266709 | Sup=0.266977 | Unsup=-0.268055 | TrainAcc=0.8846
# Fold 1 Epoch 300: TotalLoss=0.120290 | Sup=0.120545 | Unsup=-0.254785 | TrainAcc=0.9487
# Fold 1 Epoch 400: TotalLoss=0.051843 | Sup=0.052102 | Unsup=-0.259147 | TrainAcc=1.0000
# Fold 1 Epoch 500: TotalLoss=0.069359 | Sup=0.069603 | Unsup=-0.243208 | TrainAcc=0.9744
# Fold 1 Epoch 600: TotalLoss=0.050437 | Sup=0.050677 | Unsup=-0.240336 | TrainAcc=0.9872
# Fold 1 Epoch 700: TotalLoss=0.065959 | Sup=0.066217 | Unsup=-0.257535 | TrainAcc=0.9744
# Fold 1 Epoch 800: TotalLoss=0.083884 | Sup=0.084110 | Unsup=-0.226378 | TrainAcc=0.9615
# Fold 1 Epoch 900: TotalLoss=0.030808 | Sup=0.031053 | Unsup=-0.244882 | TrainAcc=0.9872
# Fold 1 Epoch 1000: TotalLoss=0.085504 | Sup=0.085745 | Unsup=-0.241007 | TrainAcc=0.9615
# Fold 1 Epoch 1100: TotalLoss=0.012103 | Sup=0.012341 | Unsup=-0.237746 | TrainAcc=1.0000
# Fold 1 Epoch 1200: TotalLoss=0.020657 | Sup=0.020891 | Unsup=-0.234290 | TrainAcc=0.9872
# Fold 1 Epoch 1300: TotalLoss=0.010659 | Sup=0.010896 | Unsup=-0.237694 | TrainAcc=1.0000
# Fold 1 Epoch 1400: TotalLoss=0.004686 | Sup=0.004916 | Unsup=-0.229903 | TrainAcc=1.0000
# Fold 1 Epoch 1500: TotalLoss=0.039114 | Sup=0.039351 | Unsup=-0.237423 | TrainAcc=0.9872
# Fold 1 Epoch 1600: TotalLoss=0.004553 | Sup=0.004784 | Unsup=-0.230964 | TrainAcc=1.0000
# Fold 1 Epoch 1700: TotalLoss=0.020430 | Sup=0.020651 | Unsup=-0.221147 | TrainAcc=0.9872
# Fold 1 Epoch 1800: TotalLoss=0.017849 | Sup=0.018089 | Unsup=-0.240171 | TrainAcc=0.9872
# Fold 1 Epoch 1900: TotalLoss=0.048983 | Sup=0.049219 | Unsup=-0.235906 | TrainAcc=0.9744
# Fold 1 Epoch 2000: TotalLoss=0.027458 | Sup=0.027678 | Unsup=-0.220350 | TrainAcc=0.9872
# Fold 1 → Acc=0.8077 | Prec=0.8387 | Rec=0.9123 | F1=0.8739 | AUC=0.8356 | CE Loss=1.1747
#
# === Fold 2 ===
# Fold 2 Epoch 1: TotalLoss=1.057244 | Sup=1.057450 | Unsup=-0.205845 | TrainAcc=0.6410
# Fold 2 Epoch 100: TotalLoss=0.336797 | Sup=0.337025 | Unsup=-0.227363 | TrainAcc=0.8333
# Fold 2 Epoch 200: TotalLoss=0.302668 | Sup=0.302888 | Unsup=-0.219945 | TrainAcc=0.8974
# Fold 2 Epoch 300: TotalLoss=0.147804 | Sup=0.148015 | Unsup=-0.210583 | TrainAcc=0.9359
# Fold 2 Epoch 400: TotalLoss=0.068285 | Sup=0.068515 | Unsup=-0.229888 | TrainAcc=0.9744
# Fold 2 Epoch 500: TotalLoss=0.036203 | Sup=0.036409 | Unsup=-0.206698 | TrainAcc=0.9744
# Fold 2 Epoch 600: TotalLoss=0.008725 | Sup=0.008939 | Unsup=-0.213942 | TrainAcc=1.0000
# Fold 2 Epoch 700: TotalLoss=0.005530 | Sup=0.005726 | Unsup=-0.195987 | TrainAcc=1.0000
# Fold 2 Epoch 800: TotalLoss=0.004071 | Sup=0.004278 | Unsup=-0.207273 | TrainAcc=1.0000
# Fold 2 Epoch 900: TotalLoss=0.008349 | Sup=0.008548 | Unsup=-0.198509 | TrainAcc=1.0000
# Fold 2 Epoch 1000: TotalLoss=0.000874 | Sup=0.001086 | Unsup=-0.212066 | TrainAcc=1.0000
# Fold 2 Epoch 1100: TotalLoss=0.002401 | Sup=0.002600 | Unsup=-0.198958 | TrainAcc=1.0000
# Fold 2 Epoch 1200: TotalLoss=0.000571 | Sup=0.000784 | Unsup=-0.212445 | TrainAcc=1.0000
# Fold 2 Epoch 1300: TotalLoss=0.000962 | Sup=0.001158 | Unsup=-0.195529 | TrainAcc=1.0000
# Fold 2 Epoch 1400: TotalLoss=0.033407 | Sup=0.033588 | Unsup=-0.180648 | TrainAcc=0.9872
# Fold 2 Epoch 1500: TotalLoss=0.003283 | Sup=0.003464 | Unsup=-0.180942 | TrainAcc=1.0000
# Fold 2 Epoch 1600: TotalLoss=0.001195 | Sup=0.001392 | Unsup=-0.196269 | TrainAcc=1.0000
# Fold 2 Epoch 1700: TotalLoss=0.000300 | Sup=0.000501 | Unsup=-0.201724 | TrainAcc=1.0000
# Fold 2 Epoch 1800: TotalLoss=0.003087 | Sup=0.003279 | Unsup=-0.191272 | TrainAcc=1.0000
# Fold 2 Epoch 1900: TotalLoss=0.001524 | Sup=0.001709 | Unsup=-0.185319 | TrainAcc=1.0000
# Fold 2 Epoch 2000: TotalLoss=0.000035 | Sup=0.000223 | Unsup=-0.187957 | TrainAcc=1.0000
# Fold 2 → Acc=0.8533 | Prec=0.8714 | Rec=0.9376 | F1=0.9033 | AUC=0.8828 | CE Loss=1.0605
#
# === Fold 3 ===
# Fold 3 Epoch 1: TotalLoss=1.221411 | Sup=1.221646 | Unsup=-0.235662 | TrainAcc=0.5769
# Fold 3 Epoch 100: TotalLoss=0.528807 | Sup=0.529048 | Unsup=-0.241058 | TrainAcc=0.8205
# Fold 3 Epoch 200: TotalLoss=0.210662 | Sup=0.210920 | Unsup=-0.257667 | TrainAcc=0.9103
# Fold 3 Epoch 300: TotalLoss=0.160775 | Sup=0.161029 | Unsup=-0.253742 | TrainAcc=0.9231
# Fold 3 Epoch 400: TotalLoss=0.069027 | Sup=0.069270 | Unsup=-0.243444 | TrainAcc=0.9872
# Fold 3 Epoch 500: TotalLoss=0.055041 | Sup=0.055317 | Unsup=-0.276137 | TrainAcc=0.9744
# Fold 3 Epoch 600: TotalLoss=0.021718 | Sup=0.021977 | Unsup=-0.259329 | TrainAcc=1.0000
# Fold 3 Epoch 700: TotalLoss=0.005204 | Sup=0.005469 | Unsup=-0.265034 | TrainAcc=1.0000
# Fold 3 Epoch 800: TotalLoss=0.023180 | Sup=0.023414 | Unsup=-0.234345 | TrainAcc=0.9872
# Fold 3 Epoch 900: TotalLoss=0.007683 | Sup=0.007959 | Unsup=-0.275919 | TrainAcc=1.0000
# Fold 3 Epoch 1000: TotalLoss=0.003319 | Sup=0.003573 | Unsup=-0.254115 | TrainAcc=1.0000
# Fold 3 Epoch 1100: TotalLoss=0.002621 | Sup=0.002850 | Unsup=-0.229543 | TrainAcc=1.0000
# Fold 3 Epoch 1200: TotalLoss=0.051463 | Sup=0.051718 | Unsup=-0.254397 | TrainAcc=0.9744
# Fold 3 Epoch 1300: TotalLoss=0.004287 | Sup=0.004506 | Unsup=-0.219481 | TrainAcc=1.0000
# Fold 3 Epoch 1400: TotalLoss=0.014699 | Sup=0.014936 | Unsup=-0.236703 | TrainAcc=0.9872
# Fold 3 Epoch 1500: TotalLoss=0.026825 | Sup=0.027061 | Unsup=-0.236214 | TrainAcc=0.9872
# Fold 3 Epoch 1600: TotalLoss=0.004220 | Sup=0.004492 | Unsup=-0.272438 | TrainAcc=1.0000
# Fold 3 Epoch 1700: TotalLoss=0.005181 | Sup=0.005459 | Unsup=-0.278201 | TrainAcc=1.0000
# Fold 3 Epoch 1800: TotalLoss=0.005831 | Sup=0.006074 | Unsup=-0.242837 | TrainAcc=1.0000
# Fold 3 Epoch 1900: TotalLoss=0.000131 | Sup=0.000357 | Unsup=-0.226435 | TrainAcc=1.0000
# Fold 3 Epoch 2000: TotalLoss=0.000464 | Sup=0.000704 | Unsup=-0.239408 | TrainAcc=1.0000
# Fold 3 → Acc=0.8120 | Prec=0.8588 | Rec=0.8889 | F1=0.8736 | AUC=0.8661 | CE Loss=1.0847
#
# === Fold 4 ===
# Fold 4 Epoch 1: TotalLoss=1.331997 | Sup=1.332317 | Unsup=-0.319655 | TrainAcc=0.4231
# Fold 4 Epoch 100: TotalLoss=0.492428 | Sup=0.492645 | Unsup=-0.217108 | TrainAcc=0.7821
# Fold 4 Epoch 200: TotalLoss=0.353298 | Sup=0.353514 | Unsup=-0.215576 | TrainAcc=0.8718
# Fold 4 Epoch 300: TotalLoss=0.295138 | Sup=0.295334 | Unsup=-0.195535 | TrainAcc=0.8974
# Fold 4 Epoch 400: TotalLoss=0.155881 | Sup=0.156065 | Unsup=-0.184303 | TrainAcc=0.9231
# Fold 4 Epoch 500: TotalLoss=0.101343 | Sup=0.101530 | Unsup=-0.186924 | TrainAcc=0.9744
# Fold 4 Epoch 600: TotalLoss=0.085058 | Sup=0.085234 | Unsup=-0.176084 | TrainAcc=0.9359
# Fold 4 Epoch 700: TotalLoss=0.025962 | Sup=0.026128 | Unsup=-0.166533 | TrainAcc=1.0000
# Fold 4 Epoch 800: TotalLoss=0.043407 | Sup=0.043571 | Unsup=-0.164478 | TrainAcc=0.9872
# Fold 4 Epoch 900: TotalLoss=0.023822 | Sup=0.023985 | Unsup=-0.163525 | TrainAcc=1.0000
# Fold 4 Epoch 1000: TotalLoss=0.051817 | Sup=0.051986 | Unsup=-0.169185 | TrainAcc=0.9744
# Fold 4 Epoch 1100: TotalLoss=0.014519 | Sup=0.014687 | Unsup=-0.168756 | TrainAcc=0.9872
# Fold 4 Epoch 1200: TotalLoss=0.011468 | Sup=0.011627 | Unsup=-0.159030 | TrainAcc=1.0000
# Fold 4 Epoch 1300: TotalLoss=0.057177 | Sup=0.057350 | Unsup=-0.173548 | TrainAcc=0.9744
# Fold 4 Epoch 1400: TotalLoss=0.012667 | Sup=0.012822 | Unsup=-0.154688 | TrainAcc=0.9872
# Fold 4 Epoch 1500: TotalLoss=0.004096 | Sup=0.004257 | Unsup=-0.161357 | TrainAcc=1.0000
# Fold 4 Epoch 1600: TotalLoss=0.003940 | Sup=0.004102 | Unsup=-0.161430 | TrainAcc=1.0000
# Fold 4 Epoch 1700: TotalLoss=0.001558 | Sup=0.001714 | Unsup=-0.156073 | TrainAcc=1.0000
# Fold 4 Epoch 1800: TotalLoss=0.014401 | Sup=0.014562 | Unsup=-0.160774 | TrainAcc=0.9872
# Fold 4 Epoch 1900: TotalLoss=0.003008 | Sup=0.003169 | Unsup=-0.160535 | TrainAcc=1.0000
# Fold 4 Epoch 2000: TotalLoss=0.006861 | Sup=0.007030 | Unsup=-0.169449 | TrainAcc=1.0000
# Fold 4 → Acc=0.8191 | Prec=0.8328 | Rec=0.9415 | F1=0.8838 | AUC=0.8237 | CE Loss=1.3187
#
# === Fold 5 ===
# Fold 5 Epoch 1: TotalLoss=1.602080 | Sup=1.602419 | Unsup=-0.339471 | TrainAcc=0.4103
# Fold 5 Epoch 100: TotalLoss=0.416710 | Sup=0.416971 | Unsup=-0.261014 | TrainAcc=0.7821
# Fold 5 Epoch 200: TotalLoss=0.201269 | Sup=0.201528 | Unsup=-0.259170 | TrainAcc=0.9231
# Fold 5 Epoch 300: TotalLoss=0.177089 | Sup=0.177339 | Unsup=-0.250698 | TrainAcc=0.9231
# Fold 5 Epoch 400: TotalLoss=0.044897 | Sup=0.045148 | Unsup=-0.250683 | TrainAcc=0.9872
# Fold 5 Epoch 500: TotalLoss=0.067506 | Sup=0.067757 | Unsup=-0.251316 | TrainAcc=0.9744
# Fold 5 Epoch 600: TotalLoss=0.070393 | Sup=0.070643 | Unsup=-0.250023 | TrainAcc=0.9615
# Fold 5 Epoch 700: TotalLoss=0.011377 | Sup=0.011630 | Unsup=-0.253403 | TrainAcc=1.0000
# Fold 5 Epoch 800: TotalLoss=0.007431 | Sup=0.007697 | Unsup=-0.265652 | TrainAcc=1.0000
# Fold 5 Epoch 900: TotalLoss=0.015842 | Sup=0.016082 | Unsup=-0.239858 | TrainAcc=1.0000
# Fold 5 Epoch 1000: TotalLoss=0.011344 | Sup=0.011604 | Unsup=-0.260033 | TrainAcc=1.0000
# Fold 5 Epoch 1100: TotalLoss=0.008477 | Sup=0.008722 | Unsup=-0.244741 | TrainAcc=1.0000
# Fold 5 Epoch 1200: TotalLoss=0.017555 | Sup=0.017792 | Unsup=-0.237115 | TrainAcc=0.9872
# Fold 5 Epoch 1300: TotalLoss=0.000557 | Sup=0.000798 | Unsup=-0.240920 | TrainAcc=1.0000
# Fold 5 Epoch 1400: TotalLoss=0.007659 | Sup=0.007908 | Unsup=-0.249395 | TrainAcc=1.0000
# Fold 5 Epoch 1500: TotalLoss=0.001402 | Sup=0.001666 | Unsup=-0.264149 | TrainAcc=1.0000
# Fold 5 Epoch 1600: TotalLoss=0.005920 | Sup=0.006155 | Unsup=-0.235126 | TrainAcc=1.0000
# Fold 5 Epoch 1700: TotalLoss=0.003200 | Sup=0.003457 | Unsup=-0.257478 | TrainAcc=1.0000
# Fold 5 Epoch 1800: TotalLoss=0.000105 | Sup=0.000368 | Unsup=-0.263019 | TrainAcc=1.0000
# Fold 5 Epoch 1900: TotalLoss=0.003826 | Sup=0.004069 | Unsup=-0.243309 | TrainAcc=1.0000
# Fold 5 Epoch 2000: TotalLoss=0.000028 | Sup=0.000267 | Unsup=-0.238560 | TrainAcc=1.0000
# Fold 5 → Acc=0.8447 | Prec=0.8769 | Rec=0.9162 | F1=0.8961 | AUC=0.8442 | CE Loss=1.3427
#
# === Fold 6 ===
# Fold 6 Epoch 1: TotalLoss=0.999160 | Sup=0.999354 | Unsup=-0.193384 | TrainAcc=0.6795
# Fold 6 Epoch 100: TotalLoss=0.441443 | Sup=0.441667 | Unsup=-0.223654 | TrainAcc=0.7949
# Fold 6 Epoch 200: TotalLoss=0.240255 | Sup=0.240496 | Unsup=-0.241011 | TrainAcc=0.9103
# Fold 6 Epoch 300: TotalLoss=0.134870 | Sup=0.135083 | Unsup=-0.212535 | TrainAcc=0.9359
# Fold 6 Epoch 400: TotalLoss=0.165335 | Sup=0.165553 | Unsup=-0.218383 | TrainAcc=0.9231
# Fold 6 Epoch 500: TotalLoss=0.058222 | Sup=0.058423 | Unsup=-0.200723 | TrainAcc=0.9744
# Fold 6 Epoch 600: TotalLoss=0.071214 | Sup=0.071420 | Unsup=-0.205505 | TrainAcc=0.9744
# Fold 6 Epoch 700: TotalLoss=0.042350 | Sup=0.042551 | Unsup=-0.201151 | TrainAcc=0.9744
# Fold 6 Epoch 800: TotalLoss=0.011135 | Sup=0.011329 | Unsup=-0.194849 | TrainAcc=1.0000
# Fold 6 Epoch 900: TotalLoss=0.024194 | Sup=0.024406 | Unsup=-0.212576 | TrainAcc=0.9872
# Fold 6 Epoch 1000: TotalLoss=0.044776 | Sup=0.044968 | Unsup=-0.192319 | TrainAcc=0.9872
# Fold 6 Epoch 1100: TotalLoss=0.042740 | Sup=0.042957 | Unsup=-0.217038 | TrainAcc=0.9872
# Fold 6 Epoch 1200: TotalLoss=0.003922 | Sup=0.004110 | Unsup=-0.188502 | TrainAcc=1.0000
# Fold 6 Epoch 1300: TotalLoss=0.004577 | Sup=0.004777 | Unsup=-0.200411 | TrainAcc=1.0000
# Fold 6 Epoch 1400: TotalLoss=0.000553 | Sup=0.000750 | Unsup=-0.197415 | TrainAcc=1.0000
# Fold 6 Epoch 1500: TotalLoss=0.003768 | Sup=0.003976 | Unsup=-0.207820 | TrainAcc=1.0000
# Fold 6 Epoch 1600: TotalLoss=0.032192 | Sup=0.032379 | Unsup=-0.186545 | TrainAcc=0.9872
# Fold 6 Epoch 1700: TotalLoss=0.011419 | Sup=0.011621 | Unsup=-0.202430 | TrainAcc=1.0000
# Fold 6 Epoch 1800: TotalLoss=0.000380 | Sup=0.000586 | Unsup=-0.206615 | TrainAcc=1.0000
# Fold 6 Epoch 1900: TotalLoss=0.000207 | Sup=0.000400 | Unsup=-0.192873 | TrainAcc=1.0000
# Fold 6 Epoch 2000: TotalLoss=0.001250 | Sup=0.001439 | Unsup=-0.189299 | TrainAcc=1.0000
# Fold 6 → Acc=0.8604 | Prec=0.8780 | Rec=0.9396 | F1=0.9077 | AUC=0.8897 | CE Loss=0.9161
#
# === Fold 7 ===
# Fold 7 Epoch 1: TotalLoss=1.167034 | Sup=1.167346 | Unsup=-0.311733 | TrainAcc=0.5128
# Fold 7 Epoch 100: TotalLoss=0.354982 | Sup=0.355210 | Unsup=-0.228044 | TrainAcc=0.8333
# Fold 7 Epoch 200: TotalLoss=0.290684 | Sup=0.290932 | Unsup=-0.247857 | TrainAcc=0.8462
# Fold 7 Epoch 300: TotalLoss=0.134772 | Sup=0.135022 | Unsup=-0.249531 | TrainAcc=0.9487
# Fold 7 Epoch 400: TotalLoss=0.085000 | Sup=0.085253 | Unsup=-0.253431 | TrainAcc=0.9744
# Fold 7 Epoch 500: TotalLoss=0.158178 | Sup=0.158399 | Unsup=-0.220851 | TrainAcc=0.9231
# Fold 7 Epoch 600: TotalLoss=0.032463 | Sup=0.032695 | Unsup=-0.231319 | TrainAcc=0.9872
# Fold 7 Epoch 700: TotalLoss=0.039286 | Sup=0.039510 | Unsup=-0.223417 | TrainAcc=0.9872
# Fold 7 Epoch 800: TotalLoss=0.007134 | Sup=0.007378 | Unsup=-0.244172 | TrainAcc=1.0000
# Fold 7 Epoch 900: TotalLoss=0.013346 | Sup=0.013580 | Unsup=-0.234069 | TrainAcc=1.0000
# Fold 7 Epoch 1000: TotalLoss=0.006150 | Sup=0.006397 | Unsup=-0.246533 | TrainAcc=1.0000
# Fold 7 Epoch 1100: TotalLoss=0.008055 | Sup=0.008297 | Unsup=-0.241458 | TrainAcc=1.0000
# Fold 7 Epoch 1200: TotalLoss=0.003661 | Sup=0.003910 | Unsup=-0.249703 | TrainAcc=1.0000
# Fold 7 Epoch 1300: TotalLoss=0.005929 | Sup=0.006167 | Unsup=-0.238334 | TrainAcc=1.0000
# Fold 7 Epoch 1400: TotalLoss=0.003636 | Sup=0.003869 | Unsup=-0.232188 | TrainAcc=1.0000
# Fold 7 Epoch 1500: TotalLoss=0.046024 | Sup=0.046263 | Unsup=-0.238957 | TrainAcc=0.9872
# Fold 7 Epoch 1600: TotalLoss=0.001331 | Sup=0.001565 | Unsup=-0.233380 | TrainAcc=1.0000
# Fold 7 Epoch 1700: TotalLoss=0.002098 | Sup=0.002339 | Unsup=-0.240821 | TrainAcc=1.0000
# Fold 7 Epoch 1800: TotalLoss=0.000446 | Sup=0.000704 | Unsup=-0.258546 | TrainAcc=1.0000
# Fold 7 Epoch 1900: TotalLoss=0.005312 | Sup=0.005571 | Unsup=-0.258723 | TrainAcc=1.0000
# Fold 7 Epoch 2000: TotalLoss=0.001806 | Sup=0.002043 | Unsup=-0.236929 | TrainAcc=1.0000
# Fold 7 → Acc=0.8219 | Prec=0.8702 | Rec=0.8889 | F1=0.8795 | AUC=0.8779 | CE Loss=1.1630
#
# === Fold 8 ===
# Fold 8 Epoch 1: TotalLoss=1.921893 | Sup=1.922086 | Unsup=-0.192539 | TrainAcc=0.3462
# Fold 8 Epoch 100: TotalLoss=0.478885 | Sup=0.479101 | Unsup=-0.215993 | TrainAcc=0.7692
# Fold 8 Epoch 200: TotalLoss=0.342850 | Sup=0.343081 | Unsup=-0.230593 | TrainAcc=0.8718
# Fold 8 Epoch 300: TotalLoss=0.145610 | Sup=0.145819 | Unsup=-0.209602 | TrainAcc=0.9487
# Fold 8 Epoch 400: TotalLoss=0.135887 | Sup=0.136087 | Unsup=-0.199224 | TrainAcc=0.9231
# Fold 8 Epoch 500: TotalLoss=0.052199 | Sup=0.052395 | Unsup=-0.196064 | TrainAcc=0.9872
# Fold 8 Epoch 600: TotalLoss=0.036896 | Sup=0.037085 | Unsup=-0.188988 | TrainAcc=1.0000
# Fold 8 Epoch 700: TotalLoss=0.020682 | Sup=0.020868 | Unsup=-0.185501 | TrainAcc=1.0000
# Fold 8 Epoch 800: TotalLoss=0.025794 | Sup=0.025990 | Unsup=-0.196233 | TrainAcc=0.9872
# Fold 8 Epoch 900: TotalLoss=0.042261 | Sup=0.042462 | Unsup=-0.200933 | TrainAcc=0.9744
# Fold 8 Epoch 1000: TotalLoss=0.017514 | Sup=0.017719 | Unsup=-0.204902 | TrainAcc=0.9872
# Fold 8 Epoch 1100: TotalLoss=0.005282 | Sup=0.005471 | Unsup=-0.189133 | TrainAcc=1.0000
# Fold 8 Epoch 1200: TotalLoss=0.047584 | Sup=0.047787 | Unsup=-0.202933 | TrainAcc=0.9744
# Fold 8 Epoch 1300: TotalLoss=0.005014 | Sup=0.005190 | Unsup=-0.176689 | TrainAcc=1.0000
# Fold 8 Epoch 1400: TotalLoss=0.003542 | Sup=0.003741 | Unsup=-0.198599 | TrainAcc=1.0000
# Fold 8 Epoch 1500: TotalLoss=0.012426 | Sup=0.012612 | Unsup=-0.185780 | TrainAcc=0.9872
# Fold 8 Epoch 1600: TotalLoss=0.003463 | Sup=0.003643 | Unsup=-0.179793 | TrainAcc=1.0000
# Fold 8 Epoch 1700: TotalLoss=0.000960 | Sup=0.001158 | Unsup=-0.197475 | TrainAcc=1.0000
# Fold 8 Epoch 1800: TotalLoss=0.000400 | Sup=0.000583 | Unsup=-0.182645 | TrainAcc=1.0000
# Fold 8 Epoch 1900: TotalLoss=0.005852 | Sup=0.006023 | Unsup=-0.171193 | TrainAcc=1.0000
# Fold 8 Epoch 2000: TotalLoss=0.000367 | Sup=0.000549 | Unsup=-0.182417 | TrainAcc=1.0000
# Fold 8 → Acc=0.8732 | Prec=0.8911 | Rec=0.9415 | F1=0.9156 | AUC=0.9127 | CE Loss=0.7192
#
# === Fold 9 ===
# Fold 9 Epoch 1: TotalLoss=1.548536 | Sup=1.548878 | Unsup=-0.341838 | TrainAcc=0.3974
# Fold 9 Epoch 100: TotalLoss=0.408117 | Sup=0.408335 | Unsup=-0.218044 | TrainAcc=0.7949
# Fold 9 Epoch 200: TotalLoss=0.277551 | Sup=0.277790 | Unsup=-0.239950 | TrainAcc=0.8846
# Fold 9 Epoch 300: TotalLoss=0.249392 | Sup=0.249595 | Unsup=-0.203418 | TrainAcc=0.8974
# Fold 9 Epoch 400: TotalLoss=0.117328 | Sup=0.117542 | Unsup=-0.213580 | TrainAcc=0.9487
# Fold 9 Epoch 500: TotalLoss=0.079058 | Sup=0.079260 | Unsup=-0.202020 | TrainAcc=0.9744
# Fold 9 Epoch 600: TotalLoss=0.039207 | Sup=0.039420 | Unsup=-0.212735 | TrainAcc=0.9744
# Fold 9 Epoch 700: TotalLoss=0.089901 | Sup=0.090101 | Unsup=-0.200005 | TrainAcc=0.9615
# Fold 9 Epoch 800: TotalLoss=0.033334 | Sup=0.033549 | Unsup=-0.214654 | TrainAcc=0.9744
# Fold 9 Epoch 900: TotalLoss=0.037856 | Sup=0.038069 | Unsup=-0.212625 | TrainAcc=0.9872
# Fold 9 Epoch 1000: TotalLoss=0.046396 | Sup=0.046603 | Unsup=-0.206225 | TrainAcc=0.9872
# Fold 9 Epoch 1100: TotalLoss=0.012360 | Sup=0.012556 | Unsup=-0.196468 | TrainAcc=1.0000
# Fold 9 Epoch 1200: TotalLoss=0.003729 | Sup=0.003936 | Unsup=-0.207195 | TrainAcc=1.0000
# Fold 9 Epoch 1300: TotalLoss=0.001315 | Sup=0.001520 | Unsup=-0.204527 | TrainAcc=1.0000
# Fold 9 Epoch 1400: TotalLoss=0.000780 | Sup=0.000989 | Unsup=-0.208048 | TrainAcc=1.0000
# Fold 9 Epoch 1500: TotalLoss=0.001962 | Sup=0.002164 | Unsup=-0.202397 | TrainAcc=1.0000
# Fold 9 Epoch 1600: TotalLoss=0.039784 | Sup=0.039989 | Unsup=-0.205082 | TrainAcc=0.9872
# Fold 9 Epoch 1700: TotalLoss=0.005452 | Sup=0.005665 | Unsup=-0.213888 | TrainAcc=1.0000
# Fold 9 Epoch 1800: TotalLoss=0.006351 | Sup=0.006584 | Unsup=-0.233144 | TrainAcc=1.0000
# Fold 9 Epoch 1900: TotalLoss=0.001000 | Sup=0.001212 | Unsup=-0.212063 | TrainAcc=1.0000
# Fold 9 Epoch 2000: TotalLoss=0.002125 | Sup=0.002385 | Unsup=-0.260441 | TrainAcc=1.0000
# Fold 9 → Acc=0.8291 | Prec=0.9085 | Rec=0.8519 | F1=0.8793 | AUC=0.9038 | CE Loss=0.9568
#
# === Fold 10 ===
# Fold 10 Epoch 1: TotalLoss=3.410223 | Sup=3.410430 | Unsup=-0.207518 | TrainAcc=0.3205
# Fold 10 Epoch 100: TotalLoss=0.501082 | Sup=0.501307 | Unsup=-0.225275 | TrainAcc=0.7821
# Fold 10 Epoch 200: TotalLoss=0.352183 | Sup=0.352424 | Unsup=-0.241217 | TrainAcc=0.8205
# Fold 10 Epoch 300: TotalLoss=0.162476 | Sup=0.162693 | Unsup=-0.216615 | TrainAcc=0.9359
# Fold 10 Epoch 400: TotalLoss=0.127485 | Sup=0.127702 | Unsup=-0.217222 | TrainAcc=0.9487
# Fold 10 Epoch 500: TotalLoss=0.077010 | Sup=0.077193 | Unsup=-0.183655 | TrainAcc=0.9872
# Fold 10 Epoch 600: TotalLoss=0.051159 | Sup=0.051345 | Unsup=-0.186301 | TrainAcc=0.9615
# Fold 10 Epoch 700: TotalLoss=0.061034 | Sup=0.061218 | Unsup=-0.184814 | TrainAcc=0.9872
# Fold 10 Epoch 800: TotalLoss=0.012939 | Sup=0.013123 | Unsup=-0.184374 | TrainAcc=1.0000
# Fold 10 Epoch 900: TotalLoss=0.013070 | Sup=0.013274 | Unsup=-0.203660 | TrainAcc=1.0000
# Fold 10 Epoch 1000: TotalLoss=0.043323 | Sup=0.043519 | Unsup=-0.196112 | TrainAcc=0.9872
# Fold 10 Epoch 1100: TotalLoss=0.001933 | Sup=0.002127 | Unsup=-0.194283 | TrainAcc=1.0000
# Fold 10 Epoch 1200: TotalLoss=0.015623 | Sup=0.015805 | Unsup=-0.182184 | TrainAcc=0.9872
# Fold 10 Epoch 1300: TotalLoss=0.003611 | Sup=0.003809 | Unsup=-0.197264 | TrainAcc=1.0000
# Fold 10 Epoch 1400: TotalLoss=0.025304 | Sup=0.025487 | Unsup=-0.183164 | TrainAcc=0.9872
# Fold 10 Epoch 1500: TotalLoss=0.031965 | Sup=0.032123 | Unsup=-0.157633 | TrainAcc=0.9744
# Fold 10 Epoch 1600: TotalLoss=0.001502 | Sup=0.001682 | Unsup=-0.179838 | TrainAcc=1.0000
# Fold 10 Epoch 1700: TotalLoss=0.000238 | Sup=0.000425 | Unsup=-0.186424 | TrainAcc=1.0000
# Fold 10 Epoch 1800: TotalLoss=0.007257 | Sup=0.007422 | Unsup=-0.164659 | TrainAcc=1.0000
# Fold 10 Epoch 1900: TotalLoss=0.000307 | Sup=0.000487 | Unsup=-0.179248 | TrainAcc=1.0000
# Fold 10 Epoch 2000: TotalLoss=0.002715 | Sup=0.002904 | Unsup=-0.188859 | TrainAcc=1.0000
# Fold 10 → Acc=0.8063 | Prec=0.8793 | Rec=0.8519 | F1=0.8653 | AUC=0.8636 | CE Loss=1.1605
#
# === Fold 11 ===
# Fold 11 Epoch 1: TotalLoss=1.780808 | Sup=1.781037 | Unsup=-0.228684 | TrainAcc=0.4359
# Fold 11 Epoch 100: TotalLoss=0.396022 | Sup=0.396257 | Unsup=-0.235125 | TrainAcc=0.8590
# Fold 11 Epoch 200: TotalLoss=0.302742 | Sup=0.303008 | Unsup=-0.265710 | TrainAcc=0.8846
# Fold 11 Epoch 300: TotalLoss=0.257969 | Sup=0.258241 | Unsup=-0.271247 | TrainAcc=0.8846
# Fold 11 Epoch 400: TotalLoss=0.153949 | Sup=0.154208 | Unsup=-0.259327 | TrainAcc=0.9487
# Fold 11 Epoch 500: TotalLoss=0.121348 | Sup=0.121626 | Unsup=-0.278636 | TrainAcc=0.9615
# Fold 11 Epoch 600: TotalLoss=0.102898 | Sup=0.103161 | Unsup=-0.262621 | TrainAcc=0.9744
# Fold 11 Epoch 700: TotalLoss=0.066653 | Sup=0.066943 | Unsup=-0.289313 | TrainAcc=0.9744
# Fold 11 Epoch 800: TotalLoss=0.101243 | Sup=0.101496 | Unsup=-0.253354 | TrainAcc=0.9615
# Fold 11 Epoch 900: TotalLoss=0.022722 | Sup=0.022994 | Unsup=-0.271459 | TrainAcc=1.0000
# Fold 11 Epoch 1000: TotalLoss=0.048288 | Sup=0.048573 | Unsup=-0.285514 | TrainAcc=0.9744
# Fold 11 Epoch 1100: TotalLoss=0.009339 | Sup=0.009591 | Unsup=-0.252380 | TrainAcc=1.0000
# Fold 11 Epoch 1200: TotalLoss=0.006358 | Sup=0.006594 | Unsup=-0.236264 | TrainAcc=1.0000
# Fold 11 Epoch 1300: TotalLoss=0.009730 | Sup=0.010001 | Unsup=-0.271422 | TrainAcc=1.0000
# Fold 11 Epoch 1400: TotalLoss=0.014681 | Sup=0.014958 | Unsup=-0.276676 | TrainAcc=1.0000
# Fold 11 Epoch 1500: TotalLoss=0.001679 | Sup=0.001943 | Unsup=-0.263180 | TrainAcc=1.0000
# Fold 11 Epoch 1600: TotalLoss=0.019228 | Sup=0.019498 | Unsup=-0.269973 | TrainAcc=0.9872
# Fold 11 Epoch 1700: TotalLoss=0.001895 | Sup=0.002153 | Unsup=-0.258009 | TrainAcc=1.0000
# Fold 11 Epoch 1800: TotalLoss=0.001947 | Sup=0.002193 | Unsup=-0.245369 | TrainAcc=1.0000
# Fold 11 Epoch 1900: TotalLoss=0.006201 | Sup=0.006447 | Unsup=-0.245675 | TrainAcc=1.0000
# Fold 11 Epoch 2000: TotalLoss=0.000414 | Sup=0.000675 | Unsup=-0.261386 | TrainAcc=1.0000
# Fold 11 → Acc=0.8348 | Prec=0.8946 | Rec=0.8772 | F1=0.8858 | AUC=0.8769 | CE Loss=1.1241
#
# === Fold 12 ===
# Fold 12 Epoch 1: TotalLoss=1.276144 | Sup=1.276490 | Unsup=-0.346498 | TrainAcc=0.5641
# Fold 12 Epoch 100: TotalLoss=0.435766 | Sup=0.436008 | Unsup=-0.241296 | TrainAcc=0.8205
# Fold 12 Epoch 200: TotalLoss=0.282319 | Sup=0.282574 | Unsup=-0.255328 | TrainAcc=0.8718
# Fold 12 Epoch 300: TotalLoss=0.229553 | Sup=0.229779 | Unsup=-0.225916 | TrainAcc=0.8974
# Fold 12 Epoch 400: TotalLoss=0.172246 | Sup=0.172473 | Unsup=-0.227098 | TrainAcc=0.9231
# Fold 12 Epoch 500: TotalLoss=0.067080 | Sup=0.067303 | Unsup=-0.223271 | TrainAcc=0.9744
# Fold 12 Epoch 600: TotalLoss=0.030757 | Sup=0.030954 | Unsup=-0.197037 | TrainAcc=1.0000
# Fold 12 Epoch 700: TotalLoss=0.049065 | Sup=0.049303 | Unsup=-0.237635 | TrainAcc=0.9744
# Fold 12 Epoch 800: TotalLoss=0.009243 | Sup=0.009443 | Unsup=-0.200963 | TrainAcc=1.0000
# Fold 12 Epoch 900: TotalLoss=0.004973 | Sup=0.005182 | Unsup=-0.209042 | TrainAcc=1.0000
# Fold 12 Epoch 1000: TotalLoss=0.002227 | Sup=0.002443 | Unsup=-0.215193 | TrainAcc=1.0000
# Fold 12 Epoch 1100: TotalLoss=0.033877 | Sup=0.034058 | Unsup=-0.180551 | TrainAcc=0.9872
# Fold 12 Epoch 1200: TotalLoss=0.001686 | Sup=0.001876 | Unsup=-0.189810 | TrainAcc=1.0000
# Fold 12 Epoch 1300: TotalLoss=0.024707 | Sup=0.024902 | Unsup=-0.194793 | TrainAcc=0.9872
# Fold 12 Epoch 1400: TotalLoss=0.019994 | Sup=0.020213 | Unsup=-0.219237 | TrainAcc=0.9872
# Fold 12 Epoch 1500: TotalLoss=0.012960 | Sup=0.013174 | Unsup=-0.213698 | TrainAcc=0.9872
# Fold 12 Epoch 1600: TotalLoss=0.000342 | Sup=0.000534 | Unsup=-0.191414 | TrainAcc=1.0000
# Fold 12 Epoch 1700: TotalLoss=0.023948 | Sup=0.024132 | Unsup=-0.183320 | TrainAcc=0.9744
# Fold 12 Epoch 1800: TotalLoss=0.000968 | Sup=0.001173 | Unsup=-0.204935 | TrainAcc=1.0000
# Fold 12 Epoch 1900: TotalLoss=0.005989 | Sup=0.006215 | Unsup=-0.226154 | TrainAcc=1.0000
# Fold 12 Epoch 2000: TotalLoss=0.000129 | Sup=0.000340 | Unsup=-0.210666 | TrainAcc=1.0000
# Fold 12 → Acc=0.8604 | Prec=0.9061 | Rec=0.9025 | F1=0.9043 | AUC=0.9034 | CE Loss=0.8046
#
# === Fold 13 ===
# Fold 13 Epoch 1: TotalLoss=2.739888 | Sup=2.740073 | Unsup=-0.184508 | TrainAcc=0.3205
# Fold 13 Epoch 100: TotalLoss=0.440522 | Sup=0.440760 | Unsup=-0.238604 | TrainAcc=0.7692
# Fold 13 Epoch 200: TotalLoss=0.318460 | Sup=0.318707 | Unsup=-0.247254 | TrainAcc=0.8462
# Fold 13 Epoch 300: TotalLoss=0.194220 | Sup=0.194444 | Unsup=-0.224449 | TrainAcc=0.9231
# Fold 13 Epoch 400: TotalLoss=0.166986 | Sup=0.167215 | Unsup=-0.229309 | TrainAcc=0.9231
# Fold 13 Epoch 500: TotalLoss=0.165751 | Sup=0.165972 | Unsup=-0.220684 | TrainAcc=0.9231
# Fold 13 Epoch 600: TotalLoss=0.078589 | Sup=0.078808 | Unsup=-0.219895 | TrainAcc=0.9615
# Fold 13 Epoch 700: TotalLoss=0.062076 | Sup=0.062296 | Unsup=-0.219708 | TrainAcc=0.9872
# Fold 13 Epoch 800: TotalLoss=0.078354 | Sup=0.078564 | Unsup=-0.210243 | TrainAcc=0.9744
# Fold 13 Epoch 900: TotalLoss=0.035004 | Sup=0.035233 | Unsup=-0.228702 | TrainAcc=0.9872
# Fold 13 Epoch 1000: TotalLoss=0.027430 | Sup=0.027635 | Unsup=-0.204501 | TrainAcc=0.9872
# Fold 13 Epoch 1100: TotalLoss=0.097491 | Sup=0.097701 | Unsup=-0.210700 | TrainAcc=0.9615
# Fold 13 Epoch 1200: TotalLoss=0.023039 | Sup=0.023258 | Unsup=-0.219473 | TrainAcc=1.0000
# Fold 13 Epoch 1300: TotalLoss=0.085603 | Sup=0.085808 | Unsup=-0.205062 | TrainAcc=0.9744
# Fold 13 Epoch 1400: TotalLoss=0.029067 | Sup=0.029277 | Unsup=-0.209589 | TrainAcc=0.9872
# Fold 13 Epoch 1500: TotalLoss=0.053758 | Sup=0.053966 | Unsup=-0.208558 | TrainAcc=0.9744
# Fold 13 Epoch 1600: TotalLoss=0.058121 | Sup=0.058333 | Unsup=-0.212287 | TrainAcc=0.9744
# Fold 13 Epoch 1700: TotalLoss=0.035675 | Sup=0.035883 | Unsup=-0.207694 | TrainAcc=0.9872
# Fold 13 Epoch 1800: TotalLoss=0.037844 | Sup=0.038054 | Unsup=-0.210661 | TrainAcc=0.9744
# Fold 13 Epoch 1900: TotalLoss=0.011690 | Sup=0.011895 | Unsup=-0.204377 | TrainAcc=1.0000
# Fold 13 Epoch 2000: TotalLoss=0.026383 | Sup=0.026604 | Unsup=-0.220741 | TrainAcc=0.9744
# Fold 13 → Acc=0.8433 | Prec=0.8657 | Rec=0.9298 | F1=0.8966 | AUC=0.8646 | CE Loss=0.8486
#
# === Fold 14 ===
# Fold 14 Epoch 1: TotalLoss=1.190281 | Sup=1.190489 | Unsup=-0.208755 | TrainAcc=0.7051
# Fold 14 Epoch 100: TotalLoss=0.417278 | Sup=0.417507 | Unsup=-0.229131 | TrainAcc=0.8462
# Fold 14 Epoch 200: TotalLoss=0.316934 | Sup=0.317193 | Unsup=-0.259146 | TrainAcc=0.8590
# Fold 14 Epoch 300: TotalLoss=0.204522 | Sup=0.204762 | Unsup=-0.239812 | TrainAcc=0.9103
# Fold 14 Epoch 400: TotalLoss=0.108991 | Sup=0.109221 | Unsup=-0.230115 | TrainAcc=0.9744
# Fold 14 Epoch 500: TotalLoss=0.079943 | Sup=0.080214 | Unsup=-0.270787 | TrainAcc=0.9744
# Fold 14 Epoch 600: TotalLoss=0.044021 | Sup=0.044250 | Unsup=-0.229252 | TrainAcc=0.9872
# Fold 14 Epoch 700: TotalLoss=0.012292 | Sup=0.012514 | Unsup=-0.221978 | TrainAcc=1.0000
# Fold 14 Epoch 800: TotalLoss=0.019126 | Sup=0.019335 | Unsup=-0.209188 | TrainAcc=1.0000
# Fold 14 Epoch 900: TotalLoss=0.031305 | Sup=0.031524 | Unsup=-0.219024 | TrainAcc=0.9744
# Fold 14 Epoch 1000: TotalLoss=0.006932 | Sup=0.007124 | Unsup=-0.192115 | TrainAcc=1.0000
# Fold 14 Epoch 1100: TotalLoss=0.063864 | Sup=0.064075 | Unsup=-0.210775 | TrainAcc=0.9744
# Fold 14 Epoch 1200: TotalLoss=0.000937 | Sup=0.001145 | Unsup=-0.208867 | TrainAcc=1.0000
# Fold 14 Epoch 1300: TotalLoss=0.001654 | Sup=0.001877 | Unsup=-0.222362 | TrainAcc=1.0000
# Fold 14 Epoch 1400: TotalLoss=0.002986 | Sup=0.003200 | Unsup=-0.213866 | TrainAcc=1.0000
# Fold 14 Epoch 1500: TotalLoss=0.013220 | Sup=0.013427 | Unsup=-0.207593 | TrainAcc=0.9872
# Fold 14 Epoch 1600: TotalLoss=0.000408 | Sup=0.000599 | Unsup=-0.191377 | TrainAcc=1.0000
# Fold 14 Epoch 1700: TotalLoss=0.001145 | Sup=0.001363 | Unsup=-0.217832 | TrainAcc=1.0000
# Fold 14 Epoch 1800: TotalLoss=0.009720 | Sup=0.009913 | Unsup=-0.192890 | TrainAcc=1.0000
# Fold 14 Epoch 1900: TotalLoss=0.000361 | Sup=0.000559 | Unsup=-0.197299 | TrainAcc=1.0000
# Fold 14 Epoch 2000: TotalLoss=0.002120 | Sup=0.002309 | Unsup=-0.188816 | TrainAcc=1.0000
# Fold 14 → Acc=0.8832 | Prec=0.8969 | Rec=0.9493 | F1=0.9223 | AUC=0.9176 | CE Loss=0.7762
#
# === Fold 15 ===
# Fold 15 Epoch 1: TotalLoss=2.823243 | Sup=2.823435 | Unsup=-0.192065 | TrainAcc=0.2692
# Fold 15 Epoch 100: TotalLoss=0.514248 | Sup=0.514473 | Unsup=-0.224919 | TrainAcc=0.7564
# Fold 15 Epoch 200: TotalLoss=0.280611 | Sup=0.280842 | Unsup=-0.230522 | TrainAcc=0.9103
# Fold 15 Epoch 300: TotalLoss=0.213510 | Sup=0.213747 | Unsup=-0.236379 | TrainAcc=0.8974
# Fold 15 Epoch 400: TotalLoss=0.204081 | Sup=0.204300 | Unsup=-0.218832 | TrainAcc=0.9103
# Fold 15 Epoch 500: TotalLoss=0.177238 | Sup=0.177490 | Unsup=-0.251536 | TrainAcc=0.9359
# Fold 15 Epoch 600: TotalLoss=0.132198 | Sup=0.132410 | Unsup=-0.211281 | TrainAcc=0.9487
# Fold 15 Epoch 700: TotalLoss=0.062313 | Sup=0.062552 | Unsup=-0.239292 | TrainAcc=0.9744
# Fold 15 Epoch 800: TotalLoss=0.029651 | Sup=0.029881 | Unsup=-0.229217 | TrainAcc=1.0000
# Fold 15 Epoch 900: TotalLoss=0.035798 | Sup=0.036018 | Unsup=-0.220634 | TrainAcc=0.9744
# Fold 15 Epoch 1000: TotalLoss=0.020706 | Sup=0.020933 | Unsup=-0.226736 | TrainAcc=0.9872
# Fold 15 Epoch 1100: TotalLoss=0.043776 | Sup=0.043993 | Unsup=-0.217507 | TrainAcc=0.9744
# Fold 15 Epoch 1200: TotalLoss=0.004568 | Sup=0.004783 | Unsup=-0.215309 | TrainAcc=1.0000
# Fold 15 Epoch 1300: TotalLoss=0.011517 | Sup=0.011729 | Unsup=-0.212615 | TrainAcc=1.0000
# Fold 15 Epoch 1400: TotalLoss=0.007546 | Sup=0.007756 | Unsup=-0.210218 | TrainAcc=1.0000
# Fold 15 Epoch 1500: TotalLoss=0.004450 | Sup=0.004662 | Unsup=-0.211535 | TrainAcc=1.0000
# Fold 15 Epoch 1600: TotalLoss=0.004685 | Sup=0.004897 | Unsup=-0.211646 | TrainAcc=1.0000
# Fold 15 Epoch 1700: TotalLoss=0.000814 | Sup=0.001024 | Unsup=-0.210426 | TrainAcc=1.0000
# Fold 15 Epoch 1800: TotalLoss=0.012293 | Sup=0.012493 | Unsup=-0.200446 | TrainAcc=0.9872
# Fold 15 Epoch 1900: TotalLoss=0.018928 | Sup=0.019159 | Unsup=-0.231556 | TrainAcc=0.9872
# Fold 15 Epoch 2000: TotalLoss=0.001095 | Sup=0.001298 | Unsup=-0.203238 | TrainAcc=1.0000
# Fold 15 → Acc=0.8590 | Prec=0.8805 | Rec=0.9337 | F1=0.9063 | AUC=0.9012 | CE Loss=0.9207
#
# === Fold 16 ===
# Fold 16 Epoch 1: TotalLoss=1.173841 | Sup=1.174058 | Unsup=-0.217317 | TrainAcc=0.5897
# Fold 16 Epoch 100: TotalLoss=0.420180 | Sup=0.420434 | Unsup=-0.253675 | TrainAcc=0.8462
# Fold 16 Epoch 200: TotalLoss=0.221659 | Sup=0.221931 | Unsup=-0.271803 | TrainAcc=0.9231
# Fold 16 Epoch 300: TotalLoss=0.160992 | Sup=0.161265 | Unsup=-0.272353 | TrainAcc=0.9231
# Fold 16 Epoch 400: TotalLoss=0.064197 | Sup=0.064465 | Unsup=-0.267515 | TrainAcc=0.9744
# Fold 16 Epoch 500: TotalLoss=0.050677 | Sup=0.050932 | Unsup=-0.254606 | TrainAcc=0.9872
# Fold 16 Epoch 600: TotalLoss=0.036552 | Sup=0.036807 | Unsup=-0.255825 | TrainAcc=0.9872
# Fold 16 Epoch 700: TotalLoss=0.019537 | Sup=0.019797 | Unsup=-0.259827 | TrainAcc=1.0000
# Fold 16 Epoch 800: TotalLoss=0.002664 | Sup=0.002913 | Unsup=-0.249159 | TrainAcc=1.0000
# Fold 16 Epoch 900: TotalLoss=0.000440 | Sup=0.000696 | Unsup=-0.256541 | TrainAcc=1.0000
# Fold 16 Epoch 1000: TotalLoss=0.045167 | Sup=0.045445 | Unsup=-0.278733 | TrainAcc=0.9744
# Fold 16 Epoch 1100: TotalLoss=0.004804 | Sup=0.005055 | Unsup=-0.250771 | TrainAcc=1.0000
# Fold 16 Epoch 1200: TotalLoss=0.000755 | Sup=0.001016 | Unsup=-0.260722 | TrainAcc=1.0000
# Fold 16 Epoch 1300: TotalLoss=0.006431 | Sup=0.006697 | Unsup=-0.266008 | TrainAcc=1.0000
# Fold 16 Epoch 1400: TotalLoss=0.007692 | Sup=0.007957 | Unsup=-0.264342 | TrainAcc=1.0000
# Fold 16 Epoch 1500: TotalLoss=0.008756 | Sup=0.009007 | Unsup=-0.250774 | TrainAcc=1.0000
# Fold 16 Epoch 1600: TotalLoss=0.027412 | Sup=0.027649 | Unsup=-0.237913 | TrainAcc=0.9872
# Fold 16 Epoch 1700: TotalLoss=0.002637 | Sup=0.002870 | Unsup=-0.233611 | TrainAcc=1.0000
# Fold 16 Epoch 1800: TotalLoss=-0.000014 | Sup=0.000251 | Unsup=-0.265246 | TrainAcc=1.0000
# Fold 16 Epoch 1900: TotalLoss=0.000467 | Sup=0.000717 | Unsup=-0.250400 | TrainAcc=1.0000
# Fold 16 Epoch 2000: TotalLoss=0.000442 | Sup=0.000697 | Unsup=-0.254996 | TrainAcc=1.0000
# Fold 16 → Acc=0.8219 | Prec=0.8514 | Rec=0.9162 | F1=0.8826 | AUC=0.8467 | CE Loss=1.4436
#
# === Fold 17 ===
# Fold 17 Epoch 1: TotalLoss=1.042390 | Sup=1.042591 | Unsup=-0.200480 | TrainAcc=0.5897
# Fold 17 Epoch 100: TotalLoss=0.401602 | Sup=0.401860 | Unsup=-0.257874 | TrainAcc=0.7949
# Fold 17 Epoch 200: TotalLoss=0.179412 | Sup=0.179676 | Unsup=-0.264103 | TrainAcc=0.9103
# Fold 17 Epoch 300: TotalLoss=0.104000 | Sup=0.104258 | Unsup=-0.257748 | TrainAcc=0.9615
# Fold 17 Epoch 400: TotalLoss=0.035494 | Sup=0.035732 | Unsup=-0.237559 | TrainAcc=0.9872
# Fold 17 Epoch 500: TotalLoss=0.015368 | Sup=0.015600 | Unsup=-0.232232 | TrainAcc=1.0000
# Fold 17 Epoch 600: TotalLoss=0.007523 | Sup=0.007776 | Unsup=-0.252851 | TrainAcc=1.0000
# Fold 17 Epoch 700: TotalLoss=0.036640 | Sup=0.036911 | Unsup=-0.270274 | TrainAcc=0.9744
# Fold 17 Epoch 800: TotalLoss=0.003994 | Sup=0.004230 | Unsup=-0.236466 | TrainAcc=1.0000
# Fold 17 Epoch 900: TotalLoss=0.009221 | Sup=0.009458 | Unsup=-0.236565 | TrainAcc=1.0000
# Fold 17 Epoch 1000: TotalLoss=0.000491 | Sup=0.000721 | Unsup=-0.229388 | TrainAcc=1.0000
# Fold 17 Epoch 1100: TotalLoss=0.025083 | Sup=0.025328 | Unsup=-0.245441 | TrainAcc=0.9744
# Fold 17 Epoch 1200: TotalLoss=0.000896 | Sup=0.001124 | Unsup=-0.228809 | TrainAcc=1.0000
# Fold 17 Epoch 1300: TotalLoss=0.000779 | Sup=0.001010 | Unsup=-0.231214 | TrainAcc=1.0000
# Fold 17 Epoch 1400: TotalLoss=0.001772 | Sup=0.002028 | Unsup=-0.255859 | TrainAcc=1.0000
# Fold 17 Epoch 1500: TotalLoss=0.002371 | Sup=0.002601 | Unsup=-0.230227 | TrainAcc=1.0000
# Fold 17 Epoch 1600: TotalLoss=0.003081 | Sup=0.003331 | Unsup=-0.249561 | TrainAcc=1.0000
# Fold 17 Epoch 1700: TotalLoss=-0.000053 | Sup=0.000187 | Unsup=-0.239882 | TrainAcc=1.0000
# Fold 17 Epoch 1800: TotalLoss=0.001197 | Sup=0.001436 | Unsup=-0.238688 | TrainAcc=1.0000
# Fold 17 Epoch 1900: TotalLoss=0.005170 | Sup=0.005414 | Unsup=-0.243868 | TrainAcc=1.0000
# Fold 17 Epoch 2000: TotalLoss=0.000243 | Sup=0.000488 | Unsup=-0.245167 | TrainAcc=1.0000
# Fold 17 → Acc=0.8604 | Prec=0.8835 | Rec=0.9318 | F1=0.9070 | AUC=0.8773 | CE Loss=1.2668
#
# === Fold 18 ===
# Fold 18 Epoch 1: TotalLoss=1.628949 | Sup=1.629201 | Unsup=-0.252592 | TrainAcc=0.3590
# Fold 18 Epoch 100: TotalLoss=0.466569 | Sup=0.466779 | Unsup=-0.209352 | TrainAcc=0.7821
# Fold 18 Epoch 200: TotalLoss=0.359619 | Sup=0.359833 | Unsup=-0.214137 | TrainAcc=0.8590
# Fold 18 Epoch 300: TotalLoss=0.193045 | Sup=0.193266 | Unsup=-0.221147 | TrainAcc=0.9103
# Fold 18 Epoch 400: TotalLoss=0.155969 | Sup=0.156183 | Unsup=-0.214555 | TrainAcc=0.9359
# Fold 18 Epoch 500: TotalLoss=0.146772 | Sup=0.146962 | Unsup=-0.190559 | TrainAcc=0.9487
# Fold 18 Epoch 600: TotalLoss=0.060689 | Sup=0.060875 | Unsup=-0.185612 | TrainAcc=0.9615
# Fold 18 Epoch 700: TotalLoss=0.032426 | Sup=0.032629 | Unsup=-0.202933 | TrainAcc=1.0000
# Fold 18 Epoch 800: TotalLoss=0.050446 | Sup=0.050652 | Unsup=-0.206179 | TrainAcc=0.9615
# Fold 18 Epoch 900: TotalLoss=0.020585 | Sup=0.020806 | Unsup=-0.220915 | TrainAcc=1.0000
# Fold 18 Epoch 1000: TotalLoss=0.018120 | Sup=0.018313 | Unsup=-0.192737 | TrainAcc=1.0000
# Fold 18 Epoch 1100: TotalLoss=0.006235 | Sup=0.006444 | Unsup=-0.208725 | TrainAcc=1.0000
# Fold 18 Epoch 1200: TotalLoss=0.073265 | Sup=0.073451 | Unsup=-0.185949 | TrainAcc=0.9615
# Fold 18 Epoch 1300: TotalLoss=0.003206 | Sup=0.003395 | Unsup=-0.188914 | TrainAcc=1.0000
# Fold 18 Epoch 1400: TotalLoss=0.006642 | Sup=0.006839 | Unsup=-0.196634 | TrainAcc=1.0000
# Fold 18 Epoch 1500: TotalLoss=0.003962 | Sup=0.004152 | Unsup=-0.190167 | TrainAcc=1.0000
# Fold 18 Epoch 1600: TotalLoss=0.003388 | Sup=0.003572 | Unsup=-0.183657 | TrainAcc=1.0000
# Fold 18 Epoch 1700: TotalLoss=0.004030 | Sup=0.004247 | Unsup=-0.216484 | TrainAcc=1.0000
# Fold 18 Epoch 1800: TotalLoss=0.025675 | Sup=0.025885 | Unsup=-0.209540 | TrainAcc=0.9872
# Fold 18 Epoch 1900: TotalLoss=0.002311 | Sup=0.002500 | Unsup=-0.188927 | TrainAcc=1.0000
# Fold 18 Epoch 2000: TotalLoss=0.000921 | Sup=0.001120 | Unsup=-0.199042 | TrainAcc=1.0000
# Fold 18 → Acc=0.8647 | Prec=0.8989 | Rec=0.9181 | F1=0.9084 | AUC=0.8833 | CE Loss=0.9649
#
# === Fold 19 ===
# Fold 19 Epoch 1: TotalLoss=1.609656 | Sup=1.609950 | Unsup=-0.293943 | TrainAcc=0.3974
# Fold 19 Epoch 100: TotalLoss=0.492876 | Sup=0.493105 | Unsup=-0.229177 | TrainAcc=0.7692
# Fold 19 Epoch 200: TotalLoss=0.411401 | Sup=0.411624 | Unsup=-0.223429 | TrainAcc=0.8846
# Fold 19 Epoch 300: TotalLoss=0.258765 | Sup=0.258999 | Unsup=-0.234713 | TrainAcc=0.8462
# Fold 19 Epoch 400: TotalLoss=0.183128 | Sup=0.183352 | Unsup=-0.223315 | TrainAcc=0.9231
# Fold 19 Epoch 500: TotalLoss=0.058218 | Sup=0.058424 | Unsup=-0.206044 | TrainAcc=0.9872
# Fold 19 Epoch 600: TotalLoss=0.068044 | Sup=0.068250 | Unsup=-0.206456 | TrainAcc=0.9744
# Fold 19 Epoch 700: TotalLoss=0.023468 | Sup=0.023681 | Unsup=-0.212790 | TrainAcc=1.0000
# Fold 19 Epoch 800: TotalLoss=0.034453 | Sup=0.034686 | Unsup=-0.232324 | TrainAcc=0.9872
# Fold 19 Epoch 900: TotalLoss=0.015054 | Sup=0.015250 | Unsup=-0.195378 | TrainAcc=1.0000
# Fold 19 Epoch 1000: TotalLoss=0.020576 | Sup=0.020772 | Unsup=-0.195370 | TrainAcc=0.9872
# Fold 19 Epoch 1100: TotalLoss=0.009861 | Sup=0.010074 | Unsup=-0.213707 | TrainAcc=1.0000
# Fold 19 Epoch 1200: TotalLoss=0.009367 | Sup=0.009555 | Unsup=-0.188599 | TrainAcc=1.0000
# Fold 19 Epoch 1300: TotalLoss=0.001789 | Sup=0.002003 | Unsup=-0.214350 | TrainAcc=1.0000
# Fold 19 Epoch 1400: TotalLoss=0.032851 | Sup=0.033041 | Unsup=-0.190201 | TrainAcc=0.9872
# Fold 19 Epoch 1500: TotalLoss=0.014772 | Sup=0.014964 | Unsup=-0.192174 | TrainAcc=0.9872
# Fold 19 Epoch 1600: TotalLoss=0.010233 | Sup=0.010443 | Unsup=-0.210595 | TrainAcc=1.0000
# Fold 19 Epoch 1700: TotalLoss=0.000895 | Sup=0.001096 | Unsup=-0.201591 | TrainAcc=1.0000
# Fold 19 Epoch 1800: TotalLoss=0.025661 | Sup=0.025867 | Unsup=-0.205837 | TrainAcc=0.9872
# Fold 19 Epoch 1900: TotalLoss=0.002544 | Sup=0.002729 | Unsup=-0.184984 | TrainAcc=1.0000
# Fold 19 Epoch 2000: TotalLoss=0.043503 | Sup=0.043702 | Unsup=-0.199119 | TrainAcc=0.9872
# Fold 19 → Acc=0.8618 | Prec=0.8881 | Rec=0.9279 | F1=0.9075 | AUC=0.9099 | CE Loss=0.7588
#
# === Fold 20 ===
# Fold 20 Epoch 1: TotalLoss=0.857555 | Sup=0.857766 | Unsup=-0.211203 | TrainAcc=0.7051
# Fold 20 Epoch 100: TotalLoss=0.461678 | Sup=0.461918 | Unsup=-0.239352 | TrainAcc=0.8077
# Fold 20 Epoch 200: TotalLoss=0.151952 | Sup=0.152181 | Unsup=-0.229765 | TrainAcc=0.9615
# Fold 20 Epoch 300: TotalLoss=0.181414 | Sup=0.181655 | Unsup=-0.241749 | TrainAcc=0.9231
# Fold 20 Epoch 400: TotalLoss=0.145841 | Sup=0.146057 | Unsup=-0.216891 | TrainAcc=0.9359
# Fold 20 Epoch 500: TotalLoss=0.090586 | Sup=0.090785 | Unsup=-0.199165 | TrainAcc=0.9872
# Fold 20 Epoch 600: TotalLoss=0.025496 | Sup=0.025725 | Unsup=-0.229304 | TrainAcc=0.9872
# Fold 20 Epoch 700: TotalLoss=0.016024 | Sup=0.016223 | Unsup=-0.198278 | TrainAcc=1.0000
# Fold 20 Epoch 800: TotalLoss=0.008005 | Sup=0.008199 | Unsup=-0.194478 | TrainAcc=1.0000
# Fold 20 Epoch 900: TotalLoss=0.003555 | Sup=0.003755 | Unsup=-0.200548 | TrainAcc=1.0000
# Fold 20 Epoch 1000: TotalLoss=0.009685 | Sup=0.009879 | Unsup=-0.193413 | TrainAcc=1.0000
# Fold 20 Epoch 1100: TotalLoss=0.008612 | Sup=0.008813 | Unsup=-0.201457 | TrainAcc=1.0000
# Fold 20 Epoch 1200: TotalLoss=0.006360 | Sup=0.006573 | Unsup=-0.212643 | TrainAcc=1.0000
# Fold 20 Epoch 1300: TotalLoss=0.001594 | Sup=0.001784 | Unsup=-0.190539 | TrainAcc=1.0000
# Fold 20 Epoch 1400: TotalLoss=0.003104 | Sup=0.003352 | Unsup=-0.247743 | TrainAcc=1.0000
# Fold 20 Epoch 1500: TotalLoss=0.067214 | Sup=0.067466 | Unsup=-0.251727 | TrainAcc=0.9744
# Fold 20 Epoch 1600: TotalLoss=0.000143 | Sup=0.000349 | Unsup=-0.206526 | TrainAcc=1.0000
# Fold 20 Epoch 1700: TotalLoss=0.000616 | Sup=0.000814 | Unsup=-0.198061 | TrainAcc=1.0000
# Fold 20 Epoch 1800: TotalLoss=0.009326 | Sup=0.009511 | Unsup=-0.185123 | TrainAcc=1.0000
# Fold 20 Epoch 1900: TotalLoss=0.002719 | Sup=0.002914 | Unsup=-0.194266 | TrainAcc=1.0000
# Fold 20 Epoch 2000: TotalLoss=0.000361 | Sup=0.000552 | Unsup=-0.191102 | TrainAcc=1.0000
# Fold 20 → Acc=0.8647 | Prec=0.8732 | Rec=0.9532 | F1=0.9115 | AUC=0.9046 | CE Loss=0.8607
#
# === Average Results Across 20 Folds ===
# Accuracy:  0.8441 ± 0.0227
# Precision: 0.8772 ± 0.0200
# Recall:    0.9155 ± 0.0293
# F1-score:  0.8955 ± 0.0158
# AUC:       0.8793 ± 0.0264
# CE Loss:   1.0333 ± 0.2071
