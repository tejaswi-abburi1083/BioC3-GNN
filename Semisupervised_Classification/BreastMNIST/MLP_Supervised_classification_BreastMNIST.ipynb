# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install numpy scikit-learn
# !pip install -q torch_geometric
# !pip install -q class_resolver
# !pip3 install pymatting
# !pip install opencv-python
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 29.8 MB/s eta 0:00:00
# Collecting pymatting
#   Downloading pymatting-1.1.14-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from pymatting) (2.0.2)
# Requirement already satisfied: pillow>=5.2.0 in /usr/local/lib/python3.12/dist-packages (from pymatting) (11.3.0)
# Requirement already satisfied: numba!=0.49.0 in /usr/local/lib/python3.12/dist-packages (from pymatting) (0.60.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from pymatting) (1.16.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba!=0.49.0->pymatting) (0.43.0)
# Downloading pymatting-1.1.14-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.7/54.7 kB 2.4 MB/s eta 0:00:00
# Installing collected packages: pymatting
# Successfully installed pymatting-1.1.14
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (4.12.0.88)
# Requirement already satisfied: numpy<2.3.0,>=2 in /usr/local/lib/python3.12/dist-packages (from opencv-python) (2.0.2)

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, log_loss
from sklearn.model_selection import StratifiedShuffleSplit
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc, roc_auc_score
import torch
import torch.nn as nn
import torch.nn.functional as nnFn
import torch.optim as optim
import numpy as np
import random
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from torch.utils.data import TensorDataset, DataLoader, Subset
from torch_geometric.data import Data

# %%
data = np.load('/home/snu/Downloads/breastmnist_224.npz', allow_pickle=True)
all_images = np.concatenate([data['train_images'], data['val_images'], data['test_images']], axis=0)
all_labels = np.concatenate([data['train_labels'], data['val_labels'], data['test_labels']], axis=0).squeeze()

# Convert to 3-channel RGB
images = all_images.astype(np.float32) / 255.0
images = np.repeat(images[:, None, :, :], 3, axis=1)  # (N, 3, 224, 224)
X_torch = torch.tensor(images)
y_torch = torch.tensor(all_labels).long()

print(f"Raw images: {X_torch.shape}, Labels: {y_torch.shape}")
# Out:
# Raw images: torch.Size([780, 3, 224, 224]), Labels: torch.Size([780])

# %%
class0_idx = [i for i in range(len(y_torch)) if y_torch[i] == 0]
class1_idx = [i for i in range(len(y_torch)) if y_torch[i] == 1]

random.seed(42)
sampled_class0 = random.sample(class0_idx, min(1000, len(class0_idx)))
sampled_class1 = random.sample(class1_idx, min(1000, len(class1_idx)))

selected_indices = sampled_class0 + sampled_class1
random.shuffle(selected_indices)

subset_dataset = Subset(TensorDataset(X_torch, y_torch), selected_indices)
subset_loader = DataLoader(subset_dataset, batch_size=32, shuffle=False)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
vit = torch.hub.load('facebookresearch/dino:main', 'dino_vitb16')
vit.eval().to(device)

vit_feats, y_list = [], []

with torch.no_grad():
    for imgs, lbls in subset_loader:
        imgs = imgs.to(device)
        feats = vit(imgs)
        vit_feats.append(feats.cpu())
        y_list.extend(lbls.cpu().tolist())

F = torch.cat(vit_feats, dim=0).numpy().astype(np.float32)
y = np.array(y_list).astype(np.int64)

num_nodes, num_feats = F.shape
print(f"Extracted ViT-DINO Features: {F.shape}, Labels: {y.shape}")
# Out:
# Using cache found in /home/snu/.cache/torch/hub/facebookresearch_dino_main
# Extracted ViT-DINO Features: (780, 768), Labels: (780,)

# %%
scaler = StandardScaler()
X = scaler.fit_transform(F)

# %%
# 20 Stratified Shuffle Splits
sss = StratifiedShuffleSplit(n_splits=20, test_size=0.9, random_state=42)

# %%
# Storage for metrics
accuracies, precisions, recalls, f1_scores, losses = [], [], [], [], []

# %%
all_y_true = []
all_y_proba = []
all_fpr = []
all_tpr = []
all_auc = []
# Cross-validation loop
for fold, (train_idx, test_idx) in enumerate(sss.split(X, y)):
    print(f"\nTraining fold {fold + 1}")

    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]

    # MLP model (tuned for performance)
    mlp = MLPClassifier(hidden_layer_sizes=(512,),
                        activation='relu', solver='adam',
                        alpha=1e-3, max_iter=1000, random_state=42)

    mlp.fit(X_train, y_train)

    y_pred = mlp.predict(X_test)
    y_pred_proba = mlp.predict_proba(X_test)[:, 1]

    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    loss = log_loss(y_test, y_pred_proba)
    auc_score = roc_auc_score(y_test, y_pred_proba)

    accuracies.append(accuracy)
    precisions.append(precision)
    recalls.append(recall)
    f1_scores.append(f1)
    losses.append(loss)
    all_y_true.extend(y_test)
    all_y_proba.extend(y_pred_proba)

    fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
    all_fpr.append(fpr)
    all_tpr.append(tpr)
    all_auc.append(auc_score)

    print(f"Accuracy: {accuracy:.4f} | Precision: {precision:.4f} | Recall: {recall:.4f} | F1: {f1:.4f} | Loss: {loss:.4f} | AUC: {auc_score:.4f}")

# Final average results
print("\nAverage Results across 20 folds:")
print(f"Accuracy: {np.mean(accuracies):.4f} ± {np.std(accuracies):.4f}")
print(f"Precision: {np.mean(precisions):.4f} ± {np.std(precisions):.4f}")
print(f"Recall: {np.mean(recalls):.4f} ± {np.std(recalls):.4f}")
print(f"F1 Score: {np.mean(f1_scores):.4f} ± {np.std(f1_scores):.4f}")
print(f"Cross-Entropy Loss: {np.mean(losses):.4f} ± {np.std(losses):.4f}")
print(f"Average AUC: {np.mean(all_auc):.4f} ± {np.std(all_auc):.4f}")
# Out:
# Training fold 1
# Accuracy: 0.8262 | Precision: 0.8871 | Recall: 0.8733 | F1: 0.8802 | Loss: 0.6114 | AUC: 0.8740
#
# Training fold 2
# Accuracy: 0.8476 | Precision: 0.9060 | Recall: 0.8830 | F1: 0.8944 | Loss: 0.5877 | AUC: 0.8972
#
# Training fold 3
# Accuracy: 0.8120 | Precision: 0.8896 | Recall: 0.8480 | F1: 0.8683 | Loss: 0.6354 | AUC: 0.8827
#
# Training fold 4
# Accuracy: 0.7977 | Precision: 0.8354 | Recall: 0.9006 | F1: 0.8668 | Loss: 0.7397 | AUC: 0.8207
#
# Training fold 5
# Accuracy: 0.8305 | Precision: 0.8893 | Recall: 0.8772 | F1: 0.8832 | Loss: 0.8527 | AUC: 0.8325
#
# Training fold 6
# Accuracy: 0.8519 | Precision: 0.9098 | Recall: 0.8850 | F1: 0.8972 | Loss: 0.5084 | AUC: 0.8991
#
# Training fold 7
# Accuracy: 0.8148 | Precision: 0.9015 | Recall: 0.8382 | F1: 0.8687 | Loss: 0.7068 | AUC: 0.8836
#
# Training fold 8
# Accuracy: 0.8447 | Precision: 0.9122 | Recall: 0.8713 | F1: 0.8913 | Loss: 0.4440 | AUC: 0.9150
#
# Training fold 9
# Accuracy: 0.8419 | Precision: 0.9052 | Recall: 0.8752 | F1: 0.8900 | Loss: 0.5766 | AUC: 0.8929
#
# Training fold 10
# Accuracy: 0.7963 | Precision: 0.9004 | Recall: 0.8109 | F1: 0.8533 | Loss: 0.7680 | AUC: 0.8671
#
# Training fold 11
# Accuracy: 0.8376 | Precision: 0.9236 | Recall: 0.8480 | F1: 0.8841 | Loss: 0.7314 | AUC: 0.8860
#
# Training fold 12
# Accuracy: 0.8447 | Precision: 0.9191 | Recall: 0.8635 | F1: 0.8905 | Loss: 0.5432 | AUC: 0.8964
#
# Training fold 13
# Accuracy: 0.8091 | Precision: 0.8680 | Recall: 0.8713 | F1: 0.8696 | Loss: 0.7705 | AUC: 0.8536
#
# Training fold 14
# Accuracy: 0.8519 | Precision: 0.8986 | Recall: 0.8986 | F1: 0.8986 | Loss: 0.4930 | AUC: 0.8995
#
# Training fold 15
# Accuracy: 0.8447 | Precision: 0.9056 | Recall: 0.8791 | F1: 0.8922 | Loss: 0.5200 | AUC: 0.9055
#
# Training fold 16
# Accuracy: 0.8262 | Precision: 0.8949 | Recall: 0.8635 | F1: 0.8790 | Loss: 0.6201 | AUC: 0.8800
#
# Training fold 17
# Accuracy: 0.8362 | Precision: 0.8917 | Recall: 0.8830 | F1: 0.8874 | Loss: 0.8253 | AUC: 0.8640
#
# Training fold 18
# Accuracy: 0.8205 | Precision: 0.8941 | Recall: 0.8558 | F1: 0.8745 | Loss: 0.6850 | AUC: 0.8814
#
# Training fold 19
# Accuracy: 0.8333 | Precision: 0.8976 | Recall: 0.8713 | F1: 0.8843 | Loss: 0.4821 | AUC: 0.8958
#
# Training fold 20
# Accuracy: 0.8405 | Precision: 0.9100 | Recall: 0.8674 | F1: 0.8882 | Loss: 0.4932 | AUC: 0.9046
#
# Average Results across 20 folds:
# Accuracy: 0.8304 ± 0.0167
# Precision: 0.8970 ± 0.0186
# Recall: 0.8682 ± 0.0203
# F1 Score: 0.8821 ± 0.0116
# Cross-Entropy Loss: 0.6297 ± 0.1207
# Average AUC: 0.8816 ± 0.0236

# %%
plt.figure(figsize=(8, 6))

for i in range(len(all_fpr)):
    plt.plot(all_fpr[i], all_tpr[i], alpha=0.3, label=f"Fold {i+1} AUC = {all_auc[i]:.2f}")

# Average ROC Curve
fpr_avg, tpr_avg, _ = roc_curve(all_y_true, all_y_proba)
auc_avg = roc_auc_score(all_y_true, all_y_proba)
plt.plot(fpr_avg, tpr_avg, color='blue', lw=2, label=f"Mean ROC (AUC = {auc_avg:.2f})")

# Diagonal line
plt.plot([0, 1], [0, 1], 'k--', label="Chance")
plt.xlabel("False Positive Rate", fontsize=16)
plt.ylabel("True Positive Rate", fontsize=16)
plt.title("ROC Curve Across 20 Folds (MLP)", fontsize=18)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend(loc="lower right", fontsize=9)
plt.grid(True)
