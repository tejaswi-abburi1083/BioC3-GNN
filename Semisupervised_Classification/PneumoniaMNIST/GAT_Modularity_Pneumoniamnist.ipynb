# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install numpy scikit-learn
# !pip install -q torch_geometric
# !pip install -q class_resolver
# !pip3 install pymatting
# !pip install opencv-python
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 26.2 MB/s eta 0:00:00
# Collecting pymatting
#   Downloading pymatting-1.1.14-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from pymatting) (2.0.2)
# Requirement already satisfied: pillow>=5.2.0 in /usr/local/lib/python3.12/dist-packages (from pymatting) (11.3.0)
# Requirement already satisfied: numba!=0.49.0 in /usr/local/lib/python3.12/dist-packages (from pymatting) (0.60.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from pymatting) (1.16.3)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba!=0.49.0->pymatting) (0.43.0)
# Downloading pymatting-1.1.14-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.7/54.7 kB 2.7 MB/s eta 0:00:00
# Installing collected packages: pymatting
# Successfully installed pymatting-1.1.14
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (4.12.0.88)
# Requirement already satisfied: numpy<2.3.0,>=2 in /usr/local/lib/python3.12/dist-packages (from opencv-python) (2.0.2)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as nnFn
import torch.optim as optim
import numpy as np
import random
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from torch_geometric.data import Data
from torch_geometric.nn import ARMAConv
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, roc_auc_score, log_loss
)
from torch.utils.data import TensorDataset, DataLoader, Subset
from torch_geometric.data import Data
from torch_geometric.nn import GATConv
from torch.utils.data import TensorDataset, DataLoader, Subset
from torchvision import models

# %%
import torch
print("CUDA available:", torch.cuda.is_available())
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("GPU Name:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU")
# Out:
# CUDA available: True
# GPU Name: NVIDIA A100-SXM4-40GB

# %%
data = np.load('/content/drive/MyDrive/TejaswiAbburi_va797/Dataset/Medmnist_data/pneumoniamnist_224.npz', allow_pickle=True)
all_images = np.concatenate([data['train_images'], data['val_images'], data['test_images']], axis=0)
all_labels = np.concatenate([data['train_labels'], data['val_labels'], data['test_labels']], axis=0).squeeze()

# Convert to 3-channel RGB
images = all_images.astype(np.float32) / 255.0
images = np.repeat(images[:, None, :, :], 3, axis=1)  # (N, 3, 224, 224)
X_torch = torch.tensor(images)
y_torch = torch.tensor(all_labels).long()
print(f"Raw images: {X_torch.shape}, Labels: {y_torch.shape}")
# Out:
# Raw images: torch.Size([5856, 3, 224, 224]), Labels: torch.Size([5856])

# %%
class0_idx = [i for i in range(len(y_torch)) if y_torch[i] == 0]
class1_idx = [i for i in range(len(y_torch)) if y_torch[i] == 1]

random.seed(42)
sampled_class0 = random.sample(class0_idx, min(2000, len(class0_idx)))
sampled_class1 = random.sample(class1_idx, min(2000, len(class1_idx)))

selected_indices = sampled_class0 + sampled_class1
random.shuffle(selected_indices)

subset_dataset = Subset(TensorDataset(X_torch, y_torch), selected_indices)
subset_loader = DataLoader(subset_dataset, batch_size=32, shuffle=False)

# %%
resnet = models.resnet18(pretrained=True)
resnet.fc = nn.Identity()
resnet = resnet.to(device)
resnet.eval()

resnet_feats = []
y_list = []
with torch.no_grad():
    for imgs, labels in subset_loader:
        imgs = imgs.to(device)
        feats = resnet(imgs)
        resnet_feats.append(feats.cpu())
        y_list.extend(labels.cpu().tolist())

features = torch.cat(resnet_feats, dim=0).numpy().astype(np.float32)  # shape (N, feat_dim)
y_labels = np.array(y_list).astype(np.float32)
print("Feature shape:", features.shape, "Label shape:", y_labels.shape)
# Out:
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 189MB/s]
# Feature shape: (3583, 512) Label shape: (3583,)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as nnFn
from torch_geometric.nn import GATConv


class GAT_SemiSupervised(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, device, heads=2, activ="RELU", dropout=0.25):
        super(GAT_SemiSupervised, self).__init__()
        self.device = device

        # GAT layer
        self.conv1 = GATConv(input_dim, hidden_dim, heads=heads, concat=True, dropout=dropout)
        self.bn1 = nn.BatchNorm1d(hidden_dim * heads)  # heads multiply feature dimension if concat=True
        self.dropout = nn.Dropout(dropout)
        self.fc = nn.Linear(hidden_dim * heads, output_dim)

        # Activation mapping
        activations = {
            "SELU": nnFn.selu,
            "SiLU": nnFn.silu,
            "GELU": nnFn.gelu,
            "RELU": nnFn.relu,
            "ELU": nnFn.elu
        }
        self.act = activations.get(activ, nnFn.elu)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index

        # GAT layer
        x = self.conv1(x, edge_index)
        x = self.bn1(x)
        x = self.act(x)
        x = self.dropout(x)

        logits = self.fc(x)
        return logits

    def modularity_loss(self, A, logits):
        S = nnFn.softmax(logits, dim=1)
        d = torch.sum(A, dim=1)
        m = torch.sum(A)
        B = A - torch.outer(d, d) / (2 * m + 1e-12)

        modularity_term = (-1 / (2 * m + 1e-12)) * torch.trace(S.T @ B @ S)
        # Collapse regularization
        I_S = torch.eye(S.shape[1], device=self.device)
        k = torch.norm(I_S)
        n = S.shape[0]
        collapse_reg = (torch.sqrt(k) / n) * torch.norm(torch.sum(S, dim=0), p='fro') - 1
        entropy_reg = -torch.mean(torch.sum(S * torch.log(S + 1e-9), dim=1))
        return modularity_term + 0.1 * collapse_reg + 0.01 * entropy_reg

# %%
def create_adj(F, alpha=1):
    F_norm = F / np.linalg.norm(F, axis=1, keepdims=True)
    W = np.dot(F_norm, F_norm.T)
    W = np.where(W >= alpha, 1, 0).astype(np.float32)
    W = W / W.max()
    return W

def load_data(adj, node_feats):
    node_feats = torch.from_numpy(node_feats).float()
    edge_index = torch.from_numpy(np.array(np.nonzero((adj > 0))))
    return Data(x=node_feats, edge_index=edge_index)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
alpha = 0.9
feats_dim = features.shape[1]
hidden_dim = 256
num_classes = 2
num_epochs = 2000
lr = 0.0001
weight_decay = 1e-4
batch_print_freq = 500
lambda_mod = 0.1  #0.2 #0.001  # weight for modularity loss
# lambda_sup = 1.0

# %%
W = create_adj(features, alpha)
data = load_data(W, features).to(device)
print(data)
# Out:
# Data(x=[3583, 512], edge_index=[2, 1642257])

# %%
sss = StratifiedShuffleSplit(n_splits=20, test_size=0.9, random_state=42)

accuracies, precisions, recalls, f1_scores, aucs, ce_losses = [], [], [], [], [], []

for fold, (train_idx, test_idx) in enumerate(sss.split(features, y_labels.astype(np.int64)), start=1):
    print(f"\n=== Fold {fold} ===")

    # Convert to tensors
    train_idx_t = torch.from_numpy(train_idx).long().to(device)
    y_train_tensor = torch.from_numpy(y_labels[train_idx]).long().to(device)
    A_tensor = torch.from_numpy(W).float().to(device)

    # Initialize model
    model = GAT_SemiSupervised(feats_dim, hidden_dim, num_classes, device, activ="RELU").to(device)
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    ce_loss = nn.CrossEntropyLoss()

    # Training
    for epoch in range(1, num_epochs + 1):
        model.train()
        optimizer.zero_grad()

        logits = model(data)
        loss_sup = ce_loss(logits[train_idx_t], y_train_tensor)
        loss_unsup = model.modularity_loss(A_tensor, logits)
        total_loss = loss_sup + lambda_mod * loss_unsup

        total_loss.backward()
        optimizer.step()

        if epoch % batch_print_freq == 0 or epoch == 1:
            model.eval()
            with torch.no_grad():
                preds_train = logits[train_idx_t].argmax(dim=1)
                acc_train = accuracy_score(y_train_tensor.cpu(), preds_train.cpu())
            print(f"Fold {fold} Epoch {epoch}: "
                  f"TotalLoss={total_loss.item():.6f} | Sup={loss_sup.item():.6f} | "
                  f"Unsup={loss_unsup.item():.6f} | TrainAcc={acc_train:.4f}")

    # Evaluation
    model.eval()
    with torch.no_grad():
        out = model(data)
        preds = out.argmax(dim=1).cpu().numpy()
        probs = torch.softmax(out, dim=1)[:, 1].cpu().numpy()  # Probability for class 1

    y_test = y_labels[test_idx]
    y_pred_test = preds[test_idx]
    y_prob_test = probs[test_idx]

    acc = accuracy_score(y_test, y_pred_test)
    prec = precision_score(y_test, y_pred_test, zero_division=0)
    rec = recall_score(y_test, y_pred_test, zero_division=0)
    f1 = f1_score(y_test, y_pred_test, zero_division=0)
    auc = roc_auc_score(y_test, y_prob_test)
    ce = log_loss(y_test, y_prob_test)

    accuracies.append(acc)
    precisions.append(prec)
    recalls.append(rec)
    f1_scores.append(f1)
    aucs.append(auc)
    ce_losses.append(ce)

    print(f"Fold {fold} → "
          f"Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | "
          f"F1={f1:.4f} | AUC={auc:.4f} | CE Loss={ce:.4f}")


# Final summary
print("\n=== Average Results Across 20 Folds ===")
print(f"Accuracy:  {np.mean(accuracies):.4f} ± {np.std(accuracies):.4f}")
print(f"Precision: {np.mean(precisions):.4f} ± {np.std(precisions):.4f}")
print(f"Recall:    {np.mean(recalls):.4f} ± {np.std(recalls):.4f}")
print(f"F1-score:  {np.mean(f1_scores):.4f} ± {np.std(f1_scores):.4f}")
print(f"AUC:       {np.mean(aucs):.4f} ± {np.std(aucs):.4f}")
print(f"CE Loss:   {np.mean(ce_losses):.4f} ± {np.std(ce_losses):.4f}")
# Out:
# === Fold 1 ===
# Fold 1 Epoch 1: TotalLoss=0.874316 | Sup=0.888106 | Unsup=-0.137902 | TrainAcc=0.4441
# Fold 1 Epoch 500: TotalLoss=-0.026247 | Sup=0.004714 | Unsup=-0.309610 | TrainAcc=1.0000
# Fold 1 Epoch 1000: TotalLoss=-0.030229 | Sup=0.001035 | Unsup=-0.312634 | TrainAcc=1.0000
# Fold 1 Epoch 1500: TotalLoss=-0.030988 | Sup=0.000547 | Unsup=-0.315358 | TrainAcc=1.0000
# Fold 1 Epoch 2000: TotalLoss=-0.031228 | Sup=0.000450 | Unsup=-0.316780 | TrainAcc=1.0000
# Fold 1 → Acc=0.9343 | Prec=0.9638 | Rec=0.9167 | F1=0.9396 | AUC=0.9786 | CE Loss=0.3496
#
# === Fold 2 ===
# Fold 2 Epoch 1: TotalLoss=0.590776 | Sup=0.604639 | Unsup=-0.138633 | TrainAcc=0.7486
# Fold 2 Epoch 500: TotalLoss=-0.028009 | Sup=0.002927 | Unsup=-0.309361 | TrainAcc=1.0000
# Fold 2 Epoch 1000: TotalLoss=-0.030583 | Sup=0.000869 | Unsup=-0.314516 | TrainAcc=1.0000
# Fold 2 Epoch 1500: TotalLoss=-0.031196 | Sup=0.000399 | Unsup=-0.315950 | TrainAcc=1.0000
# Fold 2 Epoch 2000: TotalLoss=-0.031378 | Sup=0.000322 | Unsup=-0.316999 | TrainAcc=1.0000
# Fold 2 → Acc=0.9321 | Prec=0.9551 | Rec=0.9217 | F1=0.9381 | AUC=0.9747 | CE Loss=0.3761
#
# === Fold 3 ===
# Fold 3 Epoch 1: TotalLoss=0.507715 | Sup=0.522564 | Unsup=-0.148491 | TrainAcc=0.8045
# Fold 3 Epoch 500: TotalLoss=-0.026284 | Sup=0.004682 | Unsup=-0.309662 | TrainAcc=1.0000
# Fold 3 Epoch 1000: TotalLoss=-0.029773 | Sup=0.001464 | Unsup=-0.312379 | TrainAcc=1.0000
# Fold 3 Epoch 1500: TotalLoss=-0.030912 | Sup=0.000596 | Unsup=-0.315072 | TrainAcc=1.0000
# Fold 3 Epoch 2000: TotalLoss=-0.031017 | Sup=0.000658 | Unsup=-0.316748 | TrainAcc=1.0000
# Fold 3 → Acc=0.9358 | Prec=0.9617 | Rec=0.9217 | F1=0.9413 | AUC=0.9800 | CE Loss=0.3287
#
# === Fold 4 ===
# Fold 4 Epoch 1: TotalLoss=0.790585 | Sup=0.804257 | Unsup=-0.136722 | TrainAcc=0.4693
# Fold 4 Epoch 500: TotalLoss=-0.027055 | Sup=0.003981 | Unsup=-0.310364 | TrainAcc=1.0000
# Fold 4 Epoch 1000: TotalLoss=-0.030518 | Sup=0.001062 | Unsup=-0.315799 | TrainAcc=1.0000
# Fold 4 Epoch 1500: TotalLoss=-0.031309 | Sup=0.000454 | Unsup=-0.317624 | TrainAcc=1.0000
# Fold 4 Epoch 2000: TotalLoss=-0.031133 | Sup=0.000726 | Unsup=-0.318582 | TrainAcc=1.0000
# Fold 4 → Acc=0.9293 | Prec=0.9596 | Rec=0.9117 | F1=0.9350 | AUC=0.9783 | CE Loss=0.3581
#
# === Fold 5 ===
# Fold 5 Epoch 1: TotalLoss=0.673978 | Sup=0.687423 | Unsup=-0.134449 | TrainAcc=0.5615
# Fold 5 Epoch 500: TotalLoss=-0.026592 | Sup=0.004490 | Unsup=-0.310825 | TrainAcc=1.0000
# Fold 5 Epoch 1000: TotalLoss=-0.030456 | Sup=0.001075 | Unsup=-0.315315 | TrainAcc=1.0000
# Fold 5 Epoch 1500: TotalLoss=-0.031219 | Sup=0.000481 | Unsup=-0.317005 | TrainAcc=1.0000
# Fold 5 Epoch 2000: TotalLoss=-0.031295 | Sup=0.000519 | Unsup=-0.318138 | TrainAcc=1.0000
# Fold 5 → Acc=0.9259 | Prec=0.9616 | Rec=0.9033 | F1=0.9315 | AUC=0.9717 | CE Loss=0.4123
#
# === Fold 6 ===
# Fold 6 Epoch 1: TotalLoss=0.763632 | Sup=0.777383 | Unsup=-0.137506 | TrainAcc=0.4637
# Fold 6 Epoch 500: TotalLoss=-0.024245 | Sup=0.006682 | Unsup=-0.309270 | TrainAcc=1.0000
# Fold 6 Epoch 1000: TotalLoss=-0.029382 | Sup=0.001965 | Unsup=-0.313465 | TrainAcc=1.0000
# Fold 6 Epoch 1500: TotalLoss=-0.029275 | Sup=0.002034 | Unsup=-0.313091 | TrainAcc=1.0000
# Fold 6 Epoch 2000: TotalLoss=-0.030839 | Sup=0.000669 | Unsup=-0.315083 | TrainAcc=1.0000
# Fold 6 → Acc=0.9352 | Prec=0.9710 | Rec=0.9111 | F1=0.9401 | AUC=0.9825 | CE Loss=0.3252
#
# === Fold 7 ===
# Fold 7 Epoch 1: TotalLoss=0.558186 | Sup=0.572327 | Unsup=-0.141407 | TrainAcc=0.6425
# Fold 7 Epoch 500: TotalLoss=-0.026144 | Sup=0.004052 | Unsup=-0.301955 | TrainAcc=1.0000
# Fold 7 Epoch 1000: TotalLoss=-0.029778 | Sup=0.001220 | Unsup=-0.309979 | TrainAcc=1.0000
# Fold 7 Epoch 1500: TotalLoss=-0.030671 | Sup=0.000536 | Unsup=-0.312067 | TrainAcc=1.0000
# Fold 7 Epoch 2000: TotalLoss=-0.030805 | Sup=0.000541 | Unsup=-0.313463 | TrainAcc=1.0000
# Fold 7 → Acc=0.9321 | Prec=0.9604 | Rec=0.9161 | F1=0.9377 | AUC=0.9763 | CE Loss=0.3563
#
# === Fold 8 ===
# Fold 8 Epoch 1: TotalLoss=0.793405 | Sup=0.806934 | Unsup=-0.135292 | TrainAcc=0.3631
# Fold 8 Epoch 500: TotalLoss=-0.026556 | Sup=0.004126 | Unsup=-0.306823 | TrainAcc=1.0000
# Fold 8 Epoch 1000: TotalLoss=-0.030105 | Sup=0.001183 | Unsup=-0.312880 | TrainAcc=1.0000
# Fold 8 Epoch 1500: TotalLoss=-0.031061 | Sup=0.000532 | Unsup=-0.315929 | TrainAcc=1.0000
# Fold 8 Epoch 2000: TotalLoss=-0.031439 | Sup=0.000309 | Unsup=-0.317484 | TrainAcc=1.0000
# Fold 8 → Acc=0.9380 | Prec=0.9520 | Rec=0.9361 | F1=0.9440 | AUC=0.9781 | CE Loss=0.3430
#
# === Fold 9 ===
# Fold 9 Epoch 1: TotalLoss=0.741050 | Sup=0.756684 | Unsup=-0.156338 | TrainAcc=0.5866
# Fold 9 Epoch 500: TotalLoss=-0.026850 | Sup=0.004849 | Unsup=-0.316985 | TrainAcc=1.0000
# Fold 9 Epoch 1000: TotalLoss=-0.031225 | Sup=0.000722 | Unsup=-0.319471 | TrainAcc=1.0000
# Fold 9 Epoch 1500: TotalLoss=-0.031664 | Sup=0.000355 | Unsup=-0.320190 | TrainAcc=1.0000
# Fold 9 Epoch 2000: TotalLoss=-0.031812 | Sup=0.000267 | Unsup=-0.320782 | TrainAcc=1.0000
# Fold 9 → Acc=0.9274 | Prec=0.9516 | Rec=0.9167 | F1=0.9338 | AUC=0.9755 | CE Loss=0.4533
#
# === Fold 10 ===
# Fold 10 Epoch 1: TotalLoss=0.766759 | Sup=0.780524 | Unsup=-0.137655 | TrainAcc=0.4581
# Fold 10 Epoch 500: TotalLoss=-0.026643 | Sup=0.004144 | Unsup=-0.307870 | TrainAcc=1.0000
# Fold 10 Epoch 1000: TotalLoss=-0.028984 | Sup=0.002147 | Unsup=-0.311315 | TrainAcc=1.0000
# Fold 10 Epoch 1500: TotalLoss=-0.030682 | Sup=0.000571 | Unsup=-0.312533 | TrainAcc=1.0000
# Fold 10 Epoch 2000: TotalLoss=-0.028195 | Sup=0.003297 | Unsup=-0.314922 | TrainAcc=0.9972
# Fold 10 → Acc=0.9343 | Prec=0.9665 | Rec=0.9139 | F1=0.9395 | AUC=0.9792 | CE Loss=0.3410
#
# === Fold 11 ===
# Fold 11 Epoch 1: TotalLoss=0.745470 | Sup=0.759449 | Unsup=-0.139781 | TrainAcc=0.4302
# Fold 11 Epoch 500: TotalLoss=-0.025231 | Sup=0.005489 | Unsup=-0.307203 | TrainAcc=1.0000
# Fold 11 Epoch 1000: TotalLoss=-0.030185 | Sup=0.001045 | Unsup=-0.312301 | TrainAcc=1.0000
# Fold 11 Epoch 1500: TotalLoss=-0.030922 | Sup=0.000523 | Unsup=-0.314456 | TrainAcc=1.0000
# Fold 11 Epoch 2000: TotalLoss=-0.031177 | Sup=0.000424 | Unsup=-0.316007 | TrainAcc=1.0000
# Fold 11 → Acc=0.9367 | Prec=0.9618 | Rec=0.9233 | F1=0.9422 | AUC=0.9809 | CE Loss=0.3081
#
# === Fold 12 ===
# Fold 12 Epoch 1: TotalLoss=0.531261 | Sup=0.545439 | Unsup=-0.141780 | TrainAcc=0.8045
# Fold 12 Epoch 500: TotalLoss=-0.027893 | Sup=0.003603 | Unsup=-0.314958 | TrainAcc=1.0000
# Fold 12 Epoch 1000: TotalLoss=-0.030723 | Sup=0.001018 | Unsup=-0.317413 | TrainAcc=1.0000
# Fold 12 Epoch 1500: TotalLoss=-0.031231 | Sup=0.000677 | Unsup=-0.319089 | TrainAcc=1.0000
# Fold 12 Epoch 2000: TotalLoss=-0.031665 | Sup=0.000335 | Unsup=-0.320002 | TrainAcc=1.0000
# Fold 12 → Acc=0.9333 | Prec=0.9616 | Rec=0.9172 | F1=0.9389 | AUC=0.9790 | CE Loss=0.3999
#
# === Fold 13 ===
# Fold 13 Epoch 1: TotalLoss=0.787662 | Sup=0.801872 | Unsup=-0.142100 | TrainAcc=0.4441
# Fold 13 Epoch 500: TotalLoss=-0.026100 | Sup=0.004622 | Unsup=-0.307228 | TrainAcc=1.0000
# Fold 13 Epoch 1000: TotalLoss=-0.029552 | Sup=0.001566 | Unsup=-0.311179 | TrainAcc=1.0000
# Fold 13 Epoch 1500: TotalLoss=-0.030901 | Sup=0.000499 | Unsup=-0.314002 | TrainAcc=1.0000
# Fold 13 Epoch 2000: TotalLoss=-0.031134 | Sup=0.000389 | Unsup=-0.315231 | TrainAcc=1.0000
# Fold 13 → Acc=0.9367 | Prec=0.9672 | Rec=0.9178 | F1=0.9418 | AUC=0.9809 | CE Loss=0.3385
#
# === Fold 14 ===
# Fold 14 Epoch 1: TotalLoss=0.694109 | Sup=0.707729 | Unsup=-0.136205 | TrainAcc=0.5894
# Fold 14 Epoch 500: TotalLoss=-0.024883 | Sup=0.005972 | Unsup=-0.308545 | TrainAcc=1.0000
# Fold 14 Epoch 1000: TotalLoss=-0.030083 | Sup=0.001227 | Unsup=-0.313099 | TrainAcc=1.0000
# Fold 14 Epoch 1500: TotalLoss=-0.030364 | Sup=0.001131 | Unsup=-0.314950 | TrainAcc=1.0000
# Fold 14 Epoch 2000: TotalLoss=-0.030356 | Sup=0.001113 | Unsup=-0.314690 | TrainAcc=1.0000
# Fold 14 → Acc=0.9358 | Prec=0.9418 | Rec=0.9433 | F1=0.9425 | AUC=0.9766 | CE Loss=0.3195
#
# === Fold 15 ===
# Fold 15 Epoch 1: TotalLoss=0.750326 | Sup=0.763794 | Unsup=-0.134678 | TrainAcc=0.3939
# Fold 15 Epoch 500: TotalLoss=-0.024712 | Sup=0.006365 | Unsup=-0.310773 | TrainAcc=1.0000
# Fold 15 Epoch 1000: TotalLoss=-0.029523 | Sup=0.001533 | Unsup=-0.310553 | TrainAcc=1.0000
# Fold 15 Epoch 1500: TotalLoss=-0.030891 | Sup=0.000762 | Unsup=-0.316533 | TrainAcc=1.0000
# Fold 15 Epoch 2000: TotalLoss=-0.031308 | Sup=0.000492 | Unsup=-0.318000 | TrainAcc=1.0000
# Fold 15 → Acc=0.9271 | Prec=0.9584 | Rec=0.9089 | F1=0.9330 | AUC=0.9753 | CE Loss=0.4002
#
# === Fold 16 ===
# Fold 16 Epoch 1: TotalLoss=0.722372 | Sup=0.735946 | Unsup=-0.135743 | TrainAcc=0.4693
# Fold 16 Epoch 500: TotalLoss=-0.026085 | Sup=0.005096 | Unsup=-0.311808 | TrainAcc=1.0000
# Fold 16 Epoch 1000: TotalLoss=-0.029959 | Sup=0.001632 | Unsup=-0.315911 | TrainAcc=1.0000
# Fold 16 Epoch 1500: TotalLoss=-0.031054 | Sup=0.000691 | Unsup=-0.317455 | TrainAcc=1.0000
# Fold 16 Epoch 2000: TotalLoss=-0.031491 | Sup=0.000331 | Unsup=-0.318226 | TrainAcc=1.0000
# Fold 16 → Acc=0.9262 | Prec=0.9694 | Rec=0.8961 | F1=0.9313 | AUC=0.9760 | CE Loss=0.3972
#
# === Fold 17 ===
# Fold 17 Epoch 1: TotalLoss=0.544292 | Sup=0.559328 | Unsup=-0.150362 | TrainAcc=0.7486
# Fold 17 Epoch 500: TotalLoss=-0.027503 | Sup=0.003796 | Unsup=-0.312998 | TrainAcc=1.0000
# Fold 17 Epoch 1000: TotalLoss=-0.031026 | Sup=0.000619 | Unsup=-0.316456 | TrainAcc=1.0000
# Fold 17 Epoch 1500: TotalLoss=-0.031417 | Sup=0.000317 | Unsup=-0.317337 | TrainAcc=1.0000
# Fold 17 Epoch 2000: TotalLoss=-0.031365 | Sup=0.000394 | Unsup=-0.317584 | TrainAcc=1.0000
# Fold 17 → Acc=0.9398 | Prec=0.9679 | Rec=0.9228 | F1=0.9448 | AUC=0.9821 | CE Loss=0.3128
#
# === Fold 18 ===
# Fold 18 Epoch 1: TotalLoss=0.785077 | Sup=0.799083 | Unsup=-0.140054 | TrainAcc=0.3408
# Fold 18 Epoch 500: TotalLoss=-0.026125 | Sup=0.004620 | Unsup=-0.307446 | TrainAcc=1.0000
# Fold 18 Epoch 1000: TotalLoss=-0.030090 | Sup=0.001070 | Unsup=-0.311600 | TrainAcc=1.0000
# Fold 18 Epoch 1500: TotalLoss=-0.030883 | Sup=0.000543 | Unsup=-0.314258 | TrainAcc=1.0000
# Fold 18 Epoch 2000: TotalLoss=-0.030924 | Sup=0.000511 | Unsup=-0.314352 | TrainAcc=1.0000
# Fold 18 → Acc=0.9321 | Prec=0.9626 | Rec=0.9139 | F1=0.9376 | AUC=0.9816 | CE Loss=0.3384
#
# === Fold 19 ===
# Fold 19 Epoch 1: TotalLoss=0.645716 | Sup=0.659240 | Unsup=-0.135234 | TrainAcc=0.5782
# Fold 19 Epoch 500: TotalLoss=-0.025361 | Sup=0.005795 | Unsup=-0.311555 | TrainAcc=1.0000
# Fold 19 Epoch 1000: TotalLoss=-0.030267 | Sup=0.001082 | Unsup=-0.313490 | TrainAcc=1.0000
# Fold 19 Epoch 1500: TotalLoss=-0.031061 | Sup=0.000568 | Unsup=-0.316297 | TrainAcc=1.0000
# Fold 19 Epoch 2000: TotalLoss=-0.031380 | Sup=0.000373 | Unsup=-0.317535 | TrainAcc=1.0000
# Fold 19 → Acc=0.9318 | Prec=0.9620 | Rec=0.9139 | F1=0.9373 | AUC=0.9801 | CE Loss=0.3670
#
# === Fold 20 ===
# Fold 20 Epoch 1: TotalLoss=0.654911 | Sup=0.668446 | Unsup=-0.135349 | TrainAcc=0.5531
# Fold 20 Epoch 500: TotalLoss=-0.026824 | Sup=0.004028 | Unsup=-0.308515 | TrainAcc=1.0000
# Fold 20 Epoch 1000: TotalLoss=-0.029903 | Sup=0.001397 | Unsup=-0.312996 | TrainAcc=1.0000
# Fold 20 Epoch 1500: TotalLoss=-0.031111 | Sup=0.000478 | Unsup=-0.315886 | TrainAcc=1.0000
# Fold 20 Epoch 2000: TotalLoss=-0.031367 | Sup=0.000349 | Unsup=-0.317160 | TrainAcc=1.0000
# Fold 20 → Acc=0.9340 | Prec=0.9501 | Rec=0.9306 | F1=0.9402 | AUC=0.9765 | CE Loss=0.3520
#
# === Average Results Across 20 Folds ===
# Accuracy:  0.9329 ± 0.0039
# Precision: 0.9603 ± 0.0070
# Recall:    0.9178 ± 0.0103
# F1-score:  0.9385 ± 0.0038
# AUC:       0.9782 ± 0.0028
# CE Loss:   0.3589 ± 0.0366
