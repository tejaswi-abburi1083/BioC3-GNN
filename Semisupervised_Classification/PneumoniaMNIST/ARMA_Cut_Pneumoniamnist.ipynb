# %%
import torch
import torch.nn as nn
import torch.nn.functional as nnFn
import torch.optim as optim
import numpy as np
import random
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from torch_geometric.data import Data
from torch_geometric.nn import ARMAConv
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, roc_auc_score, log_loss
)
from torch.utils.data import TensorDataset, DataLoader, Subset
from torch_geometric.data import Data
from torch_geometric.nn import ARMAConv
from torch.utils.data import TensorDataset, DataLoader, Subset
from torchvision import models

# %%
import torch
print("CUDA available:", torch.cuda.is_available())
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("GPU Name:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU")
# Out:
# CUDA available: True
# GPU Name: NVIDIA RTX A4000

# %%
# data = np.load('/home/snu/Downloads/breastmnist_224.npz', allow_pickle=True)
# all_images = np.concatenate([data['train_images'], data['val_images'], data['test_images']], axis=0)
# all_labels = np.concatenate([data['train_labels'], data['val_labels'], data['test_labels']], axis=0).squeeze()

# # Convert to 3-channel RGB
# images = all_images.astype(np.float32) / 255.0
# images = np.repeat(images[:, None, :, :], 3, axis=1)  # (N, 3, 224, 224)
# X_torch = torch.tensor(images)
# y_torch = torch.tensor(all_labels).long()
# print(f"Raw images: {X_torch.shape}, Labels: {y_torch.shape}")

# %%
data = np.load('/home/snu/Downloads/pneumoniamnist_224.npz', allow_pickle=True)
all_images = np.concatenate([data['train_images'], data['val_images'], data['test_images']], axis=0)
all_labels = np.concatenate([data['train_labels'], data['val_labels'], data['test_labels']], axis=0).squeeze()

# Convert to 3-channel RGB
images = all_images.astype(np.float32) / 255.0
images = np.repeat(images[:, None, :, :], 3, axis=1)  # (N, 3, 224, 224)
X_torch = torch.tensor(images)
y_torch = torch.tensor(all_labels).long()
print(f"Raw images: {X_torch.shape}, Labels: {y_torch.shape}")
# Out:
# Raw images: torch.Size([5856, 3, 224, 224]), Labels: torch.Size([5856])

# %%
class0_idx = [i for i in range(len(y_torch)) if y_torch[i] == 0]
class1_idx = [i for i in range(len(y_torch)) if y_torch[i] == 1]

random.seed(42)
sampled_class0 = random.sample(class0_idx, min(2000, len(class0_idx)))
sampled_class1 = random.sample(class1_idx, min(2000, len(class1_idx)))

selected_indices = sampled_class0 + sampled_class1
random.shuffle(selected_indices)

subset_dataset = Subset(TensorDataset(X_torch, y_torch), selected_indices)
subset_loader = DataLoader(subset_dataset, batch_size=32, shuffle=False)

# %%
resnet = models.resnet18(pretrained=True)
resnet.fc = nn.Identity()
resnet = resnet.to(device)
resnet.eval()

resnet_feats = []
y_list = []
with torch.no_grad():
    for imgs, labels in subset_loader:
        imgs = imgs.to(device)
        feats = resnet(imgs)
        resnet_feats.append(feats.cpu())
        y_list.extend(labels.cpu().tolist())

features = torch.cat(resnet_feats, dim=0).numpy().astype(np.float32)  # shape (N, feat_dim)
y_labels = np.array(y_list).astype(np.float32)
print("Feature shape:", features.shape, "Label shape:", y_labels.shape)
# Out:
# /home/snu/anaconda3/envs/torch_env/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/snu/anaconda3/envs/torch_env/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Feature shape: (3583, 512) Label shape: (3583,)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as nnFn
from torch_geometric.nn import ARMAConv

class ARMA_SemiSupervised(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, device, num_stacks=1, num_layers=1):
        super().__init__()
        self.device = device
        self.num_clusters = output_dim # Initialize num_clusters

        # Only one ARMAConv layer
        self.conv1 = ARMAConv(input_dim, hidden_dim,
                              num_stacks=num_stacks, num_layers=num_layers,
                              shared_weights=True, dropout=0.2)

        self.dropout = nn.Dropout(0.25)
        self.fc = nn.Linear(hidden_dim, output_dim)

        # Activation function
        activations = {
            "SELU": nnFn.selu,
            "SiLU": nnFn.silu,
            "GELU": nnFn.gelu,
            "RELU": nnFn.relu,
            "ELU": nnFn.elu,
            "PReLU": nnFn.prelu,
            "LeakyReLU": nnFn.leaky_relu
        }
        self.act = activations.get("RELU", nnFn.relu)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index

        # Single layer
        x = self.conv1(x, edge_index)
        x = self.act(x)
        x = self.dropout(x)

        logits = self.fc(x)
        return logits

    def cut_loss(self, A, S):
        S = nnFn.softmax(S, dim=1)
        A_pool = torch.matmul(torch.matmul(A, S).t(), S)
        num = torch.trace(A_pool)

        D = torch.diag(torch.sum(A, dim=-1))
        D_pooled = torch.matmul(torch.matmul(D, S).t(), S)
        den = torch.trace(D_pooled)
        mincut_loss = -(num / den)

        St_S = torch.matmul(S.t(), S)
        I_S = torch.eye(self.num_clusters, device=self.device)
        ortho_loss = torch.norm(St_S / torch.norm(St_S) - I_S / torch.norm(I_S))

        return mincut_loss + ortho_loss

# %%
def create_adj(F, alpha=1):
    F_norm = F / np.linalg.norm(F, axis=1, keepdims=True)
    W = np.dot(F_norm, F_norm.T)
    W = np.where(W >= alpha, 1, 0).astype(np.float32)
    W = W / W.max()
    return W

def load_data(adj, node_feats):
    node_feats = torch.from_numpy(node_feats).float()
    edge_index = torch.from_numpy(np.array(np.nonzero((adj > 0))))
    return Data(x=node_feats, edge_index=edge_index)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
alpha = 0.9
feats_dim = features.shape[1]
hidden_dim = 256
num_classes = 2
num_epochs = 2000
lr = 0.0001
weight_decay = 1e-4
batch_print_freq = 500
lambda_mod = 0.1  #0.2 #0.001  # weight for modularity loss
# lambda_sup = 1.0

# %%
W = create_adj(features, alpha)
data = load_data(W, features).to(device)
print(data)
# Out:
# Data(x=[3583, 512], edge_index=[2, 1642039])

# %%
sss = StratifiedShuffleSplit(n_splits=20, test_size=0.9, random_state=42)

accuracies, precisions, recalls, f1_scores, aucs, ce_losses = [], [], [], [], [], []

for fold, (train_idx, test_idx) in enumerate(sss.split(features, y_labels.astype(np.int64)), start=1):
    print(f"\n=== Fold {fold} ===")

    # Convert to tensors
    train_idx_t = torch.from_numpy(train_idx).long().to(device)
    y_train_tensor = torch.from_numpy(y_labels[train_idx]).long().to(device)
    A_tensor = torch.from_numpy(W).float().to(device)

    # Initialize model
    model = ARMA_SemiSupervised(feats_dim, hidden_dim, num_classes, device).to(device)
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    ce_loss = nn.CrossEntropyLoss()

    # Training
    for epoch in range(1, num_epochs + 1):
        model.train()
        optimizer.zero_grad()

        logits = model(data)
        loss_sup = ce_loss(logits[train_idx_t], y_train_tensor)
        loss_unsup = model.cut_loss(A_tensor, logits) # Corrected method call
        total_loss = loss_sup + lambda_mod * loss_unsup

        total_loss.backward()
        optimizer.step()

        if epoch % batch_print_freq == 0 or epoch == 1:
            model.eval()
            with torch.no_grad():
                preds_train = logits[train_idx_t].argmax(dim=1)
                acc_train = accuracy_score(y_train_tensor.cpu(), preds_train.cpu())
            print(f"Fold {fold} Epoch {epoch}: "
                  f"TotalLoss={total_loss.item():.6f} | Sup={loss_sup.item():.6f} | "
                  f"Unsup={loss_unsup.item():.6f} | TrainAcc={acc_train:.4f}")

    # Evaluation
    model.eval()
    with torch.no_grad():
        out = model(data)
        preds = out.argmax(dim=1).cpu().numpy()
        probs = torch.softmax(out, dim=1)[:, 1].cpu().numpy()  # Probability for class 1

    y_test = y_labels[test_idx]
    y_pred_test = preds[test_idx]
    y_prob_test = probs[test_idx]

    acc = accuracy_score(y_test, y_pred_test)
    prec = precision_score(y_test, y_pred_test, zero_division=0)
    rec = recall_score(y_test, y_pred_test, zero_division=0)
    f1 = f1_score(y_test, y_pred_test, zero_division=0)
    auc = roc_auc_score(y_test, y_prob_test)
    ce = log_loss(y_test, y_prob_test)

    accuracies.append(acc)
    precisions.append(prec)
    recalls.append(rec)
    f1_scores.append(f1)
    aucs.append(auc)
    ce_losses.append(ce)

    print(f"Fold {fold} → "
          f"Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | "
          f"F1={f1:.4f} | AUC={auc:.4f} | CE Loss={ce:.4f}")


# Final summary
print("\n=== Average Results Across 20 Folds ===")
print(f"Accuracy:  {np.mean(accuracies):.4f} \u00b1 {np.std(accuracies):.4f}")
print(f"Precision: {np.mean(precisions):.4f} \u00b1 {np.std(precisions):.4f}")
print(f"Recall:    {np.mean(recalls):.4f} \u00b1 {np.std(recalls):.4f}")
print(f"F1-score:  {np.mean(f1_scores):.4f} \u00b1 {np.std(f1_scores):.4f}")
print(f"AUC:       {np.mean(aucs):.4f} \u00b1 {np.std(aucs):.4f}")
print(f"CE Loss:   {np.mean(ce_losses):.4f} \u00b1 {np.std(ce_losses):.4f}")
# Out:
# === Fold 1 ===
# Fold 1 Epoch 1: TotalLoss=0.864995 | Sup=0.887268 | Unsup=-0.222736 | TrainAcc=0.4581
# Fold 1 Epoch 500: TotalLoss=-0.028553 | Sup=0.052573 | Unsup=-0.811261 | TrainAcc=0.9860
# Fold 1 Epoch 1000: TotalLoss=-0.059049 | Sup=0.022075 | Unsup=-0.811247 | TrainAcc=0.9972
# Fold 1 Epoch 1500: TotalLoss=-0.072147 | Sup=0.010076 | Unsup=-0.822227 | TrainAcc=1.0000
# Fold 1 Epoch 2000: TotalLoss=-0.074910 | Sup=0.009836 | Unsup=-0.847459 | TrainAcc=1.0000
# Fold 1 → Acc=0.9346 | Prec=0.9749 | Rec=0.9061 | F1=0.9392 | AUC=0.9867 | CE Loss=0.2571
#
# === Fold 2 ===
# Fold 2 Epoch 1: TotalLoss=0.851426 | Sup=0.874609 | Unsup=-0.231830 | TrainAcc=0.5000
# Fold 2 Epoch 500: TotalLoss=-0.012597 | Sup=0.062997 | Unsup=-0.755941 | TrainAcc=0.9804
# Fold 2 Epoch 1000: TotalLoss=-0.041602 | Sup=0.035181 | Unsup=-0.767830 | TrainAcc=0.9832
# Fold 2 Epoch 1500: TotalLoss=-0.062560 | Sup=0.014847 | Unsup=-0.774068 | TrainAcc=0.9944
# Fold 2 Epoch 2000: TotalLoss=-0.068539 | Sup=0.008824 | Unsup=-0.773631 | TrainAcc=0.9972
# Fold 2 → Acc=0.9364 | Prec=0.9534 | Rec=0.9317 | F1=0.9424 | AUC=0.9824 | CE Loss=0.2665
#
# === Fold 3 ===
# Fold 3 Epoch 1: TotalLoss=0.710191 | Sup=0.733091 | Unsup=-0.228996 | TrainAcc=0.5447
# Fold 3 Epoch 500: TotalLoss=0.000484 | Sup=0.077922 | Unsup=-0.774381 | TrainAcc=0.9749
# Fold 3 Epoch 1000: TotalLoss=-0.046920 | Sup=0.034566 | Unsup=-0.814852 | TrainAcc=0.9944
# Fold 3 Epoch 1500: TotalLoss=-0.061043 | Sup=0.022004 | Unsup=-0.830474 | TrainAcc=0.9944
# Fold 3 Epoch 2000: TotalLoss=-0.067868 | Sup=0.015335 | Unsup=-0.832021 | TrainAcc=0.9944
# Fold 3 → Acc=0.9296 | Prec=0.9729 | Rec=0.8989 | F1=0.9344 | AUC=0.9835 | CE Loss=0.2771
#
# === Fold 4 ===
# Fold 4 Epoch 1: TotalLoss=0.821255 | Sup=0.843843 | Unsup=-0.225883 | TrainAcc=0.4022
# Fold 4 Epoch 500: TotalLoss=-0.011825 | Sup=0.067600 | Unsup=-0.794248 | TrainAcc=0.9721
# Fold 4 Epoch 1000: TotalLoss=-0.053371 | Sup=0.027985 | Unsup=-0.813554 | TrainAcc=0.9916
# Fold 4 Epoch 1500: TotalLoss=-0.064143 | Sup=0.017765 | Unsup=-0.819080 | TrainAcc=0.9944
# Fold 4 Epoch 2000: TotalLoss=-0.072144 | Sup=0.011836 | Unsup=-0.839795 | TrainAcc=0.9972
# Fold 4 → Acc=0.9268 | Prec=0.9717 | Rec=0.8950 | F1=0.9318 | AUC=0.9807 | CE Loss=0.2986
#
# === Fold 5 ===
# Fold 5 Epoch 1: TotalLoss=0.695593 | Sup=0.719348 | Unsup=-0.237544 | TrainAcc=0.5447
# Fold 5 Epoch 500: TotalLoss=-0.005549 | Sup=0.074064 | Unsup=-0.796130 | TrainAcc=0.9777
# Fold 5 Epoch 1000: TotalLoss=-0.057628 | Sup=0.023541 | Unsup=-0.811695 | TrainAcc=0.9944
# Fold 5 Epoch 1500: TotalLoss=-0.067508 | Sup=0.014426 | Unsup=-0.819340 | TrainAcc=0.9972
# Fold 5 Epoch 2000: TotalLoss=-0.075252 | Sup=0.009253 | Unsup=-0.845050 | TrainAcc=0.9972
# Fold 5 → Acc=0.9262 | Prec=0.9768 | Rec=0.8889 | F1=0.9308 | AUC=0.9828 | CE Loss=0.3083
#
# === Fold 6 ===
# Fold 6 Epoch 1: TotalLoss=0.958730 | Sup=0.981053 | Unsup=-0.223232 | TrainAcc=0.3994
# Fold 6 Epoch 500: TotalLoss=0.012995 | Sup=0.094406 | Unsup=-0.814108 | TrainAcc=0.9553
# Fold 6 Epoch 1000: TotalLoss=-0.036283 | Sup=0.045011 | Unsup=-0.812942 | TrainAcc=0.9860
# Fold 6 Epoch 1500: TotalLoss=-0.063098 | Sup=0.020116 | Unsup=-0.832141 | TrainAcc=0.9972
# Fold 6 Epoch 2000: TotalLoss=-0.071153 | Sup=0.012673 | Unsup=-0.838253 | TrainAcc=0.9972
# Fold 6 → Acc=0.9374 | Prec=0.9813 | Rec=0.9050 | F1=0.9416 | AUC=0.9878 | CE Loss=0.2243
#
# === Fold 7 ===
# Fold 7 Epoch 1: TotalLoss=0.781251 | Sup=0.805232 | Unsup=-0.239809 | TrainAcc=0.5028
# Fold 7 Epoch 500: TotalLoss=0.043091 | Sup=0.121792 | Unsup=-0.787017 | TrainAcc=0.9609
# Fold 7 Epoch 1000: TotalLoss=-0.019187 | Sup=0.060774 | Unsup=-0.799613 | TrainAcc=0.9804
# Fold 7 Epoch 1500: TotalLoss=-0.050143 | Sup=0.029571 | Unsup=-0.797133 | TrainAcc=0.9916
# Fold 7 Epoch 2000: TotalLoss=-0.060635 | Sup=0.021974 | Unsup=-0.826090 | TrainAcc=0.9944
# Fold 7 → Acc=0.9340 | Prec=0.9754 | Rec=0.9044 | F1=0.9386 | AUC=0.9848 | CE Loss=0.2348
#
# === Fold 8 ===
# Fold 8 Epoch 1: TotalLoss=0.639153 | Sup=0.661902 | Unsup=-0.227490 | TrainAcc=0.6313
# Fold 8 Epoch 500: TotalLoss=-0.035771 | Sup=0.036829 | Unsup=-0.726008 | TrainAcc=0.9888
# Fold 8 Epoch 1000: TotalLoss=-0.059818 | Sup=0.016123 | Unsup=-0.759410 | TrainAcc=0.9944
# Fold 8 Epoch 1500: TotalLoss=-0.072752 | Sup=0.004829 | Unsup=-0.775807 | TrainAcc=1.0000
# Fold 8 Epoch 2000: TotalLoss=-0.060586 | Sup=0.017639 | Unsup=-0.782245 | TrainAcc=0.9916
# Fold 8 → Acc=0.9383 | Prec=0.9525 | Rec=0.9361 | F1=0.9442 | AUC=0.9832 | CE Loss=0.2742
#
# === Fold 9 ===
# Fold 9 Epoch 1: TotalLoss=0.974666 | Sup=0.997665 | Unsup=-0.229990 | TrainAcc=0.3799
# Fold 9 Epoch 500: TotalLoss=-0.062079 | Sup=0.017911 | Unsup=-0.799895 | TrainAcc=0.9972
# Fold 9 Epoch 1000: TotalLoss=-0.057577 | Sup=0.022603 | Unsup=-0.801802 | TrainAcc=0.9944
# Fold 9 Epoch 1500: TotalLoss=-0.075976 | Sup=0.005601 | Unsup=-0.815769 | TrainAcc=1.0000
# Fold 9 Epoch 2000: TotalLoss=-0.076438 | Sup=0.007605 | Unsup=-0.840434 | TrainAcc=0.9972
# Fold 9 → Acc=0.9330 | Prec=0.9670 | Rec=0.9111 | F1=0.9382 | AUC=0.9818 | CE Loss=0.3549
#
# === Fold 10 ===
# Fold 10 Epoch 1: TotalLoss=0.761755 | Sup=0.783565 | Unsup=-0.218096 | TrainAcc=0.4637
# Fold 10 Epoch 500: TotalLoss=-0.019324 | Sup=0.057592 | Unsup=-0.769159 | TrainAcc=0.9777
# Fold 10 Epoch 1000: TotalLoss=-0.039806 | Sup=0.039462 | Unsup=-0.792678 | TrainAcc=0.9832
# Fold 10 Epoch 1500: TotalLoss=-0.069929 | Sup=0.008828 | Unsup=-0.787573 | TrainAcc=1.0000
# Fold 10 Epoch 2000: TotalLoss=-0.069148 | Sup=0.011186 | Unsup=-0.803341 | TrainAcc=0.9916
# Fold 10 → Acc=0.9436 | Prec=0.9698 | Rec=0.9278 | F1=0.9483 | AUC=0.9850 | CE Loss=0.2276
#
# === Fold 11 ===
# Fold 11 Epoch 1: TotalLoss=0.715578 | Sup=0.738279 | Unsup=-0.227016 | TrainAcc=0.4832
# Fold 11 Epoch 500: TotalLoss=-0.006294 | Sup=0.071703 | Unsup=-0.779975 | TrainAcc=0.9804
# Fold 11 Epoch 1000: TotalLoss=-0.047921 | Sup=0.031426 | Unsup=-0.793469 | TrainAcc=0.9916
# Fold 11 Epoch 1500: TotalLoss=-0.069060 | Sup=0.013701 | Unsup=-0.827612 | TrainAcc=1.0000
# Fold 11 Epoch 2000: TotalLoss=-0.056333 | Sup=0.026369 | Unsup=-0.827017 | TrainAcc=0.9916
# Fold 11 → Acc=0.9336 | Prec=0.9732 | Rec=0.9061 | F1=0.9384 | AUC=0.9821 | CE Loss=0.2702
#
# === Fold 12 ===
# Fold 12 Epoch 1: TotalLoss=0.761397 | Sup=0.783986 | Unsup=-0.225890 | TrainAcc=0.4749
# Fold 12 Epoch 500: TotalLoss=-0.053449 | Sup=0.029745 | Unsup=-0.831942 | TrainAcc=0.9888
# Fold 12 Epoch 1000: TotalLoss=-0.067815 | Sup=0.015815 | Unsup=-0.836298 | TrainAcc=0.9972
# Fold 12 Epoch 1500: TotalLoss=-0.073578 | Sup=0.012736 | Unsup=-0.863135 | TrainAcc=0.9944
# Fold 12 Epoch 2000: TotalLoss=-0.081744 | Sup=0.004567 | Unsup=-0.863107 | TrainAcc=1.0000
# Fold 12 → Acc=0.9315 | Prec=0.9765 | Rec=0.8989 | F1=0.9361 | AUC=0.9846 | CE Loss=0.3522
#
# === Fold 13 ===
# Fold 13 Epoch 1: TotalLoss=0.830206 | Sup=0.853754 | Unsup=-0.235479 | TrainAcc=0.3855
# Fold 13 Epoch 500: TotalLoss=-0.003435 | Sup=0.073459 | Unsup=-0.768938 | TrainAcc=0.9721
# Fold 13 Epoch 1000: TotalLoss=-0.034128 | Sup=0.045655 | Unsup=-0.797830 | TrainAcc=0.9777
# Fold 13 Epoch 1500: TotalLoss=-0.065096 | Sup=0.015254 | Unsup=-0.803500 | TrainAcc=0.9972
# Fold 13 Epoch 2000: TotalLoss=-0.074037 | Sup=0.008141 | Unsup=-0.821773 | TrainAcc=1.0000
# Fold 13 → Acc=0.9367 | Prec=0.9750 | Rec=0.9100 | F1=0.9414 | AUC=0.9857 | CE Loss=0.2472
#
# === Fold 14 ===
# Fold 14 Epoch 1: TotalLoss=1.010529 | Sup=1.034331 | Unsup=-0.238025 | TrainAcc=0.4497
# Fold 14 Epoch 500: TotalLoss=0.016997 | Sup=0.096460 | Unsup=-0.794629 | TrainAcc=0.9721
# Fold 14 Epoch 1000: TotalLoss=-0.044164 | Sup=0.036010 | Unsup=-0.801740 | TrainAcc=0.9888
# Fold 14 Epoch 1500: TotalLoss=-0.063360 | Sup=0.020148 | Unsup=-0.835086 | TrainAcc=0.9944
# Fold 14 Epoch 2000: TotalLoss=-0.066137 | Sup=0.018428 | Unsup=-0.845649 | TrainAcc=0.9916
# Fold 14 → Acc=0.9240 | Prec=0.9755 | Rec=0.8861 | F1=0.9287 | AUC=0.9813 | CE Loss=0.2971
#
# === Fold 15 ===
# Fold 15 Epoch 1: TotalLoss=0.750243 | Sup=0.773076 | Unsup=-0.228322 | TrainAcc=0.5112
# Fold 15 Epoch 500: TotalLoss=-0.011924 | Sup=0.065872 | Unsup=-0.777961 | TrainAcc=0.9804
# Fold 15 Epoch 1000: TotalLoss=-0.053420 | Sup=0.024414 | Unsup=-0.778332 | TrainAcc=0.9944
# Fold 15 Epoch 1500: TotalLoss=-0.069343 | Sup=0.009703 | Unsup=-0.790460 | TrainAcc=0.9972
# Fold 15 Epoch 2000: TotalLoss=-0.076212 | Sup=0.004525 | Unsup=-0.807369 | TrainAcc=1.0000
# Fold 15 → Acc=0.9302 | Prec=0.9592 | Rec=0.9139 | F1=0.9360 | AUC=0.9809 | CE Loss=0.3126
#
# === Fold 16 ===
# Fold 16 Epoch 1: TotalLoss=0.741581 | Sup=0.764586 | Unsup=-0.230051 | TrainAcc=0.4916
# Fold 16 Epoch 500: TotalLoss=-0.023789 | Sup=0.056977 | Unsup=-0.807651 | TrainAcc=0.9804
# Fold 16 Epoch 1000: TotalLoss=-0.061007 | Sup=0.020788 | Unsup=-0.817951 | TrainAcc=0.9972
# Fold 16 Epoch 1500: TotalLoss=-0.065197 | Sup=0.019441 | Unsup=-0.846384 | TrainAcc=0.9916
# Fold 16 Epoch 2000: TotalLoss=-0.072850 | Sup=0.011301 | Unsup=-0.841514 | TrainAcc=0.9944
# Fold 16 → Acc=0.9287 | Prec=0.9729 | Rec=0.8972 | F1=0.9335 | AUC=0.9850 | CE Loss=0.2807
#
# === Fold 17 ===
# Fold 17 Epoch 1: TotalLoss=1.019548 | Sup=1.041893 | Unsup=-0.223446 | TrainAcc=0.4274
# Fold 17 Epoch 500: TotalLoss=-0.015463 | Sup=0.064658 | Unsup=-0.801213 | TrainAcc=0.9804
# Fold 17 Epoch 1000: TotalLoss=-0.050914 | Sup=0.031526 | Unsup=-0.824395 | TrainAcc=0.9888
# Fold 17 Epoch 1500: TotalLoss=-0.056387 | Sup=0.026165 | Unsup=-0.825523 | TrainAcc=0.9972
# Fold 17 Epoch 2000: TotalLoss=-0.068651 | Sup=0.014049 | Unsup=-0.827000 | TrainAcc=0.9972
# Fold 17 → Acc=0.9460 | Prec=0.9743 | Rec=0.9278 | F1=0.9505 | AUC=0.9878 | CE Loss=0.2185
#
# === Fold 18 ===
# Fold 18 Epoch 1: TotalLoss=0.826094 | Sup=0.847916 | Unsup=-0.218221 | TrainAcc=0.4358
# Fold 18 Epoch 500: TotalLoss=0.002141 | Sup=0.082876 | Unsup=-0.807351 | TrainAcc=0.9721
# Fold 18 Epoch 1000: TotalLoss=-0.042218 | Sup=0.040375 | Unsup=-0.825926 | TrainAcc=0.9888
# Fold 18 Epoch 1500: TotalLoss=-0.061631 | Sup=0.021408 | Unsup=-0.830395 | TrainAcc=0.9916
# Fold 18 Epoch 2000: TotalLoss=-0.074294 | Sup=0.008307 | Unsup=-0.826009 | TrainAcc=1.0000
# Fold 18 → Acc=0.9327 | Prec=0.9777 | Rec=0.9000 | F1=0.9372 | AUC=0.9841 | CE Loss=0.2688
#
# === Fold 19 ===
# Fold 19 Epoch 1: TotalLoss=0.867997 | Sup=0.892004 | Unsup=-0.240065 | TrainAcc=0.3966
# Fold 19 Epoch 500: TotalLoss=-0.032482 | Sup=0.047245 | Unsup=-0.797268 | TrainAcc=0.9916
# Fold 19 Epoch 1000: TotalLoss=-0.048909 | Sup=0.033991 | Unsup=-0.829003 | TrainAcc=0.9916
# Fold 19 Epoch 1500: TotalLoss=-0.058542 | Sup=0.024548 | Unsup=-0.830895 | TrainAcc=0.9916
# Fold 19 Epoch 2000: TotalLoss=-0.074599 | Sup=0.010007 | Unsup=-0.846063 | TrainAcc=0.9972
# Fold 19 → Acc=0.9305 | Prec=0.9747 | Rec=0.8989 | F1=0.9353 | AUC=0.9815 | CE Loss=0.3272
#
# === Fold 20 ===
# Fold 20 Epoch 1: TotalLoss=0.813546 | Sup=0.836968 | Unsup=-0.234220 | TrainAcc=0.4302
# Fold 20 Epoch 500: TotalLoss=-0.007297 | Sup=0.069269 | Unsup=-0.765665 | TrainAcc=0.9804
# Fold 20 Epoch 1000: TotalLoss=-0.046994 | Sup=0.031099 | Unsup=-0.780925 | TrainAcc=0.9944
# Fold 20 Epoch 1500: TotalLoss=-0.060992 | Sup=0.017409 | Unsup=-0.784016 | TrainAcc=0.9972
# Fold 20 Epoch 2000: TotalLoss=-0.059882 | Sup=0.021306 | Unsup=-0.811878 | TrainAcc=0.9944
# Fold 20 → Acc=0.9402 | Prec=0.9735 | Rec=0.9178 | F1=0.9448 | AUC=0.9864 | CE Loss=0.2259
#
# === Average Results Across 20 Folds ===
# Accuracy:  0.9337 ± 0.0055
# Precision: 0.9714 ± 0.0075
# Recall:    0.9081 ± 0.0137
# F1-score:  0.9386 ± 0.0055
# AUC:       0.9839 ± 0.0022
# CE Loss:   0.2762 ± 0.0399
