# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
# Mounted at /content/drive

# %%
# !pip install numpy scikit-learn
# !pip install -q torch_geometric
# !pip install -q class_resolver
# !pip3 install pymatting
# !pip install opencv-python
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 7.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 7.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 82.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 82.4 MB/s eta 0:00:00
# Collecting pymatting
#   Downloading pymatting-1.1.14-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from pymatting) (2.0.2)
# Requirement already satisfied: pillow>=5.2.0 in /usr/local/lib/python3.12/dist-packages (from pymatting) (11.3.0)
# Requirement already satisfied: numba!=0.49.0 in /usr/local/lib/python3.12/dist-packages (from pymatting) (0.60.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from pymatting) (1.16.3)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba!=0.49.0->pymatting) (0.43.0)
# Downloading pymatting-1.1.14-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.7/54.7 kB 5.0 MB/s eta 0:00:00
# Collecting pymatting
#   Downloading pymatting-1.1.14-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from pymatting) (2.0.2)
# Requirement already satisfied: pillow>=5.2.0 in /usr/local/lib/python3.12/dist-packages (from pymatting) (11.3.0)
# Requirement already satisfied: numba!=0.49.0 in /usr/local/lib/python3.12/dist-packages (from pymatting) (0.60.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from pymatting) (1.16.3)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba!=0.49.0->pymatting) (0.43.0)
# Downloading pymatting-1.1.14-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.7/54.7 kB 5.0 MB/s eta 0:00:00
# Installing collected packages: pymatting
# Successfully installed pymatting-1.1.14
# Installing collected packages: pymatting
# Successfully installed pymatting-1.1.14
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (4.12.0.88)
# Requirement already satisfied: numpy<2.3.0,>=2 in /usr/local/lib/python3.12/dist-packages (from opencv-python) (2.0.2)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (4.12.0.88)
# Requirement already satisfied: numpy<2.3.0,>=2 in /usr/local/lib/python3.12/dist-packages (from opencv-python) (2.0.2)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as nnFn
import torch.optim as optim
import numpy as np
import random
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from torch_geometric.data import Data
from torch_geometric.nn import GATConv
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, roc_auc_score, log_loss
)
from torch.utils.data import TensorDataset, DataLoader, Subset
from torch_geometric.data import Data
from torch_geometric.nn import ARMAConv
from torch.utils.data import TensorDataset, DataLoader, Subset
from torchvision import models

# %%
data = np.load('/content/drive/MyDrive/TejaswiAbburi_va797/Dataset/Medmnist_data/pneumoniamnist_224.npz', allow_pickle=True)
all_images = np.concatenate([data['train_images'], data['val_images'], data['test_images']], axis=0)
all_labels = np.concatenate([data['train_labels'], data['val_labels'], data['test_labels']], axis=0).squeeze()

# Convert to 3-channel RGB
images = all_images.astype(np.float32) / 255.0
images = np.repeat(images[:, None, :, :], 3, axis=1)  # (N, 3, 224, 224)
X_torch = torch.tensor(images)
y_torch = torch.tensor(all_labels).long()
print(f"Raw images: {X_torch.shape}, Labels: {y_torch.shape}")
# Out:
# Raw images: torch.Size([5856, 3, 224, 224]), Labels: torch.Size([5856])

# %%
import torch
print("CUDA available:", torch.cuda.is_available())
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("GPU Name:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU")
# Out:
# CUDA available: True
# GPU Name: NVIDIA A100-SXM4-40GB

# %%
class0_idx = [i for i in range(len(y_torch)) if y_torch[i] == 0]
class1_idx = [i for i in range(len(y_torch)) if y_torch[i] == 1]

random.seed(42)
sampled_class0 = random.sample(class0_idx, min(2000, len(class0_idx)))
sampled_class1 = random.sample(class1_idx, min(2000, len(class1_idx)))

selected_indices = sampled_class0 + sampled_class1
random.shuffle(selected_indices)

subset_dataset = Subset(TensorDataset(X_torch, y_torch), selected_indices)
subset_loader = DataLoader(subset_dataset, batch_size=32, shuffle=False)

# %%
resnet = models.resnet18(pretrained=True)
resnet.fc = nn.Identity()
resnet = resnet.to(device)
resnet.eval()

resnet_feats = []
y_list = []
with torch.no_grad():
    for imgs, labels in subset_loader:
        imgs = imgs.to(device)
        feats = resnet(imgs)
        resnet_feats.append(feats.cpu())
        y_list.extend(labels.cpu().tolist())

features = torch.cat(resnet_feats, dim=0).numpy().astype(np.float32)  # shape (N, feat_dim)
y_labels = np.array(y_list).astype(np.float32)
print("Feature shape:", features.shape, "Label shape:", y_labels.shape)
# Out:
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 243MB/s]
# Feature shape: (3583, 512) Label shape: (3583,)

# %%
class GAT_Supervised(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, heads=2, activ="RELU", dropout=0.2):
        super(GAT_Supervised, self).__init__()
        self.conv1 = GATConv(input_dim, hidden_dim, heads=heads, concat=True, dropout=dropout)
        self.bn1 = nn.BatchNorm1d(hidden_dim * heads)
        self.dropout = nn.Dropout(dropout)
        self.fc = nn.Linear(hidden_dim * heads, output_dim)
        activations = {
            "SELU": nnFn.selu,
            "SiLU": nnFn.silu,
            "GELU": nnFn.gelu,
            "RELU": nnFn.relu,
            "ELU": nnFn.elu
        }
        self.act = activations.get(activ, nnFn.elu)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = self.conv1(x, edge_index)
        x = self.bn1(x)
        x = self.act(x)
        x = self.dropout(x)
        logits = self.fc(x)
        return logits

# %%
def create_adj(F, alpha=1):
    F_norm = F / np.linalg.norm(F, axis=1, keepdims=True)
    W = np.dot(F_norm, F_norm.T)
    W = np.where(W >= alpha, 1, 0).astype(np.float32)
    W = W / W.max()
    return W

def load_data(adj, node_feats):
    node_feats = torch.from_numpy(node_feats).float()
    edge_index = torch.from_numpy(np.array(np.nonzero((adj > 0))))
    return Data(x=node_feats, edge_index=edge_index)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
alpha = 0.9
feats_dim = features.shape[1]
hidden_dim = 256
num_classes = 2
num_epochs = 2000
lr = 0.0001
weight_decay = 1e-4
batch_print_freq = 500
lambda_mod =  0.001  #0.2 #0.001  # weight for modularity loss
# lambda_sup = 1.0

# %%
W = create_adj(features, alpha)
data = load_data(W, features).to(device)
print(data)
# Out:
# Data(x=[3583, 512], edge_index=[2, 1642257])

# %%
sss = StratifiedShuffleSplit(n_splits=20, test_size=0.9, random_state=42)

accuracies, precisions, recalls, f1_scores, aucs, ce_losses = [], [], [], [], [], []

for fold, (train_idx, test_idx) in enumerate(sss.split(features, y_labels.astype(np.int64)), start=1):
    print(f"\n=== Fold {fold} ===")

    train_idx_t = torch.from_numpy(train_idx).long().to(device)
    y_train_tensor = torch.from_numpy(y_labels[train_idx]).long().to(device)

    model = GAT_Supervised(feats_dim, hidden_dim, num_classes).to(device)
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    ce_loss = nn.CrossEntropyLoss()

    for epoch in range(1, num_epochs + 1):
        model.train()
        optimizer.zero_grad()

        logits = model(data)
        loss = ce_loss(logits[train_idx_t], y_train_tensor)

        loss.backward()
        optimizer.step()

        if epoch % batch_print_freq == 0 or epoch == 1:
            model.eval()
            with torch.no_grad():
                preds_train = logits[train_idx_t].argmax(dim=1)
                acc_train = accuracy_score(y_train_tensor.cpu(), preds_train.cpu())
            print(f"Fold {fold} Epoch {epoch}: Loss={loss.item():.6f} | TrainAcc={acc_train:.4f}")

    model.eval()
    with torch.no_grad():
        out = model(data)
        preds = out.argmax(dim=1).cpu().numpy()
        probs = torch.softmax(out, dim=1)[:, 1].cpu().numpy()

    y_test = y_labels[test_idx]
    y_pred_test = preds[test_idx]
    y_pred_test = preds[test_idx]
    y_prob_test = probs[test_idx]

    acc = accuracy_score(y_test, y_pred_test)
    prec = precision_score(y_test, y_pred_test, zero_division=0)
    rec = recall_score(y_test, y_pred_test, zero_division=0)
    f1 = f1_score(y_test, y_pred_test, zero_division=0)
    auc = roc_auc_score(y_test, y_prob_test)
    ce = log_loss(y_test, y_prob_test)

    accuracies.append(acc)
    precisions.append(prec)
    recalls.append(rec)
    f1_scores.append(f1)
    aucs.append(auc)
    ce_losses.append(ce)

    print(f"Fold {fold} → "
          f"Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | "
          f"F1={f1:.4f} | AUC={auc:.4f} | CE Loss={ce:.4f}")


# Final summary
print("\n=== Average Results Across 20 Folds ===")
print(f"Accuracy:  {np.mean(accuracies):.4f} \u00b1 {np.std(accuracies):.4f}")
print(f"Precision: {np.mean(precisions):.4f} \u00b1 {np.std(precisions):.4f}")
print(f"Recall:    {np.mean(recalls):.4f} \u00b1 {np.std(recalls):.4f}")
print(f"F1-score:  {np.mean(f1_scores):.4f} \u00b1 {np.std(f1_scores):.4f}")
print(f"AUC:       {np.mean(aucs):.4f} \u00b1 {np.std(aucs):.4f}")
print(f"CE Loss:   {np.mean(ce_losses):.4f} \u00b1 {np.std(ce_losses):.4f}")
# Out:
# === Fold 1 ===
# Fold 1 Epoch 1: Loss=0.726612 | TrainAcc=0.4749
# Fold 1 Epoch 500: Loss=0.004093 | TrainAcc=1.0000
# Fold 1 Epoch 1000: Loss=0.001115 | TrainAcc=1.0000
# Fold 1 Epoch 1500: Loss=0.000392 | TrainAcc=1.0000
# Fold 1 Epoch 2000: Loss=0.000296 | TrainAcc=1.0000
# Fold 1 → Acc=0.9324 | Prec=0.9642 | Rec=0.9128 | F1=0.9378 | AUC=0.9805 | CE Loss=0.3152
#
# === Fold 2 ===
# Fold 2 Epoch 1: Loss=0.746971 | TrainAcc=0.5307
# Fold 2 Epoch 500: Loss=0.002859 | TrainAcc=1.0000
# Fold 2 Epoch 1000: Loss=0.000773 | TrainAcc=1.0000
# Fold 2 Epoch 1500: Loss=0.000446 | TrainAcc=1.0000
# Fold 2 Epoch 2000: Loss=0.000312 | TrainAcc=1.0000
# Fold 2 → Acc=0.9296 | Prec=0.9249 | Rec=0.9511 | F1=0.9378 | AUC=0.9740 | CE Loss=0.3636
#
# === Fold 3 ===
# Fold 3 Epoch 1: Loss=0.770836 | TrainAcc=0.5950
# Fold 3 Epoch 500: Loss=0.013127 | TrainAcc=0.9944
# Fold 3 Epoch 1000: Loss=0.001699 | TrainAcc=1.0000
# Fold 3 Epoch 1500: Loss=0.001185 | TrainAcc=1.0000
# Fold 3 Epoch 2000: Loss=0.000925 | TrainAcc=1.0000
# Fold 3 → Acc=0.9262 | Prec=0.9514 | Rec=0.9144 | F1=0.9326 | AUC=0.9790 | CE Loss=0.3086
#
# === Fold 4 ===
# Fold 4 Epoch 1: Loss=0.532456 | TrainAcc=0.7514
# Fold 4 Epoch 500: Loss=0.002666 | TrainAcc=1.0000
# Fold 4 Epoch 1000: Loss=0.000665 | TrainAcc=1.0000
# Fold 4 Epoch 1500: Loss=0.000376 | TrainAcc=1.0000
# Fold 4 Epoch 2000: Loss=0.000265 | TrainAcc=1.0000
# Fold 4 → Acc=0.9265 | Prec=0.9423 | Rec=0.9250 | F1=0.9336 | AUC=0.9734 | CE Loss=0.3553
#
# === Fold 5 ===
# Fold 5 Epoch 1: Loss=0.874396 | TrainAcc=0.4078
# Fold 5 Epoch 500: Loss=0.006741 | TrainAcc=1.0000
# Fold 5 Epoch 1000: Loss=0.001350 | TrainAcc=1.0000
# Fold 5 Epoch 1500: Loss=0.000655 | TrainAcc=1.0000
# Fold 5 Epoch 2000: Loss=0.000396 | TrainAcc=1.0000
# Fold 5 → Acc=0.9281 | Prec=0.9558 | Rec=0.9133 | F1=0.9341 | AUC=0.9737 | CE Loss=0.3322
#
# === Fold 6 ===
# Fold 6 Epoch 1: Loss=0.748865 | TrainAcc=0.4134
# Fold 6 Epoch 500: Loss=0.020104 | TrainAcc=0.9972
# Fold 6 Epoch 1000: Loss=0.001168 | TrainAcc=1.0000
# Fold 6 Epoch 1500: Loss=0.000769 | TrainAcc=1.0000
# Fold 6 Epoch 2000: Loss=0.000391 | TrainAcc=1.0000
# Fold 6 → Acc=0.9312 | Prec=0.9614 | Rec=0.9133 | F1=0.9368 | AUC=0.9804 | CE Loss=0.3068
#
# === Fold 7 ===
# Fold 7 Epoch 1: Loss=0.791879 | TrainAcc=0.3603
# Fold 7 Epoch 500: Loss=0.017052 | TrainAcc=0.9972
# Fold 7 Epoch 1000: Loss=0.001908 | TrainAcc=1.0000
# Fold 7 Epoch 1500: Loss=0.001159 | TrainAcc=1.0000
# Fold 7 Epoch 2000: Loss=0.000605 | TrainAcc=1.0000
# Fold 7 → Acc=0.9274 | Prec=0.9355 | Rec=0.9344 | F1=0.9350 | AUC=0.9750 | CE Loss=0.3197
#
# === Fold 8 ===
# Fold 8 Epoch 1: Loss=0.644007 | TrainAcc=0.6034
# Fold 8 Epoch 500: Loss=0.005141 | TrainAcc=1.0000
# Fold 8 Epoch 1000: Loss=0.001091 | TrainAcc=1.0000
# Fold 8 Epoch 1500: Loss=0.000584 | TrainAcc=1.0000
# Fold 8 Epoch 2000: Loss=0.000312 | TrainAcc=1.0000
# Fold 8 → Acc=0.9305 | Prec=0.9223 | Rec=0.9561 | F1=0.9389 | AUC=0.9696 | CE Loss=0.3762
#
# === Fold 9 ===
# Fold 9 Epoch 1: Loss=0.642245 | TrainAcc=0.5475
# Fold 9 Epoch 500: Loss=0.001946 | TrainAcc=1.0000
# Fold 9 Epoch 1000: Loss=0.000707 | TrainAcc=1.0000
# Fold 9 Epoch 1500: Loss=0.000345 | TrainAcc=1.0000
# Fold 9 Epoch 2000: Loss=0.000295 | TrainAcc=1.0000
# Fold 9 → Acc=0.9240 | Prec=0.9395 | Rec=0.9233 | F1=0.9314 | AUC=0.9752 | CE Loss=0.4204
#
# === Fold 10 ===
# Fold 10 Epoch 1: Loss=0.840537 | TrainAcc=0.2821
# Fold 10 Epoch 500: Loss=0.004858 | TrainAcc=1.0000
# Fold 10 Epoch 1000: Loss=0.003584 | TrainAcc=1.0000
# Fold 10 Epoch 1500: Loss=0.000906 | TrainAcc=1.0000
# Fold 10 Epoch 2000: Loss=0.000528 | TrainAcc=1.0000
# Fold 10 → Acc=0.9312 | Prec=0.9423 | Rec=0.9339 | F1=0.9381 | AUC=0.9775 | CE Loss=0.2972
#
# === Fold 11 ===
# Fold 11 Epoch 1: Loss=0.982870 | TrainAcc=0.2430
# Fold 11 Epoch 500: Loss=0.006244 | TrainAcc=1.0000
# Fold 11 Epoch 1000: Loss=0.001248 | TrainAcc=1.0000
# Fold 11 Epoch 1500: Loss=0.000673 | TrainAcc=1.0000
# Fold 11 Epoch 2000: Loss=0.000397 | TrainAcc=1.0000
# Fold 11 → Acc=0.9274 | Prec=0.9500 | Rec=0.9183 | F1=0.9339 | AUC=0.9742 | CE Loss=0.3406
#
# === Fold 12 ===
# Fold 12 Epoch 1: Loss=0.983414 | TrainAcc=0.3380
# Fold 12 Epoch 500: Loss=0.004635 | TrainAcc=1.0000
# Fold 12 Epoch 1000: Loss=0.000859 | TrainAcc=1.0000
# Fold 12 Epoch 1500: Loss=0.000456 | TrainAcc=1.0000
# Fold 12 Epoch 2000: Loss=0.000357 | TrainAcc=1.0000
# Fold 12 → Acc=0.9330 | Prec=0.9670 | Rec=0.9111 | F1=0.9382 | AUC=0.9806 | CE Loss=0.3336
#
# === Fold 13 ===
# Fold 13 Epoch 1: Loss=0.697446 | TrainAcc=0.5447
# Fold 13 Epoch 500: Loss=0.006281 | TrainAcc=1.0000
# Fold 13 Epoch 1000: Loss=0.001061 | TrainAcc=1.0000
# Fold 13 Epoch 1500: Loss=0.000494 | TrainAcc=1.0000
# Fold 13 Epoch 2000: Loss=0.001355 | TrainAcc=1.0000
# Fold 13 → Acc=0.9355 | Prec=0.9447 | Rec=0.9394 | F1=0.9421 | AUC=0.9816 | CE Loss=0.2903
#
# === Fold 14 ===
# Fold 14 Epoch 1: Loss=0.781393 | TrainAcc=0.4609
# Fold 14 Epoch 500: Loss=0.005263 | TrainAcc=1.0000
# Fold 14 Epoch 1000: Loss=0.001349 | TrainAcc=1.0000
# Fold 14 Epoch 1500: Loss=0.000480 | TrainAcc=1.0000
# Fold 14 Epoch 2000: Loss=0.000419 | TrainAcc=1.0000
# Fold 14 → Acc=0.9312 | Prec=0.9483 | Rec=0.9272 | F1=0.9376 | AUC=0.9758 | CE Loss=0.3132
#
# === Fold 15 ===
# Fold 15 Epoch 1: Loss=0.667412 | TrainAcc=0.5531
# Fold 15 Epoch 500: Loss=0.002773 | TrainAcc=1.0000
# Fold 15 Epoch 1000: Loss=0.001864 | TrainAcc=1.0000
# Fold 15 Epoch 1500: Loss=0.000469 | TrainAcc=1.0000
# Fold 15 Epoch 2000: Loss=0.000298 | TrainAcc=1.0000
# Fold 15 → Acc=0.9330 | Prec=0.9323 | Rec=0.9489 | F1=0.9405 | AUC=0.9777 | CE Loss=0.3197
#
# === Fold 16 ===
# Fold 16 Epoch 1: Loss=0.735786 | TrainAcc=0.4721
# Fold 16 Epoch 500: Loss=0.005085 | TrainAcc=1.0000
# Fold 16 Epoch 1000: Loss=0.000662 | TrainAcc=1.0000
# Fold 16 Epoch 1500: Loss=0.000725 | TrainAcc=1.0000
# Fold 16 Epoch 2000: Loss=0.000281 | TrainAcc=1.0000
# Fold 16 → Acc=0.9355 | Prec=0.9230 | Rec=0.9650 | F1=0.9435 | AUC=0.9791 | CE Loss=0.3021
#
# === Fold 17 ===
# Fold 17 Epoch 1: Loss=0.728556 | TrainAcc=0.3966
# Fold 17 Epoch 500: Loss=0.012621 | TrainAcc=1.0000
# Fold 17 Epoch 1000: Loss=0.002788 | TrainAcc=1.0000
# Fold 17 Epoch 1500: Loss=0.001609 | TrainAcc=1.0000
# Fold 17 Epoch 2000: Loss=0.000575 | TrainAcc=1.0000
# Fold 17 → Acc=0.9281 | Prec=0.9360 | Rec=0.9350 | F1=0.9355 | AUC=0.9749 | CE Loss=0.3744
#
# === Fold 18 ===
# Fold 18 Epoch 1: Loss=0.556615 | TrainAcc=0.7682
# Fold 18 Epoch 500: Loss=0.040254 | TrainAcc=0.9916
# Fold 18 Epoch 1000: Loss=0.010860 | TrainAcc=1.0000
# Fold 18 Epoch 1500: Loss=0.006620 | TrainAcc=0.9972
# Fold 18 Epoch 2000: Loss=0.001944 | TrainAcc=1.0000
# Fold 18 → Acc=0.9212 | Prec=0.9377 | Rec=0.9200 | F1=0.9288 | AUC=0.9705 | CE Loss=0.3231
#
# === Fold 19 ===
# Fold 19 Epoch 1: Loss=0.787691 | TrainAcc=0.3883
# Fold 19 Epoch 500: Loss=0.004521 | TrainAcc=1.0000
# Fold 19 Epoch 1000: Loss=0.000850 | TrainAcc=1.0000
# Fold 19 Epoch 1500: Loss=0.000616 | TrainAcc=1.0000
# Fold 19 Epoch 2000: Loss=0.000316 | TrainAcc=1.0000
# Fold 19 → Acc=0.9371 | Prec=0.9618 | Rec=0.9239 | F1=0.9425 | AUC=0.9807 | CE Loss=0.3205
#
# === Fold 20 ===
# Fold 20 Epoch 1: Loss=0.800422 | TrainAcc=0.4134
