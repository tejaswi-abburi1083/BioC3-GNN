# %%
import torch
import torch.nn as nn
import torch.nn.functional as nnFn
import torch.optim as optim
import numpy as np
import random
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from torch_geometric.data import Data
from torch_geometric.nn import ARMAConv
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, roc_auc_score, log_loss
)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print("Device:", device)

# === Load Patients ===
fa_patients_path = "/home/snu/Downloads/NIFD_Patients_FA_Histogram_Feature.npy"
Patients_FA_array = np.load(fa_patients_path, allow_pickle=True)

# === Load Controls ===
fa_controls_path = "/home/snu/Downloads/NIFD_Control_FA_Histogram_Feature.npy"
Controls_FA_array = np.load(fa_controls_path, allow_pickle=True)

print("Patients Shape:", Patients_FA_array.shape)
print("Controls Shape:", Controls_FA_array.shape)

# === Combine features and labels ===
X = np.vstack([Controls_FA_array, Patients_FA_array])
y = np.hstack([
    np.zeros(Controls_FA_array.shape[0], dtype=np.int64),  # 0 = Control
    np.ones(Patients_FA_array.shape[0], dtype=np.int64)    # 1 = Patient
])

# Shuffle
np.random.seed(42)
perm = np.random.permutation(X.shape[0])
X = X[perm]
y = y[perm]
# Out:
# Device: cuda
# Patients Shape: (98, 180)
# Controls Shape: (48, 180)

# %%
class ARMA_SemiSupervised(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, device, activ="ELU"):
        super(ARMA_SemiSupervised, self).__init__()
        self.device = device
        self.conv1 = ARMAConv(input_dim, hidden_dim, num_stacks=1, num_layers=1)
        self.bn1 = nn.BatchNorm1d(hidden_dim)
        self.dropout = nn.Dropout(0.2)
        self.fc = nn.Linear(hidden_dim, output_dim)
        self.num_clusters = output_dim

        activations = {
            "SELU": nnFn.selu,
            "SiLU": nnFn.silu,
            "GELU": nnFn.gelu,
            "RELU": nnFn.relu,
            "ELU": nnFn.elu
        }
        self.act = activations.get(activ, nnFn.elu)

    def forward(self, data):
      x, edge_index = data.x, data.edge_index
      x_in = x
      x = self.conv1(x, edge_index)
      x = self.bn1(x)

      if x_in.shape[1] == x.shape[1]:
          x = x + x_in  # residual (skip) connection is added

      x = self.act(x)
      x = self.dropout(x)
      logits = self.fc(x)
      return logits

    def cut_loss(self, A, S):
        S = nnFn.softmax(S, dim=1)
        A_pool = torch.matmul(torch.matmul(A, S).t(), S)
        num = torch.trace(A_pool)

        D = torch.diag(torch.sum(A, dim=-1))
        D_pooled = torch.matmul(torch.matmul(D, S).t(), S)
        den = torch.trace(D_pooled)
        mincut_loss = -(num / den)

        St_S = torch.matmul(S.t(), S)
        I_S = torch.eye(self.num_clusters, device=self.device)
        ortho_loss = torch.norm(St_S / torch.norm(St_S) - I_S / torch.norm(I_S))

        return mincut_loss + ortho_loss

# %%
def create_adj(F, alpha=1):
    F_norm = F / np.linalg.norm(F, axis=1, keepdims=True)
    W = np.dot(F_norm, F_norm.T)
    W = np.where(W >= alpha, 1, 0).astype(np.float32)
    W = W / W.max()
    return W

def load_data(adj, node_feats):
    node_feats = torch.from_numpy(node_feats).float()
    edge_index = torch.from_numpy(np.array(np.nonzero((adj > 0))))
    return Data(x=node_feats, edge_index=edge_index)

# %%
num_nodes, num_feats = X.shape
print(f"Number of features: {num_feats}")
# Out:
# Number of features: 180

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
alpha = 0.5
feats_dim = num_feats
hidden_dim = 512
num_classes = 2
num_epochs = 2000
lr = 0.0001
weight_decay = 1e-4
batch_print_freq = 100
lambda_mod = 0.01 #0.01  # weight for modularity loss
# lambda_sup = 5

# %%
W = create_adj(X, alpha)
data = load_data(W, X).to(device)
A_tensor = torch.from_numpy(W).float().to(device)
print(data)
# Out:
# Data(x=[146, 180], edge_index=[2, 21256])

# %%
sss = StratifiedShuffleSplit(n_splits=20, test_size=0.9, random_state=42)

accuracies, precisions, recalls, f1_scores, aucs, ce_losses = [], [], [], [], [], []

for fold, (train_val_idx, test_idx_global) in enumerate(sss.split(X, y), start=1):
    print(f"\n=== Fold {fold} ===")

    # Split into controls (label 0) and patients (label 1)
    controls_idx = np.where(y == 0)[0]
    patients_idx = np.where(y == 1)[0]

    sss_class = StratifiedShuffleSplit(n_splits=20, test_size=0.9, random_state=fold)
    controls_train_idx, _ = next(sss_class.split(X[controls_idx], y[controls_idx]))
    patients_train_idx, _ = next(sss_class.split(X[patients_idx], y[patients_idx]))

    controls_train = controls_idx[controls_train_idx]
    patients_train = patients_idx[patients_train_idx]
    train_idx_final = np.concatenate([controls_train, patients_train])
    np.random.shuffle(train_idx_final)

    print(f"Train Controls: {len(controls_train)}, Train Patients: {len(patients_train)}")

    train_idx_t = torch.from_numpy(train_idx_final).long().to(device)
    y_train_tensor = torch.from_numpy(y[train_idx_final]).long().to(device)

    # Initialize model and optimizer
    model = ARMA_SemiSupervised(feats_dim, hidden_dim, num_classes, device, "SELU").to(device)
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    ce_loss = nn.CrossEntropyLoss()

    # Training loop
    for epoch in range(1, num_epochs + 1):
        model.train()
        optimizer.zero_grad()

        logits = model(data)
        loss_sup = ce_loss(logits[train_idx_t], y_train_tensor)
        loss_unsup = model.cut_loss(A_tensor, logits)
        total_loss = loss_sup + lambda_mod * loss_unsup

        total_loss.backward()
        optimizer.step()

        if epoch % batch_print_freq == 0 or epoch == 1:
            model.eval()
            with torch.no_grad():
                preds_train = logits[train_idx_t].argmax(dim=1)
                acc_train = accuracy_score(y_train_tensor.cpu(), preds_train.cpu())
            print(f"Fold {fold} Epoch {epoch}: "
                  f"TotalLoss={total_loss.item():.6f} | Sup={loss_sup.item():.6f} | "
                  f"Unsup={loss_unsup.item():.6f} | TrainAcc={acc_train:.4f}")

    # Evaluation
    model.eval()
    with torch.no_grad():
        out = model(data)
        preds = out.argmax(dim=1).cpu().numpy()
        probs = torch.softmax(out, dim=1)[:, 1].cpu().numpy()

    y_test = y[test_idx_global]
    y_pred_test = preds[test_idx_global]
    y_prob_test = probs[test_idx_global]

    acc = accuracy_score(y_test, y_pred_test)
    prec = precision_score(y_test, y_pred_test, zero_division=0)
    rec = recall_score(y_test, y_pred_test, zero_division=0)
    f1 = f1_score(y_test, y_pred_test, zero_division=0)
    auc = roc_auc_score(y_test, y_prob_test)
    ce = log_loss(y_test, y_prob_test)

    accuracies.append(acc)
    precisions.append(prec)
    recalls.append(rec)
    f1_scores.append(f1)
    aucs.append(auc)
    ce_losses.append(ce)

    print(f"Fold {fold} → "
          f"Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | "
          f"F1={f1:.4f} | AUC={auc:.4f} | CE Loss={ce:.4f}")

# Summary across all folds
print("\n=== Average Results Across 20 Folds (Controls vs Patients) ===")
print(f"Accuracy:  {np.mean(accuracies):.4f} ± {np.std(accuracies):.4f}")
print(f"Precision: {np.mean(precisions):.4f} ± {np.std(precisions):.4f}")
print(f"Recall:    {np.mean(recalls):.4f} ± {np.std(recalls):.4f}")
print(f"F1-score:  {np.mean(f1_scores):.4f} ± {np.std(f1_scores):.4f}")
print(f"AUC:       {np.mean(aucs):.4f} ± {np.std(aucs):.4f}")
print(f"CE Loss:   {np.mean(ce_losses):.4f} ± {np.std(ce_losses):.4f}")
# Out:
# === Fold 1 ===
# Train Controls: 4, Train Patients: 9
# Fold 1 Epoch 1: TotalLoss=0.912531 | Sup=0.914981 | Unsup=-0.245040 | TrainAcc=0.2308
# Fold 1 Epoch 100: TotalLoss=0.020418 | Sup=0.023120 | Unsup=-0.270217 | TrainAcc=1.0000
# Fold 1 Epoch 200: TotalLoss=0.005073 | Sup=0.007893 | Unsup=-0.281981 | TrainAcc=1.0000
# Fold 1 Epoch 300: TotalLoss=0.001252 | Sup=0.004080 | Unsup=-0.282775 | TrainAcc=1.0000
# Fold 1 Epoch 400: TotalLoss=-0.000719 | Sup=0.002262 | Unsup=-0.298111 | TrainAcc=1.0000
# Fold 1 Epoch 500: TotalLoss=-0.001686 | Sup=0.001408 | Unsup=-0.309335 | TrainAcc=1.0000
# Fold 1 Epoch 600: TotalLoss=-0.002711 | Sup=0.000613 | Unsup=-0.332408 | TrainAcc=1.0000
# Fold 1 Epoch 700: TotalLoss=-0.003206 | Sup=0.000350 | Unsup=-0.355571 | TrainAcc=1.0000
# Fold 1 Epoch 800: TotalLoss=-0.003750 | Sup=0.000183 | Unsup=-0.393329 | TrainAcc=1.0000
# Fold 1 Epoch 900: TotalLoss=-0.003799 | Sup=0.000289 | Unsup=-0.408767 | TrainAcc=1.0000
# Fold 1 Epoch 1000: TotalLoss=-0.004309 | Sup=0.000095 | Unsup=-0.440431 | TrainAcc=1.0000
# Fold 1 Epoch 1100: TotalLoss=-0.004479 | Sup=0.000084 | Unsup=-0.456281 | TrainAcc=1.0000
# Fold 1 Epoch 1200: TotalLoss=-0.004605 | Sup=0.000046 | Unsup=-0.465101 | TrainAcc=1.0000
# Fold 1 Epoch 1300: TotalLoss=-0.004711 | Sup=0.000033 | Unsup=-0.474420 | TrainAcc=1.0000
# Fold 1 Epoch 1400: TotalLoss=-0.004756 | Sup=0.000023 | Unsup=-0.477889 | TrainAcc=1.0000
# Fold 1 Epoch 1500: TotalLoss=-0.004803 | Sup=0.000033 | Unsup=-0.483523 | TrainAcc=1.0000
# Fold 1 Epoch 1600: TotalLoss=-0.004855 | Sup=0.000019 | Unsup=-0.487387 | TrainAcc=1.0000
# Fold 1 Epoch 1700: TotalLoss=-0.004859 | Sup=0.000027 | Unsup=-0.488586 | TrainAcc=1.0000
# Fold 1 Epoch 1800: TotalLoss=-0.004878 | Sup=0.000016 | Unsup=-0.489398 | TrainAcc=1.0000
# Fold 1 Epoch 1900: TotalLoss=-0.004885 | Sup=0.000012 | Unsup=-0.489765 | TrainAcc=1.0000
# Fold 1 Epoch 2000: TotalLoss=-0.004894 | Sup=0.000009 | Unsup=-0.490368 | TrainAcc=1.0000
# Fold 1 → Acc=0.6515 | Prec=0.8116 | Rec=0.6292 | F1=0.7089 | AUC=0.7392 | CE Loss=1.8314
#
# === Fold 2 ===
# Train Controls: 4, Train Patients: 9
# Fold 2 Epoch 1: TotalLoss=0.928353 | Sup=0.930736 | Unsup=-0.238219 | TrainAcc=0.3077
# Fold 2 Epoch 100: TotalLoss=0.029801 | Sup=0.032640 | Unsup=-0.283908 | TrainAcc=1.0000
# Fold 2 Epoch 200: TotalLoss=0.004943 | Sup=0.007930 | Unsup=-0.298735 | TrainAcc=1.0000
# Fold 2 Epoch 300: TotalLoss=0.000964 | Sup=0.004171 | Unsup=-0.320745 | TrainAcc=1.0000
# Fold 2 Epoch 400: TotalLoss=-0.001223 | Sup=0.001971 | Unsup=-0.319414 | TrainAcc=1.0000
# Fold 2 Epoch 500: TotalLoss=-0.001738 | Sup=0.001569 | Unsup=-0.330745 | TrainAcc=1.0000
# Fold 2 Epoch 600: TotalLoss=-0.002769 | Sup=0.000706 | Unsup=-0.347522 | TrainAcc=1.0000
# Fold 2 Epoch 700: TotalLoss=-0.003058 | Sup=0.000654 | Unsup=-0.371163 | TrainAcc=1.0000
# Fold 2 Epoch 800: TotalLoss=-0.003344 | Sup=0.000543 | Unsup=-0.388776 | TrainAcc=1.0000
# Fold 2 Epoch 900: TotalLoss=-0.003774 | Sup=0.000275 | Unsup=-0.404882 | TrainAcc=1.0000
# Fold 2 Epoch 1000: TotalLoss=-0.004241 | Sup=0.000097 | Unsup=-0.433880 | TrainAcc=1.0000
# Fold 2 Epoch 1100: TotalLoss=-0.004552 | Sup=0.000064 | Unsup=-0.461637 | TrainAcc=1.0000
# Fold 2 Epoch 1200: TotalLoss=-0.004671 | Sup=0.000064 | Unsup=-0.473566 | TrainAcc=1.0000
# Fold 2 Epoch 1300: TotalLoss=-0.004771 | Sup=0.000026 | Unsup=-0.479618 | TrainAcc=1.0000
# Fold 2 Epoch 1400: TotalLoss=-0.004846 | Sup=0.000016 | Unsup=-0.486191 | TrainAcc=1.0000
# Fold 2 Epoch 1500: TotalLoss=-0.004878 | Sup=0.000008 | Unsup=-0.488561 | TrainAcc=1.0000
# Fold 2 Epoch 1600: TotalLoss=-0.004890 | Sup=0.000011 | Unsup=-0.490122 | TrainAcc=1.0000
# Fold 2 Epoch 1700: TotalLoss=-0.004904 | Sup=0.000010 | Unsup=-0.491392 | TrainAcc=1.0000
# Fold 2 Epoch 1800: TotalLoss=-0.004904 | Sup=0.000011 | Unsup=-0.491500 | TrainAcc=1.0000
# Fold 2 Epoch 1900: TotalLoss=-0.004915 | Sup=0.000006 | Unsup=-0.492114 | TrainAcc=1.0000
# Fold 2 Epoch 2000: TotalLoss=-0.004911 | Sup=0.000014 | Unsup=-0.492452 | TrainAcc=1.0000
# Fold 2 → Acc=0.7121 | Prec=0.8923 | Rec=0.6517 | F1=0.7532 | AUC=0.8174 | CE Loss=1.5034
#
# === Fold 3 ===
# Train Controls: 4, Train Patients: 9
# Fold 3 Epoch 1: TotalLoss=0.941398 | Sup=0.943787 | Unsup=-0.238910 | TrainAcc=0.3846
# Fold 3 Epoch 100: TotalLoss=0.018888 | Sup=0.021999 | Unsup=-0.311110 | TrainAcc=1.0000
# Fold 3 Epoch 200: TotalLoss=0.003220 | Sup=0.006536 | Unsup=-0.331637 | TrainAcc=1.0000
# Fold 3 Epoch 300: TotalLoss=-0.000144 | Sup=0.003404 | Unsup=-0.354832 | TrainAcc=1.0000
# Fold 3 Epoch 400: TotalLoss=-0.001586 | Sup=0.002066 | Unsup=-0.365274 | TrainAcc=1.0000
# Fold 3 Epoch 500: TotalLoss=-0.002522 | Sup=0.001243 | Unsup=-0.376493 | TrainAcc=1.0000
# Fold 3 Epoch 600: TotalLoss=-0.003206 | Sup=0.000701 | Unsup=-0.390726 | TrainAcc=1.0000
# Fold 3 Epoch 700: TotalLoss=-0.003608 | Sup=0.000555 | Unsup=-0.416351 | TrainAcc=1.0000
# Fold 3 Epoch 800: TotalLoss=-0.004150 | Sup=0.000189 | Unsup=-0.433951 | TrainAcc=1.0000
# Fold 3 Epoch 900: TotalLoss=-0.004365 | Sup=0.000094 | Unsup=-0.445906 | TrainAcc=1.0000
# Fold 3 Epoch 1000: TotalLoss=-0.004537 | Sup=0.000082 | Unsup=-0.461930 | TrainAcc=1.0000
# Fold 3 Epoch 1100: TotalLoss=-0.004650 | Sup=0.000062 | Unsup=-0.471260 | TrainAcc=1.0000
# Fold 3 Epoch 1200: TotalLoss=-0.004724 | Sup=0.000052 | Unsup=-0.477624 | TrainAcc=1.0000
# Fold 3 Epoch 1300: TotalLoss=-0.004810 | Sup=0.000026 | Unsup=-0.483625 | TrainAcc=1.0000
# Fold 3 Epoch 1400: TotalLoss=-0.004829 | Sup=0.000042 | Unsup=-0.487084 | TrainAcc=1.0000
# Fold 3 Epoch 1500: TotalLoss=-0.004830 | Sup=0.000043 | Unsup=-0.487287 | TrainAcc=1.0000
# Fold 3 Epoch 1600: TotalLoss=-0.004893 | Sup=0.000013 | Unsup=-0.490644 | TrainAcc=1.0000
# Fold 3 Epoch 1700: TotalLoss=-0.004904 | Sup=0.000014 | Unsup=-0.491764 | TrainAcc=1.0000
# Fold 3 Epoch 1800: TotalLoss=-0.004923 | Sup=0.000007 | Unsup=-0.493047 | TrainAcc=1.0000
# Fold 3 Epoch 1900: TotalLoss=-0.004941 | Sup=0.000010 | Unsup=-0.495036 | TrainAcc=1.0000
# Fold 3 Epoch 2000: TotalLoss=-0.004955 | Sup=0.000007 | Unsup=-0.496160 | TrainAcc=1.0000
# Fold 3 → Acc=0.7121 | Prec=0.8806 | Rec=0.6629 | F1=0.7564 | AUC=0.8103 | CE Loss=1.6858
#
# === Fold 4 ===
# Train Controls: 4, Train Patients: 9
# Fold 4 Epoch 1: TotalLoss=0.756972 | Sup=0.759330 | Unsup=-0.235823 | TrainAcc=0.4615
# Fold 4 Epoch 100: TotalLoss=0.034171 | Sup=0.037237 | Unsup=-0.306530 | TrainAcc=1.0000
# Fold 4 Epoch 200: TotalLoss=0.005527 | Sup=0.008941 | Unsup=-0.341431 | TrainAcc=1.0000
# Fold 4 Epoch 300: TotalLoss=0.001072 | Sup=0.004609 | Unsup=-0.353764 | TrainAcc=1.0000
# Fold 4 Epoch 400: TotalLoss=-0.001815 | Sup=0.001887 | Unsup=-0.370161 | TrainAcc=1.0000
# Fold 4 Epoch 500: TotalLoss=-0.002641 | Sup=0.001255 | Unsup=-0.389588 | TrainAcc=1.0000
# Fold 4 Epoch 600: TotalLoss=-0.003198 | Sup=0.000860 | Unsup=-0.405844 | TrainAcc=1.0000
# Fold 4 Epoch 700: TotalLoss=-0.003898 | Sup=0.000366 | Unsup=-0.426448 | TrainAcc=1.0000
# Fold 4 Epoch 800: TotalLoss=-0.004334 | Sup=0.000112 | Unsup=-0.444592 | TrainAcc=1.0000
# Fold 4 Epoch 900: TotalLoss=-0.004471 | Sup=0.000100 | Unsup=-0.457143 | TrainAcc=1.0000
# Fold 4 Epoch 1000: TotalLoss=-0.004620 | Sup=0.000110 | Unsup=-0.473020 | TrainAcc=1.0000
# Fold 4 Epoch 1100: TotalLoss=-0.004730 | Sup=0.000050 | Unsup=-0.477995 | TrainAcc=1.0000
# Fold 4 Epoch 1200: TotalLoss=-0.004799 | Sup=0.000038 | Unsup=-0.483745 | TrainAcc=1.0000
# Fold 4 Epoch 1300: TotalLoss=-0.004852 | Sup=0.000034 | Unsup=-0.488594 | TrainAcc=1.0000
# Fold 4 Epoch 1400: TotalLoss=-0.004877 | Sup=0.000028 | Unsup=-0.490455 | TrainAcc=1.0000
# Fold 4 Epoch 1500: TotalLoss=-0.004905 | Sup=0.000017 | Unsup=-0.492238 | TrainAcc=1.0000
# Fold 4 Epoch 1600: TotalLoss=-0.004916 | Sup=0.000013 | Unsup=-0.492831 | TrainAcc=1.0000
# Fold 4 Epoch 1700: TotalLoss=-0.004925 | Sup=0.000011 | Unsup=-0.493577 | TrainAcc=1.0000
# Fold 4 Epoch 1800: TotalLoss=-0.004937 | Sup=0.000011 | Unsup=-0.494819 | TrainAcc=1.0000
# Fold 4 Epoch 1900: TotalLoss=-0.004945 | Sup=0.000012 | Unsup=-0.495670 | TrainAcc=1.0000
# Fold 4 Epoch 2000: TotalLoss=-0.004946 | Sup=0.000011 | Unsup=-0.495714 | TrainAcc=1.0000
# Fold 4 → Acc=0.6742 | Prec=0.8485 | Rec=0.6292 | F1=0.7226 | AUC=0.7557 | CE Loss=1.9766
#
# === Fold 5 ===
# Train Controls: 4, Train Patients: 9
# Fold 5 Epoch 1: TotalLoss=0.881458 | Sup=0.883811 | Unsup=-0.235275 | TrainAcc=0.2308
# Fold 5 Epoch 100: TotalLoss=0.019482 | Sup=0.022790 | Unsup=-0.330855 | TrainAcc=1.0000
# Fold 5 Epoch 200: TotalLoss=0.003017 | Sup=0.006599 | Unsup=-0.358192 | TrainAcc=1.0000
# Fold 5 Epoch 300: TotalLoss=0.000191 | Sup=0.003963 | Unsup=-0.377182 | TrainAcc=1.0000
# Fold 5 Epoch 400: TotalLoss=-0.002033 | Sup=0.001854 | Unsup=-0.388735 | TrainAcc=1.0000
# Fold 5 Epoch 500: TotalLoss=-0.002795 | Sup=0.001186 | Unsup=-0.398134 | TrainAcc=1.0000
# Fold 5 Epoch 600: TotalLoss=-0.003172 | Sup=0.000860 | Unsup=-0.403128 | TrainAcc=1.0000
# Fold 5 Epoch 700: TotalLoss=-0.003733 | Sup=0.000412 | Unsup=-0.414420 | TrainAcc=1.0000
# Fold 5 Epoch 800: TotalLoss=-0.004095 | Sup=0.000201 | Unsup=-0.429513 | TrainAcc=1.0000
# Fold 5 Epoch 900: TotalLoss=-0.004151 | Sup=0.000258 | Unsup=-0.440913 | TrainAcc=1.0000
# Fold 5 Epoch 1000: TotalLoss=-0.004429 | Sup=0.000089 | Unsup=-0.451742 | TrainAcc=1.0000
# Fold 5 Epoch 1100: TotalLoss=-0.004540 | Sup=0.000055 | Unsup=-0.459531 | TrainAcc=1.0000
# Fold 5 Epoch 1200: TotalLoss=-0.004592 | Sup=0.000066 | Unsup=-0.465803 | TrainAcc=1.0000
# Fold 5 Epoch 1300: TotalLoss=-0.004729 | Sup=0.000027 | Unsup=-0.475548 | TrainAcc=1.0000
# Fold 5 Epoch 1400: TotalLoss=-0.004779 | Sup=0.000017 | Unsup=-0.479591 | TrainAcc=1.0000
# Fold 5 Epoch 1500: TotalLoss=-0.004823 | Sup=0.000032 | Unsup=-0.485556 | TrainAcc=1.0000
# Fold 5 Epoch 1600: TotalLoss=-0.004844 | Sup=0.000016 | Unsup=-0.485916 | TrainAcc=1.0000
# Fold 5 Epoch 1700: TotalLoss=-0.004884 | Sup=0.000010 | Unsup=-0.489424 | TrainAcc=1.0000
# Fold 5 Epoch 1800: TotalLoss=-0.004882 | Sup=0.000011 | Unsup=-0.489276 | TrainAcc=1.0000
# Fold 5 Epoch 1900: TotalLoss=-0.004892 | Sup=0.000010 | Unsup=-0.490238 | TrainAcc=1.0000
# Fold 5 Epoch 2000: TotalLoss=-0.004905 | Sup=0.000011 | Unsup=-0.491687 | TrainAcc=1.0000
# Fold 5 → Acc=0.7121 | Prec=0.8923 | Rec=0.6517 | F1=0.7532 | AUC=0.8401 | CE Loss=1.5747
#
# === Fold 6 ===
# Train Controls: 4, Train Patients: 9
# Fold 6 Epoch 1: TotalLoss=0.697907 | Sup=0.700272 | Unsup=-0.236504 | TrainAcc=0.5385
# Fold 6 Epoch 100: TotalLoss=0.016602 | Sup=0.019432 | Unsup=-0.282991 | TrainAcc=1.0000
# Fold 6 Epoch 200: TotalLoss=0.002498 | Sup=0.005584 | Unsup=-0.308658 | TrainAcc=1.0000
# Fold 6 Epoch 300: TotalLoss=-0.000947 | Sup=0.002294 | Unsup=-0.324134 | TrainAcc=1.0000
# Fold 6 Epoch 400: TotalLoss=-0.001531 | Sup=0.001918 | Unsup=-0.344845 | TrainAcc=1.0000
# Fold 6 Epoch 500: TotalLoss=-0.002178 | Sup=0.001414 | Unsup=-0.359174 | TrainAcc=1.0000
# Fold 6 Epoch 600: TotalLoss=-0.003403 | Sup=0.000436 | Unsup=-0.383892 | TrainAcc=1.0000
# Fold 6 Epoch 700: TotalLoss=-0.003911 | Sup=0.000259 | Unsup=-0.417031 | TrainAcc=1.0000
# Fold 6 Epoch 800: TotalLoss=-0.004308 | Sup=0.000144 | Unsup=-0.445244 | TrainAcc=1.0000
# Fold 6 Epoch 900: TotalLoss=-0.004499 | Sup=0.000112 | Unsup=-0.461098 | TrainAcc=1.0000
# Fold 6 Epoch 1000: TotalLoss=-0.004650 | Sup=0.000073 | Unsup=-0.472307 | TrainAcc=1.0000
# Fold 6 Epoch 1100: TotalLoss=-0.004731 | Sup=0.000048 | Unsup=-0.477847 | TrainAcc=1.0000
# Fold 6 Epoch 1200: TotalLoss=-0.004810 | Sup=0.000033 | Unsup=-0.484229 | TrainAcc=1.0000
# Fold 6 Epoch 1300: TotalLoss=-0.004857 | Sup=0.000036 | Unsup=-0.489315 | TrainAcc=1.0000
# Fold 6 Epoch 1400: TotalLoss=-0.004865 | Sup=0.000020 | Unsup=-0.488574 | TrainAcc=1.0000
# Fold 6 Epoch 1500: TotalLoss=-0.004892 | Sup=0.000018 | Unsup=-0.491023 | TrainAcc=1.0000
# Fold 6 Epoch 1600: TotalLoss=-0.004910 | Sup=0.000009 | Unsup=-0.491892 | TrainAcc=1.0000
# Fold 6 Epoch 1700: TotalLoss=-0.004925 | Sup=0.000011 | Unsup=-0.493551 | TrainAcc=1.0000
# Fold 6 Epoch 1800: TotalLoss=-0.004923 | Sup=0.000015 | Unsup=-0.493758 | TrainAcc=1.0000
# Fold 6 Epoch 1900: TotalLoss=-0.004934 | Sup=0.000016 | Unsup=-0.495044 | TrainAcc=1.0000
# Fold 6 Epoch 2000: TotalLoss=-0.004935 | Sup=0.000010 | Unsup=-0.494561 | TrainAcc=1.0000
# Fold 6 → Acc=0.6364 | Prec=0.8060 | Rec=0.6067 | F1=0.6923 | AUC=0.7322 | CE Loss=2.0267
#
# === Fold 7 ===
# Train Controls: 4, Train Patients: 9
# Fold 7 Epoch 1: TotalLoss=0.837195 | Sup=0.839608 | Unsup=-0.241309 | TrainAcc=0.5385
# Fold 7 Epoch 100: TotalLoss=0.019244 | Sup=0.022007 | Unsup=-0.276367 | TrainAcc=1.0000
# Fold 7 Epoch 200: TotalLoss=0.007286 | Sup=0.010174 | Unsup=-0.288806 | TrainAcc=1.0000
# Fold 7 Epoch 300: TotalLoss=0.001342 | Sup=0.004348 | Unsup=-0.300609 | TrainAcc=1.0000
# Fold 7 Epoch 400: TotalLoss=-0.001448 | Sup=0.001635 | Unsup=-0.308292 | TrainAcc=1.0000
# Fold 7 Epoch 500: TotalLoss=-0.002151 | Sup=0.001257 | Unsup=-0.340803 | TrainAcc=1.0000
# Fold 7 Epoch 600: TotalLoss=-0.003062 | Sup=0.000461 | Unsup=-0.352249 | TrainAcc=1.0000
# Fold 7 Epoch 700: TotalLoss=-0.003343 | Sup=0.000435 | Unsup=-0.377746 | TrainAcc=1.0000
# Fold 7 Epoch 800: TotalLoss=-0.003888 | Sup=0.000195 | Unsup=-0.408270 | TrainAcc=1.0000
# Fold 7 Epoch 900: TotalLoss=-0.004138 | Sup=0.000145 | Unsup=-0.428232 | TrainAcc=1.0000
# Fold 7 Epoch 1000: TotalLoss=-0.004382 | Sup=0.000079 | Unsup=-0.446130 | TrainAcc=1.0000
# Fold 7 Epoch 1100: TotalLoss=-0.004470 | Sup=0.000071 | Unsup=-0.454137 | TrainAcc=1.0000
# Fold 7 Epoch 1200: TotalLoss=-0.004627 | Sup=0.000038 | Unsup=-0.466493 | TrainAcc=1.0000
# Fold 7 Epoch 1300: TotalLoss=-0.004702 | Sup=0.000032 | Unsup=-0.473376 | TrainAcc=1.0000
# Fold 7 Epoch 1400: TotalLoss=-0.004748 | Sup=0.000028 | Unsup=-0.477555 | TrainAcc=1.0000
# Fold 7 Epoch 1500: TotalLoss=-0.004785 | Sup=0.000019 | Unsup=-0.480374 | TrainAcc=1.0000
# Fold 7 Epoch 1600: TotalLoss=-0.004815 | Sup=0.000016 | Unsup=-0.483108 | TrainAcc=1.0000
# Fold 7 Epoch 1700: TotalLoss=-0.004837 | Sup=0.000014 | Unsup=-0.485030 | TrainAcc=1.0000
# Fold 7 Epoch 1800: TotalLoss=-0.004873 | Sup=0.000011 | Unsup=-0.488424 | TrainAcc=1.0000
# Fold 7 Epoch 1900: TotalLoss=-0.004897 | Sup=0.000011 | Unsup=-0.490843 | TrainAcc=1.0000
# Fold 7 Epoch 2000: TotalLoss=-0.004901 | Sup=0.000012 | Unsup=-0.491273 | TrainAcc=1.0000
# Fold 7 → Acc=0.6591 | Prec=0.8333 | Rec=0.6180 | F1=0.7097 | AUC=0.7646 | CE Loss=1.7519
#
# === Fold 8 ===
# Train Controls: 4, Train Patients: 9
# Fold 8 Epoch 1: TotalLoss=0.655992 | Sup=0.658382 | Unsup=-0.238939 | TrainAcc=0.7692
# Fold 8 Epoch 100: TotalLoss=0.027582 | Sup=0.030548 | Unsup=-0.296608 | TrainAcc=1.0000
# Fold 8 Epoch 200: TotalLoss=0.003031 | Sup=0.006244 | Unsup=-0.321351 | TrainAcc=1.0000
# Fold 8 Epoch 300: TotalLoss=0.000042 | Sup=0.003443 | Unsup=-0.340034 | TrainAcc=1.0000
# Fold 8 Epoch 400: TotalLoss=-0.001980 | Sup=0.001668 | Unsup=-0.364804 | TrainAcc=1.0000
# Fold 8 Epoch 500: TotalLoss=-0.002962 | Sup=0.000867 | Unsup=-0.382847 | TrainAcc=1.0000
# Fold 8 Epoch 600: TotalLoss=-0.003300 | Sup=0.000654 | Unsup=-0.395396 | TrainAcc=1.0000
# Fold 8 Epoch 700: TotalLoss=-0.003774 | Sup=0.000368 | Unsup=-0.414173 | TrainAcc=1.0000
# Fold 8 Epoch 800: TotalLoss=-0.004041 | Sup=0.000266 | Unsup=-0.430715 | TrainAcc=1.0000
# Fold 8 Epoch 900: TotalLoss=-0.004350 | Sup=0.000100 | Unsup=-0.444996 | TrainAcc=1.0000
# Fold 8 Epoch 1000: TotalLoss=-0.004581 | Sup=0.000090 | Unsup=-0.467156 | TrainAcc=1.0000
# Fold 8 Epoch 1100: TotalLoss=-0.004727 | Sup=0.000048 | Unsup=-0.477462 | TrainAcc=1.0000
# Fold 8 Epoch 1200: TotalLoss=-0.004831 | Sup=0.000024 | Unsup=-0.485467 | TrainAcc=1.0000
# Fold 8 Epoch 1300: TotalLoss=-0.004890 | Sup=0.000013 | Unsup=-0.490337 | TrainAcc=1.0000
# Fold 8 Epoch 1400: TotalLoss=-0.004917 | Sup=0.000020 | Unsup=-0.493685 | TrainAcc=1.0000
# Fold 8 Epoch 1500: TotalLoss=-0.004936 | Sup=0.000008 | Unsup=-0.494427 | TrainAcc=1.0000
# Fold 8 Epoch 1600: TotalLoss=-0.004951 | Sup=0.000009 | Unsup=-0.495950 | TrainAcc=1.0000
# Fold 8 Epoch 1700: TotalLoss=-0.004955 | Sup=0.000007 | Unsup=-0.496230 | TrainAcc=1.0000
# Fold 8 Epoch 1800: TotalLoss=-0.004964 | Sup=0.000005 | Unsup=-0.496896 | TrainAcc=1.0000
# Fold 8 Epoch 1900: TotalLoss=-0.004962 | Sup=0.000014 | Unsup=-0.497562 | TrainAcc=1.0000
# Fold 8 Epoch 2000: TotalLoss=-0.004966 | Sup=0.000009 | Unsup=-0.497537 | TrainAcc=1.0000
# Fold 8 → Acc=0.7652 | Prec=0.9265 | Rec=0.7079 | F1=0.8025 | AUC=0.8605 | CE Loss=1.4524
#
# === Fold 9 ===
# Train Controls: 4, Train Patients: 9
# Fold 9 Epoch 1: TotalLoss=0.672994 | Sup=0.675380 | Unsup=-0.238624 | TrainAcc=0.5385
# Fold 9 Epoch 100: TotalLoss=0.016212 | Sup=0.019327 | Unsup=-0.311580 | TrainAcc=1.0000
# Fold 9 Epoch 200: TotalLoss=0.003209 | Sup=0.006599 | Unsup=-0.338960 | TrainAcc=1.0000
# Fold 9 Epoch 300: TotalLoss=0.000541 | Sup=0.004045 | Unsup=-0.350360 | TrainAcc=1.0000
# Fold 9 Epoch 400: TotalLoss=-0.002044 | Sup=0.001618 | Unsup=-0.366267 | TrainAcc=1.0000
# Fold 9 Epoch 500: TotalLoss=-0.002417 | Sup=0.001359 | Unsup=-0.377597 | TrainAcc=1.0000
# Fold 9 Epoch 600: TotalLoss=-0.003394 | Sup=0.000542 | Unsup=-0.393554 | TrainAcc=1.0000
# Fold 9 Epoch 700: TotalLoss=-0.003882 | Sup=0.000256 | Unsup=-0.413794 | TrainAcc=1.0000
# Fold 9 Epoch 800: TotalLoss=-0.004126 | Sup=0.000175 | Unsup=-0.430032 | TrainAcc=1.0000
# Fold 9 Epoch 900: TotalLoss=-0.004319 | Sup=0.000102 | Unsup=-0.442074 | TrainAcc=1.0000
# Fold 9 Epoch 1000: TotalLoss=-0.004487 | Sup=0.000059 | Unsup=-0.454669 | TrainAcc=1.0000
# Fold 9 Epoch 1100: TotalLoss=-0.004618 | Sup=0.000065 | Unsup=-0.468336 | TrainAcc=1.0000
# Fold 9 Epoch 1200: TotalLoss=-0.004739 | Sup=0.000047 | Unsup=-0.478589 | TrainAcc=1.0000
# Fold 9 Epoch 1300: TotalLoss=-0.004828 | Sup=0.000033 | Unsup=-0.486101 | TrainAcc=1.0000
# Fold 9 Epoch 1400: TotalLoss=-0.004867 | Sup=0.000021 | Unsup=-0.488832 | TrainAcc=1.0000
# Fold 9 Epoch 1500: TotalLoss=-0.004887 | Sup=0.000019 | Unsup=-0.490567 | TrainAcc=1.0000
# Fold 9 Epoch 1600: TotalLoss=-0.004894 | Sup=0.000014 | Unsup=-0.490789 | TrainAcc=1.0000
# Fold 9 Epoch 1700: TotalLoss=-0.004900 | Sup=0.000014 | Unsup=-0.491372 | TrainAcc=1.0000
# Fold 9 Epoch 1800: TotalLoss=-0.004903 | Sup=0.000017 | Unsup=-0.491962 | TrainAcc=1.0000
# Fold 9 Epoch 1900: TotalLoss=-0.004915 | Sup=0.000008 | Unsup=-0.492312 | TrainAcc=1.0000
# Fold 9 Epoch 2000: TotalLoss=-0.004915 | Sup=0.000011 | Unsup=-0.492633 | TrainAcc=1.0000
# Fold 9 → Acc=0.6742 | Prec=0.8485 | Rec=0.6292 | F1=0.7226 | AUC=0.7998 | CE Loss=1.7447
#
# === Fold 10 ===
# Train Controls: 4, Train Patients: 9
# Fold 10 Epoch 1: TotalLoss=0.694062 | Sup=0.696488 | Unsup=-0.242544 | TrainAcc=0.3846
# Fold 10 Epoch 100: TotalLoss=0.025751 | Sup=0.028444 | Unsup=-0.269370 | TrainAcc=1.0000
# Fold 10 Epoch 200: TotalLoss=0.006915 | Sup=0.009733 | Unsup=-0.281845 | TrainAcc=1.0000
# Fold 10 Epoch 300: TotalLoss=-0.000053 | Sup=0.002752 | Unsup=-0.280537 | TrainAcc=1.0000
# Fold 10 Epoch 400: TotalLoss=-0.000903 | Sup=0.001949 | Unsup=-0.285288 | TrainAcc=1.0000
# Fold 10 Epoch 500: TotalLoss=-0.001963 | Sup=0.001009 | Unsup=-0.297225 | TrainAcc=1.0000
# Fold 10 Epoch 600: TotalLoss=-0.002546 | Sup=0.000618 | Unsup=-0.316463 | TrainAcc=1.0000
# Fold 10 Epoch 700: TotalLoss=-0.002677 | Sup=0.000626 | Unsup=-0.330221 | TrainAcc=1.0000
# Fold 10 Epoch 800: TotalLoss=-0.003077 | Sup=0.000510 | Unsup=-0.358695 | TrainAcc=1.0000
# Fold 10 Epoch 900: TotalLoss=-0.003419 | Sup=0.000275 | Unsup=-0.369435 | TrainAcc=1.0000
# Fold 10 Epoch 1000: TotalLoss=-0.003634 | Sup=0.000291 | Unsup=-0.392501 | TrainAcc=1.0000
# Fold 10 Epoch 1100: TotalLoss=-0.004054 | Sup=0.000181 | Unsup=-0.423532 | TrainAcc=1.0000
# Fold 10 Epoch 1200: TotalLoss=-0.004222 | Sup=0.000145 | Unsup=-0.436649 | TrainAcc=1.0000
# Fold 10 Epoch 1300: TotalLoss=-0.004427 | Sup=0.000081 | Unsup=-0.450789 | TrainAcc=1.0000
# Fold 10 Epoch 1400: TotalLoss=-0.004542 | Sup=0.000075 | Unsup=-0.461666 | TrainAcc=1.0000
# Fold 10 Epoch 1500: TotalLoss=-0.004684 | Sup=0.000038 | Unsup=-0.472214 | TrainAcc=1.0000
# Fold 10 Epoch 1600: TotalLoss=-0.004729 | Sup=0.000030 | Unsup=-0.475966 | TrainAcc=1.0000
# Fold 10 Epoch 1700: TotalLoss=-0.004764 | Sup=0.000023 | Unsup=-0.478666 | TrainAcc=1.0000
# Fold 10 Epoch 1800: TotalLoss=-0.004776 | Sup=0.000037 | Unsup=-0.481270 | TrainAcc=1.0000
# Fold 10 Epoch 1900: TotalLoss=-0.004781 | Sup=0.000027 | Unsup=-0.480801 | TrainAcc=1.0000
# Fold 10 Epoch 2000: TotalLoss=-0.004776 | Sup=0.000041 | Unsup=-0.481734 | TrainAcc=1.0000
# Fold 10 → Acc=0.5758 | Prec=0.7538 | Rec=0.5506 | F1=0.6364 | AUC=0.6452 | CE Loss=1.9890
#
# === Fold 11 ===
# Train Controls: 4, Train Patients: 9
# Fold 11 Epoch 1: TotalLoss=0.819292 | Sup=0.821695 | Unsup=-0.240294 | TrainAcc=0.4615
# Fold 11 Epoch 100: TotalLoss=0.020015 | Sup=0.022990 | Unsup=-0.297447 | TrainAcc=1.0000
# Fold 11 Epoch 200: TotalLoss=0.003475 | Sup=0.006736 | Unsup=-0.326123 | TrainAcc=1.0000
# Fold 11 Epoch 300: TotalLoss=-0.000489 | Sup=0.003033 | Unsup=-0.352127 | TrainAcc=1.0000
# Fold 11 Epoch 400: TotalLoss=-0.002088 | Sup=0.001609 | Unsup=-0.369729 | TrainAcc=1.0000
# Fold 11 Epoch 500: TotalLoss=-0.002925 | Sup=0.000851 | Unsup=-0.377525 | TrainAcc=1.0000
# Fold 11 Epoch 600: TotalLoss=-0.003537 | Sup=0.000431 | Unsup=-0.396847 | TrainAcc=1.0000
# Fold 11 Epoch 700: TotalLoss=-0.003926 | Sup=0.000277 | Unsup=-0.420320 | TrainAcc=1.0000
# Fold 11 Epoch 800: TotalLoss=-0.004179 | Sup=0.000146 | Unsup=-0.432537 | TrainAcc=1.0000
# Fold 11 Epoch 900: TotalLoss=-0.004306 | Sup=0.000112 | Unsup=-0.441842 | TrainAcc=1.0000
# Fold 11 Epoch 1000: TotalLoss=-0.004435 | Sup=0.000114 | Unsup=-0.454936 | TrainAcc=1.0000
# Fold 11 Epoch 1100: TotalLoss=-0.004536 | Sup=0.000096 | Unsup=-0.463199 | TrainAcc=1.0000
# Fold 11 Epoch 1200: TotalLoss=-0.004716 | Sup=0.000034 | Unsup=-0.474947 | TrainAcc=1.0000
# Fold 11 Epoch 1300: TotalLoss=-0.004758 | Sup=0.000056 | Unsup=-0.481419 | TrainAcc=1.0000
# Fold 11 Epoch 1400: TotalLoss=-0.004836 | Sup=0.000033 | Unsup=-0.486885 | TrainAcc=1.0000
# Fold 11 Epoch 1500: TotalLoss=-0.004877 | Sup=0.000020 | Unsup=-0.489710 | TrainAcc=1.0000
# Fold 11 Epoch 1600: TotalLoss=-0.004907 | Sup=0.000020 | Unsup=-0.492704 | TrainAcc=1.0000
# Fold 11 Epoch 1700: TotalLoss=-0.004930 | Sup=0.000013 | Unsup=-0.494237 | TrainAcc=1.0000
# Fold 11 Epoch 1800: TotalLoss=-0.004931 | Sup=0.000012 | Unsup=-0.494361 | TrainAcc=1.0000
# Fold 11 Epoch 1900: TotalLoss=-0.004930 | Sup=0.000013 | Unsup=-0.494302 | TrainAcc=1.0000
# Fold 11 Epoch 2000: TotalLoss=-0.004942 | Sup=0.000016 | Unsup=-0.495813 | TrainAcc=1.0000
# Fold 11 → Acc=0.6591 | Prec=0.8333 | Rec=0.6180 | F1=0.7097 | AUC=0.7917 | CE Loss=1.7889
#
# === Fold 12 ===
# Train Controls: 4, Train Patients: 9
# Fold 12 Epoch 1: TotalLoss=0.779714 | Sup=0.782082 | Unsup=-0.236841 | TrainAcc=0.3846
# Fold 12 Epoch 100: TotalLoss=0.025802 | Sup=0.028893 | Unsup=-0.309112 | TrainAcc=1.0000
# Fold 12 Epoch 200: TotalLoss=0.005227 | Sup=0.008471 | Unsup=-0.324406 | TrainAcc=1.0000
# Fold 12 Epoch 300: TotalLoss=-0.000459 | Sup=0.002930 | Unsup=-0.338881 | TrainAcc=1.0000
# Fold 12 Epoch 400: TotalLoss=-0.001394 | Sup=0.002077 | Unsup=-0.347165 | TrainAcc=1.0000
# Fold 12 Epoch 500: TotalLoss=-0.002568 | Sup=0.001054 | Unsup=-0.362220 | TrainAcc=1.0000
# Fold 12 Epoch 600: TotalLoss=-0.002821 | Sup=0.000959 | Unsup=-0.378050 | TrainAcc=1.0000
# Fold 12 Epoch 700: TotalLoss=-0.003623 | Sup=0.000451 | Unsup=-0.407352 | TrainAcc=1.0000
# Fold 12 Epoch 800: TotalLoss=-0.003985 | Sup=0.000240 | Unsup=-0.422467 | TrainAcc=1.0000
# Fold 12 Epoch 900: TotalLoss=-0.004190 | Sup=0.000169 | Unsup=-0.435860 | TrainAcc=1.0000
# Fold 12 Epoch 1000: TotalLoss=-0.004324 | Sup=0.000141 | Unsup=-0.446547 | TrainAcc=1.0000
# Fold 12 Epoch 1100: TotalLoss=-0.004505 | Sup=0.000062 | Unsup=-0.456703 | TrainAcc=1.0000
# Fold 12 Epoch 1200: TotalLoss=-0.004633 | Sup=0.000052 | Unsup=-0.468538 | TrainAcc=1.0000
# Fold 12 Epoch 1300: TotalLoss=-0.004726 | Sup=0.000058 | Unsup=-0.478369 | TrainAcc=1.0000
# Fold 12 Epoch 1400: TotalLoss=-0.004820 | Sup=0.000026 | Unsup=-0.484543 | TrainAcc=1.0000
# Fold 12 Epoch 1500: TotalLoss=-0.004874 | Sup=0.000012 | Unsup=-0.488600 | TrainAcc=1.0000
# Fold 12 Epoch 1600: TotalLoss=-0.004887 | Sup=0.000017 | Unsup=-0.490337 | TrainAcc=1.0000
# Fold 12 Epoch 1700: TotalLoss=-0.004898 | Sup=0.000012 | Unsup=-0.491055 | TrainAcc=1.0000
# Fold 12 Epoch 1800: TotalLoss=-0.004914 | Sup=0.000007 | Unsup=-0.492123 | TrainAcc=1.0000
# Fold 12 Epoch 1900: TotalLoss=-0.004950 | Sup=0.000007 | Unsup=-0.495614 | TrainAcc=1.0000
# Fold 12 Epoch 2000: TotalLoss=-0.004955 | Sup=0.000008 | Unsup=-0.496310 | TrainAcc=1.0000
# Fold 12 → Acc=0.6439 | Prec=0.8281 | Rec=0.5955 | F1=0.6928 | AUC=0.7263 | CE Loss=2.3718
#
# === Fold 13 ===
# Train Controls: 4, Train Patients: 9
# Fold 13 Epoch 1: TotalLoss=0.915802 | Sup=0.918215 | Unsup=-0.241323 | TrainAcc=0.3077
# Fold 13 Epoch 100: TotalLoss=0.033611 | Sup=0.036640 | Unsup=-0.302815 | TrainAcc=1.0000
# Fold 13 Epoch 200: TotalLoss=0.008086 | Sup=0.011326 | Unsup=-0.324011 | TrainAcc=1.0000
# Fold 13 Epoch 300: TotalLoss=0.000252 | Sup=0.003710 | Unsup=-0.345740 | TrainAcc=1.0000
# Fold 13 Epoch 400: TotalLoss=-0.001835 | Sup=0.001774 | Unsup=-0.360875 | TrainAcc=1.0000
# Fold 13 Epoch 500: TotalLoss=-0.002844 | Sup=0.000999 | Unsup=-0.384324 | TrainAcc=1.0000
# Fold 13 Epoch 600: TotalLoss=-0.003657 | Sup=0.000457 | Unsup=-0.411449 | TrainAcc=1.0000
# Fold 13 Epoch 700: TotalLoss=-0.003958 | Sup=0.000264 | Unsup=-0.422271 | TrainAcc=1.0000
# Fold 13 Epoch 800: TotalLoss=-0.004241 | Sup=0.000193 | Unsup=-0.443325 | TrainAcc=1.0000
# Fold 13 Epoch 900: TotalLoss=-0.004580 | Sup=0.000051 | Unsup=-0.463105 | TrainAcc=1.0000
# Fold 13 Epoch 1000: TotalLoss=-0.004627 | Sup=0.000104 | Unsup=-0.473168 | TrainAcc=1.0000
# Fold 13 Epoch 1100: TotalLoss=-0.004769 | Sup=0.000031 | Unsup=-0.480018 | TrainAcc=1.0000
# Fold 13 Epoch 1200: TotalLoss=-0.004826 | Sup=0.000025 | Unsup=-0.485189 | TrainAcc=1.0000
# Fold 13 Epoch 1300: TotalLoss=-0.004865 | Sup=0.000020 | Unsup=-0.488510 | TrainAcc=1.0000
# Fold 13 Epoch 1400: TotalLoss=-0.004877 | Sup=0.000017 | Unsup=-0.489471 | TrainAcc=1.0000
# Fold 13 Epoch 1500: TotalLoss=-0.004902 | Sup=0.000015 | Unsup=-0.491659 | TrainAcc=1.0000
# Fold 13 Epoch 1600: TotalLoss=-0.004903 | Sup=0.000014 | Unsup=-0.491745 | TrainAcc=1.0000
# Fold 13 Epoch 1700: TotalLoss=-0.004908 | Sup=0.000012 | Unsup=-0.491990 | TrainAcc=1.0000
# Fold 13 Epoch 1800: TotalLoss=-0.004913 | Sup=0.000016 | Unsup=-0.492878 | TrainAcc=1.0000
# Fold 13 Epoch 1900: TotalLoss=-0.004923 | Sup=0.000008 | Unsup=-0.493091 | TrainAcc=1.0000
# Fold 13 Epoch 2000: TotalLoss=-0.004926 | Sup=0.000005 | Unsup=-0.493033 | TrainAcc=1.0000
# Fold 13 → Acc=0.7197 | Prec=0.8939 | Rec=0.6629 | F1=0.7613 | AUC=0.8079 | CE Loss=1.6204
#
# === Fold 14 ===
# Train Controls: 4, Train Patients: 9
# Fold 14 Epoch 1: TotalLoss=0.668262 | Sup=0.670624 | Unsup=-0.236109 | TrainAcc=0.5385
# Fold 14 Epoch 100: TotalLoss=0.023260 | Sup=0.026388 | Unsup=-0.312792 | TrainAcc=1.0000
# Fold 14 Epoch 200: TotalLoss=0.004424 | Sup=0.007795 | Unsup=-0.337105 | TrainAcc=1.0000
# Fold 14 Epoch 300: TotalLoss=-0.000471 | Sup=0.003064 | Unsup=-0.353515 | TrainAcc=1.0000
# Fold 14 Epoch 400: TotalLoss=-0.001785 | Sup=0.001811 | Unsup=-0.359659 | TrainAcc=1.0000
# Fold 14 Epoch 500: TotalLoss=-0.002600 | Sup=0.001150 | Unsup=-0.374990 | TrainAcc=1.0000
# Fold 14 Epoch 600: TotalLoss=-0.003015 | Sup=0.000874 | Unsup=-0.388958 | TrainAcc=1.0000
# Fold 14 Epoch 700: TotalLoss=-0.003777 | Sup=0.000338 | Unsup=-0.411512 | TrainAcc=1.0000
# Fold 14 Epoch 800: TotalLoss=-0.004168 | Sup=0.000172 | Unsup=-0.433929 | TrainAcc=1.0000
# Fold 14 Epoch 900: TotalLoss=-0.004395 | Sup=0.000138 | Unsup=-0.453309 | TrainAcc=1.0000
# Fold 14 Epoch 1000: TotalLoss=-0.004595 | Sup=0.000069 | Unsup=-0.466382 | TrainAcc=1.0000
# Fold 14 Epoch 1100: TotalLoss=-0.004782 | Sup=0.000038 | Unsup=-0.482021 | TrainAcc=1.0000
# Fold 14 Epoch 1200: TotalLoss=-0.004834 | Sup=0.000034 | Unsup=-0.486804 | TrainAcc=1.0000
# Fold 14 Epoch 1300: TotalLoss=-0.004874 | Sup=0.000015 | Unsup=-0.488910 | TrainAcc=1.0000
# Fold 14 Epoch 1400: TotalLoss=-0.004897 | Sup=0.000016 | Unsup=-0.491227 | TrainAcc=1.0000
# Fold 14 Epoch 1500: TotalLoss=-0.004899 | Sup=0.000009 | Unsup=-0.490762 | TrainAcc=1.0000
# Fold 14 Epoch 1600: TotalLoss=-0.004906 | Sup=0.000011 | Unsup=-0.491694 | TrainAcc=1.0000
# Fold 14 Epoch 1700: TotalLoss=-0.004905 | Sup=0.000014 | Unsup=-0.491904 | TrainAcc=1.0000
# Fold 14 Epoch 1800: TotalLoss=-0.004913 | Sup=0.000007 | Unsup=-0.492058 | TrainAcc=1.0000
# Fold 14 Epoch 1900: TotalLoss=-0.004916 | Sup=0.000011 | Unsup=-0.492670 | TrainAcc=1.0000
# Fold 14 Epoch 2000: TotalLoss=-0.004917 | Sup=0.000005 | Unsup=-0.492207 | TrainAcc=1.0000
# Fold 14 → Acc=0.6364 | Prec=0.8254 | Rec=0.5843 | F1=0.6842 | AUC=0.7293 | CE Loss=2.0944
#
# === Fold 15 ===
# Train Controls: 4, Train Patients: 9
# Fold 15 Epoch 1: TotalLoss=0.892647 | Sup=0.895022 | Unsup=-0.237504 | TrainAcc=0.3077
# Fold 15 Epoch 100: TotalLoss=0.029283 | Sup=0.032147 | Unsup=-0.286390 | TrainAcc=1.0000
# Fold 15 Epoch 200: TotalLoss=0.004996 | Sup=0.008169 | Unsup=-0.317277 | TrainAcc=1.0000
# Fold 15 Epoch 300: TotalLoss=0.001044 | Sup=0.004392 | Unsup=-0.334797 | TrainAcc=1.0000
# Fold 15 Epoch 400: TotalLoss=-0.001300 | Sup=0.002154 | Unsup=-0.345383 | TrainAcc=1.0000
# Fold 15 Epoch 500: TotalLoss=-0.002278 | Sup=0.001348 | Unsup=-0.362673 | TrainAcc=1.0000
# Fold 15 Epoch 600: TotalLoss=-0.003126 | Sup=0.000692 | Unsup=-0.381782 | TrainAcc=1.0000
# Fold 15 Epoch 700: TotalLoss=-0.003535 | Sup=0.000423 | Unsup=-0.395827 | TrainAcc=1.0000
# Fold 15 Epoch 800: TotalLoss=-0.003878 | Sup=0.000253 | Unsup=-0.413047 | TrainAcc=1.0000
# Fold 15 Epoch 900: TotalLoss=-0.004143 | Sup=0.000152 | Unsup=-0.429488 | TrainAcc=1.0000
# Fold 15 Epoch 1000: TotalLoss=-0.004375 | Sup=0.000114 | Unsup=-0.448844 | TrainAcc=1.0000
# Fold 15 Epoch 1100: TotalLoss=-0.004507 | Sup=0.000096 | Unsup=-0.460225 | TrainAcc=1.0000
# Fold 15 Epoch 1200: TotalLoss=-0.004612 | Sup=0.000053 | Unsup=-0.466502 | TrainAcc=1.0000
# Fold 15 Epoch 1300: TotalLoss=-0.004729 | Sup=0.000041 | Unsup=-0.476981 | TrainAcc=1.0000
# Fold 15 Epoch 1400: TotalLoss=-0.004729 | Sup=0.000059 | Unsup=-0.478782 | TrainAcc=1.0000
# Fold 15 Epoch 1500: TotalLoss=-0.004809 | Sup=0.000018 | Unsup=-0.482747 | TrainAcc=1.0000
# Fold 15 Epoch 1600: TotalLoss=-0.004826 | Sup=0.000021 | Unsup=-0.484688 | TrainAcc=1.0000
# Fold 15 Epoch 1700: TotalLoss=-0.004882 | Sup=0.000013 | Unsup=-0.489447 | TrainAcc=1.0000
# Fold 15 Epoch 1800: TotalLoss=-0.004875 | Sup=0.000014 | Unsup=-0.488864 | TrainAcc=1.0000
# Fold 15 Epoch 1900: TotalLoss=-0.004878 | Sup=0.000020 | Unsup=-0.489783 | TrainAcc=1.0000
# Fold 15 Epoch 2000: TotalLoss=-0.004889 | Sup=0.000009 | Unsup=-0.489876 | TrainAcc=1.0000
# Fold 15 → Acc=0.7348 | Prec=0.9355 | Rec=0.6517 | F1=0.7682 | AUC=0.8336 | CE Loss=1.3276
#
# === Fold 16 ===
# Train Controls: 4, Train Patients: 9
# Fold 16 Epoch 1: TotalLoss=0.756707 | Sup=0.759164 | Unsup=-0.245726 | TrainAcc=0.4615
# Fold 16 Epoch 100: TotalLoss=0.015728 | Sup=0.019009 | Unsup=-0.328041 | TrainAcc=1.0000
# Fold 16 Epoch 200: TotalLoss=0.003791 | Sup=0.007294 | Unsup=-0.350370 | TrainAcc=1.0000
# Fold 16 Epoch 300: TotalLoss=0.000684 | Sup=0.004272 | Unsup=-0.358770 | TrainAcc=1.0000
# Fold 16 Epoch 400: TotalLoss=-0.001491 | Sup=0.002241 | Unsup=-0.373170 | TrainAcc=1.0000
# Fold 16 Epoch 500: TotalLoss=-0.002443 | Sup=0.001355 | Unsup=-0.379777 | TrainAcc=1.0000
# Fold 16 Epoch 600: TotalLoss=-0.003499 | Sup=0.000694 | Unsup=-0.419210 | TrainAcc=1.0000
# Fold 16 Epoch 700: TotalLoss=-0.004109 | Sup=0.000234 | Unsup=-0.434308 | TrainAcc=1.0000
# Fold 16 Epoch 800: TotalLoss=-0.004402 | Sup=0.000106 | Unsup=-0.450803 | TrainAcc=1.0000
# Fold 16 Epoch 900: TotalLoss=-0.004489 | Sup=0.000155 | Unsup=-0.464412 | TrainAcc=1.0000
# Fold 16 Epoch 1000: TotalLoss=-0.004597 | Sup=0.000120 | Unsup=-0.471693 | TrainAcc=1.0000
# Fold 16 Epoch 1100: TotalLoss=-0.004706 | Sup=0.000068 | Unsup=-0.477418 | TrainAcc=1.0000
# Fold 16 Epoch 1200: TotalLoss=-0.004796 | Sup=0.000029 | Unsup=-0.482519 | TrainAcc=1.0000
# Fold 16 Epoch 1300: TotalLoss=-0.004817 | Sup=0.000038 | Unsup=-0.485515 | TrainAcc=1.0000
# Fold 16 Epoch 1400: TotalLoss=-0.004857 | Sup=0.000023 | Unsup=-0.487988 | TrainAcc=1.0000
# Fold 16 Epoch 1500: TotalLoss=-0.004874 | Sup=0.000025 | Unsup=-0.489966 | TrainAcc=1.0000
# Fold 16 Epoch 1600: TotalLoss=-0.004897 | Sup=0.000013 | Unsup=-0.491035 | TrainAcc=1.0000
# Fold 16 Epoch 1700: TotalLoss=-0.004895 | Sup=0.000016 | Unsup=-0.491107 | TrainAcc=1.0000
# Fold 16 Epoch 1800: TotalLoss=-0.004920 | Sup=0.000008 | Unsup=-0.492769 | TrainAcc=1.0000
# Fold 16 Epoch 1900: TotalLoss=-0.004906 | Sup=0.000017 | Unsup=-0.492267 | TrainAcc=1.0000
# Fold 16 Epoch 2000: TotalLoss=-0.004923 | Sup=0.000009 | Unsup=-0.493192 | TrainAcc=1.0000
# Fold 16 → Acc=0.6667 | Prec=0.8358 | Rec=0.6292 | F1=0.7179 | AUC=0.7617 | CE Loss=1.9475
#
# === Fold 17 ===
# Train Controls: 4, Train Patients: 9
# Fold 17 Epoch 1: TotalLoss=0.699759 | Sup=0.702194 | Unsup=-0.243513 | TrainAcc=0.6154
# Fold 17 Epoch 100: TotalLoss=0.012258 | Sup=0.015106 | Unsup=-0.284798 | TrainAcc=1.0000
# Fold 17 Epoch 200: TotalLoss=0.001989 | Sup=0.004996 | Unsup=-0.300713 | TrainAcc=1.0000
# Fold 17 Epoch 300: TotalLoss=-0.001121 | Sup=0.002037 | Unsup=-0.315741 | TrainAcc=1.0000
# Fold 17 Epoch 400: TotalLoss=-0.001885 | Sup=0.001355 | Unsup=-0.323934 | TrainAcc=1.0000
# Fold 17 Epoch 500: TotalLoss=-0.002694 | Sup=0.000885 | Unsup=-0.357955 | TrainAcc=1.0000
# Fold 17 Epoch 600: TotalLoss=-0.003404 | Sup=0.000493 | Unsup=-0.389692 | TrainAcc=1.0000
# Fold 17 Epoch 700: TotalLoss=-0.003936 | Sup=0.000255 | Unsup=-0.419034 | TrainAcc=1.0000
# Fold 17 Epoch 800: TotalLoss=-0.004162 | Sup=0.000153 | Unsup=-0.431406 | TrainAcc=1.0000
# Fold 17 Epoch 900: TotalLoss=-0.004257 | Sup=0.000153 | Unsup=-0.441011 | TrainAcc=1.0000
# Fold 17 Epoch 1000: TotalLoss=-0.004426 | Sup=0.000105 | Unsup=-0.453112 | TrainAcc=1.0000
# Fold 17 Epoch 1100: TotalLoss=-0.004496 | Sup=0.000080 | Unsup=-0.457559 | TrainAcc=1.0000
# Fold 17 Epoch 1200: TotalLoss=-0.004593 | Sup=0.000067 | Unsup=-0.465969 | TrainAcc=1.0000
# Fold 17 Epoch 1300: TotalLoss=-0.004687 | Sup=0.000046 | Unsup=-0.473262 | TrainAcc=1.0000
# Fold 17 Epoch 1400: TotalLoss=-0.004739 | Sup=0.000041 | Unsup=-0.478031 | TrainAcc=1.0000
# Fold 17 Epoch 1500: TotalLoss=-0.004777 | Sup=0.000030 | Unsup=-0.480761 | TrainAcc=1.0000
# Fold 17 Epoch 1600: TotalLoss=-0.004776 | Sup=0.000027 | Unsup=-0.480307 | TrainAcc=1.0000
# Fold 17 Epoch 1700: TotalLoss=-0.004814 | Sup=0.000019 | Unsup=-0.483297 | TrainAcc=1.0000
# Fold 17 Epoch 1800: TotalLoss=-0.004875 | Sup=0.000011 | Unsup=-0.488603 | TrainAcc=1.0000
# Fold 17 Epoch 1900: TotalLoss=-0.004890 | Sup=0.000009 | Unsup=-0.489896 | TrainAcc=1.0000
# Fold 17 Epoch 2000: TotalLoss=-0.004905 | Sup=0.000006 | Unsup=-0.491074 | TrainAcc=1.0000
# Fold 17 → Acc=0.6818 | Prec=0.8615 | Rec=0.6292 | F1=0.7273 | AUC=0.7897 | CE Loss=1.6299
#
# === Fold 18 ===
# Train Controls: 4, Train Patients: 9
# Fold 18 Epoch 1: TotalLoss=0.630771 | Sup=0.633152 | Unsup=-0.238092 | TrainAcc=0.6923
# Fold 18 Epoch 100: TotalLoss=0.020276 | Sup=0.023294 | Unsup=-0.301819 | TrainAcc=1.0000
# Fold 18 Epoch 200: TotalLoss=0.004899 | Sup=0.008156 | Unsup=-0.325657 | TrainAcc=1.0000
# Fold 18 Epoch 300: TotalLoss=-0.000130 | Sup=0.003259 | Unsup=-0.338867 | TrainAcc=1.0000
# Fold 18 Epoch 400: TotalLoss=-0.001330 | Sup=0.002282 | Unsup=-0.361184 | TrainAcc=1.0000
# Fold 18 Epoch 500: TotalLoss=-0.002293 | Sup=0.001390 | Unsup=-0.368257 | TrainAcc=1.0000
# Fold 18 Epoch 600: TotalLoss=-0.003160 | Sup=0.000684 | Unsup=-0.384470 | TrainAcc=1.0000
# Fold 18 Epoch 700: TotalLoss=-0.003367 | Sup=0.000606 | Unsup=-0.397374 | TrainAcc=1.0000
# Fold 18 Epoch 800: TotalLoss=-0.003904 | Sup=0.000264 | Unsup=-0.416880 | TrainAcc=1.0000
# Fold 18 Epoch 900: TotalLoss=-0.004053 | Sup=0.000264 | Unsup=-0.431766 | TrainAcc=1.0000
# Fold 18 Epoch 1000: TotalLoss=-0.004331 | Sup=0.000123 | Unsup=-0.445447 | TrainAcc=1.0000
# Fold 18 Epoch 1100: TotalLoss=-0.004564 | Sup=0.000066 | Unsup=-0.462989 | TrainAcc=1.0000
# Fold 18 Epoch 1200: TotalLoss=-0.004707 | Sup=0.000058 | Unsup=-0.476534 | TrainAcc=1.0000
# Fold 18 Epoch 1300: TotalLoss=-0.004799 | Sup=0.000034 | Unsup=-0.483279 | TrainAcc=1.0000
# Fold 18 Epoch 1400: TotalLoss=-0.004858 | Sup=0.000012 | Unsup=-0.487021 | TrainAcc=1.0000
# Fold 18 Epoch 1500: TotalLoss=-0.004875 | Sup=0.000019 | Unsup=-0.489371 | TrainAcc=1.0000
# Fold 18 Epoch 1600: TotalLoss=-0.004891 | Sup=0.000012 | Unsup=-0.490376 | TrainAcc=1.0000
# Fold 18 Epoch 1700: TotalLoss=-0.004886 | Sup=0.000012 | Unsup=-0.489795 | TrainAcc=1.0000
# Fold 18 Epoch 1800: TotalLoss=-0.004890 | Sup=0.000023 | Unsup=-0.491269 | TrainAcc=1.0000
# Fold 18 Epoch 1900: TotalLoss=-0.004900 | Sup=0.000014 | Unsup=-0.491384 | TrainAcc=1.0000
# Fold 18 Epoch 2000: TotalLoss=-0.004913 | Sup=0.000004 | Unsup=-0.491742 | TrainAcc=1.0000
# Fold 18 → Acc=0.5985 | Prec=0.7812 | Rec=0.5618 | F1=0.6536 | AUC=0.7034 | CE Loss=2.1587
#
# === Fold 19 ===
# Train Controls: 4, Train Patients: 9
# Fold 19 Epoch 1: TotalLoss=0.870769 | Sup=0.873175 | Unsup=-0.240653 | TrainAcc=0.3846
# Fold 19 Epoch 100: TotalLoss=0.017268 | Sup=0.019976 | Unsup=-0.270817 | TrainAcc=1.0000
# Fold 19 Epoch 200: TotalLoss=0.003751 | Sup=0.006632 | Unsup=-0.288092 | TrainAcc=1.0000
# Fold 19 Epoch 300: TotalLoss=0.000447 | Sup=0.003454 | Unsup=-0.300709 | TrainAcc=1.0000
# Fold 19 Epoch 400: TotalLoss=-0.001428 | Sup=0.001678 | Unsup=-0.310682 | TrainAcc=1.0000
# Fold 19 Epoch 500: TotalLoss=-0.002096 | Sup=0.001247 | Unsup=-0.334296 | TrainAcc=1.0000
# Fold 19 Epoch 600: TotalLoss=-0.002888 | Sup=0.000578 | Unsup=-0.346626 | TrainAcc=1.0000
# Fold 19 Epoch 700: TotalLoss=-0.003564 | Sup=0.000270 | Unsup=-0.383389 | TrainAcc=1.0000
# Fold 19 Epoch 800: TotalLoss=-0.003968 | Sup=0.000195 | Unsup=-0.416284 | TrainAcc=1.0000
# Fold 19 Epoch 900: TotalLoss=-0.004236 | Sup=0.000126 | Unsup=-0.436167 | TrainAcc=1.0000
# Fold 19 Epoch 1000: TotalLoss=-0.004377 | Sup=0.000065 | Unsup=-0.444237 | TrainAcc=1.0000
# Fold 19 Epoch 1100: TotalLoss=-0.004544 | Sup=0.000050 | Unsup=-0.459419 | TrainAcc=1.0000
# Fold 19 Epoch 1200: TotalLoss=-0.004656 | Sup=0.000044 | Unsup=-0.470022 | TrainAcc=1.0000
# Fold 19 Epoch 1300: TotalLoss=-0.004714 | Sup=0.000029 | Unsup=-0.474278 | TrainAcc=1.0000
# Fold 19 Epoch 1400: TotalLoss=-0.004764 | Sup=0.000017 | Unsup=-0.478160 | TrainAcc=1.0000
# Fold 19 Epoch 1500: TotalLoss=-0.004790 | Sup=0.000026 | Unsup=-0.481551 | TrainAcc=1.0000
# Fold 19 Epoch 1600: TotalLoss=-0.004839 | Sup=0.000018 | Unsup=-0.485675 | TrainAcc=1.0000
# Fold 19 Epoch 1700: TotalLoss=-0.004838 | Sup=0.000016 | Unsup=-0.485404 | TrainAcc=1.0000
# Fold 19 Epoch 1800: TotalLoss=-0.004878 | Sup=0.000007 | Unsup=-0.488559 | TrainAcc=1.0000
# Fold 19 Epoch 1900: TotalLoss=-0.004873 | Sup=0.000012 | Unsup=-0.488441 | TrainAcc=1.0000
# Fold 19 Epoch 2000: TotalLoss=-0.004891 | Sup=0.000008 | Unsup=-0.489957 | TrainAcc=1.0000
# Fold 19 → Acc=0.6439 | Prec=0.8182 | Rec=0.6067 | F1=0.6968 | AUC=0.7220 | CE Loss=1.7698
#
# === Fold 20 ===
# Train Controls: 4, Train Patients: 9
# Fold 20 Epoch 1: TotalLoss=0.647761 | Sup=0.650145 | Unsup=-0.238359 | TrainAcc=0.5385
# Fold 20 Epoch 100: TotalLoss=0.025965 | Sup=0.028771 | Unsup=-0.280599 | TrainAcc=1.0000
# Fold 20 Epoch 200: TotalLoss=0.003752 | Sup=0.006711 | Unsup=-0.295913 | TrainAcc=1.0000
# Fold 20 Epoch 300: TotalLoss=-0.000071 | Sup=0.002921 | Unsup=-0.299265 | TrainAcc=1.0000
# Fold 20 Epoch 400: TotalLoss=-0.001590 | Sup=0.001521 | Unsup=-0.311166 | TrainAcc=1.0000
# Fold 20 Epoch 500: TotalLoss=-0.002251 | Sup=0.001231 | Unsup=-0.348164 | TrainAcc=1.0000
# Fold 20 Epoch 600: TotalLoss=-0.003410 | Sup=0.000330 | Unsup=-0.373998 | TrainAcc=1.0000
# Fold 20 Epoch 700: TotalLoss=-0.003522 | Sup=0.000295 | Unsup=-0.381694 | TrainAcc=1.0000
# Fold 20 Epoch 800: TotalLoss=-0.003668 | Sup=0.000371 | Unsup=-0.403929 | TrainAcc=1.0000
# Fold 20 Epoch 900: TotalLoss=-0.004075 | Sup=0.000107 | Unsup=-0.418277 | TrainAcc=1.0000
# Fold 20 Epoch 1000: TotalLoss=-0.004256 | Sup=0.000114 | Unsup=-0.436909 | TrainAcc=1.0000
# Fold 20 Epoch 1100: TotalLoss=-0.004426 | Sup=0.000108 | Unsup=-0.453382 | TrainAcc=1.0000
# Fold 20 Epoch 1200: TotalLoss=-0.004618 | Sup=0.000043 | Unsup=-0.466107 | TrainAcc=1.0000
# Fold 20 Epoch 1300: TotalLoss=-0.004695 | Sup=0.000047 | Unsup=-0.474154 | TrainAcc=1.0000
# Fold 20 Epoch 1400: TotalLoss=-0.004724 | Sup=0.000053 | Unsup=-0.477775 | TrainAcc=1.0000
# Fold 20 Epoch 1500: TotalLoss=-0.004769 | Sup=0.000044 | Unsup=-0.481271 | TrainAcc=1.0000
# Fold 20 Epoch 1600: TotalLoss=-0.004789 | Sup=0.000041 | Unsup=-0.483004 | TrainAcc=1.0000
# Fold 20 Epoch 1700: TotalLoss=-0.004787 | Sup=0.000036 | Unsup=-0.482277 | TrainAcc=1.0000
# Fold 20 Epoch 1800: TotalLoss=-0.004817 | Sup=0.000024 | Unsup=-0.484079 | TrainAcc=1.0000
# Fold 20 Epoch 1900: TotalLoss=-0.004859 | Sup=0.000029 | Unsup=-0.488806 | TrainAcc=1.0000
# Fold 20 Epoch 2000: TotalLoss=-0.004880 | Sup=0.000016 | Unsup=-0.489677 | TrainAcc=1.0000
# Fold 20 → Acc=0.6591 | Prec=0.8235 | Rec=0.6292 | F1=0.7134 | AUC=0.7523 | CE Loss=1.6438
#
# === Average Results Across 20 Folds (Controls vs Patients) ===
# Accuracy:  0.6708 ± 0.0445
# Precision: 0.8465 ± 0.0450
# Recall:    0.6253 ± 0.0352
# F1-score:  0.7191 ± 0.0384
# AUC:       0.7691 ± 0.0515
# CE Loss:   1.7945 ± 0.2520

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import pandas as pd
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, log_loss

# ==========================================
# CONFIG
# ==========================================
SEED = 42
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

hidden_dim = 512
num_epochs = 5000
lr = 1e-4
weight_decay = 1e-4
batch_print_freq = 500  # print every 500 epochs

# λ_mod list
lambda_mod_list = [0.001, 0.005, 0.009, 0.01, 0.05, 0.09, 0.1, 0.3, 0.5, 0.9, 1, 2, 5, 8]

# Directory for checkpoints
checkpoint_dir = "ARMA_Cut_NIFD"
os.makedirs(checkpoint_dir, exist_ok=True)

results_summary = []

# ==========================================
# Main loop for λ_mod sweep
# ==========================================
for lambda_mod in lambda_mod_list:
    print(f"\n==============================")
    print(f" Running with λ_mod = {lambda_mod}")
    print(f"==============================")

    accuracies, precisions, recalls, f1_scores, aucs, ce_losses = [], [], [], [], [], []
    sss = StratifiedShuffleSplit(n_splits=20, test_size=0.5, random_state=SEED)

    for fold, (train_val_idx, test_idx_global) in enumerate(sss.split(X, y), start=1):
        print(f"\n=== Fold {fold} ===")

        # --- Split Controls and Patients ---
        controls_idx = np.where(y == 0)[0]
        patients_idx = np.where(y == 1)[0]

        sss_class = StratifiedShuffleSplit(n_splits=20, test_size=0.5, random_state=fold)
        controls_train_idx, _ = next(sss_class.split(X[controls_idx], y[controls_idx]))
        patients_train_idx, _ = next(sss_class.split(X[patients_idx], y[patients_idx]))

        controls_train = controls_idx[controls_train_idx]
        patients_train = patients_idx[patients_train_idx]
        train_idx_final = np.concatenate([controls_train, patients_train])
        np.random.shuffle(train_idx_final)

        print(f"Train Controls: {len(controls_train)}, Train Patients: {len(patients_train)}")

        train_idx_t = torch.from_numpy(train_idx_final).long().to(device)
        y_train_tensor = torch.from_numpy(y[train_idx_final]).long().to(device)

        # --- Initialize model ---
        model = ARMA_SemiSupervised(feats_dim, hidden_dim, num_classes, device, "RELU").to(device)
        optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
        ce_loss = nn.CrossEntropyLoss()

        best_loss = float('inf')
        best_model_state = None

        # --- Training loop ---
        for epoch in range(1, num_epochs + 1):
            model.train()
            optimizer.zero_grad()

            logits = model(data)
            loss_sup = ce_loss(logits[train_idx_t], y_train_tensor)
            loss_unsup = model.cut_loss(A_tensor, logits)  # unsupervised regularization
            total_loss = loss_sup + lambda_mod * loss_unsup

            total_loss.backward()
            optimizer.step()

            # Track best model
            if total_loss.item() < best_loss:
                best_loss = total_loss.item()
                best_model_state = model.state_dict().copy()

            if epoch % batch_print_freq == 0 or epoch == 1:
                model.eval()
                with torch.no_grad():
                    preds_train = logits[train_idx_t].argmax(dim=1)
                    acc_train = accuracy_score(y_train_tensor.cpu(), preds_train.cpu())
                print(f"Fold {fold} Epoch {epoch}: "
                      f"TotalLoss={total_loss.item():.6f} | Sup={loss_sup.item():.6f} | "
                      f"Unsup={loss_unsup.item():.6f} | TrainAcc={acc_train:.4f}")

        # --- Save checkpoint ---
        checkpoint_path = os.path.join(checkpoint_dir, f"checkpoint_lambda_{lambda_mod}_fold_{fold}.pt")
        torch.save({
            'lambda_mod': lambda_mod,
            'fold': fold,
            'model_state_dict': best_model_state,
            'optimizer_state_dict': optimizer.state_dict(),
            'best_loss': best_loss,
        }, checkpoint_path)
        print(f" Saved checkpoint: {checkpoint_path}")

        # --- Evaluation ---
        model.load_state_dict(best_model_state)
        model.eval()
        with torch.no_grad():
            out = model(data)
            preds = out.argmax(dim=1).cpu().numpy()
            probs = torch.softmax(out, dim=1)[:, 1].cpu().numpy()

        y_test = y[test_idx_global]
        y_pred_test = preds[test_idx_global]
        y_prob_test = probs[test_idx_global]

        acc = accuracy_score(y_test, y_pred_test)
        prec = precision_score(y_test, y_pred_test, zero_division=0)
        rec = recall_score(y_test, y_pred_test, zero_division=0)
        f1 = f1_score(y_test, y_pred_test, zero_division=0)
        auc = roc_auc_score(y_test, y_prob_test)
        ce = log_loss(y_test, y_prob_test)

        accuracies.append(acc)
        precisions.append(prec)
        recalls.append(rec)
        f1_scores.append(f1)
        aucs.append(auc)
        ce_losses.append(ce)

        print(f"Fold {fold} → "
              f"Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | "
              f"F1={f1:.4f} | AUC={auc:.4f} | CE Loss={ce:.4f}")

    # --- Average results per λ_mod ---
    mean_acc, std_acc = np.mean(accuracies), np.std(accuracies)
    mean_prec, std_prec = np.mean(precisions), np.std(precisions)
    mean_rec, std_rec = np.mean(recalls), np.std(recalls)
    mean_f1, std_f1 = np.mean(f1_scores), np.std(f1_scores)
    mean_auc, std_auc = np.mean(aucs), np.std(aucs)
    mean_ce, std_ce = np.mean(ce_losses), np.std(ce_losses)

    results_summary.append({
        "λ_mod": lambda_mod,
        "Accuracy": f"{mean_acc:.4f} ± {std_acc:.4f}",
        "Precision": f"{mean_prec:.4f} ± {std_prec:.4f}",
        "Recall": f"{mean_rec:.4f} ± {std_rec:.4f}",
        "F1": f"{mean_f1:.4f} ± {std_f1:.4f}",
        "AUC": f"{mean_auc:.4f} ± {std_auc:.4f}",
        "CE Loss": f"{mean_ce:.4f} ± {std_ce:.4f}",
    })

    print(f"\n=== λ_mod = {lambda_mod} → Average Results ===")
    print(f"Accuracy:  {mean_acc:.4f} ± {std_acc:.4f}")
    print(f"Precision: {mean_prec:.4f} ± {std_prec:.4f}")
    print(f"Recall:    {mean_rec:.4f} ± {std_rec:.4f}")
    print(f"F1-score:  {mean_f1:.4f} ± {std_f1:.4f}")
    print(f"AUC:       {mean_auc:.4f} ± {std_auc:.4f}")
    print(f"CE Loss:   {mean_ce:.4f} ± {std_ce:.4f}")

# ==========================================
# Final summary table
# ==========================================
print("\n\n========== FINAL SUMMARY TABLE (Controls vs Patients) ==========")
results_df = pd.DataFrame(results_summary)
print(results_df.to_string(index=False))
# Out:
# ==============================
#  Running with λ_mod = 0.001
# ==============================
#
# === Fold 1 ===
# Train Controls: 24, Train Patients: 49
# Fold 1 Epoch 1: TotalLoss=0.861455 | Sup=0.861688 | Unsup=-0.232636 | TrainAcc=0.2877
# Fold 1 Epoch 500: TotalLoss=0.006631 | Sup=0.006872 | Unsup=-0.240591 | TrainAcc=1.0000
# Fold 1 Epoch 1000: TotalLoss=0.000850 | Sup=0.001110 | Unsup=-0.260094 | TrainAcc=1.0000
# Fold 1 Epoch 1500: TotalLoss=-0.000022 | Sup=0.000330 | Unsup=-0.351255 | TrainAcc=1.0000
# Fold 1 Epoch 2000: TotalLoss=-0.000305 | Sup=0.000143 | Unsup=-0.447872 | TrainAcc=1.0000
# Fold 1 Epoch 2500: TotalLoss=-0.000358 | Sup=0.000112 | Unsup=-0.469697 | TrainAcc=1.0000
# Fold 1 Epoch 3000: TotalLoss=-0.000417 | Sup=0.000064 | Unsup=-0.480532 | TrainAcc=1.0000
# Fold 1 Epoch 3500: TotalLoss=-0.000436 | Sup=0.000045 | Unsup=-0.481451 | TrainAcc=1.0000
# Fold 1 Epoch 4000: TotalLoss=-0.000410 | Sup=0.000073 | Unsup=-0.483228 | TrainAcc=1.0000
# Fold 1 Epoch 4500: TotalLoss=-0.000419 | Sup=0.000063 | Unsup=-0.482046 | TrainAcc=1.0000
# Fold 1 Epoch 5000: TotalLoss=-0.000424 | Sup=0.000060 | Unsup=-0.484445 | TrainAcc=1.0000
#  Saved checkpoint: ARMA_Cut_NIFD/checkpoint_lambda_0.001_fold_1.pt
# Fold 1 → Acc=0.7671 | Prec=0.9706 | Rec=0.6735 | F1=0.7952 | AUC=0.9328 | CE Loss=0.8647
#
# === Fold 2 ===
# Train Controls: 24, Train Patients: 49
# Fold 2 Epoch 1: TotalLoss=0.722149 | Sup=0.722382 | Unsup=-0.233001 | TrainAcc=0.5616
# Fold 2 Epoch 500: TotalLoss=0.004537 | Sup=0.004806 | Unsup=-0.269087 | TrainAcc=1.0000
# Fold 2 Epoch 1000: TotalLoss=0.000283 | Sup=0.000583 | Unsup=-0.299662 | TrainAcc=1.0000
# Fold 2 Epoch 1500: TotalLoss=-0.000268 | Sup=0.000136 | Unsup=-0.403635 | TrainAcc=1.0000
# Fold 2 Epoch 2000: TotalLoss=-0.000367 | Sup=0.000094 | Unsup=-0.460819 | TrainAcc=1.0000
# Fold 2 Epoch 2500: TotalLoss=-0.000427 | Sup=0.000053 | Unsup=-0.480612 | TrainAcc=1.0000
# Fold 2 Epoch 3000: TotalLoss=-0.000438 | Sup=0.000046 | Unsup=-0.484685 | TrainAcc=1.0000
# Fold 2 Epoch 3500: TotalLoss=-0.000416 | Sup=0.000066 | Unsup=-0.482302 | TrainAcc=1.0000
# Fold 2 Epoch 4000: TotalLoss=-0.000434 | Sup=0.000050 | Unsup=-0.484682 | TrainAcc=1.0000
# Fold 2 Epoch 4500: TotalLoss=-0.000427 | Sup=0.000057 | Unsup=-0.484338 | TrainAcc=1.0000
# Fold 2 Epoch 5000: TotalLoss=-0.000422 | Sup=0.000061 | Unsup=-0.483598 | TrainAcc=1.0000
#  Saved checkpoint: ARMA_Cut_NIFD/checkpoint_lambda_0.001_fold_2.pt
# Fold 2 → Acc=0.8219 | Prec=1.0000 | Rec=0.7347 | F1=0.8471 | AUC=0.9379 | CE Loss=0.6139
#
# === Fold 3 ===
# Train Controls: 24, Train Patients: 49
# Fold 3 Epoch 1: TotalLoss=0.742245 | Sup=0.742478 | Unsup=-0.233557 | TrainAcc=0.4795
# Fold 3 Epoch 500: TotalLoss=0.004828 | Sup=0.005083 | Unsup=-0.254803 | TrainAcc=1.0000
# Fold 3 Epoch 1000: TotalLoss=0.000424 | Sup=0.000685 | Unsup=-0.260627 | TrainAcc=1.0000
# Fold 3 Epoch 1500: TotalLoss=-0.000087 | Sup=0.000215 | Unsup=-0.302417 | TrainAcc=1.0000
# Fold 3 Epoch 2000: TotalLoss=-0.000304 | Sup=0.000080 | Unsup=-0.384175 | TrainAcc=1.0000
# Fold 3 Epoch 2500: TotalLoss=-0.000424 | Sup=0.000048 | Unsup=-0.472741 | TrainAcc=1.0000
# Fold 3 Epoch 3000: TotalLoss=-0.000431 | Sup=0.000043 | Unsup=-0.474549 | TrainAcc=1.0000
# Fold 3 Epoch 3500: TotalLoss=-0.000420 | Sup=0.000066 | Unsup=-0.485944 | TrainAcc=1.0000
# Fold 3 Epoch 4000: TotalLoss=-0.000429 | Sup=0.000054 | Unsup=-0.482591 | TrainAcc=1.0000
# Fold 3 Epoch 4500: TotalLoss=-0.000440 | Sup=0.000043 | Unsup=-0.483299 | TrainAcc=1.0000
# Fold 3 Epoch 5000: TotalLoss=-0.000413 | Sup=0.000072 | Unsup=-0.485548 | TrainAcc=1.0000
#  Saved checkpoint: ARMA_Cut_NIFD/checkpoint_lambda_0.001_fold_3.pt
# Fold 3 → Acc=0.7945 | Prec=0.9474 | Rec=0.7347 | F1=0.8276 | AUC=0.9371 | CE Loss=0.7745
#
# === Fold 4 ===
# Train Controls: 24, Train Patients: 49
# Fold 4 Epoch 1: TotalLoss=0.749489 | Sup=0.749723 | Unsup=-0.233384 | TrainAcc=0.5068
# Fold 4 Epoch 500: TotalLoss=0.006088 | Sup=0.006337 | Unsup=-0.249210 | TrainAcc=1.0000
# Fold 4 Epoch 1000: TotalLoss=0.000548 | Sup=0.000809 | Unsup=-0.261799 | TrainAcc=1.0000
# Fold 4 Epoch 1500: TotalLoss=-0.000198 | Sup=0.000149 | Unsup=-0.346941 | TrainAcc=1.0000
# Fold 4 Epoch 2000: TotalLoss=-0.000364 | Sup=0.000097 | Unsup=-0.460779 | TrainAcc=1.0000
# Fold 4 Epoch 2500: TotalLoss=-0.000428 | Sup=0.000052 | Unsup=-0.480529 | TrainAcc=1.0000
# Fold 4 Epoch 3000: TotalLoss=-0.000431 | Sup=0.000052 | Unsup=-0.483114 | TrainAcc=1.0000
# Fold 4 Epoch 3500: TotalLoss=-0.000435 | Sup=0.000049 | Unsup=-0.484299 | TrainAcc=1.0000
# Fold 4 Epoch 4000: TotalLoss=-0.000434 | Sup=0.000048 | Unsup=-0.482346 | TrainAcc=1.0000
# Fold 4 Epoch 4500: TotalLoss=-0.000432 | Sup=0.000053 | Unsup=-0.484421 | TrainAcc=1.0000
# Fold 4 Epoch 5000: TotalLoss=-0.000423 | Sup=0.000061 | Unsup=-0.483934 | TrainAcc=1.0000
#  Saved checkpoint: ARMA_Cut_NIFD/checkpoint_lambda_0.001_fold_4.pt
# Fold 4 → Acc=0.7808 | Prec=0.9714 | Rec=0.6939 | F1=0.8095 | AUC=0.9269 | CE Loss=0.8011
#
# === Fold 5 ===
# Train Controls: 24, Train Patients: 49
# Fold 5 Epoch 1: TotalLoss=0.773918 | Sup=0.774151 | Unsup=-0.233080 | TrainAcc=0.4110
# Fold 5 Epoch 500: TotalLoss=0.004475 | Sup=0.004687 | Unsup=-0.212167 | TrainAcc=1.0000
# Fold 5 Epoch 1000: TotalLoss=0.000846 | Sup=0.001058 | Unsup=-0.211886 | TrainAcc=1.0000
# Fold 5 Epoch 1500: TotalLoss=0.000016 | Sup=0.000260 | Unsup=-0.243889 | TrainAcc=1.0000
# Fold 5 Epoch 2000: TotalLoss=-0.000178 | Sup=0.000147 | Unsup=-0.325749 | TrainAcc=1.0000
# Fold 5 Epoch 2500: TotalLoss=-0.000396 | Sup=0.000063 | Unsup=-0.458826 | TrainAcc=1.0000
# Fold 5 Epoch 3000: TotalLoss=-0.000431 | Sup=0.000049 | Unsup=-0.479501 | TrainAcc=1.0000
# Fold 5 Epoch 3500: TotalLoss=-0.000424 | Sup=0.000059 | Unsup=-0.482999 | TrainAcc=1.0000
# Fold 5 Epoch 4000: TotalLoss=-0.000431 | Sup=0.000051 | Unsup=-0.481854 | TrainAcc=1.0000
# Fold 5 Epoch 4500: TotalLoss=-0.000437 | Sup=0.000048 | Unsup=-0.485817 | TrainAcc=1.0000
# Fold 5 Epoch 5000: TotalLoss=-0.000420 | Sup=0.000064 | Unsup=-0.484708 | TrainAcc=1.0000
#  Saved checkpoint: ARMA_Cut_NIFD/checkpoint_lambda_0.001_fold_5.pt
# Fold 5 → Acc=0.8356 | Prec=1.0000 | Rec=0.7551 | F1=0.8605 | AUC=0.9456 | CE Loss=0.6095
#
# === Fold 6 ===
# Train Controls: 24, Train Patients: 49
# Fold 6 Epoch 1: TotalLoss=0.661380 | Sup=0.661613 | Unsup=-0.233120 | TrainAcc=0.5753
# Fold 6 Epoch 500: TotalLoss=0.002865 | Sup=0.003116 | Unsup=-0.251123 | TrainAcc=1.0000
# Fold 6 Epoch 1000: TotalLoss=0.000344 | Sup=0.000607 | Unsup=-0.262458 | TrainAcc=1.0000
# Fold 6 Epoch 1500: TotalLoss=-0.000101 | Sup=0.000215 | Unsup=-0.316510 | TrainAcc=1.0000
# Fold 6 Epoch 2000: TotalLoss=-0.000368 | Sup=0.000081 | Unsup=-0.448955 | TrainAcc=1.0000
# Fold 6 Epoch 2500: TotalLoss=-0.000436 | Sup=0.000046 | Unsup=-0.482362 | TrainAcc=1.0000
# Fold 6 Epoch 3000: TotalLoss=-0.000418 | Sup=0.000058 | Unsup=-0.476243 | TrainAcc=1.0000
# Fold 6 Epoch 3500: TotalLoss=-0.000430 | Sup=0.000055 | Unsup=-0.484980 | TrainAcc=1.0000
# Fold 6 Epoch 4000: TotalLoss=-0.000435 | Sup=0.000050 | Unsup=-0.485454 | TrainAcc=1.0000
# Fold 6 Epoch 4500: TotalLoss=-0.000413 | Sup=0.000071 | Unsup=-0.483878 | TrainAcc=1.0000
# Fold 6 Epoch 5000: TotalLoss=-0.000435 | Sup=0.000051 | Unsup=-0.485906 | TrainAcc=1.0000
#  Saved checkpoint: ARMA_Cut_NIFD/checkpoint_lambda_0.001_fold_6.pt
# Fold 6 → Acc=0.8493 | Prec=1.0000 | Rec=0.7755 | F1=0.8736 | AUC=0.9515 | CE Loss=0.5221
#
# === Fold 7 ===
# Train Controls: 24, Train Patients: 49
# Fold 7 Epoch 1: TotalLoss=0.692718 | Sup=0.692951 | Unsup=-0.233249 | TrainAcc=0.4795
# Fold 7 Epoch 500: TotalLoss=0.004800 | Sup=0.005043 | Unsup=-0.242793 | TrainAcc=1.0000
# Fold 7 Epoch 1000: TotalLoss=0.000370 | Sup=0.000622 | Unsup=-0.252739 | TrainAcc=1.0000
# Fold 7 Epoch 1500: TotalLoss=-0.000129 | Sup=0.000197 | Unsup=-0.326149 | TrainAcc=1.0000
# Fold 7 Epoch 2000: TotalLoss=-0.000327 | Sup=0.000119 | Unsup=-0.446777 | TrainAcc=1.0000
# Fold 7 Epoch 2500: TotalLoss=-0.000423 | Sup=0.000053 | Unsup=-0.475602 | TrainAcc=1.0000
# Fold 7 Epoch 3000: TotalLoss=-0.000427 | Sup=0.000058 | Unsup=-0.485188 | TrainAcc=1.0000
# Fold 7 Epoch 3500: TotalLoss=-0.000435 | Sup=0.000050 | Unsup=-0.485295 | TrainAcc=1.0000
# Fold 7 Epoch 4000: TotalLoss=-0.000440 | Sup=0.000047 | Unsup=-0.486487 | TrainAcc=1.0000
# Fold 7 Epoch 4500: TotalLoss=-0.000437 | Sup=0.000052 | Unsup=-0.489450 | TrainAcc=1.0000
# Fold 7 Epoch 5000: TotalLoss=-0.000424 | Sup=0.000061 | Unsup=-0.485103 | TrainAcc=1.0000
#  Saved checkpoint: ARMA_Cut_NIFD/checkpoint_lambda_0.001_fold_7.pt
# Fold 7 → Acc=0.8082 | Prec=1.0000 | Rec=0.7143 | F1=0.8333 | AUC=0.9269 | CE Loss=0.8185
#
# === Fold 8 ===
# Train Controls: 24, Train Patients: 49
# Fold 8 Epoch 1: TotalLoss=0.768097 | Sup=0.768331 | Unsup=-0.233470 | TrainAcc=0.4795
# Fold 8 Epoch 500: TotalLoss=0.005453 | Sup=0.005691 | Unsup=-0.238762 | TrainAcc=1.0000
# Fold 8 Epoch 1000: TotalLoss=0.000596 | Sup=0.000851 | Unsup=-0.254584 | TrainAcc=1.0000
# Fold 8 Epoch 1500: TotalLoss=-0.000138 | Sup=0.000176 | Unsup=-0.313981 | TrainAcc=1.0000
# Fold 8 Epoch 2000: TotalLoss=-0.000333 | Sup=0.000106 | Unsup=-0.438779 | TrainAcc=1.0000
# Fold 8 Epoch 2500: TotalLoss=-0.000403 | Sup=0.000065 | Unsup=-0.468489 | TrainAcc=1.0000
# Fold 8 Epoch 3000: TotalLoss=-0.000414 | Sup=0.000068 | Unsup=-0.482111 | TrainAcc=1.0000
# Fold 8 Epoch 3500: TotalLoss=-0.000414 | Sup=0.000069 | Unsup=-0.482621 | TrainAcc=1.0000
# Fold 8 Epoch 4000: TotalLoss=-0.000424 | Sup=0.000059 | Unsup=-0.483184 | TrainAcc=1.0000
# Fold 8 Epoch 4500: TotalLoss=-0.000425 | Sup=0.000057 | Unsup=-0.482353 | TrainAcc=1.0000
# Fold 8 Epoch 5000: TotalLoss=-0.000419 | Sup=0.000064 | Unsup=-0.482388 | TrainAcc=1.0000
#  Saved checkpoint: ARMA_Cut_NIFD/checkpoint_lambda_0.001_fold_8.pt
# Fold 8 → Acc=0.7671 | Prec=0.9444 | Rec=0.6939 | F1=0.8000 | AUC=0.9379 | CE Loss=0.7580
#
# === Fold 9 ===
# Train Controls: 24, Train Patients: 49
# Fold 9 Epoch 1: TotalLoss=0.683810 | Sup=0.684045 | Unsup=-0.234063 | TrainAcc=0.5753
# Fold 9 Epoch 500: TotalLoss=0.004520 | Sup=0.004731 | Unsup=-0.210830 | TrainAcc=1.0000
# Fold 9 Epoch 1000: TotalLoss=0.000608 | Sup=0.000818 | Unsup=-0.210103 | TrainAcc=1.0000
# Fold 9 Epoch 1500: TotalLoss=-0.000089 | Sup=0.000175 | Unsup=-0.263524 | TrainAcc=1.0000
# Fold 9 Epoch 2000: TotalLoss=-0.000330 | Sup=0.000110 | Unsup=-0.440219 | TrainAcc=1.0000
# Fold 9 Epoch 2500: TotalLoss=-0.000414 | Sup=0.000062 | Unsup=-0.476171 | TrainAcc=1.0000
# Fold 9 Epoch 3000: TotalLoss=-0.000430 | Sup=0.000047 | Unsup=-0.477797 | TrainAcc=1.0000
# Fold 9 Epoch 3500: TotalLoss=-0.000451 | Sup=0.000033 | Unsup=-0.483168 | TrainAcc=1.0000
# Fold 9 Epoch 4000: TotalLoss=-0.000434 | Sup=0.000046 | Unsup=-0.480528 | TrainAcc=1.0000
# Fold 9 Epoch 4500: TotalLoss=-0.000437 | Sup=0.000043 | Unsup=-0.480003 | TrainAcc=1.0000
# Fold 9 Epoch 5000: TotalLoss=-0.000431 | Sup=0.000050 | Unsup=-0.480251 | TrainAcc=1.0000
#  Saved checkpoint: ARMA_Cut_NIFD/checkpoint_lambda_0.001_fold_9.pt
# Fold 9 → Acc=0.8356 | Prec=1.0000 | Rec=0.7551 | F1=0.8605 | AUC=0.9617 | CE Loss=0.4856
#
# === Fold 10 ===
# Train Controls: 24, Train Patients: 49
# Fold 10 Epoch 1: TotalLoss=0.783522 | Sup=0.783757 | Unsup=-0.234593 | TrainAcc=0.4247
# Fold 10 Epoch 500: TotalLoss=0.005556 | Sup=0.005798 | Unsup=-0.242246 | TrainAcc=1.0000
# Fold 10 Epoch 1000: TotalLoss=0.000512 | Sup=0.000770 | Unsup=-0.258052 | TrainAcc=1.0000
# Fold 10 Epoch 1500: TotalLoss=-0.000076 | Sup=0.000222 | Unsup=-0.298644 | TrainAcc=1.0000
# Fold 10 Epoch 2000: TotalLoss=-0.000334 | Sup=0.000097 | Unsup=-0.430993 | TrainAcc=1.0000
# Fold 10 Epoch 2500: TotalLoss=-0.000427 | Sup=0.000053 | Unsup=-0.479999 | TrainAcc=1.0000
# Fold 10 Epoch 3000: TotalLoss=-0.000446 | Sup=0.000039 | Unsup=-0.485206 | TrainAcc=1.0000
# Fold 10 Epoch 3500: TotalLoss=-0.000449 | Sup=0.000036 | Unsup=-0.485438 | TrainAcc=1.0000
# Fold 10 Epoch 4000: TotalLoss=-0.000437 | Sup=0.000049 | Unsup=-0.486491 | TrainAcc=1.0000
# Fold 10 Epoch 4500: TotalLoss=-0.000419 | Sup=0.000065 | Unsup=-0.483717 | TrainAcc=1.0000
# Fold 10 Epoch 5000: TotalLoss=-0.000418 | Sup=0.000067 | Unsup=-0.485088 | TrainAcc=1.0000
#  Saved checkpoint: ARMA_Cut_NIFD/checkpoint_lambda_0.001_fold_10.pt
# Fold 10 → Acc=0.7808 | Prec=0.9714 | Rec=0.6939 | F1=0.8095 | AUC=0.9337 | CE Loss=0.7652
#
# === Fold 11 ===
# Train Controls: 24, Train Patients: 49
# Fold 11 Epoch 1: TotalLoss=0.772572 | Sup=0.772804 | Unsup=-0.232111 | TrainAcc=0.4795
# Fold 11 Epoch 500: TotalLoss=0.004390 | Sup=0.004630 | Unsup=-0.239318 | TrainAcc=1.0000
# Fold 11 Epoch 1000: TotalLoss=0.000400 | Sup=0.000665 | Unsup=-0.265208 | TrainAcc=1.0000
# Fold 11 Epoch 1500: TotalLoss=-0.000183 | Sup=0.000160 | Unsup=-0.342346 | TrainAcc=1.0000
# Fold 11 Epoch 2000: TotalLoss=-0.000385 | Sup=0.000076 | Unsup=-0.460635 | TrainAcc=1.0000
# Fold 11 Epoch 2500: TotalLoss=-0.000432 | Sup=0.000047 | Unsup=-0.479396 | TrainAcc=1.0000
# Fold 11 Epoch 3000: TotalLoss=-0.000422 | Sup=0.000062 | Unsup=-0.484726 | TrainAcc=1.0000
# Fold 11 Epoch 3500: TotalLoss=-0.000441 | Sup=0.000046 | Unsup=-0.486465 | TrainAcc=1.0000
# Fold 11 Epoch 4000: TotalLoss=-0.000442 | Sup=0.000046 | Unsup=-0.487559 | TrainAcc=1.0000
# Fold 11 Epoch 4500: TotalLoss=-0.000431 | Sup=0.000056 | Unsup=-0.487438 | TrainAcc=1.0000
# Fold 11 Epoch 5000: TotalLoss=-0.000429 | Sup=0.000058 | Unsup=-0.487268 | TrainAcc=1.0000
#  Saved checkpoint: ARMA_Cut_NIFD/checkpoint_lambda_0.001_fold_11.pt
# Fold 11 → Acc=0.8219 | Prec=1.0000 | Rec=0.7347 | F1=0.8471 | AUC=0.9430 | CE Loss=0.7288
#
# === Fold 12 ===
# Train Controls: 24, Train Patients: 49
# Fold 12 Epoch 1: TotalLoss=0.774869 | Sup=0.775104 | Unsup=-0.234455 | TrainAcc=0.5068
# Fold 12 Epoch 500: TotalLoss=0.004489 | Sup=0.004727 | Unsup=-0.238467 | TrainAcc=1.0000
# Fold 12 Epoch 1000: TotalLoss=0.000423 | Sup=0.000677 | Unsup=-0.254740 | TrainAcc=1.0000
# Fold 12 Epoch 1500: TotalLoss=-0.000175 | Sup=0.000155 | Unsup=-0.330335 | TrainAcc=1.0000
# Fold 12 Epoch 2000: TotalLoss=-0.000359 | Sup=0.000082 | Unsup=-0.441116 | TrainAcc=1.0000
# Fold 12 Epoch 2500: TotalLoss=-0.000411 | Sup=0.000062 | Unsup=-0.472726 | TrainAcc=1.0000
# Fold 12 Epoch 3000: TotalLoss=-0.000424 | Sup=0.000051 | Unsup=-0.474451 | TrainAcc=1.0000
# Fold 12 Epoch 3500: TotalLoss=-0.000440 | Sup=0.000042 | Unsup=-0.481183 | TrainAcc=1.0000
# Fold 12 Epoch 4000: TotalLoss=-0.000425 | Sup=0.000057 | Unsup=-0.482275 | TrainAcc=1.0000
# Fold 12 Epoch 4500: TotalLoss=-0.000424 | Sup=0.000058 | Unsup=-0.481438 | TrainAcc=1.0000
# Fold 12 Epoch 5000: TotalLoss=-0.000427 | Sup=0.000055 | Unsup=-0.481613 | TrainAcc=1.0000
#  Saved checkpoint: ARMA_Cut_NIFD/checkpoint_lambda_0.001_fold_12.pt
# Fold 12 → Acc=0.7808 | Prec=1.0000 | Rec=0.6735 | F1=0.8049 | AUC=0.9090 | CE Loss=0.7713
#
# === Fold 13 ===
# Train Controls: 24, Train Patients: 49
# Fold 13 Epoch 1: TotalLoss=0.817369 | Sup=0.817604 | Unsup=-0.234559 | TrainAcc=0.4521
# Fold 13 Epoch 500: TotalLoss=0.005745 | Sup=0.005984 | Unsup=-0.238926 | TrainAcc=1.0000
# Fold 13 Epoch 1000: TotalLoss=0.000586 | Sup=0.000837 | Unsup=-0.251797 | TrainAcc=1.0000
# Fold 13 Epoch 1500: TotalLoss=-0.000117 | Sup=0.000223 | Unsup=-0.339438 | TrainAcc=1.0000
# Fold 13 Epoch 2000: TotalLoss=-0.000351 | Sup=0.000103 | Unsup=-0.453785 | TrainAcc=1.0000
# Fold 13 Epoch 2500: TotalLoss=-0.000422 | Sup=0.000059 | Unsup=-0.481349 | TrainAcc=1.0000
# Fold 13 Epoch 3000: TotalLoss=-0.000424 | Sup=0.000055 | Unsup=-0.478603 | TrainAcc=1.0000
# Fold 13 Epoch 3500: TotalLoss=-0.000431 | Sup=0.000052 | Unsup=-0.483504 | TrainAcc=1.0000
# Fold 13 Epoch 4000: TotalLoss=-0.000424 | Sup=0.000058 | Unsup=-0.481758 | TrainAcc=1.0000
# Fold 13 Epoch 4500: TotalLoss=-0.000427 | Sup=0.000055 | Unsup=-0.482778 | TrainAcc=1.0000
# Fold 13 Epoch 5000: TotalLoss=-0.000411 | Sup=0.000071 | Unsup=-0.482491 | TrainAcc=1.0000
#  Saved checkpoint: ARMA_Cut_NIFD/checkpoint_lambda_0.001_fold_13.pt
# Fold 13 → Acc=0.7945 | Prec=1.0000 | Rec=0.6939 | F1=0.8193 | AUC=0.9447 | CE Loss=0.6859
#
# === Fold 14 ===
# Train Controls: 24, Train Patients: 49
# Fold 14 Epoch 1: TotalLoss=0.741511 | Sup=0.741744 | Unsup=-0.232629 | TrainAcc=0.4521
# Fold 14 Epoch 500: TotalLoss=0.005046 | Sup=0.005306 | Unsup=-0.259525 | TrainAcc=1.0000
# Fold 14 Epoch 1000: TotalLoss=0.000475 | Sup=0.000753 | Unsup=-0.278322 | TrainAcc=1.0000
# Fold 14 Epoch 1500: TotalLoss=-0.000191 | Sup=0.000179 | Unsup=-0.370424 | TrainAcc=1.0000
# Fold 14 Epoch 2000: TotalLoss=-0.000362 | Sup=0.000092 | Unsup=-0.453436 | TrainAcc=1.0000
# Fold 14 Epoch 2500: TotalLoss=-0.000408 | Sup=0.000062 | Unsup=-0.469911 | TrainAcc=1.0000
# Fold 14 Epoch 3000: TotalLoss=-0.000431 | Sup=0.000046 | Unsup=-0.477481 | TrainAcc=1.0000
# Fold 14 Epoch 3500: TotalLoss=-0.000443 | Sup=0.000039 | Unsup=-0.482441 | TrainAcc=1.0000
# Fold 14 Epoch 4000: TotalLoss=-0.000427 | Sup=0.000057 | Unsup=-0.483846 | TrainAcc=1.0000
# Fold 14 Epoch 4500: TotalLoss=-0.000424 | Sup=0.000061 | Unsup=-0.484126 | TrainAcc=1.0000
# Fold 14 Epoch 5000: TotalLoss=-0.000417 | Sup=0.000067 | Unsup=-0.483304 | TrainAcc=1.0000
#  Saved checkpoint: ARMA_Cut_NIFD/checkpoint_lambda_0.001_fold_14.pt
# Fold 14 → Acc=0.8493 | Prec=1.0000 | Rec=0.7755 | F1=0.8736 | AUC=0.9371 | CE Loss=0.5704
#
# === Fold 15 ===
# Train Controls: 24, Train Patients: 49
# Fold 15 Epoch 1: TotalLoss=0.846198 | Sup=0.846430 | Unsup=-0.231747 | TrainAcc=0.3836
# Fold 15 Epoch 500: TotalLoss=0.006947 | Sup=0.007175 | Unsup=-0.227783 | TrainAcc=1.0000
# Fold 15 Epoch 1000: TotalLoss=0.001173 | Sup=0.001409 | Unsup=-0.235314 | TrainAcc=1.0000
# Fold 15 Epoch 1500: TotalLoss=-0.000041 | Sup=0.000225 | Unsup=-0.265540 | TrainAcc=1.0000
# Fold 15 Epoch 2000: TotalLoss=-0.000299 | Sup=0.000068 | Unsup=-0.367255 | TrainAcc=1.0000
# Fold 15 Epoch 2500: TotalLoss=-0.000405 | Sup=0.000056 | Unsup=-0.461522 | TrainAcc=1.0000
# Fold 15 Epoch 3000: TotalLoss=-0.000436 | Sup=0.000044 | Unsup=-0.480400 | TrainAcc=1.0000
# Fold 15 Epoch 3500: TotalLoss=-0.000419 | Sup=0.000061 | Unsup=-0.480044 | TrainAcc=1.0000
# Fold 15 Epoch 4000: TotalLoss=-0.000429 | Sup=0.000056 | Unsup=-0.484972 | TrainAcc=1.0000
# Fold 15 Epoch 4500: TotalLoss=-0.000438 | Sup=0.000044 | Unsup=-0.481353 | TrainAcc=1.0000
# Fold 15 Epoch 5000: TotalLoss=-0.000413 | Sup=0.000069 | Unsup=-0.481409 | TrainAcc=1.0000
#  Saved checkpoint: ARMA_Cut_NIFD/checkpoint_lambda_0.001_fold_15.pt
# Fold 15 → Acc=0.7945 | Prec=1.0000 | Rec=0.6939 | F1=0.8193 | AUC=0.9702 | CE Loss=0.5949
#
# === Fold 16 ===
# Train Controls: 24, Train Patients: 49
# Fold 16 Epoch 1: TotalLoss=0.771050 | Sup=0.771284 | Unsup=-0.234152 | TrainAcc=0.5205
# Fold 16 Epoch 500: TotalLoss=0.005464 | Sup=0.005745 | Unsup=-0.280854 | TrainAcc=1.0000
# Fold 16 Epoch 1000: TotalLoss=0.000431 | Sup=0.000732 | Unsup=-0.301480 | TrainAcc=1.0000
# Fold 16 Epoch 1500: TotalLoss=-0.000132 | Sup=0.000234 | Unsup=-0.366442 | TrainAcc=1.0000
# Fold 16 Epoch 2000: TotalLoss=-0.000376 | Sup=0.000065 | Unsup=-0.441033 | TrainAcc=1.0000
# Fold 16 Epoch 2500: TotalLoss=-0.000427 | Sup=0.000047 | Unsup=-0.473399 | TrainAcc=1.0000
# Fold 16 Epoch 3000: TotalLoss=-0.000440 | Sup=0.000043 | Unsup=-0.483170 | TrainAcc=1.0000
# Fold 16 Epoch 3500: TotalLoss=-0.000434 | Sup=0.000054 | Unsup=-0.487335 | TrainAcc=1.0000
# Fold 16 Epoch 4000: TotalLoss=-0.000428 | Sup=0.000060 | Unsup=-0.487708 | TrainAcc=1.0000
# Fold 16 Epoch 4500: TotalLoss=-0.000421 | Sup=0.000066 | Unsup=-0.487084 | TrainAcc=1.0000
# Fold 16 Epoch 5000: TotalLoss=-0.000423 | Sup=0.000064 | Unsup=-0.487196 | TrainAcc=1.0000
#  Saved checkpoint: ARMA_Cut_NIFD/checkpoint_lambda_0.001_fold_16.pt
# Fold 16 → Acc=0.8082 | Prec=1.0000 | Rec=0.7143 | F1=0.8333 | AUC=0.9558 | CE Loss=0.6900
#
# === Fold 17 ===
# Train Controls: 24, Train Patients: 49
# Fold 17 Epoch 1: TotalLoss=0.671304 | Sup=0.671537 | Unsup=-0.232717 | TrainAcc=0.5753
# Fold 17 Epoch 500: TotalLoss=0.004264 | Sup=0.004489 | Unsup=-0.225280 | TrainAcc=1.0000
# Fold 17 Epoch 1000: TotalLoss=0.000358 | Sup=0.000588 | Unsup=-0.230274 | TrainAcc=1.0000
# Fold 17 Epoch 1500: TotalLoss=-0.000124 | Sup=0.000146 | Unsup=-0.269930 | TrainAcc=1.0000
# Fold 17 Epoch 2000: TotalLoss=-0.000283 | Sup=0.000077 | Unsup=-0.360407 | TrainAcc=1.0000
# Fold 17 Epoch 2500: TotalLoss=-0.000373 | Sup=0.000061 | Unsup=-0.434113 | TrainAcc=1.0000
# Fold 17 Epoch 3000: TotalLoss=-0.000419 | Sup=0.000050 | Unsup=-0.468737 | TrainAcc=1.0000
# Fold 17 Epoch 3500: TotalLoss=-0.000424 | Sup=0.000050 | Unsup=-0.473965 | TrainAcc=1.0000
# Fold 17 Epoch 4000: TotalLoss=-0.000432 | Sup=0.000044 | Unsup=-0.475848 | TrainAcc=1.0000
# Fold 17 Epoch 4500: TotalLoss=-0.000423 | Sup=0.000052 | Unsup=-0.474618 | TrainAcc=1.0000
# Fold 17 Epoch 5000: TotalLoss=-0.000426 | Sup=0.000054 | Unsup=-0.480854 | TrainAcc=1.0000
#  Saved checkpoint: ARMA_Cut_NIFD/checkpoint_lambda_0.001_fold_17.pt
# Fold 17 → Acc=0.7945 | Prec=0.9722 | Rec=0.7143 | F1=0.8235 | AUC=0.9430 | CE Loss=0.7154
#
# === Fold 18 ===
# Train Controls: 24, Train Patients: 49
# Fold 18 Epoch 1: TotalLoss=0.646569 | Sup=0.646801 | Unsup=-0.231765 | TrainAcc=0.6301
# Fold 18 Epoch 500: TotalLoss=0.003926 | Sup=0.004145 | Unsup=-0.218550 | TrainAcc=1.0000
# Fold 18 Epoch 1000: TotalLoss=0.000228 | Sup=0.000464 | Unsup=-0.235892 | TrainAcc=1.0000
# Fold 18 Epoch 1500: TotalLoss=-0.000150 | Sup=0.000147 | Unsup=-0.296268 | TrainAcc=1.0000
# Fold 18 Epoch 2000: TotalLoss=-0.000337 | Sup=0.000076 | Unsup=-0.412885 | TrainAcc=1.0000
# Fold 18 Epoch 2500: TotalLoss=-0.000409 | Sup=0.000064 | Unsup=-0.472723 | TrainAcc=1.0000
# Fold 18 Epoch 3000: TotalLoss=-0.000434 | Sup=0.000045 | Unsup=-0.478673 | TrainAcc=1.0000
# Fold 18 Epoch 3500: TotalLoss=-0.000432 | Sup=0.000050 | Unsup=-0.482218 | TrainAcc=1.0000
# Fold 18 Epoch 4000: TotalLoss=-0.000439 | Sup=0.000044 | Unsup=-0.483343 | TrainAcc=1.0000
# Fold 18 Epoch 4500: TotalLoss=-0.000423 | Sup=0.000059 | Unsup=-0.481422 | TrainAcc=1.0000
# Fold 18 Epoch 5000: TotalLoss=-0.000417 | Sup=0.000066 | Unsup=-0.482662 | TrainAcc=1.0000
#  Saved checkpoint: ARMA_Cut_NIFD/checkpoint_lambda_0.001_fold_18.pt
# Fold 18 → Acc=0.7808 | Prec=1.0000 | Rec=0.6735 | F1=0.8049 | AUC=0.9226 | CE Loss=0.7180
#
# === Fold 19 ===
# Train Controls: 24, Train Patients: 49
# Fold 19 Epoch 1: TotalLoss=0.665792 | Sup=0.666024 | Unsup=-0.231581 | TrainAcc=0.5616
# Fold 19 Epoch 500: TotalLoss=0.003861 | Sup=0.004074 | Unsup=-0.212012 | TrainAcc=1.0000
# Fold 19 Epoch 1000: TotalLoss=0.000414 | Sup=0.000640 | Unsup=-0.225913 | TrainAcc=1.0000
# Fold 19 Epoch 1500: TotalLoss=-0.000084 | Sup=0.000202 | Unsup=-0.285558 | TrainAcc=1.0000
# Fold 19 Epoch 2000: TotalLoss=-0.000276 | Sup=0.000120 | Unsup=-0.396101 | TrainAcc=1.0000
# Fold 19 Epoch 2500: TotalLoss=-0.000415 | Sup=0.000052 | Unsup=-0.466768 | TrainAcc=1.0000
# Fold 19 Epoch 3000: TotalLoss=-0.000399 | Sup=0.000077 | Unsup=-0.475867 | TrainAcc=1.0000
# Fold 19 Epoch 3500: TotalLoss=-0.000433 | Sup=0.000047 | Unsup=-0.479546 | TrainAcc=1.0000
# Fold 19 Epoch 4000: TotalLoss=-0.000426 | Sup=0.000055 | Unsup=-0.480683 | TrainAcc=1.0000
# Fold 19 Epoch 4500: TotalLoss=-0.000432 | Sup=0.000050 | Unsup=-0.481705 | TrainAcc=1.0000
# Fold 19 Epoch 5000: TotalLoss=-0.000409 | Sup=0.000072 | Unsup=-0.481034 | TrainAcc=1.0000
#  Saved checkpoint: ARMA_Cut_NIFD/checkpoint_lambda_0.001_fold_19.pt
# Fold 19 → Acc=0.8219 | Prec=1.0000 | Rec=0.7347 | F1=0.8471 | AUC=0.9269 | CE Loss=0.6109
#
# === Fold 20 ===
# Train Controls: 24, Train Patients: 49
# Fold 20 Epoch 1: TotalLoss=0.636377 | Sup=0.636608 | Unsup=-0.231626 | TrainAcc=0.6438
# Fold 20 Epoch 500: TotalLoss=0.004614 | Sup=0.004830 | Unsup=-0.216218 | TrainAcc=1.0000
# Fold 20 Epoch 1000: TotalLoss=0.000647 | Sup=0.000854 | Unsup=-0.206658 | TrainAcc=1.0000
# Fold 20 Epoch 1500: TotalLoss=0.000042 | Sup=0.000281 | Unsup=-0.238944 | TrainAcc=1.0000
# Fold 20 Epoch 2000: TotalLoss=-0.000196 | Sup=0.000123 | Unsup=-0.318731 | TrainAcc=1.0000
# Fold 20 Epoch 2500: TotalLoss=-0.000340 | Sup=0.000090 | Unsup=-0.430479 | TrainAcc=1.0000
# Fold 20 Epoch 3000: TotalLoss=-0.000399 | Sup=0.000072 | Unsup=-0.470405 | TrainAcc=1.0000
# Fold 20 Epoch 3500: TotalLoss=-0.000420 | Sup=0.000057 | Unsup=-0.477231 | TrainAcc=1.0000
# Fold 20 Epoch 4000: TotalLoss=-0.000425 | Sup=0.000054 | Unsup=-0.478623 | TrainAcc=1.0000
# Fold 20 Epoch 4500: TotalLoss=-0.000404 | Sup=0.000074 | Unsup=-0.478047 | TrainAcc=1.0000
# Fold 20 Epoch 5000: TotalLoss=-0.000423 | Sup=0.000060 | Unsup=-0.483473 | TrainAcc=1.0000
#  Saved checkpoint: ARMA_Cut_NIFD/checkpoint_lambda_0.001_fold_20.pt
# Fold 20 → Acc=0.7945 | Prec=0.9722 | Rec=0.7143 | F1=0.8235 | AUC=0.9651 | CE Loss=0.6553
#
# === λ_mod = 0.001 → Average Results ===
# Accuracy:  0.8041 ± 0.0249
# Precision: 0.9875 ± 0.0184
# Recall:    0.7173 ± 0.0311
# F1-score:  0.8307 ± 0.0235
# AUC:       0.9405 ± 0.0148
# CE Loss:   0.6877 ± 0.0998
#
# ==============================
#  Running with λ_mod = 0.005
# ==============================
#
# === Fold 1 ===
# Train Controls: 24, Train Patients: 49
# Fold 1 Epoch 1: TotalLoss=0.804779 | Sup=0.805946 | Unsup=-0.233367 | TrainAcc=0.3562
# Fold 1 Epoch 500: TotalLoss=0.004174 | Sup=0.005384 | Unsup=-0.241930 | TrainAcc=1.0000
# Fold 1 Epoch 1000: TotalLoss=-0.001157 | Sup=0.000698 | Unsup=-0.370892 | TrainAcc=1.0000
# Fold 1 Epoch 1500: TotalLoss=-0.002141 | Sup=0.000219 | Unsup=-0.472060 | TrainAcc=1.0000
# Fold 1 Epoch 2000: TotalLoss=-0.002315 | Sup=0.000101 | Unsup=-0.483160 | TrainAcc=1.0000
# Fold 1 Epoch 2500: TotalLoss=-0.002355 | Sup=0.000081 | Unsup=-0.487173 | TrainAcc=1.0000
# Fold 1 Epoch 3000: TotalLoss=-0.002377 | Sup=0.000057 | Unsup=-0.486828 | TrainAcc=1.0000
# Fold 1 Epoch 3500: TotalLoss=-0.002399 | Sup=0.000064 | Unsup=-0.492470 | TrainAcc=1.0000
# Fold 1 Epoch 4000: TotalLoss=-0.002423 | Sup=0.000041 | Unsup=-0.492707 | TrainAcc=1.0000
# Fold 1 Epoch 4500: TotalLoss=-0.002393 | Sup=0.000059 | Unsup=-0.490503 | TrainAcc=1.0000
# Fold 1 Epoch 5000: TotalLoss=-0.002410 | Sup=0.000054 | Unsup=-0.492772 | TrainAcc=1.0000
#  Saved checkpoint: ARMA_Cut_NIFD/checkpoint_lambda_0.005_fold_1.pt
# Fold 1 → Acc=0.8082 | Prec=1.0000 | Rec=0.7143 | F1=0.8333 | AUC=0.9456 | CE Loss=0.8221
#
# === Fold 2 ===
# Train Controls: 24, Train Patients: 49
# Fold 2 Epoch 1: TotalLoss=0.580103 | Sup=0.581274 | Unsup=-0.234247 | TrainAcc=0.6575
# Fold 2 Epoch 500: TotalLoss=0.002679 | Sup=0.003985 | Unsup=-0.261319 | TrainAcc=1.0000
# Fold 2 Epoch 1000: TotalLoss=-0.001284 | Sup=0.000697 | Unsup=-0.396169 | TrainAcc=1.0000
# Fold 2 Epoch 1500: TotalLoss=-0.002265 | Sup=0.000137 | Unsup=-0.480392 | TrainAcc=1.0000
# Fold 2 Epoch 2000: TotalLoss=-0.002361 | Sup=0.000071 | Unsup=-0.486311 | TrainAcc=1.0000
# Fold 2 Epoch 2500: TotalLoss=-0.002390 | Sup=0.000055 | Unsup=-0.489008 | TrainAcc=1.0000
# Fold 2 Epoch 3000: TotalLoss=-0.002419 | Sup=0.000051 | Unsup=-0.493842 | TrainAcc=1.0000
# Fold 2 Epoch 3500: TotalLoss=-0.002415 | Sup=0.000056 | Unsup=-0.494205 | TrainAcc=1.0000
# Fold 2 Epoch 4000: TotalLoss=-0.002422 | Sup=0.000051 | Unsup=-0.494498 | TrainAcc=1.0000
# Fold 2 Epoch 4500: TotalLoss=-0.002423 | Sup=0.000046 | Unsup=-0.493692 | TrainAcc=1.0000
# Fold 2 Epoch 5000: TotalLoss=-0.002424 | Sup=0.000048 | Unsup=-0.494380 | TrainAcc=1.0000
#  Saved checkpoint: ARMA_Cut_NIFD/checkpoint_lambda_0.005_fold_2.pt
# Fold 2 → Acc=0.7808 | Prec=0.9459 | Rec=0.7143 | F1=0.8140 | AUC=0.9260 | CE Loss=0.9767
#
# === Fold 3 ===
# Train Controls: 24, Train Patients: 49
# Fold 3 Epoch 1: TotalLoss=0.661494 | Sup=0.662662 | Unsup=-0.233698 | TrainAcc=0.5890
# Fold 3 Epoch 500: TotalLoss=0.003929 | Sup=0.005139 | Unsup=-0.242070 | TrainAcc=1.0000
# Fold 3 Epoch 1000: TotalLoss=-0.000601 | Sup=0.000953 | Unsup=-0.310789 | TrainAcc=1.0000
# Fold 3 Epoch 1500: TotalLoss=-0.002136 | Sup=0.000200 | Unsup=-0.467232 | TrainAcc=1.0000
# Fold 3 Epoch 2000: TotalLoss=-0.002385 | Sup=0.000056 | Unsup=-0.488180 | TrainAcc=1.0000
# Fold 3 Epoch 2500: TotalLoss=-0.002374 | Sup=0.000068 | Unsup=-0.488415 | TrainAcc=1.0000
# Fold 3 Epoch 3000: TotalLoss=-0.002399 | Sup=0.000047 | Unsup=-0.489116 | TrainAcc=1.0000
# Fold 3 Epoch 3500: TotalLoss=-0.002412 | Sup=0.000059 | Unsup=-0.494218 | TrainAcc=1.0000
# Fold 3 Epoch 4000: TotalLoss=-0.002420 | Sup=0.000049 | Unsup=-0.493804 | TrainAcc=1.0000
# Fold 3 Epoch 4500: TotalLoss=-0.002417 | Sup=0.000048 | Unsup=-0.493023 | TrainAcc=1.0000
# Fold 3 Epoch 5000: TotalLoss=-0.002412 | Sup=0.000055 | Unsup=-0.493473 | TrainAcc=1.0000
#  Saved checkpoint: ARMA_Cut_NIFD/checkpoint_lambda_0.005_fold_3.pt
# Fold 3 → Acc=0.8082 | Prec=0.9487 | Rec=0.7551 | F1=0.8409 | AUC=0.9354 | CE Loss=0.8596
#
# === Fold 4 ===
# Train Controls: 24, Train Patients: 49
# Fold 4 Epoch 1: TotalLoss=0.751997 | Sup=0.753161 | Unsup=-0.232669 | TrainAcc=0.5205
# Fold 4 Epoch 500: TotalLoss=0.003678 | Sup=0.005001 | Unsup=-0.264555 | TrainAcc=1.0000
# Fold 4 Epoch 1000: TotalLoss=-0.000716 | Sup=0.001009 | Unsup=-0.344988 | TrainAcc=1.0000
# Fold 4 Epoch 1500: TotalLoss=-0.002205 | Sup=0.000202 | Unsup=-0.481429 | TrainAcc=1.0000
# Fold 4 Epoch 2000: TotalLoss=-0.002369 | Sup=0.000088 | Unsup=-0.491364 | TrainAcc=1.0000
# Fold 4 Epoch 2500: TotalLoss=-0.002414 | Sup=0.000058 | Unsup=-0.494465 | TrainAcc=1.0000
# Fold 4 Epoch 3000: TotalLoss=-0.002426 | Sup=0.000047 | Unsup=-0.494477 | TrainAcc=1.0000
# Fold 4 Epoch 3500: TotalLoss=-0.002421 | Sup=0.000051 | Unsup=-0.494460 | TrainAcc=1.0000
# Fold 4 Epoch 4000: TotalLoss=-0.002415 | Sup=0.000057 | Unsup=-0.494540 | TrainAcc=1.0000
# Fold 4 Epoch 4500: TotalLoss=-0.002422 | Sup=0.000051 | Unsup=-0.494721 | TrainAcc=1.0000
# Fold 4 Epoch 5000: TotalLoss=-0.002411 | Sup=0.000062 | Unsup=-0.494688 | TrainAcc=1.0000
#  Saved checkpoint: ARMA_Cut_NIFD/checkpoint_lambda_0.005_fold_4.pt
# Fold 4 → Acc=0.8082 | Prec=0.9730 | Rec=0.7347 | F1=0.8372 | AUC=0.9226 | CE Loss=0.8722
#
# === Fold 5 ===
# Train Controls: 24, Train Patients: 49
# Fold 5 Epoch 1: TotalLoss=0.813073 | Sup=0.814235 | Unsup=-0.232432 | TrainAcc=0.3699
# Fold 5 Epoch 500: TotalLoss=0.004128 | Sup=0.005243 | Unsup=-0.223127 | TrainAcc=1.0000
# Fold 5 Epoch 1000: TotalLoss=-0.000893 | Sup=0.000755 | Unsup=-0.329577 | TrainAcc=1.0000
# Fold 5 Epoch 1500: TotalLoss=-0.001926 | Sup=0.000351 | Unsup=-0.455544 | TrainAcc=1.0000
# Fold 5 Epoch 2000: TotalLoss=-0.002292 | Sup=0.000146 | Unsup=-0.487623 | TrainAcc=1.0000
# Fold 5 Epoch 2500: TotalLoss=-0.002382 | Sup=0.000080 | Unsup=-0.492341 | TrainAcc=1.0000
# Fold 5 Epoch 3000: TotalLoss=-0.002410 | Sup=0.000060 | Unsup=-0.493993 | TrainAcc=1.0000
# Fold 5 Epoch 3500: TotalLoss=-0.002408 | Sup=0.000060 | Unsup=-0.493680 | TrainAcc=1.0000
# Fold 5 Epoch 4000: TotalLoss=-0.002393 | Sup=0.000070 | Unsup=-0.492597 | TrainAcc=1.0000
# Fold 5 Epoch 4500: TotalLoss=-0.002390 | Sup=0.000075 | Unsup=-0.492950 | TrainAcc=1.0000
# Fold 5 Epoch 5000: TotalLoss=-0.002390 | Sup=0.000073 | Unsup=-0.492584 | TrainAcc=1.0000
#  Saved checkpoint: ARMA_Cut_NIFD/checkpoint_lambda_0.005_fold_5.pt
# Fold 5 → Acc=0.8493 | Prec=1.0000 | Rec=0.7755 | F1=0.8736 | AUC=0.9600 | CE Loss=0.6221
#
# === Fold 6 ===
# Train Controls: 24, Train Patients: 49
# Fold 6 Epoch 1: TotalLoss=0.755867 | Sup=0.757033 | Unsup=-0.233254 | TrainAcc=0.4384
# Fold 6 Epoch 500: TotalLoss=0.004058 | Sup=0.005375 | Unsup=-0.263413 | TrainAcc=1.0000
# Fold 6 Epoch 1000: TotalLoss=-0.000968 | Sup=0.000789 | Unsup=-0.351446 | TrainAcc=1.0000
# Fold 6 Epoch 1500: TotalLoss=-0.002037 | Sup=0.000327 | Unsup=-0.472825 | TrainAcc=1.0000
# Fold 6 Epoch 2000: TotalLoss=-0.002350 | Sup=0.000104 | Unsup=-0.490804 | TrainAcc=1.0000
# Fold 6 Epoch 2500: TotalLoss=-0.002398 | Sup=0.000070 | Unsup=-0.493488 | TrainAcc=1.0000
# Fold 6 Epoch 3000: TotalLoss=-0.002426 | Sup=0.000043 | Unsup=-0.493852 | TrainAcc=1.0000
# Fold 6 Epoch 3500: TotalLoss=-0.002419 | Sup=0.000049 | Unsup=-0.493532 | TrainAcc=1.0000
# Fold 6 Epoch 4000: TotalLoss=-0.002409 | Sup=0.000056 | Unsup=-0.493048 | TrainAcc=1.0000
# Fold 6 Epoch 4500: TotalLoss=-0.002405 | Sup=0.000065 | Unsup=-0.494047 | TrainAcc=1.0000
# Fold 6 Epoch 5000: TotalLoss=-0.002394 | Sup=0.000077 | Unsup=-0.494164 | TrainAcc=1.0000
#  Saved checkpoint: ARMA_Cut_NIFD/checkpoint_lambda_0.005_fold_6.pt
# Fold 6 → Acc=0.8356 | Prec=1.0000 | Rec=0.7551 | F1=0.8605 | AUC=0.9464 | CE Loss=0.6537
#
# === Fold 7 ===
# Train Controls: 24, Train Patients: 49
# Fold 7 Epoch 1: TotalLoss=0.669710 | Sup=0.670871 | Unsup=-0.232229 | TrainAcc=0.6027
# Fold 7 Epoch 500: TotalLoss=0.003097 | Sup=0.004358 | Unsup=-0.252148 | TrainAcc=1.0000
# Fold 7 Epoch 1000: TotalLoss=-0.001069 | Sup=0.000681 | Unsup=-0.349980 | TrainAcc=1.0000
# Fold 7 Epoch 1500: TotalLoss=-0.002129 | Sup=0.000260 | Unsup=-0.477749 | TrainAcc=1.0000
# Fold 7 Epoch 2000: TotalLoss=-0.002350 | Sup=0.000114 | Unsup=-0.492747 | TrainAcc=1.0000
# Fold 7 Epoch 2500: TotalLoss=-0.002404 | Sup=0.000066 | Unsup=-0.494004 | TrainAcc=1.0000
# Fold 7 Epoch 3000: TotalLoss=-0.002409 | Sup=0.000063 | Unsup=-0.494333 | TrainAcc=1.0000
# Fold 7 Epoch 3500: TotalLoss=-0.002418 | Sup=0.000052 | Unsup=-0.493959 | TrainAcc=1.0000
# Fold 7 Epoch 4000: TotalLoss=-0.002411 | Sup=0.000057 | Unsup=-0.493508 | TrainAcc=1.0000
# Fold 7 Epoch 4500: TotalLoss=-0.002405 | Sup=0.000064 | Unsup=-0.493845 | TrainAcc=1.0000
# Fold 7 Epoch 5000: TotalLoss=-0.002395 | Sup=0.000074 | Unsup=-0.493812 | TrainAcc=1.0000
#  Saved checkpoint: ARMA_Cut_NIFD/checkpoint_lambda_0.005_fold_7.pt
# Fold 7 → Acc=0.8082 | Prec=1.0000 | Rec=0.7143 | F1=0.8333 | AUC=0.9243 | CE Loss=0.9472
#
# === Fold 8 ===
# Train Controls: 24, Train Patients: 49
# Fold 8 Epoch 1: TotalLoss=0.763156 | Sup=0.764324 | Unsup=-0.233598 | TrainAcc=0.3973
# Fold 8 Epoch 500: TotalLoss=0.003652 | Sup=0.004869 | Unsup=-0.243413 | TrainAcc=1.0000
# Fold 8 Epoch 1000: TotalLoss=-0.001201 | Sup=0.000733 | Unsup=-0.386866 | TrainAcc=1.0000
# Fold 8 Epoch 1500: TotalLoss=-0.002268 | Sup=0.000137 | Unsup=-0.481021 | TrainAcc=1.0000
# Fold 8 Epoch 2000: TotalLoss=-0.002368 | Sup=0.000091 | Unsup=-0.491745 | TrainAcc=1.0000
# Fold 8 Epoch 2500: TotalLoss=-0.002385 | Sup=0.000082 | Unsup=-0.493325 | TrainAcc=1.0000
# Fold 8 Epoch 3000: TotalLoss=-0.002420 | Sup=0.000052 | Unsup=-0.494289 | TrainAcc=1.0000
# Fold 8 Epoch 3500: TotalLoss=-0.002429 | Sup=0.000041 | Unsup=-0.494018 | TrainAcc=1.0000
# Fold 8 Epoch 4000: TotalLoss=-0.002409 | Sup=0.000061 | Unsup=-0.493922 | TrainAcc=1.0000
# Fold 8 Epoch 4500: TotalLoss=-0.002417 | Sup=0.000054 | Unsup=-0.494325 | TrainAcc=1.0000
# Fold 8 Epoch 5000: TotalLoss=-0.002405 | Sup=0.000060 | Unsup=-0.493068 | TrainAcc=1.0000
#  Saved checkpoint: ARMA_Cut_NIFD/checkpoint_lambda_0.005_fold_8.pt
# Fold 8 → Acc=0.7945 | Prec=0.9722 | Rec=0.7143 | F1=0.8235 | AUC=0.9354 | CE Loss=0.8989
#
# === Fold 9 ===
# Train Controls: 24, Train Patients: 49
# Fold 9 Epoch 1: TotalLoss=0.824825 | Sup=0.826000 | Unsup=-0.234978 | TrainAcc=0.4384
# Fold 9 Epoch 500: TotalLoss=0.004477 | Sup=0.005645 | Unsup=-0.233727 | TrainAcc=1.0000
# Fold 9 Epoch 1000: TotalLoss=-0.000773 | Sup=0.000732 | Unsup=-0.300997 | TrainAcc=1.0000
# Fold 9 Epoch 1500: TotalLoss=-0.002053 | Sup=0.000239 | Unsup=-0.458386 | TrainAcc=1.0000
# Fold 9 Epoch 2000: TotalLoss=-0.002312 | Sup=0.000094 | Unsup=-0.481306 | TrainAcc=1.0000
# Fold 9 Epoch 2500: TotalLoss=-0.002378 | Sup=0.000057 | Unsup=-0.487072 | TrainAcc=1.0000
# Fold 9 Epoch 3000: TotalLoss=-0.002379 | Sup=0.000088 | Unsup=-0.493308 | TrainAcc=1.0000
# Fold 9 Epoch 3500: TotalLoss=-0.002393 | Sup=0.000073 | Unsup=-0.493246 | TrainAcc=1.0000
# Fold 9 Epoch 4000: TotalLoss=-0.002412 | Sup=0.000049 | Unsup=-0.492340 | TrainAcc=1.0000
# Fold 9 Epoch 4500: TotalLoss=-0.002399 | Sup=0.000069 | Unsup=-0.493730 | TrainAcc=1.0000
# Fold 9 Epoch 5000: TotalLoss=-0.002391 | Sup=0.000071 | Unsup=-0.492497 | TrainAcc=1.0000
#  Saved checkpoint: ARMA_Cut_NIFD/checkpoint_lambda_0.005_fold_9.pt
# Fold 9 → Acc=0.8493 | Prec=0.9750 | Rec=0.7959 | F1=0.8764 | AUC=0.9575 | CE Loss=0.6260
#
# === Fold 10 ===
# Train Controls: 24, Train Patients: 49
# Fold 10 Epoch 1: TotalLoss=0.787813 | Sup=0.788973 | Unsup=-0.231872 | TrainAcc=0.3836
# Fold 10 Epoch 500: TotalLoss=0.003621 | Sup=0.004944 | Unsup=-0.264551 | TrainAcc=1.0000
# Fold 10 Epoch 1000: TotalLoss=-0.000832 | Sup=0.000910 | Unsup=-0.348419 | TrainAcc=1.0000
# Fold 10 Epoch 1500: TotalLoss=-0.002210 | Sup=0.000189 | Unsup=-0.479709 | TrainAcc=1.0000
# Fold 10 Epoch 2000: TotalLoss=-0.002355 | Sup=0.000076 | Unsup=-0.486329 | TrainAcc=1.0000
# Fold 10 Epoch 2500: TotalLoss=-0.002373 | Sup=0.000054 | Unsup=-0.485497 | TrainAcc=1.0000
# Fold 10 Epoch 3000: TotalLoss=-0.002412 | Sup=0.000033 | Unsup=-0.489093 | TrainAcc=1.0000
# Fold 10 Epoch 3500: TotalLoss=-0.002384 | Sup=0.000061 | Unsup=-0.489143 | TrainAcc=1.0000
# Fold 10 Epoch 4000: TotalLoss=-0.002388 | Sup=0.000056 | Unsup=-0.488881 | TrainAcc=1.0000
# Fold 10 Epoch 4500: TotalLoss=-0.002389 | Sup=0.000055 | Unsup=-0.488813 | TrainAcc=1.0000
# Fold 10 Epoch 5000: TotalLoss=-0.002374 | Sup=0.000065 | Unsup=-0.487822 | TrainAcc=1.0000
#  Saved checkpoint: ARMA_Cut_NIFD/checkpoint_lambda_0.005_fold_10.pt
# Fold 10 → Acc=0.7808 | Prec=0.9714 | Rec=0.6939 | F1=0.8095 | AUC=0.9320 | CE Loss=0.8416
#
# === Fold 11 ===
# Train Controls: 24, Train Patients: 49
# Fold 11 Epoch 1: TotalLoss=0.729604 | Sup=0.730775 | Unsup=-0.234239 | TrainAcc=0.4658
# Fold 11 Epoch 500: TotalLoss=0.003063 | Sup=0.004381 | Unsup=-0.263581 | TrainAcc=1.0000
# Fold 11 Epoch 1000: TotalLoss=-0.000967 | Sup=0.000798 | Unsup=-0.352976 | TrainAcc=1.0000
# Fold 11 Epoch 1500: TotalLoss=-0.002192 | Sup=0.000213 | Unsup=-0.480980 | TrainAcc=1.0000
# Fold 11 Epoch 2000: TotalLoss=-0.002341 | Sup=0.000097 | Unsup=-0.487671 | TrainAcc=1.0000
# Fold 11 Epoch 2500: TotalLoss=-0.002382 | Sup=0.000088 | Unsup=-0.494027 | TrainAcc=1.0000
# Fold 11 Epoch 3000: TotalLoss=-0.002427 | Sup=0.000044 | Unsup=-0.494260 | TrainAcc=1.0000
# Fold 11 Epoch 3500: TotalLoss=-0.002427 | Sup=0.000038 | Unsup=-0.493057 | TrainAcc=1.0000
# Fold 11 Epoch 4000: TotalLoss=-0.002424 | Sup=0.000048 | Unsup=-0.494514 | TrainAcc=1.0000
# Fold 11 Epoch 4500: TotalLoss=-0.002421 | Sup=0.000050 | Unsup=-0.494202 | TrainAcc=1.0000
# Fold 11 Epoch 5000: TotalLoss=-0.002403 | Sup=0.000071 | Unsup=-0.494671 | TrainAcc=1.0000
#  Saved checkpoint: ARMA_Cut_NIFD/checkpoint_lambda_0.005_fold_11.pt
# Fold 11 → Acc=0.8082 | Prec=1.0000 | Rec=0.7143 | F1=0.8333 | AUC=0.9396 | CE Loss=0.8581
#
# === Fold 12 ===
# Train Controls: 24, Train Patients: 49
# Fold 12 Epoch 1: TotalLoss=0.794629 | Sup=0.795800 | Unsup=-0.234223 | TrainAcc=0.4658
# Fold 12 Epoch 500: TotalLoss=0.003155 | Sup=0.004326 | Unsup=-0.234183 | TrainAcc=1.0000
# Fold 12 Epoch 1000: TotalLoss=-0.001010 | Sup=0.000681 | Unsup=-0.338343 | TrainAcc=1.0000
# Fold 12 Epoch 1500: TotalLoss=-0.002096 | Sup=0.000232 | Unsup=-0.465698 | TrainAcc=1.0000
# Fold 12 Epoch 2000: TotalLoss=-0.002341 | Sup=0.000092 | Unsup=-0.486585 | TrainAcc=1.0000
# Fold 12 Epoch 2500: TotalLoss=-0.002342 | Sup=0.000102 | Unsup=-0.488722 | TrainAcc=1.0000
# Fold 12 Epoch 3000: TotalLoss=-0.002415 | Sup=0.000052 | Unsup=-0.493344 | TrainAcc=1.0000
# Fold 12 Epoch 3500: TotalLoss=-0.002427 | Sup=0.000044 | Unsup=-0.494056 | TrainAcc=1.0000
# Fold 12 Epoch 4000: TotalLoss=-0.002426 | Sup=0.000047 | Unsup=-0.494592 | TrainAcc=1.0000
# Fold 12 Epoch 4500: TotalLoss=-0.002421 | Sup=0.000049 | Unsup=-0.494086 | TrainAcc=1.0000
# Fold 12 Epoch 5000: TotalLoss=-0.002374 | Sup=0.000086 | Unsup=-0.491976 | TrainAcc=1.0000
#  Saved checkpoint: ARMA_Cut_NIFD/checkpoint_lambda_0.005_fold_12.pt
# Fold 12 → Acc=0.7945 | Prec=1.0000 | Rec=0.6939 | F1=0.8193 | AUC=0.9099 | CE Loss=1.0646
#
# === Fold 13 ===
# Train Controls: 24, Train Patients: 49
# Fold 13 Epoch 1: TotalLoss=0.811238 | Sup=0.812397 | Unsup=-0.231761 | TrainAcc=0.3973
# Fold 13 Epoch 500: TotalLoss=0.004374 | Sup=0.005734 | Unsup=-0.271941 | TrainAcc=1.0000
# Fold 13 Epoch 1000: TotalLoss=-0.001122 | Sup=0.000783 | Unsup=-0.381095 | TrainAcc=1.0000
# Fold 13 Epoch 1500: TotalLoss=-0.002200 | Sup=0.000194 | Unsup=-0.478759 | TrainAcc=1.0000
# Fold 13 Epoch 2000: TotalLoss=-0.002382 | Sup=0.000077 | Unsup=-0.491825 | TrainAcc=1.0000
# Fold 13 Epoch 2500: TotalLoss=-0.002387 | Sup=0.000076 | Unsup=-0.492583 | TrainAcc=1.0000
# Fold 13 Epoch 3000: TotalLoss=-0.002421 | Sup=0.000047 | Unsup=-0.493449 | TrainAcc=1.0000
# Fold 13 Epoch 3500: TotalLoss=-0.002425 | Sup=0.000046 | Unsup=-0.494188 | TrainAcc=1.0000
# Fold 13 Epoch 4000: TotalLoss=-0.002391 | Sup=0.000082 | Unsup=-0.494486 | TrainAcc=1.0000
# Fold 13 Epoch 4500: TotalLoss=-0.002416 | Sup=0.000057 | Unsup=-0.494608 | TrainAcc=1.0000
# Fold 13 Epoch 5000: TotalLoss=-0.002405 | Sup=0.000067 | Unsup=-0.494333 | TrainAcc=1.0000
#  Saved checkpoint: ARMA_Cut_NIFD/checkpoint_lambda_0.005_fold_13.pt
# Fold 13 → Acc=0.7808 | Prec=1.0000 | Rec=0.6735 | F1=0.8049 | AUC=0.9320 | CE Loss=0.9329
#
# === Fold 14 ===
# Train Controls: 24, Train Patients: 49
# Fold 14 Epoch 1: TotalLoss=0.841692 | Sup=0.842854 | Unsup=-0.232293 | TrainAcc=0.3699
# Fold 14 Epoch 500: TotalLoss=0.004716 | Sup=0.006145 | Unsup=-0.285800 | TrainAcc=1.0000
# Fold 14 Epoch 1000: TotalLoss=-0.000742 | Sup=0.001018 | Unsup=-0.351866 | TrainAcc=1.0000
# Fold 14 Epoch 1500: TotalLoss=-0.001897 | Sup=0.000385 | Unsup=-0.456398 | TrainAcc=1.0000
# Fold 14 Epoch 2000: TotalLoss=-0.002271 | Sup=0.000110 | Unsup=-0.476187 | TrainAcc=1.0000
# Fold 14 Epoch 2500: TotalLoss=-0.002345 | Sup=0.000083 | Unsup=-0.485745 | TrainAcc=1.0000
# Fold 14 Epoch 3000: TotalLoss=-0.002368 | Sup=0.000072 | Unsup=-0.488041 | TrainAcc=1.0000
# Fold 14 Epoch 3500: TotalLoss=-0.002381 | Sup=0.000060 | Unsup=-0.488103 | TrainAcc=1.0000
# Fold 14 Epoch 4000: TotalLoss=-0.002391 | Sup=0.000051 | Unsup=-0.488333 | TrainAcc=1.0000
# Fold 14 Epoch 4500: TotalLoss=-0.002372 | Sup=0.000065 | Unsup=-0.487506 | TrainAcc=1.0000
# Fold 14 Epoch 5000: TotalLoss=-0.002368 | Sup=0.000071 | Unsup=-0.487672 | TrainAcc=1.0000
#  Saved checkpoint: ARMA_Cut_NIFD/checkpoint_lambda_0.005_fold_14.pt
# Fold 14 → Acc=0.8493 | Prec=1.0000 | Rec=0.7755 | F1=0.8736 | AUC=0.9405 | CE Loss=0.6236
#
# === Fold 15 ===
# Train Controls: 24, Train Patients: 49
# Fold 15 Epoch 1: TotalLoss=0.802334 | Sup=0.803498 | Unsup=-0.232976 | TrainAcc=0.4795
# Fold 15 Epoch 500: TotalLoss=0.003548 | Sup=0.004719 | Unsup=-0.234105 | TrainAcc=1.0000
# Fold 15 Epoch 1000: TotalLoss=-0.000540 | Sup=0.000975 | Unsup=-0.303013 | TrainAcc=1.0000
# Fold 15 Epoch 1500: TotalLoss=-0.001787 | Sup=0.000368 | Unsup=-0.431177 | TrainAcc=1.0000
# Fold 15 Epoch 2000: TotalLoss=-0.002305 | Sup=0.000120 | Unsup=-0.484929 | TrainAcc=1.0000
# Fold 15 Epoch 2500: TotalLoss=-0.002372 | Sup=0.000083 | Unsup=-0.491105 | TrainAcc=1.0000
# Fold 15 Epoch 3000: TotalLoss=-0.002408 | Sup=0.000052 | Unsup=-0.492054 | TrainAcc=1.0000
# Fold 15 Epoch 3500: TotalLoss=-0.002406 | Sup=0.000061 | Unsup=-0.493454 | TrainAcc=1.0000
# Fold 15 Epoch 4000: TotalLoss=-0.002415 | Sup=0.000051 | Unsup=-0.493150 | TrainAcc=1.0000
# Fold 15 Epoch 4500: TotalLoss=-0.002392 | Sup=0.000069 | Unsup=-0.492324 | TrainAcc=1.0000
# Fold 15 Epoch 5000: TotalLoss=-0.002405 | Sup=0.000064 | Unsup=-0.493827 | TrainAcc=1.0000
#  Saved checkpoint: ARMA_Cut_NIFD/checkpoint_lambda_0.005_fold_15.pt
# Fold 15 → Acc=0.8082 | Prec=1.0000 | Rec=0.7143 | F1=0.8333 | AUC=0.9609 | CE Loss=0.7899
#
# === Fold 16 ===
# Train Controls: 24, Train Patients: 49
# Fold 16 Epoch 1: TotalLoss=0.711367 | Sup=0.712529 | Unsup=-0.232493 | TrainAcc=0.5342
# Fold 16 Epoch 500: TotalLoss=0.003554 | Sup=0.005034 | Unsup=-0.296027 | TrainAcc=1.0000
# Fold 16 Epoch 1000: TotalLoss=-0.001238 | Sup=0.000766 | Unsup=-0.400711 | TrainAcc=1.0000
# Fold 16 Epoch 1500: TotalLoss=-0.002270 | Sup=0.000131 | Unsup=-0.480184 | TrainAcc=1.0000
# Fold 16 Epoch 2000: TotalLoss=-0.002411 | Sup=0.000056 | Unsup=-0.493391 | TrainAcc=1.0000
# Fold 16 Epoch 2500: TotalLoss=-0.002429 | Sup=0.000044 | Unsup=-0.494523 | TrainAcc=1.0000
# Fold 16 Epoch 3000: TotalLoss=-0.002425 | Sup=0.000049 | Unsup=-0.494811 | TrainAcc=1.0000
# Fold 16 Epoch 3500: TotalLoss=-0.002427 | Sup=0.000043 | Unsup=-0.494049 | TrainAcc=1.0000
# Fold 16 Epoch 4000: TotalLoss=-0.002432 | Sup=0.000042 | Unsup=-0.494677 | TrainAcc=1.0000
# Fold 16 Epoch 4500: TotalLoss=-0.002420 | Sup=0.000052 | Unsup=-0.494355 | TrainAcc=1.0000
# Fold 16 Epoch 5000: TotalLoss=-0.002406 | Sup=0.000065 | Unsup=-0.494192 | TrainAcc=1.0000
#  Saved checkpoint: ARMA_Cut_NIFD/checkpoint_lambda_0.005_fold_16.pt
# Fold 16 → Acc=0.8082 | Prec=1.0000 | Rec=0.7143 | F1=0.8333 | AUC=0.9413 | CE Loss=0.9160
#
# === Fold 17 ===
# Train Controls: 24, Train Patients: 49
# Fold 17 Epoch 1: TotalLoss=0.651107 | Sup=0.652270 | Unsup=-0.232581 | TrainAcc=0.6301
# Fold 17 Epoch 500: TotalLoss=0.003020 | Sup=0.004167 | Unsup=-0.229335 | TrainAcc=1.0000
# Fold 17 Epoch 1000: TotalLoss=-0.000941 | Sup=0.000661 | Unsup=-0.320291 | TrainAcc=1.0000
# Fold 17 Epoch 1500: TotalLoss=-0.002118 | Sup=0.000217 | Unsup=-0.467017 | TrainAcc=1.0000
# Fold 17 Epoch 2000: TotalLoss=-0.002315 | Sup=0.000103 | Unsup=-0.483646 | TrainAcc=1.0000
# Fold 17 Epoch 2500: TotalLoss=-0.002387 | Sup=0.000071 | Unsup=-0.491489 | TrainAcc=1.0000
# Fold 17 Epoch 3000: TotalLoss=-0.002415 | Sup=0.000048 | Unsup=-0.492677 | TrainAcc=1.0000
# Fold 17 Epoch 3500: TotalLoss=-0.002415 | Sup=0.000053 | Unsup=-0.493575 | TrainAcc=1.0000
# Fold 17 Epoch 4000: TotalLoss=-0.002405 | Sup=0.000061 | Unsup=-0.493337 | TrainAcc=1.0000
# Fold 17 Epoch 4500: TotalLoss=-0.002415 | Sup=0.000048 | Unsup=-0.492622 | TrainAcc=1.0000
# Fold 17 Epoch 5000: TotalLoss=-0.002401 | Sup=0.000064 | Unsup=-0.492960 | TrainAcc=1.0000
#  Saved checkpoint: ARMA_Cut_NIFD/checkpoint_lambda_0.005_fold_17.pt
# Fold 17 → Acc=0.7808 | Prec=0.9714 | Rec=0.6939 | F1=0.8095 | AUC=0.9362 | CE Loss=0.9793
#
# === Fold 18 ===
# Train Controls: 24, Train Patients: 49
# Fold 18 Epoch 1: TotalLoss=0.855399 | Sup=0.856568 | Unsup=-0.233827 | TrainAcc=0.3288
# Fold 18 Epoch 500: TotalLoss=0.004217 | Sup=0.005367 | Unsup=-0.229966 | TrainAcc=1.0000
# Fold 18 Epoch 1000: TotalLoss=-0.000781 | Sup=0.000872 | Unsup=-0.330534 | TrainAcc=1.0000
# Fold 18 Epoch 1500: TotalLoss=-0.002070 | Sup=0.000245 | Unsup=-0.463099 | TrainAcc=1.0000
# Fold 18 Epoch 2000: TotalLoss=-0.002298 | Sup=0.000120 | Unsup=-0.483593 | TrainAcc=1.0000
# Fold 18 Epoch 2500: TotalLoss=-0.002401 | Sup=0.000064 | Unsup=-0.493031 | TrainAcc=1.0000
# Fold 18 Epoch 3000: TotalLoss=-0.002419 | Sup=0.000044 | Unsup=-0.492571 | TrainAcc=1.0000
# Fold 18 Epoch 3500: TotalLoss=-0.002381 | Sup=0.000085 | Unsup=-0.493227 | TrainAcc=1.0000
# Fold 18 Epoch 4000: TotalLoss=-0.002416 | Sup=0.000049 | Unsup=-0.493156 | TrainAcc=1.0000
# Fold 18 Epoch 4500: TotalLoss=-0.002420 | Sup=0.000041 | Unsup=-0.492253 | TrainAcc=1.0000
# Fold 18 Epoch 5000: TotalLoss=-0.002401 | Sup=0.000059 | Unsup=-0.492115 | TrainAcc=1.0000
#  Saved checkpoint: ARMA_Cut_NIFD/checkpoint_lambda_0.005_fold_18.pt
# Fold 18 → Acc=0.7671 | Prec=0.9706 | Rec=0.6735 | F1=0.7952 | AUC=0.9260 | CE Loss=1.0137
#
# === Fold 19 ===
# Train Controls: 24, Train Patients: 49
# Fold 19 Epoch 1: TotalLoss=0.828478 | Sup=0.829640 | Unsup=-0.232458 | TrainAcc=0.3562
# Fold 19 Epoch 500: TotalLoss=0.004766 | Sup=0.005991 | Unsup=-0.245025 | TrainAcc=1.0000
# Fold 19 Epoch 1000: TotalLoss=-0.000171 | Sup=0.001344 | Unsup=-0.303080 | TrainAcc=1.0000
# Fold 19 Epoch 1500: TotalLoss=-0.001883 | Sup=0.000362 | Unsup=-0.448812 | TrainAcc=1.0000
# Fold 19 Epoch 2000: TotalLoss=-0.002268 | Sup=0.000135 | Unsup=-0.480680 | TrainAcc=1.0000
# Fold 19 Epoch 2500: TotalLoss=-0.002341 | Sup=0.000089 | Unsup=-0.486174 | TrainAcc=1.0000
# Fold 19 Epoch 3000: TotalLoss=-0.002381 | Sup=0.000057 | Unsup=-0.487635 | TrainAcc=1.0000
# Fold 19 Epoch 3500: TotalLoss=-0.002390 | Sup=0.000054 | Unsup=-0.488691 | TrainAcc=1.0000
# Fold 19 Epoch 4000: TotalLoss=-0.002379 | Sup=0.000065 | Unsup=-0.488627 | TrainAcc=1.0000
# Fold 19 Epoch 4500: TotalLoss=-0.002380 | Sup=0.000063 | Unsup=-0.488734 | TrainAcc=1.0000
# Fold 19 Epoch 5000: TotalLoss=-0.002377 | Sup=0.000068 | Unsup=-0.489098 | TrainAcc=1.0000
#  Saved checkpoint: ARMA_Cut_NIFD/checkpoint_lambda_0.005_fold_19.pt
# Fold 19 → Acc=0.7945 | Prec=1.0000 | Rec=0.6939 | F1=0.8193 | AUC=0.9235 | CE Loss=0.7622
#
# === Fold 20 ===
# Train Controls: 24, Train Patients: 49
# Fold 20 Epoch 1: TotalLoss=0.587597 | Sup=0.588759 | Unsup=-0.232286 | TrainAcc=0.6712
# Fold 20 Epoch 500: TotalLoss=0.003018 | Sup=0.004046 | Unsup=-0.205595 | TrainAcc=1.0000
# Fold 20 Epoch 1000: TotalLoss=-0.000473 | Sup=0.000784 | Unsup=-0.251370 | TrainAcc=1.0000
# Fold 20 Epoch 1500: TotalLoss=-0.002012 | Sup=0.000282 | Unsup=-0.458737 | TrainAcc=1.0000
# Fold 20 Epoch 2000: TotalLoss=-0.002318 | Sup=0.000117 | Unsup=-0.487036 | TrainAcc=1.0000
# Fold 20 Epoch 2500: TotalLoss=-0.002363 | Sup=0.000087 | Unsup=-0.489889 | TrainAcc=1.0000
# Fold 20 Epoch 3000: TotalLoss=-0.002371 | Sup=0.000088 | Unsup=-0.491636 | TrainAcc=1.0000
# ...
# Fold 9 Epoch 1500: TotalLoss=-3.819901 | Sup=0.121701 | Unsup=-0.492700 | TrainAcc=0.9178
# Fold 9 Epoch 2000: TotalLoss=-3.820410 | Sup=0.119697 | Unsup=-0.492513 | TrainAcc=0.9178
# Fold 9 Epoch 2500: TotalLoss=-3.820386 | Sup=0.129824 | Unsup=-0.493776 | TrainAcc=0.9178
# Fold 9 Epoch 3000: TotalLoss=-3.821909 | Sup=0.121979 | Unsup=-0.492986 | TrainAcc=0.9178
# Fold 9 Epoch 3500: TotalLoss=-3.821472 | Sup=0.128918 | Unsup=-0.493799 | TrainAcc=0.9178
# Fold 9 Epoch 4000: TotalLoss=-3.822116 | Sup=0.126352 | Unsup=-0.493559 | TrainAcc=0.9178
# Fold 9 Epoch 4500: TotalLoss=-3.822166 | Sup=0.123947 | Unsup=-0.493264 | TrainAcc=0.9178
# Fold 9 Epoch 5000: TotalLoss=-3.822100 | Sup=0.119953 | Unsup=-0.492757 | TrainAcc=0.9178
#  Saved checkpoint: ARMA_Cut_NIFD/checkpoint_lambda_8_fold_9.pt
# Fold 9 → Acc=0.7534 | Prec=0.8974 | Rec=0.7143 | F1=0.7955 | AUC=0.8520 | CE Loss=2.0666
#
# === Fold 10 ===
# Train Controls: 24, Train Patients: 49
# Fold 10 Epoch 1: TotalLoss=-1.176429 | Sup=0.687264 | Unsup=-0.232962 | TrainAcc=0.5068
# Fold 10 Epoch 500: TotalLoss=-3.719835 | Sup=0.175019 | Unsup=-0.486857 | TrainAcc=0.9041
# Fold 10 Epoch 1000: TotalLoss=-3.774723 | Sup=0.150760 | Unsup=-0.490685 | TrainAcc=0.9041
# Fold 10 Epoch 1500: TotalLoss=-3.777915 | Sup=0.158111 | Unsup=-0.492003 | TrainAcc=0.9041
# Fold 10 Epoch 2000: TotalLoss=-3.779761 | Sup=0.153181 | Unsup=-0.491618 | TrainAcc=0.9041
# Fold 10 Epoch 2500: TotalLoss=-3.779878 | Sup=0.145108 | Unsup=-0.490623 | TrainAcc=0.9041
# Fold 10 Epoch 3000: TotalLoss=-3.781052 | Sup=0.151302 | Unsup=-0.491544 | TrainAcc=0.9041
# Fold 10 Epoch 3500: TotalLoss=-3.780893 | Sup=0.154891 | Unsup=-0.491973 | TrainAcc=0.9041
# Fold 10 Epoch 4000: TotalLoss=-3.780908 | Sup=0.152055 | Unsup=-0.491620 | TrainAcc=0.9041
# Fold 10 Epoch 4500: TotalLoss=-3.780743 | Sup=0.146977 | Unsup=-0.490965 | TrainAcc=0.9041
# Fold 10 Epoch 5000: TotalLoss=-3.781294 | Sup=0.151688 | Unsup=-0.491623 | TrainAcc=0.9041
#  Saved checkpoint: ARMA_Cut_NIFD/checkpoint_lambda_8_fold_10.pt
# Fold 10 → Acc=0.7534 | Prec=0.9429 | Rec=0.6735 | F1=0.7857 | AUC=0.8767 | CE Loss=2.0738
#
# === Fold 11 ===
# Train Controls: 24, Train Patients: 49
# Fold 11 Epoch 1: TotalLoss=-1.035155 | Sup=0.840703 | Unsup=-0.234482 | TrainAcc=0.3836
# Fold 11 Epoch 500: TotalLoss=-3.713464 | Sup=0.168392 | Unsup=-0.485232 | TrainAcc=0.9041
# Fold 11 Epoch 1000: TotalLoss=-3.768716 | Sup=0.145821 | Unsup=-0.489317 | TrainAcc=0.9041
# Fold 11 Epoch 1500: TotalLoss=-3.773194 | Sup=0.160747 | Unsup=-0.491743 | TrainAcc=0.9041
# Fold 11 Epoch 2000: TotalLoss=-3.775083 | Sup=0.150494 | Unsup=-0.490697 | TrainAcc=0.9041
# Fold 11 Epoch 2500: TotalLoss=-3.776021 | Sup=0.147676 | Unsup=-0.490462 | TrainAcc=0.9041
# Fold 11 Epoch 3000: TotalLoss=-3.776018 | Sup=0.155395 | Unsup=-0.491427 | TrainAcc=0.9041
# Fold 11 Epoch 3500: TotalLoss=-3.776114 | Sup=0.147032 | Unsup=-0.490393 | TrainAcc=0.9041
# Fold 11 Epoch 4000: TotalLoss=-3.776753 | Sup=0.154966 | Unsup=-0.491465 | TrainAcc=0.9041
# Fold 11 Epoch 4500: TotalLoss=-3.776587 | Sup=0.151701 | Unsup=-0.491036 | TrainAcc=0.9041
# Fold 11 Epoch 5000: TotalLoss=-3.776706 | Sup=0.153076 | Unsup=-0.491223 | TrainAcc=0.9041
#  Saved checkpoint: ARMA_Cut_NIFD/checkpoint_lambda_8_fold_11.pt
# Fold 11 → Acc=0.7397 | Prec=0.9167 | Rec=0.6735 | F1=0.7765 | AUC=0.8605 | CE Loss=2.2232
#
# === Fold 12 ===
# Train Controls: 24, Train Patients: 49
# Fold 12 Epoch 1: TotalLoss=-1.165667 | Sup=0.704286 | Unsup=-0.233744 | TrainAcc=0.5479
# Fold 12 Epoch 500: TotalLoss=-3.802177 | Sup=0.122784 | Unsup=-0.490620 | TrainAcc=0.9315
# Fold 12 Epoch 1000: TotalLoss=-3.852653 | Sup=0.099145 | Unsup=-0.493975 | TrainAcc=0.9315
# Fold 12 Epoch 1500: TotalLoss=-3.855813 | Sup=0.089845 | Unsup=-0.493207 | TrainAcc=0.9315
# Fold 12 Epoch 2000: TotalLoss=-3.857316 | Sup=0.095967 | Unsup=-0.494160 | TrainAcc=0.9315
# Fold 12 Epoch 2500: TotalLoss=-3.856391 | Sup=0.103572 | Unsup=-0.494995 | TrainAcc=0.9315
# Fold 12 Epoch 3000: TotalLoss=-3.857899 | Sup=0.092577 | Unsup=-0.493809 | TrainAcc=0.9315
# Fold 12 Epoch 3500: TotalLoss=-3.858052 | Sup=0.092882 | Unsup=-0.493867 | TrainAcc=0.9315
# Fold 12 Epoch 4000: TotalLoss=-3.858054 | Sup=0.098304 | Unsup=-0.494545 | TrainAcc=0.9315
# Fold 12 Epoch 4500: TotalLoss=-3.858355 | Sup=0.095054 | Unsup=-0.494176 | TrainAcc=0.9315
# Fold 12 Epoch 5000: TotalLoss=-3.858350 | Sup=0.096916 | Unsup=-0.494408 | TrainAcc=0.9315
#  Saved checkpoint: ARMA_Cut_NIFD/checkpoint_lambda_8_fold_12.pt
# Fold 12 → Acc=0.8219 | Prec=0.9737 | Rec=0.7551 | F1=0.8506 | AUC=0.8929 | CE Loss=1.7805
#
# === Fold 13 ===
# Train Controls: 24, Train Patients: 49
# Fold 13 Epoch 1: TotalLoss=-1.091379 | Sup=0.773567 | Unsup=-0.233118 | TrainAcc=0.3973
# Fold 13 Epoch 500: TotalLoss=-3.746662 | Sup=0.162367 | Unsup=-0.488629 | TrainAcc=0.9041
# Fold 13 Epoch 1000: TotalLoss=-3.775370 | Sup=0.144031 | Unsup=-0.489925 | TrainAcc=0.9041
# Fold 13 Epoch 1500: TotalLoss=-3.777032 | Sup=0.165169 | Unsup=-0.492775 | TrainAcc=0.9041
# Fold 13 Epoch 2000: TotalLoss=-3.778628 | Sup=0.167670 | Unsup=-0.493287 | TrainAcc=0.9041
# Fold 13 Epoch 2500: TotalLoss=-3.781031 | Sup=0.156102 | Unsup=-0.492142 | TrainAcc=0.9041
# Fold 13 Epoch 3000: TotalLoss=-3.780852 | Sup=0.157562 | Unsup=-0.492302 | TrainAcc=0.9041
# Fold 13 Epoch 3500: TotalLoss=-3.781720 | Sup=0.159437 | Unsup=-0.492645 | TrainAcc=0.9041
# Fold 13 Epoch 4000: TotalLoss=-3.781873 | Sup=0.146939 | Unsup=-0.491101 | TrainAcc=0.9041
# Fold 13 Epoch 4500: TotalLoss=-3.782077 | Sup=0.152717 | Unsup=-0.491849 | TrainAcc=0.9041
# Fold 13 Epoch 5000: TotalLoss=-3.781850 | Sup=0.161232 | Unsup=-0.492885 | TrainAcc=0.9041
#  Saved checkpoint: ARMA_Cut_NIFD/checkpoint_lambda_8_fold_13.pt
# Fold 13 → Acc=0.7945 | Prec=1.0000 | Rec=0.6939 | F1=0.8193 | AUC=0.8206 | CE Loss=2.0007
#
# === Fold 14 ===
# Train Controls: 24, Train Patients: 49
# Fold 14 Epoch 1: TotalLoss=-1.214614 | Sup=0.655742 | Unsup=-0.233795 | TrainAcc=0.6027
# Fold 14 Epoch 500: TotalLoss=-3.646070 | Sup=0.244662 | Unsup=-0.486341 | TrainAcc=0.8630
# Fold 14 Epoch 1000: TotalLoss=-3.658087 | Sup=0.238335 | Unsup=-0.487053 | TrainAcc=0.8630
# Fold 14 Epoch 1500: TotalLoss=-3.663971 | Sup=0.233461 | Unsup=-0.487179 | TrainAcc=0.8630
# Fold 14 Epoch 2000: TotalLoss=-3.664396 | Sup=0.229474 | Unsup=-0.486734 | TrainAcc=0.8630
# Fold 14 Epoch 2500: TotalLoss=-3.664815 | Sup=0.245243 | Unsup=-0.488757 | TrainAcc=0.8630
# Fold 14 Epoch 3000: TotalLoss=-3.666259 | Sup=0.231804 | Unsup=-0.487258 | TrainAcc=0.8630
# Fold 14 Epoch 3500: TotalLoss=-3.665816 | Sup=0.227386 | Unsup=-0.486650 | TrainAcc=0.8630
# Fold 14 Epoch 4000: TotalLoss=-3.703117 | Sup=0.194330 | Unsup=-0.487181 | TrainAcc=0.8630
# Fold 14 Epoch 4500: TotalLoss=-3.703313 | Sup=0.189507 | Unsup=-0.486602 | TrainAcc=0.8630
# Fold 14 Epoch 5000: TotalLoss=-3.703469 | Sup=0.188037 | Unsup=-0.486438 | TrainAcc=0.8630
#  Saved checkpoint: ARMA_Cut_NIFD/checkpoint_lambda_8_fold_14.pt
# Fold 14 → Acc=0.7808 | Prec=0.9459 | Rec=0.7143 | F1=0.8140 | AUC=0.8818 | CE Loss=1.7099
#
# === Fold 15 ===
# Train Controls: 24, Train Patients: 49
# Fold 15 Epoch 1: TotalLoss=-1.067779 | Sup=0.806309 | Unsup=-0.234261 | TrainAcc=0.4795
# Fold 15 Epoch 500: TotalLoss=-3.609501 | Sup=0.243103 | Unsup=-0.481576 | TrainAcc=0.8493
# Fold 15 Epoch 1000: TotalLoss=-3.618810 | Sup=0.253012 | Unsup=-0.483978 | TrainAcc=0.8493
# Fold 15 Epoch 1500: TotalLoss=-3.624013 | Sup=0.250783 | Unsup=-0.484350 | TrainAcc=0.8493
# Fold 15 Epoch 2000: TotalLoss=-3.663497 | Sup=0.210687 | Unsup=-0.484273 | TrainAcc=0.8493
# Fold 15 Epoch 2500: TotalLoss=-3.664972 | Sup=0.223391 | Unsup=-0.486045 | TrainAcc=0.8493
# Fold 15 Epoch 3000: TotalLoss=-3.665409 | Sup=0.219853 | Unsup=-0.485658 | TrainAcc=0.8493
# Fold 15 Epoch 3500: TotalLoss=-3.665640 | Sup=0.223626 | Unsup=-0.486158 | TrainAcc=0.8493
# Fold 15 Epoch 4000: TotalLoss=-3.665580 | Sup=0.223547 | Unsup=-0.486141 | TrainAcc=0.8493
# Fold 15 Epoch 4500: TotalLoss=-3.665807 | Sup=0.218937 | Unsup=-0.485593 | TrainAcc=0.8493
# Fold 15 Epoch 5000: TotalLoss=-3.665549 | Sup=0.226555 | Unsup=-0.486513 | TrainAcc=0.8493
#  Saved checkpoint: ARMA_Cut_NIFD/checkpoint_lambda_8_fold_15.pt
# Fold 15 → Acc=0.7534 | Prec=1.0000 | Rec=0.6327 | F1=0.7750 | AUC=0.9439 | CE Loss=1.9252
#
# === Fold 16 ===
# Train Controls: 24, Train Patients: 49
# Fold 16 Epoch 1: TotalLoss=-1.145564 | Sup=0.723535 | Unsup=-0.233637 | TrainAcc=0.5479
# Fold 16 Epoch 500: TotalLoss=-3.757809 | Sup=0.167456 | Unsup=-0.490658 | TrainAcc=0.9178
# Fold 16 Epoch 1000: TotalLoss=-3.803668 | Sup=0.150557 | Unsup=-0.494278 | TrainAcc=0.9178
# Fold 16 Epoch 1500: TotalLoss=-3.815935 | Sup=0.134237 | Unsup=-0.493771 | TrainAcc=0.9178
# Fold 16 Epoch 2000: TotalLoss=-3.816498 | Sup=0.124084 | Unsup=-0.492573 | TrainAcc=0.9178
# Fold 16 Epoch 2500: TotalLoss=-3.819218 | Sup=0.125991 | Unsup=-0.493151 | TrainAcc=0.9178
# Fold 16 Epoch 3000: TotalLoss=-3.819547 | Sup=0.121980 | Unsup=-0.492691 | TrainAcc=0.9178
# Fold 16 Epoch 3500: TotalLoss=-3.819692 | Sup=0.125262 | Unsup=-0.493119 | TrainAcc=0.9178
# Fold 16 Epoch 4000: TotalLoss=-3.819535 | Sup=0.117284 | Unsup=-0.492102 | TrainAcc=0.9178
# Fold 16 Epoch 4500: TotalLoss=-3.819805 | Sup=0.119831 | Unsup=-0.492454 | TrainAcc=0.9178
# Fold 16 Epoch 5000: TotalLoss=-3.819876 | Sup=0.124680 | Unsup=-0.493069 | TrainAcc=0.9178
#  Saved checkpoint: ARMA_Cut_NIFD/checkpoint_lambda_8_fold_16.pt
# Fold 16 → Acc=0.7671 | Prec=0.9706 | Rec=0.6735 | F1=0.7952 | AUC=0.9090 | CE Loss=1.9728
#
# === Fold 17 ===
# Train Controls: 24, Train Patients: 49
# Fold 17 Epoch 1: TotalLoss=-1.235142 | Sup=0.632863 | Unsup=-0.233501 | TrainAcc=0.6027
# Fold 17 Epoch 500: TotalLoss=-3.750979 | Sup=0.172553 | Unsup=-0.490442 | TrainAcc=0.9178
# Fold 17 Epoch 1000: TotalLoss=-3.808530 | Sup=0.127083 | Unsup=-0.491952 | TrainAcc=0.9178
# Fold 17 Epoch 1500: TotalLoss=-3.812832 | Sup=0.116419 | Unsup=-0.491156 | TrainAcc=0.9178
# Fold 17 Epoch 2000: TotalLoss=-3.814433 | Sup=0.132378 | Unsup=-0.493351 | TrainAcc=0.9178
# Fold 17 Epoch 2500: TotalLoss=-3.815690 | Sup=0.122170 | Unsup=-0.492232 | TrainAcc=0.9178
# Fold 17 Epoch 3000: TotalLoss=-3.816409 | Sup=0.124912 | Unsup=-0.492665 | TrainAcc=0.9178
# Fold 17 Epoch 3500: TotalLoss=-3.816530 | Sup=0.127285 | Unsup=-0.492977 | TrainAcc=0.9178
# Fold 17 Epoch 4000: TotalLoss=-3.816624 | Sup=0.122856 | Unsup=-0.492435 | TrainAcc=0.9178
# Fold 17 Epoch 4500: TotalLoss=-3.816526 | Sup=0.119701 | Unsup=-0.492028 | TrainAcc=0.9178
# Fold 17 Epoch 5000: TotalLoss=-3.816246 | Sup=0.116930 | Unsup=-0.491647 | TrainAcc=0.9178
#  Saved checkpoint: ARMA_Cut_NIFD/checkpoint_lambda_8_fold_17.pt
# Fold 17 → Acc=0.7671 | Prec=0.9444 | Rec=0.6939 | F1=0.8000 | AUC=0.8878 | CE Loss=1.9668
#
# === Fold 18 ===
# Train Controls: 24, Train Patients: 49
# Fold 18 Epoch 1: TotalLoss=-1.139302 | Sup=0.735555 | Unsup=-0.234357 | TrainAcc=0.5342
# Fold 18 Epoch 500: TotalLoss=-3.715427 | Sup=0.154092 | Unsup=-0.483690 | TrainAcc=0.9041
# Fold 18 Epoch 1000: TotalLoss=-3.760379 | Sup=0.179297 | Unsup=-0.492460 | TrainAcc=0.9041
# Fold 18 Epoch 1500: TotalLoss=-3.774531 | Sup=0.160490 | Unsup=-0.491878 | TrainAcc=0.9041
# Fold 18 Epoch 2000: TotalLoss=-3.776177 | Sup=0.148627 | Unsup=-0.490601 | TrainAcc=0.9041
# Fold 18 Epoch 2500: TotalLoss=-3.776621 | Sup=0.158942 | Unsup=-0.491945 | TrainAcc=0.9041
# Fold 18 Epoch 3000: TotalLoss=-3.776703 | Sup=0.147623 | Unsup=-0.490541 | TrainAcc=0.9041
# Fold 18 Epoch 3500: TotalLoss=-3.777812 | Sup=0.153866 | Unsup=-0.491460 | TrainAcc=0.9041
# Fold 18 Epoch 4000: TotalLoss=-3.777643 | Sup=0.157635 | Unsup=-0.491910 | TrainAcc=0.9041
# Fold 18 Epoch 4500: TotalLoss=-3.777821 | Sup=0.152224 | Unsup=-0.491256 | TrainAcc=0.9041
# Fold 18 Epoch 5000: TotalLoss=-3.777647 | Sup=0.149357 | Unsup=-0.490876 | TrainAcc=0.9041
#  Saved checkpoint: ARMA_Cut_NIFD/checkpoint_lambda_8_fold_18.pt
# Fold 18 → Acc=0.7397 | Prec=0.9688 | Rec=0.6327 | F1=0.7654 | AUC=0.8197 | CE Loss=2.3397
#
# === Fold 19 ===
# Train Controls: 24, Train Patients: 49
# Fold 19 Epoch 1: TotalLoss=-1.215302 | Sup=0.645579 | Unsup=-0.232610 | TrainAcc=0.6301
# Fold 19 Epoch 500: TotalLoss=-3.646825 | Sup=0.233936 | Unsup=-0.485095 | TrainAcc=0.8630
# Fold 19 Epoch 1000: TotalLoss=-3.659316 | Sup=0.254057 | Unsup=-0.489172 | TrainAcc=0.8630
# Fold 19 Epoch 1500: TotalLoss=-3.660710 | Sup=0.253029 | Unsup=-0.489217 | TrainAcc=0.8630
# Fold 19 Epoch 2000: TotalLoss=-3.662879 | Sup=0.218149 | Unsup=-0.485128 | TrainAcc=0.8630
# Fold 19 Epoch 2500: TotalLoss=-3.665426 | Sup=0.234746 | Unsup=-0.487521 | TrainAcc=0.8630
# Fold 19 Epoch 3000: TotalLoss=-3.666194 | Sup=0.232691 | Unsup=-0.487361 | TrainAcc=0.8630
# Fold 19 Epoch 3500: TotalLoss=-3.703321 | Sup=0.192523 | Unsup=-0.486980 | TrainAcc=0.8630
# Fold 19 Epoch 4000: TotalLoss=-3.701993 | Sup=0.203037 | Unsup=-0.488129 | TrainAcc=0.8630
# Fold 19 Epoch 4500: TotalLoss=-3.703450 | Sup=0.185038 | Unsup=-0.486061 | TrainAcc=0.8630
# Fold 19 Epoch 5000: TotalLoss=-3.703611 | Sup=0.186709 | Unsup=-0.486290 | TrainAcc=0.8630
#  Saved checkpoint: ARMA_Cut_NIFD/checkpoint_lambda_8_fold_19.pt
# Fold 19 → Acc=0.7260 | Prec=0.9394 | Rec=0.6327 | F1=0.7561 | AUC=0.8724 | CE Loss=2.1203
#
# === Fold 20 ===
# Train Controls: 24, Train Patients: 49
# Fold 20 Epoch 1: TotalLoss=-1.153660 | Sup=0.721066 | Unsup=-0.234341 | TrainAcc=0.4521
# Fold 20 Epoch 500: TotalLoss=-3.685982 | Sup=0.202883 | Unsup=-0.486108 | TrainAcc=0.8767
# Fold 20 Epoch 1000: TotalLoss=-3.699842 | Sup=0.204736 | Unsup=-0.488072 | TrainAcc=0.8767
# Fold 20 Epoch 1500: TotalLoss=-3.700355 | Sup=0.199021 | Unsup=-0.487422 | TrainAcc=0.8767
# Fold 20 Epoch 2000: TotalLoss=-3.702453 | Sup=0.208063 | Unsup=-0.488814 | TrainAcc=0.8767
# Fold 20 Epoch 2500: TotalLoss=-3.702919 | Sup=0.202486 | Unsup=-0.488176 | TrainAcc=0.8767
# Fold 20 Epoch 3000: TotalLoss=-3.703352 | Sup=0.208090 | Unsup=-0.488930 | TrainAcc=0.8767
# Fold 20 Epoch 3500: TotalLoss=-3.703429 | Sup=0.211562 | Unsup=-0.489374 | TrainAcc=0.8767
# Fold 20 Epoch 4000: TotalLoss=-3.703618 | Sup=0.204317 | Unsup=-0.488492 | TrainAcc=0.8767
# Fold 20 Epoch 4500: TotalLoss=-3.703907 | Sup=0.213207 | Unsup=-0.489639 | TrainAcc=0.8767
# Fold 20 Epoch 5000: TotalLoss=-3.704000 | Sup=0.209452 | Unsup=-0.489182 | TrainAcc=0.8767
#  Saved checkpoint: ARMA_Cut_NIFD/checkpoint_lambda_8_fold_20.pt
# Fold 20 → Acc=0.8082 | Prec=0.9730 | Rec=0.7347 | F1=0.8372 | AUC=0.9252 | CE Loss=1.3635
#
# === λ_mod = 8 → Average Results ===
# Accuracy:  0.7719 ± 0.0285
# Precision: 0.9599 ± 0.0299
# Recall:    0.6898 ± 0.0385
# F1-score:  0.8019 ± 0.0277
# AUC:       0.8832 ± 0.0316
# CE Loss:   1.9240 ± 0.2772
#
#
# ========== FINAL SUMMARY TABLE (Controls vs Patients) ==========
#  λ_mod        Accuracy       Precision          Recall              F1             AUC         CE Loss
#  0.001 0.8041 ± 0.0249 0.9875 ± 0.0184 0.7173 ± 0.0311 0.8307 ± 0.0235 0.9405 ± 0.0148 0.6877 ± 0.0998
#  0.005 0.8062 ± 0.0234 0.9851 ± 0.0180 0.7224 ± 0.0332 0.8331 ± 0.0226 0.9379 ± 0.0141 0.8427 ± 0.1295
#  0.009 0.8055 ± 0.0299 0.9806 ± 0.0214 0.7245 ± 0.0351 0.8330 ± 0.0278 0.9355 ± 0.0123 0.8819 ± 0.1732
#  0.010 0.8007 ± 0.0269 0.9832 ± 0.0162 0.7153 ± 0.0350 0.8277 ± 0.0259 0.9367 ± 0.0146 0.9092 ± 0.1391
#  0.050 0.8096 ± 0.0263 0.9825 ± 0.0175 0.7296 ± 0.0376 0.8367 ± 0.0256 0.9362 ± 0.0151 1.2827 ± 0.2391
#  0.090 0.8082 ± 0.0217 0.9827 ± 0.0171 0.7276 ± 0.0355 0.8354 ± 0.0217 0.9341 ± 0.0169 1.4407 ± 0.1827
#  0.100 0.8027 ± 0.0265 0.9756 ± 0.0185 0.7245 ± 0.0374 0.8309 ± 0.0253 0.9328 ± 0.0195 1.4853 ± 0.2029
#  0.300 0.8041 ± 0.0319 0.9782 ± 0.0204 0.7245 ± 0.0435 0.8317 ± 0.0302 0.9311 ± 0.0193 1.6746 ± 0.2856
#  0.500 0.8082 ± 0.0312 0.9797 ± 0.0223 0.7296 ± 0.0402 0.8357 ± 0.0291 0.9253 ± 0.0180 1.7305 ± 0.2703
#  0.900 0.8151 ± 0.0251 0.9893 ± 0.0178 0.7327 ± 0.0341 0.8413 ± 0.0237 0.9214 ± 0.0210 1.7790 ± 0.2479
#  1.000 0.8082 ± 0.0277 0.9802 ± 0.0263 0.7296 ± 0.0364 0.8359 ± 0.0261 0.9161 ± 0.0211 1.8514 ± 0.2600
#  2.000 0.8116 ± 0.0280 0.9838 ± 0.0230 0.7316 ± 0.0331 0.8388 ± 0.0256 0.9070 ± 0.0268 1.9319 ± 0.2996
#  5.000 0.8089 ± 0.0214 0.9801 ± 0.0235 0.7306 ± 0.0271 0.8367 ± 0.0196 0.8851 ± 0.0265 2.1222 ± 0.2303
#  8.000 0.7719 ± 0.0285 0.9599 ± 0.0299 0.6898 ± 0.0385 0.8019 ± 0.0277 0.8832 ± 0.0316 1.9240 ± 0.2772

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import pandas as pd
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, log_loss

# ==========================================
# CONFIG
# ==========================================
SEED = 42
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

hidden_dim = 512
num_epochs = 5000
lr = 1e-4
weight_decay = 1e-4
batch_print_freq = 500  # print every 500 epochs

# λ_mod list
lambda_mod_list = [0.001, 0.005, 0.009, 0.01, 0.05, 0.09, 0.1, 0.3, 0.5, 0.9, 1, 2, 5, 8]

# Directory for checkpoints
checkpoint_dir = "ARMA_Cut_NIFD_90_10"
os.makedirs(checkpoint_dir, exist_ok=True)

results_summary = []

# ==========================================
# Main loop for λ_mod sweep
# ==========================================
for lambda_mod in lambda_mod_list:
    print(f"\n==============================")
    print(f" Running with λ_mod = {lambda_mod}")
    print(f"==============================")

    accuracies, precisions, recalls, f1_scores, aucs, ce_losses = [], [], [], [], [], []
    sss = StratifiedShuffleSplit(n_splits=20, test_size=0.1, random_state=SEED)

    for fold, (train_val_idx, test_idx_global) in enumerate(sss.split(X, y), start=1):
        print(f"\n=== Fold {fold} ===")

        # --- Split Controls and Patients ---
        controls_idx = np.where(y == 0)[0]
        patients_idx = np.where(y == 1)[0]

        sss_class = StratifiedShuffleSplit(n_splits=20, test_size=0.1, random_state=fold)
        controls_train_idx, _ = next(sss_class.split(X[controls_idx], y[controls_idx]))
        patients_train_idx, _ = next(sss_class.split(X[patients_idx], y[patients_idx]))

        controls_train = controls_idx[controls_train_idx]
        patients_train = patients_idx[patients_train_idx]
        train_idx_final = np.concatenate([controls_train, patients_train])
        np.random.shuffle(train_idx_final)

        print(f"Train Controls: {len(controls_train)}, Train Patients: {len(patients_train)}")

        train_idx_t = torch.from_numpy(train_idx_final).long().to(device)
        y_train_tensor = torch.from_numpy(y[train_idx_final]).long().to(device)

        # --- Initialize model ---
        model = ARMA_SemiSupervised(feats_dim, hidden_dim, num_classes, device, "RELU").to(device)
        optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
        ce_loss = nn.CrossEntropyLoss()

        best_loss = float('inf')
        best_model_state = None

        # --- Training loop ---
        for epoch in range(1, num_epochs + 1):
            model.train()
            optimizer.zero_grad()

            logits = model(data)
            loss_sup = ce_loss(logits[train_idx_t], y_train_tensor)
            loss_unsup = model.cut_loss(A_tensor, logits)  # unsupervised regularization
            total_loss = loss_sup + lambda_mod * loss_unsup

            total_loss.backward()
            optimizer.step()

            # Track best model
            if total_loss.item() < best_loss:
                best_loss = total_loss.item()
                best_model_state = model.state_dict().copy()

            if epoch % batch_print_freq == 0 or epoch == 1:
                model.eval()
                with torch.no_grad():
                    preds_train = logits[train_idx_t].argmax(dim=1)
                    acc_train = accuracy_score(y_train_tensor.cpu(), preds_train.cpu())
                print(f"Fold {fold} Epoch {epoch}: "
                      f"TotalLoss={total_loss.item():.6f} | Sup={loss_sup.item():.6f} | "
                      f"Unsup={loss_unsup.item():.6f} | TrainAcc={acc_train:.4f}")

        # --- Save checkpoint ---
        checkpoint_path = os.path.join(checkpoint_dir, f"checkpoint_lambda_{lambda_mod}_fold_{fold}.pt")
        torch.save({
            'lambda_mod': lambda_mod,
            'fold': fold,
            'model_state_dict': best_model_state,
            'optimizer_state_dict': optimizer.state_dict(),
            'best_loss': best_loss,
        }, checkpoint_path)
        print(f" Saved checkpoint: {checkpoint_path}")

        # --- Evaluation ---
        model.load_state_dict(best_model_state)
        model.eval()
        with torch.no_grad():
            out = model(data)
            preds = out.argmax(dim=1).cpu().numpy()
            probs = torch.softmax(out, dim=1)[:, 1].cpu().numpy()

        y_test = y[test_idx_global]
        y_pred_test = preds[test_idx_global]
        y_prob_test = probs[test_idx_global]

        acc = accuracy_score(y_test, y_pred_test)
        prec = precision_score(y_test, y_pred_test, zero_division=0)
        rec = recall_score(y_test, y_pred_test, zero_division=0)
        f1 = f1_score(y_test, y_pred_test, zero_division=0)
        auc = roc_auc_score(y_test, y_prob_test)
        ce = log_loss(y_test, y_prob_test)

        accuracies.append(acc)
        precisions.append(prec)
        recalls.append(rec)
        f1_scores.append(f1)
        aucs.append(auc)
        ce_losses.append(ce)

        print(f"Fold {fold} → "
              f"Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | "
              f"F1={f1:.4f} | AUC={auc:.4f} | CE Loss={ce:.4f}")

    # --- Average results per λ_mod ---
    mean_acc, std_acc = np.mean(accuracies), np.std(accuracies)
    mean_prec, std_prec = np.mean(precisions), np.std(precisions)
    mean_rec, std_rec = np.mean(recalls), np.std(recalls)
    mean_f1, std_f1 = np.mean(f1_scores), np.std(f1_scores)
    mean_auc, std_auc = np.mean(aucs), np.std(aucs)
    mean_ce, std_ce = np.mean(ce_losses), np.std(ce_losses)

    results_summary.append({
        "λ_mod": lambda_mod,
        "Accuracy": f"{mean_acc:.4f} ± {std_acc:.4f}",
        "Precision": f"{mean_prec:.4f} ± {std_prec:.4f}",
        "Recall": f"{mean_rec:.4f} ± {std_rec:.4f}",
        "F1": f"{mean_f1:.4f} ± {std_f1:.4f}",
        "AUC": f"{mean_auc:.4f} ± {std_auc:.4f}",
        "CE Loss": f"{mean_ce:.4f} ± {std_ce:.4f}",
    })

    print(f"\n=== λ_mod = {lambda_mod} → Average Results ===")
    print(f"Accuracy:  {mean_acc:.4f} ± {std_acc:.4f}")
    print(f"Precision: {mean_prec:.4f} ± {std_prec:.4f}")
    print(f"Recall:    {mean_rec:.4f} ± {std_rec:.4f}")
    print(f"F1-score:  {mean_f1:.4f} ± {std_f1:.4f}")
    print(f"AUC:       {mean_auc:.4f} ± {std_auc:.4f}")
    print(f"CE Loss:   {mean_ce:.4f} ± {std_ce:.4f}")

# ==========================================
# Final summary table
# ==========================================
print("\n\n========== FINAL SUMMARY TABLE (Controls vs Patients) ==========")
results_df = pd.DataFrame(results_summary)
print(results_df.to_string(index=False))
