# %%
import torch
import torch.nn as nn
import torch.nn.functional as nnFn
import torch.optim as optim
import numpy as np
import random
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from torch_geometric.data import Data
from torch_geometric.nn import ARMAConv
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, roc_auc_score, log_loss
)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print("Device:", device)

# === Load Patients ===
fa_patients_path = "/home/snu/Downloads/NIFD_Patients_FA_Histogram_Feature.npy"
Patients_FA_array = np.load(fa_patients_path, allow_pickle=True)

# === Load Controls ===
fa_controls_path = "/home/snu/Downloads/NIFD_Control_FA_Histogram_Feature.npy"
Controls_FA_array = np.load(fa_controls_path, allow_pickle=True)

print("Patients Shape:", Patients_FA_array.shape)
print("Controls Shape:", Controls_FA_array.shape)

# === Combine features and labels ===
X = np.vstack([Controls_FA_array, Patients_FA_array])
y = np.hstack([
    np.zeros(Controls_FA_array.shape[0], dtype=np.int64),  # 0 = Control
    np.ones(Patients_FA_array.shape[0], dtype=np.int64)    # 1 = Patient
])

# Shuffle
np.random.seed(42)
perm = np.random.permutation(X.shape[0])
X = X[perm]
y = y[perm]
# Out:
# Device: cuda
# Patients Shape: (98, 180)
# Controls Shape: (48, 180)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as nnFn
from torch_geometric.nn import GATConv


class GAT_SemiSupervised(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, device, heads=2, activ="RELU", dropout=0.25):
        super(GAT_SemiSupervised, self).__init__()
        self.device = device

        # GAT layer
        self.conv1 = GATConv(input_dim, hidden_dim, heads=heads, concat=True, dropout=dropout)
        self.bn1 = nn.BatchNorm1d(hidden_dim * heads)  # heads multiply feature dimension if concat=True
        self.dropout = nn.Dropout(dropout)
        self.fc = nn.Linear(hidden_dim * heads, output_dim)
        self.num_clusters = output_dim

        # Activation mapping
        activations = {
            "SELU": nnFn.selu,
            "SiLU": nnFn.silu,
            "GELU": nnFn.gelu,
            "RELU": nnFn.relu,
            "ELU": nnFn.elu
        }
        self.act = activations.get(activ, nnFn.elu)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index

        # GAT layer
        x = self.conv1(x, edge_index)
        x = self.bn1(x)
        x = self.act(x)
        x = self.dropout(x)

        logits = self.fc(x)
        return logits

    def cut_loss(self, A, S):
        S = nnFn.softmax(S, dim=1)
        A_pool = torch.matmul(torch.matmul(A, S).t(), S)
        num = torch.trace(A_pool)

        D = torch.diag(torch.sum(A, dim=-1))
        D_pooled = torch.matmul(torch.matmul(D, S).t(), S)
        den = torch.trace(D_pooled)
        mincut_loss = -(num / den)

        St_S = torch.matmul(S.t(), S)
        I_S = torch.eye(self.num_clusters, device=self.device)
        ortho_loss = torch.norm(St_S / torch.norm(St_S) - I_S / torch.norm(I_S))

        return mincut_loss + ortho_loss

# %%
def create_adj(F, alpha=1):
    F_norm = F / np.linalg.norm(F, axis=1, keepdims=True)
    W = np.dot(F_norm, F_norm.T)
    W = np.where(W >= alpha, 1, 0).astype(np.float32)
    W = W / W.max()
    return W

def load_data(adj, node_feats):
    node_feats = torch.from_numpy(node_feats).float()
    edge_index = torch.from_numpy(np.array(np.nonzero((adj > 0))))
    return Data(x=node_feats, edge_index=edge_index)

# %%
num_nodes, num_feats = X.shape
print(f"Number of features: {num_feats}")
# Out:
# Number of features: 180

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
alpha = 0.5
feats_dim = num_feats
hidden_dim = 512
num_classes = 2
num_epochs = 2000
lr = 0.0001
weight_decay = 1e-4
batch_print_freq = 100
lambda_mod = 0.5 #0.01  # weight for modularity loss
# lambda_sup = 5

# %%
W = create_adj(X, alpha)
data = load_data(W, X).to(device)
A_tensor = torch.from_numpy(W).float().to(device)
print(data)
# Out:
# Data(x=[146, 180], edge_index=[2, 21256])

# %%
sss = StratifiedShuffleSplit(n_splits=20, test_size=0.9, random_state=42)

accuracies, precisions, recalls, f1_scores, aucs, ce_losses = [], [], [], [], [], []

for fold, (train_val_idx, test_idx_global) in enumerate(sss.split(X, y), start=1):
    print(f"\n=== Fold {fold} ===")

    # Split into controls (label 0) and patients (label 1)
    controls_idx = np.where(y == 0)[0]
    patients_idx = np.where(y == 1)[0]

    sss_class = StratifiedShuffleSplit(n_splits=20, test_size=0.9, random_state=fold)
    controls_train_idx, _ = next(sss_class.split(X[controls_idx], y[controls_idx]))
    patients_train_idx, _ = next(sss_class.split(X[patients_idx], y[patients_idx]))

    controls_train = controls_idx[controls_train_idx]
    patients_train = patients_idx[patients_train_idx]
    train_idx_final = np.concatenate([controls_train, patients_train])
    np.random.shuffle(train_idx_final)

    print(f"Train Controls: {len(controls_train)}, Train Patients: {len(patients_train)}")

    train_idx_t = torch.from_numpy(train_idx_final).long().to(device)
    y_train_tensor = torch.from_numpy(y[train_idx_final]).long().to(device)

    # Initialize model and optimizer
    model = GAT_SemiSupervised(feats_dim, hidden_dim, num_classes, device, activ="RELU").to(device)
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    ce_loss = nn.CrossEntropyLoss()

    # Training loop
    for epoch in range(1, num_epochs + 1):
        model.train()
        optimizer.zero_grad()

        logits = model(data)
        loss_sup = ce_loss(logits[train_idx_t], y_train_tensor)
        loss_unsup = model.cut_loss(A_tensor, logits)
        total_loss = loss_sup + lambda_mod * loss_unsup

        total_loss.backward()
        optimizer.step()

        if epoch % batch_print_freq == 0 or epoch == 1:
            model.eval()
            with torch.no_grad():
                preds_train = logits[train_idx_t].argmax(dim=1)
                acc_train = accuracy_score(y_train_tensor.cpu(), preds_train.cpu())
            print(f"Fold {fold} Epoch {epoch}: "
                  f"TotalLoss={total_loss.item():.6f} | Sup={loss_sup.item():.6f} | "
                  f"Unsup={loss_unsup.item():.6f} | TrainAcc={acc_train:.4f}")

    # Evaluation
    model.eval()
    with torch.no_grad():
        out = model(data)
        preds = out.argmax(dim=1).cpu().numpy()
        probs = torch.softmax(out, dim=1)[:, 1].cpu().numpy()

    y_test = y[test_idx_global]
    y_pred_test = preds[test_idx_global]
    y_prob_test = probs[test_idx_global]

    acc = accuracy_score(y_test, y_pred_test)
    prec = precision_score(y_test, y_pred_test, zero_division=0)
    rec = recall_score(y_test, y_pred_test, zero_division=0)
    f1 = f1_score(y_test, y_pred_test, zero_division=0)
    auc = roc_auc_score(y_test, y_prob_test)
    ce = log_loss(y_test, y_prob_test)

    accuracies.append(acc)
    precisions.append(prec)
    recalls.append(rec)
    f1_scores.append(f1)
    aucs.append(auc)
    ce_losses.append(ce)

    print(f"Fold {fold} → "
          f"Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | "
          f"F1={f1:.4f} | AUC={auc:.4f} | CE Loss={ce:.4f}")

# Summary across all folds
print("\n=== Average Results Across 20 Folds (Controls vs Patients) ===")
print(f"Accuracy:  {np.mean(accuracies):.4f} ± {np.std(accuracies):.4f}")
print(f"Precision: {np.mean(precisions):.4f} ± {np.std(precisions):.4f}")
print(f"Recall:    {np.mean(recalls):.4f} ± {np.std(recalls):.4f}")
print(f"F1-score:  {np.mean(f1_scores):.4f} ± {np.std(f1_scores):.4f}")
print(f"AUC:       {np.mean(aucs):.4f} ± {np.std(aucs):.4f}")
print(f"CE Loss:   {np.mean(ce_losses):.4f} ± {np.std(ce_losses):.4f}")
# Out:
# === Fold 1 ===
# Train Controls: 4, Train Patients: 9
# Fold 1 Epoch 1: TotalLoss=0.620691 | Sup=0.737583 | Unsup=-0.233784 | TrainAcc=0.3077
# Fold 1 Epoch 100: TotalLoss=0.511251 | Sup=0.626628 | Unsup=-0.230756 | TrainAcc=0.6154
# Fold 1 Epoch 200: TotalLoss=0.094933 | Sup=0.217056 | Unsup=-0.244245 | TrainAcc=0.9231
# Fold 1 Epoch 300: TotalLoss=0.040516 | Sup=0.211748 | Unsup=-0.342466 | TrainAcc=0.9231
# Fold 1 Epoch 400: TotalLoss=-0.185526 | Sup=0.015884 | Unsup=-0.402821 | TrainAcc=1.0000
# Fold 1 Epoch 500: TotalLoss=-0.214737 | Sup=0.001730 | Unsup=-0.432933 | TrainAcc=1.0000
# Fold 1 Epoch 600: TotalLoss=-0.222056 | Sup=0.002349 | Unsup=-0.448811 | TrainAcc=1.0000
# Fold 1 Epoch 700: TotalLoss=-0.156305 | Sup=0.068762 | Unsup=-0.450133 | TrainAcc=0.9231
# Fold 1 Epoch 800: TotalLoss=-0.221367 | Sup=0.000841 | Unsup=-0.444415 | TrainAcc=1.0000
# Fold 1 Epoch 900: TotalLoss=-0.233880 | Sup=0.000465 | Unsup=-0.468691 | TrainAcc=1.0000
# Fold 1 Epoch 1000: TotalLoss=-0.225134 | Sup=0.003247 | Unsup=-0.456764 | TrainAcc=1.0000
# Fold 1 Epoch 1100: TotalLoss=-0.235702 | Sup=0.000077 | Unsup=-0.471558 | TrainAcc=1.0000
# Fold 1 Epoch 1200: TotalLoss=-0.239967 | Sup=0.000030 | Unsup=-0.479995 | TrainAcc=1.0000
# Fold 1 Epoch 1300: TotalLoss=-0.236118 | Sup=0.000981 | Unsup=-0.474199 | TrainAcc=1.0000
# Fold 1 Epoch 1400: TotalLoss=-0.217418 | Sup=0.015812 | Unsup=-0.466461 | TrainAcc=1.0000
# Fold 1 Epoch 1500: TotalLoss=-0.239501 | Sup=0.000036 | Unsup=-0.479073 | TrainAcc=1.0000
# Fold 1 Epoch 1600: TotalLoss=-0.218651 | Sup=0.020142 | Unsup=-0.477586 | TrainAcc=1.0000
# Fold 1 Epoch 1700: TotalLoss=-0.241708 | Sup=0.000012 | Unsup=-0.483441 | TrainAcc=1.0000
# Fold 1 Epoch 1800: TotalLoss=-0.240340 | Sup=0.000106 | Unsup=-0.480892 | TrainAcc=1.0000
# Fold 1 Epoch 1900: TotalLoss=-0.234150 | Sup=0.000098 | Unsup=-0.468498 | TrainAcc=1.0000
# Fold 1 Epoch 2000: TotalLoss=-0.239022 | Sup=0.000101 | Unsup=-0.478246 | TrainAcc=1.0000
# Fold 1 → Acc=0.6136 | Prec=0.7879 | Rec=0.5843 | F1=0.6710 | AUC=0.7000 | CE Loss=3.2281
#
# === Fold 2 ===
# Train Controls: 4, Train Patients: 9
# Fold 2 Epoch 1: TotalLoss=0.594196 | Sup=0.711202 | Unsup=-0.234013 | TrainAcc=0.4615
# Fold 2 Epoch 100: TotalLoss=0.461713 | Sup=0.576476 | Unsup=-0.229526 | TrainAcc=0.7692
# Fold 2 Epoch 200: TotalLoss=0.322665 | Sup=0.437119 | Unsup=-0.228909 | TrainAcc=0.7692
# Fold 2 Epoch 300: TotalLoss=-0.078450 | Sup=0.081324 | Unsup=-0.319547 | TrainAcc=1.0000
# Fold 2 Epoch 400: TotalLoss=-0.190504 | Sup=0.013845 | Unsup=-0.408697 | TrainAcc=1.0000
# Fold 2 Epoch 500: TotalLoss=-0.190086 | Sup=0.016247 | Unsup=-0.412666 | TrainAcc=1.0000
# Fold 2 Epoch 600: TotalLoss=-0.209187 | Sup=0.005443 | Unsup=-0.429260 | TrainAcc=1.0000
# Fold 2 Epoch 700: TotalLoss=-0.224946 | Sup=0.000215 | Unsup=-0.450322 | TrainAcc=1.0000
# Fold 2 Epoch 800: TotalLoss=-0.225667 | Sup=0.005597 | Unsup=-0.462529 | TrainAcc=1.0000
# Fold 2 Epoch 900: TotalLoss=-0.229184 | Sup=0.000462 | Unsup=-0.459292 | TrainAcc=1.0000
# Fold 2 Epoch 1000: TotalLoss=-0.222226 | Sup=0.000528 | Unsup=-0.445508 | TrainAcc=1.0000
# Fold 2 Epoch 1100: TotalLoss=-0.226494 | Sup=0.009946 | Unsup=-0.472879 | TrainAcc=1.0000
# Fold 2 Epoch 1200: TotalLoss=-0.236119 | Sup=0.001007 | Unsup=-0.474252 | TrainAcc=1.0000
# Fold 2 Epoch 1300: TotalLoss=-0.238170 | Sup=0.000048 | Unsup=-0.476436 | TrainAcc=1.0000
# Fold 2 Epoch 1400: TotalLoss=-0.233069 | Sup=0.000034 | Unsup=-0.466206 | TrainAcc=1.0000
# Fold 2 Epoch 1500: TotalLoss=-0.236463 | Sup=0.000082 | Unsup=-0.473090 | TrainAcc=1.0000
# Fold 2 Epoch 1600: TotalLoss=-0.235531 | Sup=0.002679 | Unsup=-0.476421 | TrainAcc=1.0000
# Fold 2 Epoch 1700: TotalLoss=-0.235671 | Sup=0.000066 | Unsup=-0.471473 | TrainAcc=1.0000
# Fold 2 Epoch 1800: TotalLoss=-0.239097 | Sup=0.000053 | Unsup=-0.478300 | TrainAcc=1.0000
# Fold 2 Epoch 1900: TotalLoss=-0.239201 | Sup=0.000174 | Unsup=-0.478750 | TrainAcc=1.0000
# Fold 2 Epoch 2000: TotalLoss=-0.244219 | Sup=0.000080 | Unsup=-0.488600 | TrainAcc=1.0000
# Fold 2 → Acc=0.7045 | Prec=0.8788 | Rec=0.6517 | F1=0.7484 | AUC=0.8074 | CE Loss=2.2471
#
# === Fold 3 ===
# Train Controls: 4, Train Patients: 9
# Fold 3 Epoch 1: TotalLoss=0.605075 | Sup=0.722024 | Unsup=-0.233899 | TrainAcc=0.3846
# Fold 3 Epoch 100: TotalLoss=0.402829 | Sup=0.518035 | Unsup=-0.230412 | TrainAcc=0.6923
# Fold 3 Epoch 200: TotalLoss=0.134156 | Sup=0.261811 | Unsup=-0.255310 | TrainAcc=0.9231
# Fold 3 Epoch 300: TotalLoss=-0.124482 | Sup=0.071064 | Unsup=-0.391092 | TrainAcc=0.9231
# Fold 3 Epoch 400: TotalLoss=-0.213264 | Sup=0.005971 | Unsup=-0.438470 | TrainAcc=1.0000
# Fold 3 Epoch 500: TotalLoss=-0.226254 | Sup=0.000872 | Unsup=-0.454252 | TrainAcc=1.0000
# Fold 3 Epoch 600: TotalLoss=-0.214189 | Sup=0.009144 | Unsup=-0.446666 | TrainAcc=1.0000
# Fold 3 Epoch 700: TotalLoss=-0.233022 | Sup=0.003141 | Unsup=-0.472326 | TrainAcc=1.0000
# Fold 3 Epoch 800: TotalLoss=-0.228429 | Sup=0.005498 | Unsup=-0.467854 | TrainAcc=1.0000
# Fold 3 Epoch 900: TotalLoss=-0.239115 | Sup=0.000540 | Unsup=-0.479310 | TrainAcc=1.0000
# Fold 3 Epoch 1000: TotalLoss=-0.239724 | Sup=0.000341 | Unsup=-0.480131 | TrainAcc=1.0000
# Fold 3 Epoch 1100: TotalLoss=-0.235414 | Sup=0.002935 | Unsup=-0.476698 | TrainAcc=1.0000
# Fold 3 Epoch 1200: TotalLoss=-0.239632 | Sup=0.000412 | Unsup=-0.480089 | TrainAcc=1.0000
# Fold 3 Epoch 1300: TotalLoss=-0.239535 | Sup=0.000129 | Unsup=-0.479329 | TrainAcc=1.0000
# Fold 3 Epoch 1400: TotalLoss=-0.242605 | Sup=0.000085 | Unsup=-0.485381 | TrainAcc=1.0000
# Fold 3 Epoch 1500: TotalLoss=-0.239100 | Sup=0.000234 | Unsup=-0.478668 | TrainAcc=1.0000
# Fold 3 Epoch 1600: TotalLoss=-0.239883 | Sup=0.000115 | Unsup=-0.479996 | TrainAcc=1.0000
# Fold 3 Epoch 1700: TotalLoss=-0.245389 | Sup=0.000076 | Unsup=-0.490932 | TrainAcc=1.0000
# Fold 3 Epoch 1800: TotalLoss=-0.235811 | Sup=0.006653 | Unsup=-0.484929 | TrainAcc=1.0000
# Fold 3 Epoch 1900: TotalLoss=-0.238864 | Sup=0.000067 | Unsup=-0.477862 | TrainAcc=1.0000
# Fold 3 Epoch 2000: TotalLoss=-0.239943 | Sup=0.000021 | Unsup=-0.479928 | TrainAcc=1.0000
# Fold 3 → Acc=0.7197 | Prec=0.8939 | Rec=0.6629 | F1=0.7613 | AUC=0.8359 | CE Loss=2.1273
#
# === Fold 4 ===
# Train Controls: 4, Train Patients: 9
# Fold 4 Epoch 1: TotalLoss=0.716732 | Sup=0.833559 | Unsup=-0.233655 | TrainAcc=0.3077
# Fold 4 Epoch 100: TotalLoss=0.488608 | Sup=0.604501 | Unsup=-0.231787 | TrainAcc=0.6923
# Fold 4 Epoch 200: TotalLoss=0.582452 | Sup=0.698165 | Unsup=-0.231426 | TrainAcc=0.6923
# Fold 4 Epoch 300: TotalLoss=0.497405 | Sup=0.613552 | Unsup=-0.232293 | TrainAcc=0.6923
# Fold 4 Epoch 400: TotalLoss=0.499635 | Sup=0.615606 | Unsup=-0.231942 | TrainAcc=0.6923
# Fold 4 Epoch 500: TotalLoss=0.539186 | Sup=0.655117 | Unsup=-0.231862 | TrainAcc=0.6923
# Fold 4 Epoch 600: TotalLoss=0.546322 | Sup=0.662505 | Unsup=-0.232367 | TrainAcc=0.6923
# Fold 4 Epoch 700: TotalLoss=0.472697 | Sup=0.589009 | Unsup=-0.232625 | TrainAcc=0.6923
# Fold 4 Epoch 800: TotalLoss=0.469247 | Sup=0.585511 | Unsup=-0.232528 | TrainAcc=0.6923
# Fold 4 Epoch 900: TotalLoss=0.529760 | Sup=0.646167 | Unsup=-0.232816 | TrainAcc=0.6923
# Fold 4 Epoch 1000: TotalLoss=0.447611 | Sup=0.563828 | Unsup=-0.232434 | TrainAcc=0.6923
# Fold 4 Epoch 1100: TotalLoss=0.510487 | Sup=0.626438 | Unsup=-0.231904 | TrainAcc=0.6923
# Fold 4 Epoch 1200: TotalLoss=0.472288 | Sup=0.588923 | Unsup=-0.233268 | TrainAcc=0.6923
# Fold 4 Epoch 1300: TotalLoss=0.536495 | Sup=0.652654 | Unsup=-0.232317 | TrainAcc=0.6923
# Fold 4 Epoch 1400: TotalLoss=0.536269 | Sup=0.652466 | Unsup=-0.232393 | TrainAcc=0.6154
# Fold 4 Epoch 1500: TotalLoss=0.503636 | Sup=0.619898 | Unsup=-0.232524 | TrainAcc=0.6923
# Fold 4 Epoch 1600: TotalLoss=0.401733 | Sup=0.515914 | Unsup=-0.228362 | TrainAcc=0.7692
# Fold 4 Epoch 1700: TotalLoss=-0.066182 | Sup=0.110653 | Unsup=-0.353670 | TrainAcc=0.9231
# Fold 4 Epoch 1800: TotalLoss=-0.175662 | Sup=0.035880 | Unsup=-0.423084 | TrainAcc=1.0000
# Fold 4 Epoch 1900: TotalLoss=-0.214715 | Sup=0.007014 | Unsup=-0.443458 | TrainAcc=1.0000
# Fold 4 Epoch 2000: TotalLoss=-0.226020 | Sup=0.007029 | Unsup=-0.466097 | TrainAcc=1.0000
# Fold 4 → Acc=0.6818 | Prec=0.8730 | Rec=0.6180 | F1=0.7237 | AUC=0.7392 | CE Loss=1.5805
#
# === Fold 5 ===
# Train Controls: 4, Train Patients: 9
# Fold 5 Epoch 1: TotalLoss=0.607265 | Sup=0.724092 | Unsup=-0.233655 | TrainAcc=0.3846
# Fold 5 Epoch 100: TotalLoss=0.610281 | Sup=0.726042 | Unsup=-0.231523 | TrainAcc=0.6923
# Fold 5 Epoch 200: TotalLoss=0.273691 | Sup=0.392262 | Unsup=-0.237143 | TrainAcc=0.9231
# Fold 5 Epoch 300: TotalLoss=-0.178671 | Sup=0.018030 | Unsup=-0.393401 | TrainAcc=1.0000
# Fold 5 Epoch 400: TotalLoss=-0.186519 | Sup=0.021288 | Unsup=-0.415615 | TrainAcc=1.0000
# Fold 5 Epoch 500: TotalLoss=-0.217507 | Sup=0.001099 | Unsup=-0.437213 | TrainAcc=1.0000
# Fold 5 Epoch 600: TotalLoss=-0.224246 | Sup=0.003318 | Unsup=-0.455127 | TrainAcc=1.0000
# Fold 5 Epoch 700: TotalLoss=-0.224478 | Sup=0.003782 | Unsup=-0.456520 | TrainAcc=1.0000
# Fold 5 Epoch 800: TotalLoss=-0.231382 | Sup=0.000617 | Unsup=-0.463998 | TrainAcc=1.0000
# Fold 5 Epoch 900: TotalLoss=-0.231818 | Sup=0.000082 | Unsup=-0.463801 | TrainAcc=1.0000
# Fold 5 Epoch 1000: TotalLoss=-0.237604 | Sup=0.000077 | Unsup=-0.475362 | TrainAcc=1.0000
# Fold 5 Epoch 1100: TotalLoss=-0.237665 | Sup=0.000075 | Unsup=-0.475479 | TrainAcc=1.0000
# Fold 5 Epoch 1200: TotalLoss=-0.235819 | Sup=0.000353 | Unsup=-0.472343 | TrainAcc=1.0000
# Fold 5 Epoch 1300: TotalLoss=-0.242154 | Sup=0.000014 | Unsup=-0.484335 | TrainAcc=1.0000
# Fold 5 Epoch 1400: TotalLoss=-0.238701 | Sup=0.000242 | Unsup=-0.477886 | TrainAcc=1.0000
# Fold 5 Epoch 1500: TotalLoss=-0.239979 | Sup=0.000165 | Unsup=-0.480288 | TrainAcc=1.0000
# Fold 5 Epoch 1600: TotalLoss=-0.242594 | Sup=0.000142 | Unsup=-0.485471 | TrainAcc=1.0000
# Fold 5 Epoch 1700: TotalLoss=-0.237535 | Sup=0.000749 | Unsup=-0.476567 | TrainAcc=1.0000
# Fold 5 Epoch 1800: TotalLoss=-0.242825 | Sup=0.000009 | Unsup=-0.485668 | TrainAcc=1.0000
# Fold 5 Epoch 1900: TotalLoss=-0.244585 | Sup=0.000048 | Unsup=-0.489266 | TrainAcc=1.0000
# Fold 5 Epoch 2000: TotalLoss=-0.242189 | Sup=0.000007 | Unsup=-0.484393 | TrainAcc=1.0000
# Fold 5 → Acc=0.7045 | Prec=0.8906 | Rec=0.6404 | F1=0.7451 | AUC=0.8437 | CE Loss=2.6879
#
# === Fold 6 ===
# Train Controls: 4, Train Patients: 9
# Fold 6 Epoch 1: TotalLoss=0.692083 | Sup=0.808726 | Unsup=-0.233285 | TrainAcc=0.3077
# Fold 6 Epoch 100: TotalLoss=0.512301 | Sup=0.627935 | Unsup=-0.231268 | TrainAcc=0.6923
# Fold 6 Epoch 200: TotalLoss=0.497957 | Sup=0.614221 | Unsup=-0.232528 | TrainAcc=0.6923
# Fold 6 Epoch 300: TotalLoss=0.366299 | Sup=0.480799 | Unsup=-0.229002 | TrainAcc=0.6923
# Fold 6 Epoch 400: TotalLoss=-0.040148 | Sup=0.111601 | Unsup=-0.303498 | TrainAcc=0.9231
# Fold 6 Epoch 500: TotalLoss=-0.162490 | Sup=0.039741 | Unsup=-0.404461 | TrainAcc=1.0000
# Fold 6 Epoch 600: TotalLoss=-0.207891 | Sup=0.002152 | Unsup=-0.420086 | TrainAcc=1.0000
# Fold 6 Epoch 700: TotalLoss=-0.201753 | Sup=0.010933 | Unsup=-0.425372 | TrainAcc=1.0000
# Fold 6 Epoch 800: TotalLoss=-0.217216 | Sup=0.004238 | Unsup=-0.442907 | TrainAcc=1.0000
# Fold 6 Epoch 900: TotalLoss=-0.221394 | Sup=0.000635 | Unsup=-0.444058 | TrainAcc=1.0000
# Fold 6 Epoch 1000: TotalLoss=-0.226006 | Sup=0.000370 | Unsup=-0.452752 | TrainAcc=1.0000
# Fold 6 Epoch 1100: TotalLoss=-0.233231 | Sup=0.000561 | Unsup=-0.467583 | TrainAcc=1.0000
# Fold 6 Epoch 1200: TotalLoss=-0.225582 | Sup=0.000319 | Unsup=-0.451801 | TrainAcc=1.0000
# Fold 6 Epoch 1300: TotalLoss=-0.239694 | Sup=0.000043 | Unsup=-0.479475 | TrainAcc=1.0000
# Fold 6 Epoch 1400: TotalLoss=-0.233010 | Sup=0.001528 | Unsup=-0.469076 | TrainAcc=1.0000
# Fold 6 Epoch 1500: TotalLoss=-0.234196 | Sup=0.000203 | Unsup=-0.468797 | TrainAcc=1.0000
# Fold 6 Epoch 1600: TotalLoss=-0.235131 | Sup=0.000049 | Unsup=-0.470359 | TrainAcc=1.0000
# Fold 6 Epoch 1700: TotalLoss=-0.234085 | Sup=0.000010 | Unsup=-0.468190 | TrainAcc=1.0000
# Fold 6 Epoch 1800: TotalLoss=-0.240131 | Sup=0.000089 | Unsup=-0.480440 | TrainAcc=1.0000
# Fold 6 Epoch 1900: TotalLoss=-0.236702 | Sup=0.000055 | Unsup=-0.473514 | TrainAcc=1.0000
# Fold 6 Epoch 2000: TotalLoss=-0.238787 | Sup=0.000059 | Unsup=-0.477691 | TrainAcc=1.0000
# Fold 6 → Acc=0.6061 | Prec=0.7937 | Rec=0.5618 | F1=0.6579 | AUC=0.7468 | CE Loss=2.6422
#
# === Fold 7 ===
# Train Controls: 4, Train Patients: 9
# Fold 7 Epoch 1: TotalLoss=0.610503 | Sup=0.727397 | Unsup=-0.233787 | TrainAcc=0.3846
# Fold 7 Epoch 100: TotalLoss=0.554370 | Sup=0.670321 | Unsup=-0.231902 | TrainAcc=0.6923
# Fold 7 Epoch 200: TotalLoss=0.460148 | Sup=0.574157 | Unsup=-0.228019 | TrainAcc=0.6923
# Fold 7 Epoch 300: TotalLoss=-0.020712 | Sup=0.112204 | Unsup=-0.265834 | TrainAcc=1.0000
# Fold 7 Epoch 400: TotalLoss=-0.177231 | Sup=0.009103 | Unsup=-0.372669 | TrainAcc=1.0000
# Fold 7 Epoch 500: TotalLoss=-0.199023 | Sup=0.007460 | Unsup=-0.412966 | TrainAcc=1.0000
# Fold 7 Epoch 600: TotalLoss=-0.224440 | Sup=0.001720 | Unsup=-0.452320 | TrainAcc=1.0000
# Fold 7 Epoch 700: TotalLoss=-0.209608 | Sup=0.001817 | Unsup=-0.422849 | TrainAcc=1.0000
# Fold 7 Epoch 800: TotalLoss=-0.226622 | Sup=0.000874 | Unsup=-0.454992 | TrainAcc=1.0000
# Fold 7 Epoch 900: TotalLoss=-0.221254 | Sup=0.002080 | Unsup=-0.446667 | TrainAcc=1.0000
# Fold 7 Epoch 1000: TotalLoss=-0.232275 | Sup=0.000107 | Unsup=-0.464764 | TrainAcc=1.0000
# Fold 7 Epoch 1100: TotalLoss=-0.222753 | Sup=0.000222 | Unsup=-0.445950 | TrainAcc=1.0000
# Fold 7 Epoch 1200: TotalLoss=-0.226518 | Sup=0.002093 | Unsup=-0.457220 | TrainAcc=1.0000
# Fold 7 Epoch 1300: TotalLoss=-0.235261 | Sup=0.001934 | Unsup=-0.474390 | TrainAcc=1.0000
# Fold 7 Epoch 1400: TotalLoss=-0.235053 | Sup=0.000260 | Unsup=-0.470627 | TrainAcc=1.0000
# Fold 7 Epoch 1500: TotalLoss=-0.238155 | Sup=0.000695 | Unsup=-0.477700 | TrainAcc=1.0000
# Fold 7 Epoch 1600: TotalLoss=-0.242394 | Sup=0.000182 | Unsup=-0.485152 | TrainAcc=1.0000
# Fold 7 Epoch 1700: TotalLoss=-0.236098 | Sup=0.000182 | Unsup=-0.472560 | TrainAcc=1.0000
# Fold 7 Epoch 1800: TotalLoss=-0.234693 | Sup=0.000309 | Unsup=-0.470004 | TrainAcc=1.0000
# Fold 7 Epoch 1900: TotalLoss=-0.240494 | Sup=0.000586 | Unsup=-0.482160 | TrainAcc=1.0000
# Fold 7 Epoch 2000: TotalLoss=-0.243514 | Sup=0.000032 | Unsup=-0.487093 | TrainAcc=1.0000
# Fold 7 → Acc=0.6970 | Prec=0.8551 | Rec=0.6629 | F1=0.7468 | AUC=0.8079 | CE Loss=2.1975
#
# === Fold 8 ===
# Train Controls: 4, Train Patients: 9
# Fold 8 Epoch 1: TotalLoss=0.561843 | Sup=0.678764 | Unsup=-0.233842 | TrainAcc=0.6154
# Fold 8 Epoch 100: TotalLoss=0.422939 | Sup=0.538645 | Unsup=-0.231411 | TrainAcc=0.7692
# Fold 8 Epoch 200: TotalLoss=0.444660 | Sup=0.559626 | Unsup=-0.229931 | TrainAcc=0.6923
# Fold 8 Epoch 300: TotalLoss=0.220629 | Sup=0.344752 | Unsup=-0.248247 | TrainAcc=0.9231
# Fold 8 Epoch 400: TotalLoss=-0.155456 | Sup=0.033201 | Unsup=-0.377314 | TrainAcc=1.0000
# Fold 8 Epoch 500: TotalLoss=-0.194237 | Sup=0.012211 | Unsup=-0.412898 | TrainAcc=1.0000
# Fold 8 Epoch 600: TotalLoss=-0.215318 | Sup=0.003374 | Unsup=-0.437383 | TrainAcc=1.0000
# Fold 8 Epoch 700: TotalLoss=-0.221434 | Sup=0.002389 | Unsup=-0.447645 | TrainAcc=1.0000
# Fold 8 Epoch 800: TotalLoss=-0.222602 | Sup=0.001660 | Unsup=-0.448523 | TrainAcc=1.0000
# Fold 8 Epoch 900: TotalLoss=-0.225669 | Sup=0.000901 | Unsup=-0.453139 | TrainAcc=1.0000
# Fold 8 Epoch 1000: TotalLoss=-0.232790 | Sup=0.000158 | Unsup=-0.465897 | TrainAcc=1.0000
# Fold 8 Epoch 1100: TotalLoss=-0.231849 | Sup=0.000521 | Unsup=-0.464740 | TrainAcc=1.0000
# Fold 8 Epoch 1200: TotalLoss=-0.230570 | Sup=0.000431 | Unsup=-0.462002 | TrainAcc=1.0000
# Fold 8 Epoch 1300: TotalLoss=-0.227421 | Sup=0.000058 | Unsup=-0.454958 | TrainAcc=1.0000
# Fold 8 Epoch 1400: TotalLoss=-0.232029 | Sup=0.000106 | Unsup=-0.464271 | TrainAcc=1.0000
# Fold 8 Epoch 1500: TotalLoss=-0.231197 | Sup=0.000045 | Unsup=-0.462484 | TrainAcc=1.0000
# Fold 8 Epoch 1600: TotalLoss=-0.232398 | Sup=0.000165 | Unsup=-0.465126 | TrainAcc=1.0000
# Fold 8 Epoch 1700: TotalLoss=-0.235339 | Sup=0.000402 | Unsup=-0.471483 | TrainAcc=1.0000
# Fold 8 Epoch 1800: TotalLoss=-0.240724 | Sup=0.000035 | Unsup=-0.481517 | TrainAcc=1.0000
# Fold 8 Epoch 1900: TotalLoss=-0.240090 | Sup=0.000057 | Unsup=-0.480295 | TrainAcc=1.0000
# Fold 8 Epoch 2000: TotalLoss=-0.240369 | Sup=0.001058 | Unsup=-0.482854 | TrainAcc=1.0000
# Fold 8 → Acc=0.7652 | Prec=0.9394 | Rec=0.6966 | F1=0.8000 | AUC=0.8618 | CE Loss=1.8109
#
# === Fold 9 ===
# Train Controls: 4, Train Patients: 9
# Fold 9 Epoch 1: TotalLoss=0.660757 | Sup=0.777509 | Unsup=-0.233505 | TrainAcc=0.2308
# Fold 9 Epoch 100: TotalLoss=0.492915 | Sup=0.608434 | Unsup=-0.231037 | TrainAcc=0.6154
# Fold 9 Epoch 200: TotalLoss=0.266312 | Sup=0.382241 | Unsup=-0.231858 | TrainAcc=1.0000
# Fold 9 Epoch 300: TotalLoss=-0.007007 | Sup=0.145864 | Unsup=-0.305741 | TrainAcc=0.9231
# Fold 9 Epoch 400: TotalLoss=-0.184017 | Sup=0.015358 | Unsup=-0.398749 | TrainAcc=1.0000
# Fold 9 Epoch 500: TotalLoss=-0.204038 | Sup=0.004293 | Unsup=-0.416663 | TrainAcc=1.0000
# Fold 9 Epoch 600: TotalLoss=-0.218814 | Sup=0.001954 | Unsup=-0.441535 | TrainAcc=1.0000
# Fold 9 Epoch 700: TotalLoss=-0.221561 | Sup=0.002949 | Unsup=-0.449019 | TrainAcc=1.0000
# Fold 9 Epoch 800: TotalLoss=-0.227861 | Sup=0.000285 | Unsup=-0.456291 | TrainAcc=1.0000
# Fold 9 Epoch 900: TotalLoss=-0.229878 | Sup=0.000513 | Unsup=-0.460783 | TrainAcc=1.0000
# Fold 9 Epoch 1000: TotalLoss=-0.227627 | Sup=0.002069 | Unsup=-0.459390 | TrainAcc=1.0000
# Fold 9 Epoch 1100: TotalLoss=-0.237107 | Sup=0.000233 | Unsup=-0.474681 | TrainAcc=1.0000
# Fold 9 Epoch 1200: TotalLoss=-0.232083 | Sup=0.000015 | Unsup=-0.464195 | TrainAcc=1.0000
# Fold 9 Epoch 1300: TotalLoss=-0.236326 | Sup=0.000505 | Unsup=-0.473661 | TrainAcc=1.0000
# Fold 9 Epoch 1400: TotalLoss=-0.237874 | Sup=0.000022 | Unsup=-0.475793 | TrainAcc=1.0000
# Fold 9 Epoch 1500: TotalLoss=-0.241311 | Sup=0.000162 | Unsup=-0.482946 | TrainAcc=1.0000
# Fold 9 Epoch 1600: TotalLoss=-0.232347 | Sup=0.000030 | Unsup=-0.464753 | TrainAcc=1.0000
# Fold 9 Epoch 1700: TotalLoss=-0.236505 | Sup=0.000009 | Unsup=-0.473028 | TrainAcc=1.0000
# Fold 9 Epoch 1800: TotalLoss=-0.240079 | Sup=0.000111 | Unsup=-0.480380 | TrainAcc=1.0000
# Fold 9 Epoch 1900: TotalLoss=-0.241750 | Sup=0.000023 | Unsup=-0.483547 | TrainAcc=1.0000
# Fold 9 Epoch 2000: TotalLoss=-0.240616 | Sup=0.000195 | Unsup=-0.481622 | TrainAcc=1.0000
# Fold 9 → Acc=0.7348 | Prec=0.8857 | Rec=0.6966 | F1=0.7799 | AUC=0.8005 | CE Loss=2.0206
#
# === Fold 10 ===
# Train Controls: 4, Train Patients: 9
# Fold 10 Epoch 1: TotalLoss=0.611197 | Sup=0.727791 | Unsup=-0.233188 | TrainAcc=0.3846
# Fold 10 Epoch 100: TotalLoss=0.584262 | Sup=0.700210 | Unsup=-0.231895 | TrainAcc=0.6923
# Fold 10 Epoch 200: TotalLoss=0.476129 | Sup=0.592669 | Unsup=-0.233080 | TrainAcc=0.6923
# Fold 10 Epoch 300: TotalLoss=0.517611 | Sup=0.634019 | Unsup=-0.232816 | TrainAcc=0.6923
# Fold 10 Epoch 400: TotalLoss=0.494619 | Sup=0.610335 | Unsup=-0.231432 | TrainAcc=0.6923
# Fold 10 Epoch 500: TotalLoss=0.227641 | Sup=0.345128 | Unsup=-0.234974 | TrainAcc=0.9231
# Fold 10 Epoch 600: TotalLoss=-0.052186 | Sup=0.108106 | Unsup=-0.320585 | TrainAcc=0.9231
# Fold 10 Epoch 700: TotalLoss=-0.186425 | Sup=0.018004 | Unsup=-0.408859 | TrainAcc=1.0000
# Fold 10 Epoch 800: TotalLoss=-0.214085 | Sup=0.004303 | Unsup=-0.436776 | TrainAcc=1.0000
# Fold 10 Epoch 900: TotalLoss=-0.217609 | Sup=0.001360 | Unsup=-0.437938 | TrainAcc=1.0000
# Fold 10 Epoch 1000: TotalLoss=-0.224143 | Sup=0.000528 | Unsup=-0.449341 | TrainAcc=1.0000
# Fold 10 Epoch 1100: TotalLoss=-0.224329 | Sup=0.000234 | Unsup=-0.449127 | TrainAcc=1.0000
# Fold 10 Epoch 1200: TotalLoss=-0.226899 | Sup=0.003298 | Unsup=-0.460395 | TrainAcc=1.0000
# Fold 10 Epoch 1300: TotalLoss=-0.228614 | Sup=0.000053 | Unsup=-0.457335 | TrainAcc=1.0000
# Fold 10 Epoch 1400: TotalLoss=-0.231814 | Sup=0.000091 | Unsup=-0.463809 | TrainAcc=1.0000
# Fold 10 Epoch 1500: TotalLoss=-0.223190 | Sup=0.000825 | Unsup=-0.448031 | TrainAcc=1.0000
# Fold 10 Epoch 1600: TotalLoss=-0.228295 | Sup=0.000042 | Unsup=-0.456674 | TrainAcc=1.0000
# Fold 10 Epoch 1700: TotalLoss=-0.228838 | Sup=0.000101 | Unsup=-0.457878 | TrainAcc=1.0000
# Fold 10 Epoch 1800: TotalLoss=-0.233093 | Sup=0.000153 | Unsup=-0.466492 | TrainAcc=1.0000
# Fold 10 Epoch 1900: TotalLoss=-0.237368 | Sup=0.000100 | Unsup=-0.474937 | TrainAcc=1.0000
# Fold 10 Epoch 2000: TotalLoss=-0.238609 | Sup=0.000038 | Unsup=-0.477294 | TrainAcc=1.0000
# Fold 10 → Acc=0.5758 | Prec=0.7463 | Rec=0.5618 | F1=0.6410 | AUC=0.6188 | CE Loss=3.0522
#
# === Fold 11 ===
# Train Controls: 4, Train Patients: 9
# Fold 11 Epoch 1: TotalLoss=0.638040 | Sup=0.754886 | Unsup=-0.233693 | TrainAcc=0.3846
# Fold 11 Epoch 100: TotalLoss=0.570388 | Sup=0.686198 | Unsup=-0.231619 | TrainAcc=0.6154
# Fold 11 Epoch 200: TotalLoss=0.176979 | Sup=0.290196 | Unsup=-0.226435 | TrainAcc=0.9231
# Fold 11 Epoch 300: TotalLoss=-0.134247 | Sup=0.043803 | Unsup=-0.356100 | TrainAcc=1.0000
# Fold 11 Epoch 400: TotalLoss=-0.188906 | Sup=0.013778 | Unsup=-0.405367 | TrainAcc=1.0000
# Fold 11 Epoch 500: TotalLoss=-0.194728 | Sup=0.017768 | Unsup=-0.424990 | TrainAcc=1.0000
# Fold 11 Epoch 600: TotalLoss=-0.214190 | Sup=0.006041 | Unsup=-0.440462 | TrainAcc=1.0000
# Fold 11 Epoch 700: TotalLoss=-0.216888 | Sup=0.008386 | Unsup=-0.450548 | TrainAcc=1.0000
# Fold 11 Epoch 800: TotalLoss=-0.223129 | Sup=0.003592 | Unsup=-0.453442 | TrainAcc=1.0000
# Fold 11 Epoch 900: TotalLoss=-0.227166 | Sup=0.002133 | Unsup=-0.458598 | TrainAcc=1.0000
# Fold 11 Epoch 1000: TotalLoss=-0.228010 | Sup=0.000271 | Unsup=-0.456563 | TrainAcc=1.0000
# Fold 11 Epoch 1100: TotalLoss=-0.234437 | Sup=0.000093 | Unsup=-0.469059 | TrainAcc=1.0000
# Fold 11 Epoch 1200: TotalLoss=-0.232689 | Sup=0.001986 | Unsup=-0.469350 | TrainAcc=1.0000
# Fold 11 Epoch 1300: TotalLoss=-0.232471 | Sup=0.000579 | Unsup=-0.466101 | TrainAcc=1.0000
# Fold 11 Epoch 1400: TotalLoss=-0.234428 | Sup=0.000019 | Unsup=-0.468893 | TrainAcc=1.0000
# Fold 11 Epoch 1500: TotalLoss=-0.234155 | Sup=0.000014 | Unsup=-0.468339 | TrainAcc=1.0000
# Fold 11 Epoch 1600: TotalLoss=-0.240143 | Sup=0.000595 | Unsup=-0.481475 | TrainAcc=1.0000
# Fold 11 Epoch 1700: TotalLoss=-0.235272 | Sup=0.000050 | Unsup=-0.470643 | TrainAcc=1.0000
# Fold 11 Epoch 1800: TotalLoss=-0.238576 | Sup=0.000112 | Unsup=-0.477376 | TrainAcc=1.0000
# Fold 11 Epoch 1900: TotalLoss=-0.242881 | Sup=0.000354 | Unsup=-0.486469 | TrainAcc=1.0000
# Fold 11 Epoch 2000: TotalLoss=-0.241934 | Sup=0.000674 | Unsup=-0.485216 | TrainAcc=1.0000
# Fold 11 → Acc=0.6439 | Prec=0.8182 | Rec=0.6067 | F1=0.6968 | AUC=0.7663 | CE Loss=2.8178
#
# === Fold 12 ===
# Train Controls: 4, Train Patients: 9
# Fold 12 Epoch 1: TotalLoss=0.578751 | Sup=0.695537 | Unsup=-0.233571 | TrainAcc=0.5385
# Fold 12 Epoch 100: TotalLoss=0.498995 | Sup=0.614923 | Unsup=-0.231856 | TrainAcc=0.6923
# Fold 12 Epoch 200: TotalLoss=0.585142 | Sup=0.700433 | Unsup=-0.230582 | TrainAcc=0.6923
# Fold 12 Epoch 300: TotalLoss=0.548970 | Sup=0.665162 | Unsup=-0.232383 | TrainAcc=0.6923
# Fold 12 Epoch 400: TotalLoss=0.518684 | Sup=0.634438 | Unsup=-0.231507 | TrainAcc=0.6923
# Fold 12 Epoch 500: TotalLoss=0.545396 | Sup=0.661612 | Unsup=-0.232431 | TrainAcc=0.6923
# Fold 12 Epoch 600: TotalLoss=0.549093 | Sup=0.665437 | Unsup=-0.232688 | TrainAcc=0.6923
# Fold 12 Epoch 700: TotalLoss=0.467640 | Sup=0.583394 | Unsup=-0.231509 | TrainAcc=0.6923
# Fold 12 Epoch 800: TotalLoss=0.554744 | Sup=0.670873 | Unsup=-0.232257 | TrainAcc=0.6923
# Fold 12 Epoch 900: TotalLoss=0.472122 | Sup=0.588244 | Unsup=-0.232244 | TrainAcc=0.6923
# Fold 12 Epoch 1000: TotalLoss=0.297226 | Sup=0.411114 | Unsup=-0.227777 | TrainAcc=0.8462
# Fold 12 Epoch 1100: TotalLoss=-0.164706 | Sup=0.027521 | Unsup=-0.384454 | TrainAcc=1.0000
# Fold 12 Epoch 1200: TotalLoss=-0.198543 | Sup=0.015446 | Unsup=-0.427977 | TrainAcc=1.0000
# Fold 12 Epoch 1300: TotalLoss=-0.214619 | Sup=0.004909 | Unsup=-0.439057 | TrainAcc=1.0000
# Fold 12 Epoch 1400: TotalLoss=-0.223579 | Sup=0.004920 | Unsup=-0.457000 | TrainAcc=1.0000
# Fold 12 Epoch 1500: TotalLoss=-0.215745 | Sup=0.013302 | Unsup=-0.458093 | TrainAcc=1.0000
# Fold 12 Epoch 1600: TotalLoss=-0.227430 | Sup=0.001502 | Unsup=-0.457863 | TrainAcc=1.0000
# Fold 12 Epoch 1700: TotalLoss=-0.226457 | Sup=0.003294 | Unsup=-0.459502 | TrainAcc=1.0000
# Fold 12 Epoch 1800: TotalLoss=-0.234320 | Sup=0.001416 | Unsup=-0.471472 | TrainAcc=1.0000
# Fold 12 Epoch 1900: TotalLoss=-0.239707 | Sup=0.000400 | Unsup=-0.480215 | TrainAcc=1.0000
# Fold 12 Epoch 2000: TotalLoss=-0.239165 | Sup=0.000969 | Unsup=-0.480268 | TrainAcc=1.0000
# Fold 12 → Acc=0.7121 | Prec=0.8806 | Rec=0.6629 | F1=0.7564 | AUC=0.7686 | CE Loss=1.9145
#
# === Fold 13 ===
# Train Controls: 4, Train Patients: 9
# Fold 13 Epoch 1: TotalLoss=0.604530 | Sup=0.721433 | Unsup=-0.233804 | TrainAcc=0.4615
# Fold 13 Epoch 100: TotalLoss=0.446340 | Sup=0.561575 | Unsup=-0.230470 | TrainAcc=0.6923
# Fold 13 Epoch 200: TotalLoss=0.376623 | Sup=0.490033 | Unsup=-0.226820 | TrainAcc=0.8462
# Fold 13 Epoch 300: TotalLoss=-0.107666 | Sup=0.066252 | Unsup=-0.347835 | TrainAcc=1.0000
# Fold 13 Epoch 400: TotalLoss=-0.179569 | Sup=0.022916 | Unsup=-0.404968 | TrainAcc=1.0000
# Fold 13 Epoch 500: TotalLoss=-0.222204 | Sup=0.007002 | Unsup=-0.458413 | TrainAcc=1.0000
# Fold 13 Epoch 600: TotalLoss=-0.189709 | Sup=0.040957 | Unsup=-0.461333 | TrainAcc=1.0000
# Fold 13 Epoch 700: TotalLoss=-0.233723 | Sup=0.001099 | Unsup=-0.469645 | TrainAcc=1.0000
# Fold 13 Epoch 800: TotalLoss=-0.235099 | Sup=0.000349 | Unsup=-0.470897 | TrainAcc=1.0000
# Fold 13 Epoch 900: TotalLoss=-0.234497 | Sup=0.003314 | Unsup=-0.475621 | TrainAcc=1.0000
# Fold 13 Epoch 1000: TotalLoss=-0.239364 | Sup=0.001488 | Unsup=-0.481703 | TrainAcc=1.0000
# Fold 13 Epoch 1100: TotalLoss=-0.228976 | Sup=0.001098 | Unsup=-0.460149 | TrainAcc=1.0000
# Fold 13 Epoch 1200: TotalLoss=-0.240845 | Sup=0.001019 | Unsup=-0.483727 | TrainAcc=1.0000
# Fold 13 Epoch 1300: TotalLoss=-0.239184 | Sup=0.000521 | Unsup=-0.479411 | TrainAcc=1.0000
# Fold 13 Epoch 1400: TotalLoss=-0.238728 | Sup=0.000767 | Unsup=-0.478992 | TrainAcc=1.0000
# Fold 13 Epoch 1500: TotalLoss=-0.241303 | Sup=0.001190 | Unsup=-0.484986 | TrainAcc=1.0000
# Fold 13 Epoch 1600: TotalLoss=-0.243052 | Sup=0.000975 | Unsup=-0.488054 | TrainAcc=1.0000
# Fold 13 Epoch 1700: TotalLoss=-0.244142 | Sup=0.000069 | Unsup=-0.488422 | TrainAcc=1.0000
# Fold 13 Epoch 1800: TotalLoss=-0.243546 | Sup=0.000367 | Unsup=-0.487825 | TrainAcc=1.0000
# Fold 13 Epoch 1900: TotalLoss=-0.243693 | Sup=0.000120 | Unsup=-0.487626 | TrainAcc=1.0000
# Fold 13 Epoch 2000: TotalLoss=-0.244260 | Sup=0.000221 | Unsup=-0.488963 | TrainAcc=1.0000
# Fold 13 → Acc=0.7424 | Prec=0.9104 | Rec=0.6854 | F1=0.7821 | AUC=0.7822 | CE Loss=2.3388
#
# === Fold 14 ===
# Train Controls: 4, Train Patients: 9
# Fold 14 Epoch 1: TotalLoss=0.570753 | Sup=0.687562 | Unsup=-0.233617 | TrainAcc=0.4615
# Fold 14 Epoch 100: TotalLoss=0.504940 | Sup=0.620360 | Unsup=-0.230839 | TrainAcc=0.6923
# Fold 14 Epoch 200: TotalLoss=0.523750 | Sup=0.639508 | Unsup=-0.231516 | TrainAcc=0.6923
# Fold 14 Epoch 300: TotalLoss=0.416910 | Sup=0.530003 | Unsup=-0.226186 | TrainAcc=0.7692
# Fold 14 Epoch 400: TotalLoss=0.041648 | Sup=0.175609 | Unsup=-0.267922 | TrainAcc=1.0000
# Fold 14 Epoch 500: TotalLoss=-0.039080 | Sup=0.145316 | Unsup=-0.368792 | TrainAcc=0.9231
# Fold 14 Epoch 600: TotalLoss=-0.203362 | Sup=0.008001 | Unsup=-0.422726 | TrainAcc=1.0000
# Fold 14 Epoch 700: TotalLoss=-0.214540 | Sup=0.001702 | Unsup=-0.432484 | TrainAcc=1.0000
# Fold 14 Epoch 800: TotalLoss=-0.215914 | Sup=0.001445 | Unsup=-0.434718 | TrainAcc=1.0000
# Fold 14 Epoch 900: TotalLoss=-0.226834 | Sup=0.000401 | Unsup=-0.454470 | TrainAcc=1.0000
# Fold 14 Epoch 1000: TotalLoss=-0.225100 | Sup=0.000534 | Unsup=-0.451267 | TrainAcc=1.0000
# Fold 14 Epoch 1100: TotalLoss=-0.228275 | Sup=0.000644 | Unsup=-0.457837 | TrainAcc=1.0000
# Fold 14 Epoch 1200: TotalLoss=-0.230417 | Sup=0.000423 | Unsup=-0.461679 | TrainAcc=1.0000
# Fold 14 Epoch 1300: TotalLoss=-0.228066 | Sup=0.000247 | Unsup=-0.456626 | TrainAcc=1.0000
# Fold 14 Epoch 1400: TotalLoss=-0.232929 | Sup=0.000906 | Unsup=-0.467670 | TrainAcc=1.0000
# Fold 14 Epoch 1500: TotalLoss=-0.234407 | Sup=0.000096 | Unsup=-0.469006 | TrainAcc=1.0000
# Fold 14 Epoch 1600: TotalLoss=-0.235454 | Sup=0.000059 | Unsup=-0.471025 | TrainAcc=1.0000
# Fold 14 Epoch 1700: TotalLoss=-0.238843 | Sup=0.000591 | Unsup=-0.478868 | TrainAcc=1.0000
# Fold 14 Epoch 1800: TotalLoss=-0.239162 | Sup=0.000153 | Unsup=-0.478630 | TrainAcc=1.0000
# Fold 14 Epoch 1900: TotalLoss=-0.237944 | Sup=0.001195 | Unsup=-0.478278 | TrainAcc=1.0000
# Fold 14 Epoch 2000: TotalLoss=-0.238819 | Sup=0.000054 | Unsup=-0.477746 | TrainAcc=1.0000
# Fold 14 → Acc=0.6288 | Prec=0.8226 | Rec=0.5730 | F1=0.6755 | AUC=0.7584 | CE Loss=2.5895
#
# === Fold 15 ===
# Train Controls: 4, Train Patients: 9
# Fold 15 Epoch 1: TotalLoss=0.587648 | Sup=0.704430 | Unsup=-0.233564 | TrainAcc=0.4615
# Fold 15 Epoch 100: TotalLoss=0.486175 | Sup=0.601760 | Unsup=-0.231169 | TrainAcc=0.6923
# Fold 15 Epoch 200: TotalLoss=0.228727 | Sup=0.338709 | Unsup=-0.219965 | TrainAcc=0.8462
# Fold 15 Epoch 300: TotalLoss=0.078177 | Sup=0.195767 | Unsup=-0.235180 | TrainAcc=0.9231
# Fold 15 Epoch 400: TotalLoss=-0.143187 | Sup=0.035804 | Unsup=-0.357981 | TrainAcc=1.0000
# Fold 15 Epoch 500: TotalLoss=-0.155279 | Sup=0.052273 | Unsup=-0.415105 | TrainAcc=1.0000
# Fold 15 Epoch 600: TotalLoss=-0.217298 | Sup=0.004775 | Unsup=-0.444148 | TrainAcc=1.0000
# Fold 15 Epoch 700: TotalLoss=-0.224970 | Sup=0.000576 | Unsup=-0.451091 | TrainAcc=1.0000
# Fold 15 Epoch 800: TotalLoss=-0.214827 | Sup=0.006375 | Unsup=-0.442403 | TrainAcc=1.0000
# Fold 15 Epoch 900: TotalLoss=-0.213109 | Sup=0.013413 | Unsup=-0.453044 | TrainAcc=1.0000
# Fold 15 Epoch 1000: TotalLoss=-0.230818 | Sup=0.000115 | Unsup=-0.461866 | TrainAcc=1.0000
# Fold 15 Epoch 1100: TotalLoss=-0.234311 | Sup=0.000236 | Unsup=-0.469093 | TrainAcc=1.0000
# Fold 15 Epoch 1200: TotalLoss=-0.233440 | Sup=0.000131 | Unsup=-0.467143 | TrainAcc=1.0000
# Fold 15 Epoch 1300: TotalLoss=-0.228587 | Sup=0.000066 | Unsup=-0.457305 | TrainAcc=1.0000
# Fold 15 Epoch 1400: TotalLoss=-0.238644 | Sup=0.000008 | Unsup=-0.477304 | TrainAcc=1.0000
# Fold 15 Epoch 1500: TotalLoss=-0.239466 | Sup=0.000048 | Unsup=-0.479028 | TrainAcc=1.0000
# Fold 15 Epoch 1600: TotalLoss=-0.233109 | Sup=0.003234 | Unsup=-0.472685 | TrainAcc=1.0000
# Fold 15 Epoch 1700: TotalLoss=-0.240969 | Sup=0.000155 | Unsup=-0.482247 | TrainAcc=1.0000
# Fold 15 Epoch 1800: TotalLoss=-0.239378 | Sup=0.000009 | Unsup=-0.478773 | TrainAcc=1.0000
# Fold 15 Epoch 1900: TotalLoss=-0.153309 | Sup=0.088585 | Unsup=-0.483788 | TrainAcc=0.9231
# Fold 15 Epoch 2000: TotalLoss=-0.238243 | Sup=0.000147 | Unsup=-0.476780 | TrainAcc=1.0000
# Fold 15 → Acc=0.7121 | Prec=0.9048 | Rec=0.6404 | F1=0.7500 | AUC=0.8236 | CE Loss=2.1573
#
# === Fold 16 ===
# Train Controls: 4, Train Patients: 9
# Fold 16 Epoch 1: TotalLoss=0.543289 | Sup=0.660169 | Unsup=-0.233761 | TrainAcc=0.6154
# Fold 16 Epoch 100: TotalLoss=0.531258 | Sup=0.647101 | Unsup=-0.231687 | TrainAcc=0.6154
# Fold 16 Epoch 200: TotalLoss=0.283746 | Sup=0.397941 | Unsup=-0.228390 | TrainAcc=0.9231
# Fold 16 Epoch 300: TotalLoss=-0.103367 | Sup=0.080140 | Unsup=-0.367013 | TrainAcc=1.0000
# Fold 16 Epoch 400: TotalLoss=-0.204427 | Sup=0.007303 | Unsup=-0.423460 | TrainAcc=1.0000
# Fold 16 Epoch 500: TotalLoss=-0.219561 | Sup=0.003327 | Unsup=-0.445776 | TrainAcc=1.0000
# Fold 16 Epoch 600: TotalLoss=-0.219105 | Sup=0.003879 | Unsup=-0.445968 | TrainAcc=1.0000
# Fold 16 Epoch 700: TotalLoss=-0.228245 | Sup=0.000913 | Unsup=-0.458318 | TrainAcc=1.0000
# Fold 16 Epoch 800: TotalLoss=-0.230920 | Sup=0.001598 | Unsup=-0.465034 | TrainAcc=1.0000
# Fold 16 Epoch 900: TotalLoss=-0.233548 | Sup=0.000950 | Unsup=-0.468996 | TrainAcc=1.0000
# Fold 16 Epoch 1000: TotalLoss=-0.237782 | Sup=0.000066 | Unsup=-0.475695 | TrainAcc=1.0000
# Fold 16 Epoch 1100: TotalLoss=-0.233660 | Sup=0.000176 | Unsup=-0.467671 | TrainAcc=1.0000
# Fold 16 Epoch 1200: TotalLoss=-0.236518 | Sup=0.000375 | Unsup=-0.473786 | TrainAcc=1.0000
# Fold 16 Epoch 1300: TotalLoss=-0.236643 | Sup=0.000097 | Unsup=-0.473480 | TrainAcc=1.0000
# Fold 16 Epoch 1400: TotalLoss=-0.235163 | Sup=0.000058 | Unsup=-0.470442 | TrainAcc=1.0000
# Fold 16 Epoch 1500: TotalLoss=-0.231488 | Sup=0.000017 | Unsup=-0.463010 | TrainAcc=1.0000
# Fold 16 Epoch 1600: TotalLoss=-0.236876 | Sup=0.000033 | Unsup=-0.473817 | TrainAcc=1.0000
# Fold 16 Epoch 1700: TotalLoss=-0.237981 | Sup=0.000646 | Unsup=-0.477255 | TrainAcc=1.0000
# Fold 16 Epoch 1800: TotalLoss=-0.237599 | Sup=0.000084 | Unsup=-0.475365 | TrainAcc=1.0000
# Fold 16 Epoch 1900: TotalLoss=-0.243009 | Sup=0.000672 | Unsup=-0.487362 | TrainAcc=1.0000
# Fold 16 Epoch 2000: TotalLoss=-0.244430 | Sup=0.000130 | Unsup=-0.489121 | TrainAcc=1.0000
# Fold 16 → Acc=0.6667 | Prec=0.8261 | Rec=0.6404 | F1=0.7215 | AUC=0.7665 | CE Loss=2.7531
#
# === Fold 17 ===
# Train Controls: 4, Train Patients: 9
# Fold 17 Epoch 1: TotalLoss=0.554826 | Sup=0.671747 | Unsup=-0.233842 | TrainAcc=0.6923
# Fold 17 Epoch 100: TotalLoss=0.559232 | Sup=0.673819 | Unsup=-0.229175 | TrainAcc=0.7692
# Fold 17 Epoch 200: TotalLoss=0.131590 | Sup=0.259566 | Unsup=-0.255951 | TrainAcc=0.9231
# Fold 17 Epoch 300: TotalLoss=-0.143427 | Sup=0.049484 | Unsup=-0.385823 | TrainAcc=1.0000
# Fold 17 Epoch 400: TotalLoss=-0.208671 | Sup=0.007800 | Unsup=-0.432941 | TrainAcc=1.0000
# Fold 17 Epoch 500: TotalLoss=-0.216779 | Sup=0.002323 | Unsup=-0.438206 | TrainAcc=1.0000
# Fold 17 Epoch 600: TotalLoss=-0.221010 | Sup=0.004191 | Unsup=-0.450401 | TrainAcc=1.0000
# Fold 17 Epoch 700: TotalLoss=-0.221794 | Sup=0.004440 | Unsup=-0.452469 | TrainAcc=1.0000
# Fold 17 Epoch 800: TotalLoss=-0.229654 | Sup=0.000204 | Unsup=-0.459717 | TrainAcc=1.0000
# Fold 17 Epoch 900: TotalLoss=-0.226826 | Sup=0.001473 | Unsup=-0.456598 | TrainAcc=1.0000
# Fold 17 Epoch 1000: TotalLoss=-0.235519 | Sup=0.002948 | Unsup=-0.476933 | TrainAcc=1.0000
# Fold 17 Epoch 1100: TotalLoss=-0.233394 | Sup=0.000625 | Unsup=-0.468038 | TrainAcc=1.0000
# Fold 17 Epoch 1200: TotalLoss=-0.235365 | Sup=0.000143 | Unsup=-0.471015 | TrainAcc=1.0000
# Fold 17 Epoch 1300: TotalLoss=-0.240697 | Sup=0.000069 | Unsup=-0.481532 | TrainAcc=1.0000
# Fold 17 Epoch 1400: TotalLoss=-0.235304 | Sup=0.000228 | Unsup=-0.471065 | TrainAcc=1.0000
# Fold 17 Epoch 1500: TotalLoss=-0.236419 | Sup=0.000038 | Unsup=-0.472914 | TrainAcc=1.0000
# Fold 17 Epoch 1600: TotalLoss=-0.233055 | Sup=0.000164 | Unsup=-0.466438 | TrainAcc=1.0000
# Fold 17 Epoch 1700: TotalLoss=-0.238869 | Sup=0.000036 | Unsup=-0.477810 | TrainAcc=1.0000
# Fold 17 Epoch 1800: TotalLoss=-0.242018 | Sup=0.000036 | Unsup=-0.484110 | TrainAcc=1.0000
# Fold 17 Epoch 1900: TotalLoss=-0.243287 | Sup=0.000094 | Unsup=-0.486762 | TrainAcc=1.0000
# Fold 17 Epoch 2000: TotalLoss=-0.240165 | Sup=0.000006 | Unsup=-0.480341 | TrainAcc=1.0000
# Fold 17 → Acc=0.7273 | Prec=0.8841 | Rec=0.6854 | F1=0.7722 | AUC=0.8393 | CE Loss=2.1553
#
# === Fold 18 ===
# Train Controls: 4, Train Patients: 9
# Fold 18 Epoch 1: TotalLoss=0.519670 | Sup=0.636575 | Unsup=-0.233810 | TrainAcc=0.8462
# Fold 18 Epoch 100: TotalLoss=0.502042 | Sup=0.617242 | Unsup=-0.230401 | TrainAcc=0.6923
# Fold 18 Epoch 200: TotalLoss=0.481878 | Sup=0.597006 | Unsup=-0.230256 | TrainAcc=0.6923
# Fold 18 Epoch 300: TotalLoss=0.404806 | Sup=0.518512 | Unsup=-0.227411 | TrainAcc=0.6923
# Fold 18 Epoch 400: TotalLoss=0.005052 | Sup=0.135200 | Unsup=-0.260297 | TrainAcc=1.0000
# Fold 18 Epoch 500: TotalLoss=-0.149194 | Sup=0.033113 | Unsup=-0.364614 | TrainAcc=1.0000
# Fold 18 Epoch 600: TotalLoss=-0.158466 | Sup=0.040463 | Unsup=-0.397857 | TrainAcc=1.0000
# Fold 18 Epoch 700: TotalLoss=-0.201554 | Sup=0.013486 | Unsup=-0.430081 | TrainAcc=1.0000
# Fold 18 Epoch 800: TotalLoss=-0.218492 | Sup=0.002177 | Unsup=-0.441338 | TrainAcc=1.0000
# Fold 18 Epoch 900: TotalLoss=-0.216629 | Sup=0.002518 | Unsup=-0.438294 | TrainAcc=1.0000
# Fold 18 Epoch 1000: TotalLoss=-0.224015 | Sup=0.001753 | Unsup=-0.451537 | TrainAcc=1.0000
# Fold 18 Epoch 1100: TotalLoss=-0.223556 | Sup=0.006701 | Unsup=-0.460514 | TrainAcc=1.0000
# Fold 18 Epoch 1200: TotalLoss=-0.233790 | Sup=0.000183 | Unsup=-0.467946 | TrainAcc=1.0000
# Fold 18 Epoch 1300: TotalLoss=-0.225539 | Sup=0.005073 | Unsup=-0.461223 | TrainAcc=1.0000
# Fold 18 Epoch 1400: TotalLoss=-0.229318 | Sup=0.000171 | Unsup=-0.458979 | TrainAcc=1.0000
# Fold 18 Epoch 1500: TotalLoss=-0.235445 | Sup=0.001294 | Unsup=-0.473478 | TrainAcc=1.0000
# Fold 18 Epoch 1600: TotalLoss=-0.237233 | Sup=0.000378 | Unsup=-0.475223 | TrainAcc=1.0000
# Fold 18 Epoch 1700: TotalLoss=-0.239610 | Sup=0.000161 | Unsup=-0.479543 | TrainAcc=1.0000
# Fold 18 Epoch 1800: TotalLoss=-0.240805 | Sup=0.000305 | Unsup=-0.482220 | TrainAcc=1.0000
# Fold 18 Epoch 1900: TotalLoss=-0.241857 | Sup=0.000297 | Unsup=-0.484309 | TrainAcc=1.0000
# Fold 18 Epoch 2000: TotalLoss=-0.240573 | Sup=0.000103 | Unsup=-0.481353 | TrainAcc=1.0000
# Fold 18 → Acc=0.6061 | Prec=0.7846 | Rec=0.5730 | F1=0.6623 | AUC=0.7049 | CE Loss=2.7860
#
# === Fold 19 ===
# Train Controls: 4, Train Patients: 9
# Fold 19 Epoch 1: TotalLoss=0.544944 | Sup=0.661709 | Unsup=-0.233530 | TrainAcc=0.6923
# Fold 19 Epoch 100: TotalLoss=0.441750 | Sup=0.556950 | Unsup=-0.230400 | TrainAcc=0.7692
# Fold 19 Epoch 200: TotalLoss=0.089793 | Sup=0.207531 | Unsup=-0.235478 | TrainAcc=1.0000
# Fold 19 Epoch 300: TotalLoss=-0.169093 | Sup=0.016554 | Unsup=-0.371293 | TrainAcc=1.0000
# Fold 19 Epoch 400: TotalLoss=-0.193397 | Sup=0.008406 | Unsup=-0.403607 | TrainAcc=1.0000
# Fold 19 Epoch 500: TotalLoss=-0.177748 | Sup=0.033445 | Unsup=-0.422386 | TrainAcc=1.0000
# Fold 19 Epoch 600: TotalLoss=-0.221792 | Sup=0.000172 | Unsup=-0.443928 | TrainAcc=1.0000
# Fold 19 Epoch 700: TotalLoss=-0.226038 | Sup=0.000110 | Unsup=-0.452295 | TrainAcc=1.0000
# Fold 19 Epoch 800: TotalLoss=-0.226364 | Sup=0.000747 | Unsup=-0.454223 | TrainAcc=1.0000
# Fold 19 Epoch 900: TotalLoss=-0.231184 | Sup=0.000219 | Unsup=-0.462807 | TrainAcc=1.0000
# Fold 19 Epoch 1000: TotalLoss=-0.232260 | Sup=0.000179 | Unsup=-0.464878 | TrainAcc=1.0000
# Fold 19 Epoch 1100: TotalLoss=-0.238874 | Sup=0.000349 | Unsup=-0.478446 | TrainAcc=1.0000
# Fold 19 Epoch 1200: TotalLoss=-0.234053 | Sup=0.000167 | Unsup=-0.468440 | TrainAcc=1.0000
# Fold 19 Epoch 1300: TotalLoss=-0.236218 | Sup=0.000479 | Unsup=-0.473395 | TrainAcc=1.0000
# Fold 19 Epoch 1400: TotalLoss=-0.235180 | Sup=0.000025 | Unsup=-0.470409 | TrainAcc=1.0000
# Fold 19 Epoch 1500: TotalLoss=-0.238653 | Sup=0.000054 | Unsup=-0.477415 | TrainAcc=1.0000
# Fold 19 Epoch 1600: TotalLoss=-0.241802 | Sup=0.000009 | Unsup=-0.483622 | TrainAcc=1.0000
# Fold 19 Epoch 1700: TotalLoss=-0.242203 | Sup=0.000010 | Unsup=-0.484426 | TrainAcc=1.0000
# Fold 19 Epoch 1800: TotalLoss=-0.238264 | Sup=0.000126 | Unsup=-0.476780 | TrainAcc=1.0000
# Fold 19 Epoch 1900: TotalLoss=-0.242567 | Sup=0.000042 | Unsup=-0.485218 | TrainAcc=1.0000
# Fold 19 Epoch 2000: TotalLoss=-0.242009 | Sup=0.000647 | Unsup=-0.485313 | TrainAcc=1.0000
# Fold 19 → Acc=0.7121 | Prec=0.8806 | Rec=0.6629 | F1=0.7564 | AUC=0.8248 | CE Loss=2.2089
#
# === Fold 20 ===
# Train Controls: 4, Train Patients: 9
# Fold 20 Epoch 1: TotalLoss=0.613692 | Sup=0.730611 | Unsup=-0.233837 | TrainAcc=0.3846
# Fold 20 Epoch 100: TotalLoss=0.392658 | Sup=0.507408 | Unsup=-0.229500 | TrainAcc=0.7692
# Fold 20 Epoch 200: TotalLoss=0.098459 | Sup=0.215236 | Unsup=-0.233555 | TrainAcc=1.0000
# Fold 20 Epoch 300: TotalLoss=-0.099480 | Sup=0.061200 | Unsup=-0.321360 | TrainAcc=1.0000
# Fold 20 Epoch 400: TotalLoss=-0.093278 | Sup=0.111107 | Unsup=-0.408769 | TrainAcc=0.9231
# Fold 20 Epoch 500: TotalLoss=-0.216113 | Sup=0.001125 | Unsup=-0.434478 | TrainAcc=1.0000
# Fold 20 Epoch 600: TotalLoss=-0.195547 | Sup=0.018412 | Unsup=-0.427918 | TrainAcc=1.0000
# Fold 20 Epoch 700: TotalLoss=-0.214038 | Sup=0.004973 | Unsup=-0.438022 | TrainAcc=1.0000
# Fold 20 Epoch 800: TotalLoss=-0.228293 | Sup=0.000803 | Unsup=-0.458191 | TrainAcc=1.0000
# Fold 20 Epoch 900: TotalLoss=-0.228977 | Sup=0.000439 | Unsup=-0.458831 | TrainAcc=1.0000
# Fold 20 Epoch 1000: TotalLoss=-0.232729 | Sup=0.000134 | Unsup=-0.465727 | TrainAcc=1.0000
# Fold 20 Epoch 1100: TotalLoss=-0.236730 | Sup=0.000012 | Unsup=-0.473483 | TrainAcc=1.0000
# Fold 20 Epoch 1200: TotalLoss=-0.235559 | Sup=0.000087 | Unsup=-0.471291 | TrainAcc=1.0000
# Fold 20 Epoch 1300: TotalLoss=-0.234388 | Sup=0.000065 | Unsup=-0.468904 | TrainAcc=1.0000
# Fold 20 Epoch 1400: TotalLoss=-0.226642 | Sup=0.000098 | Unsup=-0.453479 | TrainAcc=1.0000
# Fold 20 Epoch 1500: TotalLoss=-0.227601 | Sup=0.000038 | Unsup=-0.455278 | TrainAcc=1.0000
# Fold 20 Epoch 1600: TotalLoss=-0.241371 | Sup=0.000034 | Unsup=-0.482811 | TrainAcc=1.0000
# Fold 20 Epoch 1700: TotalLoss=-0.239670 | Sup=0.000070 | Unsup=-0.479478 | TrainAcc=1.0000
# Fold 20 Epoch 1800: TotalLoss=-0.238513 | Sup=0.000004 | Unsup=-0.477036 | TrainAcc=1.0000
# Fold 20 Epoch 1900: TotalLoss=-0.242189 | Sup=0.000001 | Unsup=-0.484380 | TrainAcc=1.0000
# Fold 20 Epoch 2000: TotalLoss=-0.242100 | Sup=0.000004 | Unsup=-0.484207 | TrainAcc=1.0000
# Fold 20 → Acc=0.6818 | Prec=0.8615 | Rec=0.6292 | F1=0.7273 | AUC=0.7923 | CE Loss=2.6540
#
# === Average Results Across 20 Folds (Controls vs Patients) ===
# Accuracy:  0.6818 ± 0.0514
# Precision: 0.8559 ± 0.0489
# Recall:    0.6348 ± 0.0437
# F1-score:  0.7288 ± 0.0452
# AUC:       0.7794 ± 0.0571
# CE Loss:   2.3985 ± 0.4182
