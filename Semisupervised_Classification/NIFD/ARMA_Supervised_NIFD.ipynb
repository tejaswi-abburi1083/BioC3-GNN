# %%
import torch
import torch.nn as nn
import torch.nn.functional as nnFn
import torch.optim as optim
import numpy as np
import random
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from torch_geometric.data import Data
from torch_geometric.nn import ARMAConv
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, roc_auc_score, log_loss
)

# %%
# === Load Patients ===
fa_patients_path = "/home/snu/Downloads/NIFD_Patients_FA_Histogram_Feature.npy"
Patients_FA_array = np.load(fa_patients_path, allow_pickle=True)

# === Load Controls ===
fa_controls_path = "/home/snu/Downloads/NIFD_Control_FA_Histogram_Feature.npy"
Controls_FA_array = np.load(fa_controls_path, allow_pickle=True)

print("Patients Shape:", Patients_FA_array.shape)
print("Controls Shape:", Controls_FA_array.shape)

# === Combine features and labels ===
X = np.vstack([Controls_FA_array, Patients_FA_array])
y = np.hstack([
    np.zeros(Controls_FA_array.shape[0], dtype=np.int64),  # 0 = Control
    np.ones(Patients_FA_array.shape[0], dtype=np.int64)    # 1 = Patient
])

# Shuffle
np.random.seed(42)
perm = np.random.permutation(X.shape[0])
X = X[perm]
y = y[perm]
# Out:
# Patients Shape: (98, 180)
# Controls Shape: (48, 180)

# %%
class ARMA_Supervised(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, activ="SELU"):
        super(ARMA_Supervised, self).__init__()
        self.conv1 = ARMAConv(input_dim, hidden_dim, num_stacks=1, num_layers=1)
        self.bn1 = nn.BatchNorm1d(hidden_dim)
        self.dropout = nn.Dropout(0.2)
        self.fc = nn.Linear(hidden_dim, output_dim)

        activations = {
            "SELU": nnFn.selu,
            "SiLU": nnFn.silu,
            "GELU": nnFn.gelu,
            "RELU": nnFn.relu,
            "ELU": nnFn.elu
        }
        self.act = activations.get(activ, nnFn.elu)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x_in = x

        # ARMA layer
        x = self.conv1(x, edge_index)
        x = self.bn1(x)

        # Residual connection (if dimensions match)
        if x_in.shape[1] == x.shape[1]:
            x = x + x_in

        x = self.act(x)
        x = self.dropout(x)
        logits = self.fc(x)
        return logits

# %%
def create_adj(F, alpha=1):
    F_norm = F / np.linalg.norm(F, axis=1, keepdims=True)
    W = np.dot(F_norm, F_norm.T)
    W = np.where(W >= alpha, 1, 0).astype(np.float32)
    W = W / W.max()
    return W

def load_data(adj, node_feats):
    node_feats = torch.from_numpy(node_feats).float()
    edge_index = torch.from_numpy(np.array(np.nonzero((adj > 0))))
    return Data(x=node_feats, edge_index=edge_index)

# %%
num_nodes, num_feats = X.shape
print(f"Number of features: {num_feats}")
# Out:
# Number of features: 180

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
alpha = 0.5
feats_dim = num_feats
hidden_dim = 512
num_classes = 2
num_epochs = 2000
lr = 0.0001
weight_decay = 1e-4
batch_print_freq = 100

# %%
W = create_adj(X, alpha)
data = load_data(W, X).to(device)
A_tensor = torch.from_numpy(W).float().to(device)
print(data)
# Out:
# Data(x=[146, 180], edge_index=[2, 21256])

# %%
sss = StratifiedShuffleSplit(n_splits=20, test_size=0.9, random_state=42)

accuracies, precisions, recalls, f1_scores, aucs, ce_losses = [], [], [], [], [], []

for fold, (train_idx, test_idx) in enumerate(sss.split(X, y), start=1):
    print(f"\n=== Fold {fold} ===")

    train_idx_t = torch.from_numpy(train_idx).long().to(device)
    y_train_tensor = torch.from_numpy(y[train_idx]).long().to(device)

    model = ARMA_Supervised(feats_dim, hidden_dim, num_classes, "SELU").to(device)
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    ce_loss = nn.CrossEntropyLoss()


    for epoch in range(1, num_epochs + 1):
        model.train()
        optimizer.zero_grad()

        logits = model(data)
        loss = ce_loss(logits[train_idx_t], y_train_tensor)
        loss.backward()
        optimizer.step()

        if epoch % batch_print_freq == 0 or epoch == 1:
            model.eval()
            with torch.no_grad():
                preds_train = logits[train_idx_t].argmax(dim=1)
                acc_train = accuracy_score(y_train_tensor.cpu(), preds_train.cpu())
            print(f"Fold {fold} Epoch {epoch}: "
                  f"Loss={loss.item():.6f} | TrainAcc={acc_train:.4f}")


    model.eval()
    with torch.no_grad():
        out = model(data)
        preds = out.argmax(dim=1).cpu().numpy()
        probs = torch.softmax(out, dim=1)[:, 1].cpu().numpy()  # Probability for class 1

    y_test = y[test_idx]
    y_pred_test = preds[test_idx]
    y_prob_test = probs[test_idx]


    acc = accuracy_score(y_test, y_pred_test)
    prec = precision_score(y_test, y_pred_test, zero_division=0)
    rec = recall_score(y_test, y_pred_test, zero_division=0)
    f1 = f1_score(y_test, y_pred_test, zero_division=0)
    auc = roc_auc_score(y_test, y_prob_test)
    ce = log_loss(y_test, y_prob_test)

    accuracies.append(acc)
    precisions.append(prec)
    recalls.append(rec)
    f1_scores.append(f1)
    aucs.append(auc)
    ce_losses.append(ce)

    print(f"Fold {fold} → "
          f"Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | "
          f"F1={f1:.4f} | AUC={auc:.4f} | CE Loss={ce:.4f}")


print("\n=== Average Results Across 20 Folds ===")
print(f"Accuracy:  {np.mean(accuracies):.4f} ± {np.std(accuracies):.4f}")
print(f"Precision: {np.mean(precisions):.4f} ± {np.std(precisions):.4f}")
print(f"Recall:    {np.mean(recalls):.4f} ± {np.std(recalls):.4f}")
print(f"F1-score:  {np.mean(f1_scores):.4f} ± {np.std(f1_scores):.4f}")
print(f"CE Loss:   {np.mean(ce_losses):.4f} ± {np.std(ce_losses):.4f}")
print(f"AUC:       {np.mean(aucs):.4f} ± {np.std(aucs):.4f}")
# Out:
# === Fold 1 ===
# Fold 1 Epoch 1: Loss=0.763262 | TrainAcc=0.3571
# Fold 1 Epoch 100: Loss=0.034102 | TrainAcc=1.0000
# Fold 1 Epoch 200: Loss=0.008362 | TrainAcc=1.0000
# Fold 1 Epoch 300: Loss=0.005416 | TrainAcc=1.0000
# Fold 1 Epoch 400: Loss=0.001872 | TrainAcc=1.0000
# Fold 1 Epoch 500: Loss=0.001305 | TrainAcc=1.0000
# Fold 1 Epoch 600: Loss=0.001034 | TrainAcc=1.0000
# Fold 1 Epoch 700: Loss=0.000682 | TrainAcc=1.0000
# Fold 1 Epoch 800: Loss=0.000329 | TrainAcc=1.0000
# Fold 1 Epoch 900: Loss=0.000266 | TrainAcc=1.0000
# Fold 1 Epoch 1000: Loss=0.000188 | TrainAcc=1.0000
# Fold 1 Epoch 1100: Loss=0.000221 | TrainAcc=1.0000
# Fold 1 Epoch 1200: Loss=0.000155 | TrainAcc=1.0000
# Fold 1 Epoch 1300: Loss=0.000095 | TrainAcc=1.0000
# Fold 1 Epoch 1400: Loss=0.000076 | TrainAcc=1.0000
# Fold 1 Epoch 1500: Loss=0.000088 | TrainAcc=1.0000
# Fold 1 Epoch 1600: Loss=0.000035 | TrainAcc=1.0000
# Fold 1 Epoch 1700: Loss=0.000034 | TrainAcc=1.0000
# Fold 1 Epoch 1800: Loss=0.000025 | TrainAcc=1.0000
# Fold 1 Epoch 1900: Loss=0.000024 | TrainAcc=1.0000
# Fold 1 Epoch 2000: Loss=0.000026 | TrainAcc=1.0000
# Fold 1 → Acc=0.5985 | Prec=0.7500 | Rec=0.6067 | F1=0.6708 | AUC=0.6849 | CE Loss=1.0523
#
# === Fold 2 ===
# Fold 2 Epoch 1: Loss=0.652193 | TrainAcc=0.6429
# Fold 2 Epoch 100: Loss=0.022926 | TrainAcc=1.0000
# Fold 2 Epoch 200: Loss=0.005714 | TrainAcc=1.0000
# Fold 2 Epoch 300: Loss=0.002868 | TrainAcc=1.0000
# Fold 2 Epoch 400: Loss=0.001200 | TrainAcc=1.0000
# Fold 2 Epoch 500: Loss=0.000634 | TrainAcc=1.0000
# Fold 2 Epoch 600: Loss=0.000468 | TrainAcc=1.0000
# Fold 2 Epoch 700: Loss=0.000274 | TrainAcc=1.0000
# Fold 2 Epoch 800: Loss=0.000113 | TrainAcc=1.0000
# Fold 2 Epoch 900: Loss=0.000141 | TrainAcc=1.0000
# Fold 2 Epoch 1000: Loss=0.000055 | TrainAcc=1.0000
# Fold 2 Epoch 1100: Loss=0.000038 | TrainAcc=1.0000
# Fold 2 Epoch 1200: Loss=0.000031 | TrainAcc=1.0000
# Fold 2 Epoch 1300: Loss=0.000023 | TrainAcc=1.0000
# Fold 2 Epoch 1400: Loss=0.000041 | TrainAcc=1.0000
# Fold 2 Epoch 1500: Loss=0.000022 | TrainAcc=1.0000
# Fold 2 Epoch 1600: Loss=0.000024 | TrainAcc=1.0000
# Fold 2 Epoch 1700: Loss=0.000012 | TrainAcc=1.0000
# Fold 2 Epoch 1800: Loss=0.000006 | TrainAcc=1.0000
# Fold 2 Epoch 1900: Loss=0.000012 | TrainAcc=1.0000
# Fold 2 Epoch 2000: Loss=0.000012 | TrainAcc=1.0000
# Fold 2 → Acc=0.6288 | Prec=0.7857 | Rec=0.6180 | F1=0.6918 | AUC=0.7358 | CE Loss=0.9632
#
# === Fold 3 ===
# Fold 3 Epoch 1: Loss=0.725567 | TrainAcc=0.4286
# Fold 3 Epoch 100: Loss=0.039318 | TrainAcc=1.0000
# Fold 3 Epoch 200: Loss=0.008569 | TrainAcc=1.0000
# Fold 3 Epoch 300: Loss=0.003817 | TrainAcc=1.0000
# Fold 3 Epoch 400: Loss=0.001332 | TrainAcc=1.0000
# Fold 3 Epoch 500: Loss=0.001115 | TrainAcc=1.0000
# Fold 3 Epoch 600: Loss=0.000918 | TrainAcc=1.0000
# Fold 3 Epoch 700: Loss=0.000386 | TrainAcc=1.0000
# Fold 3 Epoch 800: Loss=0.000358 | TrainAcc=1.0000
# Fold 3 Epoch 900: Loss=0.000199 | TrainAcc=1.0000
# Fold 3 Epoch 1000: Loss=0.000191 | TrainAcc=1.0000
# Fold 3 Epoch 1100: Loss=0.000130 | TrainAcc=1.0000
# Fold 3 Epoch 1200: Loss=0.000121 | TrainAcc=1.0000
# Fold 3 Epoch 1300: Loss=0.000049 | TrainAcc=1.0000
# Fold 3 Epoch 1400: Loss=0.000066 | TrainAcc=1.0000
# Fold 3 Epoch 1500: Loss=0.000065 | TrainAcc=1.0000
# Fold 3 Epoch 1600: Loss=0.000024 | TrainAcc=1.0000
# Fold 3 Epoch 1700: Loss=0.000022 | TrainAcc=1.0000
# Fold 3 Epoch 1800: Loss=0.000023 | TrainAcc=1.0000
# Fold 3 Epoch 1900: Loss=0.000026 | TrainAcc=1.0000
# Fold 3 Epoch 2000: Loss=0.000013 | TrainAcc=1.0000
# Fold 3 → Acc=0.6288 | Prec=0.7564 | Rec=0.6629 | F1=0.7066 | AUC=0.6389 | CE Loss=1.1562
#
# === Fold 4 ===
# Fold 4 Epoch 1: Loss=0.651655 | TrainAcc=0.5714
# Fold 4 Epoch 100: Loss=0.016112 | TrainAcc=1.0000
# Fold 4 Epoch 200: Loss=0.004875 | TrainAcc=1.0000
# Fold 4 Epoch 300: Loss=0.002588 | TrainAcc=1.0000
# Fold 4 Epoch 400: Loss=0.001811 | TrainAcc=1.0000
# Fold 4 Epoch 500: Loss=0.000917 | TrainAcc=1.0000
# Fold 4 Epoch 600: Loss=0.000572 | TrainAcc=1.0000
# Fold 4 Epoch 700: Loss=0.000291 | TrainAcc=1.0000
# Fold 4 Epoch 800: Loss=0.000211 | TrainAcc=1.0000
# Fold 4 Epoch 900: Loss=0.000134 | TrainAcc=1.0000
# Fold 4 Epoch 1000: Loss=0.000098 | TrainAcc=1.0000
# Fold 4 Epoch 1100: Loss=0.000058 | TrainAcc=1.0000
# Fold 4 Epoch 1200: Loss=0.000059 | TrainAcc=1.0000
# Fold 4 Epoch 1300: Loss=0.000061 | TrainAcc=1.0000
# Fold 4 Epoch 1400: Loss=0.000044 | TrainAcc=1.0000
# Fold 4 Epoch 1500: Loss=0.000029 | TrainAcc=1.0000
# Fold 4 Epoch 1600: Loss=0.000021 | TrainAcc=1.0000
# Fold 4 Epoch 1700: Loss=0.000018 | TrainAcc=1.0000
# Fold 4 Epoch 1800: Loss=0.000025 | TrainAcc=1.0000
# Fold 4 Epoch 1900: Loss=0.000021 | TrainAcc=1.0000
# Fold 4 Epoch 2000: Loss=0.000019 | TrainAcc=1.0000
# Fold 4 → Acc=0.6364 | Prec=0.8361 | Rec=0.5730 | F1=0.6800 | AUC=0.7565 | CE Loss=0.9818
#
# === Fold 5 ===
# Fold 5 Epoch 1: Loss=0.617970 | TrainAcc=0.6429
# Fold 5 Epoch 100: Loss=0.019407 | TrainAcc=1.0000
# Fold 5 Epoch 200: Loss=0.007853 | TrainAcc=1.0000
# Fold 5 Epoch 300: Loss=0.004054 | TrainAcc=1.0000
# Fold 5 Epoch 400: Loss=0.001929 | TrainAcc=1.0000
# Fold 5 Epoch 500: Loss=0.001255 | TrainAcc=1.0000
# Fold 5 Epoch 600: Loss=0.000513 | TrainAcc=1.0000
# Fold 5 Epoch 700: Loss=0.000318 | TrainAcc=1.0000
# Fold 5 Epoch 800: Loss=0.000218 | TrainAcc=1.0000
# Fold 5 Epoch 900: Loss=0.000150 | TrainAcc=1.0000
# Fold 5 Epoch 1000: Loss=0.000087 | TrainAcc=1.0000
# Fold 5 Epoch 1100: Loss=0.000101 | TrainAcc=1.0000
# Fold 5 Epoch 1200: Loss=0.000073 | TrainAcc=1.0000
# Fold 5 Epoch 1300: Loss=0.000076 | TrainAcc=1.0000
# Fold 5 Epoch 1400: Loss=0.000062 | TrainAcc=1.0000
# Fold 5 Epoch 1500: Loss=0.000039 | TrainAcc=1.0000
# Fold 5 Epoch 1600: Loss=0.000023 | TrainAcc=1.0000
# Fold 5 Epoch 1700: Loss=0.000035 | TrainAcc=1.0000
# Fold 5 Epoch 1800: Loss=0.000026 | TrainAcc=1.0000
# Fold 5 Epoch 1900: Loss=0.000034 | TrainAcc=1.0000
# Fold 5 Epoch 2000: Loss=0.000024 | TrainAcc=1.0000
# Fold 5 → Acc=0.6818 | Prec=0.8507 | Rec=0.6404 | F1=0.7308 | AUC=0.7481 | CE Loss=0.9425
#
# === Fold 6 ===
# Fold 6 Epoch 1: Loss=0.627021 | TrainAcc=0.5714
# Fold 6 Epoch 100: Loss=0.016792 | TrainAcc=1.0000
# Fold 6 Epoch 200: Loss=0.004927 | TrainAcc=1.0000
# Fold 6 Epoch 300: Loss=0.002287 | TrainAcc=1.0000
# Fold 6 Epoch 400: Loss=0.001347 | TrainAcc=1.0000
# Fold 6 Epoch 500: Loss=0.000550 | TrainAcc=1.0000
# Fold 6 Epoch 600: Loss=0.000628 | TrainAcc=1.0000
# Fold 6 Epoch 700: Loss=0.000212 | TrainAcc=1.0000
# Fold 6 Epoch 800: Loss=0.000160 | TrainAcc=1.0000
# Fold 6 Epoch 900: Loss=0.000094 | TrainAcc=1.0000
# Fold 6 Epoch 1000: Loss=0.000094 | TrainAcc=1.0000
# Fold 6 Epoch 1100: Loss=0.000054 | TrainAcc=1.0000
# Fold 6 Epoch 1200: Loss=0.000041 | TrainAcc=1.0000
# Fold 6 Epoch 1300: Loss=0.000040 | TrainAcc=1.0000
# Fold 6 Epoch 1400: Loss=0.000021 | TrainAcc=1.0000
# Fold 6 Epoch 1500: Loss=0.000022 | TrainAcc=1.0000
# Fold 6 Epoch 1600: Loss=0.000023 | TrainAcc=1.0000
# Fold 6 Epoch 1700: Loss=0.000016 | TrainAcc=1.0000
# Fold 6 Epoch 1800: Loss=0.000020 | TrainAcc=1.0000
# Fold 6 Epoch 1900: Loss=0.000009 | TrainAcc=1.0000
# Fold 6 Epoch 2000: Loss=0.000016 | TrainAcc=1.0000
# Fold 6 → Acc=0.6818 | Prec=0.8219 | Rec=0.6742 | F1=0.7407 | AUC=0.7536 | CE Loss=1.0001
#
# === Fold 7 ===
# Fold 7 Epoch 1: Loss=0.689218 | TrainAcc=0.5000
# Fold 7 Epoch 100: Loss=0.030077 | TrainAcc=1.0000
# Fold 7 Epoch 200: Loss=0.007596 | TrainAcc=1.0000
# Fold 7 Epoch 300: Loss=0.003413 | TrainAcc=1.0000
# Fold 7 Epoch 400: Loss=0.001624 | TrainAcc=1.0000
# Fold 7 Epoch 500: Loss=0.000973 | TrainAcc=1.0000
# Fold 7 Epoch 600: Loss=0.000849 | TrainAcc=1.0000
# Fold 7 Epoch 700: Loss=0.000539 | TrainAcc=1.0000
# Fold 7 Epoch 800: Loss=0.000501 | TrainAcc=1.0000
# Fold 7 Epoch 900: Loss=0.000266 | TrainAcc=1.0000
# Fold 7 Epoch 1000: Loss=0.000209 | TrainAcc=1.0000
# Fold 7 Epoch 1100: Loss=0.000118 | TrainAcc=1.0000
# Fold 7 Epoch 1200: Loss=0.000081 | TrainAcc=1.0000
# Fold 7 Epoch 1300: Loss=0.000087 | TrainAcc=1.0000
# Fold 7 Epoch 1400: Loss=0.000046 | TrainAcc=1.0000
# Fold 7 Epoch 1500: Loss=0.000041 | TrainAcc=1.0000
# Fold 7 Epoch 1600: Loss=0.000036 | TrainAcc=1.0000
# Fold 7 Epoch 1700: Loss=0.000025 | TrainAcc=1.0000
# Fold 7 Epoch 1800: Loss=0.000041 | TrainAcc=1.0000
# Fold 7 Epoch 1900: Loss=0.000026 | TrainAcc=1.0000
# Fold 7 Epoch 2000: Loss=0.000021 | TrainAcc=1.0000
# Fold 7 → Acc=0.6667 | Prec=0.8082 | Rec=0.6629 | F1=0.7284 | AUC=0.7296 | CE Loss=0.9382
#
# === Fold 8 ===
# Fold 8 Epoch 1: Loss=0.636775 | TrainAcc=0.7143
# Fold 8 Epoch 100: Loss=0.017434 | TrainAcc=1.0000
# Fold 8 Epoch 200: Loss=0.004960 | TrainAcc=1.0000
# Fold 8 Epoch 300: Loss=0.002304 | TrainAcc=1.0000
# Fold 8 Epoch 400: Loss=0.001178 | TrainAcc=1.0000
# Fold 8 Epoch 500: Loss=0.000736 | TrainAcc=1.0000
# Fold 8 Epoch 600: Loss=0.000478 | TrainAcc=1.0000
# Fold 8 Epoch 700: Loss=0.000260 | TrainAcc=1.0000
# Fold 8 Epoch 800: Loss=0.000097 | TrainAcc=1.0000
# Fold 8 Epoch 900: Loss=0.000096 | TrainAcc=1.0000
# Fold 8 Epoch 1000: Loss=0.000085 | TrainAcc=1.0000
# Fold 8 Epoch 1100: Loss=0.000060 | TrainAcc=1.0000
# Fold 8 Epoch 1200: Loss=0.000048 | TrainAcc=1.0000
# Fold 8 Epoch 1300: Loss=0.000050 | TrainAcc=1.0000
# Fold 8 Epoch 1400: Loss=0.000032 | TrainAcc=1.0000
# Fold 8 Epoch 1500: Loss=0.000022 | TrainAcc=1.0000
# Fold 8 Epoch 1600: Loss=0.000019 | TrainAcc=1.0000
# Fold 8 Epoch 1700: Loss=0.000015 | TrainAcc=1.0000
# Fold 8 Epoch 1800: Loss=0.000026 | TrainAcc=1.0000
# Fold 8 Epoch 1900: Loss=0.000017 | TrainAcc=1.0000
# Fold 8 Epoch 2000: Loss=0.000009 | TrainAcc=1.0000
# Fold 8 → Acc=0.5985 | Prec=0.7143 | Rec=0.6742 | F1=0.6936 | AUC=0.5814 | CE Loss=1.5069
#
# === Fold 9 ===
# Fold 9 Epoch 1: Loss=0.939575 | TrainAcc=0.2857
# Fold 9 Epoch 100: Loss=0.030230 | TrainAcc=1.0000
# Fold 9 Epoch 200: Loss=0.008622 | TrainAcc=1.0000
# Fold 9 Epoch 300: Loss=0.006168 | TrainAcc=1.0000
# Fold 9 Epoch 400: Loss=0.002315 | TrainAcc=1.0000
# Fold 9 Epoch 500: Loss=0.001084 | TrainAcc=1.0000
# Fold 9 Epoch 600: Loss=0.000623 | TrainAcc=1.0000
# Fold 9 Epoch 700: Loss=0.000214 | TrainAcc=1.0000
# Fold 9 Epoch 800: Loss=0.000164 | TrainAcc=1.0000
# Fold 9 Epoch 900: Loss=0.000136 | TrainAcc=1.0000
# Fold 9 Epoch 1000: Loss=0.000072 | TrainAcc=1.0000
# Fold 9 Epoch 1100: Loss=0.000066 | TrainAcc=1.0000
# Fold 9 Epoch 1200: Loss=0.000044 | TrainAcc=1.0000
# Fold 9 Epoch 1300: Loss=0.000029 | TrainAcc=1.0000
# Fold 9 Epoch 1400: Loss=0.000020 | TrainAcc=1.0000
# Fold 9 Epoch 1500: Loss=0.000020 | TrainAcc=1.0000
# Fold 9 Epoch 1600: Loss=0.000027 | TrainAcc=1.0000
# Fold 9 Epoch 1700: Loss=0.000023 | TrainAcc=1.0000
# Fold 9 Epoch 1800: Loss=0.000012 | TrainAcc=1.0000
# Fold 9 Epoch 1900: Loss=0.000026 | TrainAcc=1.0000
# Fold 9 Epoch 2000: Loss=0.000011 | TrainAcc=1.0000
# Fold 9 → Acc=0.6212 | Prec=0.7910 | Rec=0.5955 | F1=0.6795 | AUC=0.6653 | CE Loss=1.2488
#
# === Fold 10 ===
# Fold 10 Epoch 1: Loss=0.734866 | TrainAcc=0.4286
# Fold 10 Epoch 100: Loss=0.030371 | TrainAcc=1.0000
# Fold 10 Epoch 200: Loss=0.008340 | TrainAcc=1.0000
# Fold 10 Epoch 300: Loss=0.002869 | TrainAcc=1.0000
# Fold 10 Epoch 400: Loss=0.002193 | TrainAcc=1.0000
# Fold 10 Epoch 500: Loss=0.001942 | TrainAcc=1.0000
# Fold 10 Epoch 600: Loss=0.000869 | TrainAcc=1.0000
# Fold 10 Epoch 700: Loss=0.000484 | TrainAcc=1.0000
# Fold 10 Epoch 800: Loss=0.000362 | TrainAcc=1.0000
# Fold 10 Epoch 900: Loss=0.000237 | TrainAcc=1.0000
# Fold 10 Epoch 1000: Loss=0.000316 | TrainAcc=1.0000
# Fold 10 Epoch 1100: Loss=0.000216 | TrainAcc=1.0000
# Fold 10 Epoch 1200: Loss=0.000147 | TrainAcc=1.0000
# Fold 10 Epoch 1300: Loss=0.000131 | TrainAcc=1.0000
# Fold 10 Epoch 1400: Loss=0.000107 | TrainAcc=1.0000
# Fold 10 Epoch 1500: Loss=0.000101 | TrainAcc=1.0000
# Fold 10 Epoch 1600: Loss=0.000071 | TrainAcc=1.0000
# Fold 10 Epoch 1700: Loss=0.000049 | TrainAcc=1.0000
# Fold 10 Epoch 1800: Loss=0.000053 | TrainAcc=1.0000
# Fold 10 Epoch 1900: Loss=0.000054 | TrainAcc=1.0000
# Fold 10 Epoch 2000: Loss=0.000045 | TrainAcc=1.0000
# Fold 10 → Acc=0.5682 | Prec=0.7353 | Rec=0.5618 | F1=0.6369 | AUC=0.5341 | CE Loss=1.3064
#
# === Fold 11 ===
# Fold 11 Epoch 1: Loss=0.649744 | TrainAcc=0.5714
# Fold 11 Epoch 100: Loss=0.019895 | TrainAcc=1.0000
# Fold 11 Epoch 200: Loss=0.006692 | TrainAcc=1.0000
# Fold 11 Epoch 300: Loss=0.002737 | TrainAcc=1.0000
# Fold 11 Epoch 400: Loss=0.001859 | TrainAcc=1.0000
# Fold 11 Epoch 500: Loss=0.001340 | TrainAcc=1.0000
# Fold 11 Epoch 600: Loss=0.000589 | TrainAcc=1.0000
# Fold 11 Epoch 700: Loss=0.000237 | TrainAcc=1.0000
# Fold 11 Epoch 800: Loss=0.000170 | TrainAcc=1.0000
# Fold 11 Epoch 900: Loss=0.000157 | TrainAcc=1.0000
# Fold 11 Epoch 1000: Loss=0.000124 | TrainAcc=1.0000
# Fold 11 Epoch 1100: Loss=0.000086 | TrainAcc=1.0000
# Fold 11 Epoch 1200: Loss=0.000063 | TrainAcc=1.0000
# Fold 11 Epoch 1300: Loss=0.000039 | TrainAcc=1.0000
# Fold 11 Epoch 1400: Loss=0.000037 | TrainAcc=1.0000
# Fold 11 Epoch 1500: Loss=0.000028 | TrainAcc=1.0000
# Fold 11 Epoch 1600: Loss=0.000022 | TrainAcc=1.0000
# Fold 11 Epoch 1700: Loss=0.000030 | TrainAcc=1.0000
# Fold 11 Epoch 1800: Loss=0.000018 | TrainAcc=1.0000
# Fold 11 Epoch 1900: Loss=0.000011 | TrainAcc=1.0000
# Fold 11 Epoch 2000: Loss=0.000016 | TrainAcc=1.0000
# Fold 11 → Acc=0.6894 | Prec=0.8750 | Rec=0.6292 | F1=0.7320 | AUC=0.8072 | CE Loss=0.9013
#
# === Fold 12 ===
# Fold 12 Epoch 1: Loss=0.634064 | TrainAcc=0.7143
# Fold 12 Epoch 100: Loss=0.013203 | TrainAcc=1.0000
# Fold 12 Epoch 200: Loss=0.005178 | TrainAcc=1.0000
# Fold 12 Epoch 300: Loss=0.001812 | TrainAcc=1.0000
# Fold 12 Epoch 400: Loss=0.001422 | TrainAcc=1.0000
# Fold 12 Epoch 500: Loss=0.001054 | TrainAcc=1.0000
# Fold 12 Epoch 600: Loss=0.000405 | TrainAcc=1.0000
# Fold 12 Epoch 700: Loss=0.000322 | TrainAcc=1.0000
# Fold 12 Epoch 800: Loss=0.000219 | TrainAcc=1.0000
# Fold 12 Epoch 900: Loss=0.000179 | TrainAcc=1.0000
# Fold 12 Epoch 1000: Loss=0.000156 | TrainAcc=1.0000
# Fold 12 Epoch 1100: Loss=0.000089 | TrainAcc=1.0000
# Fold 12 Epoch 1200: Loss=0.000056 | TrainAcc=1.0000
# Fold 12 Epoch 1300: Loss=0.000051 | TrainAcc=1.0000
# Fold 12 Epoch 1400: Loss=0.000046 | TrainAcc=1.0000
# Fold 12 Epoch 1500: Loss=0.000031 | TrainAcc=1.0000
# Fold 12 Epoch 1600: Loss=0.000031 | TrainAcc=1.0000
# Fold 12 Epoch 1700: Loss=0.000026 | TrainAcc=1.0000
# Fold 12 Epoch 1800: Loss=0.000020 | TrainAcc=1.0000
# Fold 12 Epoch 1900: Loss=0.000030 | TrainAcc=1.0000
# Fold 12 Epoch 2000: Loss=0.000033 | TrainAcc=1.0000
# Fold 12 → Acc=0.6591 | Prec=0.7895 | Rec=0.6742 | F1=0.7273 | AUC=0.6723 | CE Loss=1.2326
#
# === Fold 13 ===
# Fold 13 Epoch 1: Loss=0.819787 | TrainAcc=0.5714
# Fold 13 Epoch 100: Loss=0.039370 | TrainAcc=1.0000
# Fold 13 Epoch 200: Loss=0.012646 | TrainAcc=1.0000
# Fold 13 Epoch 300: Loss=0.004365 | TrainAcc=1.0000
# Fold 13 Epoch 400: Loss=0.002367 | TrainAcc=1.0000
# Fold 13 Epoch 500: Loss=0.000892 | TrainAcc=1.0000
# Fold 13 Epoch 600: Loss=0.000843 | TrainAcc=1.0000
# Fold 13 Epoch 700: Loss=0.000482 | TrainAcc=1.0000
# Fold 13 Epoch 800: Loss=0.002377 | TrainAcc=1.0000
# Fold 13 Epoch 900: Loss=0.000364 | TrainAcc=1.0000
# Fold 13 Epoch 1000: Loss=0.000160 | TrainAcc=1.0000
# Fold 13 Epoch 1100: Loss=0.000164 | TrainAcc=1.0000
# Fold 13 Epoch 1200: Loss=0.000071 | TrainAcc=1.0000
# Fold 13 Epoch 1300: Loss=0.000057 | TrainAcc=1.0000
# Fold 13 Epoch 1400: Loss=0.000080 | TrainAcc=1.0000
# Fold 13 Epoch 1500: Loss=0.000072 | TrainAcc=1.0000
# Fold 13 Epoch 1600: Loss=0.000047 | TrainAcc=1.0000
# Fold 13 Epoch 1700: Loss=0.000079 | TrainAcc=1.0000
# Fold 13 Epoch 1800: Loss=0.000062 | TrainAcc=1.0000
# Fold 13 Epoch 1900: Loss=0.000031 | TrainAcc=1.0000
# Fold 13 Epoch 2000: Loss=0.000018 | TrainAcc=1.0000
# Fold 13 → Acc=0.5909 | Prec=0.7108 | Rec=0.6629 | F1=0.6860 | AUC=0.5388 | CE Loss=1.3936
#
# === Fold 14 ===
# Fold 14 Epoch 1: Loss=0.607197 | TrainAcc=0.7857
# Fold 14 Epoch 100: Loss=0.019164 | TrainAcc=1.0000
# Fold 14 Epoch 200: Loss=0.006812 | TrainAcc=1.0000
# Fold 14 Epoch 300: Loss=0.004016 | TrainAcc=1.0000
# Fold 14 Epoch 400: Loss=0.001480 | TrainAcc=1.0000
# Fold 14 Epoch 500: Loss=0.000746 | TrainAcc=1.0000
# Fold 14 Epoch 600: Loss=0.000456 | TrainAcc=1.0000
# Fold 14 Epoch 700: Loss=0.000194 | TrainAcc=1.0000
# Fold 14 Epoch 800: Loss=0.000133 | TrainAcc=1.0000
# Fold 14 Epoch 900: Loss=0.000096 | TrainAcc=1.0000
# Fold 14 Epoch 1000: Loss=0.000043 | TrainAcc=1.0000
# Fold 14 Epoch 1100: Loss=0.000040 | TrainAcc=1.0000
# Fold 14 Epoch 1200: Loss=0.000026 | TrainAcc=1.0000
# Fold 14 Epoch 1300: Loss=0.000021 | TrainAcc=1.0000
# Fold 14 Epoch 1400: Loss=0.000016 | TrainAcc=1.0000
# Fold 14 Epoch 1500: Loss=0.000013 | TrainAcc=1.0000
# Fold 14 Epoch 1600: Loss=0.000012 | TrainAcc=1.0000
# Fold 14 Epoch 1700: Loss=0.000012 | TrainAcc=1.0000
# Fold 14 Epoch 1800: Loss=0.000011 | TrainAcc=1.0000
# Fold 14 Epoch 1900: Loss=0.000012 | TrainAcc=1.0000
# Fold 14 Epoch 2000: Loss=0.000024 | TrainAcc=1.0000
# Fold 14 → Acc=0.5985 | Prec=0.7571 | Rec=0.5955 | F1=0.6667 | AUC=0.6621 | CE Loss=1.6552
#
# === Fold 15 ===
# Fold 15 Epoch 1: Loss=0.828916 | TrainAcc=0.5000
# Fold 15 Epoch 100: Loss=0.027167 | TrainAcc=1.0000
# Fold 15 Epoch 200: Loss=0.008817 | TrainAcc=1.0000
# Fold 15 Epoch 300: Loss=0.005506 | TrainAcc=1.0000
# Fold 15 Epoch 400: Loss=0.001707 | TrainAcc=1.0000
# Fold 15 Epoch 500: Loss=0.000931 | TrainAcc=1.0000
# Fold 15 Epoch 600: Loss=0.000650 | TrainAcc=1.0000
# Fold 15 Epoch 700: Loss=0.000321 | TrainAcc=1.0000
# Fold 15 Epoch 800: Loss=0.000354 | TrainAcc=1.0000
# Fold 15 Epoch 900: Loss=0.000258 | TrainAcc=1.0000
# Fold 15 Epoch 1000: Loss=0.000130 | TrainAcc=1.0000
# Fold 15 Epoch 1100: Loss=0.000100 | TrainAcc=1.0000
# Fold 15 Epoch 1200: Loss=0.000083 | TrainAcc=1.0000
# Fold 15 Epoch 1300: Loss=0.000047 | TrainAcc=1.0000
# Fold 15 Epoch 1400: Loss=0.000042 | TrainAcc=1.0000
# Fold 15 Epoch 1500: Loss=0.000020 | TrainAcc=1.0000
# Fold 15 Epoch 1600: Loss=0.000065 | TrainAcc=1.0000
# Fold 15 Epoch 1700: Loss=0.000027 | TrainAcc=1.0000
# Fold 15 Epoch 1800: Loss=0.000018 | TrainAcc=1.0000
# Fold 15 Epoch 1900: Loss=0.000018 | TrainAcc=1.0000
# Fold 15 Epoch 2000: Loss=0.000025 | TrainAcc=1.0000
# Fold 15 → Acc=0.6288 | Prec=0.8030 | Rec=0.5955 | F1=0.6839 | AUC=0.7693 | CE Loss=0.8870
#
# === Fold 16 ===
# Fold 16 Epoch 1: Loss=0.800291 | TrainAcc=0.4286
# Fold 16 Epoch 100: Loss=0.027177 | TrainAcc=1.0000
# Fold 16 Epoch 200: Loss=0.009269 | TrainAcc=1.0000
# Fold 16 Epoch 300: Loss=0.003129 | TrainAcc=1.0000
# Fold 16 Epoch 400: Loss=0.002338 | TrainAcc=1.0000
# Fold 16 Epoch 500: Loss=0.000945 | TrainAcc=1.0000
# Fold 16 Epoch 600: Loss=0.000683 | TrainAcc=1.0000
# Fold 16 Epoch 700: Loss=0.000566 | TrainAcc=1.0000
# Fold 16 Epoch 800: Loss=0.000316 | TrainAcc=1.0000
# Fold 16 Epoch 900: Loss=0.000149 | TrainAcc=1.0000
# Fold 16 Epoch 1000: Loss=0.000110 | TrainAcc=1.0000
# Fold 16 Epoch 1100: Loss=0.000064 | TrainAcc=1.0000
# Fold 16 Epoch 1200: Loss=0.000047 | TrainAcc=1.0000
# Fold 16 Epoch 1300: Loss=0.000030 | TrainAcc=1.0000
# Fold 16 Epoch 1400: Loss=0.000041 | TrainAcc=1.0000
# Fold 16 Epoch 1500: Loss=0.000033 | TrainAcc=1.0000
# Fold 16 Epoch 1600: Loss=0.000020 | TrainAcc=1.0000
# Fold 16 Epoch 1700: Loss=0.000026 | TrainAcc=1.0000
# Fold 16 Epoch 1800: Loss=0.000015 | TrainAcc=1.0000
# Fold 16 Epoch 1900: Loss=0.000012 | TrainAcc=1.0000
# Fold 16 Epoch 2000: Loss=0.000012 | TrainAcc=1.0000
# Fold 16 → Acc=0.5379 | Prec=0.7000 | Rec=0.5506 | F1=0.6164 | AUC=0.5751 | CE Loss=1.4715
#
# === Fold 17 ===
# Fold 17 Epoch 1: Loss=0.791992 | TrainAcc=0.4286
# Fold 17 Epoch 100: Loss=0.022025 | TrainAcc=1.0000
# Fold 17 Epoch 200: Loss=0.007439 | TrainAcc=1.0000
# Fold 17 Epoch 300: Loss=0.004104 | TrainAcc=1.0000
# Fold 17 Epoch 400: Loss=0.001909 | TrainAcc=1.0000
# Fold 17 Epoch 500: Loss=0.001530 | TrainAcc=1.0000
# Fold 17 Epoch 600: Loss=0.000862 | TrainAcc=1.0000
# Fold 17 Epoch 700: Loss=0.000858 | TrainAcc=1.0000
# Fold 17 Epoch 800: Loss=0.000448 | TrainAcc=1.0000
# Fold 17 Epoch 900: Loss=0.000289 | TrainAcc=1.0000
# Fold 17 Epoch 1000: Loss=0.000183 | TrainAcc=1.0000
# Fold 17 Epoch 1100: Loss=0.000123 | TrainAcc=1.0000
# Fold 17 Epoch 1200: Loss=0.000123 | TrainAcc=1.0000
# Fold 17 Epoch 1300: Loss=0.000090 | TrainAcc=1.0000
# Fold 17 Epoch 1400: Loss=0.000062 | TrainAcc=1.0000
# Fold 17 Epoch 1500: Loss=0.000058 | TrainAcc=1.0000
# Fold 17 Epoch 1600: Loss=0.000066 | TrainAcc=1.0000
# Fold 17 Epoch 1700: Loss=0.000026 | TrainAcc=1.0000
# Fold 17 Epoch 1800: Loss=0.000026 | TrainAcc=1.0000
# Fold 17 Epoch 1900: Loss=0.000052 | TrainAcc=1.0000
# Fold 17 Epoch 2000: Loss=0.000026 | TrainAcc=1.0000
# Fold 17 → Acc=0.6894 | Prec=0.9000 | Rec=0.6067 | F1=0.7248 | AUC=0.7944 | CE Loss=0.9249
#
# === Fold 18 ===
# Fold 18 Epoch 1: Loss=0.922329 | TrainAcc=0.2143
# Fold 18 Epoch 100: Loss=0.024842 | TrainAcc=1.0000
# Fold 18 Epoch 200: Loss=0.010163 | TrainAcc=1.0000
# Fold 18 Epoch 300: Loss=0.003396 | TrainAcc=1.0000
# Fold 18 Epoch 400: Loss=0.001571 | TrainAcc=1.0000
# Fold 18 Epoch 500: Loss=0.000999 | TrainAcc=1.0000
# Fold 18 Epoch 600: Loss=0.000828 | TrainAcc=1.0000
# Fold 18 Epoch 700: Loss=0.000434 | TrainAcc=1.0000
# Fold 18 Epoch 800: Loss=0.000316 | TrainAcc=1.0000
# Fold 18 Epoch 900: Loss=0.000288 | TrainAcc=1.0000
# Fold 18 Epoch 1000: Loss=0.000184 | TrainAcc=1.0000
# Fold 18 Epoch 1100: Loss=0.000119 | TrainAcc=1.0000
# Fold 18 Epoch 1200: Loss=0.000070 | TrainAcc=1.0000
# Fold 18 Epoch 1300: Loss=0.000054 | TrainAcc=1.0000
# Fold 18 Epoch 1400: Loss=0.000050 | TrainAcc=1.0000
# Fold 18 Epoch 1500: Loss=0.000030 | TrainAcc=1.0000
# Fold 18 Epoch 1600: Loss=0.000036 | TrainAcc=1.0000
# Fold 18 Epoch 1700: Loss=0.000036 | TrainAcc=1.0000
# Fold 18 Epoch 1800: Loss=0.000023 | TrainAcc=1.0000
# Fold 18 Epoch 1900: Loss=0.000028 | TrainAcc=1.0000
# Fold 18 Epoch 2000: Loss=0.000020 | TrainAcc=1.0000
# Fold 18 → Acc=0.6894 | Prec=0.8077 | Rec=0.7079 | F1=0.7545 | AUC=0.7463 | CE Loss=0.8578
#
# === Fold 19 ===
# Fold 19 Epoch 1: Loss=0.886382 | TrainAcc=0.3571
# Fold 19 Epoch 100: Loss=0.021910 | TrainAcc=1.0000
# Fold 19 Epoch 200: Loss=0.008717 | TrainAcc=1.0000
# Fold 19 Epoch 300: Loss=0.002257 | TrainAcc=1.0000
# Fold 19 Epoch 400: Loss=0.001680 | TrainAcc=1.0000
# Fold 19 Epoch 500: Loss=0.000778 | TrainAcc=1.0000
# Fold 19 Epoch 600: Loss=0.000714 | TrainAcc=1.0000
# Fold 19 Epoch 700: Loss=0.000346 | TrainAcc=1.0000
# Fold 19 Epoch 800: Loss=0.000263 | TrainAcc=1.0000
# Fold 19 Epoch 900: Loss=0.000288 | TrainAcc=1.0000
# Fold 19 Epoch 1000: Loss=0.000124 | TrainAcc=1.0000
# Fold 19 Epoch 1100: Loss=0.000100 | TrainAcc=1.0000
# Fold 19 Epoch 1200: Loss=0.000056 | TrainAcc=1.0000
# Fold 19 Epoch 1300: Loss=0.000049 | TrainAcc=1.0000
# Fold 19 Epoch 1400: Loss=0.000037 | TrainAcc=1.0000
# Fold 19 Epoch 1500: Loss=0.000021 | TrainAcc=1.0000
# Fold 19 Epoch 1600: Loss=0.000026 | TrainAcc=1.0000
# Fold 19 Epoch 1700: Loss=0.000023 | TrainAcc=1.0000
# Fold 19 Epoch 1800: Loss=0.000017 | TrainAcc=1.0000
# Fold 19 Epoch 1900: Loss=0.000011 | TrainAcc=1.0000
# Fold 19 Epoch 2000: Loss=0.000010 | TrainAcc=1.0000
# Fold 19 → Acc=0.6591 | Prec=0.8056 | Rec=0.6517 | F1=0.7205 | AUC=0.7264 | CE Loss=0.9386
#
# === Fold 20 ===
# Fold 20 Epoch 1: Loss=0.739192 | TrainAcc=0.4286
# Fold 20 Epoch 100: Loss=0.023352 | TrainAcc=1.0000
# Fold 20 Epoch 200: Loss=0.008416 | TrainAcc=1.0000
# Fold 20 Epoch 300: Loss=0.002777 | TrainAcc=1.0000
# Fold 20 Epoch 400: Loss=0.002162 | TrainAcc=1.0000
# Fold 20 Epoch 500: Loss=0.001040 | TrainAcc=1.0000
# Fold 20 Epoch 600: Loss=0.000647 | TrainAcc=1.0000
# Fold 20 Epoch 700: Loss=0.000387 | TrainAcc=1.0000
# Fold 20 Epoch 800: Loss=0.000351 | TrainAcc=1.0000
# Fold 20 Epoch 900: Loss=0.000144 | TrainAcc=1.0000
# Fold 20 Epoch 1000: Loss=0.000162 | TrainAcc=1.0000
# Fold 20 Epoch 1100: Loss=0.000097 | TrainAcc=1.0000
# Fold 20 Epoch 1200: Loss=0.000106 | TrainAcc=1.0000
# Fold 20 Epoch 1300: Loss=0.000064 | TrainAcc=1.0000
# Fold 20 Epoch 1400: Loss=0.000043 | TrainAcc=1.0000
# Fold 20 Epoch 1500: Loss=0.000058 | TrainAcc=1.0000
# Fold 20 Epoch 1600: Loss=0.000040 | TrainAcc=1.0000
# Fold 20 Epoch 1700: Loss=0.000032 | TrainAcc=1.0000
# Fold 20 Epoch 1800: Loss=0.000032 | TrainAcc=1.0000
# Fold 20 Epoch 1900: Loss=0.000034 | TrainAcc=1.0000
# Fold 20 Epoch 2000: Loss=0.000020 | TrainAcc=1.0000
# Fold 20 → Acc=0.5379 | Prec=0.6944 | Rec=0.5618 | F1=0.6211 | AUC=0.5592 | CE Loss=1.7782
#
# === Average Results Across 20 Folds ===
# Accuracy:  0.6295 ± 0.0471
# Precision: 0.7846 ± 0.0560
# Recall:    0.6253 ± 0.0441
# F1-score:  0.6946 ± 0.0382
# CE Loss:   1.1568 ± 0.2716
# AUC:       0.6840 ± 0.0848
