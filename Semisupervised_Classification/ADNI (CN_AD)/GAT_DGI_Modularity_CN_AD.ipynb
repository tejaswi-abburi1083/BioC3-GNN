# %%
import os
import sys
import numpy as np
import random
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.data import Data
from torch_geometric.nn import GCNConv
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, log_loss, roc_auc_score, roc_curve
from sklearn.ensemble import RandomForestClassifier  # (only if you want to compare)
import warnings
warnings.filterwarnings("ignore")

# %%
SEED = 42
np.random.seed(SEED)
random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)
torch.set_num_threads(4)

# %%
SEED = 42
np.random.seed(SEED)
random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)
torch.set_num_threads(4)

fa_cn = "/home/snu/Downloads/Histogram_CN_FA_20bin_updated.npy"
fa_ad = "/home/snu/Downloads/Histogram_AD_FA_20bin_updated.npy"

X_cn = np.load(fa_cn, allow_pickle=True)
X_ad = np.load(fa_ad, allow_pickle=True)

X = np.vstack([X_cn, X_ad]).astype(np.float32)
y = np.hstack([
    np.zeros(X_cn.shape[0], dtype=np.int64),
    np.ones(X_ad.shape[0], dtype=np.int64)
])

perm = np.random.RandomState(SEED).permutation(len(X))
X = X[perm]
y = y[perm]

num_nodes, num_feats = X.shape
print(f"Dataset: nodes={num_nodes}, feats={num_feats}")
# Out:
# Dataset: nodes=223, feats=180

# %%
def create_adj(F, alpha=1):
    norms = np.linalg.norm(F, axis=1, keepdims=True)
    norms[norms == 0] = 1.0
    F_norm = F / norms
    W = np.dot(F_norm, F_norm.T)
    W = (W >= alpha).astype(np.float32)
    return W

# %%
W0 = create_adj(X, alpha=0.8)
print(f"W0: {W0.shape}")
# Out:
# W0: (223, 223)

# %%
def load_graph_torch(adj, node_feats):
    node_feats_t = torch.from_numpy(node_feats).float()
    edge_idx = np.array(np.nonzero(adj))
    edge_index = torch.from_numpy(edge_idx).long()
    return node_feats_t, edge_index
node_feats_all, edge_index_all = load_graph_torch(W0, X)
print(f"Number of edges: {edge_index_all.size(1)}")
# Out:
# Number of edges: 41689

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import GATConv

class GATEncoder(torch.nn.Module):
    def __init__(self, input_dim, hidden_dim, device, activ="SELU", heads=1):
        super(GATEncoder, self).__init__()

        activations = {
            "SELU": F.selu,
            "SiLU": F.silu,
            "GELU": F.gelu,
            "ELU": F.elu,
            "RELU": F.relu
        }
        self.act = activations.get(activ, F.elu)

        self.gat = GATConv(
            in_channels=input_dim,
            out_channels=hidden_dim,
            heads=heads,
            dropout=0.3,
            concat=False
        )

        self.batchnorm = nn.BatchNorm1d(hidden_dim)
        self.dropout = nn.Dropout(0.3)
        self.mlp = nn.Linear(hidden_dim, hidden_dim)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = self.gat(x, edge_index)
        x = self.act(x)
        x = self.dropout(x)
        x = self.batchnorm(x)
        logits = self.mlp(x)
        return logits

# %%
class AvgReadout(nn.Module):
    def __init__(self):
        super().__init__()
    def forward(self, seq, msk=None):
        if msk is None:
            return torch.mean(seq, 0)
        else:
            msk = torch.unsqueeze(msk, -1)
            return torch.sum(seq * msk, 0) / torch.sum(msk)

# %%
class Discriminator(nn.Module):
    def __init__(self, n_h):
        super().__init__()
        self.f_k = nn.Bilinear(n_h, n_h, 1)
        nn.init.xavier_uniform_(self.f_k.weight.data)
        if self.f_k.bias is not None:
            self.f_k.bias.data.fill_(0.0)
    def forward(self, c, h_pl, h_mi):
        c_x = torch.unsqueeze(c, 0).expand_as(h_pl)
        sc_1 = torch.squeeze(self.f_k(h_pl, c_x), 1)
        sc_2 = torch.squeeze(self.f_k(h_mi, c_x), 1)
        logits = torch.cat((sc_1, sc_2), 0)
        return logits

# %%
class DGI(nn.Module):
    def __init__(self, n_in, n_h, heads, dropout=0.25):
        super().__init__()
        self.gat1 = GATEncoder(n_in, n_h, heads=heads, device='cuda' if torch.cuda.is_available() else 'cpu', activ=nn.ELU())
        self.read = AvgReadout()
        self.sigm = nn.Sigmoid()
        self.disc = Discriminator(n_h * heads)

    def forward(self, seq1, seq2, edge_index):
        # Create Data objects for the GATEncoder
        data1 = Data(x=seq1, edge_index=edge_index)
        data2 = Data(x=seq2, edge_index=edge_index)

        h_1 = self.gat1(data1)
        c = self.read(h_1)
        c = self.sigm(c)
        h_2 = self.gat1(data2)
        logits = self.disc(c, h_1, h_2)
        return logits, h_1

# %%
class DGI_with_classifier(DGI):
    def __init__(self, n_in, n_h, heads, n_classes=2, cut=0, dropout=0.25):
        super().__init__(n_in, n_h, heads, dropout=dropout)
        self.classifier = nn.Linear(n_h * heads, n_classes)
        self.cut = cut

    def get_embeddings(self, node_feats, edge_index):
        _, embeddings = self.forward(node_feats, node_feats, edge_index)
        return embeddings

    def cut_loss(self, A, S):
        S = F.softmax(S, dim=1)
        A_pool = torch.matmul(torch.matmul(A, S).t(), S)
        num = torch.trace(A_pool)
        D = torch.diag(torch.sum(A, dim=-1))
        D_pooled = torch.matmul(torch.matmul(D, S).t(), S)
        den = torch.trace(D_pooled)
        mincut_loss = -(num / den)
        St_S = torch.matmul(S.t(), S)
        I_S = torch.eye(S.shape[1], device=A.device)
        ortho_loss = torch.norm(St_S / torch.norm(St_S) - I_S / torch.norm(I_S))
        return mincut_loss + ortho_loss

    def modularity_loss(self, A, S):
        C = F.softmax(S, dim=1)
        d = torch.sum(A, dim=1)
        m = torch.sum(A)
        B = A - torch.ger(d, d) / (2 * m)
        I_S = torch.eye(C.shape[1], device=A.device)
        k = torch.norm(I_S)
        n = S.shape[0]
        modularity_term = (-1 / (2 * m)) * torch.trace(torch.mm(torch.mm(C.t(), B), C))
        collapse_reg_term = (torch.sqrt(k) / n) * torch.norm(torch.sum(C, dim=0), p='fro') - 1
        return modularity_term + collapse_reg_term

    def Reg_loss(self, A, embeddings):
        logits = self.classifier(embeddings)
        if self.cut == 1:
            return self.cut_loss(A, logits)
        else:
            return self.modularity_loss(A, logits)

# %%
from sklearn.model_selection import StratifiedShuffleSplit
sss = StratifiedShuffleSplit(n_splits=20, test_size=0.5, random_state=SEED)
accuracies, precisions, recalls, f1_scores, losses = [], [], [], [], []
all_y_true = []
all_y_proba = []
all_fpr, all_tpr, all_auc = [], [], []

# %%
def get_device():
    try:
        if torch.cuda.is_available():
            dev = torch.device("cuda")
            # test a tiny tensor operation to check CUDA health
            torch.tensor([1.0], device=dev) + 1.0
            return dev
    except Exception as e:
        print("CUDA not usable, falling back to CPU:", e)
        try:
            torch.cuda.empty_cache()
        except:
            pass
    return torch.device("cpu")

device = get_device()
print("Using device:", device)
# Out:
# Using device: cuda

# %%
A_tensor = torch.from_numpy(W0).to(device)
hidden_dim = 512
heads = 1
dropout = 0.2
cut = 0
num_epochs = 2500
lr = 1e-4
weight_decay = 1e-4
# sup_weight = 1.0
# dgi_weight = 0.3
reg_weight = 0.001

# %%
for fold, (train_idx, test_idx) in enumerate(sss.split(X, y)):
    print(f"\n=== Fold {fold+1} ===")

    cn_idx = np.where(y == 0)[0]
    ad_idx = np.where(y == 1)[0]

    sss_class = StratifiedShuffleSplit(n_splits=20, test_size=0.9, random_state=fold)
    cn_train_idx, cn_test_idx = next(sss_class.split(X[cn_idx], y[cn_idx]))
    ad_train_idx, ad_test_idx = next(sss_class.split(X[ad_idx], y[ad_idx]))

    cn_train = cn_idx[cn_train_idx]
    ad_train = ad_idx[ad_train_idx]
    cn_test = cn_idx[cn_test_idx]
    ad_test = ad_idx[ad_test_idx]

    balanced_train_idx = np.concatenate([cn_train, ad_train])
    test_idx = np.concatenate([cn_test, ad_test])
    np.random.shuffle(balanced_train_idx)
    np.random.shuffle(test_idx)

    print(f"Train CN: {len(cn_train)}, Train AD: {len(ad_train)}")
    print(f"Test CN: {len(cn_test)}, Test AD: {len(ad_test)}")

    node_feats = node_feats_all.to(device)
    edge_index = edge_index_all.to(device)
    y_tensor = torch.from_numpy(y).long().to(device)
    train_idx_t = torch.from_numpy(balanced_train_idx).long().to(device)
    test_idx_t = torch.from_numpy(test_idx).long().to(device)

    N = node_feats.size(0)
    lbl = torch.cat([torch.ones(N, device=device), torch.zeros(N, device=device)])

    model = DGI_with_classifier(num_feats, hidden_dim, heads=heads, n_classes=2, cut=cut, dropout=dropout).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    bce_loss = nn.BCEWithLogitsLoss()
    ce_loss = nn.CrossEntropyLoss()

    for epoch in range(1, num_epochs + 1):
        model.train()
        optimizer.zero_grad()

        perm = torch.randperm(N, device=device)
        corrupt = node_feats[perm]

        logits_dgi, embeddings = model(node_feats, corrupt, edge_index)
        dgi_loss = bce_loss(logits_dgi.squeeze(), lbl)

        logits_cls = model.classifier(embeddings)
        train_logits = logits_cls[train_idx_t]
        train_labels = y_tensor[train_idx_t]
        supervised_loss = ce_loss(train_logits, train_labels)

        reg_loss_val = model.Reg_loss(A_tensor, embeddings)
        total_loss = supervised_loss + dgi_loss + reg_loss_val

        total_loss.backward()
        optimizer.step()

        if epoch % 500 == 0 or epoch == 1:
            model.eval()
            with torch.no_grad():
                logits_eval = model.classifier(model.get_embeddings(node_feats, edge_index))
                preds_train = torch.argmax(logits_eval[train_idx_t], dim=1).cpu().numpy()
                acc = accuracy_score(train_labels.cpu().numpy(), preds_train)
            print(f"Epoch {epoch}: Sup={supervised_loss.item():.4f} | DGI={dgi_loss.item():.4f} | Reg={reg_loss_val.item():.4f} | Total={total_loss.item():.4f} | TrainAcc={acc:.4f}")
    model.eval()
    with torch.no_grad():
        emb_final = model.get_embeddings(node_feats, edge_index)
        logits_final = model.classifier(emb_final)
        probs = F.softmax(logits_final, dim=1).cpu().numpy()
        y_pred = np.argmax(probs, axis=1)

    y_test = y[test_idx]
    y_pred_test = y_pred[test_idx]
    y_proba_test = probs[test_idx, 1]

    acc = accuracy_score(y_test, y_pred_test)
    prec = precision_score(y_test, y_pred_test, zero_division=0)
    rec = recall_score(y_test, y_pred_test, zero_division=0)
    f1 = f1_score(y_test, y_pred_test, zero_division=0)
    loss_val = log_loss(y_test, y_proba_test)
    auc_score = roc_auc_score(y_test, y_proba_test)

    accuracies.append(acc)
    precisions.append(prec)
    recalls.append(rec)
    f1_scores.append(f1)
    losses.append(loss_val)
    all_auc.append(auc_score)

    print(f"Fold {fold+1} → Acc={acc:.4f} Prec={prec:.4f} Rec={rec:.4f} F1={f1:.4f} AUC={auc_score:.4f}")

print("\n=== Average Results ===")
print(f"Accuracy: {np.mean(accuracies):.4f} \u00b1 {np.std(accuracies):.4f}")
print(f"Precision: {np.mean(precisions):.4f} \u00b1 {np.std(precisions):.4f}")
print(f"Recall: {np.mean(recalls):.4f} \u00b1 {np.std(recalls):.4f}")
print(f"F1: {np.mean(f1_scores):.4f} \u00b1 {np.std(f1_scores):.4f}")
print(f"LogLoss: {np.mean(losses):.4f} \u00b1 {np.std(losses):.4f}")
print(f"AUC: {np.mean(all_auc):.4f} \u00b1 {np.std(all_auc):.4f}")
# Out:
# === Fold 1 ===
# Train CN: 13, Train AD: 9
# Test CN: 120, Test AD: 81
# Epoch 1: Sup=0.6674 | DGI=0.7146 | Reg=-0.2843 | Total=1.0978 | TrainAcc=0.5909
# Epoch 500: Sup=0.0572 | DGI=0.7280 | Reg=-0.3009 | Total=0.4843 | TrainAcc=1.0000
# Epoch 1000: Sup=0.0130 | DGI=0.7025 | Reg=-0.3043 | Total=0.4113 | TrainAcc=1.0000
# Epoch 1500: Sup=0.0016 | DGI=0.7035 | Reg=-0.3046 | Total=0.4004 | TrainAcc=1.0000
# Epoch 2000: Sup=0.0017 | DGI=0.6933 | Reg=-0.3058 | Total=0.3892 | TrainAcc=1.0000
# Epoch 2500: Sup=0.0001 | DGI=0.6936 | Reg=-0.3070 | Total=0.3868 | TrainAcc=1.0000
# Fold 1 → Acc=0.7960 Prec=0.7778 Rec=0.6914 F1=0.7320 AUC=0.8598
#
# === Fold 2 ===
# Train CN: 13, Train AD: 9
# Test CN: 120, Test AD: 81
# Epoch 1: Sup=0.7592 | DGI=0.7166 | Reg=-0.2841 | Total=1.1916 | TrainAcc=0.4091
# Epoch 500: Sup=0.4445 | DGI=0.6973 | Reg=-0.2894 | Total=0.8524 | TrainAcc=0.8636
# Epoch 1000: Sup=0.0179 | DGI=0.6959 | Reg=-0.2859 | Total=0.4279 | TrainAcc=1.0000
# Epoch 1500: Sup=0.0196 | DGI=0.6948 | Reg=-0.2935 | Total=0.4209 | TrainAcc=1.0000
# Epoch 2000: Sup=0.0014 | DGI=0.7018 | Reg=-0.2987 | Total=0.4045 | TrainAcc=1.0000
# Epoch 2500: Sup=0.0005 | DGI=0.6956 | Reg=-0.2998 | Total=0.3963 | TrainAcc=1.0000
# Fold 2 → Acc=0.6716 Prec=0.5701 Rec=0.7531 F1=0.6489 AUC=0.7579
#
# === Fold 3 ===
# Train CN: 13, Train AD: 9
# Test CN: 120, Test AD: 81
# Epoch 1: Sup=0.7212 | DGI=0.7111 | Reg=-0.2841 | Total=1.1482 | TrainAcc=0.4091
# Epoch 500: Sup=0.0391 | DGI=0.6983 | Reg=-0.3023 | Total=0.4352 | TrainAcc=1.0000
# Epoch 1000: Sup=0.0007 | DGI=0.6934 | Reg=-0.3031 | Total=0.3909 | TrainAcc=1.0000
# Epoch 1500: Sup=0.0036 | DGI=0.6935 | Reg=-0.3037 | Total=0.3934 | TrainAcc=1.0000
# Epoch 2000: Sup=0.0005 | DGI=0.6952 | Reg=-0.3047 | Total=0.3910 | TrainAcc=1.0000
# Epoch 2500: Sup=0.0069 | DGI=0.6943 | Reg=-0.3052 | Total=0.3960 | TrainAcc=1.0000
# Fold 3 → Acc=0.7612 Prec=0.7619 Rec=0.5926 F1=0.6667 AUC=0.8208
#
# === Fold 4 ===
# Train CN: 13, Train AD: 9
# Test CN: 120, Test AD: 81
# Epoch 1: Sup=0.6362 | DGI=0.7120 | Reg=-0.2841 | Total=1.0640 | TrainAcc=0.4091
# Epoch 500: Sup=0.0019 | DGI=0.6959 | Reg=-0.3068 | Total=0.3909 | TrainAcc=1.0000
# Epoch 1000: Sup=0.0025 | DGI=0.6956 | Reg=-0.3080 | Total=0.3900 | TrainAcc=1.0000
# Epoch 1500: Sup=0.0004 | DGI=0.6954 | Reg=-0.3088 | Total=0.3870 | TrainAcc=1.0000
# Epoch 2000: Sup=0.0004 | DGI=0.6935 | Reg=-0.3087 | Total=0.3852 | TrainAcc=1.0000
# Epoch 2500: Sup=0.0002 | DGI=0.6932 | Reg=-0.3092 | Total=0.3842 | TrainAcc=1.0000
# Fold 4 → Acc=0.7711 Prec=0.7160 Rec=0.7160 F1=0.7160 AUC=0.8227
#
# === Fold 5 ===
# Train CN: 13, Train AD: 9
# Test CN: 120, Test AD: 81
# Epoch 1: Sup=0.7860 | DGI=0.7134 | Reg=-0.2839 | Total=1.2155 | TrainAcc=0.4091
# Epoch 500: Sup=0.0490 | DGI=0.7054 | Reg=-0.2997 | Total=0.4548 | TrainAcc=0.9091
# Epoch 1000: Sup=0.0016 | DGI=0.6938 | Reg=-0.3059 | Total=0.3895 | TrainAcc=0.9545
# Epoch 1500: Sup=0.0009 | DGI=0.6992 | Reg=-0.3061 | Total=0.3939 | TrainAcc=1.0000
# Epoch 2000: Sup=0.0004 | DGI=0.6933 | Reg=-0.3073 | Total=0.3864 | TrainAcc=1.0000
# Epoch 2500: Sup=0.0006 | DGI=0.6975 | Reg=-0.3072 | Total=0.3909 | TrainAcc=1.0000
# Fold 5 → Acc=0.7512 Prec=0.7246 Rec=0.6173 F1=0.6667 AUC=0.8330
#
# === Fold 6 ===
# Train CN: 13, Train AD: 9
# Test CN: 120, Test AD: 81
# Epoch 1: Sup=0.6073 | DGI=0.7133 | Reg=-0.2841 | Total=1.0364 | TrainAcc=0.4091
# Epoch 500: Sup=0.1147 | DGI=0.6979 | Reg=-0.2977 | Total=0.5149 | TrainAcc=0.9545
# Epoch 1000: Sup=0.0148 | DGI=0.7001 | Reg=-0.3027 | Total=0.4121 | TrainAcc=1.0000
# Epoch 1500: Sup=0.0569 | DGI=0.7008 | Reg=-0.3023 | Total=0.4554 | TrainAcc=1.0000
# Epoch 2000: Sup=0.0028 | DGI=0.6935 | Reg=-0.3043 | Total=0.3920 | TrainAcc=1.0000
# Epoch 2500: Sup=0.0042 | DGI=0.6934 | Reg=-0.3033 | Total=0.3943 | TrainAcc=1.0000
# Fold 6 → Acc=0.7264 Prec=0.6354 Rec=0.7531 F1=0.6893 AUC=0.7938
#
# === Fold 7 ===
# Train CN: 13, Train AD: 9
# Test CN: 120, Test AD: 81
# Epoch 1: Sup=0.6815 | DGI=0.7119 | Reg=-0.2842 | Total=1.1093 | TrainAcc=0.4091
# Epoch 500: Sup=0.4139 | DGI=0.6954 | Reg=-0.3027 | Total=0.8067 | TrainAcc=0.8636
# Epoch 1000: Sup=0.0096 | DGI=0.6962 | Reg=-0.3053 | Total=0.4005 | TrainAcc=1.0000
# Epoch 1500: Sup=0.0017 | DGI=0.7211 | Reg=-0.3059 | Total=0.4168 | TrainAcc=1.0000
# Epoch 2000: Sup=0.0002 | DGI=0.6952 | Reg=-0.3069 | Total=0.3885 | TrainAcc=1.0000
# Epoch 2500: Sup=0.0001 | DGI=0.6934 | Reg=-0.3070 | Total=0.3865 | TrainAcc=1.0000
# Fold 7 → Acc=0.7264 Prec=0.6667 Rec=0.6420 F1=0.6541 AUC=0.7736
#
# === Fold 8 ===
# Train CN: 13, Train AD: 9
# Test CN: 120, Test AD: 81
# Epoch 1: Sup=0.7459 | DGI=0.7132 | Reg=-0.2842 | Total=1.1750 | TrainAcc=0.4091
# Epoch 500: Sup=0.2329 | DGI=0.7011 | Reg=-0.2987 | Total=0.6353 | TrainAcc=0.9091
# Epoch 1000: Sup=0.0072 | DGI=0.6947 | Reg=-0.2999 | Total=0.4021 | TrainAcc=1.0000
# Epoch 1500: Sup=0.0007 | DGI=0.6947 | Reg=-0.3025 | Total=0.3928 | TrainAcc=1.0000
# Epoch 2000: Sup=0.0029 | DGI=0.6932 | Reg=-0.3022 | Total=0.3939 | TrainAcc=1.0000
# Epoch 2500: Sup=0.0005 | DGI=0.6940 | Reg=-0.3015 | Total=0.3930 | TrainAcc=1.0000
# Fold 8 → Acc=0.7910 Prec=0.7532 Rec=0.7160 F1=0.7342 AUC=0.8267
#
# === Fold 9 ===
# Train CN: 13, Train AD: 9
# Test CN: 120, Test AD: 81
# Epoch 1: Sup=0.6728 | DGI=0.7143 | Reg=-0.2841 | Total=1.1031 | TrainAcc=0.4091
# Epoch 500: Sup=0.0738 | DGI=0.6977 | Reg=-0.2988 | Total=0.4727 | TrainAcc=1.0000
# Epoch 1000: Sup=0.0079 | DGI=0.6941 | Reg=-0.3039 | Total=0.3981 | TrainAcc=1.0000
# Epoch 1500: Sup=0.0011 | DGI=0.6963 | Reg=-0.3047 | Total=0.3926 | TrainAcc=1.0000
# Epoch 2000: Sup=0.0011 | DGI=0.6937 | Reg=-0.3059 | Total=0.3889 | TrainAcc=1.0000
# Epoch 2500: Sup=0.0012 | DGI=0.6945 | Reg=-0.3056 | Total=0.3901 | TrainAcc=1.0000
# Fold 9 → Acc=0.7761 Prec=0.7500 Rec=0.6667 F1=0.7059 AUC=0.8329
#
# === Fold 10 ===
# Train CN: 13, Train AD: 9
# Test CN: 120, Test AD: 81
# Epoch 1: Sup=0.7626 | DGI=0.7142 | Reg=-0.2840 | Total=1.1929 | TrainAcc=0.5909
# Epoch 500: Sup=0.4865 | DGI=0.6970 | Reg=-0.2777 | Total=0.9058 | TrainAcc=0.8182
# Epoch 1000: Sup=0.1675 | DGI=0.6982 | Reg=-0.2703 | Total=0.5954 | TrainAcc=0.9545
# Epoch 1500: Sup=0.0055 | DGI=0.6975 | Reg=-0.2952 | Total=0.4078 | TrainAcc=1.0000
# Epoch 2000: Sup=0.0009 | DGI=0.6937 | Reg=-0.2981 | Total=0.3965 | TrainAcc=1.0000
# Epoch 2500: Sup=0.0048 | DGI=0.6940 | Reg=-0.2987 | Total=0.4001 | TrainAcc=1.0000
# Fold 10 → Acc=0.6567 Prec=0.5556 Rec=0.7407 F1=0.6349 AUC=0.7465
#
# === Fold 11 ===
# Train CN: 13, Train AD: 9
# Test CN: 120, Test AD: 81
# Epoch 1: Sup=0.8330 | DGI=0.7124 | Reg=-0.2841 | Total=1.2613 | TrainAcc=0.4091
# Epoch 500: Sup=0.0457 | DGI=0.7147 | Reg=-0.3008 | Total=0.4597 | TrainAcc=0.9545
# Epoch 1000: Sup=0.0004 | DGI=0.7052 | Reg=-0.3030 | Total=0.4026 | TrainAcc=1.0000
# Epoch 1500: Sup=0.0008 | DGI=0.6946 | Reg=-0.3035 | Total=0.3919 | TrainAcc=1.0000
# Epoch 2000: Sup=0.0335 | DGI=0.7059 | Reg=-0.3047 | Total=0.4347 | TrainAcc=1.0000
# Epoch 2500: Sup=0.0002 | DGI=0.6962 | Reg=-0.3051 | Total=0.3913 | TrainAcc=1.0000
# Fold 11 → Acc=0.7960 Prec=0.7632 Rec=0.7160 F1=0.7389 AUC=0.8532
#
# === Fold 12 ===
# Train CN: 13, Train AD: 9
# Test CN: 120, Test AD: 81
# Epoch 1: Sup=0.6910 | DGI=0.7110 | Reg=-0.2843 | Total=1.1177 | TrainAcc=0.4091
# Epoch 500: Sup=0.1838 | DGI=0.6971 | Reg=-0.2995 | Total=0.5813 | TrainAcc=1.0000
# Epoch 1000: Sup=0.0034 | DGI=0.6947 | Reg=-0.3021 | Total=0.3960 | TrainAcc=1.0000
# Epoch 1500: Sup=0.0017 | DGI=0.7142 | Reg=-0.3039 | Total=0.4120 | TrainAcc=1.0000
# Epoch 2000: Sup=0.0003 | DGI=0.6955 | Reg=-0.3058 | Total=0.3900 | TrainAcc=1.0000
# Epoch 2500: Sup=0.0132 | DGI=0.6985 | Reg=-0.3058 | Total=0.4059 | TrainAcc=1.0000
# Fold 12 → Acc=0.7662 Prec=0.6809 Rec=0.7901 F1=0.7314 AUC=0.8318
#
# === Fold 13 ===
# Train CN: 13, Train AD: 9
# Test CN: 120, Test AD: 81
# Epoch 1: Sup=0.7561 | DGI=0.7114 | Reg=-0.2841 | Total=1.1834 | TrainAcc=0.4091
# Epoch 500: Sup=0.0379 | DGI=0.6956 | Reg=-0.2938 | Total=0.4397 | TrainAcc=1.0000
# Epoch 1000: Sup=0.0107 | DGI=0.7256 | Reg=-0.3014 | Total=0.4348 | TrainAcc=1.0000
# Epoch 1500: Sup=0.0009 | DGI=0.6936 | Reg=-0.3021 | Total=0.3924 | TrainAcc=1.0000
# Epoch 2000: Sup=0.0001 | DGI=0.6955 | Reg=-0.3009 | Total=0.3947 | TrainAcc=1.0000
# Epoch 2500: Sup=0.0005 | DGI=0.6937 | Reg=-0.3036 | Total=0.3906 | TrainAcc=1.0000
# Fold 13 → Acc=0.7761 Prec=0.7195 Rec=0.7284 F1=0.7239 AUC=0.8512
#
# === Fold 14 ===
# Train CN: 13, Train AD: 9
# Test CN: 120, Test AD: 81
# Epoch 1: Sup=0.6413 | DGI=0.7129 | Reg=-0.2841 | Total=1.0701 | TrainAcc=0.4091
# Epoch 500: Sup=0.1815 | DGI=0.6967 | Reg=-0.3011 | Total=0.5771 | TrainAcc=0.9545
# Epoch 1000: Sup=0.0051 | DGI=0.7010 | Reg=-0.3037 | Total=0.4025 | TrainAcc=1.0000
# Epoch 1500: Sup=0.0127 | DGI=0.6940 | Reg=-0.3043 | Total=0.4024 | TrainAcc=1.0000
# Epoch 2000: Sup=0.0007 | DGI=0.6937 | Reg=-0.3057 | Total=0.3887 | TrainAcc=1.0000
# Epoch 2500: Sup=0.0033 | DGI=0.6939 | Reg=-0.3060 | Total=0.3912 | TrainAcc=1.0000
# Fold 14 → Acc=0.7562 Prec=0.7051 Rec=0.6790 F1=0.6918 AUC=0.8299
#
# === Fold 15 ===
# Train CN: 13, Train AD: 9
# Test CN: 120, Test AD: 81
# Epoch 1: Sup=0.7213 | DGI=0.7075 | Reg=-0.2840 | Total=1.1448 | TrainAcc=0.5909
# Epoch 500: Sup=0.0845 | DGI=0.6935 | Reg=-0.2970 | Total=0.4810 | TrainAcc=1.0000
# Epoch 1000: Sup=0.0074 | DGI=0.6991 | Reg=-0.3003 | Total=0.4062 | TrainAcc=1.0000
# Epoch 1500: Sup=0.0021 | DGI=0.7007 | Reg=-0.3059 | Total=0.3968 | TrainAcc=1.0000
# Epoch 2000: Sup=0.0008 | DGI=0.7114 | Reg=-0.3045 | Total=0.4076 | TrainAcc=1.0000
# Epoch 2500: Sup=0.0001 | DGI=0.6959 | Reg=-0.3064 | Total=0.3897 | TrainAcc=1.0000
# Fold 15 → Acc=0.7960 Prec=0.7128 Rec=0.8272 F1=0.7657 AUC=0.8437
#
# === Fold 16 ===
# Train CN: 13, Train AD: 9
# Test CN: 120, Test AD: 81
# Epoch 1: Sup=0.7204 | DGI=0.7110 | Reg=-0.2841 | Total=1.1473 | TrainAcc=0.5909
# Epoch 500: Sup=0.0201 | DGI=0.7026 | Reg=-0.3023 | Total=0.4204 | TrainAcc=1.0000
# Epoch 1000: Sup=0.0013 | DGI=0.6938 | Reg=-0.3043 | Total=0.3908 | TrainAcc=1.0000
# Epoch 1500: Sup=0.0028 | DGI=0.6942 | Reg=-0.3042 | Total=0.3928 | TrainAcc=1.0000
# Epoch 2000: Sup=0.0001 | DGI=0.6989 | Reg=-0.3055 | Total=0.3935 | TrainAcc=1.0000
# Epoch 2500: Sup=0.0000 | DGI=0.6954 | Reg=-0.3059 | Total=0.3895 | TrainAcc=1.0000
# Fold 16 → Acc=0.7662 Prec=0.7297 Rec=0.6667 F1=0.6968 AUC=0.8478
#
# === Fold 17 ===
# Train CN: 13, Train AD: 9
# Test CN: 120, Test AD: 81
# Epoch 1: Sup=0.8391 | DGI=0.7108 | Reg=-0.2839 | Total=1.2660 | TrainAcc=0.4091
# Epoch 500: Sup=0.1150 | DGI=0.6962 | Reg=-0.3019 | Total=0.5093 | TrainAcc=1.0000
# Epoch 1000: Sup=0.0014 | DGI=0.6966 | Reg=-0.3035 | Total=0.3945 | TrainAcc=1.0000
# Epoch 1500: Sup=0.0059 | DGI=0.7010 | Reg=-0.3039 | Total=0.4029 | TrainAcc=1.0000
# Epoch 2000: Sup=0.0001 | DGI=0.6935 | Reg=-0.3053 | Total=0.3882 | TrainAcc=1.0000
# Epoch 2500: Sup=0.0002 | DGI=0.6933 | Reg=-0.3052 | Total=0.3883 | TrainAcc=1.0000
# Fold 17 → Acc=0.8010 Prec=0.7253 Rec=0.8148 F1=0.7674 AUC=0.8771
#
# === Fold 18 ===
# Train CN: 13, Train AD: 9
# Test CN: 120, Test AD: 81
# Epoch 1: Sup=0.6368 | DGI=0.7154 | Reg=-0.2842 | Total=1.0680 | TrainAcc=0.5909
# Epoch 500: Sup=0.0178 | DGI=0.6942 | Reg=-0.3089 | Total=0.4030 | TrainAcc=1.0000
# Epoch 1000: Sup=0.0005 | DGI=0.6955 | Reg=-0.3094 | Total=0.3867 | TrainAcc=1.0000
# Epoch 1500: Sup=0.0006 | DGI=0.6941 | Reg=-0.3097 | Total=0.3850 | TrainAcc=1.0000
# Epoch 2000: Sup=0.0001 | DGI=0.7044 | Reg=-0.3098 | Total=0.3947 | TrainAcc=1.0000
# Epoch 2500: Sup=0.0013 | DGI=0.6933 | Reg=-0.3097 | Total=0.3849 | TrainAcc=1.0000
# Fold 18 → Acc=0.7811 Prec=0.7467 Rec=0.6914 F1=0.7179 AUC=0.8247
#
# === Fold 19 ===
# Train CN: 13, Train AD: 9
# Test CN: 120, Test AD: 81
# Epoch 1: Sup=0.6796 | DGI=0.7150 | Reg=-0.2839 | Total=1.1107 | TrainAcc=0.5909
# Epoch 500: Sup=0.1768 | DGI=0.7033 | Reg=-0.2892 | Total=0.5909 | TrainAcc=1.0000
# Epoch 1000: Sup=0.0505 | DGI=0.6950 | Reg=-0.2984 | Total=0.4471 | TrainAcc=1.0000
# Epoch 1500: Sup=0.0003 | DGI=0.6963 | Reg=-0.2975 | Total=0.3991 | TrainAcc=1.0000
# Epoch 2000: Sup=0.0005 | DGI=0.7139 | Reg=-0.2996 | Total=0.4147 | TrainAcc=1.0000
# Epoch 2500: Sup=0.0002 | DGI=0.6934 | Reg=-0.3018 | Total=0.3918 | TrainAcc=1.0000
# Fold 19 → Acc=0.7463 Prec=0.6667 Rec=0.7407 F1=0.7018 AUC=0.8659
#
# === Fold 20 ===
# Train CN: 13, Train AD: 9
# Test CN: 120, Test AD: 81
# Epoch 1: Sup=0.7204 | DGI=0.7085 | Reg=-0.2841 | Total=1.1448 | TrainAcc=0.6364
# Epoch 500: Sup=0.0550 | DGI=0.6987 | Reg=-0.2960 | Total=0.4578 | TrainAcc=1.0000
# Epoch 1000: Sup=0.0045 | DGI=0.7035 | Reg=-0.2990 | Total=0.4090 | TrainAcc=1.0000
# Epoch 1500: Sup=0.0013 | DGI=0.7086 | Reg=-0.3022 | Total=0.4077 | TrainAcc=1.0000
# Epoch 2000: Sup=0.0006 | DGI=0.6933 | Reg=-0.3022 | Total=0.3917 | TrainAcc=1.0000
# Epoch 2500: Sup=0.0043 | DGI=0.6935 | Reg=-0.3044 | Total=0.3934 | TrainAcc=1.0000
# Fold 20 → Acc=0.7114 Prec=0.6186 Rec=0.7407 F1=0.6742 AUC=0.8234
#
# === Average Results ===
# Accuracy: 0.7562 ± 0.0392
# Precision: 0.6990 ± 0.0614
# Recall: 0.7142 ± 0.0592
# F1: 0.7029 ± 0.0365
# LogLoss: 1.8225 ± 0.3119
# AUC: 0.8258 ± 0.0335

# %%
# import torch
# import torch.nn as nn
# import torch.nn.functional as F
# import numpy as np
# import pandas as pd
# from sklearn.model_selection import StratifiedShuffleSplit
# from sklearn.metrics import (
#     accuracy_score, precision_score, recall_score, f1_score,
#     log_loss, roc_auc_score
# )

# A_tensor = torch.from_numpy(W0).to(device)
# hidden_dim = 512
# cut = 0
# num_epochs = 5000
# lr = 1e-4
# weight_decay = 1e-4
# reg_weights = [0.001, 0.005, 0.009, 0.01, 0.05, 0.09, 0.1, 0.3, 0.5, 0.9, 1, 2, 5, 8]
# sss = StratifiedShuffleSplit(n_splits=20, test_size=0.9, random_state=SEED)

# results_summary = []

# for reg_weight in reg_weights:
#     print(f"\n================ REG_WEIGHT = {reg_weight} ================")
#     accuracies, precisions, recalls, f1_scores, losses, all_auc = [], [], [], [], [], []

#     for fold, (train_idx, test_idx) in enumerate(sss.split(X, y)):
#         print(f"\n=== Fold {fold+1} ===")

#         cn_idx = np.where(y == 0)[0]
#         ad_idx = np.where(y == 1)[0]
#         sss_class = StratifiedShuffleSplit(n_splits=20, test_size=0.5, random_state=fold)
#         cn_train_idx, cn_test_idx = next(sss_class.split(X[cn_idx], y[cn_idx]))
#         ad_train_idx, ad_test_idx = next(sss_class.split(X[ad_idx], y[ad_idx]))

#         cn_train = cn_idx[cn_train_idx]
#         ad_train = ad_idx[ad_train_idx]
#         cn_test = cn_idx[cn_test_idx]
#         ad_test = ad_idx[ad_test_idx]

#         balanced_train_idx = np.concatenate([cn_train, ad_train])
#         test_idx = np.concatenate([cn_test, ad_test])
#         np.random.shuffle(balanced_train_idx)
#         np.random.shuffle(test_idx)

#         print(f"Train CN: {len(cn_train)}, Train AD: {len(ad_train)}")
#         print(f"Test CN: {len(cn_test)}, Test AD: {len(ad_test)}")

#         node_feats = node_feats_all.to(device)
#         edge_index = edge_index_all.to(device)
#         y_tensor = torch.from_numpy(y).long().to(device)
#         train_idx_t = torch.from_numpy(balanced_train_idx).long().to(device)
#         test_idx_t = torch.from_numpy(test_idx).long().to(device)

#         N = node_feats.size(0)
#         lbl = torch.cat([torch.ones(N, device=device), torch.zeros(N, device=device)])

#         model = DGI_with_classifier(num_feats, hidden_dim, n_classes=2, cut=cut).to(device)
#         optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
#         bce_loss = nn.BCEWithLogitsLoss()
#         ce_loss = nn.CrossEntropyLoss()

#         for epoch in range(1, num_epochs + 1):
#             model.train()
#             optimizer.zero_grad()
#             perm = torch.randperm(N, device=device)
#             corrupt = node_feats[perm]
#             logits_dgi, embeddings = model(node_feats, corrupt, edge_index)
#             dgi_loss = bce_loss(logits_dgi.squeeze(), lbl)
#             logits_cls = model.classifier(embeddings)
#             train_logits = logits_cls[train_idx_t]
#             train_labels = y_tensor[train_idx_t]
#             supervised_loss = ce_loss(train_logits, train_labels)
#             reg_loss_val = model.Reg_loss(A_tensor, embeddings)
#             total_loss = supervised_loss + dgi_loss + reg_weight * reg_loss_val
#             total_loss.backward()
#             optimizer.step()
#             if epoch % 500 == 0 or epoch == 1:
#                 model.eval()
#                 with torch.no_grad():
#                     logits_eval = model.classifier(model.get_embeddings(node_feats, edge_index))
#                     preds_train = torch.argmax(logits_eval[train_idx_t], dim=1).cpu().numpy()
#                     acc = accuracy_score(train_labels.cpu().numpy(), preds_train)
#                 print(f"Epoch {epoch}: Sup={supervised_loss.item():.4f} | "
#                       f"DGI={dgi_loss.item():.4f} | Reg={reg_loss_val.item():.4f} | "
#                       f"Total={total_loss.item():.4f} | TrainAcc={acc:.4f}")

#         model.eval()
#         with torch.no_grad():
#             emb_final = model.get_embeddings(node_feats, edge_index)
#             logits_final = model.classifier(emb_final)
#             probs = F.softmax(logits_final, dim=1).cpu().numpy()
#             y_pred = np.argmax(probs, axis=1)

#         y_test = y[test_idx]
#         y_pred_test = y_pred[test_idx]
#         y_proba_test = probs[test_idx, 1]

#         acc = accuracy_score(y_test, y_pred_test)
#         prec = precision_score(y_test, y_pred_test, zero_division=0)
#         rec = recall_score(y_test, y_pred_test, zero_division=0)
#         f1 = f1_score(y_test, y_pred_test, zero_division=0)
#         loss_val = log_loss(y_test, y_proba_test)
#         auc_score = roc_auc_score(y_test, y_proba_test)

#         accuracies.append(acc)
#         precisions.append(prec)
#         recalls.append(rec)
#         f1_scores.append(f1)
#         losses.append(loss_val)
#         all_auc.append(auc_score)
#         print(f"Fold {fold+1} → Acc={acc:.4f} Prec={prec:.4f} Rec={rec:.4f} "
#               f"F1={f1:.4f} AUC={auc_score:.4f}")

#     mean_acc, std_acc = np.mean(accuracies), np.std(accuracies)
#     mean_prec, std_prec = np.mean(precisions), np.std(precisions)
#     mean_rec, std_rec = np.mean(recalls), np.std(recalls)
#     mean_f1, std_f1 = np.mean(f1_scores), np.std(f1_scores)
#     mean_loss, std_loss = np.mean(losses), np.std(losses)
#     mean_auc, std_auc = np.mean(all_auc), np.std(all_auc)

#     results_summary.append({
#         "Reg_Weight": reg_weight,
#         "Accuracy": f"{mean_acc:.4f} \u00b1 {std_acc:.4f}",
#         "Precision": f"{mean_prec:.4f} \u00b1 {std_prec:.4f}",
#         "Recall": f"{mean_rec:.4f} \u00b1 {std_rec:.4f}",
#         "F1": f"{mean_f1:.4f} \u00b1 {std_f1:.4f}",
#         "LogLoss": f"{mean_loss:.4f} \u00b1 {std_loss:.4f}",
#         "AUC": f"{mean_auc:.4f} \u00b1 {std_auc:.4f}"
#     })

#     print(f"\n=== Average Results for reg_weight = {reg_weight} ===")
#     print(f"Accuracy: {mean_acc:.4f} \u00b1 {std_acc:.4f}")
#     print(f"Precision: {mean_prec:.4f} \u00b1 {std_prec:.4f}")
#     print(f"Recall: {mean_rec:.4f} \u00b1 {std_rec:.4f}")
#     print(f"F1: {mean_f1:.4f} \u00b1 {std_f1:.4f}")
#     print(f"LogLoss: {mean_loss:.4f} \u00b1 {std_loss:.4f}")
#     print(f"AUC: {mean_auc:.4f} \u00b1 {std_auc:.4f}")

# # ============================
# # Final summary table
# # ============================
# print("\n\n========== FINAL SUMMARY TABLE ==========")
# results_df = pd.DataFrame(results_summary)
# print(results_df.to_string(index=False))

# %%
# import torch
# import torch.nn as nn
# import torch.nn.functional as F
# import numpy as np
# import pandas as pd
# from sklearn.model_selection import StratifiedShuffleSplit
# from sklearn.metrics import (
#     accuracy_score, precision_score, recall_score, f1_score,
#     log_loss, roc_auc_score
# )

# A_tensor = torch.from_numpy(W0).to(device)
# hidden_dim = 512
# cut = 0
# num_epochs = 5000
# lr = 1e-4
# weight_decay = 1e-4
# reg_weights = [0.001, 0.005, 0.009, 0.01, 0.05, 0.09, 0.1, 0.3, 0.5, 0.9, 1, 2, 5, 8]
# sss = StratifiedShuffleSplit(n_splits=20, test_size=0.9, random_state=SEED)

# results_summary = []

# for reg_weight in reg_weights:
#     print(f"\n================ REG_WEIGHT = {reg_weight} ================")
#     accuracies, precisions, recalls, f1_scores, losses, all_auc = [], [], [], [], [], []

#     for fold, (train_idx, test_idx) in enumerate(sss.split(X, y)):
#         print(f"\n=== Fold {fold+1} ===")

#         cn_idx = np.where(y == 0)[0]
#         ad_idx = np.where(y == 1)[0]
#         sss_class = StratifiedShuffleSplit(n_splits=20, test_size=0.1, random_state=fold)
#         cn_train_idx, cn_test_idx = next(sss_class.split(X[cn_idx], y[cn_idx]))
#         ad_train_idx, ad_test_idx = next(sss_class.split(X[ad_idx], y[ad_idx]))

#         cn_train = cn_idx[cn_train_idx]
#         ad_train = ad_idx[ad_train_idx]
#         cn_test = cn_idx[cn_test_idx]
#         ad_test = ad_idx[ad_test_idx]

#         balanced_train_idx = np.concatenate([cn_train, ad_train])
#         test_idx = np.concatenate([cn_test, ad_test])
#         np.random.shuffle(balanced_train_idx)
#         np.random.shuffle(test_idx)

#         print(f"Train CN: {len(cn_train)}, Train AD: {len(ad_train)}")
#         print(f"Test CN: {len(cn_test)}, Test AD: {len(ad_test)}")

#         node_feats = node_feats_all.to(device)
#         edge_index = edge_index_all.to(device)
#         y_tensor = torch.from_numpy(y).long().to(device)
#         train_idx_t = torch.from_numpy(balanced_train_idx).long().to(device)
#         test_idx_t = torch.from_numpy(test_idx).long().to(device)

#         N = node_feats.size(0)
#         lbl = torch.cat([torch.ones(N, device=device), torch.zeros(N, device=device)])

#         model = DGI_with_classifier(num_feats, hidden_dim, n_classes=2, cut=cut).to(device)
#         optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
#         bce_loss = nn.BCEWithLogitsLoss()
#         ce_loss = nn.CrossEntropyLoss()

#         for epoch in range(1, num_epochs + 1):
#             model.train()
#             optimizer.zero_grad()
#             perm = torch.randperm(N, device=device)
#             corrupt = node_feats[perm]
#             logits_dgi, embeddings = model(node_feats, corrupt, edge_index)
#             dgi_loss = bce_loss(logits_dgi.squeeze(), lbl)
#             logits_cls = model.classifier(embeddings)
#             train_logits = logits_cls[train_idx_t]
#             train_labels = y_tensor[train_idx_t]
#             supervised_loss = ce_loss(train_logits, train_labels)
#             reg_loss_val = model.Reg_loss(A_tensor, embeddings)
#             total_loss = supervised_loss + dgi_loss + reg_weight * reg_loss_val
#             total_loss.backward()
#             optimizer.step()
#             if epoch % 500 == 0 or epoch == 1:
#                 model.eval()
#                 with torch.no_grad():
#                     logits_eval = model.classifier(model.get_embeddings(node_feats, edge_index))
#                     preds_train = torch.argmax(logits_eval[train_idx_t], dim=1).cpu().numpy()
#                     acc = accuracy_score(train_labels.cpu().numpy(), preds_train)
#                 print(f"Epoch {epoch}: Sup={supervised_loss.item():.4f} | "
#                       f"DGI={dgi_loss.item():.4f} | Reg={reg_loss_val.item():.4f} | "
#                       f"Total={total_loss.item():.4f} | TrainAcc={acc:.4f}")

#         model.eval()
#         with torch.no_grad():
#             emb_final = model.get_embeddings(node_feats, edge_index)
#             logits_final = model.classifier(emb_final)
#             probs = F.softmax(logits_final, dim=1).cpu().numpy()
#             y_pred = np.argmax(probs, axis=1)

#         y_test = y[test_idx]
#         y_pred_test = y_pred[test_idx]
#         y_proba_test = probs[test_idx, 1]

#         acc = accuracy_score(y_test, y_pred_test)
#         prec = precision_score(y_test, y_pred_test, zero_division=0)
#         rec = recall_score(y_test, y_pred_test, zero_division=0)
#         f1 = f1_score(y_test, y_pred_test, zero_division=0)
#         loss_val = log_loss(y_test, y_proba_test)
#         auc_score = roc_auc_score(y_test, y_proba_test)

#         accuracies.append(acc)
#         precisions.append(prec)
#         recalls.append(rec)
#         f1_scores.append(f1)
#         losses.append(loss_val)
#         all_auc.append(auc_score)
#         print(f"Fold {fold+1} \u2192 Acc={acc:.4f} Prec={prec:.4f} Rec={rec:.4f} "
#               f"F1={f1:.4f} AUC={auc_score:.4f}")

#     mean_acc, std_acc = np.mean(accuracies), np.std(accuracies)
#     mean_prec, std_prec = np.mean(precisions), np.std(precisions)
#     mean_rec, std_rec = np.mean(recalls), np.std(recalls)
#     mean_f1, std_f1 = np.mean(f1_scores), np.std(f1_scores)
#     mean_loss, std_loss = np.mean(losses), np.std(losses)
#     mean_auc, std_auc = np.mean(all_auc), np.std(all_auc)

#     results_summary.append({
#         "Reg_Weight": reg_weight,
#         "Accuracy": f"{mean_acc:.4f} \u00b1 {std_acc:.4f}",
#         "Precision": f"{mean_prec:.4f} \u00b1 {std_prec:.4f}",
#         "Recall": f"{mean_rec:.4f} \u00b1 {std_rec:.4f}",
#         "F1": f"{mean_f1:.4f} \u00b1 {std_f1:.4f}",
#         "LogLoss": f"{mean_loss:.4f} \u00b1 {std_loss:.4f}",
#         "AUC": f"{mean_auc:.4f} \u00b1 {std_auc:.4f}"
#     })

#     print(f"\n=== Average Results for reg_weight = {reg_weight} ===")
#     print(f"Accuracy: {mean_acc:.4f} \u00b1 {std_acc:.4f}")
#     print(f"Precision: {mean_prec:.4f} \u00b1 {std_prec:.4f}")
#     print(f"Recall: {mean_rec:.4f} \u00b1 {std_rec:.4f}")
#     print(f"F1: {mean_f1:.4f} \u00b1 {std_f1:.4f}")
#     print(f"LogLoss: {mean_loss:.4f} \u00b1 {std_loss:.4f}")
#     print(f"AUC: {mean_auc:.4f} \u00b1 {std_auc:.4f}")

# # ============================
# # Final summary table
# # ============================
# print("\n\n========== FINAL SUMMARY TABLE ==========")
# results_df = pd.DataFrame(results_summary)
# print(results_df.to_string(index=False))
