# %%
import os
import sys
import numpy as np
import random
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.data import Data
from torch_geometric.nn import GCNConv
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, log_loss, roc_auc_score, roc_curve
from sklearn.ensemble import RandomForestClassifier  # (only if you want to compare)
import warnings
warnings.filterwarnings("ignore")

# %%
SEED = 42
np.random.seed(SEED)
random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)
torch.set_num_threads(4)

# %%
SEED = 42
np.random.seed(SEED)
random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)
torch.set_num_threads(4)

fa_cn = "/home/snu/Downloads/Histogram_CN_FA_20bin_updated.npy"
fa_ad = "/home/snu/Downloads/Histogram_AD_FA_20bin_updated.npy"

X_cn = np.load(fa_cn, allow_pickle=True)
X_ad = np.load(fa_ad, allow_pickle=True)

X = np.vstack([X_cn, X_ad]).astype(np.float32)
y = np.hstack([
    np.zeros(X_cn.shape[0], dtype=np.int64),
    np.ones(X_ad.shape[0], dtype=np.int64)
])

perm = np.random.RandomState(SEED).permutation(len(X))
X = X[perm]
y = y[perm]

num_nodes, num_feats = X.shape
print(f"Dataset: nodes={num_nodes}, feats={num_feats}")
# Out:
# Dataset: nodes=223, feats=180

# %%
def create_adj(F, alpha=1):
    norms = np.linalg.norm(F, axis=1, keepdims=True)
    norms[norms == 0] = 1.0
    F_norm = F / norms
    W = np.dot(F_norm, F_norm.T)
    W = (W >= alpha).astype(np.float32)
    return W

# %%
W0 = create_adj(X, alpha=0.8)
print(f"W0: {W0.shape}")
# Out:
# W0: (223, 223)

# %%
def load_graph_torch(adj, node_feats):
    node_feats_t = torch.from_numpy(node_feats).float()
    edge_idx = np.array(np.nonzero(adj))
    edge_index = torch.from_numpy(edge_idx).long()
    return node_feats_t, edge_index
node_feats_all, edge_index_all = load_graph_torch(W0, X)
print(f"Number of edges: {edge_index_all.size(1)}")
# Out:
# Number of edges: 41689

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import GATConv

class GATEncoder(torch.nn.Module):
    def __init__(self, input_dim, hidden_dim, device, activ="SELU", heads=1):
        super(GATEncoder, self).__init__()

        activations = {
            "SELU": F.selu,
            "SiLU": F.silu,
            "GELU": F.gelu,
            "ELU": F.elu,
            "RELU": F.relu
        }
        self.act = activations.get(activ, F.elu)

        self.gat = GATConv(
            in_channels=input_dim,
            out_channels=hidden_dim,
            heads=heads,
            dropout=0.3,
            concat=False
        )

        self.batchnorm = nn.BatchNorm1d(hidden_dim)
        self.dropout = nn.Dropout(0.3)
        self.mlp = nn.Linear(hidden_dim, hidden_dim)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = self.gat(x, edge_index)
        x = self.act(x)
        x = self.dropout(x)
        x = self.batchnorm(x)
        logits = self.mlp(x)
        return logits

# %%
class AvgReadout(nn.Module):
    def __init__(self):
        super().__init__()
    def forward(self, seq, msk=None):
        if msk is None:
            return torch.mean(seq, 0)
        else:
            msk = torch.unsqueeze(msk, -1)
            return torch.sum(seq * msk, 0) / torch.sum(msk)

# %%
class Discriminator(nn.Module):
    def __init__(self, n_h):
        super().__init__()
        self.f_k = nn.Bilinear(n_h, n_h, 1)
        nn.init.xavier_uniform_(self.f_k.weight.data)
        if self.f_k.bias is not None:
            self.f_k.bias.data.fill_(0.0)
    def forward(self, c, h_pl, h_mi):
        c_x = torch.unsqueeze(c, 0).expand_as(h_pl)
        sc_1 = torch.squeeze(self.f_k(h_pl, c_x), 1)
        sc_2 = torch.squeeze(self.f_k(h_mi, c_x), 1)
        logits = torch.cat((sc_1, sc_2), 0)
        return logits

# %%
class DGI(nn.Module):
    def __init__(self, n_in, n_h, heads, dropout=0.25):
        super().__init__()
        self.gat1 = GATEncoder(n_in, n_h, heads=heads, device='cuda' if torch.cuda.is_available() else 'cpu', activ=nn.ELU())
        self.read = AvgReadout()
        self.sigm = nn.Sigmoid()
        self.disc = Discriminator(n_h * heads)

    def forward(self, seq1, seq2, edge_index):
        # Create Data objects for the GATEncoder
        data1 = Data(x=seq1, edge_index=edge_index)
        data2 = Data(x=seq2, edge_index=edge_index)

        h_1 = self.gat1(data1)
        c = self.read(h_1)
        c = self.sigm(c)
        h_2 = self.gat1(data2)
        logits = self.disc(c, h_1, h_2)
        return logits, h_1

# %%
class DGI_with_classifier(DGI):
    def __init__(self, n_in, n_h, heads, n_classes=2, cut=0, dropout=0.25):
        super().__init__(n_in, n_h, heads, dropout=dropout)
        self.classifier = nn.Linear(n_h * heads, n_classes)
        self.cut = cut

    def get_embeddings(self, node_feats, edge_index):
        _, embeddings = self.forward(node_feats, node_feats, edge_index)
        return embeddings

    def cut_loss(self, A, S):
        S = F.softmax(S, dim=1)
        A_pool = torch.matmul(torch.matmul(A, S).t(), S)
        num = torch.trace(A_pool)
        D = torch.diag(torch.sum(A, dim=-1))
        D_pooled = torch.matmul(torch.matmul(D, S).t(), S)
        den = torch.trace(D_pooled)
        mincut_loss = -(num / den)
        St_S = torch.matmul(S.t(), S)
        I_S = torch.eye(S.shape[1], device=A.device)
        ortho_loss = torch.norm(St_S / torch.norm(St_S) - I_S / torch.norm(I_S))
        return mincut_loss + ortho_loss

    def modularity_loss(self, A, S):
        C = F.softmax(S, dim=1)
        d = torch.sum(A, dim=1)
        m = torch.sum(A)
        B = A - torch.ger(d, d) / (2 * m)
        I_S = torch.eye(C.shape[1], device=A.device)
        k = torch.norm(I_S)
        n = S.shape[0]
        modularity_term = (-1 / (2 * m)) * torch.trace(torch.mm(torch.mm(C.t(), B), C))
        collapse_reg_term = (torch.sqrt(k) / n) * torch.norm(torch.sum(C, dim=0), p='fro') - 1
        return modularity_term + collapse_reg_term

    def Reg_loss(self, A, embeddings):
        logits = self.classifier(embeddings)
        if self.cut == 1:
            return self.cut_loss(A, logits)
        else:
            return self.modularity_loss(A, logits)

# %%
from sklearn.model_selection import StratifiedShuffleSplit
sss = StratifiedShuffleSplit(n_splits=20, test_size=0.5, random_state=SEED)
accuracies, precisions, recalls, f1_scores, losses = [], [], [], [], []
all_y_true = []
all_y_proba = []
all_fpr, all_tpr, all_auc = [], [], []

# %%
def get_device():
    try:
        if torch.cuda.is_available():
            dev = torch.device("cuda")
            # test a tiny tensor operation to check CUDA health
            torch.tensor([1.0], device=dev) + 1.0
            return dev
    except Exception as e:
        print("CUDA not usable, falling back to CPU:", e)
        try:
            torch.cuda.empty_cache()
        except:
            pass
    return torch.device("cpu")

device = get_device()
print("Using device:", device)
# Out:
# Using device: cuda

# %%
A_tensor = torch.from_numpy(W0).to(device)
hidden_dim = 512
heads = 1
dropout = 0.2
cut = 1
num_epochs = 2500
lr = 1e-4
weight_decay = 1e-4
# sup_weight = 1.0
# dgi_weight = 0.3
reg_weight = 0.001

# %%
for fold, (train_idx, test_idx) in enumerate(sss.split(X, y)):
    print(f"\n=== Fold {fold+1} ===")

    cn_idx = np.where(y == 0)[0]
    ad_idx = np.where(y == 1)[0]

    sss_class = StratifiedShuffleSplit(n_splits=20, test_size=0.9, random_state=fold)
    cn_train_idx, cn_test_idx = next(sss_class.split(X[cn_idx], y[cn_idx]))
    ad_train_idx, ad_test_idx = next(sss_class.split(X[ad_idx], y[ad_idx]))

    cn_train = cn_idx[cn_train_idx]
    ad_train = ad_idx[ad_train_idx]
    cn_test = cn_idx[cn_test_idx]
    ad_test = ad_idx[ad_test_idx]

    balanced_train_idx = np.concatenate([cn_train, ad_train])
    test_idx = np.concatenate([cn_test, ad_test])
    np.random.shuffle(balanced_train_idx)
    np.random.shuffle(test_idx)

    print(f"Train CN: {len(cn_train)}, Train AD: {len(ad_train)}")
    print(f"Test CN: {len(cn_test)}, Test AD: {len(ad_test)}")

    node_feats = node_feats_all.to(device)
    edge_index = edge_index_all.to(device)
    y_tensor = torch.from_numpy(y).long().to(device)
    train_idx_t = torch.from_numpy(balanced_train_idx).long().to(device)
    test_idx_t = torch.from_numpy(test_idx).long().to(device)

    N = node_feats.size(0)
    lbl = torch.cat([torch.ones(N, device=device), torch.zeros(N, device=device)])

    model = DGI_with_classifier(num_feats, hidden_dim, heads=heads, n_classes=2, cut=cut, dropout=dropout).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    bce_loss = nn.BCEWithLogitsLoss()
    ce_loss = nn.CrossEntropyLoss()

    for epoch in range(1, num_epochs + 1):
        model.train()
        optimizer.zero_grad()

        perm = torch.randperm(N, device=device)
        corrupt = node_feats[perm]

        logits_dgi, embeddings = model(node_feats, corrupt, edge_index)
        dgi_loss = bce_loss(logits_dgi.squeeze(), lbl)

        logits_cls = model.classifier(embeddings)
        train_logits = logits_cls[train_idx_t]
        train_labels = y_tensor[train_idx_t]
        supervised_loss = ce_loss(train_logits, train_labels)

        reg_loss_val = model.Reg_loss(A_tensor, embeddings)
        total_loss = supervised_loss + dgi_loss + reg_loss_val

        total_loss.backward()
        optimizer.step()

        if epoch % 500 == 0 or epoch == 1:
            model.eval()
            with torch.no_grad():
                logits_eval = model.classifier(model.get_embeddings(node_feats, edge_index))
                preds_train = torch.argmax(logits_eval[train_idx_t], dim=1).cpu().numpy()
                acc = accuracy_score(train_labels.cpu().numpy(), preds_train)
            print(f"Epoch {epoch}: Sup={supervised_loss.item():.4f} | DGI={dgi_loss.item():.4f} | Reg={reg_loss_val.item():.4f} | Total={total_loss.item():.4f} | TrainAcc={acc:.4f}")
    model.eval()
    with torch.no_grad():
        emb_final = model.get_embeddings(node_feats, edge_index)
        logits_final = model.classifier(emb_final)
        probs = F.softmax(logits_final, dim=1).cpu().numpy()
        y_pred = np.argmax(probs, axis=1)

    y_test = y[test_idx]
    y_pred_test = y_pred[test_idx]
    y_proba_test = probs[test_idx, 1]

    acc = accuracy_score(y_test, y_pred_test)
    prec = precision_score(y_test, y_pred_test, zero_division=0)
    rec = recall_score(y_test, y_pred_test, zero_division=0)
    f1 = f1_score(y_test, y_pred_test, zero_division=0)
    loss_val = log_loss(y_test, y_proba_test)
    auc_score = roc_auc_score(y_test, y_proba_test)

    accuracies.append(acc)
    precisions.append(prec)
    recalls.append(rec)
    f1_scores.append(f1)
    losses.append(loss_val)
    all_auc.append(auc_score)

    print(f"Fold {fold+1} → Acc={acc:.4f} Prec={prec:.4f} Rec={rec:.4f} F1={f1:.4f} AUC={auc_score:.4f}")

print("\n=== Average Results ===")
print(f"Accuracy: {np.mean(accuracies):.4f} \u00b1 {np.std(accuracies):.4f}")
print(f"Precision: {np.mean(precisions):.4f} \u00b1 {np.std(precisions):.4f}")
print(f"Recall: {np.mean(recalls):.4f} \u00b1 {np.std(recalls):.4f}")
print(f"F1: {np.mean(f1_scores):.4f} \u00b1 {np.std(f1_scores):.4f}")
print(f"LogLoss: {np.mean(losses):.4f} \u00b1 {np.std(losses):.4f}")
print(f"AUC: {np.mean(all_auc):.4f} \u00b1 {np.std(all_auc):.4f}")
# Out:
# === Fold 1 ===
# Train CN: 13, Train AD: 9
# Test CN: 120, Test AD: 81
# Epoch 1: Sup=0.6674 | DGI=0.7146 | Reg=-0.2347 | Total=1.1473 | TrainAcc=0.5909
# Epoch 500: Sup=0.2301 | DGI=0.6982 | Reg=-0.4775 | Total=0.4508 | TrainAcc=0.8636
# Epoch 1000: Sup=0.0852 | DGI=0.6961 | Reg=-0.5187 | Total=0.2625 | TrainAcc=0.8636
# Epoch 1500: Sup=0.0022 | DGI=0.7032 | Reg=-0.5249 | Total=0.1804 | TrainAcc=0.9545
# Epoch 2000: Sup=0.0007 | DGI=0.7121 | Reg=-0.5202 | Total=0.1926 | TrainAcc=1.0000
# Epoch 2500: Sup=0.0006 | DGI=0.6939 | Reg=-0.5391 | Total=0.1554 | TrainAcc=1.0000
# Fold 1 → Acc=0.8060 Prec=0.7333 Rec=0.8148 F1=0.7719 AUC=0.8408
#
# === Fold 2 ===
# Train CN: 13, Train AD: 9
# Test CN: 120, Test AD: 81
# Epoch 1: Sup=0.7592 | DGI=0.7166 | Reg=-0.2348 | Total=1.2410 | TrainAcc=0.4091
# Epoch 500: Sup=0.3725 | DGI=0.6962 | Reg=-0.3959 | Total=0.6727 | TrainAcc=0.8636
# Epoch 1000: Sup=0.0193 | DGI=0.6958 | Reg=-0.4874 | Total=0.2277 | TrainAcc=1.0000
# Epoch 1500: Sup=0.0341 | DGI=0.7219 | Reg=-0.5139 | Total=0.2421 | TrainAcc=1.0000
# Epoch 2000: Sup=0.0003 | DGI=0.7188 | Reg=-0.5183 | Total=0.2008 | TrainAcc=1.0000
# Epoch 2500: Sup=0.0002 | DGI=0.7092 | Reg=-0.5143 | Total=0.1951 | TrainAcc=1.0000
# Fold 2 → Acc=0.6915 Prec=0.5922 Rec=0.7531 F1=0.6630 AUC=0.7849
#
# === Fold 3 ===
# Train CN: 13, Train AD: 9
# Test CN: 120, Test AD: 81
# Epoch 1: Sup=0.7212 | DGI=0.7111 | Reg=-0.2391 | Total=1.1932 | TrainAcc=0.4091
# Epoch 500: Sup=0.0254 | DGI=0.6947 | Reg=-0.4879 | Total=0.2322 | TrainAcc=0.9545
# Epoch 1000: Sup=0.0001 | DGI=0.6946 | Reg=-0.5094 | Total=0.1853 | TrainAcc=1.0000
# Epoch 1500: Sup=0.0019 | DGI=0.7010 | Reg=-0.5210 | Total=0.1819 | TrainAcc=1.0000
# Epoch 2000: Sup=0.0001 | DGI=0.6960 | Reg=-0.5133 | Total=0.1828 | TrainAcc=1.0000
# Epoch 2500: Sup=0.0181 | DGI=0.6934 | Reg=-0.5330 | Total=0.1785 | TrainAcc=1.0000
# Fold 3 → Acc=0.7562 Prec=0.7222 Rec=0.6420 F1=0.6797 AUC=0.8251
#
# === Fold 4 ===
# Train CN: 13, Train AD: 9
# Test CN: 120, Test AD: 81
# Epoch 1: Sup=0.6362 | DGI=0.7120 | Reg=-0.2356 | Total=1.1126 | TrainAcc=0.4091
# Epoch 500: Sup=0.0006 | DGI=0.7573 | Reg=-0.5246 | Total=0.2333 | TrainAcc=1.0000
# Epoch 1000: Sup=0.0008 | DGI=0.6971 | Reg=-0.5396 | Total=0.1583 | TrainAcc=1.0000
# Epoch 1500: Sup=0.0005 | DGI=0.6947 | Reg=-0.5398 | Total=0.1554 | TrainAcc=1.0000
# Epoch 2000: Sup=0.0006 | DGI=0.6946 | Reg=-0.5420 | Total=0.1532 | TrainAcc=1.0000
# Epoch 2500: Sup=0.0000 | DGI=0.6955 | Reg=-0.5414 | Total=0.1542 | TrainAcc=1.0000
# Fold 4 → Acc=0.7612 Prec=0.6737 Rec=0.7901 F1=0.7273 AUC=0.8172
#
# === Fold 5 ===
# Train CN: 13, Train AD: 9
# Test CN: 120, Test AD: 81
# Epoch 1: Sup=0.7860 | DGI=0.7134 | Reg=-0.2365 | Total=1.2629 | TrainAcc=0.4091
# Epoch 500: Sup=0.0858 | DGI=0.7021 | Reg=-0.4724 | Total=0.3155 | TrainAcc=0.9091
# Epoch 1000: Sup=0.0007 | DGI=0.7064 | Reg=-0.5217 | Total=0.1854 | TrainAcc=1.0000
# Epoch 1500: Sup=0.0002 | DGI=0.6937 | Reg=-0.5352 | Total=0.1588 | TrainAcc=1.0000
# Epoch 2000: Sup=0.0003 | DGI=0.6933 | Reg=-0.5360 | Total=0.1576 | TrainAcc=1.0000
# Epoch 2500: Sup=0.0007 | DGI=0.6960 | Reg=-0.5390 | Total=0.1578 | TrainAcc=1.0000
# Fold 5 → Acc=0.7711 Prec=0.7108 Rec=0.7284 F1=0.7195 AUC=0.8317
#
# === Fold 6 ===
# Train CN: 13, Train AD: 9
# Test CN: 120, Test AD: 81
# Epoch 1: Sup=0.6073 | DGI=0.7133 | Reg=-0.2394 | Total=1.0811 | TrainAcc=0.4091
# Epoch 500: Sup=0.1340 | DGI=0.7003 | Reg=-0.4751 | Total=0.3593 | TrainAcc=0.9545
# Epoch 1000: Sup=0.0032 | DGI=0.6997 | Reg=-0.4998 | Total=0.2031 | TrainAcc=1.0000
# Epoch 1500: Sup=0.1429 | DGI=0.6944 | Reg=-0.5173 | Total=0.3201 | TrainAcc=1.0000
# Epoch 2000: Sup=0.0007 | DGI=0.6936 | Reg=-0.5284 | Total=0.1660 | TrainAcc=1.0000
# Epoch 2500: Sup=0.0283 | DGI=0.6938 | Reg=-0.5254 | Total=0.1967 | TrainAcc=1.0000
# Fold 6 → Acc=0.7313 Prec=0.6311 Rec=0.8025 F1=0.7065 AUC=0.7946
#
# === Fold 7 ===
# Train CN: 13, Train AD: 9
# Test CN: 120, Test AD: 81
# Epoch 1: Sup=0.6815 | DGI=0.7119 | Reg=-0.2356 | Total=1.1578 | TrainAcc=0.4091
# Epoch 500: Sup=0.4475 | DGI=0.6950 | Reg=-0.4505 | Total=0.6920 | TrainAcc=0.8636
# Epoch 1000: Sup=0.0123 | DGI=0.6946 | Reg=-0.5117 | Total=0.1951 | TrainAcc=1.0000
# Epoch 1500: Sup=0.0003 | DGI=0.6940 | Reg=-0.5236 | Total=0.1708 | TrainAcc=1.0000
# Epoch 2000: Sup=0.0001 | DGI=0.7185 | Reg=-0.5242 | Total=0.1944 | TrainAcc=1.0000
# Epoch 2500: Sup=0.0000 | DGI=0.6950 | Reg=-0.5328 | Total=0.1622 | TrainAcc=1.0000
# Fold 7 → Acc=0.7313 Prec=0.6517 Rec=0.7160 F1=0.6824 AUC=0.7685
#
# === Fold 8 ===
# Train CN: 13, Train AD: 9
# Test CN: 120, Test AD: 81
# Epoch 1: Sup=0.7459 | DGI=0.7132 | Reg=-0.2358 | Total=1.2234 | TrainAcc=0.4091
# Epoch 500: Sup=0.2260 | DGI=0.7100 | Reg=-0.4423 | Total=0.4937 | TrainAcc=0.9091
# Epoch 1000: Sup=0.0056 | DGI=0.7179 | Reg=-0.5077 | Total=0.2158 | TrainAcc=1.0000
# Epoch 1500: Sup=0.0001 | DGI=0.7008 | Reg=-0.5229 | Total=0.1780 | TrainAcc=1.0000
# Epoch 2000: Sup=0.0050 | DGI=0.6979 | Reg=-0.5301 | Total=0.1728 | TrainAcc=1.0000
# Epoch 2500: Sup=0.0005 | DGI=0.6940 | Reg=-0.5261 | Total=0.1684 | TrainAcc=1.0000
# Fold 8 → Acc=0.7960 Prec=0.7439 Rec=0.7531 F1=0.7485 AUC=0.8272
#
# === Fold 9 ===
# Train CN: 13, Train AD: 9
# Test CN: 120, Test AD: 81
# Epoch 1: Sup=0.6728 | DGI=0.7143 | Reg=-0.2350 | Total=1.1522 | TrainAcc=0.4091
# Epoch 500: Sup=0.0407 | DGI=0.6951 | Reg=-0.4942 | Total=0.2416 | TrainAcc=1.0000
# Epoch 1000: Sup=0.0077 | DGI=0.6936 | Reg=-0.5191 | Total=0.1822 | TrainAcc=1.0000
# Epoch 1500: Sup=0.0006 | DGI=0.6976 | Reg=-0.5211 | Total=0.1771 | TrainAcc=1.0000
# Epoch 2000: Sup=0.0004 | DGI=0.7159 | Reg=-0.5353 | Total=0.1810 | TrainAcc=1.0000
# Epoch 2500: Sup=0.0002 | DGI=0.6993 | Reg=-0.5366 | Total=0.1629 | TrainAcc=1.0000
# Fold 9 → Acc=0.8060 Prec=0.7442 Rec=0.7901 F1=0.7665 AUC=0.8383
#
# === Fold 10 ===
# Train CN: 13, Train AD: 9
# Test CN: 120, Test AD: 81
# Epoch 1: Sup=0.7626 | DGI=0.7142 | Reg=-0.2384 | Total=1.2385 | TrainAcc=0.5909
# Epoch 500: Sup=0.4810 | DGI=0.6953 | Reg=-0.3539 | Total=0.8225 | TrainAcc=0.8182
# Epoch 1000: Sup=0.1145 | DGI=0.6989 | Reg=-0.3954 | Total=0.4180 | TrainAcc=0.9545
# Epoch 1500: Sup=0.0006 | DGI=0.6939 | Reg=-0.5004 | Total=0.1942 | TrainAcc=1.0000
# Epoch 2000: Sup=0.0001 | DGI=0.6968 | Reg=-0.5086 | Total=0.1883 | TrainAcc=1.0000
# Epoch 2500: Sup=0.0028 | DGI=0.6970 | Reg=-0.5156 | Total=0.1842 | TrainAcc=1.0000
# Fold 10 → Acc=0.6667 Prec=0.5648 Rec=0.7531 F1=0.6455 AUC=0.7675
#
# === Fold 11 ===
# Train CN: 13, Train AD: 9
# Test CN: 120, Test AD: 81
# Epoch 1: Sup=0.8330 | DGI=0.7124 | Reg=-0.2369 | Total=1.3085 | TrainAcc=0.4091
# Epoch 500: Sup=0.1338 | DGI=0.7182 | Reg=-0.4692 | Total=0.3828 | TrainAcc=0.8182
# Epoch 1000: Sup=0.0409 | DGI=0.6944 | Reg=-0.5105 | Total=0.2248 | TrainAcc=0.7727
# Epoch 1500: Sup=0.0010 | DGI=0.6939 | Reg=-0.5158 | Total=0.1791 | TrainAcc=0.8182
# Epoch 2000: Sup=0.0085 | DGI=0.7047 | Reg=-0.5289 | Total=0.1843 | TrainAcc=0.9091
# Epoch 2500: Sup=0.0003 | DGI=0.6999 | Reg=-0.5327 | Total=0.1675 | TrainAcc=0.9091
# Fold 11 → Acc=0.7960 Prec=0.7778 Rec=0.6914 F1=0.7320 AUC=0.8338
#
# === Fold 12 ===
# Train CN: 13, Train AD: 9
# Test CN: 120, Test AD: 81
# Epoch 1: Sup=0.6910 | DGI=0.7110 | Reg=-0.2395 | Total=1.1625 | TrainAcc=0.4091
# Epoch 500: Sup=0.2153 | DGI=0.7037 | Reg=-0.4899 | Total=0.4290 | TrainAcc=1.0000
# Epoch 1000: Sup=0.0046 | DGI=0.7087 | Reg=-0.5088 | Total=0.2044 | TrainAcc=1.0000
# Epoch 1500: Sup=0.0011 | DGI=0.7058 | Reg=-0.5286 | Total=0.1782 | TrainAcc=1.0000
# Epoch 2000: Sup=0.0000 | DGI=0.6939 | Reg=-0.5198 | Total=0.1742 | TrainAcc=1.0000
# Epoch 2500: Sup=0.0025 | DGI=0.6936 | Reg=-0.5307 | Total=0.1654 | TrainAcc=1.0000
# Fold 12 → Acc=0.7612 Prec=0.6634 Rec=0.8272 F1=0.7363 AUC=0.8277
#
# === Fold 13 ===
# Train CN: 13, Train AD: 9
# Test CN: 120, Test AD: 81
# Epoch 1: Sup=0.7561 | DGI=0.7114 | Reg=-0.2376 | Total=1.2299 | TrainAcc=0.4091
# Epoch 500: Sup=0.0369 | DGI=0.7087 | Reg=-0.4679 | Total=0.2777 | TrainAcc=1.0000
# Epoch 1000: Sup=0.0035 | DGI=0.7063 | Reg=-0.5158 | Total=0.1940 | TrainAcc=1.0000
# Epoch 1500: Sup=0.0003 | DGI=0.6939 | Reg=-0.5217 | Total=0.1725 | TrainAcc=1.0000
# Epoch 2000: Sup=0.0000 | DGI=0.6970 | Reg=-0.5113 | Total=0.1856 | TrainAcc=1.0000
# Epoch 2500: Sup=0.0027 | DGI=0.6934 | Reg=-0.5069 | Total=0.1892 | TrainAcc=1.0000
# Fold 13 → Acc=0.7960 Prec=0.7439 Rec=0.7531 F1=0.7485 AUC=0.8648
#
# === Fold 14 ===
# Train CN: 13, Train AD: 9
# Test CN: 120, Test AD: 81
# Epoch 1: Sup=0.6413 | DGI=0.7129 | Reg=-0.2369 | Total=1.1172 | TrainAcc=0.4091
# Epoch 500: Sup=0.1850 | DGI=0.6967 | Reg=-0.4810 | Total=0.4007 | TrainAcc=0.9545
# Epoch 1000: Sup=0.0051 | DGI=0.7083 | Reg=-0.5071 | Total=0.2062 | TrainAcc=0.9545
# Epoch 1500: Sup=0.0120 | DGI=0.6940 | Reg=-0.5357 | Total=0.1703 | TrainAcc=0.9545
# Epoch 2000: Sup=0.0002 | DGI=0.6949 | Reg=-0.5341 | Total=0.1610 | TrainAcc=0.9545
# Epoch 2500: Sup=0.0003 | DGI=0.6932 | Reg=-0.5226 | Total=0.1710 | TrainAcc=0.9545
# Fold 14 → Acc=0.7711 Prec=0.7215 Rec=0.7037 F1=0.7125 AUC=0.8391
#
# === Fold 15 ===
# Train CN: 13, Train AD: 9
# Test CN: 120, Test AD: 81
# Epoch 1: Sup=0.7213 | DGI=0.7075 | Reg=-0.2402 | Total=1.1885 | TrainAcc=0.5909
# Epoch 500: Sup=0.1376 | DGI=0.6941 | Reg=-0.4700 | Total=0.3617 | TrainAcc=1.0000
# Epoch 1000: Sup=0.0106 | DGI=0.6933 | Reg=-0.5301 | Total=0.1738 | TrainAcc=1.0000
# Epoch 1500: Sup=0.0007 | DGI=0.6970 | Reg=-0.5393 | Total=0.1583 | TrainAcc=1.0000
# Epoch 2000: Sup=0.0006 | DGI=0.7025 | Reg=-0.5346 | Total=0.1685 | TrainAcc=1.0000
# Epoch 2500: Sup=0.0000 | DGI=0.7020 | Reg=-0.5377 | Total=0.1644 | TrainAcc=1.0000
# Fold 15 → Acc=0.7612 Prec=0.6571 Rec=0.8519 F1=0.7419 AUC=0.8411
#
# === Fold 16 ===
# Train CN: 13, Train AD: 9
# Test CN: 120, Test AD: 81
# Epoch 1: Sup=0.7204 | DGI=0.7110 | Reg=-0.2361 | Total=1.1953 | TrainAcc=0.5909
# Epoch 500: Sup=0.0080 | DGI=0.6964 | Reg=-0.5016 | Total=0.2029 | TrainAcc=1.0000
# Epoch 1000: Sup=0.0011 | DGI=0.6947 | Reg=-0.5267 | Total=0.1691 | TrainAcc=1.0000
# Epoch 1500: Sup=0.0071 | DGI=0.6991 | Reg=-0.5264 | Total=0.1797 | TrainAcc=1.0000
# Epoch 2000: Sup=0.0000 | DGI=0.6961 | Reg=-0.5390 | Total=0.1572 | TrainAcc=1.0000
# Epoch 2500: Sup=0.0000 | DGI=0.6938 | Reg=-0.5338 | Total=0.1600 | TrainAcc=1.0000
# Fold 16 → Acc=0.7960 Prec=0.7439 Rec=0.7531 F1=0.7485 AUC=0.8433
#
# === Fold 17 ===
# Train CN: 13, Train AD: 9
# Test CN: 120, Test AD: 81
# Epoch 1: Sup=0.8391 | DGI=0.7108 | Reg=-0.2344 | Total=1.3155 | TrainAcc=0.4091
# Epoch 500: Sup=0.0702 | DGI=0.6999 | Reg=-0.5075 | Total=0.2626 | TrainAcc=1.0000
# Epoch 1000: Sup=0.0007 | DGI=0.6981 | Reg=-0.5271 | Total=0.1717 | TrainAcc=1.0000
# Epoch 1500: Sup=0.0036 | DGI=0.6988 | Reg=-0.5275 | Total=0.1749 | TrainAcc=1.0000
# Epoch 2000: Sup=0.0000 | DGI=0.6936 | Reg=-0.5333 | Total=0.1604 | TrainAcc=1.0000
# Epoch 2500: Sup=0.0000 | DGI=0.6935 | Reg=-0.5324 | Total=0.1611 | TrainAcc=1.0000
# Fold 17 → Acc=0.8109 Prec=0.7216 Rec=0.8642 F1=0.7865 AUC=0.8699
#
# === Fold 18 ===
# Train CN: 13, Train AD: 9
# Test CN: 120, Test AD: 81
# Epoch 1: Sup=0.6368 | DGI=0.7154 | Reg=-0.2398 | Total=1.1123 | TrainAcc=0.5909
# Epoch 500: Sup=0.0234 | DGI=0.6986 | Reg=-0.5319 | Total=0.1902 | TrainAcc=1.0000
# Epoch 1000: Sup=0.0007 | DGI=0.7146 | Reg=-0.5338 | Total=0.1815 | TrainAcc=1.0000
# Epoch 1500: Sup=0.0003 | DGI=0.6933 | Reg=-0.5423 | Total=0.1513 | TrainAcc=1.0000
# Epoch 2000: Sup=0.0000 | DGI=0.7142 | Reg=-0.5456 | Total=0.1687 | TrainAcc=1.0000
# Epoch 2500: Sup=0.0001 | DGI=0.7004 | Reg=-0.5443 | Total=0.1562 | TrainAcc=1.0000
# Fold 18 → Acc=0.7761 Prec=0.7093 Rec=0.7531 F1=0.7305 AUC=0.8119
#
# === Fold 19 ===
# Train CN: 13, Train AD: 9
# Test CN: 120, Test AD: 81
# Epoch 1: Sup=0.6796 | DGI=0.7150 | Reg=-0.2369 | Total=1.1577 | TrainAcc=0.5909
# Epoch 500: Sup=0.1552 | DGI=0.6960 | Reg=-0.4581 | Total=0.3932 | TrainAcc=1.0000
# Epoch 1000: Sup=0.1065 | DGI=0.6950 | Reg=-0.5103 | Total=0.2912 | TrainAcc=1.0000
# Epoch 1500: Sup=0.0001 | DGI=0.7021 | Reg=-0.5061 | Total=0.1961 | TrainAcc=1.0000
# Epoch 2000: Sup=0.0014 | DGI=0.7140 | Reg=-0.5237 | Total=0.1918 | TrainAcc=1.0000
# Epoch 2500: Sup=0.0002 | DGI=0.6946 | Reg=-0.5224 | Total=0.1723 | TrainAcc=1.0000
# Fold 19 → Acc=0.7761 Prec=0.6875 Rec=0.8148 F1=0.7458 AUC=0.8673
#
# === Fold 20 ===
# Train CN: 13, Train AD: 9
# Test CN: 120, Test AD: 81
# Epoch 1: Sup=0.7204 | DGI=0.7085 | Reg=-0.2345 | Total=1.1944 | TrainAcc=0.6364
# Epoch 500: Sup=0.0420 | DGI=0.7114 | Reg=-0.4761 | Total=0.2773 | TrainAcc=1.0000
# Epoch 1000: Sup=0.0017 | DGI=0.7406 | Reg=-0.5013 | Total=0.2410 | TrainAcc=1.0000
# Epoch 1500: Sup=0.0002 | DGI=0.6938 | Reg=-0.5154 | Total=0.1785 | TrainAcc=1.0000
# Epoch 2000: Sup=0.0002 | DGI=0.6954 | Reg=-0.5296 | Total=0.1660 | TrainAcc=1.0000
# Epoch 2500: Sup=0.0049 | DGI=0.6942 | Reg=-0.5329 | Total=0.1662 | TrainAcc=1.0000
# Fold 20 → Acc=0.7065 Prec=0.6122 Rec=0.7407 F1=0.6704 AUC=0.8069
#
# === Average Results ===
# Accuracy: 0.7634 ± 0.0390
# Precision: 0.6903 ± 0.0563
# Recall: 0.7648 ± 0.0540
# F1: 0.7232 ± 0.0373
# LogLoss: 2.4338 ± 0.3851
# AUC: 0.8251 ± 0.0286

# %%
# import torch
# import torch.nn as nn
# import torch.nn.functional as F
# import numpy as np
# import pandas as pd
# from sklearn.model_selection import StratifiedShuffleSplit
# from sklearn.metrics import (
#     accuracy_score, precision_score, recall_score, f1_score,
#     log_loss, roc_auc_score
# )

# A_tensor = torch.from_numpy(W0).to(device)
# hidden_dim = 512
# cut = 0
# num_epochs = 5000
# lr = 1e-4
# weight_decay = 1e-4
# reg_weights = [0.001, 0.005, 0.009, 0.01, 0.05, 0.09, 0.1, 0.3, 0.5, 0.9, 1, 2, 5, 8]
# sss = StratifiedShuffleSplit(n_splits=20, test_size=0.9, random_state=SEED)

# results_summary = []

# for reg_weight in reg_weights:
#     print(f"\n================ REG_WEIGHT = {reg_weight} ================")
#     accuracies, precisions, recalls, f1_scores, losses, all_auc = [], [], [], [], [], []

#     for fold, (train_idx, test_idx) in enumerate(sss.split(X, y)):
#         print(f"\n=== Fold {fold+1} ===")

#         cn_idx = np.where(y == 0)[0]
#         mci_idx = np.where(y == 1)[0]
#         sss_class = StratifiedShuffleSplit(n_splits=20, test_size=0.5, random_state=fold)
#         cn_train_idx, cn_test_idx = next(sss_class.split(X[cn_idx], y[cn_idx]))
#         mci_train_idx, mci_test_idx = next(sss_class.split(X[mci_idx], y[mci_idx]))

#         cn_train = cn_idx[cn_train_idx]
#         mci_train = mci_idx[mci_train_idx]
#         cn_test = cn_idx[cn_test_idx]
#         mci_test = mci_idx[mci_test_idx]

#         balanced_train_idx = np.concatenate([cn_train, mci_train])
#         test_idx = np.concatenate([cn_test, mci_test])
#         np.random.shuffle(balanced_train_idx)
#         np.random.shuffle(test_idx)

#         print(f"Train CN: {len(cn_train)}, Train MCI: {len(mci_train)}")
#         print(f"Test CN: {len(cn_test)}, Test MCI: {len(mci_test)}")

#         node_feats = node_feats_all.to(device)
#         edge_index = edge_index_all.to(device)
#         y_tensor = torch.from_numpy(y).long().to(device)
#         train_idx_t = torch.from_numpy(balanced_train_idx).long().to(device)
#         test_idx_t = torch.from_numpy(test_idx).long().to(device)

#         N = node_feats.size(0)
#         lbl = torch.cat([torch.ones(N, device=device), torch.zeros(N, device=device)])

#         model = DGI_with_classifier(num_feats, hidden_dim, n_classes=2, cut=cut).to(device)
#         optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
#         bce_loss = nn.BCEWithLogitsLoss()
#         ce_loss = nn.CrossEntropyLoss()

#         for epoch in range(1, num_epochs + 1):
#             model.train()
#             optimizer.zero_grad()
#             perm = torch.randperm(N, device=device)
#             corrupt = node_feats[perm]
#             logits_dgi, embeddings = model(node_feats, corrupt, edge_index)
#             dgi_loss = bce_loss(logits_dgi.squeeze(), lbl)
#             logits_cls = model.classifier(embeddings)
#             train_logits = logits_cls[train_idx_t]
#             train_labels = y_tensor[train_idx_t]
#             supervised_loss = ce_loss(train_logits, train_labels)
#             reg_loss_val = model.Reg_loss(A_tensor, embeddings)
#             total_loss = supervised_loss + dgi_loss + reg_weight * reg_loss_val
#             total_loss.backward()
#             optimizer.step()
#             if epoch % 500 == 0 or epoch == 1:
#                 model.eval()
#                 with torch.no_grad():
#                     logits_eval = model.classifier(model.get_embeddings(node_feats, edge_index))
#                     preds_train = torch.argmax(logits_eval[train_idx_t], dim=1).cpu().numpy()
#                     acc = accuracy_score(train_labels.cpu().numpy(), preds_train)
#                 print(f"Epoch {epoch}: Sup={supervised_loss.item():.4f} | "
#                       f"DGI={dgi_loss.item():.4f} | Reg={reg_loss_val.item():.4f} | "
#                       f"Total={total_loss.item():.4f} | TrainAcc={acc:.4f}")

#         model.eval()
#         with torch.no_grad():
#             emb_final = model.get_embeddings(node_feats, edge_index)
#             logits_final = model.classifier(emb_final)
#             probs = F.softmax(logits_final, dim=1).cpu().numpy()
#             y_pred = np.argmax(probs, axis=1)

#         y_test = y[test_idx]
#         y_pred_test = y_pred[test_idx]
#         y_proba_test = probs[test_idx, 1]

#         acc = accuracy_score(y_test, y_pred_test)
#         prec = precision_score(y_test, y_pred_test, zero_division=0)
#         rec = recall_score(y_test, y_pred_test, zero_division=0)
#         f1 = f1_score(y_test, y_pred_test, zero_division=0)
#         loss_val = log_loss(y_test, y_proba_test)
#         auc_score = roc_auc_score(y_test, y_proba_test)

#         accuracies.append(acc)
#         precisions.append(prec)
#         recalls.append(rec)
#         f1_scores.append(f1)
#         losses.append(loss_val)
#         all_auc.append(auc_score)
#         print(f"Fold {fold+1} → Acc={acc:.4f} Prec={prec:.4f} Rec={rec:.4f} "
#               f"F1={f1:.4f} AUC={auc_score:.4f}")

#     mean_acc, std_acc = np.mean(accuracies), np.std(accuracies)
#     mean_prec, std_prec = np.mean(precisions), np.std(precisions)
#     mean_rec, std_rec = np.mean(recalls), np.std(recalls)
#     mean_f1, std_f1 = np.mean(f1_scores), np.std(f1_scores)
#     mean_loss, std_loss = np.mean(losses), np.std(losses)
#     mean_auc, std_auc = np.mean(all_auc), np.std(all_auc)

#     results_summary.append({
#         "Reg_Weight": reg_weight,
#         "Accuracy": f"{mean_acc:.4f} ± {std_acc:.4f}",
#         "Precision": f"{mean_prec:.4f} ± {std_prec:.4f}",
#         "Recall": f"{mean_rec:.4f} ± {std_rec:.4f}",
#         "F1": f"{mean_f1:.4f} ± {std_f1:.4f}",
#         "LogLoss": f"{mean_loss:.4f} ± {std_loss:.4f}",
#         "AUC": f"{mean_auc:.4f} ± {std_auc:.4f}"
#     })

#     print(f"\n=== Average Results for reg_weight = {reg_weight} ===")
#     print(f"Accuracy: {mean_acc:.4f} ± {std_acc:.4f}")
#     print(f"Precision: {mean_prec:.4f} ± {std_prec:.4f}")
#     print(f"Recall: {mean_rec:.4f} ± {std_rec:.4f}")
#     print(f"F1: {mean_f1:.4f} ± {std_f1:.4f}")
#     print(f"LogLoss: {mean_loss:.4f} ± {std_loss:.4f}")
#     print(f"AUC: {mean_auc:.4f} ± {std_auc:.4f}")

# # ============================
# # Final summary table
# # ============================
# print("\n\n========== FINAL SUMMARY TABLE ==========")
# results_df = pd.DataFrame(results_summary)
# print(results_df.to_string(index=False))

# %%
# import torch
# import torch.nn as nn
# import torch.nn.functional as F
# import numpy as np
# import pandas as pd
# from sklearn.model_selection import StratifiedShuffleSplit
# from sklearn.metrics import (
#     accuracy_score, precision_score, recall_score, f1_score,
#     log_loss, roc_auc_score
# )

# A_tensor = torch.from_numpy(W0).to(device)
# hidden_dim = 512
# cut = 0
# num_epochs = 5000
# lr = 1e-4
# weight_decay = 1e-4
# reg_weights = [0.001, 0.005, 0.009, 0.01, 0.05, 0.09, 0.1, 0.3, 0.5, 0.9, 1, 2, 5, 8]
# sss = StratifiedShuffleSplit(n_splits=20, test_size=0.9, random_state=SEED)

# results_summary = []

# for reg_weight in reg_weights:
#     print(f"\n================ REG_WEIGHT = {reg_weight} ================")
#     accuracies, precisions, recalls, f1_scores, losses, all_auc = [], [], [], [], [], []

#     for fold, (train_idx, test_idx) in enumerate(sss.split(X, y)):
#         print(f"\n=== Fold {fold+1} ===")

#         cn_idx = np.where(y == 0)[0]
#         mci_idx = np.where(y == 1)[0]
#         sss_class = StratifiedShuffleSplit(n_splits=20, test_size=0.1, random_state=fold)
#         cn_train_idx, cn_test_idx = next(sss_class.split(X[cn_idx], y[cn_idx]))
#         mci_train_idx, mci_test_idx = next(sss_class.split(X[mci_idx], y[mci_idx]))

#         cn_train = cn_idx[cn_train_idx]
#         mci_train = mci_idx[mci_train_idx]
#         cn_test = cn_idx[cn_test_idx]
#         mci_test = mci_idx[mci_test_idx]

#         balanced_train_idx = np.concatenate([cn_train, mci_train])
#         test_idx = np.concatenate([cn_test, mci_test])
#         np.random.shuffle(balanced_train_idx)
#         np.random.shuffle(test_idx)

#         print(f"Train CN: {len(cn_train)}, Train MCI: {len(mci_train)}")
#         print(f"Test CN: {len(cn_test)}, Test MCI: {len(mci_test)}")

#         node_feats = node_feats_all.to(device)
#         edge_index = edge_index_all.to(device)
#         y_tensor = torch.from_numpy(y).long().to(device)
#         train_idx_t = torch.from_numpy(balanced_train_idx).long().to(device)
#         test_idx_t = torch.from_numpy(test_idx).long().to(device)

#         N = node_feats.size(0)
#         lbl = torch.cat([torch.ones(N, device=device), torch.zeros(N, device=device)])

#         model = DGI_with_classifier(num_feats, hidden_dim, n_classes=2, cut=cut).to(device)
#         optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
#         bce_loss = nn.BCEWithLogitsLoss()
#         ce_loss = nn.CrossEntropyLoss()

#         for epoch in range(1, num_epochs + 1):
#             model.train()
#             optimizer.zero_grad()
#             perm = torch.randperm(N, device=device)
#             corrupt = node_feats[perm]
#             logits_dgi, embeddings = model(node_feats, corrupt, edge_index)
#             dgi_loss = bce_loss(logits_dgi.squeeze(), lbl)
#             logits_cls = model.classifier(embeddings)
#             train_logits = logits_cls[train_idx_t]
#             train_labels = y_tensor[train_idx_t]
#             supervised_loss = ce_loss(train_logits, train_labels)
#             reg_loss_val = model.Reg_loss(A_tensor, embeddings)
#             total_loss = supervised_loss + dgi_loss + reg_weight * reg_loss_val
#             total_loss.backward()
#             optimizer.step()
#             if epoch % 500 == 0 or epoch == 1:
#                 model.eval()
#                 with torch.no_grad():
#                     logits_eval = model.classifier(model.get_embeddings(node_feats, edge_index))
#                     preds_train = torch.argmax(logits_eval[train_idx_t], dim=1).cpu().numpy()
#                     acc = accuracy_score(train_labels.cpu().numpy(), preds_train)
#                 print(f"Epoch {epoch}: Sup={supervised_loss.item():.4f} | "
#                       f"DGI={dgi_loss.item():.4f} | Reg={reg_loss_val.item():.4f} | "
#                       f"Total={total_loss.item():.4f} | TrainAcc={acc:.4f}")

#         model.eval()
#         with torch.no_grad():
#             emb_final = model.get_embeddings(node_feats, edge_index)
#             logits_final = model.classifier(emb_final)
#             probs = F.softmax(logits_final, dim=1).cpu().numpy()
#             y_pred = np.argmax(probs, axis=1)

#         y_test = y[test_idx]
#         y_pred_test = y_pred[test_idx]
#         y_proba_test = probs[test_idx, 1]

#         acc = accuracy_score(y_test, y_pred_test)
#         prec = precision_score(y_test, y_pred_test, zero_division=0)
#         rec = recall_score(y_test, y_pred_test, zero_division=0)
#         f1 = f1_score(y_test, y_pred_test, zero_division=0)
#         loss_val = log_loss(y_test, y_proba_test)
#         auc_score = roc_auc_score(y_test, y_proba_test)

#         accuracies.append(acc)
#         precisions.append(prec)
#         recalls.append(rec)
#         f1_scores.append(f1)
#         losses.append(loss_val)
#         all_auc.append(auc_score)
#         print(f"Fold {fold+1} → Acc={acc:.4f} Prec={prec:.4f} Rec={rec:.4f} "
#               f"F1={f1:.4f} AUC={auc_score:.4f}")

#     mean_acc, std_acc = np.mean(accuracies), np.std(accuracies)
#     mean_prec, std_prec = np.mean(precisions), np.std(precisions)
#     mean_rec, std_rec = np.mean(recalls), np.std(recalls)
#     mean_f1, std_f1 = np.mean(f1_scores), np.std(f1_scores)
#     mean_loss, std_loss = np.mean(losses), np.std(losses)
#     mean_auc, std_auc = np.mean(all_auc), np.std(all_auc)

#     results_summary.append({
#         "Reg_Weight": reg_weight,
#         "Accuracy": f"{mean_acc:.4f} ± {std_acc:.4f}",
#         "Precision": f"{mean_prec:.4f} ± {std_prec:.4f}",
#         "Recall": f"{mean_rec:.4f} ± {std_rec:.4f}",
#         "F1": f"{mean_f1:.4f} ± {std_f1:.4f}",
#         "LogLoss": f"{mean_loss:.4f} ± {std_loss:.4f}",
#         "AUC": f"{mean_auc:.4f} ± {std_auc:.4f}"
#     })

#     print(f"\n=== Average Results for reg_weight = {reg_weight} ===")
#     print(f"Accuracy: {mean_acc:.4f} ± {std_acc:.4f}")
#     print(f"Precision: {mean_prec:.4f} ± {std_prec:.4f}")
#     print(f"Recall: {mean_rec:.4f} ± {std_rec:.4f}")
#     print(f"F1: {mean_f1:.4f} ± {std_f1:.4f}")
#     print(f"LogLoss: {mean_loss:.4f} ± {std_loss:.4f}")
#     print(f"AUC: {mean_auc:.4f} ± {std_auc:.4f}")

# # ============================
# # Final summary table
# # ============================
# print("\n\n========== FINAL SUMMARY TABLE ==========")
# results_df = pd.DataFrame(results_summary)
# print(results_df.to_string(index=False))
