# %%
import torch
import torch.nn as nn
import torch.nn.functional as nnFn
import torch.optim as optim
import numpy as np
import random
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from torch_geometric.data import Data
from torch_geometric.nn import GATConv
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, roc_auc_score, log_loss
)

# %%
fa_feature_path = "/home/snu/Downloads/Histogram_CN_FA_20bin_updated.npy"
Histogram_feature_CN_FA_array = np.load(fa_feature_path, allow_pickle=True)

fa_feature_path = "/home/snu/Downloads/Histogram_AD_FA_20bin_updated.npy"
Histogram_feature_AD_FA_array = np.load(fa_feature_path, allow_pickle=True)

X = np.vstack([Histogram_feature_CN_FA_array, Histogram_feature_AD_FA_array])
y = np.hstack([
    np.zeros(Histogram_feature_CN_FA_array.shape[0], dtype=np.int64),
    np.ones(Histogram_feature_AD_FA_array.shape[0], dtype=np.int64)
])

num_nodes, num_feats = X.shape
print(f"Features: {X.shape}, Labels: {y.shape}")
# Out:
# Features: (223, 180), Labels: (223,)

# %%
class GAT_Supervised(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, heads=4, activ="RELU", dropout=0.2):
        super(GAT_Supervised, self).__init__()
        self.conv1 = GATConv(input_dim, hidden_dim, heads=heads, concat=True, dropout=dropout)
        self.bn1 = nn.BatchNorm1d(hidden_dim * heads)
        self.dropout = nn.Dropout(dropout)
        self.fc = nn.Linear(hidden_dim * heads, output_dim)
        activations = {
            "SELU": nnFn.selu,
            "SiLU": nnFn.silu,
            "GELU": nnFn.gelu,
            "RELU": nnFn.relu,
            "ELU": nnFn.elu
        }
        self.act = activations.get(activ, nnFn.elu)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = self.conv1(x, edge_index)
        x = self.bn1(x)
        x = self.act(x)
        x = self.dropout(x)
        logits = self.fc(x)
        return logits

# %%
def create_adj(F, alpha=1):
    F_norm = F / np.linalg.norm(F, axis=1, keepdims=True)
    W = np.dot(F_norm, F_norm.T)
    W = np.where(W >= alpha, 1, 0).astype(np.float32)
    W = W / W.max()
    return W

def load_data(adj, node_feats):
    node_feats = torch.from_numpy(node_feats).float()
    edge_index = torch.from_numpy(np.array(np.nonzero((adj > 0))))
    return Data(x=node_feats, edge_index=edge_index)

# %%
num_nodes, num_feats = X.shape
print(f"Number of features: {num_feats}")
# Out:
# Number of features: 180

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
alpha = 0.8
feats_dim = num_feats
hidden_dim = 512
num_classes = 2
num_epochs = 2000
lr = 0.0001
weight_decay = 1e-4
batch_print_freq = 100

# %%
W = create_adj(X, alpha)
data = load_data(W, X).to(device)
A_tensor = torch.from_numpy(W).float().to(device)
print(data)
# Out:
# Data(x=[223, 180], edge_index=[2, 41689])

# %%
sss = StratifiedShuffleSplit(n_splits=20, test_size=0.9, random_state=42)

accuracies, precisions, recalls, f1_scores, aucs, ce_losses = [], [], [], [], [], []

for fold, (train_idx, test_idx) in enumerate(sss.split(X, y), start=1):
    print(f"\n=== Fold {fold} ===")

    train_idx_t = torch.from_numpy(train_idx).long().to(device)
    y_train_tensor = torch.from_numpy(y[train_idx]).long().to(device)

    model = GAT_Supervised(feats_dim, hidden_dim, num_classes).to(device)
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    ce_loss = nn.CrossEntropyLoss()


    for epoch in range(1, num_epochs + 1):
        model.train()
        optimizer.zero_grad()

        logits = model(data)
        loss = ce_loss(logits[train_idx_t], y_train_tensor)
        loss.backward()
        optimizer.step()

        if epoch % batch_print_freq == 0 or epoch == 1:
            model.eval()
            with torch.no_grad():
                preds_train = logits[train_idx_t].argmax(dim=1)
                acc_train = accuracy_score(y_train_tensor.cpu(), preds_train.cpu())
            print(f"Fold {fold} Epoch {epoch}: "
                  f"Loss={loss.item():.6f} | TrainAcc={acc_train:.4f}")


    model.eval()
    with torch.no_grad():
        out = model(data)
        preds = out.argmax(dim=1).cpu().numpy()
        probs = torch.softmax(out, dim=1)[:, 1].cpu().numpy()  # Probability for class 1

    y_test = y[test_idx]
    y_pred_test = preds[test_idx]
    y_prob_test = probs[test_idx]


    acc = accuracy_score(y_test, y_pred_test)
    prec = precision_score(y_test, y_pred_test, zero_division=0)
    rec = recall_score(y_test, y_pred_test, zero_division=0)
    f1 = f1_score(y_test, y_pred_test, zero_division=0)
    auc = roc_auc_score(y_test, y_prob_test)
    ce = log_loss(y_test, y_prob_test)

    accuracies.append(acc)
    precisions.append(prec)
    recalls.append(rec)
    f1_scores.append(f1)
    aucs.append(auc)
    ce_losses.append(ce)

    print(f"Fold {fold} → "
          f"Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | "
          f"F1={f1:.4f} | AUC={auc:.4f} | CE Loss={ce:.4f}")


print("\n=== Average Results Across 20 Folds ===")
print(f"Accuracy:  {np.mean(accuracies):.4f} ± {np.std(accuracies):.4f}")
print(f"Precision: {np.mean(precisions):.4f} ± {np.std(precisions):.4f}")
print(f"Recall:    {np.mean(recalls):.4f} ± {np.std(recalls):.4f}")
print(f"F1-score:  {np.mean(f1_scores):.4f} ± {np.std(f1_scores):.4f}")
print(f"CE Loss:   {np.mean(ce_losses):.4f} ± {np.std(ce_losses):.4f}")
print(f"AUC:       {np.mean(aucs):.4f} ± {np.std(aucs):.4f}")
# Out:
# === Fold 1 ===
# Fold 1 Epoch 1: Loss=0.732672 | TrainAcc=0.5000
# Fold 1 Epoch 100: Loss=0.273673 | TrainAcc=0.8182
# Fold 1 Epoch 200: Loss=0.178731 | TrainAcc=0.9091
# Fold 1 Epoch 300: Loss=0.073270 | TrainAcc=1.0000
# Fold 1 Epoch 400: Loss=0.014858 | TrainAcc=1.0000
# Fold 1 Epoch 500: Loss=0.004854 | TrainAcc=1.0000
# Fold 1 Epoch 600: Loss=0.002780 | TrainAcc=1.0000
# Fold 1 Epoch 700: Loss=0.001815 | TrainAcc=1.0000
# Fold 1 Epoch 800: Loss=0.001221 | TrainAcc=1.0000
# Fold 1 Epoch 900: Loss=0.001368 | TrainAcc=1.0000
# Fold 1 Epoch 1000: Loss=0.000892 | TrainAcc=1.0000
# Fold 1 Epoch 1100: Loss=0.001280 | TrainAcc=1.0000
# Fold 1 Epoch 1200: Loss=0.000692 | TrainAcc=1.0000
# Fold 1 Epoch 1300: Loss=0.000471 | TrainAcc=1.0000
# Fold 1 Epoch 1400: Loss=0.000358 | TrainAcc=1.0000
# Fold 1 Epoch 1500: Loss=0.000376 | TrainAcc=1.0000
# Fold 1 Epoch 1600: Loss=0.000347 | TrainAcc=1.0000
# Fold 1 Epoch 1700: Loss=0.000516 | TrainAcc=1.0000
# Fold 1 Epoch 1800: Loss=0.000516 | TrainAcc=1.0000
# Fold 1 Epoch 1900: Loss=0.000611 | TrainAcc=1.0000
# Fold 1 Epoch 2000: Loss=0.000412 | TrainAcc=1.0000
# Fold 1 → Acc=0.7910 | Prec=0.7294 | Rec=0.7654 | F1=0.7470 | AUC=0.8424 | CE Loss=1.2788
#
# === Fold 2 ===
# Fold 2 Epoch 1: Loss=0.800546 | TrainAcc=0.2727
# Fold 2 Epoch 100: Loss=0.573822 | TrainAcc=0.6818
# Fold 2 Epoch 200: Loss=0.509271 | TrainAcc=0.6818
# Fold 2 Epoch 300: Loss=0.342661 | TrainAcc=0.9545
# Fold 2 Epoch 400: Loss=0.046452 | TrainAcc=1.0000
# Fold 2 Epoch 500: Loss=0.015942 | TrainAcc=1.0000
# Fold 2 Epoch 600: Loss=0.007466 | TrainAcc=1.0000
# Fold 2 Epoch 700: Loss=0.003492 | TrainAcc=1.0000
# Fold 2 Epoch 800: Loss=0.002865 | TrainAcc=1.0000
# Fold 2 Epoch 900: Loss=0.001396 | TrainAcc=1.0000
# Fold 2 Epoch 1000: Loss=0.003541 | TrainAcc=1.0000
# Fold 2 Epoch 1100: Loss=0.002602 | TrainAcc=1.0000
# Fold 2 Epoch 1200: Loss=0.001486 | TrainAcc=1.0000
# Fold 2 Epoch 1300: Loss=0.000807 | TrainAcc=1.0000
# Fold 2 Epoch 1400: Loss=0.001013 | TrainAcc=1.0000
# Fold 2 Epoch 1500: Loss=0.000855 | TrainAcc=1.0000
# Fold 2 Epoch 1600: Loss=0.001153 | TrainAcc=1.0000
# Fold 2 Epoch 1700: Loss=0.000333 | TrainAcc=1.0000
# Fold 2 Epoch 1800: Loss=0.000499 | TrainAcc=1.0000
# Fold 2 Epoch 1900: Loss=0.000341 | TrainAcc=1.0000
# Fold 2 Epoch 2000: Loss=0.000982 | TrainAcc=1.0000
# Fold 2 → Acc=0.7313 | Prec=0.6452 | Rec=0.7407 | F1=0.6897 | AUC=0.7945 | CE Loss=1.0158
#
# === Fold 3 ===
# Fold 3 Epoch 1: Loss=0.689630 | TrainAcc=0.5909
# Fold 3 Epoch 100: Loss=0.317012 | TrainAcc=0.8636
# Fold 3 Epoch 200: Loss=0.166300 | TrainAcc=0.9091
# Fold 3 Epoch 300: Loss=0.040749 | TrainAcc=1.0000
# Fold 3 Epoch 400: Loss=0.009323 | TrainAcc=1.0000
# Fold 3 Epoch 500: Loss=0.004789 | TrainAcc=1.0000
# Fold 3 Epoch 600: Loss=0.006650 | TrainAcc=1.0000
# Fold 3 Epoch 700: Loss=0.001719 | TrainAcc=1.0000
# Fold 3 Epoch 800: Loss=0.001616 | TrainAcc=1.0000
# Fold 3 Epoch 900: Loss=0.002651 | TrainAcc=1.0000
# Fold 3 Epoch 1000: Loss=0.001199 | TrainAcc=1.0000
# Fold 3 Epoch 1100: Loss=0.000803 | TrainAcc=1.0000
# Fold 3 Epoch 1200: Loss=0.001657 | TrainAcc=1.0000
# Fold 3 Epoch 1300: Loss=0.000858 | TrainAcc=1.0000
# Fold 3 Epoch 1400: Loss=0.000440 | TrainAcc=1.0000
# Fold 3 Epoch 1500: Loss=0.000278 | TrainAcc=1.0000
# Fold 3 Epoch 1600: Loss=0.000765 | TrainAcc=1.0000
# Fold 3 Epoch 1700: Loss=0.000262 | TrainAcc=1.0000
# Fold 3 Epoch 1800: Loss=0.000309 | TrainAcc=1.0000
# Fold 3 Epoch 1900: Loss=0.000730 | TrainAcc=1.0000
# Fold 3 Epoch 2000: Loss=0.000187 | TrainAcc=1.0000
# Fold 3 → Acc=0.7662 | Prec=0.7656 | Rec=0.6049 | F1=0.6759 | AUC=0.8367 | CE Loss=1.7801
#
# === Fold 4 ===
# Fold 4 Epoch 1: Loss=0.715709 | TrainAcc=0.4545
# Fold 4 Epoch 100: Loss=0.283890 | TrainAcc=0.9545
# Fold 4 Epoch 200: Loss=0.125026 | TrainAcc=1.0000
# Fold 4 Epoch 300: Loss=0.062393 | TrainAcc=1.0000
# Fold 4 Epoch 400: Loss=0.011003 | TrainAcc=1.0000
# Fold 4 Epoch 500: Loss=0.005812 | TrainAcc=1.0000
# Fold 4 Epoch 600: Loss=0.003366 | TrainAcc=1.0000
# Fold 4 Epoch 700: Loss=0.003502 | TrainAcc=1.0000
# Fold 4 Epoch 800: Loss=0.001709 | TrainAcc=1.0000
# Fold 4 Epoch 900: Loss=0.001258 | TrainAcc=1.0000
# Fold 4 Epoch 1000: Loss=0.001754 | TrainAcc=1.0000
# Fold 4 Epoch 1100: Loss=0.001072 | TrainAcc=1.0000
# Fold 4 Epoch 1200: Loss=0.000663 | TrainAcc=1.0000
# Fold 4 Epoch 1300: Loss=0.000637 | TrainAcc=1.0000
# Fold 4 Epoch 1400: Loss=0.000546 | TrainAcc=1.0000
# Fold 4 Epoch 1500: Loss=0.000623 | TrainAcc=1.0000
# Fold 4 Epoch 1600: Loss=0.000206 | TrainAcc=1.0000
# Fold 4 Epoch 1700: Loss=0.000469 | TrainAcc=1.0000
# Fold 4 Epoch 1800: Loss=0.000322 | TrainAcc=1.0000
# Fold 4 Epoch 1900: Loss=0.000318 | TrainAcc=1.0000
# Fold 4 Epoch 2000: Loss=0.000395 | TrainAcc=1.0000
# Fold 4 → Acc=0.7861 | Prec=0.7375 | Rec=0.7284 | F1=0.7329 | AUC=0.8420 | CE Loss=1.2597
#
# === Fold 5 ===
# Fold 5 Epoch 1: Loss=0.679808 | TrainAcc=0.3636
# Fold 5 Epoch 100: Loss=0.382436 | TrainAcc=0.8636
# Fold 5 Epoch 200: Loss=0.231296 | TrainAcc=0.9545
# Fold 5 Epoch 300: Loss=0.106001 | TrainAcc=1.0000
# Fold 5 Epoch 400: Loss=0.055166 | TrainAcc=1.0000
# Fold 5 Epoch 500: Loss=0.044138 | TrainAcc=1.0000
# Fold 5 Epoch 600: Loss=0.008760 | TrainAcc=1.0000
# Fold 5 Epoch 700: Loss=0.015130 | TrainAcc=1.0000
# Fold 5 Epoch 800: Loss=0.002626 | TrainAcc=1.0000
# Fold 5 Epoch 900: Loss=0.001939 | TrainAcc=1.0000
# Fold 5 Epoch 1000: Loss=0.001478 | TrainAcc=1.0000
# Fold 5 Epoch 1100: Loss=0.001009 | TrainAcc=1.0000
# Fold 5 Epoch 1200: Loss=0.003429 | TrainAcc=1.0000
# Fold 5 Epoch 1300: Loss=0.000638 | TrainAcc=1.0000
# Fold 5 Epoch 1400: Loss=0.000576 | TrainAcc=1.0000
# Fold 5 Epoch 1500: Loss=0.001197 | TrainAcc=1.0000
# Fold 5 Epoch 1600: Loss=0.000473 | TrainAcc=1.0000
# Fold 5 Epoch 1700: Loss=0.000738 | TrainAcc=1.0000
# Fold 5 Epoch 1800: Loss=0.000565 | TrainAcc=1.0000
# Fold 5 Epoch 1900: Loss=0.001308 | TrainAcc=1.0000
# Fold 5 Epoch 2000: Loss=0.000384 | TrainAcc=1.0000
# Fold 5 → Acc=0.7711 | Prec=0.7536 | Rec=0.6420 | F1=0.6933 | AUC=0.8490 | CE Loss=1.4233
#
# === Fold 6 ===
# Fold 6 Epoch 1: Loss=0.652165 | TrainAcc=0.7273
# Fold 6 Epoch 100: Loss=0.346719 | TrainAcc=0.7727
# Fold 6 Epoch 200: Loss=0.211847 | TrainAcc=0.8636
# Fold 6 Epoch 300: Loss=0.072546 | TrainAcc=1.0000
# Fold 6 Epoch 400: Loss=0.018170 | TrainAcc=1.0000
# Fold 6 Epoch 500: Loss=0.007449 | TrainAcc=1.0000
# Fold 6 Epoch 600: Loss=0.004130 | TrainAcc=1.0000
# Fold 6 Epoch 700: Loss=0.003712 | TrainAcc=1.0000
# Fold 6 Epoch 800: Loss=0.003001 | TrainAcc=1.0000
# Fold 6 Epoch 900: Loss=0.001322 | TrainAcc=1.0000
# Fold 6 Epoch 1000: Loss=0.001118 | TrainAcc=1.0000
# Fold 6 Epoch 1100: Loss=0.000870 | TrainAcc=1.0000
# Fold 6 Epoch 1200: Loss=0.000862 | TrainAcc=1.0000
# Fold 6 Epoch 1300: Loss=0.003804 | TrainAcc=1.0000
# Fold 6 Epoch 1400: Loss=0.000451 | TrainAcc=1.0000
# Fold 6 Epoch 1500: Loss=0.000486 | TrainAcc=1.0000
# Fold 6 Epoch 1600: Loss=0.000672 | TrainAcc=1.0000
# Fold 6 Epoch 1700: Loss=0.000297 | TrainAcc=1.0000
# Fold 6 Epoch 1800: Loss=0.000252 | TrainAcc=1.0000
# Fold 6 Epoch 1900: Loss=0.000873 | TrainAcc=1.0000
# Fold 6 Epoch 2000: Loss=0.000472 | TrainAcc=1.0000
# Fold 6 → Acc=0.8060 | Prec=0.8182 | Rec=0.6667 | F1=0.7347 | AUC=0.8273 | CE Loss=1.4208
#
# === Fold 7 ===
# Fold 7 Epoch 1: Loss=0.708584 | TrainAcc=0.6364
# Fold 7 Epoch 100: Loss=0.445729 | TrainAcc=0.7273
# Fold 7 Epoch 200: Loss=0.332681 | TrainAcc=0.8182
# Fold 7 Epoch 300: Loss=0.081504 | TrainAcc=1.0000
# Fold 7 Epoch 400: Loss=0.028145 | TrainAcc=1.0000
# Fold 7 Epoch 500: Loss=0.010181 | TrainAcc=1.0000
# Fold 7 Epoch 600: Loss=0.007126 | TrainAcc=1.0000
# Fold 7 Epoch 700: Loss=0.002653 | TrainAcc=1.0000
# Fold 7 Epoch 800: Loss=0.003041 | TrainAcc=1.0000
# Fold 7 Epoch 900: Loss=0.000913 | TrainAcc=1.0000
# Fold 7 Epoch 1000: Loss=0.001720 | TrainAcc=1.0000
# Fold 7 Epoch 1100: Loss=0.000880 | TrainAcc=1.0000
# Fold 7 Epoch 1200: Loss=0.000998 | TrainAcc=1.0000
# Fold 7 Epoch 1300: Loss=0.001172 | TrainAcc=1.0000
# Fold 7 Epoch 1400: Loss=0.000906 | TrainAcc=1.0000
# Fold 7 Epoch 1500: Loss=0.000400 | TrainAcc=1.0000
# Fold 7 Epoch 1600: Loss=0.000408 | TrainAcc=1.0000
# Fold 7 Epoch 1700: Loss=0.000397 | TrainAcc=1.0000
# Fold 7 Epoch 1800: Loss=0.000332 | TrainAcc=1.0000
# Fold 7 Epoch 1900: Loss=0.000313 | TrainAcc=1.0000
# Fold 7 Epoch 2000: Loss=0.000281 | TrainAcc=1.0000
# Fold 7 → Acc=0.7761 | Prec=0.7000 | Rec=0.7778 | F1=0.7368 | AUC=0.8520 | CE Loss=0.9818
#
# === Fold 8 ===
# Fold 8 Epoch 1: Loss=0.763627 | TrainAcc=0.3182
# Fold 8 Epoch 100: Loss=0.549911 | TrainAcc=0.6818
# Fold 8 Epoch 200: Loss=0.447168 | TrainAcc=0.7727
# Fold 8 Epoch 300: Loss=0.098169 | TrainAcc=1.0000
# Fold 8 Epoch 400: Loss=0.029262 | TrainAcc=1.0000
# Fold 8 Epoch 500: Loss=0.010063 | TrainAcc=1.0000
# Fold 8 Epoch 600: Loss=0.003287 | TrainAcc=1.0000
# Fold 8 Epoch 700: Loss=0.002295 | TrainAcc=1.0000
# Fold 8 Epoch 800: Loss=0.001747 | TrainAcc=1.0000
# Fold 8 Epoch 900: Loss=0.000917 | TrainAcc=1.0000
# Fold 8 Epoch 1000: Loss=0.000642 | TrainAcc=1.0000
# Fold 8 Epoch 1100: Loss=0.000681 | TrainAcc=1.0000
# Fold 8 Epoch 1200: Loss=0.001191 | TrainAcc=1.0000
# Fold 8 Epoch 1300: Loss=0.000391 | TrainAcc=1.0000
# Fold 8 Epoch 1400: Loss=0.000529 | TrainAcc=1.0000
# Fold 8 Epoch 1500: Loss=0.000686 | TrainAcc=1.0000
# Fold 8 Epoch 1600: Loss=0.001725 | TrainAcc=1.0000
# Fold 8 Epoch 1700: Loss=0.000330 | TrainAcc=1.0000
# Fold 8 Epoch 1800: Loss=0.000278 | TrainAcc=1.0000
# Fold 8 Epoch 1900: Loss=0.002165 | TrainAcc=1.0000
# Fold 8 Epoch 2000: Loss=0.000405 | TrainAcc=1.0000
# Fold 8 → Acc=0.7910 | Prec=0.7241 | Rec=0.7778 | F1=0.7500 | AUC=0.8615 | CE Loss=0.8638
#
# === Fold 9 ===
# Fold 9 Epoch 1: Loss=0.664664 | TrainAcc=0.5455
# Fold 9 Epoch 100: Loss=0.488071 | TrainAcc=0.7727
# Fold 9 Epoch 200: Loss=0.238132 | TrainAcc=0.9545
# Fold 9 Epoch 300: Loss=0.079975 | TrainAcc=1.0000
# Fold 9 Epoch 400: Loss=0.025581 | TrainAcc=1.0000
# Fold 9 Epoch 500: Loss=0.007527 | TrainAcc=1.0000
# Fold 9 Epoch 600: Loss=0.003054 | TrainAcc=1.0000
# Fold 9 Epoch 700: Loss=0.009466 | TrainAcc=1.0000
# Fold 9 Epoch 800: Loss=0.002681 | TrainAcc=1.0000
# Fold 9 Epoch 900: Loss=0.002459 | TrainAcc=1.0000
# Fold 9 Epoch 1000: Loss=0.001486 | TrainAcc=1.0000
# Fold 9 Epoch 1100: Loss=0.000605 | TrainAcc=1.0000
# Fold 9 Epoch 1200: Loss=0.001222 | TrainAcc=1.0000
# Fold 9 Epoch 1300: Loss=0.000935 | TrainAcc=1.0000
# Fold 9 Epoch 1400: Loss=0.001370 | TrainAcc=1.0000
# Fold 9 Epoch 1500: Loss=0.001522 | TrainAcc=1.0000
# Fold 9 Epoch 1600: Loss=0.000669 | TrainAcc=1.0000
# Fold 9 Epoch 1700: Loss=0.000649 | TrainAcc=1.0000
# Fold 9 Epoch 1800: Loss=0.000989 | TrainAcc=1.0000
# Fold 9 Epoch 1900: Loss=0.000439 | TrainAcc=1.0000
# Fold 9 Epoch 2000: Loss=0.000534 | TrainAcc=1.0000
# Fold 9 → Acc=0.7612 | Prec=0.6941 | Rec=0.7284 | F1=0.7108 | AUC=0.8355 | CE Loss=0.9360
#
# === Fold 10 ===
# Fold 10 Epoch 1: Loss=0.673811 | TrainAcc=0.5909
# Fold 10 Epoch 100: Loss=0.567846 | TrainAcc=0.6818
# Fold 10 Epoch 200: Loss=0.526952 | TrainAcc=0.7727
# Fold 10 Epoch 300: Loss=0.331584 | TrainAcc=0.9091
# Fold 10 Epoch 400: Loss=0.162928 | TrainAcc=0.9545
# Fold 10 Epoch 500: Loss=0.046432 | TrainAcc=1.0000
# Fold 10 Epoch 600: Loss=0.013764 | TrainAcc=1.0000
# Fold 10 Epoch 700: Loss=0.016801 | TrainAcc=1.0000
# Fold 10 Epoch 800: Loss=0.013476 | TrainAcc=1.0000
# Fold 10 Epoch 900: Loss=0.005063 | TrainAcc=1.0000
# Fold 10 Epoch 1000: Loss=0.002234 | TrainAcc=1.0000
# Fold 10 Epoch 1100: Loss=0.005710 | TrainAcc=1.0000
# Fold 10 Epoch 1200: Loss=0.001402 | TrainAcc=1.0000
# Fold 10 Epoch 1300: Loss=0.000567 | TrainAcc=1.0000
# Fold 10 Epoch 1400: Loss=0.001408 | TrainAcc=1.0000
# Fold 10 Epoch 1500: Loss=0.001903 | TrainAcc=1.0000
# Fold 10 Epoch 1600: Loss=0.001575 | TrainAcc=1.0000
# Fold 10 Epoch 1700: Loss=0.000912 | TrainAcc=1.0000
# Fold 10 Epoch 1800: Loss=0.000529 | TrainAcc=1.0000
# Fold 10 Epoch 1900: Loss=0.000642 | TrainAcc=1.0000
# Fold 10 Epoch 2000: Loss=0.000632 | TrainAcc=1.0000
# Fold 10 → Acc=0.7363 | Prec=0.6321 | Rec=0.8272 | F1=0.7166 | AUC=0.8119 | CE Loss=1.2752
#
# === Fold 11 ===
# Fold 11 Epoch 1: Loss=0.729778 | TrainAcc=0.6364
# Fold 11 Epoch 100: Loss=0.285156 | TrainAcc=0.8636
# Fold 11 Epoch 200: Loss=0.208183 | TrainAcc=0.9091
# Fold 11 Epoch 300: Loss=0.116222 | TrainAcc=0.9545
# Fold 11 Epoch 400: Loss=0.053676 | TrainAcc=1.0000
# Fold 11 Epoch 500: Loss=0.008800 | TrainAcc=1.0000
# Fold 11 Epoch 600: Loss=0.005267 | TrainAcc=1.0000
# Fold 11 Epoch 700: Loss=0.002048 | TrainAcc=1.0000
# Fold 11 Epoch 800: Loss=0.001277 | TrainAcc=1.0000
# Fold 11 Epoch 900: Loss=0.001401 | TrainAcc=1.0000
# Fold 11 Epoch 1000: Loss=0.002646 | TrainAcc=1.0000
# Fold 11 Epoch 1100: Loss=0.002088 | TrainAcc=1.0000
# Fold 11 Epoch 1200: Loss=0.000601 | TrainAcc=1.0000
# Fold 11 Epoch 1300: Loss=0.000426 | TrainAcc=1.0000
# Fold 11 Epoch 1400: Loss=0.000488 | TrainAcc=1.0000
# Fold 11 Epoch 1500: Loss=0.001274 | TrainAcc=1.0000
# Fold 11 Epoch 1600: Loss=0.000475 | TrainAcc=1.0000
# Fold 11 Epoch 1700: Loss=0.000807 | TrainAcc=1.0000
# Fold 11 Epoch 1800: Loss=0.000361 | TrainAcc=1.0000
# Fold 11 Epoch 1900: Loss=0.000673 | TrainAcc=1.0000
# Fold 11 Epoch 2000: Loss=0.000503 | TrainAcc=1.0000
# Fold 11 → Acc=0.7960 | Prec=0.7778 | Rec=0.6914 | F1=0.7320 | AUC=0.8533 | CE Loss=1.0632
#
# === Fold 12 ===
# Fold 12 Epoch 1: Loss=0.692933 | TrainAcc=0.5000
# Fold 12 Epoch 100: Loss=0.548618 | TrainAcc=0.6818
# Fold 12 Epoch 200: Loss=0.450499 | TrainAcc=0.8182
# Fold 12 Epoch 300: Loss=0.257020 | TrainAcc=1.0000
# Fold 12 Epoch 400: Loss=0.132923 | TrainAcc=0.9545
# Fold 12 Epoch 500: Loss=0.034810 | TrainAcc=1.0000
# Fold 12 Epoch 600: Loss=0.012746 | TrainAcc=1.0000
# Fold 12 Epoch 700: Loss=0.006692 | TrainAcc=1.0000
# Fold 12 Epoch 800: Loss=0.003452 | TrainAcc=1.0000
# Fold 12 Epoch 900: Loss=0.005537 | TrainAcc=1.0000
# Fold 12 Epoch 1000: Loss=0.003692 | TrainAcc=1.0000
# Fold 12 Epoch 1100: Loss=0.001631 | TrainAcc=1.0000
# Fold 12 Epoch 1200: Loss=0.027753 | TrainAcc=1.0000
# Fold 12 Epoch 1300: Loss=0.000910 | TrainAcc=1.0000
# Fold 12 Epoch 1400: Loss=0.001108 | TrainAcc=1.0000
# Fold 12 Epoch 1500: Loss=0.001784 | TrainAcc=1.0000
# Fold 12 Epoch 1600: Loss=0.000705 | TrainAcc=1.0000
# Fold 12 Epoch 1700: Loss=0.000802 | TrainAcc=1.0000
# Fold 12 Epoch 1800: Loss=0.000877 | TrainAcc=1.0000
# Fold 12 Epoch 1900: Loss=0.000370 | TrainAcc=1.0000
# Fold 12 Epoch 2000: Loss=0.000643 | TrainAcc=1.0000
# Fold 12 → Acc=0.6468 | Prec=0.5862 | Rec=0.4198 | F1=0.4892 | AUC=0.6806 | CE Loss=1.4595
#
# === Fold 13 ===
# Fold 13 Epoch 1: Loss=0.782097 | TrainAcc=0.1818
# Fold 13 Epoch 100: Loss=0.358557 | TrainAcc=0.8182
# Fold 13 Epoch 200: Loss=0.188604 | TrainAcc=0.8636
# Fold 13 Epoch 300: Loss=0.046449 | TrainAcc=1.0000
# Fold 13 Epoch 400: Loss=0.016441 | TrainAcc=1.0000
# Fold 13 Epoch 500: Loss=0.005657 | TrainAcc=1.0000
# Fold 13 Epoch 600: Loss=0.003162 | TrainAcc=1.0000
# Fold 13 Epoch 700: Loss=0.001380 | TrainAcc=1.0000
# Fold 13 Epoch 800: Loss=0.002007 | TrainAcc=1.0000
# Fold 13 Epoch 900: Loss=0.000881 | TrainAcc=1.0000
# Fold 13 Epoch 1000: Loss=0.002860 | TrainAcc=1.0000
# Fold 13 Epoch 1100: Loss=0.001262 | TrainAcc=1.0000
# Fold 13 Epoch 1200: Loss=0.001085 | TrainAcc=1.0000
# Fold 13 Epoch 1300: Loss=0.000755 | TrainAcc=1.0000
# Fold 13 Epoch 1400: Loss=0.000981 | TrainAcc=1.0000
# Fold 13 Epoch 1500: Loss=0.001304 | TrainAcc=1.0000
# Fold 13 Epoch 1600: Loss=0.000580 | TrainAcc=1.0000
# Fold 13 Epoch 1700: Loss=0.000307 | TrainAcc=1.0000
# Fold 13 Epoch 1800: Loss=0.000284 | TrainAcc=1.0000
# Fold 13 Epoch 1900: Loss=0.000505 | TrainAcc=1.0000
# Fold 13 Epoch 2000: Loss=0.000299 | TrainAcc=1.0000
# Fold 13 → Acc=0.7811 | Prec=0.7846 | Rec=0.6296 | F1=0.6986 | AUC=0.8273 | CE Loss=1.5151
#
# === Fold 14 ===
# Fold 14 Epoch 1: Loss=0.679141 | TrainAcc=0.5909
# Fold 14 Epoch 100: Loss=0.534443 | TrainAcc=0.7273
# Fold 14 Epoch 200: Loss=0.420504 | TrainAcc=0.8636
# Fold 14 Epoch 300: Loss=0.290482 | TrainAcc=0.8636
# Fold 14 Epoch 400: Loss=0.036640 | TrainAcc=1.0000
# Fold 14 Epoch 500: Loss=0.031839 | TrainAcc=1.0000
# Fold 14 Epoch 600: Loss=0.007187 | TrainAcc=1.0000
# Fold 14 Epoch 700: Loss=0.008796 | TrainAcc=1.0000
# Fold 14 Epoch 800: Loss=0.002008 | TrainAcc=1.0000
# Fold 14 Epoch 900: Loss=0.001019 | TrainAcc=1.0000
# Fold 14 Epoch 1000: Loss=0.002350 | TrainAcc=1.0000
# Fold 14 Epoch 1100: Loss=0.001254 | TrainAcc=1.0000
# Fold 14 Epoch 1200: Loss=0.002251 | TrainAcc=1.0000
# Fold 14 Epoch 1300: Loss=0.001055 | TrainAcc=1.0000
# Fold 14 Epoch 1400: Loss=0.002216 | TrainAcc=1.0000
# Fold 14 Epoch 1500: Loss=0.000685 | TrainAcc=1.0000
# Fold 14 Epoch 1600: Loss=0.000590 | TrainAcc=1.0000
# Fold 14 Epoch 1700: Loss=0.001105 | TrainAcc=1.0000
# Fold 14 Epoch 1800: Loss=0.000423 | TrainAcc=1.0000
# Fold 14 Epoch 1900: Loss=0.000465 | TrainAcc=1.0000
# Fold 14 Epoch 2000: Loss=0.001197 | TrainAcc=1.0000
# Fold 14 → Acc=0.6915 | Prec=0.6067 | Rec=0.6667 | F1=0.6353 | AUC=0.7624 | CE Loss=1.1835
#
# === Fold 15 ===
# Fold 15 Epoch 1: Loss=0.658452 | TrainAcc=0.7273
# Fold 15 Epoch 100: Loss=0.371466 | TrainAcc=0.8636
# Fold 15 Epoch 200: Loss=0.200144 | TrainAcc=0.9545
# Fold 15 Epoch 300: Loss=0.060960 | TrainAcc=1.0000
# Fold 15 Epoch 400: Loss=0.022618 | TrainAcc=1.0000
# Fold 15 Epoch 500: Loss=0.004088 | TrainAcc=1.0000
# Fold 15 Epoch 600: Loss=0.004271 | TrainAcc=1.0000
# Fold 15 Epoch 700: Loss=0.001772 | TrainAcc=1.0000
# Fold 15 Epoch 800: Loss=0.003022 | TrainAcc=1.0000
# Fold 15 Epoch 900: Loss=0.004726 | TrainAcc=1.0000
# Fold 15 Epoch 1000: Loss=0.002172 | TrainAcc=1.0000
# Fold 15 Epoch 1100: Loss=0.000773 | TrainAcc=1.0000
# Fold 15 Epoch 1200: Loss=0.001152 | TrainAcc=1.0000
# Fold 15 Epoch 1300: Loss=0.000477 | TrainAcc=1.0000
# Fold 15 Epoch 1400: Loss=0.001811 | TrainAcc=1.0000
# Fold 15 Epoch 1500: Loss=0.000792 | TrainAcc=1.0000
# Fold 15 Epoch 1600: Loss=0.000240 | TrainAcc=1.0000
# Fold 15 Epoch 1700: Loss=0.000333 | TrainAcc=1.0000
# Fold 15 Epoch 1800: Loss=0.000680 | TrainAcc=1.0000
# Fold 15 Epoch 1900: Loss=0.000545 | TrainAcc=1.0000
# Fold 15 Epoch 2000: Loss=0.000241 | TrainAcc=1.0000
# Fold 15 → Acc=0.7861 | Prec=0.7714 | Rec=0.6667 | F1=0.7152 | AUC=0.8345 | CE Loss=1.2429
#
# === Fold 16 ===
# Fold 16 Epoch 1: Loss=0.631593 | TrainAcc=0.7727
# Fold 16 Epoch 100: Loss=0.388126 | TrainAcc=0.8636
# Fold 16 Epoch 200: Loss=0.211284 | TrainAcc=0.9091
# Fold 16 Epoch 300: Loss=0.071129 | TrainAcc=0.9545
# Fold 16 Epoch 400: Loss=0.012842 | TrainAcc=1.0000
# Fold 16 Epoch 500: Loss=0.008925 | TrainAcc=1.0000
# Fold 16 Epoch 600: Loss=0.003808 | TrainAcc=1.0000
# Fold 16 Epoch 700: Loss=0.003027 | TrainAcc=1.0000
# Fold 16 Epoch 800: Loss=0.001888 | TrainAcc=1.0000
# Fold 16 Epoch 900: Loss=0.000991 | TrainAcc=1.0000
# Fold 16 Epoch 1000: Loss=0.000633 | TrainAcc=1.0000
# Fold 16 Epoch 1100: Loss=0.003310 | TrainAcc=1.0000
# Fold 16 Epoch 1200: Loss=0.000581 | TrainAcc=1.0000
# Fold 16 Epoch 1300: Loss=0.001037 | TrainAcc=1.0000
# Fold 16 Epoch 1400: Loss=0.001197 | TrainAcc=1.0000
# Fold 16 Epoch 1500: Loss=0.001163 | TrainAcc=1.0000
# Fold 16 Epoch 1600: Loss=0.000606 | TrainAcc=1.0000
# Fold 16 Epoch 1700: Loss=0.001043 | TrainAcc=1.0000
# Fold 16 Epoch 1800: Loss=0.000582 | TrainAcc=1.0000
# Fold 16 Epoch 1900: Loss=0.000387 | TrainAcc=1.0000
# Fold 16 Epoch 2000: Loss=0.000613 | TrainAcc=1.0000
# Fold 16 → Acc=0.8060 | Prec=0.8182 | Rec=0.6667 | F1=0.7347 | AUC=0.8531 | CE Loss=1.1480
#
# === Fold 17 ===
# Fold 17 Epoch 1: Loss=0.715089 | TrainAcc=0.5455
# Fold 17 Epoch 100: Loss=0.298597 | TrainAcc=0.9091
# Fold 17 Epoch 200: Loss=0.175947 | TrainAcc=0.9545
# Fold 17 Epoch 300: Loss=0.101909 | TrainAcc=0.9545
# Fold 17 Epoch 400: Loss=0.015493 | TrainAcc=1.0000
# Fold 17 Epoch 500: Loss=0.004346 | TrainAcc=1.0000
# Fold 17 Epoch 600: Loss=0.004921 | TrainAcc=1.0000
# Fold 17 Epoch 700: Loss=0.001664 | TrainAcc=1.0000
# Fold 17 Epoch 800: Loss=0.002388 | TrainAcc=1.0000
# Fold 17 Epoch 900: Loss=0.001124 | TrainAcc=1.0000
# Fold 17 Epoch 1000: Loss=0.001088 | TrainAcc=1.0000
# Fold 17 Epoch 1100: Loss=0.001688 | TrainAcc=1.0000
# Fold 17 Epoch 1200: Loss=0.000636 | TrainAcc=1.0000
# Fold 17 Epoch 1300: Loss=0.000575 | TrainAcc=1.0000
# Fold 17 Epoch 1400: Loss=0.000555 | TrainAcc=1.0000
# Fold 17 Epoch 1500: Loss=0.000233 | TrainAcc=1.0000
# Fold 17 Epoch 1600: Loss=0.000272 | TrainAcc=1.0000
# Fold 17 Epoch 1700: Loss=0.000489 | TrainAcc=1.0000
# Fold 17 Epoch 1800: Loss=0.000786 | TrainAcc=1.0000
# Fold 17 Epoch 1900: Loss=0.001278 | TrainAcc=1.0000
# Fold 17 Epoch 2000: Loss=0.002208 | TrainAcc=1.0000
# Fold 17 → Acc=0.7512 | Prec=0.7385 | Rec=0.5926 | F1=0.6575 | AUC=0.8053 | CE Loss=1.7667
#
# === Fold 18 ===
# Fold 18 Epoch 1: Loss=0.707739 | TrainAcc=0.3182
# Fold 18 Epoch 100: Loss=0.335005 | TrainAcc=0.8182
# Fold 18 Epoch 200: Loss=0.265735 | TrainAcc=0.8636
# Fold 18 Epoch 300: Loss=0.190273 | TrainAcc=0.9545
# Fold 18 Epoch 400: Loss=0.029055 | TrainAcc=1.0000
# Fold 18 Epoch 500: Loss=0.008731 | TrainAcc=1.0000
# Fold 18 Epoch 600: Loss=0.006131 | TrainAcc=1.0000
# Fold 18 Epoch 700: Loss=0.003724 | TrainAcc=1.0000
# Fold 18 Epoch 800: Loss=0.003840 | TrainAcc=1.0000
# Fold 18 Epoch 900: Loss=0.007909 | TrainAcc=1.0000
# Fold 18 Epoch 1000: Loss=0.001093 | TrainAcc=1.0000
# Fold 18 Epoch 1100: Loss=0.000642 | TrainAcc=1.0000
# Fold 18 Epoch 1200: Loss=0.001533 | TrainAcc=1.0000
# Fold 18 Epoch 1300: Loss=0.000806 | TrainAcc=1.0000
# Fold 18 Epoch 1400: Loss=0.000618 | TrainAcc=1.0000
# Fold 18 Epoch 1500: Loss=0.001128 | TrainAcc=1.0000
# Fold 18 Epoch 1600: Loss=0.000296 | TrainAcc=1.0000
# Fold 18 Epoch 1700: Loss=0.000718 | TrainAcc=1.0000
# Fold 18 Epoch 1800: Loss=0.000216 | TrainAcc=1.0000
# Fold 18 Epoch 1900: Loss=0.000743 | TrainAcc=1.0000
# Fold 18 Epoch 2000: Loss=0.000710 | TrainAcc=1.0000
# Fold 18 → Acc=0.7612 | Prec=0.8000 | Rec=0.5432 | F1=0.6471 | AUC=0.8227 | CE Loss=1.7165
#
# === Fold 19 ===
# Fold 19 Epoch 1: Loss=0.745187 | TrainAcc=0.4091
# Fold 19 Epoch 100: Loss=0.379906 | TrainAcc=0.7727
# Fold 19 Epoch 200: Loss=0.340121 | TrainAcc=0.8182
# Fold 19 Epoch 300: Loss=0.232146 | TrainAcc=0.8636
# Fold 19 Epoch 400: Loss=0.063889 | TrainAcc=1.0000
# Fold 19 Epoch 500: Loss=0.012890 | TrainAcc=1.0000
# Fold 19 Epoch 600: Loss=0.009265 | TrainAcc=1.0000
# Fold 19 Epoch 700: Loss=0.005227 | TrainAcc=1.0000
# Fold 19 Epoch 800: Loss=0.003791 | TrainAcc=1.0000
# Fold 19 Epoch 900: Loss=0.002072 | TrainAcc=1.0000
# Fold 19 Epoch 1000: Loss=0.001580 | TrainAcc=1.0000
# Fold 19 Epoch 1100: Loss=0.001061 | TrainAcc=1.0000
# Fold 19 Epoch 1200: Loss=0.004711 | TrainAcc=1.0000
# Fold 19 Epoch 1300: Loss=0.003649 | TrainAcc=1.0000
# Fold 19 Epoch 1400: Loss=0.001472 | TrainAcc=1.0000
# Fold 19 Epoch 1500: Loss=0.000618 | TrainAcc=1.0000
# Fold 19 Epoch 1600: Loss=0.000630 | TrainAcc=1.0000
# Fold 19 Epoch 1700: Loss=0.000620 | TrainAcc=1.0000
# Fold 19 Epoch 1800: Loss=0.001005 | TrainAcc=1.0000
# Fold 19 Epoch 1900: Loss=0.000404 | TrainAcc=1.0000
# Fold 19 Epoch 2000: Loss=0.001280 | TrainAcc=1.0000
# Fold 19 → Acc=0.7313 | Prec=0.6753 | Rec=0.6420 | F1=0.6582 | AUC=0.7756 | CE Loss=1.3419
#
# === Fold 20 ===
# Fold 20 Epoch 1: Loss=0.709203 | TrainAcc=0.3636
# Fold 20 Epoch 100: Loss=0.502617 | TrainAcc=0.6818
# Fold 20 Epoch 200: Loss=0.327741 | TrainAcc=0.8636
# Fold 20 Epoch 300: Loss=0.105125 | TrainAcc=0.9545
# Fold 20 Epoch 400: Loss=0.029783 | TrainAcc=1.0000
# Fold 20 Epoch 500: Loss=0.006451 | TrainAcc=1.0000
# Fold 20 Epoch 600: Loss=0.003407 | TrainAcc=1.0000
# Fold 20 Epoch 700: Loss=0.002737 | TrainAcc=1.0000
# Fold 20 Epoch 800: Loss=0.002401 | TrainAcc=1.0000
# Fold 20 Epoch 900: Loss=0.001710 | TrainAcc=1.0000
# Fold 20 Epoch 1000: Loss=0.001015 | TrainAcc=1.0000
# Fold 20 Epoch 1100: Loss=0.001261 | TrainAcc=1.0000
# Fold 20 Epoch 1200: Loss=0.001166 | TrainAcc=1.0000
# Fold 20 Epoch 1300: Loss=0.000373 | TrainAcc=1.0000
# Fold 20 Epoch 1400: Loss=0.000390 | TrainAcc=1.0000
# Fold 20 Epoch 1500: Loss=0.000550 | TrainAcc=1.0000
# Fold 20 Epoch 1600: Loss=0.000253 | TrainAcc=1.0000
# Fold 20 Epoch 1700: Loss=0.000552 | TrainAcc=1.0000
# Fold 20 Epoch 1800: Loss=0.000245 | TrainAcc=1.0000
# Fold 20 Epoch 1900: Loss=0.000474 | TrainAcc=1.0000
# Fold 20 Epoch 2000: Loss=0.000472 | TrainAcc=1.0000
# Fold 20 → Acc=0.5323 | Prec=0.4611 | Rec=0.9506 | F1=0.6210 | AUC=0.7724 | CE Loss=3.1654
#
# === Average Results Across 20 Folds ===
# Accuracy:  0.7500 ± 0.0630
# Precision: 0.7110 ± 0.0873
# Recall:    0.6864 ± 0.1084
# F1-score:  0.6888 ± 0.0594
# CE Loss:   1.3919 ± 0.4816
# AUC:       0.8170 ± 0.0420

# %%
sss = StratifiedShuffleSplit(n_splits=20, test_size=0.3, random_state=42)

accuracies, precisions, recalls, f1_scores, aucs, ce_losses = [], [], [], [], [], []

for fold, (train_idx, test_idx) in enumerate(sss.split(X, y), start=1):
    print(f"\n=== Fold {fold} ===")

    train_idx_t = torch.from_numpy(train_idx).long().to(device)
    y_train_tensor = torch.from_numpy(y[train_idx]).long().to(device)

    model = GAT_Supervised(feats_dim, hidden_dim, num_classes).to(device)
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    ce_loss = nn.CrossEntropyLoss()


    for epoch in range(1, num_epochs + 1):
        model.train()
        optimizer.zero_grad()

        logits = model(data)
        loss = ce_loss(logits[train_idx_t], y_train_tensor)
        loss.backward()
        optimizer.step()

        if epoch % batch_print_freq == 0 or epoch == 1:
            model.eval()
            with torch.no_grad():
                preds_train = logits[train_idx_t].argmax(dim=1)
                acc_train = accuracy_score(y_train_tensor.cpu(), preds_train.cpu())
            print(f"Fold {fold} Epoch {epoch}: "
                  f"Loss={loss.item():.6f} | TrainAcc={acc_train:.4f}")


    model.eval()
    with torch.no_grad():
        out = model(data)
        preds = out.argmax(dim=1).cpu().numpy()
        probs = torch.softmax(out, dim=1)[:, 1].cpu().numpy()  # Probability for class 1

    y_test = y[test_idx]
    y_pred_test = preds[test_idx]
    y_prob_test = probs[test_idx]


    acc = accuracy_score(y_test, y_pred_test)
    prec = precision_score(y_test, y_pred_test, zero_division=0)
    rec = recall_score(y_test, y_pred_test, zero_division=0)
    f1 = f1_score(y_test, y_pred_test, zero_division=0)
    auc = roc_auc_score(y_test, y_prob_test)
    ce = log_loss(y_test, y_prob_test)

    accuracies.append(acc)
    precisions.append(prec)
    recalls.append(rec)
    f1_scores.append(f1)
    aucs.append(auc)
    ce_losses.append(ce)

    print(f"Fold {fold} → "
          f"Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | "
          f"F1={f1:.4f} | AUC={auc:.4f} | CE Loss={ce:.4f}")


print("\n=== Average Results Across 20 Folds ===")
print(f"Accuracy:  {np.mean(accuracies):.4f} ± {np.std(accuracies):.4f}")
print(f"Precision: {np.mean(precisions):.4f} ± {np.std(precisions):.4f}")
print(f"Recall:    {np.mean(recalls):.4f} ± {np.std(recalls):.4f}")
print(f"F1-score:  {np.mean(f1_scores):.4f} ± {np.std(f1_scores):.4f}")
print(f"CE Loss:   {np.mean(ce_losses):.4f} ± {np.std(ce_losses):.4f}")
print(f"AUC:       {np.mean(aucs):.4f} ± {np.std(aucs):.4f}")
# Out:
# === Fold 1 ===
# Fold 1 Epoch 1: Loss=0.677825 | TrainAcc=0.5962
# Fold 1 Epoch 100: Loss=0.421072 | TrainAcc=0.8205
# Fold 1 Epoch 200: Loss=0.312741 | TrainAcc=0.8590
# Fold 1 Epoch 300: Loss=0.217347 | TrainAcc=0.9167
# Fold 1 Epoch 400: Loss=0.119140 | TrainAcc=0.9295
# Fold 1 Epoch 500: Loss=0.052396 | TrainAcc=0.9808
# Fold 1 Epoch 600: Loss=0.032940 | TrainAcc=0.9936
# Fold 1 Epoch 700: Loss=0.014470 | TrainAcc=1.0000
# Fold 1 Epoch 800: Loss=0.005173 | TrainAcc=1.0000
# Fold 1 Epoch 900: Loss=0.022443 | TrainAcc=0.9872
# Fold 1 Epoch 1000: Loss=0.013288 | TrainAcc=1.0000
# Fold 1 Epoch 1100: Loss=0.019187 | TrainAcc=0.9936
# Fold 1 Epoch 1200: Loss=0.003376 | TrainAcc=1.0000
# Fold 1 Epoch 1300: Loss=0.006426 | TrainAcc=1.0000
# Fold 1 Epoch 1400: Loss=0.002716 | TrainAcc=1.0000
# Fold 1 Epoch 1500: Loss=0.002778 | TrainAcc=1.0000
# Fold 1 Epoch 1600: Loss=0.004142 | TrainAcc=1.0000
# Fold 1 Epoch 1700: Loss=0.002656 | TrainAcc=1.0000
# Fold 1 Epoch 1800: Loss=0.002557 | TrainAcc=1.0000
# Fold 1 Epoch 1900: Loss=0.001894 | TrainAcc=1.0000
# Fold 1 Epoch 2000: Loss=0.001150 | TrainAcc=1.0000
# Fold 1 → Acc=0.8060 | Prec=0.7059 | Rec=0.8889 | F1=0.7869 | AUC=0.9148 | CE Loss=1.1655
#
# === Fold 2 ===
# Fold 2 Epoch 1: Loss=0.738069 | TrainAcc=0.5128
# Fold 2 Epoch 100: Loss=0.475749 | TrainAcc=0.7628
# Fold 2 Epoch 200: Loss=0.342740 | TrainAcc=0.8526
# Fold 2 Epoch 300: Loss=0.147824 | TrainAcc=0.9615
# Fold 2 Epoch 400: Loss=0.089560 | TrainAcc=0.9872
# Fold 2 Epoch 500: Loss=0.033521 | TrainAcc=0.9872
# Fold 2 Epoch 600: Loss=0.015977 | TrainAcc=0.9936
# Fold 2 Epoch 700: Loss=0.006701 | TrainAcc=1.0000
# Fold 2 Epoch 800: Loss=0.012602 | TrainAcc=0.9936
# Fold 2 Epoch 900: Loss=0.007813 | TrainAcc=1.0000
# Fold 2 Epoch 1000: Loss=0.005709 | TrainAcc=1.0000
# Fold 2 Epoch 1100: Loss=0.003453 | TrainAcc=1.0000
# Fold 2 Epoch 1200: Loss=0.002076 | TrainAcc=1.0000
# Fold 2 Epoch 1300: Loss=0.003499 | TrainAcc=1.0000
# Fold 2 Epoch 1400: Loss=0.003185 | TrainAcc=1.0000
# Fold 2 Epoch 1500: Loss=0.007326 | TrainAcc=0.9936
# Fold 2 Epoch 1600: Loss=0.002513 | TrainAcc=1.0000
# Fold 2 Epoch 1700: Loss=0.000663 | TrainAcc=1.0000
# Fold 2 Epoch 1800: Loss=0.003498 | TrainAcc=1.0000
# Fold 2 Epoch 1900: Loss=0.002273 | TrainAcc=1.0000
# Fold 2 Epoch 2000: Loss=0.001014 | TrainAcc=1.0000
# Fold 2 → Acc=0.7015 | Prec=0.6296 | Rec=0.6296 | F1=0.6296 | AUC=0.8134 | CE Loss=2.3983
#
# === Fold 3 ===
# Fold 3 Epoch 1: Loss=0.747873 | TrainAcc=0.4744
# Fold 3 Epoch 100: Loss=0.472230 | TrainAcc=0.7949
# Fold 3 Epoch 200: Loss=0.330938 | TrainAcc=0.8654
# Fold 3 Epoch 300: Loss=0.205401 | TrainAcc=0.9359
# Fold 3 Epoch 400: Loss=0.123513 | TrainAcc=0.9615
# Fold 3 Epoch 500: Loss=0.098132 | TrainAcc=0.9744
# Fold 3 Epoch 600: Loss=0.032735 | TrainAcc=0.9936
# Fold 3 Epoch 700: Loss=0.028070 | TrainAcc=0.9872
# Fold 3 Epoch 800: Loss=0.028506 | TrainAcc=0.9872
# Fold 3 Epoch 900: Loss=0.012381 | TrainAcc=1.0000
# Fold 3 Epoch 1000: Loss=0.006883 | TrainAcc=1.0000
# Fold 3 Epoch 1100: Loss=0.005206 | TrainAcc=1.0000
# Fold 3 Epoch 1200: Loss=0.002173 | TrainAcc=1.0000
# Fold 3 Epoch 1300: Loss=0.002213 | TrainAcc=1.0000
# Fold 3 Epoch 1400: Loss=0.003304 | TrainAcc=1.0000
# Fold 3 Epoch 1500: Loss=0.002166 | TrainAcc=1.0000
# Fold 3 Epoch 1600: Loss=0.000985 | TrainAcc=1.0000
# Fold 3 Epoch 1700: Loss=0.001516 | TrainAcc=1.0000
# Fold 3 Epoch 1800: Loss=0.003891 | TrainAcc=1.0000
# Fold 3 Epoch 1900: Loss=0.001099 | TrainAcc=1.0000
# Fold 3 Epoch 2000: Loss=0.001233 | TrainAcc=1.0000
# Fold 3 → Acc=0.7313 | Prec=0.6552 | Rec=0.7037 | F1=0.6786 | AUC=0.8250 | CE Loss=1.6561
#
# === Fold 4 ===
# Fold 4 Epoch 1: Loss=0.694887 | TrainAcc=0.4487
# Fold 4 Epoch 100: Loss=0.491205 | TrainAcc=0.8397
# Fold 4 Epoch 200: Loss=0.342220 | TrainAcc=0.8846
# Fold 4 Epoch 300: Loss=0.203004 | TrainAcc=0.9551
# Fold 4 Epoch 400: Loss=0.128550 | TrainAcc=0.9615
# Fold 4 Epoch 500: Loss=0.071134 | TrainAcc=0.9679
# Fold 4 Epoch 600: Loss=0.051163 | TrainAcc=0.9936
# Fold 4 Epoch 700: Loss=0.031825 | TrainAcc=0.9936
# Fold 4 Epoch 800: Loss=0.018502 | TrainAcc=0.9936
# Fold 4 Epoch 900: Loss=0.009224 | TrainAcc=0.9936
# Fold 4 Epoch 1000: Loss=0.014482 | TrainAcc=0.9936
# Fold 4 Epoch 1100: Loss=0.008527 | TrainAcc=1.0000
# Fold 4 Epoch 1200: Loss=0.006914 | TrainAcc=1.0000
# Fold 4 Epoch 1300: Loss=0.004720 | TrainAcc=1.0000
# Fold 4 Epoch 1400: Loss=0.001343 | TrainAcc=1.0000
# Fold 4 Epoch 1500: Loss=0.001062 | TrainAcc=1.0000
# Fold 4 Epoch 1600: Loss=0.001812 | TrainAcc=1.0000
# Fold 4 Epoch 1700: Loss=0.001719 | TrainAcc=1.0000
# Fold 4 Epoch 1800: Loss=0.000986 | TrainAcc=1.0000
# Fold 4 Epoch 1900: Loss=0.001961 | TrainAcc=1.0000
# Fold 4 Epoch 2000: Loss=0.002108 | TrainAcc=1.0000
# Fold 4 → Acc=0.7910 | Prec=0.7407 | Rec=0.7407 | F1=0.7407 | AUC=0.8528 | CE Loss=1.7157
#
# === Fold 5 ===
# Fold 5 Epoch 1: Loss=0.681919 | TrainAcc=0.5256
# Fold 5 Epoch 100: Loss=0.489626 | TrainAcc=0.8077
# Fold 5 Epoch 200: Loss=0.372785 | TrainAcc=0.8526
# Fold 5 Epoch 300: Loss=0.237342 | TrainAcc=0.9167
# Fold 5 Epoch 400: Loss=0.157078 | TrainAcc=0.9551
# Fold 5 Epoch 500: Loss=0.081549 | TrainAcc=0.9744
# Fold 5 Epoch 600: Loss=0.045897 | TrainAcc=0.9872
# Fold 5 Epoch 700: Loss=0.040470 | TrainAcc=0.9808
# Fold 5 Epoch 800: Loss=0.009833 | TrainAcc=1.0000
# Fold 5 Epoch 900: Loss=0.005517 | TrainAcc=1.0000
# Fold 5 Epoch 1000: Loss=0.010076 | TrainAcc=1.0000
# Fold 5 Epoch 1100: Loss=0.006339 | TrainAcc=1.0000
# Fold 5 Epoch 1200: Loss=0.008319 | TrainAcc=1.0000
# Fold 5 Epoch 1300: Loss=0.001560 | TrainAcc=1.0000
# Fold 5 Epoch 1400: Loss=0.004277 | TrainAcc=1.0000
# Fold 5 Epoch 1500: Loss=0.001798 | TrainAcc=1.0000
# Fold 5 Epoch 1600: Loss=0.001736 | TrainAcc=1.0000
# Fold 5 Epoch 1700: Loss=0.004733 | TrainAcc=1.0000
# Fold 5 Epoch 1800: Loss=0.004105 | TrainAcc=1.0000
# Fold 5 Epoch 1900: Loss=0.005472 | TrainAcc=1.0000
# Fold 5 Epoch 2000: Loss=0.000907 | TrainAcc=1.0000
# Fold 5 → Acc=0.7612 | Prec=0.7037 | Rec=0.7037 | F1=0.7037 | AUC=0.8889 | CE Loss=1.2508
#
# === Fold 6 ===
# Fold 6 Epoch 1: Loss=0.672869 | TrainAcc=0.6410
# Fold 6 Epoch 100: Loss=0.508949 | TrainAcc=0.7821
# Fold 6 Epoch 200: Loss=0.341413 | TrainAcc=0.8654
# Fold 6 Epoch 300: Loss=0.226423 | TrainAcc=0.9038
# Fold 6 Epoch 400: Loss=0.100027 | TrainAcc=0.9487
# Fold 6 Epoch 500: Loss=0.070703 | TrainAcc=0.9808
# Fold 6 Epoch 600: Loss=0.037790 | TrainAcc=0.9936
# Fold 6 Epoch 700: Loss=0.031972 | TrainAcc=0.9936
# Fold 6 Epoch 800: Loss=0.016970 | TrainAcc=0.9872
# Fold 6 Epoch 900: Loss=0.014191 | TrainAcc=0.9936
# Fold 6 Epoch 1000: Loss=0.010831 | TrainAcc=1.0000
# Fold 6 Epoch 1100: Loss=0.003643 | TrainAcc=1.0000
# Fold 6 Epoch 1200: Loss=0.003144 | TrainAcc=1.0000
# Fold 6 Epoch 1300: Loss=0.003398 | TrainAcc=1.0000
# Fold 6 Epoch 1400: Loss=0.001564 | TrainAcc=1.0000
# Fold 6 Epoch 1500: Loss=0.013971 | TrainAcc=0.9936
# Fold 6 Epoch 1600: Loss=0.000969 | TrainAcc=1.0000
# Fold 6 Epoch 1700: Loss=0.003725 | TrainAcc=1.0000
# Fold 6 Epoch 1800: Loss=0.024718 | TrainAcc=0.9872
# Fold 6 Epoch 1900: Loss=0.001055 | TrainAcc=1.0000
# Fold 6 Epoch 2000: Loss=0.000659 | TrainAcc=1.0000
# Fold 6 → Acc=0.7313 | Prec=0.6552 | Rec=0.7037 | F1=0.6786 | AUC=0.7833 | CE Loss=2.0312
#
# === Fold 7 ===
# Fold 7 Epoch 1: Loss=0.704979 | TrainAcc=0.4551
# Fold 7 Epoch 100: Loss=0.487952 | TrainAcc=0.8013
# Fold 7 Epoch 200: Loss=0.315940 | TrainAcc=0.8782
# Fold 7 Epoch 300: Loss=0.199936 | TrainAcc=0.9295
# Fold 7 Epoch 400: Loss=0.151950 | TrainAcc=0.9359
# Fold 7 Epoch 500: Loss=0.075250 | TrainAcc=0.9744
# Fold 7 Epoch 600: Loss=0.044109 | TrainAcc=0.9872
# Fold 7 Epoch 700: Loss=0.034733 | TrainAcc=0.9872
# Fold 7 Epoch 800: Loss=0.017099 | TrainAcc=1.0000
# Fold 7 Epoch 900: Loss=0.012098 | TrainAcc=1.0000
# Fold 7 Epoch 1000: Loss=0.004221 | TrainAcc=1.0000
# Fold 7 Epoch 1100: Loss=0.002146 | TrainAcc=1.0000
# Fold 7 Epoch 1200: Loss=0.015598 | TrainAcc=0.9936
# Fold 7 Epoch 1300: Loss=0.001442 | TrainAcc=1.0000
# Fold 7 Epoch 1400: Loss=0.003243 | TrainAcc=1.0000
# Fold 7 Epoch 1500: Loss=0.001351 | TrainAcc=1.0000
# Fold 7 Epoch 1600: Loss=0.002236 | TrainAcc=1.0000
# Fold 7 Epoch 1700: Loss=0.001398 | TrainAcc=1.0000
# Fold 7 Epoch 1800: Loss=0.002111 | TrainAcc=1.0000
# Fold 7 Epoch 1900: Loss=0.001864 | TrainAcc=1.0000
# Fold 7 Epoch 2000: Loss=0.000859 | TrainAcc=1.0000
# Fold 7 → Acc=0.7612 | Prec=0.6774 | Rec=0.7778 | F1=0.7241 | AUC=0.8019 | CE Loss=1.9235
#
# === Fold 8 ===
# Fold 8 Epoch 1: Loss=0.692068 | TrainAcc=0.4744
# Fold 8 Epoch 100: Loss=0.491455 | TrainAcc=0.8077
# Fold 8 Epoch 200: Loss=0.291539 | TrainAcc=0.8782
# Fold 8 Epoch 300: Loss=0.148128 | TrainAcc=0.9615
# Fold 8 Epoch 400: Loss=0.105173 | TrainAcc=0.9679
# Fold 8 Epoch 500: Loss=0.028866 | TrainAcc=0.9936
# Fold 8 Epoch 600: Loss=0.012542 | TrainAcc=1.0000
# Fold 8 Epoch 700: Loss=0.018055 | TrainAcc=0.9936
# Fold 8 Epoch 800: Loss=0.009285 | TrainAcc=1.0000
# Fold 8 Epoch 900: Loss=0.006039 | TrainAcc=1.0000
# Fold 8 Epoch 1000: Loss=0.004069 | TrainAcc=1.0000
# Fold 8 Epoch 1100: Loss=0.014184 | TrainAcc=0.9936
# Fold 8 Epoch 1200: Loss=0.002415 | TrainAcc=1.0000
# Fold 8 Epoch 1300: Loss=0.001886 | TrainAcc=1.0000
# Fold 8 Epoch 1400: Loss=0.011003 | TrainAcc=0.9936
# Fold 8 Epoch 1500: Loss=0.000926 | TrainAcc=1.0000
# Fold 8 Epoch 1600: Loss=0.002072 | TrainAcc=1.0000
# Fold 8 Epoch 1700: Loss=0.001072 | TrainAcc=1.0000
# Fold 8 Epoch 1800: Loss=0.000771 | TrainAcc=1.0000
# Fold 8 Epoch 1900: Loss=0.001307 | TrainAcc=1.0000
# Fold 8 Epoch 2000: Loss=0.000567 | TrainAcc=1.0000
# Fold 8 → Acc=0.7910 | Prec=0.6757 | Rec=0.9259 | F1=0.7812 | AUC=0.8681 | CE Loss=1.8631
#
# === Fold 9 ===
# Fold 9 Epoch 1: Loss=0.707013 | TrainAcc=0.5769
# Fold 9 Epoch 100: Loss=0.545554 | TrainAcc=0.7115
# Fold 9 Epoch 200: Loss=0.403770 | TrainAcc=0.8462
# Fold 9 Epoch 300: Loss=0.287060 | TrainAcc=0.9103
# Fold 9 Epoch 400: Loss=0.188973 | TrainAcc=0.9167
# Fold 9 Epoch 500: Loss=0.087548 | TrainAcc=0.9872
# Fold 9 Epoch 600: Loss=0.051630 | TrainAcc=0.9872
# Fold 9 Epoch 700: Loss=0.044737 | TrainAcc=0.9936
# Fold 9 Epoch 800: Loss=0.026964 | TrainAcc=0.9872
# Fold 9 Epoch 900: Loss=0.035903 | TrainAcc=0.9872
# Fold 9 Epoch 1000: Loss=0.016856 | TrainAcc=1.0000
# Fold 9 Epoch 1100: Loss=0.005252 | TrainAcc=1.0000
# Fold 9 Epoch 1200: Loss=0.015092 | TrainAcc=0.9936
# Fold 9 Epoch 1300: Loss=0.002071 | TrainAcc=1.0000
# Fold 9 Epoch 1400: Loss=0.006868 | TrainAcc=1.0000
# Fold 9 Epoch 1500: Loss=0.004416 | TrainAcc=1.0000
# Fold 9 Epoch 1600: Loss=0.001829 | TrainAcc=1.0000
# Fold 9 Epoch 1700: Loss=0.003668 | TrainAcc=1.0000
# Fold 9 Epoch 1800: Loss=0.000962 | TrainAcc=1.0000
# Fold 9 Epoch 1900: Loss=0.002354 | TrainAcc=1.0000
# Fold 9 Epoch 2000: Loss=0.004530 | TrainAcc=1.0000
# Fold 9 → Acc=0.8060 | Prec=0.7917 | Rec=0.7037 | F1=0.7451 | AUC=0.8333 | CE Loss=1.5470
#
# === Fold 10 ===
# Fold 10 Epoch 1: Loss=0.695133 | TrainAcc=0.5513
# Fold 10 Epoch 100: Loss=0.441097 | TrainAcc=0.8333
# Fold 10 Epoch 200: Loss=0.304117 | TrainAcc=0.8910
# Fold 10 Epoch 300: Loss=0.185244 | TrainAcc=0.9423
# Fold 10 Epoch 400: Loss=0.137246 | TrainAcc=0.9487
# Fold 10 Epoch 500: Loss=0.042089 | TrainAcc=0.9808
# Fold 10 Epoch 600: Loss=0.033220 | TrainAcc=0.9936
# Fold 10 Epoch 700: Loss=0.021070 | TrainAcc=0.9936
# Fold 10 Epoch 800: Loss=0.011788 | TrainAcc=1.0000
# Fold 10 Epoch 900: Loss=0.006927 | TrainAcc=1.0000
# Fold 10 Epoch 1000: Loss=0.004215 | TrainAcc=1.0000
# Fold 10 Epoch 1100: Loss=0.009473 | TrainAcc=0.9936
# Fold 10 Epoch 1200: Loss=0.002225 | TrainAcc=1.0000
# Fold 10 Epoch 1300: Loss=0.007998 | TrainAcc=0.9936
# Fold 10 Epoch 1400: Loss=0.001853 | TrainAcc=1.0000
# Fold 10 Epoch 1500: Loss=0.004867 | TrainAcc=1.0000
# Fold 10 Epoch 1600: Loss=0.002170 | TrainAcc=1.0000
# Fold 10 Epoch 1700: Loss=0.001542 | TrainAcc=1.0000
# Fold 10 Epoch 1800: Loss=0.003012 | TrainAcc=1.0000
# Fold 10 Epoch 1900: Loss=0.001568 | TrainAcc=1.0000
# Fold 10 Epoch 2000: Loss=0.001922 | TrainAcc=1.0000
# Fold 10 → Acc=0.7612 | Prec=0.7037 | Rec=0.7037 | F1=0.7037 | AUC=0.8537 | CE Loss=1.7357
#
# === Fold 11 ===
# Fold 11 Epoch 1: Loss=0.691941 | TrainAcc=0.4679
# Fold 11 Epoch 100: Loss=0.466874 | TrainAcc=0.8077
# Fold 11 Epoch 200: Loss=0.348438 | TrainAcc=0.8718
# Fold 11 Epoch 300: Loss=0.198813 | TrainAcc=0.9359
# Fold 11 Epoch 400: Loss=0.108605 | TrainAcc=0.9744
# Fold 11 Epoch 500: Loss=0.062111 | TrainAcc=0.9744
# Fold 11 Epoch 600: Loss=0.032435 | TrainAcc=0.9872
# Fold 11 Epoch 700: Loss=0.020200 | TrainAcc=0.9936
# Fold 11 Epoch 800: Loss=0.026273 | TrainAcc=0.9872
# Fold 11 Epoch 900: Loss=0.009575 | TrainAcc=1.0000
# Fold 11 Epoch 1000: Loss=0.002788 | TrainAcc=1.0000
# Fold 11 Epoch 1100: Loss=0.002834 | TrainAcc=1.0000
# Fold 11 Epoch 1200: Loss=0.002193 | TrainAcc=1.0000
# Fold 11 Epoch 1300: Loss=0.005177 | TrainAcc=1.0000
# Fold 11 Epoch 1400: Loss=0.004344 | TrainAcc=1.0000
# Fold 11 Epoch 1500: Loss=0.002457 | TrainAcc=1.0000
# Fold 11 Epoch 1600: Loss=0.003345 | TrainAcc=1.0000
# Fold 11 Epoch 1700: Loss=0.002313 | TrainAcc=1.0000
# Fold 11 Epoch 1800: Loss=0.001791 | TrainAcc=1.0000
# Fold 11 Epoch 1900: Loss=0.000464 | TrainAcc=1.0000
# Fold 11 Epoch 2000: Loss=0.000438 | TrainAcc=1.0000
# Fold 11 → Acc=0.8358 | Prec=0.8333 | Rec=0.7407 | F1=0.7843 | AUC=0.8602 | CE Loss=1.3894
#
# === Fold 12 ===
# Fold 12 Epoch 1: Loss=0.695518 | TrainAcc=0.4936
# Fold 12 Epoch 100: Loss=0.474421 | TrainAcc=0.7756
# Fold 12 Epoch 200: Loss=0.320421 | TrainAcc=0.8590
# Fold 12 Epoch 300: Loss=0.178176 | TrainAcc=0.9423
# Fold 12 Epoch 400: Loss=0.097414 | TrainAcc=0.9679
# Fold 12 Epoch 500: Loss=0.051507 | TrainAcc=0.9808
# Fold 12 Epoch 600: Loss=0.018305 | TrainAcc=1.0000
# Fold 12 Epoch 700: Loss=0.031539 | TrainAcc=0.9872
# Fold 12 Epoch 800: Loss=0.007223 | TrainAcc=1.0000
# Fold 12 Epoch 900: Loss=0.016198 | TrainAcc=0.9872
# Fold 12 Epoch 1000: Loss=0.004345 | TrainAcc=1.0000
# Fold 12 Epoch 1100: Loss=0.007782 | TrainAcc=0.9936
# Fold 12 Epoch 1200: Loss=0.003125 | TrainAcc=1.0000
# Fold 12 Epoch 1300: Loss=0.002256 | TrainAcc=1.0000
# Fold 12 Epoch 1400: Loss=0.004726 | TrainAcc=1.0000
# Fold 12 Epoch 1500: Loss=0.003480 | TrainAcc=1.0000
# Fold 12 Epoch 1600: Loss=0.002487 | TrainAcc=1.0000
# Fold 12 Epoch 1700: Loss=0.001210 | TrainAcc=1.0000
# Fold 12 Epoch 1800: Loss=0.000850 | TrainAcc=1.0000
# Fold 12 Epoch 1900: Loss=0.000460 | TrainAcc=1.0000
# Fold 12 Epoch 2000: Loss=0.000342 | TrainAcc=1.0000
# Fold 12 → Acc=0.7313 | Prec=0.6452 | Rec=0.7407 | F1=0.6897 | AUC=0.8194 | CE Loss=2.1994
#
# === Fold 13 ===
# Fold 13 Epoch 1: Loss=0.744456 | TrainAcc=0.4231
# Fold 13 Epoch 100: Loss=0.508274 | TrainAcc=0.7500
# Fold 13 Epoch 200: Loss=0.400540 | TrainAcc=0.8269
# Fold 13 Epoch 300: Loss=0.221562 | TrainAcc=0.9231
# Fold 13 Epoch 400: Loss=0.138468 | TrainAcc=0.9615
# Fold 13 Epoch 500: Loss=0.086448 | TrainAcc=0.9615
# Fold 13 Epoch 600: Loss=0.044660 | TrainAcc=0.9808
# Fold 13 Epoch 700: Loss=0.029110 | TrainAcc=1.0000
# Fold 13 Epoch 800: Loss=0.012109 | TrainAcc=1.0000
# Fold 13 Epoch 900: Loss=0.005745 | TrainAcc=1.0000
# Fold 13 Epoch 1000: Loss=0.004040 | TrainAcc=1.0000
# Fold 13 Epoch 1100: Loss=0.005245 | TrainAcc=1.0000
# Fold 13 Epoch 1200: Loss=0.008309 | TrainAcc=0.9936
# Fold 13 Epoch 1300: Loss=0.003132 | TrainAcc=1.0000
# Fold 13 Epoch 1400: Loss=0.005402 | TrainAcc=1.0000
# Fold 13 Epoch 1500: Loss=0.001484 | TrainAcc=1.0000
# Fold 13 Epoch 1600: Loss=0.001615 | TrainAcc=1.0000
# Fold 13 Epoch 1700: Loss=0.002133 | TrainAcc=1.0000
# Fold 13 Epoch 1800: Loss=0.001356 | TrainAcc=1.0000
# Fold 13 Epoch 1900: Loss=0.003698 | TrainAcc=1.0000
# Fold 13 Epoch 2000: Loss=0.002796 | TrainAcc=1.0000
# Fold 13 → Acc=0.7313 | Prec=0.6154 | Rec=0.8889 | F1=0.7273 | AUC=0.8542 | CE Loss=1.9503
#
# === Fold 14 ===
# Fold 14 Epoch 1: Loss=0.715071 | TrainAcc=0.3590
# Fold 14 Epoch 100: Loss=0.530628 | TrainAcc=0.7244
# Fold 14 Epoch 200: Loss=0.363843 | TrainAcc=0.8782
# Fold 14 Epoch 300: Loss=0.243489 | TrainAcc=0.9038
# Fold 14 Epoch 400: Loss=0.171580 | TrainAcc=0.9295
# Fold 14 Epoch 500: Loss=0.089429 | TrainAcc=0.9615
# Fold 14 Epoch 600: Loss=0.045553 | TrainAcc=0.9808
# Fold 14 Epoch 700: Loss=0.030938 | TrainAcc=1.0000
# Fold 14 Epoch 800: Loss=0.018517 | TrainAcc=1.0000
# Fold 14 Epoch 900: Loss=0.015093 | TrainAcc=0.9936
# Fold 14 Epoch 1000: Loss=0.003650 | TrainAcc=1.0000
# Fold 14 Epoch 1100: Loss=0.012129 | TrainAcc=1.0000
# Fold 14 Epoch 1200: Loss=0.002663 | TrainAcc=1.0000
# Fold 14 Epoch 1300: Loss=0.012862 | TrainAcc=0.9936
# Fold 14 Epoch 1400: Loss=0.001942 | TrainAcc=1.0000
# Fold 14 Epoch 1500: Loss=0.011017 | TrainAcc=0.9936
# Fold 14 Epoch 1600: Loss=0.001122 | TrainAcc=1.0000
# Fold 14 Epoch 1700: Loss=0.002073 | TrainAcc=1.0000
# Fold 14 Epoch 1800: Loss=0.005421 | TrainAcc=1.0000
# Fold 14 Epoch 1900: Loss=0.000940 | TrainAcc=1.0000
# Fold 14 Epoch 2000: Loss=0.000344 | TrainAcc=1.0000
# Fold 14 → Acc=0.8060 | Prec=0.7692 | Rec=0.7407 | F1=0.7547 | AUC=0.8514 | CE Loss=1.5483
#
# === Fold 15 ===
# Fold 15 Epoch 1: Loss=0.689390 | TrainAcc=0.5449
# Fold 15 Epoch 100: Loss=0.499094 | TrainAcc=0.7949
# Fold 15 Epoch 200: Loss=0.337302 | TrainAcc=0.8654
# Fold 15 Epoch 300: Loss=0.205419 | TrainAcc=0.9359
# Fold 15 Epoch 400: Loss=0.148744 | TrainAcc=0.9551
# Fold 15 Epoch 500: Loss=0.053776 | TrainAcc=0.9872
# Fold 15 Epoch 600: Loss=0.060446 | TrainAcc=0.9808
# Fold 15 Epoch 700: Loss=0.012559 | TrainAcc=1.0000
# Fold 15 Epoch 800: Loss=0.019842 | TrainAcc=0.9872
# Fold 15 Epoch 900: Loss=0.007063 | TrainAcc=1.0000
# Fold 15 Epoch 1000: Loss=0.007449 | TrainAcc=0.9936
# Fold 15 Epoch 1100: Loss=0.001868 | TrainAcc=1.0000
# Fold 15 Epoch 1200: Loss=0.004220 | TrainAcc=1.0000
# Fold 15 Epoch 1300: Loss=0.002604 | TrainAcc=1.0000
# Fold 15 Epoch 1400: Loss=0.003737 | TrainAcc=1.0000
# Fold 15 Epoch 1500: Loss=0.010512 | TrainAcc=0.9936
# Fold 15 Epoch 1600: Loss=0.001588 | TrainAcc=1.0000
# Fold 15 Epoch 1700: Loss=0.002554 | TrainAcc=1.0000
# Fold 15 Epoch 1800: Loss=0.003079 | TrainAcc=1.0000
# Fold 15 Epoch 1900: Loss=0.000859 | TrainAcc=1.0000
# Fold 15 Epoch 2000: Loss=0.000531 | TrainAcc=1.0000
# Fold 15 → Acc=0.8358 | Prec=0.7857 | Rec=0.8148 | F1=0.8000 | AUC=0.8481 | CE Loss=1.6003
#
# === Fold 16 ===
# Fold 16 Epoch 1: Loss=0.679929 | TrainAcc=0.5577
# Fold 16 Epoch 100: Loss=0.497304 | TrainAcc=0.7436
# Fold 16 Epoch 200: Loss=0.307577 | TrainAcc=0.8654
# Fold 16 Epoch 300: Loss=0.153793 | TrainAcc=0.9615
# Fold 16 Epoch 400: Loss=0.087717 | TrainAcc=0.9744
# Fold 16 Epoch 500: Loss=0.036387 | TrainAcc=0.9872
# Fold 16 Epoch 600: Loss=0.029521 | TrainAcc=0.9936
# Fold 16 Epoch 700: Loss=0.009999 | TrainAcc=1.0000
# Fold 16 Epoch 800: Loss=0.009649 | TrainAcc=1.0000
# Fold 16 Epoch 900: Loss=0.003214 | TrainAcc=1.0000
# Fold 16 Epoch 1000: Loss=0.002481 | TrainAcc=1.0000
# Fold 16 Epoch 1100: Loss=0.001836 | TrainAcc=1.0000
# Fold 16 Epoch 1200: Loss=0.005786 | TrainAcc=1.0000
# Fold 16 Epoch 1300: Loss=0.004134 | TrainAcc=1.0000
# Fold 16 Epoch 1400: Loss=0.003097 | TrainAcc=1.0000
# Fold 16 Epoch 1500: Loss=0.002074 | TrainAcc=1.0000
# Fold 16 Epoch 1600: Loss=0.001168 | TrainAcc=1.0000
# Fold 16 Epoch 1700: Loss=0.004999 | TrainAcc=1.0000
# Fold 16 Epoch 1800: Loss=0.001614 | TrainAcc=1.0000
# Fold 16 Epoch 1900: Loss=0.014569 | TrainAcc=0.9936
# Fold 16 Epoch 2000: Loss=0.000662 | TrainAcc=1.0000
# Fold 16 → Acc=0.7612 | Prec=0.6897 | Rec=0.7407 | F1=0.7143 | AUC=0.8241 | CE Loss=1.9675
#
# === Fold 17 ===
# Fold 17 Epoch 1: Loss=0.714912 | TrainAcc=0.4167
# Fold 17 Epoch 100: Loss=0.421189 | TrainAcc=0.8526
# Fold 17 Epoch 200: Loss=0.259009 | TrainAcc=0.9103
# Fold 17 Epoch 300: Loss=0.148878 | TrainAcc=0.9487
# Fold 17 Epoch 400: Loss=0.084179 | TrainAcc=0.9872
# Fold 17 Epoch 500: Loss=0.066889 | TrainAcc=0.9872
# Fold 17 Epoch 600: Loss=0.050477 | TrainAcc=0.9936
# Fold 17 Epoch 700: Loss=0.025335 | TrainAcc=0.9936
# Fold 17 Epoch 800: Loss=0.008175 | TrainAcc=1.0000
# Fold 17 Epoch 900: Loss=0.008492 | TrainAcc=1.0000
# Fold 17 Epoch 1000: Loss=0.009469 | TrainAcc=1.0000
# Fold 17 Epoch 1100: Loss=0.004072 | TrainAcc=1.0000
# Fold 17 Epoch 1200: Loss=0.003854 | TrainAcc=1.0000
# Fold 17 Epoch 1300: Loss=0.001725 | TrainAcc=1.0000
# Fold 17 Epoch 1400: Loss=0.005264 | TrainAcc=1.0000
# Fold 17 Epoch 1500: Loss=0.002079 | TrainAcc=1.0000
# Fold 17 Epoch 1600: Loss=0.001097 | TrainAcc=1.0000
# Fold 17 Epoch 1700: Loss=0.000481 | TrainAcc=1.0000
# Fold 17 Epoch 1800: Loss=0.002615 | TrainAcc=1.0000
# Fold 17 Epoch 1900: Loss=0.000524 | TrainAcc=1.0000
# Fold 17 Epoch 2000: Loss=0.001382 | TrainAcc=1.0000
# Fold 17 → Acc=0.7761 | Prec=0.6875 | Rec=0.8148 | F1=0.7458 | AUC=0.8204 | CE Loss=1.6472
#
# === Fold 18 ===
# Fold 18 Epoch 1: Loss=0.728753 | TrainAcc=0.4167
# Fold 18 Epoch 100: Loss=0.424780 | TrainAcc=0.8077
# Fold 18 Epoch 200: Loss=0.262620 | TrainAcc=0.9167
# Fold 18 Epoch 300: Loss=0.184298 | TrainAcc=0.9423
# Fold 18 Epoch 400: Loss=0.089012 | TrainAcc=0.9872
# Fold 18 Epoch 500: Loss=0.105082 | TrainAcc=0.9679
# Fold 18 Epoch 600: Loss=0.066980 | TrainAcc=0.9808
# Fold 18 Epoch 700: Loss=0.061269 | TrainAcc=0.9872
# Fold 18 Epoch 800: Loss=0.063643 | TrainAcc=0.9872
# Fold 18 Epoch 900: Loss=0.043547 | TrainAcc=0.9936
# Fold 18 Epoch 1000: Loss=0.050190 | TrainAcc=0.9872
# Fold 18 Epoch 1100: Loss=0.053205 | TrainAcc=0.9936
# Fold 18 Epoch 1200: Loss=0.038521 | TrainAcc=0.9936
# Fold 18 Epoch 1300: Loss=0.038828 | TrainAcc=0.9936
# Fold 18 Epoch 1400: Loss=0.029769 | TrainAcc=0.9936
# Fold 18 Epoch 1500: Loss=0.050127 | TrainAcc=0.9872
# Fold 18 Epoch 1600: Loss=0.039889 | TrainAcc=0.9936
# Fold 18 Epoch 1700: Loss=0.039153 | TrainAcc=0.9936
# Fold 18 Epoch 1800: Loss=0.040565 | TrainAcc=0.9936
# Fold 18 Epoch 1900: Loss=0.035135 | TrainAcc=0.9936
# Fold 18 Epoch 2000: Loss=0.022023 | TrainAcc=0.9936
# Fold 18 → Acc=0.8060 | Prec=0.7692 | Rec=0.7407 | F1=0.7547 | AUC=0.8444 | CE Loss=1.2707
#
# === Fold 19 ===
# Fold 19 Epoch 1: Loss=0.681579 | TrainAcc=0.5897
# Fold 19 Epoch 100: Loss=0.503173 | TrainAcc=0.7821
# Fold 19 Epoch 200: Loss=0.311640 | TrainAcc=0.8526
# Fold 19 Epoch 300: Loss=0.134841 | TrainAcc=0.9551
# Fold 19 Epoch 400: Loss=0.079488 | TrainAcc=0.9679
# Fold 19 Epoch 500: Loss=0.042479 | TrainAcc=0.9872
# Fold 19 Epoch 600: Loss=0.015754 | TrainAcc=1.0000
# Fold 19 Epoch 700: Loss=0.018462 | TrainAcc=0.9936
# Fold 19 Epoch 800: Loss=0.017511 | TrainAcc=0.9872
# Fold 19 Epoch 900: Loss=0.014264 | TrainAcc=0.9936
# Fold 19 Epoch 1000: Loss=0.003109 | TrainAcc=1.0000
# Fold 19 Epoch 1100: Loss=0.004838 | TrainAcc=1.0000
# Fold 19 Epoch 1200: Loss=0.004593 | TrainAcc=1.0000
# Fold 19 Epoch 1300: Loss=0.003410 | TrainAcc=1.0000
# Fold 19 Epoch 1400: Loss=0.004942 | TrainAcc=1.0000
# Fold 19 Epoch 1500: Loss=0.013302 | TrainAcc=0.9936
# Fold 19 Epoch 1600: Loss=0.006272 | TrainAcc=1.0000
# Fold 19 Epoch 1700: Loss=0.001915 | TrainAcc=1.0000
# Fold 19 Epoch 1800: Loss=0.002420 | TrainAcc=1.0000
# Fold 19 Epoch 1900: Loss=0.000776 | TrainAcc=1.0000
# Fold 19 Epoch 2000: Loss=0.000405 | TrainAcc=1.0000
# Fold 19 → Acc=0.7313 | Prec=0.6364 | Rec=0.7778 | F1=0.7000 | AUC=0.8509 | CE Loss=1.9851
#
# === Fold 20 ===
# Fold 20 Epoch 1: Loss=0.728338 | TrainAcc=0.5513
# Fold 20 Epoch 100: Loss=0.489601 | TrainAcc=0.7885
# Fold 20 Epoch 200: Loss=0.321710 | TrainAcc=0.8910
# Fold 20 Epoch 300: Loss=0.233593 | TrainAcc=0.9103
# Fold 20 Epoch 400: Loss=0.168410 | TrainAcc=0.9487
# Fold 20 Epoch 500: Loss=0.093864 | TrainAcc=0.9808
# Fold 20 Epoch 600: Loss=0.049206 | TrainAcc=0.9872
# Fold 20 Epoch 700: Loss=0.022017 | TrainAcc=0.9936
# Fold 20 Epoch 800: Loss=0.025583 | TrainAcc=0.9872
# Fold 20 Epoch 900: Loss=0.013737 | TrainAcc=0.9936
# Fold 20 Epoch 1000: Loss=0.033529 | TrainAcc=0.9936
# Fold 20 Epoch 1100: Loss=0.012873 | TrainAcc=0.9936
# Fold 20 Epoch 1200: Loss=0.003186 | TrainAcc=1.0000
# Fold 20 Epoch 1300: Loss=0.004068 | TrainAcc=1.0000
# Fold 20 Epoch 1400: Loss=0.005858 | TrainAcc=1.0000
# Fold 20 Epoch 1500: Loss=0.001440 | TrainAcc=1.0000
# Fold 20 Epoch 1600: Loss=0.001193 | TrainAcc=1.0000
# Fold 20 Epoch 1700: Loss=0.001700 | TrainAcc=1.0000
# Fold 20 Epoch 1800: Loss=0.001552 | TrainAcc=1.0000
# Fold 20 Epoch 1900: Loss=0.002643 | TrainAcc=1.0000
# Fold 20 Epoch 2000: Loss=0.000444 | TrainAcc=1.0000
# Fold 20 → Acc=0.7313 | Prec=0.6800 | Rec=0.6296 | F1=0.6538 | AUC=0.8083 | CE Loss=1.6690
#
# === Average Results Across 20 Folds ===
# Accuracy:  0.7694 ± 0.0379
# Precision: 0.7025 ± 0.0590
# Recall:    0.7556 ± 0.0772
# F1-score:  0.7248 ± 0.0449
# CE Loss:   1.7257 ± 0.3128
# AUC:       0.8408 ± 0.0298
