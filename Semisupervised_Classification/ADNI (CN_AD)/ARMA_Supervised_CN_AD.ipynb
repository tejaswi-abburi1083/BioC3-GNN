# %%
import torch
import torch.nn as nn
import torch.nn.functional as nnFn
import torch.optim as optim
import numpy as np
import random
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from torch_geometric.data import Data
from torch_geometric.nn import ARMAConv
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, roc_auc_score, log_loss
)

# %%
fa_feature_path = "/home/snu/Downloads/Histogram_CN_FA_20bin_updated.npy"
Histogram_feature_CN_FA_array = np.load(fa_feature_path, allow_pickle=True)

fa_feature_path = "/home/snu/Downloads/Histogram_AD_FA_20bin_updated.npy"
Histogram_feature_AD_FA_array = np.load(fa_feature_path, allow_pickle=True)

X = np.vstack([Histogram_feature_CN_FA_array, Histogram_feature_AD_FA_array])
y = np.hstack([
    np.zeros(Histogram_feature_CN_FA_array.shape[0], dtype=np.int64),
    np.ones(Histogram_feature_AD_FA_array.shape[0], dtype=np.int64)
])

num_nodes, num_feats = X.shape
print(f"Features: {X.shape}, Labels: {y.shape}")
# Out:
# Features: (223, 180), Labels: (223,)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import ARMAConv

class ARMA_Supervised(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, activ="SELU"):
        super(ARMA_Supervised, self).__init__()
        self.conv1 = ARMAConv(input_dim, hidden_dim, num_stacks=1, num_layers=1)
        self.bn1 = nn.BatchNorm1d(hidden_dim)
        self.dropout = nn.Dropout(0.2)
        self.fc = nn.Linear(hidden_dim, output_dim)
        activations = {
            "SELU": F.selu,
            "SiLU": F.silu,
            "GELU": F.gelu,
            "RELU": F.relu,
            "ELU": F.elu
        }
        self.act = activations.get(activ, F.elu)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = self.conv1(x, edge_index)
        x = self.bn1(x)
        x = self.act(x)
        x = self.dropout(x)
        logits = self.fc(x)
        return logits

# %%
def create_adj(F, alpha=1):
    F_norm = F / np.linalg.norm(F, axis=1, keepdims=True)
    W = np.dot(F_norm, F_norm.T)
    W = np.where(W >= alpha, 1, 0).astype(np.float32)
    W = W / W.max()
    return W

def load_data(adj, node_feats):
    node_feats = torch.from_numpy(node_feats).float()
    edge_index = torch.from_numpy(np.array(np.nonzero((adj > 0))))
    return Data(x=node_feats, edge_index=edge_index)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
alpha = 0.8
feats_dim = num_feats
hidden_dim = 512
num_classes = 2
num_epochs = 2000
lr = 0.0001
weight_decay = 1e-4
batch_print_freq = 100

# %%
W = create_adj(X, alpha)
data = load_data(W, X).to(device)
A_tensor = torch.from_numpy(W).float().to(device)
print(data)
# Out:
# Data(x=[223, 180], edge_index=[2, 41689])

# %%
sss = StratifiedShuffleSplit(n_splits=20, test_size=0.9, random_state=42)

accuracies, precisions, recalls, f1_scores, aucs, ce_losses = [], [], [], [], [], []

for fold, (train_idx, test_idx) in enumerate(sss.split(X, y), start=1):
    print(f"\n=== Fold {fold} ===")

    train_idx_t = torch.from_numpy(train_idx).long().to(device)
    y_train_tensor = torch.from_numpy(y[train_idx]).long().to(device)

    model = ARMA_Supervised(feats_dim, hidden_dim, num_classes, "SELU").to(device)
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    ce_loss = nn.CrossEntropyLoss()


    for epoch in range(1, num_epochs + 1):
        model.train()
        optimizer.zero_grad()

        logits = model(data)
        loss = ce_loss(logits[train_idx_t], y_train_tensor)
        loss.backward()
        optimizer.step()

        if epoch % batch_print_freq == 0 or epoch == 1:
            model.eval()
            with torch.no_grad():
                preds_train = logits[train_idx_t].argmax(dim=1)
                acc_train = accuracy_score(y_train_tensor.cpu(), preds_train.cpu())
            print(f"Fold {fold} Epoch {epoch}: "
                  f"Loss={loss.item():.6f} | TrainAcc={acc_train:.4f}")


    model.eval()
    with torch.no_grad():
        out = model(data)
        preds = out.argmax(dim=1).cpu().numpy()
        probs = torch.softmax(out, dim=1)[:, 1].cpu().numpy()  # Probability for class 1

    y_test = y[test_idx]
    y_pred_test = preds[test_idx]
    y_prob_test = probs[test_idx]


    acc = accuracy_score(y_test, y_pred_test)
    prec = precision_score(y_test, y_pred_test, zero_division=0)
    rec = recall_score(y_test, y_pred_test, zero_division=0)
    f1 = f1_score(y_test, y_pred_test, zero_division=0)
    auc = roc_auc_score(y_test, y_prob_test)
    ce = log_loss(y_test, y_prob_test)

    accuracies.append(acc)
    precisions.append(prec)
    recalls.append(rec)
    f1_scores.append(f1)
    aucs.append(auc)
    ce_losses.append(ce)

    print(f"Fold {fold} → "
          f"Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | "
          f"F1={f1:.4f} | AUC={auc:.4f} | CE Loss={ce:.4f}")


print("\n=== Average Results Across 20 Folds ===")
print(f"Accuracy:  {np.mean(accuracies):.4f} ± {np.std(accuracies):.4f}")
print(f"Precision: {np.mean(precisions):.4f} ± {np.std(precisions):.4f}")
print(f"Recall:    {np.mean(recalls):.4f} ± {np.std(recalls):.4f}")
print(f"F1-score:  {np.mean(f1_scores):.4f} ± {np.std(f1_scores):.4f}")
print(f"CE Loss:   {np.mean(ce_losses):.4f} ± {np.std(ce_losses):.4f}")
print(f"AUC:       {np.mean(aucs):.4f} ± {np.std(aucs):.4f}")
# Out:
# === Fold 1 ===
# Fold 1 Epoch 1: Loss=0.701834 | TrainAcc=0.6364
# Fold 1 Epoch 100: Loss=0.021265 | TrainAcc=1.0000
# Fold 1 Epoch 200: Loss=0.005985 | TrainAcc=1.0000
# Fold 1 Epoch 300: Loss=0.002603 | TrainAcc=1.0000
# Fold 1 Epoch 400: Loss=0.001180 | TrainAcc=1.0000
# Fold 1 Epoch 500: Loss=0.000543 | TrainAcc=1.0000
# Fold 1 Epoch 600: Loss=0.000550 | TrainAcc=1.0000
# Fold 1 Epoch 700: Loss=0.000207 | TrainAcc=1.0000
# Fold 1 Epoch 800: Loss=0.000120 | TrainAcc=1.0000
# Fold 1 Epoch 900: Loss=0.000084 | TrainAcc=1.0000
# Fold 1 Epoch 1000: Loss=0.000042 | TrainAcc=1.0000
# Fold 1 Epoch 1100: Loss=0.000032 | TrainAcc=1.0000
# Fold 1 Epoch 1200: Loss=0.000036 | TrainAcc=1.0000
# Fold 1 Epoch 1300: Loss=0.000022 | TrainAcc=1.0000
# Fold 1 Epoch 1400: Loss=0.000024 | TrainAcc=1.0000
# Fold 1 Epoch 1500: Loss=0.000011 | TrainAcc=1.0000
# Fold 1 Epoch 1600: Loss=0.000019 | TrainAcc=1.0000
# Fold 1 Epoch 1700: Loss=0.000013 | TrainAcc=1.0000
# Fold 1 Epoch 1800: Loss=0.000020 | TrainAcc=1.0000
# Fold 1 Epoch 1900: Loss=0.000017 | TrainAcc=1.0000
# Fold 1 Epoch 2000: Loss=0.000014 | TrainAcc=1.0000
# Fold 1 → Acc=0.7612 | Prec=0.6813 | Rec=0.7654 | F1=0.7209 | AUC=0.8193 | CE Loss=1.0542
#
# === Fold 2 ===
# Fold 2 Epoch 1: Loss=0.725102 | TrainAcc=0.5455
# Fold 2 Epoch 100: Loss=0.041852 | TrainAcc=1.0000
# Fold 2 Epoch 200: Loss=0.010603 | TrainAcc=1.0000
# Fold 2 Epoch 300: Loss=0.004553 | TrainAcc=1.0000
# Fold 2 Epoch 400: Loss=0.002094 | TrainAcc=1.0000
# Fold 2 Epoch 500: Loss=0.001298 | TrainAcc=1.0000
# Fold 2 Epoch 600: Loss=0.000921 | TrainAcc=1.0000
# Fold 2 Epoch 700: Loss=0.000406 | TrainAcc=1.0000
# Fold 2 Epoch 800: Loss=0.000346 | TrainAcc=1.0000
# Fold 2 Epoch 900: Loss=0.000197 | TrainAcc=1.0000
# Fold 2 Epoch 1000: Loss=0.000192 | TrainAcc=1.0000
# Fold 2 Epoch 1100: Loss=0.000114 | TrainAcc=1.0000
# Fold 2 Epoch 1200: Loss=0.000095 | TrainAcc=1.0000
# Fold 2 Epoch 1300: Loss=0.000084 | TrainAcc=1.0000
# Fold 2 Epoch 1400: Loss=0.000086 | TrainAcc=1.0000
# Fold 2 Epoch 1500: Loss=0.000042 | TrainAcc=1.0000
# Fold 2 Epoch 1600: Loss=0.000047 | TrainAcc=1.0000
# Fold 2 Epoch 1700: Loss=0.000045 | TrainAcc=1.0000
# Fold 2 Epoch 1800: Loss=0.000061 | TrainAcc=1.0000
# Fold 2 Epoch 1900: Loss=0.000031 | TrainAcc=1.0000
# Fold 2 Epoch 2000: Loss=0.000037 | TrainAcc=1.0000
# Fold 2 → Acc=0.7264 | Prec=0.6477 | Rec=0.7037 | F1=0.6746 | AUC=0.7658 | CE Loss=0.9071
#
# === Fold 3 ===
# Fold 3 Epoch 1: Loss=0.772992 | TrainAcc=0.4545
# Fold 3 Epoch 100: Loss=0.029696 | TrainAcc=1.0000
# Fold 3 Epoch 200: Loss=0.008269 | TrainAcc=1.0000
# Fold 3 Epoch 300: Loss=0.003580 | TrainAcc=1.0000
# Fold 3 Epoch 400: Loss=0.002191 | TrainAcc=1.0000
# Fold 3 Epoch 500: Loss=0.001127 | TrainAcc=1.0000
# Fold 3 Epoch 600: Loss=0.000606 | TrainAcc=1.0000
# Fold 3 Epoch 700: Loss=0.000481 | TrainAcc=1.0000
# Fold 3 Epoch 800: Loss=0.000413 | TrainAcc=1.0000
# Fold 3 Epoch 900: Loss=0.000239 | TrainAcc=1.0000
# Fold 3 Epoch 1000: Loss=0.000152 | TrainAcc=1.0000
# Fold 3 Epoch 1100: Loss=0.000103 | TrainAcc=1.0000
# Fold 3 Epoch 1200: Loss=0.000098 | TrainAcc=1.0000
# Fold 3 Epoch 1300: Loss=0.000073 | TrainAcc=1.0000
# Fold 3 Epoch 1400: Loss=0.000066 | TrainAcc=1.0000
# Fold 3 Epoch 1500: Loss=0.000046 | TrainAcc=1.0000
# Fold 3 Epoch 1600: Loss=0.000059 | TrainAcc=1.0000
# Fold 3 Epoch 1700: Loss=0.000068 | TrainAcc=1.0000
# Fold 3 Epoch 1800: Loss=0.000058 | TrainAcc=1.0000
# Fold 3 Epoch 1900: Loss=0.000052 | TrainAcc=1.0000
# Fold 3 Epoch 2000: Loss=0.000030 | TrainAcc=1.0000
# Fold 3 → Acc=0.7711 | Prec=0.7465 | Rec=0.6543 | F1=0.6974 | AUC=0.8298 | CE Loss=1.0212
#
# === Fold 4 ===
# Fold 4 Epoch 1: Loss=0.674898 | TrainAcc=0.6818
# Fold 4 Epoch 100: Loss=0.024906 | TrainAcc=1.0000
# Fold 4 Epoch 200: Loss=0.006207 | TrainAcc=1.0000
# Fold 4 Epoch 300: Loss=0.002948 | TrainAcc=1.0000
# Fold 4 Epoch 400: Loss=0.001322 | TrainAcc=1.0000
# Fold 4 Epoch 500: Loss=0.000846 | TrainAcc=1.0000
# Fold 4 Epoch 600: Loss=0.000615 | TrainAcc=1.0000
# Fold 4 Epoch 700: Loss=0.000297 | TrainAcc=1.0000
# Fold 4 Epoch 800: Loss=0.000153 | TrainAcc=1.0000
# Fold 4 Epoch 900: Loss=0.000118 | TrainAcc=1.0000
# Fold 4 Epoch 1000: Loss=0.000078 | TrainAcc=1.0000
# Fold 4 Epoch 1100: Loss=0.000047 | TrainAcc=1.0000
# Fold 4 Epoch 1200: Loss=0.000040 | TrainAcc=1.0000
# Fold 4 Epoch 1300: Loss=0.000031 | TrainAcc=1.0000
# Fold 4 Epoch 1400: Loss=0.000035 | TrainAcc=1.0000
# Fold 4 Epoch 1500: Loss=0.000015 | TrainAcc=1.0000
# Fold 4 Epoch 1600: Loss=0.000017 | TrainAcc=1.0000
# Fold 4 Epoch 1700: Loss=0.000011 | TrainAcc=1.0000
# Fold 4 Epoch 1800: Loss=0.000010 | TrainAcc=1.0000
# Fold 4 Epoch 1900: Loss=0.000010 | TrainAcc=1.0000
# Fold 4 Epoch 2000: Loss=0.000018 | TrainAcc=1.0000
# Fold 4 → Acc=0.7711 | Prec=0.6699 | Rec=0.8519 | F1=0.7500 | AUC=0.8443 | CE Loss=1.0078
#
# === Fold 5 ===
# Fold 5 Epoch 1: Loss=0.708278 | TrainAcc=0.5455
# Fold 5 Epoch 100: Loss=0.050683 | TrainAcc=1.0000
# Fold 5 Epoch 200: Loss=0.011832 | TrainAcc=1.0000
# Fold 5 Epoch 300: Loss=0.004888 | TrainAcc=1.0000
# Fold 5 Epoch 400: Loss=0.003269 | TrainAcc=1.0000
# Fold 5 Epoch 500: Loss=0.001521 | TrainAcc=1.0000
# Fold 5 Epoch 600: Loss=0.000845 | TrainAcc=1.0000
# Fold 5 Epoch 700: Loss=0.000674 | TrainAcc=1.0000
# Fold 5 Epoch 800: Loss=0.000407 | TrainAcc=1.0000
# Fold 5 Epoch 900: Loss=0.000358 | TrainAcc=1.0000
# Fold 5 Epoch 1000: Loss=0.000214 | TrainAcc=1.0000
# Fold 5 Epoch 1100: Loss=0.000244 | TrainAcc=1.0000
# Fold 5 Epoch 1200: Loss=0.000224 | TrainAcc=1.0000
# Fold 5 Epoch 1300: Loss=0.000104 | TrainAcc=1.0000
# Fold 5 Epoch 1400: Loss=0.000164 | TrainAcc=1.0000
# Fold 5 Epoch 1500: Loss=0.000080 | TrainAcc=1.0000
# Fold 5 Epoch 1600: Loss=0.000059 | TrainAcc=1.0000
# Fold 5 Epoch 1700: Loss=0.000043 | TrainAcc=1.0000
# Fold 5 Epoch 1800: Loss=0.000046 | TrainAcc=1.0000
# Fold 5 Epoch 1900: Loss=0.000043 | TrainAcc=1.0000
# Fold 5 Epoch 2000: Loss=0.000040 | TrainAcc=1.0000
# Fold 5 → Acc=0.7662 | Prec=0.6809 | Rec=0.7901 | F1=0.7314 | AUC=0.8335 | CE Loss=0.7918
#
# === Fold 6 ===
# Fold 6 Epoch 1: Loss=0.799372 | TrainAcc=0.5000
# Fold 6 Epoch 100: Loss=0.038006 | TrainAcc=1.0000
# Fold 6 Epoch 200: Loss=0.009543 | TrainAcc=1.0000
# Fold 6 Epoch 300: Loss=0.006428 | TrainAcc=1.0000
# Fold 6 Epoch 400: Loss=0.002326 | TrainAcc=1.0000
# Fold 6 Epoch 500: Loss=0.001608 | TrainAcc=1.0000
# Fold 6 Epoch 600: Loss=0.000962 | TrainAcc=1.0000
# Fold 6 Epoch 700: Loss=0.000738 | TrainAcc=1.0000
# Fold 6 Epoch 800: Loss=0.000355 | TrainAcc=1.0000
# Fold 6 Epoch 900: Loss=0.000258 | TrainAcc=1.0000
# Fold 6 Epoch 1000: Loss=0.000242 | TrainAcc=1.0000
# Fold 6 Epoch 1100: Loss=0.000220 | TrainAcc=1.0000
# Fold 6 Epoch 1200: Loss=0.000129 | TrainAcc=1.0000
# Fold 6 Epoch 1300: Loss=0.000088 | TrainAcc=1.0000
# Fold 6 Epoch 1400: Loss=0.000061 | TrainAcc=1.0000
# Fold 6 Epoch 1500: Loss=0.000064 | TrainAcc=1.0000
# Fold 6 Epoch 1600: Loss=0.000065 | TrainAcc=1.0000
# Fold 6 Epoch 1700: Loss=0.000050 | TrainAcc=1.0000
# Fold 6 Epoch 1800: Loss=0.000050 | TrainAcc=1.0000
# Fold 6 Epoch 1900: Loss=0.000053 | TrainAcc=1.0000
# Fold 6 Epoch 2000: Loss=0.000036 | TrainAcc=1.0000
# Fold 6 → Acc=0.7413 | Prec=0.6747 | Rec=0.6914 | F1=0.6829 | AUC=0.8056 | CE Loss=0.9351
#
# === Fold 7 ===
# Fold 7 Epoch 1: Loss=0.679382 | TrainAcc=0.4545
# Fold 7 Epoch 100: Loss=0.042747 | TrainAcc=1.0000
# Fold 7 Epoch 200: Loss=0.012293 | TrainAcc=1.0000
# Fold 7 Epoch 300: Loss=0.005233 | TrainAcc=1.0000
# Fold 7 Epoch 400: Loss=0.002883 | TrainAcc=1.0000
# Fold 7 Epoch 500: Loss=0.001903 | TrainAcc=1.0000
# Fold 7 Epoch 600: Loss=0.000942 | TrainAcc=1.0000
# Fold 7 Epoch 700: Loss=0.000667 | TrainAcc=1.0000
# Fold 7 Epoch 800: Loss=0.000516 | TrainAcc=1.0000
# Fold 7 Epoch 900: Loss=0.000370 | TrainAcc=1.0000
# Fold 7 Epoch 1000: Loss=0.000197 | TrainAcc=1.0000
# Fold 7 Epoch 1100: Loss=0.000114 | TrainAcc=1.0000
# Fold 7 Epoch 1200: Loss=0.000119 | TrainAcc=1.0000
# Fold 7 Epoch 1300: Loss=0.000057 | TrainAcc=1.0000
# Fold 7 Epoch 1400: Loss=0.000039 | TrainAcc=1.0000
# Fold 7 Epoch 1500: Loss=0.000043 | TrainAcc=1.0000
# Fold 7 Epoch 1600: Loss=0.000053 | TrainAcc=1.0000
# Fold 7 Epoch 1700: Loss=0.000043 | TrainAcc=1.0000
# Fold 7 Epoch 1800: Loss=0.000039 | TrainAcc=1.0000
# Fold 7 Epoch 1900: Loss=0.000047 | TrainAcc=1.0000
# Fold 7 Epoch 2000: Loss=0.000036 | TrainAcc=1.0000
# Fold 7 → Acc=0.7662 | Prec=0.7024 | Rec=0.7284 | F1=0.7152 | AUC=0.8372 | CE Loss=0.8317
#
# === Fold 8 ===
# Fold 8 Epoch 1: Loss=0.760605 | TrainAcc=0.4091
# Fold 8 Epoch 100: Loss=0.049852 | TrainAcc=1.0000
# Fold 8 Epoch 200: Loss=0.012959 | TrainAcc=1.0000
# Fold 8 Epoch 300: Loss=0.005390 | TrainAcc=1.0000
# Fold 8 Epoch 400: Loss=0.002555 | TrainAcc=1.0000
# Fold 8 Epoch 500: Loss=0.001311 | TrainAcc=1.0000
# Fold 8 Epoch 600: Loss=0.000826 | TrainAcc=1.0000
# Fold 8 Epoch 700: Loss=0.000451 | TrainAcc=1.0000
# Fold 8 Epoch 800: Loss=0.000329 | TrainAcc=1.0000
# Fold 8 Epoch 900: Loss=0.000210 | TrainAcc=1.0000
# Fold 8 Epoch 1000: Loss=0.000230 | TrainAcc=1.0000
# Fold 8 Epoch 1100: Loss=0.000110 | TrainAcc=1.0000
# Fold 8 Epoch 1200: Loss=0.000097 | TrainAcc=1.0000
# Fold 8 Epoch 1300: Loss=0.000073 | TrainAcc=1.0000
# Fold 8 Epoch 1400: Loss=0.000065 | TrainAcc=1.0000
# Fold 8 Epoch 1500: Loss=0.000038 | TrainAcc=1.0000
# Fold 8 Epoch 1600: Loss=0.000035 | TrainAcc=1.0000
# Fold 8 Epoch 1700: Loss=0.000033 | TrainAcc=1.0000
# Fold 8 Epoch 1800: Loss=0.000022 | TrainAcc=1.0000
# Fold 8 Epoch 1900: Loss=0.000033 | TrainAcc=1.0000
# Fold 8 Epoch 2000: Loss=0.000028 | TrainAcc=1.0000
# Fold 8 → Acc=0.7662 | Prec=0.7024 | Rec=0.7284 | F1=0.7152 | AUC=0.8316 | CE Loss=0.7869
#
# === Fold 9 ===
# Fold 9 Epoch 1: Loss=0.742316 | TrainAcc=0.5455
# Fold 9 Epoch 100: Loss=0.029143 | TrainAcc=1.0000
# Fold 9 Epoch 200: Loss=0.007318 | TrainAcc=1.0000
# Fold 9 Epoch 300: Loss=0.003781 | TrainAcc=1.0000
# Fold 9 Epoch 400: Loss=0.001868 | TrainAcc=1.0000
# Fold 9 Epoch 500: Loss=0.001160 | TrainAcc=1.0000
# Fold 9 Epoch 600: Loss=0.000652 | TrainAcc=1.0000
# Fold 9 Epoch 700: Loss=0.000381 | TrainAcc=1.0000
# Fold 9 Epoch 800: Loss=0.000235 | TrainAcc=1.0000
# Fold 9 Epoch 900: Loss=0.000145 | TrainAcc=1.0000
# Fold 9 Epoch 1000: Loss=0.000079 | TrainAcc=1.0000
# Fold 9 Epoch 1100: Loss=0.000061 | TrainAcc=1.0000
# Fold 9 Epoch 1200: Loss=0.000060 | TrainAcc=1.0000
# Fold 9 Epoch 1300: Loss=0.000058 | TrainAcc=1.0000
# Fold 9 Epoch 1400: Loss=0.000051 | TrainAcc=1.0000
# Fold 9 Epoch 1500: Loss=0.000031 | TrainAcc=1.0000
# Fold 9 Epoch 1600: Loss=0.000026 | TrainAcc=1.0000
# Fold 9 Epoch 1700: Loss=0.000017 | TrainAcc=1.0000
# Fold 9 Epoch 1800: Loss=0.000018 | TrainAcc=1.0000
# Fold 9 Epoch 1900: Loss=0.000015 | TrainAcc=1.0000
# Fold 9 Epoch 2000: Loss=0.000018 | TrainAcc=1.0000
# Fold 9 → Acc=0.7562 | Prec=0.6600 | Rec=0.8148 | F1=0.7293 | AUC=0.8345 | CE Loss=0.8073
#
# === Fold 10 ===
# Fold 10 Epoch 1: Loss=0.858294 | TrainAcc=0.3182
# Fold 10 Epoch 100: Loss=0.070370 | TrainAcc=1.0000
# Fold 10 Epoch 200: Loss=0.016454 | TrainAcc=1.0000
# Fold 10 Epoch 300: Loss=0.007249 | TrainAcc=1.0000
# Fold 10 Epoch 400: Loss=0.003432 | TrainAcc=1.0000
# Fold 10 Epoch 500: Loss=0.002560 | TrainAcc=1.0000
# Fold 10 Epoch 600: Loss=0.001146 | TrainAcc=1.0000
# Fold 10 Epoch 700: Loss=0.000869 | TrainAcc=1.0000
# Fold 10 Epoch 800: Loss=0.000630 | TrainAcc=1.0000
# Fold 10 Epoch 900: Loss=0.000461 | TrainAcc=1.0000
# Fold 10 Epoch 1000: Loss=0.000365 | TrainAcc=1.0000
# Fold 10 Epoch 1100: Loss=0.000211 | TrainAcc=1.0000
# Fold 10 Epoch 1200: Loss=0.000175 | TrainAcc=1.0000
# Fold 10 Epoch 1300: Loss=0.000098 | TrainAcc=1.0000
# Fold 10 Epoch 1400: Loss=0.000074 | TrainAcc=1.0000
# Fold 10 Epoch 1500: Loss=0.000086 | TrainAcc=1.0000
# Fold 10 Epoch 1600: Loss=0.000075 | TrainAcc=1.0000
# Fold 10 Epoch 1700: Loss=0.000055 | TrainAcc=1.0000
# Fold 10 Epoch 1800: Loss=0.000046 | TrainAcc=1.0000
# Fold 10 Epoch 1900: Loss=0.000038 | TrainAcc=1.0000
# Fold 10 Epoch 2000: Loss=0.000036 | TrainAcc=1.0000
# Fold 10 → Acc=0.6667 | Prec=0.5833 | Rec=0.6049 | F1=0.5939 | AUC=0.7429 | CE Loss=1.0290
#
# === Fold 11 ===
# Fold 11 Epoch 1: Loss=0.646487 | TrainAcc=0.5000
# Fold 11 Epoch 100: Loss=0.022276 | TrainAcc=1.0000
# Fold 11 Epoch 200: Loss=0.007852 | TrainAcc=1.0000
# Fold 11 Epoch 300: Loss=0.002903 | TrainAcc=1.0000
# Fold 11 Epoch 400: Loss=0.001558 | TrainAcc=1.0000
# Fold 11 Epoch 500: Loss=0.000927 | TrainAcc=1.0000
# Fold 11 Epoch 600: Loss=0.000628 | TrainAcc=1.0000
# Fold 11 Epoch 700: Loss=0.000517 | TrainAcc=1.0000
# Fold 11 Epoch 800: Loss=0.000404 | TrainAcc=1.0000
# Fold 11 Epoch 900: Loss=0.000283 | TrainAcc=1.0000
# Fold 11 Epoch 1000: Loss=0.000161 | TrainAcc=1.0000
# Fold 11 Epoch 1100: Loss=0.000100 | TrainAcc=1.0000
# Fold 11 Epoch 1200: Loss=0.000059 | TrainAcc=1.0000
# Fold 11 Epoch 1300: Loss=0.000038 | TrainAcc=1.0000
# Fold 11 Epoch 1400: Loss=0.000030 | TrainAcc=1.0000
# Fold 11 Epoch 1500: Loss=0.000032 | TrainAcc=1.0000
# Fold 11 Epoch 1600: Loss=0.000034 | TrainAcc=1.0000
# Fold 11 Epoch 1700: Loss=0.000018 | TrainAcc=1.0000
# Fold 11 Epoch 1800: Loss=0.000031 | TrainAcc=1.0000
# Fold 11 Epoch 1900: Loss=0.000019 | TrainAcc=1.0000
# Fold 11 Epoch 2000: Loss=0.000016 | TrainAcc=1.0000
# Fold 11 → Acc=0.7413 | Prec=0.6986 | Rec=0.6296 | F1=0.6623 | AUC=0.8206 | CE Loss=0.9005
#
# === Fold 12 ===
# Fold 12 Epoch 1: Loss=0.838208 | TrainAcc=0.3636
# Fold 12 Epoch 100: Loss=0.051294 | TrainAcc=1.0000
# Fold 12 Epoch 200: Loss=0.012137 | TrainAcc=1.0000
# Fold 12 Epoch 300: Loss=0.004222 | TrainAcc=1.0000
# Fold 12 Epoch 400: Loss=0.002042 | TrainAcc=1.0000
# Fold 12 Epoch 500: Loss=0.001791 | TrainAcc=1.0000
# Fold 12 Epoch 600: Loss=0.000747 | TrainAcc=1.0000
# Fold 12 Epoch 700: Loss=0.000618 | TrainAcc=1.0000
# Fold 12 Epoch 800: Loss=0.000562 | TrainAcc=1.0000
# Fold 12 Epoch 900: Loss=0.000386 | TrainAcc=1.0000
# Fold 12 Epoch 1000: Loss=0.000240 | TrainAcc=1.0000
# Fold 12 Epoch 1100: Loss=0.000210 | TrainAcc=1.0000
# Fold 12 Epoch 1200: Loss=0.000140 | TrainAcc=1.0000
# Fold 12 Epoch 1300: Loss=0.000078 | TrainAcc=1.0000
# Fold 12 Epoch 1400: Loss=0.000082 | TrainAcc=1.0000
# Fold 12 Epoch 1500: Loss=0.000060 | TrainAcc=1.0000
# Fold 12 Epoch 1600: Loss=0.000056 | TrainAcc=1.0000
# Fold 12 Epoch 1700: Loss=0.000073 | TrainAcc=1.0000
# Fold 12 Epoch 1800: Loss=0.000032 | TrainAcc=1.0000
# Fold 12 Epoch 1900: Loss=0.000035 | TrainAcc=1.0000
# Fold 12 Epoch 2000: Loss=0.000049 | TrainAcc=1.0000
# Fold 12 → Acc=0.6816 | Prec=0.6104 | Rec=0.5802 | F1=0.5949 | AUC=0.7160 | CE Loss=0.9818
#
# === Fold 13 ===
# Fold 13 Epoch 1: Loss=0.660249 | TrainAcc=0.5455
# Fold 13 Epoch 100: Loss=0.024777 | TrainAcc=1.0000
# Fold 13 Epoch 200: Loss=0.007355 | TrainAcc=1.0000
# Fold 13 Epoch 300: Loss=0.002544 | TrainAcc=1.0000
# Fold 13 Epoch 400: Loss=0.001631 | TrainAcc=1.0000
# Fold 13 Epoch 500: Loss=0.000885 | TrainAcc=1.0000
# Fold 13 Epoch 600: Loss=0.000679 | TrainAcc=1.0000
# Fold 13 Epoch 700: Loss=0.000330 | TrainAcc=1.0000
# Fold 13 Epoch 800: Loss=0.000181 | TrainAcc=1.0000
# Fold 13 Epoch 900: Loss=0.000198 | TrainAcc=1.0000
# Fold 13 Epoch 1000: Loss=0.000117 | TrainAcc=1.0000
# Fold 13 Epoch 1100: Loss=0.000094 | TrainAcc=1.0000
# Fold 13 Epoch 1200: Loss=0.000076 | TrainAcc=1.0000
# Fold 13 Epoch 1300: Loss=0.000055 | TrainAcc=1.0000
# Fold 13 Epoch 1400: Loss=0.000028 | TrainAcc=1.0000
# Fold 13 Epoch 1500: Loss=0.000028 | TrainAcc=1.0000
# Fold 13 Epoch 1600: Loss=0.000027 | TrainAcc=1.0000
# Fold 13 Epoch 1700: Loss=0.000023 | TrainAcc=1.0000
# Fold 13 Epoch 1800: Loss=0.000021 | TrainAcc=1.0000
# Fold 13 Epoch 1900: Loss=0.000023 | TrainAcc=1.0000
# Fold 13 Epoch 2000: Loss=0.000015 | TrainAcc=1.0000
# Fold 13 → Acc=0.7562 | Prec=0.6818 | Rec=0.7407 | F1=0.7101 | AUC=0.8413 | CE Loss=0.9511
#
# === Fold 14 ===
# Fold 14 Epoch 1: Loss=0.776608 | TrainAcc=0.4545
# Fold 14 Epoch 100: Loss=0.041421 | TrainAcc=1.0000
# Fold 14 Epoch 200: Loss=0.009555 | TrainAcc=1.0000
# Fold 14 Epoch 300: Loss=0.005611 | TrainAcc=1.0000
# Fold 14 Epoch 400: Loss=0.003708 | TrainAcc=1.0000
# Fold 14 Epoch 500: Loss=0.001435 | TrainAcc=1.0000
# Fold 14 Epoch 600: Loss=0.001178 | TrainAcc=1.0000
# Fold 14 Epoch 700: Loss=0.000381 | TrainAcc=1.0000
# Fold 14 Epoch 800: Loss=0.000330 | TrainAcc=1.0000
# Fold 14 Epoch 900: Loss=0.000321 | TrainAcc=1.0000
# Fold 14 Epoch 1000: Loss=0.000129 | TrainAcc=1.0000
# Fold 14 Epoch 1100: Loss=0.000152 | TrainAcc=1.0000
# Fold 14 Epoch 1200: Loss=0.000118 | TrainAcc=1.0000
# Fold 14 Epoch 1300: Loss=0.000083 | TrainAcc=1.0000
# Fold 14 Epoch 1400: Loss=0.000088 | TrainAcc=1.0000
# Fold 14 Epoch 1500: Loss=0.000063 | TrainAcc=1.0000
# Fold 14 Epoch 1600: Loss=0.000046 | TrainAcc=1.0000
# Fold 14 Epoch 1700: Loss=0.000043 | TrainAcc=1.0000
# Fold 14 Epoch 1800: Loss=0.000052 | TrainAcc=1.0000
# Fold 14 Epoch 1900: Loss=0.000037 | TrainAcc=1.0000
# Fold 14 Epoch 2000: Loss=0.000032 | TrainAcc=1.0000
# Fold 14 → Acc=0.7214 | Prec=0.6344 | Rec=0.7284 | F1=0.6782 | AUC=0.7849 | CE Loss=0.8945
#
# === Fold 15 ===
# Fold 15 Epoch 1: Loss=0.709788 | TrainAcc=0.6364
# Fold 15 Epoch 100: Loss=0.031933 | TrainAcc=1.0000
# Fold 15 Epoch 200: Loss=0.011143 | TrainAcc=1.0000
# Fold 15 Epoch 300: Loss=0.004541 | TrainAcc=1.0000
# Fold 15 Epoch 400: Loss=0.002315 | TrainAcc=1.0000
# Fold 15 Epoch 500: Loss=0.001141 | TrainAcc=1.0000
# Fold 15 Epoch 600: Loss=0.000821 | TrainAcc=1.0000
# Fold 15 Epoch 700: Loss=0.000707 | TrainAcc=1.0000
# Fold 15 Epoch 800: Loss=0.000556 | TrainAcc=1.0000
# Fold 15 Epoch 900: Loss=0.000601 | TrainAcc=1.0000
# Fold 15 Epoch 1000: Loss=0.000402 | TrainAcc=1.0000
# Fold 15 Epoch 1100: Loss=0.000280 | TrainAcc=1.0000
# Fold 15 Epoch 1200: Loss=0.000141 | TrainAcc=1.0000
# Fold 15 Epoch 1300: Loss=0.000143 | TrainAcc=1.0000
# Fold 15 Epoch 1400: Loss=0.000082 | TrainAcc=1.0000
# Fold 15 Epoch 1500: Loss=0.000077 | TrainAcc=1.0000
# Fold 15 Epoch 1600: Loss=0.000048 | TrainAcc=1.0000
# Fold 15 Epoch 1700: Loss=0.000037 | TrainAcc=1.0000
# Fold 15 Epoch 1800: Loss=0.000033 | TrainAcc=1.0000
# Fold 15 Epoch 1900: Loss=0.000036 | TrainAcc=1.0000
# Fold 15 Epoch 2000: Loss=0.000028 | TrainAcc=1.0000
# Fold 15 → Acc=0.7562 | Prec=0.6818 | Rec=0.7407 | F1=0.7101 | AUC=0.8336 | CE Loss=0.8689
#
# === Fold 16 ===
# Fold 16 Epoch 1: Loss=0.833364 | TrainAcc=0.3636
# Fold 16 Epoch 100: Loss=0.027946 | TrainAcc=1.0000
# Fold 16 Epoch 200: Loss=0.008116 | TrainAcc=1.0000
# Fold 16 Epoch 300: Loss=0.003317 | TrainAcc=1.0000
# Fold 16 Epoch 400: Loss=0.001775 | TrainAcc=1.0000
# Fold 16 Epoch 500: Loss=0.001077 | TrainAcc=1.0000
# Fold 16 Epoch 600: Loss=0.000761 | TrainAcc=1.0000
# Fold 16 Epoch 700: Loss=0.000515 | TrainAcc=1.0000
# Fold 16 Epoch 800: Loss=0.000338 | TrainAcc=1.0000
# Fold 16 Epoch 900: Loss=0.000190 | TrainAcc=1.0000
# Fold 16 Epoch 1000: Loss=0.000143 | TrainAcc=1.0000
# Fold 16 Epoch 1100: Loss=0.000121 | TrainAcc=1.0000
# Fold 16 Epoch 1200: Loss=0.000113 | TrainAcc=1.0000
# Fold 16 Epoch 1300: Loss=0.000081 | TrainAcc=1.0000
# Fold 16 Epoch 1400: Loss=0.000062 | TrainAcc=1.0000
# Fold 16 Epoch 1500: Loss=0.000075 | TrainAcc=1.0000
# Fold 16 Epoch 1600: Loss=0.000080 | TrainAcc=1.0000
# Fold 16 Epoch 1700: Loss=0.000053 | TrainAcc=1.0000
# Fold 16 Epoch 1800: Loss=0.000035 | TrainAcc=1.0000
# Fold 16 Epoch 1900: Loss=0.000039 | TrainAcc=1.0000
# Fold 16 Epoch 2000: Loss=0.000037 | TrainAcc=1.0000
# Fold 16 → Acc=0.7562 | Prec=0.7000 | Rec=0.6914 | F1=0.6957 | AUC=0.8127 | CE Loss=0.8583
#
# === Fold 17 ===
# Fold 17 Epoch 1: Loss=0.724494 | TrainAcc=0.5455
# Fold 17 Epoch 100: Loss=0.031742 | TrainAcc=1.0000
# Fold 17 Epoch 200: Loss=0.011305 | TrainAcc=1.0000
# Fold 17 Epoch 300: Loss=0.002962 | TrainAcc=1.0000
# Fold 17 Epoch 400: Loss=0.001601 | TrainAcc=1.0000
# Fold 17 Epoch 500: Loss=0.000925 | TrainAcc=1.0000
# Fold 17 Epoch 600: Loss=0.000636 | TrainAcc=1.0000
# Fold 17 Epoch 700: Loss=0.000301 | TrainAcc=1.0000
# Fold 17 Epoch 800: Loss=0.000190 | TrainAcc=1.0000
# Fold 17 Epoch 900: Loss=0.000091 | TrainAcc=1.0000
# Fold 17 Epoch 1000: Loss=0.000077 | TrainAcc=1.0000
# Fold 17 Epoch 1100: Loss=0.000087 | TrainAcc=1.0000
# Fold 17 Epoch 1200: Loss=0.000046 | TrainAcc=1.0000
# Fold 17 Epoch 1300: Loss=0.000045 | TrainAcc=1.0000
# Fold 17 Epoch 1400: Loss=0.000022 | TrainAcc=1.0000
# Fold 17 Epoch 1500: Loss=0.000025 | TrainAcc=1.0000
# Fold 17 Epoch 1600: Loss=0.000020 | TrainAcc=1.0000
# Fold 17 Epoch 1700: Loss=0.000020 | TrainAcc=1.0000
# Fold 17 Epoch 1800: Loss=0.000016 | TrainAcc=1.0000
# Fold 17 Epoch 1900: Loss=0.000017 | TrainAcc=1.0000
# Fold 17 Epoch 2000: Loss=0.000014 | TrainAcc=1.0000
# Fold 17 → Acc=0.7562 | Prec=0.6860 | Rec=0.7284 | F1=0.7066 | AUC=0.8108 | CE Loss=1.0384
#
# === Fold 18 ===
# Fold 18 Epoch 1: Loss=0.703993 | TrainAcc=0.4545
# Fold 18 Epoch 100: Loss=0.051644 | TrainAcc=1.0000
# Fold 18 Epoch 200: Loss=0.012389 | TrainAcc=1.0000
# Fold 18 Epoch 300: Loss=0.004882 | TrainAcc=1.0000
# Fold 18 Epoch 400: Loss=0.002338 | TrainAcc=1.0000
# Fold 18 Epoch 500: Loss=0.001565 | TrainAcc=1.0000
# Fold 18 Epoch 600: Loss=0.000997 | TrainAcc=1.0000
# Fold 18 Epoch 700: Loss=0.000587 | TrainAcc=1.0000
# Fold 18 Epoch 800: Loss=0.000573 | TrainAcc=1.0000
# Fold 18 Epoch 900: Loss=0.000402 | TrainAcc=1.0000
# Fold 18 Epoch 1000: Loss=0.000231 | TrainAcc=1.0000
# Fold 18 Epoch 1100: Loss=0.000189 | TrainAcc=1.0000
# Fold 18 Epoch 1200: Loss=0.000144 | TrainAcc=1.0000
# Fold 18 Epoch 1300: Loss=0.000131 | TrainAcc=1.0000
# Fold 18 Epoch 1400: Loss=0.000062 | TrainAcc=1.0000
# Fold 18 Epoch 1500: Loss=0.000065 | TrainAcc=1.0000
# Fold 18 Epoch 1600: Loss=0.000044 | TrainAcc=1.0000
# Fold 18 Epoch 1700: Loss=0.000057 | TrainAcc=1.0000
# Fold 18 Epoch 1800: Loss=0.000050 | TrainAcc=1.0000
# Fold 18 Epoch 1900: Loss=0.000061 | TrainAcc=1.0000
# Fold 18 Epoch 2000: Loss=0.000050 | TrainAcc=1.0000
# Fold 18 → Acc=0.7512 | Prec=0.7067 | Rec=0.6543 | F1=0.6795 | AUC=0.8001 | CE Loss=0.8123
#
# === Fold 19 ===
# Fold 19 Epoch 1: Loss=0.928811 | TrainAcc=0.3182
# Fold 19 Epoch 100: Loss=0.064172 | TrainAcc=1.0000
# Fold 19 Epoch 200: Loss=0.015457 | TrainAcc=1.0000
# Fold 19 Epoch 300: Loss=0.006671 | TrainAcc=1.0000
# Fold 19 Epoch 400: Loss=0.004007 | TrainAcc=1.0000
# Fold 19 Epoch 500: Loss=0.002514 | TrainAcc=1.0000
# Fold 19 Epoch 600: Loss=0.002162 | TrainAcc=1.0000
# Fold 19 Epoch 700: Loss=0.001018 | TrainAcc=1.0000
# Fold 19 Epoch 800: Loss=0.000439 | TrainAcc=1.0000
# Fold 19 Epoch 900: Loss=0.000225 | TrainAcc=1.0000
# Fold 19 Epoch 1000: Loss=0.000490 | TrainAcc=1.0000
# Fold 19 Epoch 1100: Loss=0.000147 | TrainAcc=1.0000
# Fold 19 Epoch 1200: Loss=0.000130 | TrainAcc=1.0000
# Fold 19 Epoch 1300: Loss=0.000069 | TrainAcc=1.0000
# Fold 19 Epoch 1400: Loss=0.000062 | TrainAcc=1.0000
# Fold 19 Epoch 1500: Loss=0.000076 | TrainAcc=1.0000
# Fold 19 Epoch 1600: Loss=0.000052 | TrainAcc=1.0000
# Fold 19 Epoch 1700: Loss=0.000060 | TrainAcc=1.0000
# Fold 19 Epoch 1800: Loss=0.000046 | TrainAcc=1.0000
# Fold 19 Epoch 1900: Loss=0.000043 | TrainAcc=1.0000
# Fold 19 Epoch 2000: Loss=0.000030 | TrainAcc=1.0000
# Fold 19 → Acc=0.6766 | Prec=0.5952 | Rec=0.6173 | F1=0.6061 | AUC=0.7449 | CE Loss=1.0354
#
# === Fold 20 ===
# Fold 20 Epoch 1: Loss=0.962454 | TrainAcc=0.3636
# Fold 20 Epoch 100: Loss=0.059481 | TrainAcc=1.0000
# Fold 20 Epoch 200: Loss=0.011174 | TrainAcc=1.0000
# Fold 20 Epoch 300: Loss=0.006332 | TrainAcc=1.0000
# Fold 20 Epoch 400: Loss=0.003138 | TrainAcc=1.0000
# Fold 20 Epoch 500: Loss=0.001731 | TrainAcc=1.0000
# Fold 20 Epoch 600: Loss=0.001408 | TrainAcc=1.0000
# Fold 20 Epoch 700: Loss=0.000726 | TrainAcc=1.0000
# Fold 20 Epoch 800: Loss=0.000526 | TrainAcc=1.0000
# Fold 20 Epoch 900: Loss=0.000228 | TrainAcc=1.0000
# Fold 20 Epoch 1000: Loss=0.000157 | TrainAcc=1.0000
# Fold 20 Epoch 1100: Loss=0.000071 | TrainAcc=1.0000
# Fold 20 Epoch 1200: Loss=0.000060 | TrainAcc=1.0000
# Fold 20 Epoch 1300: Loss=0.000030 | TrainAcc=1.0000
# Fold 20 Epoch 1400: Loss=0.000032 | TrainAcc=1.0000
# Fold 20 Epoch 1500: Loss=0.000028 | TrainAcc=1.0000
# Fold 20 Epoch 1600: Loss=0.000031 | TrainAcc=1.0000
# Fold 20 Epoch 1700: Loss=0.000024 | TrainAcc=1.0000
# Fold 20 Epoch 1800: Loss=0.000019 | TrainAcc=1.0000
# Fold 20 Epoch 1900: Loss=0.000022 | TrainAcc=1.0000
# Fold 20 Epoch 2000: Loss=0.000016 | TrainAcc=1.0000
# Fold 20 → Acc=0.6816 | Prec=0.5810 | Rec=0.7531 | F1=0.6559 | AUC=0.7629 | CE Loss=1.1560
#
# === Average Results Across 20 Folds ===
# Accuracy:  0.7386 ± 0.0336
# Precision: 0.6663 ± 0.0436
# Recall:    0.7099 ± 0.0691
# F1-score:  0.6855 ± 0.0434
# CE Loss:   0.9335 ± 0.1015
# AUC:       0.8036 ± 0.0370
