# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import torch
os.environ['TORCH'] = torch.__version__
print(torch.__version__)
# Out:
# 2.8.0+cu126

# %%
# !pip install sympy
# Out:
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (1.13.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy) (1.3.0)

# %%
# !pip install -q torch_geometric
# !pip install -q class_resolver
# !pip3 install pymatting
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 29.4 MB/s eta 0:00:00
# Collecting pymatting
#   Downloading pymatting-1.1.14-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from pymatting) (2.0.2)
# Requirement already satisfied: pillow>=5.2.0 in /usr/local/lib/python3.12/dist-packages (from pymatting) (11.3.0)
# Requirement already satisfied: numba!=0.49.0 in /usr/local/lib/python3.12/dist-packages (from pymatting) (0.60.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from pymatting) (1.16.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba!=0.49.0->pymatting) (0.43.0)
# Downloading pymatting-1.1.14-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.7/54.7 kB 3.9 MB/s eta 0:00:00
# Installing collected packages: pymatting
# Successfully installed pymatting-1.1.14

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.data import Data
from torch_geometric.nn import GCNConv
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, log_loss

# %%
fa_patients_path = "/home/snu/Downloads/NIFD_Patients_FA_Histogram_Feature.npy"
Patients_FA_array = np.load(fa_patients_path, allow_pickle=True)

fa_controls_path = "/home/snu/Downloads/NIFD_Control_FA_Histogram_Feature.npy"
Controls_FA_array = np.load(fa_controls_path, allow_pickle=True)

print("Patients Shape:", Patients_FA_array.shape)
print("Controls Shape:", Controls_FA_array.shape)

X = np.vstack([Controls_FA_array, Patients_FA_array])
y = np.hstack([
    np.zeros(Controls_FA_array.shape[0], dtype=np.int64),  # 0 = Control
    np.ones(Patients_FA_array.shape[0], dtype=np.int64)    # 1 = Patient
])

np.random.seed(42)
perm = np.random.permutation(X.shape[0])
X = X[perm]
y = y[perm]
# Out:
# Patients Shape: (98, 180)
# Controls Shape: (48, 180)

# %%
def create_adj(F, alpha=1):
    F_norm = F / np.linalg.norm(F, axis=1, keepdims=True)
    W = np.dot(F_norm, F_norm.T)
    W = (W >= alpha).astype(np.float32)
    return W

# %%
def asymmetrize_random(adj_matrix, seed=None):
    """
    Randomly orient each undirected edge from a symmetric adjacency matrix.
    """
    adj = np.array(adj_matrix, dtype=np.float32)
    n = adj.shape[0]
    asym = np.zeros((n, n), dtype=np.float32)
    rng = np.random.default_rng(seed)

    for i in range(n):
        for j in range(i + 1, n):
            if adj[i, j]:
                if rng.random() < 0.5:
                    asym[i, j] = adj[i, j]
                else:
                    asym[j, i] = adj[i, j]

    return asym

# %%
def load_data(adj, node_feats):
    node_feats = torch.from_numpy(node_feats).float()
    edge_index = torch.from_numpy(np.array(np.nonzero(adj))).long()
    return node_feats, edge_index

# %%
features = X.astype(np.float32)
device = 'cuda' if torch.cuda.is_available() else 'cpu'

W0 = create_adj(features, alpha=0.5)
# W_asym = asymmetrize_random(W0, seed=42)
node_feats, edge_index = load_data(W0, features)
data = Data(x=node_feats, edge_index=edge_index).to(device)
A = torch.from_numpy(W0).to(device)
print(data)
# Out:
# Data(x=[146, 180], edge_index=[2, 21256])

# %%
class GCNEncoder(torch.nn.Module):
    def __init__(self, input_dim, hidden_dim, device, activ):
        super(GCNEncoder, self).__init__()
        self.device = device
        self.gcn1 = GCNConv(input_dim, hidden_dim)
        self.batchnorm = nn.BatchNorm1d(hidden_dim)
        self.dropout = nn.Dropout(0.25)
        self.mlp = nn.Linear(hidden_dim, hidden_dim)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = self.gcn1(x, edge_index)
        x = self.dropout(x)
        x = self.batchnorm(x)
        logits = self.mlp(x)
        return logits

# %%
class AvgReadout(nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, seq, msk=None):
        if msk is None:
            return torch.mean(seq, 0)
        else:
            msk = torch.unsqueeze(msk, -1)
            return torch.sum(seq * msk, 0) / torch.sum(msk)

# %%
class Discriminator(nn.Module):
    def __init__(self, n_h):
        super().__init__()
        self.f_k = nn.Bilinear(n_h, n_h, 1)
        nn.init.xavier_uniform_(self.f_k.weight.data)
        if self.f_k.bias is not None:
            self.f_k.bias.data.fill_(0.0)

    def forward(self, c, h_pl, h_mi):
        c_x = torch.unsqueeze(c, 0).expand_as(h_pl)
        sc_1 = torch.squeeze(self.f_k(h_pl, c_x), 1)
        sc_2 = torch.squeeze(self.f_k(h_mi, c_x), 1)
        logits = torch.cat((sc_1, sc_2), 0)
        return logits

# %%
class DGI(nn.Module):
    def __init__(self, n_in, n_h, dropout=0.25):
        super().__init__()
        self.gcn1 = GCNEncoder(n_in, n_h, device='cuda' if torch.cuda.is_available() else 'cpu', activ=nn.ELU())
        self.read = AvgReadout()
        self.sigm = nn.Sigmoid()
        self.disc = Discriminator(n_h)

    def forward(self, seq1, seq2, edge_index):
        # Create Data objects for the GCNEncoder
        data1 = Data(x=seq1, edge_index=edge_index)
        data2 = Data(x=seq2, edge_index=edge_index)

        h_1 = self.gcn1(data1)
        c = self.read(h_1)
        c = self.sigm(c)
        h_2 = self.gcn1(data2)
        logits = self.disc(c, h_1, h_2)
        return logits, h_1

# %%
class DGI_with_classifier(DGI):
    def __init__(self, n_in, n_h, n_classes=2, cut=0, dropout=0.25):
        super().__init__(n_in, n_h, dropout=dropout)
        self.classifier = nn.Linear(n_h, n_classes)
        self.cut = cut

    def get_embeddings(self, node_feats, edge_index):
        _, embeddings = self.forward(node_feats, node_feats, edge_index)
        return embeddings

    def cut_loss(self, A, S):
        S = F.softmax(S, dim=1)
        A_pool = torch.matmul(torch.matmul(A, S).t(), S)
        num = torch.trace(A_pool)
        D = torch.diag(torch.sum(A, dim=-1))
        D_pooled = torch.matmul(torch.matmul(D, S).t(), S)
        den = torch.trace(D_pooled)
        mincut_loss = -(num / den)
        St_S = torch.matmul(S.t(), S)
        I_S = torch.eye(S.shape[1], device=A.device)
        ortho_loss = torch.norm(St_S / torch.norm(St_S) - I_S / torch.norm(I_S))
        return mincut_loss + ortho_loss

    def modularity_loss(self, A, S):
        C = F.softmax(S, dim=1)
        d = torch.sum(A, dim=1)
        m = torch.sum(A)
        B = A - torch.ger(d, d) / (2 * m)
        I_S = torch.eye(C.shape[1], device=A.device)
        k = torch.norm(I_S)
        n = S.shape[0]
        modularity_term = (-1 / (2 * m)) * torch.trace(torch.mm(torch.mm(C.t(), B), C))
        collapse_reg_term = (torch.sqrt(k) / n) * torch.norm(torch.sum(C, dim=0), p='fro') - 1
        return modularity_term + collapse_reg_term

    def Reg_loss(self, A, embeddings):
        logits = self.classifier(embeddings)
        if self.cut == 1:
            return self.cut_loss(A, logits)
        else:
            return self.modularity_loss(A, logits)

# %%
hidden_dim = 512
cut = 0
dropout = 0.3
model = DGI_with_classifier(features.shape[1], hidden_dim, n_classes=2, cut=cut, dropout=dropout).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001, weight_decay = 0.00001)
bce_loss = nn.BCEWithLogitsLoss()

num_epochs = 8000
for epoch in range(num_epochs + 1):
    model.train()
    optimizer.zero_grad()

    perm = torch.randperm(node_feats.size(0))
    corrupt_features = node_feats[perm]

    logits, embeddings = model(node_feats.to(device), corrupt_features.to(device), edge_index.to(device))

    lbl = torch.cat([
        torch.ones(node_feats.size(0)),
        torch.zeros(node_feats.size(0))
    ]).to(device)

    dgi_loss = bce_loss(logits.squeeze(), lbl)
    reg_loss = model.Reg_loss(A, embeddings)
    loss = dgi_loss + 0.5 * reg_loss

    if epoch % 500 == 0:
        print(f"Epoch {epoch} | DGI Loss: {dgi_loss.item():.4f} | Reg Loss: {reg_loss.item():.4f} | Total: {loss.item():.4f}")

    loss.backward()
    optimizer.step()
# Out:
# Epoch 0 | DGI Loss: 0.7116 | Reg Loss: -0.2839 | Total: 0.5697
# Epoch 500 | DGI Loss: 0.7311 | Reg Loss: -0.2841 | Total: 0.5891
# Epoch 1000 | DGI Loss: 0.7105 | Reg Loss: -0.2841 | Total: 0.5684
# Epoch 1500 | DGI Loss: 0.6968 | Reg Loss: -0.2842 | Total: 0.5547
# Epoch 2000 | DGI Loss: 0.6961 | Reg Loss: -0.2845 | Total: 0.5539
# Epoch 2500 | DGI Loss: 0.6935 | Reg Loss: -0.2846 | Total: 0.5512
# Epoch 3000 | DGI Loss: 0.7015 | Reg Loss: -0.2844 | Total: 0.5593
# Epoch 3500 | DGI Loss: 0.6933 | Reg Loss: -0.2844 | Total: 0.5511
# Epoch 4000 | DGI Loss: 0.6938 | Reg Loss: -0.2845 | Total: 0.5516
# Epoch 4500 | DGI Loss: 0.6935 | Reg Loss: -0.2846 | Total: 0.5512
# Epoch 5000 | DGI Loss: 0.6933 | Reg Loss: -0.2846 | Total: 0.5510
# Epoch 5500 | DGI Loss: 0.6932 | Reg Loss: -0.2845 | Total: 0.5510
# Epoch 6000 | DGI Loss: 0.6931 | Reg Loss: -0.2846 | Total: 0.5509
# Epoch 6500 | DGI Loss: 0.6931 | Reg Loss: -0.2846 | Total: 0.5508
# Epoch 7000 | DGI Loss: 0.6932 | Reg Loss: -0.2844 | Total: 0.5510
# Epoch 7500 | DGI Loss: 0.6931 | Reg Loss: -0.2846 | Total: 0.5509
# Epoch 8000 | DGI Loss: 0.6931 | Reg Loss: -0.2846 | Total: 0.5509

# %%
model.eval()
with torch.no_grad():
    embeddings = model.get_embeddings(node_feats.to(device), edge_index.to(device))
    class_probabilities = F.softmax(model.classifier(embeddings), dim=1).cpu().numpy()

y_pred = np.argmax(class_probabilities, axis=1)

# %%
acc_score = accuracy_score(y, y_pred)
acc_score_inverted = accuracy_score(y, 1 - y_pred)
prec_score = precision_score(y, y_pred)
rec_score = recall_score(y, y_pred)
f1 = f1_score(y, y_pred)
log_loss_value = log_loss(y, class_probabilities)

print("Accuracy:", acc_score)
print("Accuracy (inverted):", acc_score_inverted)
print("Precision:", prec_score)
print("Recall:", rec_score)
print("F1:", f1)
print("Log Loss:", log_loss_value)
# Out:
# Accuracy: 0.678082191780822
# Accuracy (inverted): 0.3219178082191781
# Precision: 0.6976744186046512
# Recall: 0.9183673469387755
# F1: 0.7929515418502202
# Log Loss: 0.6231503046531645

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import AdamW
from torch.optim.lr_scheduler import StepLR
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, log_loss

hidden_dim   = 512
cut          = 0
dropout      = 0.3
num_runs     = 10
num_epochs   = 8000
lambda_list  = [0.1, 0.3, 0.5, 0.9]
base_seed    = 42

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

node_feats = node_feats.to(device)
edge_index = edge_index.to(device)
A = A.to(device)

if isinstance(y, torch.Tensor):
    y_np = y.detach().cpu().numpy().astype(int)
else:
    y_np = np.asarray(y).astype(int)

N, feats_dim = node_feats.size(0), node_feats.size(1)

all_results = []
bce_loss = nn.BCEWithLogitsLoss()

for lam in lambda_list:
    print(f"\n================ LAMBDA = {lam} ================\n")

    acc_scores, prec_scores, rec_scores, f1_scores, log_losses = [], [], [], [], []

    for run in range(num_runs):
        print(f"\n--- Run {run+1}/{num_runs} ---")

        seed = base_seed + run
        torch.manual_seed(seed)
        np.random.seed(seed)
        if torch.cuda.is_available():
            torch.cuda.manual_seed_all(seed)


        model = DGI_with_classifier(feats_dim, hidden_dim, n_classes=2, cut=cut, dropout=dropout).to(device)
        optimizer = torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=0.00001)
        scheduler = StepLR(optimizer, step_size=200, gamma=0.5)


        for epoch in range(num_epochs + 1):
            model.train()
            optimizer.zero_grad()

            perm = torch.randperm(N, device=device)
            corrupt_features = node_feats[perm]

            logits, embeddings = model(node_feats, corrupt_features, edge_index)

            lbl = torch.cat([torch.ones(N, device=device), torch.zeros(N, device=device)])
            dgi_loss = bce_loss(logits.squeeze(), lbl)
            reg_loss = model.Reg_loss(A, embeddings)

            loss = dgi_loss + lam * reg_loss

            if epoch % 500 == 0:
                print(f"Epoch {epoch:4d} | DGI: {dgi_loss.item():.4f} | Reg: {reg_loss.item():.4f} | "
                      f"λ*Reg: {(lam * reg_loss).item():.4f} | Total: {loss.item():.4f}")

            loss.backward()
            optimizer.step()
            scheduler.step()

        model.eval()
        with torch.no_grad():
            emb = model.get_embeddings(node_feats, edge_index)
            logits_cls = model.classifier(emb)                   # [N, 2]
            class_probabilities = F.softmax(logits_cls, dim=1).cpu().numpy()
            y_pred = np.argmax(class_probabilities, axis=1)

        acc  = accuracy_score(y_np, y_pred)
        acc_inv = accuracy_score(y_np, 1 - y_pred)

        if acc_inv > acc:
            acc = acc_inv
            y_pred = 1 - y_pred
            class_probabilities = class_probabilities[:, ::-1]

        prec = precision_score(y_np, y_pred, zero_division=0)
        rec  = recall_score(y_np, y_pred, zero_division=0)
        f1   = f1_score(y_np, y_pred, zero_division=0)
        ll   = log_loss(y_np, class_probabilities)

        print(f"Run {run+1} | Accuracy: {acc:.4f} | Precision: {prec:.4f} | Recall: {rec:.4f} | F1: {f1:.4f} | LogLoss: {ll:.4f}")

        acc_scores.append(acc)
        prec_scores.append(prec)
        rec_scores.append(rec)
        f1_scores.append(f1)
        log_losses.append(ll)

    lambda_results = {
        "lambda": lam,
        "accuracy":  (float(np.mean(acc_scores)), float(np.std(acc_scores))),
        "precision": (float(np.mean(prec_scores)), float(np.std(prec_scores))),
        "recall":    (float(np.mean(rec_scores)), float(np.std(rec_scores))),
        "f1":        (float(np.mean(f1_scores)),  float(np.std(f1_scores))),
        "log_loss":  (float(np.mean(log_losses)), float(np.std(log_losses))),
    }
    all_results.append(lambda_results)

    print(f"\n--- RESULTS FOR LAMBDA = {lam} ---")
    print(f"Accuracy : {lambda_results['accuracy'][0]:.4f} ± {lambda_results['accuracy'][1]:.4f}")
    print(f"Precision: {lambda_results['precision'][0]:.4f} ± {lambda_results['precision'][1]:.4f}")
    print(f"Recall   : {lambda_results['recall'][0]:.4f} ± {lambda_results['recall'][1]:.4f}")
    print(f"F1 Score : {lambda_results['f1'][0]:.4f} ± {lambda_results['f1'][1]:.4f}")
    print(f"Log Loss : {lambda_results['log_loss'][0]:.4f} ± {lambda_results['log_loss'][1]:.4f}")

print("\n================ FINAL SUMMARY FOR ALL LAMBDAS ================\n")
print(f"{'Lambda':>8} | {'Accuracy':>18} | {'Precision':>18} | {'Recall':>18} | {'F1 Score':>18} | {'Log Loss':>18}")
print("-" * 108)
for res in all_results:
    print(f"{res['lambda']:>8} | "
          f"{res['accuracy'][0]:.4f} ± {res['accuracy'][1]:.4f} | "
          f"{res['precision'][0]:.4f} ± {res['precision'][1]:.4f} | "
          f"{res['recall'][0]:.4f} ± {res['recall'][1]:.4f} | "
          f"{res['f1'][0]:.4f} ± {res['f1'][1]:.4f} | "
          f"{res['log_loss'][0]:.4f} ± {res['log_loss'][1]:.4f}")
# Out:
# ================ LAMBDA = 0.1 ================
#
#
# --- Run 1/10 ---
# Epoch    0 | DGI: 0.7094 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6810
# Epoch  500 | DGI: 0.6932 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Run 1 | Accuracy: 0.6849 | Precision: 0.7063 | Recall: 0.9082 | F1: 0.7946 | LogLoss: 0.6794
#
# --- Run 2/10 ---
# Epoch    0 | DGI: 0.7096 | Reg: -0.2837 | λ*Reg: -0.0284 | Total: 0.6812
# Epoch  500 | DGI: 0.6932 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Run 2 | Accuracy: 0.6781 | Precision: 0.6977 | Recall: 0.9184 | F1: 0.7930 | LogLoss: 0.6869
#
# --- Run 3/10 ---
# Epoch    0 | DGI: 0.7145 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6861
# Epoch  500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Run 3 | Accuracy: 0.6781 | Precision: 0.6977 | Recall: 0.9184 | F1: 0.7930 | LogLoss: 0.6778
#
# --- Run 4/10 ---
# Epoch    0 | DGI: 0.7136 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6852
# Epoch  500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Run 4 | Accuracy: 0.6849 | Precision: 0.7063 | Recall: 0.9082 | F1: 0.7946 | LogLoss: 0.6768
#
# --- Run 5/10 ---
# Epoch    0 | DGI: 0.7108 | Reg: -0.2837 | λ*Reg: -0.0284 | Total: 0.6824
# Epoch  500 | DGI: 0.6932 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Run 5 | Accuracy: 0.6849 | Precision: 0.7063 | Recall: 0.9082 | F1: 0.7946 | LogLoss: 0.6806
#
# --- Run 6/10 ---
# Epoch    0 | DGI: 0.7106 | Reg: -0.2839 | λ*Reg: -0.0284 | Total: 0.6822
# Epoch  500 | DGI: 0.6932 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Run 6 | Accuracy: 0.6781 | Precision: 0.6977 | Recall: 0.9184 | F1: 0.7930 | LogLoss: 0.6753
#
# --- Run 7/10 ---
# Epoch    0 | DGI: 0.7117 | Reg: -0.2840 | λ*Reg: -0.0284 | Total: 0.6833
# Epoch  500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Run 7 | Accuracy: 0.6849 | Precision: 0.7063 | Recall: 0.9082 | F1: 0.7946 | LogLoss: 0.6772
#
# --- Run 8/10 ---
# Epoch    0 | DGI: 0.7117 | Reg: -0.2839 | λ*Reg: -0.0284 | Total: 0.6833
# Epoch  500 | DGI: 0.6932 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Run 8 | Accuracy: 0.6849 | Precision: 0.7063 | Recall: 0.9082 | F1: 0.7946 | LogLoss: 0.6896
#
# --- Run 9/10 ---
# Epoch    0 | DGI: 0.7120 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6836
# Epoch  500 | DGI: 0.6932 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Run 9 | Accuracy: 0.6849 | Precision: 0.7063 | Recall: 0.9082 | F1: 0.7946 | LogLoss: 0.6752
#
# --- Run 10/10 ---
# Epoch    0 | DGI: 0.7104 | Reg: -0.2840 | λ*Reg: -0.0284 | Total: 0.6820
# Epoch  500 | DGI: 0.6932 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0284 | Total: 0.6647
# Run 10 | Accuracy: 0.6781 | Precision: 0.6977 | Recall: 0.9184 | F1: 0.7930 | LogLoss: 0.6925
#
# --- RESULTS FOR LAMBDA = 0.1 ---
# Accuracy : 0.6822 ± 0.0034
# Precision: 0.7029 ± 0.0042
# Recall   : 0.9122 ± 0.0050
# F1 Score : 0.7940 ± 0.0008
# Log Loss : 0.6811 ± 0.0059
#
# ================ LAMBDA = 0.3 ================
#
#
# --- Run 1/10 ---
# Epoch    0 | DGI: 0.7094 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6242
# Epoch  500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0853 | Total: 0.6079
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0853 | Total: 0.6079
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0853 | Total: 0.6079
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0853 | Total: 0.6079
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0853 | Total: 0.6079
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Run 1 | Accuracy: 0.6781 | Precision: 0.6977 | Recall: 0.9184 | F1: 0.7930 | LogLoss: 0.6769
#
# --- Run 2/10 ---
# Epoch    0 | DGI: 0.7096 | Reg: -0.2837 | λ*Reg: -0.0851 | Total: 0.6245
# Epoch  500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0853 | Total: 0.6079
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0853 | Total: 0.6079
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0853 | Total: 0.6079
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0853 | Total: 0.6079
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0853 | Total: 0.6079
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.0853 | Total: 0.6079
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0853 | Total: 0.6079
# Run 2 | Accuracy: 0.6781 | Precision: 0.6977 | Recall: 0.9184 | F1: 0.7930 | LogLoss: 0.6784
#
# --- Run 3/10 ---
# Epoch    0 | DGI: 0.7145 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6293
# Epoch  500 | DGI: 0.6932 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0853 | Total: 0.6079
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0853 | Total: 0.6079
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0853 | Total: 0.6079
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0853 | Total: 0.6079
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0853 | Total: 0.6079
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0853 | Total: 0.6079
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0853 | Total: 0.6079
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0853 | Total: 0.6079
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0853 | Total: 0.6079
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0853 | Total: 0.6079
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0853 | Total: 0.6079
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.0853 | Total: 0.6079
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0853 | Total: 0.6079
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0853 | Total: 0.6079
# Run 3 | Accuracy: 0.6849 | Precision: 0.7063 | Recall: 0.9082 | F1: 0.7946 | LogLoss: 0.6749
#
# --- Run 4/10 ---
# Epoch    0 | DGI: 0.7136 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6284
# Epoch  500 | DGI: 0.6932 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0853 | Total: 0.6079
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0853 | Total: 0.6079
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0853 | Total: 0.6079
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0853 | Total: 0.6079
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.0853 | Total: 0.6079
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0853 | Total: 0.6079
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.0853 | Total: 0.6079
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0853 | Total: 0.6079
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0853 | Total: 0.6079
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0853 | Total: 0.6079
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0853 | Total: 0.6079
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0853 | Total: 0.6079
# Run 4 | Accuracy: 0.6781 | Precision: 0.6977 | Recall: 0.9184 | F1: 0.7930 | LogLoss: 0.6735
#
# --- Run 5/10 ---
# Epoch    0 | DGI: 0.7108 | Reg: -0.2837 | λ*Reg: -0.0851 | Total: 0.6257
# Epoch  500 | DGI: 0.6932 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Run 5 | Accuracy: 0.6370 | Precision: 0.6596 | Recall: 0.9490 | F1: 0.7782 | LogLoss: 0.6956
#
# --- Run 6/10 ---
# Epoch    0 | DGI: 0.7106 | Reg: -0.2839 | λ*Reg: -0.0852 | Total: 0.6254
# Epoch  500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Run 6 | Accuracy: 0.6849 | Precision: 0.7063 | Recall: 0.9082 | F1: 0.7946 | LogLoss: 0.6815
#
# --- Run 7/10 ---
# Epoch    0 | DGI: 0.7117 | Reg: -0.2840 | λ*Reg: -0.0852 | Total: 0.6265
# Epoch  500 | DGI: 0.6932 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0853 | Total: 0.6079
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0853 | Total: 0.6079
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0853 | Total: 0.6079
# Run 7 | Accuracy: 0.6849 | Precision: 0.7063 | Recall: 0.9082 | F1: 0.7946 | LogLoss: 0.6754
#
# --- Run 8/10 ---
# Epoch    0 | DGI: 0.7117 | Reg: -0.2839 | λ*Reg: -0.0852 | Total: 0.6265
# Epoch  500 | DGI: 0.6932 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0853 | Total: 0.6079
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0853 | Total: 0.6079
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0853 | Total: 0.6079
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0853 | Total: 0.6079
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0853 | Total: 0.6079
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0853 | Total: 0.6079
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0853 | Total: 0.6079
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0853 | Total: 0.6079
# Run 8 | Accuracy: 0.6849 | Precision: 0.7063 | Recall: 0.9082 | F1: 0.7946 | LogLoss: 0.6761
#
# --- Run 9/10 ---
# Epoch    0 | DGI: 0.7120 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6268
# Epoch  500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0853 | Total: 0.6079
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.0853 | Total: 0.6079
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.0853 | Total: 0.6079
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.0853 | Total: 0.6079
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.0853 | Total: 0.6079
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0853 | Total: 0.6079
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0853 | Total: 0.6079
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.0853 | Total: 0.6079
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.0853 | Total: 0.6079
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.0853 | Total: 0.6079
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0853 | Total: 0.6079
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2844 | λ*Reg: -0.0853 | Total: 0.6078
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0853 | Total: 0.6079
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0853 | Total: 0.6079
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0853 | Total: 0.6079
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.0853 | Total: 0.6079
# Run 9 | Accuracy: 0.6849 | Precision: 0.7063 | Recall: 0.9082 | F1: 0.7946 | LogLoss: 0.6739
#
# --- Run 10/10 ---
# Epoch    0 | DGI: 0.7104 | Reg: -0.2840 | λ*Reg: -0.0852 | Total: 0.6252
# Epoch  500 | DGI: 0.6932 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0852 | Total: 0.6079
# Run 10 | Accuracy: 0.6781 | Precision: 0.6977 | Recall: 0.9184 | F1: 0.7930 | LogLoss: 0.6917
#
# --- RESULTS FOR LAMBDA = 0.3 ---
# Accuracy : 0.6774 ± 0.0139
# Precision: 0.6982 ± 0.0135
# Recall   : 0.9163 ± 0.0119
# F1 Score : 0.7923 ± 0.0048
# Log Loss : 0.6798 ± 0.0073
#
# ================ LAMBDA = 0.5 ================
#
#
# --- Run 1/10 ---
# Epoch    0 | DGI: 0.7094 | Reg: -0.2841 | λ*Reg: -0.1420 | Total: 0.5674
# Epoch  500 | DGI: 0.6932 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5510
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5510
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5510
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5510
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5510
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5511
# Run 1 | Accuracy: 0.6781 | Precision: 0.6977 | Recall: 0.9184 | F1: 0.7930 | LogLoss: 0.6737
#
# --- Run 2/10 ---
# Epoch    0 | DGI: 0.7096 | Reg: -0.2837 | λ*Reg: -0.1419 | Total: 0.5677
# Epoch  500 | DGI: 0.6932 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5510
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5510
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5510
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5510
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5510
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5510
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5510
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5510
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.1421 | Total: 0.5510
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5510
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.1421 | Total: 0.5510
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5510
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5510
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5511
# Run 2 | Accuracy: 0.6849 | Precision: 0.7063 | Recall: 0.9082 | F1: 0.7946 | LogLoss: 0.6752
#
# --- Run 3/10 ---
# Epoch    0 | DGI: 0.7145 | Reg: -0.2841 | λ*Reg: -0.1420 | Total: 0.5725
# Epoch  500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Run 3 | Accuracy: 0.6849 | Precision: 0.7063 | Recall: 0.9082 | F1: 0.7946 | LogLoss: 0.6837
#
# --- Run 4/10 ---
# Epoch    0 | DGI: 0.7136 | Reg: -0.2841 | λ*Reg: -0.1420 | Total: 0.5716
# Epoch  500 | DGI: 0.6932 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.1421 | Total: 0.5510
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.1422 | Total: 0.5510
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.1421 | Total: 0.5510
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5510
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5510
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.1421 | Total: 0.5510
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.1422 | Total: 0.5510
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5510
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2844 | λ*Reg: -0.1422 | Total: 0.5510
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5510
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5510
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.1421 | Total: 0.5510
# Run 4 | Accuracy: 0.6849 | Precision: 0.7063 | Recall: 0.9082 | F1: 0.7946 | LogLoss: 0.6691
#
# --- Run 5/10 ---
# Epoch    0 | DGI: 0.7108 | Reg: -0.2837 | λ*Reg: -0.1419 | Total: 0.5689
# Epoch  500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Run 5 | Accuracy: 0.6849 | Precision: 0.7063 | Recall: 0.9082 | F1: 0.7946 | LogLoss: 0.6878
#
# --- Run 6/10 ---
# Epoch    0 | DGI: 0.7106 | Reg: -0.2839 | λ*Reg: -0.1419 | Total: 0.5687
# Epoch  500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5510
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5510
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5510
# Run 6 | Accuracy: 0.6781 | Precision: 0.6977 | Recall: 0.9184 | F1: 0.7930 | LogLoss: 0.6722
#
# --- Run 7/10 ---
# Epoch    0 | DGI: 0.7117 | Reg: -0.2840 | λ*Reg: -0.1420 | Total: 0.5697
# Epoch  500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Run 7 | Accuracy: 0.6849 | Precision: 0.7063 | Recall: 0.9082 | F1: 0.7946 | LogLoss: 0.6877
#
# --- Run 8/10 ---
# Epoch    0 | DGI: 0.7117 | Reg: -0.2839 | λ*Reg: -0.1419 | Total: 0.5697
# Epoch  500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5510
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5510
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.1421 | Total: 0.5510
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5510
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5510
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5510
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.1422 | Total: 0.5510
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5510
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5510
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5510
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.1421 | Total: 0.5510
# Run 8 | Accuracy: 0.6849 | Precision: 0.7063 | Recall: 0.9082 | F1: 0.7946 | LogLoss: 0.6739
#
# --- Run 9/10 ---
# Epoch    0 | DGI: 0.7120 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5700
# Epoch  500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5510
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5510
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Run 9 | Accuracy: 0.6849 | Precision: 0.7063 | Recall: 0.9082 | F1: 0.7946 | LogLoss: 0.6769
#
# --- Run 10/10 ---
# Epoch    0 | DGI: 0.7104 | Reg: -0.2840 | λ*Reg: -0.1420 | Total: 0.5684
# Epoch  500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.1421 | Total: 0.5511
# Run 10 | Accuracy: 0.6781 | Precision: 0.6977 | Recall: 0.9184 | F1: 0.7930 | LogLoss: 0.6772
#
# --- RESULTS FOR LAMBDA = 0.5 ---
# Accuracy : 0.6829 ± 0.0031
# Precision: 0.7037 ± 0.0040
# Recall   : 0.9112 ± 0.0047
# F1 Score : 0.7941 ± 0.0008
# Log Loss : 0.6777 ± 0.0062
#
# ================ LAMBDA = 0.9 ================
#
#
# --- Run 1/10 ---
# Epoch    0 | DGI: 0.7094 | Reg: -0.2841 | λ*Reg: -0.2557 | Total: 0.4538
# Epoch  500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.2557 | Total: 0.4374
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4374
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4374
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4374
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4374
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4374
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.2558 | Total: 0.4373
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.2558 | Total: 0.4373
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4373
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4373
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4373
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4374
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4373
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4374
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4374
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4373
# Run 1 | Accuracy: 0.6849 | Precision: 0.7063 | Recall: 0.9082 | F1: 0.7946 | LogLoss: 0.6739
#
# --- Run 2/10 ---
# Epoch    0 | DGI: 0.7096 | Reg: -0.2837 | λ*Reg: -0.2554 | Total: 0.4542
# Epoch  500 | DGI: 0.6932 | Reg: -0.2841 | λ*Reg: -0.2557 | Total: 0.4375
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.2557 | Total: 0.4374
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.2557 | Total: 0.4374
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.2557 | Total: 0.4374
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4374
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.2557 | Total: 0.4374
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4374
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2557 | Total: 0.4374
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.2557 | Total: 0.4374
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.2557 | Total: 0.4374
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4374
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2557 | Total: 0.4374
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2557 | Total: 0.4374
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4373
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.2557 | Total: 0.4374
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4373
# Run 2 | Accuracy: 0.6781 | Precision: 0.6977 | Recall: 0.9184 | F1: 0.7930 | LogLoss: 0.6786
#
# --- Run 3/10 ---
# Epoch    0 | DGI: 0.7145 | Reg: -0.2841 | λ*Reg: -0.2557 | Total: 0.4588
# Epoch  500 | DGI: 0.6932 | Reg: -0.2843 | λ*Reg: -0.2558 | Total: 0.4373
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4374
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4373
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.2558 | Total: 0.4373
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.2558 | Total: 0.4373
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.2559 | Total: 0.4373
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.2559 | Total: 0.4373
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.2558 | Total: 0.4373
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.2559 | Total: 0.4373
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.2558 | Total: 0.4373
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.2558 | Total: 0.4373
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.2559 | Total: 0.4373
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.2559 | Total: 0.4373
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4374
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.2559 | Total: 0.4373
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4374
# Run 3 | Accuracy: 0.6849 | Precision: 0.7063 | Recall: 0.9082 | F1: 0.7946 | LogLoss: 0.6725
#
# --- Run 4/10 ---
# Epoch    0 | DGI: 0.7136 | Reg: -0.2841 | λ*Reg: -0.2557 | Total: 0.4579
# Epoch  500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2557 | Total: 0.4374
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.2557 | Total: 0.4374
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.2557 | Total: 0.4374
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.2557 | Total: 0.4374
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.2557 | Total: 0.4374
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4374
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4374
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.2557 | Total: 0.4374
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4373
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.2557 | Total: 0.4374
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4374
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4374
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.2558 | Total: 0.4373
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4374
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4374
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2557 | Total: 0.4374
# Run 4 | Accuracy: 0.6849 | Precision: 0.7063 | Recall: 0.9082 | F1: 0.7946 | LogLoss: 0.6776
#
# --- Run 5/10 ---
# Epoch    0 | DGI: 0.7108 | Reg: -0.2837 | λ*Reg: -0.2553 | Total: 0.4555
# Epoch  500 | DGI: 0.6932 | Reg: -0.2841 | λ*Reg: -0.2557 | Total: 0.4375
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.2557 | Total: 0.4375
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.2557 | Total: 0.4374
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.2557 | Total: 0.4375
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.2557 | Total: 0.4374
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.2557 | Total: 0.4374
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.2557 | Total: 0.4374
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.2557 | Total: 0.4375
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.2557 | Total: 0.4374
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.2557 | Total: 0.4375
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.2557 | Total: 0.4374
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.2557 | Total: 0.4374
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.2557 | Total: 0.4375
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.2557 | Total: 0.4375
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.2557 | Total: 0.4375
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.2557 | Total: 0.4374
# Run 5 | Accuracy: 0.6781 | Precision: 0.6977 | Recall: 0.9184 | F1: 0.7930 | LogLoss: 0.6853
#
# --- Run 6/10 ---
# Epoch    0 | DGI: 0.7106 | Reg: -0.2839 | λ*Reg: -0.2555 | Total: 0.4551
# Epoch  500 | DGI: 0.6932 | Reg: -0.2841 | λ*Reg: -0.2557 | Total: 0.4374
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4374
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4374
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.2558 | Total: 0.4373
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4373
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4374
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4374
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4374
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4374
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4373
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.2558 | Total: 0.4373
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4373
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4374
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4374
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4374
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4374
# Run 6 | Accuracy: 0.6781 | Precision: 0.6977 | Recall: 0.9184 | F1: 0.7930 | LogLoss: 0.6753
#
# --- Run 7/10 ---
# Epoch    0 | DGI: 0.7117 | Reg: -0.2840 | λ*Reg: -0.2556 | Total: 0.4561
# Epoch  500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.2557 | Total: 0.4375
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.2557 | Total: 0.4375
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.2557 | Total: 0.4375
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.2557 | Total: 0.4375
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.2557 | Total: 0.4375
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.2557 | Total: 0.4375
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.2557 | Total: 0.4375
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.2557 | Total: 0.4375
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.2557 | Total: 0.4375
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.2557 | Total: 0.4375
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.2557 | Total: 0.4375
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.2557 | Total: 0.4375
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.2557 | Total: 0.4375
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.2557 | Total: 0.4375
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.2557 | Total: 0.4375
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.2557 | Total: 0.4375
# Run 7 | Accuracy: 0.6438 | Precision: 0.6620 | Recall: 0.9592 | F1: 0.7833 | LogLoss: 0.6936
#
# --- Run 8/10 ---
# Epoch    0 | DGI: 0.7117 | Reg: -0.2839 | λ*Reg: -0.2555 | Total: 0.4562
# Epoch  500 | DGI: 0.6932 | Reg: -0.2841 | λ*Reg: -0.2557 | Total: 0.4375
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4374
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4374
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4373
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.2559 | Total: 0.4373
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4373
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4374
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4373
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2557 | Total: 0.4374
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4373
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.2558 | Total: 0.4373
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.2558 | Total: 0.4373
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4374
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.2558 | Total: 0.4373
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4373
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4374
# Run 8 | Accuracy: 0.6849 | Precision: 0.7063 | Recall: 0.9082 | F1: 0.7946 | LogLoss: 0.6744
#
# --- Run 9/10 ---
# Epoch    0 | DGI: 0.7120 | Reg: -0.2841 | λ*Reg: -0.2557 | Total: 0.4563
# Epoch  500 | DGI: 0.6932 | Reg: -0.2843 | λ*Reg: -0.2559 | Total: 0.4373
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4373
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4373
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2844 | λ*Reg: -0.2559 | Total: 0.4372
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.2559 | Total: 0.4373
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4374
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.2559 | Total: 0.4373
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.2558 | Total: 0.4373
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.2559 | Total: 0.4372
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.2559 | Total: 0.4373
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.2559 | Total: 0.4373
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.2559 | Total: 0.4372
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.2559 | Total: 0.4373
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.2559 | Total: 0.4373
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4374
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.2559 | Total: 0.4373
# Run 9 | Accuracy: 0.6849 | Precision: 0.7063 | Recall: 0.9082 | F1: 0.7946 | LogLoss: 0.6682
#
# --- Run 10/10 ---
# Epoch    0 | DGI: 0.7104 | Reg: -0.2840 | λ*Reg: -0.2556 | Total: 0.4548
# Epoch  500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4373
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.2559 | Total: 0.4373
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.2558 | Total: 0.4373
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.2559 | Total: 0.4372
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4373
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.2559 | Total: 0.4373
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.2559 | Total: 0.4373
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.2559 | Total: 0.4372
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.2559 | Total: 0.4373
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.2558 | Total: 0.4373
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4374
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4373
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4373
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.2558 | Total: 0.4373
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2842 | λ*Reg: -0.2558 | Total: 0.4373
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2843 | λ*Reg: -0.2559 | Total: 0.4373
# Run 10 | Accuracy: 0.6849 | Precision: 0.7063 | Recall: 0.9082 | F1: 0.7946 | LogLoss: 0.6752
#
# --- RESULTS FOR LAMBDA = 0.9 ---
# Accuracy : 0.6788 ± 0.0120
# Precision: 0.6993 ± 0.0130
# Recall   : 0.9163 ± 0.0150
# F1 Score : 0.7930 ± 0.0033
# Log Loss : 0.6775 ± 0.0068
#
# ================ FINAL SUMMARY FOR ALL LAMBDAS ================
#
#   Lambda |           Accuracy |          Precision |             Recall |           F1 Score |           Log Loss
# ------------------------------------------------------------------------------------------------------------
#      0.1 | 0.6822 ± 0.0034 | 0.7029 ± 0.0042 | 0.9122 ± 0.0050 | 0.7940 ± 0.0008 | 0.6811 ± 0.0059
#      0.3 | 0.6774 ± 0.0139 | 0.6982 ± 0.0135 | 0.9163 ± 0.0119 | 0.7923 ± 0.0048 | 0.6798 ± 0.0073
#      0.5 | 0.6829 ± 0.0031 | 0.7037 ± 0.0040 | 0.9112 ± 0.0047 | 0.7941 ± 0.0008 | 0.6777 ± 0.0062
#      0.9 | 0.6788 ± 0.0120 | 0.6993 ± 0.0130 | 0.9163 ± 0.0150 | 0.7930 ± 0.0033 | 0.6775 ± 0.0068

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import AdamW
from torch.optim.lr_scheduler import StepLR
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, log_loss

hidden_dim   = 512
cut          = 0
dropout      = 0.25
num_runs     = 10
num_epochs   = 8000
lambda_list  = [0.001, 0.005, 0.009, 0.01, 0.05, 0.09, 0.1, 0.3, 0.5, 0.9, 1, 2, 5, 8]
base_seed    = 42

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

node_feats = node_feats.to(device)
edge_index = edge_index.to(device)
A = A.to(device)

if isinstance(y, torch.Tensor):
    y_np = y.detach().cpu().numpy().astype(int)
else:
    y_np = np.asarray(y).astype(int)

N, feats_dim = node_feats.size(0), node_feats.size(1)

all_results = []
bce_loss = nn.BCEWithLogitsLoss()

for lam in lambda_list:
    print(f"\n================ LAMBDA = {lam} ================\n")

    acc_scores, prec_scores, rec_scores, f1_scores, log_losses = [], [], [], [], []

    for run in range(num_runs):
        print(f"\n--- Run {run+1}/{num_runs} ---")

        seed = base_seed + run
        torch.manual_seed(seed)
        np.random.seed(seed)
        if torch.cuda.is_available():
            torch.cuda.manual_seed_all(seed)


        model = DGI_with_classifier(feats_dim, hidden_dim, n_classes=2, cut=cut, dropout=dropout).to(device)
        optimizer = torch.optim.Adam(model.parameters(), lr=0.0001, weight_decay=0.0001)
        scheduler = StepLR(optimizer, step_size=200, gamma=0.5)


        for epoch in range(num_epochs + 1):
            model.train()
            optimizer.zero_grad()

            perm = torch.randperm(N, device=device)
            corrupt_features = node_feats[perm]

            logits, embeddings = model(node_feats, corrupt_features, edge_index)

            lbl = torch.cat([torch.ones(N, device=device), torch.zeros(N, device=device)])
            dgi_loss = bce_loss(logits.squeeze(), lbl)
            reg_loss = model.Reg_loss(A, embeddings)

            loss = dgi_loss + lam * reg_loss

            if epoch % 500 == 0:
                print(f"Epoch {epoch:4d} | DGI: {dgi_loss.item():.4f} | Reg: {reg_loss.item():.4f} | "
                      f"λ*Reg: {(lam * reg_loss).item():.4f} | Total: {loss.item():.4f}")

            loss.backward()
            optimizer.step()
            scheduler.step()

        model.eval()
        with torch.no_grad():
            emb = model.get_embeddings(node_feats, edge_index)
            logits_cls = model.classifier(emb)                   # [N, 2]
            class_probabilities = F.softmax(logits_cls, dim=1).cpu().numpy()
            y_pred = np.argmax(class_probabilities, axis=1)

        acc  = accuracy_score(y_np, y_pred)
        acc_inv = accuracy_score(y_np, 1 - y_pred)

        if acc_inv > acc:
            acc = acc_inv
            y_pred = 1 - y_pred
            class_probabilities = class_probabilities[:, ::-1]

        prec = precision_score(y_np, y_pred, zero_division=0)
        rec  = recall_score(y_np, y_pred, zero_division=0)
        f1   = f1_score(y_np, y_pred, zero_division=0)
        ll   = log_loss(y_np, class_probabilities)

        print(f"Run {run+1} | Accuracy: {acc:.4f} | Precision: {prec:.4f} | Recall: {rec:.4f} | F1: {f1:.4f} | LogLoss: {ll:.4f}")

        acc_scores.append(acc)
        prec_scores.append(prec)
        rec_scores.append(rec)
        f1_scores.append(f1)
        log_losses.append(ll)

    lambda_results = {
        "lambda": lam,
        "accuracy":  (float(np.mean(acc_scores)), float(np.std(acc_scores))),
        "precision": (float(np.mean(prec_scores)), float(np.std(prec_scores))),
        "recall":    (float(np.mean(rec_scores)), float(np.std(rec_scores))),
        "f1":        (float(np.mean(f1_scores)),  float(np.std(f1_scores))),
        "log_loss":  (float(np.mean(log_losses)), float(np.std(log_losses))),
    }
    all_results.append(lambda_results)

    print(f"\n--- RESULTS FOR LAMBDA = {lam} ---")
    print(f"Accuracy : {lambda_results['accuracy'][0]:.4f} ± {lambda_results['accuracy'][1]:.4f}")
    print(f"Precision: {lambda_results['precision'][0]:.4f} ± {lambda_results['precision'][1]:.4f}")
    print(f"Recall   : {lambda_results['recall'][0]:.4f} ± {lambda_results['recall'][1]:.4f}")
    print(f"F1 Score : {lambda_results['f1'][0]:.4f} ± {lambda_results['f1'][1]:.4f}")
    print(f"Log Loss : {lambda_results['log_loss'][0]:.4f} ± {lambda_results['log_loss'][1]:.4f}")

print("\n================ FINAL SUMMARY FOR ALL LAMBDAS ================\n")
print(f"{'Lambda':>8} | {'Accuracy':>18} | {'Precision':>18} | {'Recall':>18} | {'F1 Score':>18} | {'Log Loss':>18}")
print("-" * 108)
for res in all_results:
    print(f"{res['lambda']:>8} | "
          f"{res['accuracy'][0]:.4f} ± {res['accuracy'][1]:.4f} | "
          f"{res['precision'][0]:.4f} ± {res['precision'][1]:.4f} | "
          f"{res['recall'][0]:.4f} ± {res['recall'][1]:.4f} | "
          f"{res['f1'][0]:.4f} ± {res['f1'][1]:.4f} | "
          f"{res['log_loss'][0]:.4f} ± {res['log_loss'][1]:.4f}")
# Out:
# ================ LAMBDA = 0.001 ================
#
#
# --- Run 1/10 ---
# Epoch    0 | DGI: 0.7107 | Reg: -0.2835 | λ*Reg: -0.0003 | Total: 0.7105
# Epoch  500 | DGI: 0.6931 | Reg: -0.2840 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2840 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2840 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2840 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2840 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2840 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2840 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2840 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2840 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2840 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2840 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2840 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2840 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2840 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2840 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2840 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 8500 | DGI: 0.6931 | Reg: -0.2840 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 9000 | DGI: 0.6931 | Reg: -0.2840 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 9500 | DGI: 0.6931 | Reg: -0.2840 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 10000 | DGI: 0.6931 | Reg: -0.2840 | λ*Reg: -0.0003 | Total: 0.6929
# Run 1 | Accuracy: 0.6712 | Precision: 0.6712 | Recall: 1.0000 | F1: 0.8033 | LogLoss: 0.6882
#
# --- Run 2/10 ---
# Epoch    0 | DGI: 0.7106 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.7103
# Epoch  500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 8500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 9000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 9500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 10000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Run 2 | Accuracy: 0.6507 | Precision: 0.6643 | Recall: 0.9694 | F1: 0.7884 | LogLoss: 0.6926
#
# --- Run 3/10 ---
# Epoch    0 | DGI: 0.7139 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.7136
# Epoch  500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 8500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 9000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 9500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 10000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Run 3 | Accuracy: 0.6712 | Precision: 0.6712 | Recall: 1.0000 | F1: 0.8033 | LogLoss: 0.6924
#
# --- Run 4/10 ---
# Epoch    0 | DGI: 0.7059 | Reg: -0.2833 | λ*Reg: -0.0003 | Total: 0.7057
# Epoch  500 | DGI: 0.6931 | Reg: -0.2840 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2840 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2840 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2840 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2840 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2840 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2840 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2840 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2840 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2840 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2840 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2840 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2840 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2840 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2840 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2840 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 8500 | DGI: 0.6931 | Reg: -0.2840 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 9000 | DGI: 0.6931 | Reg: -0.2840 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 9500 | DGI: 0.6931 | Reg: -0.2840 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 10000 | DGI: 0.6931 | Reg: -0.2840 | λ*Reg: -0.0003 | Total: 0.6929
# Run 4 | Accuracy: 0.6712 | Precision: 0.6712 | Recall: 1.0000 | F1: 0.8033 | LogLoss: 0.6876
#
# --- Run 5/10 ---
# Epoch    0 | DGI: 0.7134 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.7131
# Epoch  500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 8500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 9000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 9500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 10000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Run 5 | Accuracy: 0.6712 | Precision: 0.6761 | Recall: 0.9796 | F1: 0.8000 | LogLoss: 0.6923
#
# --- Run 6/10 ---
# Epoch    0 | DGI: 0.7130 | Reg: -0.2833 | λ*Reg: -0.0003 | Total: 0.7127
# Epoch  500 | DGI: 0.6931 | Reg: -0.2840 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2840 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2840 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2840 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2840 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2840 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2840 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2840 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2840 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2840 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2840 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2840 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2840 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2840 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2840 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2840 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 8500 | DGI: 0.6931 | Reg: -0.2840 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 9000 | DGI: 0.6931 | Reg: -0.2840 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 9500 | DGI: 0.6931 | Reg: -0.2840 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 10000 | DGI: 0.6931 | Reg: -0.2840 | λ*Reg: -0.0003 | Total: 0.6929
# Run 6 | Accuracy: 0.6712 | Precision: 0.6712 | Recall: 1.0000 | F1: 0.8033 | LogLoss: 0.6866
#
# --- Run 7/10 ---
# Epoch    0 | DGI: 0.7126 | Reg: -0.2832 | λ*Reg: -0.0003 | Total: 0.7124
# Epoch  500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 8500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 9000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 9500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 10000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Run 7 | Accuracy: 0.6849 | Precision: 0.6806 | Recall: 1.0000 | F1: 0.8099 | LogLoss: 0.6897
#
# --- Run 8/10 ---
# Epoch    0 | DGI: 0.7120 | Reg: -0.2835 | λ*Reg: -0.0003 | Total: 0.7117
# Epoch  500 | DGI: 0.6931 | Reg: -0.2840 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 8500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 9000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 9500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 10000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Run 8 | Accuracy: 0.6712 | Precision: 0.6712 | Recall: 1.0000 | F1: 0.8033 | LogLoss: 0.6883
#
# --- Run 9/10 ---
# Epoch    0 | DGI: 0.7101 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.7098
# Epoch  500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 8500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 9000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 9500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 10000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Run 9 | Accuracy: 0.6781 | Precision: 0.6947 | Recall: 0.9286 | F1: 0.7948 | LogLoss: 0.6915
#
# --- Run 10/10 ---
# Epoch    0 | DGI: 0.7064 | Reg: -0.2838 | λ*Reg: -0.0003 | Total: 0.7061
# Epoch  500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 8500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 9000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 9500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Epoch 10000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0003 | Total: 0.6929
# Run 10 | Accuracy: 0.6575 | Precision: 0.6667 | Recall: 0.9796 | F1: 0.7934 | LogLoss: 0.6916
#
# --- RESULTS FOR LAMBDA = 0.001 ---
# Accuracy : 0.6699 ± 0.0091
# Precision: 0.6738 ± 0.0081
# Recall   : 0.9857 ± 0.0220
# F1 Score : 0.8003 ± 0.0060
# Log Loss : 0.6901 ± 0.0021
#
# ================ LAMBDA = 0.005 ================
#
#
# --- Run 1/10 ---
# Epoch    0 | DGI: 0.7107 | Reg: -0.2835 | λ*Reg: -0.0014 | Total: 0.7093
# Epoch  500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 8500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 9000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 9500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 10000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Run 1 | Accuracy: 0.6712 | Precision: 0.6712 | Recall: 1.0000 | F1: 0.8033 | LogLoss: 0.6899
#
# --- Run 2/10 ---
# Epoch    0 | DGI: 0.7106 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.7092
# Epoch  500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 8500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 9000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 9500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 10000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Run 2 | Accuracy: 0.6507 | Precision: 0.6691 | Recall: 0.9490 | F1: 0.7848 | LogLoss: 0.6932
#
# --- Run 3/10 ---
# Epoch    0 | DGI: 0.7139 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.7124
# Epoch  500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 8500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 9000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 9500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 10000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Run 3 | Accuracy: 0.6575 | Precision: 0.6667 | Recall: 0.9796 | F1: 0.7934 | LogLoss: 0.6931
#
# --- Run 4/10 ---
# Epoch    0 | DGI: 0.7059 | Reg: -0.2833 | λ*Reg: -0.0014 | Total: 0.7045
# Epoch  500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 8500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 9000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 9500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 10000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Run 4 | Accuracy: 0.6712 | Precision: 0.6712 | Recall: 1.0000 | F1: 0.8033 | LogLoss: 0.6893
#
# --- Run 5/10 ---
# Epoch    0 | DGI: 0.7134 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.7120
# Epoch  500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 8500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 9000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 9500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 10000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Run 5 | Accuracy: 0.6644 | Precision: 0.6738 | Recall: 0.9694 | F1: 0.7950 | LogLoss: 0.6933
#
# --- Run 6/10 ---
# Epoch    0 | DGI: 0.7130 | Reg: -0.2833 | λ*Reg: -0.0014 | Total: 0.7116
# Epoch  500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 8500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 9000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 9500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 10000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Run 6 | Accuracy: 0.6712 | Precision: 0.6712 | Recall: 1.0000 | F1: 0.8033 | LogLoss: 0.6886
#
# --- Run 7/10 ---
# Epoch    0 | DGI: 0.7126 | Reg: -0.2832 | λ*Reg: -0.0014 | Total: 0.7112
# Epoch  500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 8500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 9000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 9500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 10000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Run 7 | Accuracy: 0.6849 | Precision: 0.6806 | Recall: 1.0000 | F1: 0.8099 | LogLoss: 0.6906
#
# --- Run 8/10 ---
# Epoch    0 | DGI: 0.7120 | Reg: -0.2835 | λ*Reg: -0.0014 | Total: 0.7105
# Epoch  500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 8500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 9000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 9500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 10000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Run 8 | Accuracy: 0.6781 | Precision: 0.6783 | Recall: 0.9898 | F1: 0.8050 | LogLoss: 0.6896
#
# --- Run 9/10 ---
# Epoch    0 | DGI: 0.7101 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.7086
# Epoch  500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 8500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 9000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 9500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 10000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Run 9 | Accuracy: 0.6712 | Precision: 0.6953 | Recall: 0.9082 | F1: 0.7876 | LogLoss: 0.6926
#
# --- Run 10/10 ---
# Epoch    0 | DGI: 0.7064 | Reg: -0.2838 | λ*Reg: -0.0014 | Total: 0.7049
# Epoch  500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 8500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 9000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 9500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Epoch 10000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0014 | Total: 0.6917
# Run 10 | Accuracy: 0.6644 | Precision: 0.6738 | Recall: 0.9694 | F1: 0.7950 | LogLoss: 0.6924
#
# --- RESULTS FOR LAMBDA = 0.005 ---
# Accuracy : 0.6685 ± 0.0093
# Precision: 0.6751 ± 0.0078
# Recall   : 0.9765 ± 0.0281
# F1 Score : 0.7981 ± 0.0077
# Log Loss : 0.6913 ± 0.0017
#
# ================ LAMBDA = 0.009 ================
#
#
# --- Run 1/10 ---
# Epoch    0 | DGI: 0.7107 | Reg: -0.2835 | λ*Reg: -0.0026 | Total: 0.7082
# Epoch  500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 8500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 9000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 9500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 10000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Run 1 | Accuracy: 0.6712 | Precision: 0.6712 | Recall: 1.0000 | F1: 0.8033 | LogLoss: 0.6906
#
# --- Run 2/10 ---
# Epoch    0 | DGI: 0.7106 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.7081
# Epoch  500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 8500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 9000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 9500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 10000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Run 2 | Accuracy: 0.6438 | Precision: 0.6667 | Recall: 0.9388 | F1: 0.7797 | LogLoss: 0.6933
#
# --- Run 3/10 ---
# Epoch    0 | DGI: 0.7139 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.7113
# Epoch  500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 8500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 9000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 9500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 10000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Run 3 | Accuracy: 0.6575 | Precision: 0.6667 | Recall: 0.9796 | F1: 0.7934 | LogLoss: 0.6931
#
# --- Run 4/10 ---
# Epoch    0 | DGI: 0.7059 | Reg: -0.2833 | λ*Reg: -0.0026 | Total: 0.7034
# Epoch  500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 8500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 9000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 9500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 10000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Run 4 | Accuracy: 0.6849 | Precision: 0.6806 | Recall: 1.0000 | F1: 0.8099 | LogLoss: 0.6902
#
# --- Run 5/10 ---
# Epoch    0 | DGI: 0.7134 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.7109
# Epoch  500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 8500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 9000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 9500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 10000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Run 5 | Accuracy: 0.6644 | Precision: 0.6738 | Recall: 0.9694 | F1: 0.7950 | LogLoss: 0.6934
#
# --- Run 6/10 ---
# Epoch    0 | DGI: 0.7130 | Reg: -0.2833 | λ*Reg: -0.0025 | Total: 0.7104
# Epoch  500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 8500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 9000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 9500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 10000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Run 6 | Accuracy: 0.6712 | Precision: 0.6712 | Recall: 1.0000 | F1: 0.8033 | LogLoss: 0.6898
#
# --- Run 7/10 ---
# Epoch    0 | DGI: 0.7126 | Reg: -0.2832 | λ*Reg: -0.0025 | Total: 0.7101
# Epoch  500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 8500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 9000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 9500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 10000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Run 7 | Accuracy: 0.6712 | Precision: 0.6712 | Recall: 1.0000 | F1: 0.8033 | LogLoss: 0.6913
#
# --- Run 8/10 ---
# Epoch    0 | DGI: 0.7120 | Reg: -0.2835 | λ*Reg: -0.0026 | Total: 0.7094
# Epoch  500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 8500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 9000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 9500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 10000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Run 8 | Accuracy: 0.6986 | Precision: 0.6929 | Recall: 0.9898 | F1: 0.8151 | LogLoss: 0.6903
#
# --- Run 9/10 ---
# Epoch    0 | DGI: 0.7101 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.7075
# Epoch  500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 8500 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# Epoch 9000 | DGI: 0.6931 | Reg: -0.2841 | λ*Reg: -0.0026 | Total: 0.6906
# ...
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5844
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5845
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5845
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2775 | Total: -1.5844
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2775 | Total: -1.5843
# Epoch 8500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5845
# Epoch 9000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2775 | Total: -1.5843
# Epoch 9500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5844
# Epoch 10000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2775 | Total: -1.5843
# Run 2 | Accuracy: 0.6849 | Precision: 0.7063 | Recall: 0.9082 | F1: 0.7946 | LogLoss: 0.7554
#
# --- Run 3/10 ---
# Epoch    0 | DGI: 0.7139 | Reg: -0.2841 | λ*Reg: -2.2724 | Total: -1.5586
# Epoch  500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2775 | Total: -1.5843
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2775 | Total: -1.5844
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2774 | Total: -1.5842
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5845
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2777 | Total: -1.5845
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5844
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2775 | Total: -1.5843
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2777 | Total: -1.5845
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5844
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2777 | Total: -1.5845
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5844
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2777 | Total: -1.5845
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5845
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5845
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5845
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5845
# Epoch 8500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5845
# Epoch 9000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2777 | Total: -1.5845
# Epoch 9500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5844
# Epoch 10000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5844
# Run 3 | Accuracy: 0.6849 | Precision: 0.7063 | Recall: 0.9082 | F1: 0.7946 | LogLoss: 0.7599
#
# --- Run 4/10 ---
# Epoch    0 | DGI: 0.7059 | Reg: -0.2833 | λ*Reg: -2.2667 | Total: -1.5608
# Epoch  500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2772 | Total: -1.5841
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5844
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2775 | Total: -1.5844
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2775 | Total: -1.5844
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2775 | Total: -1.5844
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5845
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2774 | Total: -1.5842
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5845
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5845
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5845
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5844
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5845
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2775 | Total: -1.5843
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2775 | Total: -1.5844
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2775 | Total: -1.5843
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2777 | Total: -1.5845
# Epoch 8500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2777 | Total: -1.5845
# Epoch 9000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5844
# Epoch 9500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5845
# Epoch 10000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2775 | Total: -1.5844
# Run 4 | Accuracy: 0.6849 | Precision: 0.7063 | Recall: 0.9082 | F1: 0.7946 | LogLoss: 0.7568
#
# --- Run 5/10 ---
# Epoch    0 | DGI: 0.7134 | Reg: -0.2841 | λ*Reg: -2.2727 | Total: -1.5593
# Epoch  500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2774 | Total: -1.5843
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5845
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5845
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2777 | Total: -1.5845
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2775 | Total: -1.5844
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5844
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5845
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2777 | Total: -1.5845
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2775 | Total: -1.5844
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2775 | Total: -1.5843
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5844
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2777 | Total: -1.5845
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2777 | Total: -1.5846
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2775 | Total: -1.5843
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2777 | Total: -1.5845
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5845
# Epoch 8500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5844
# Epoch 9000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5844
# Epoch 9500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2777 | Total: -1.5845
# Epoch 10000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5845
# Run 5 | Accuracy: 0.6849 | Precision: 0.7063 | Recall: 0.9082 | F1: 0.7946 | LogLoss: 0.7654
#
# --- Run 6/10 ---
# Epoch    0 | DGI: 0.7130 | Reg: -0.2833 | λ*Reg: -2.2661 | Total: -1.5531
# Epoch  500 | DGI: 0.6931 | Reg: -0.2846 | λ*Reg: -2.2771 | Total: -1.5839
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5844
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2777 | Total: -1.5845
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5845
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5844
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5845
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2775 | Total: -1.5844
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2777 | Total: -1.5845
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5844
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5845
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2773 | Total: -1.5842
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5845
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2775 | Total: -1.5844
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2777 | Total: -1.5846
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2775 | Total: -1.5844
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2773 | Total: -1.5842
# Epoch 8500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5845
# Epoch 9000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2775 | Total: -1.5843
# Epoch 9500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5844
# Epoch 10000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5845
# Run 6 | Accuracy: 0.6849 | Precision: 0.7063 | Recall: 0.9082 | F1: 0.7946 | LogLoss: 0.7515
#
# --- Run 7/10 ---
# Epoch    0 | DGI: 0.7126 | Reg: -0.2832 | λ*Reg: -2.2657 | Total: -1.5530
# Epoch  500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2772 | Total: -1.5841
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2774 | Total: -1.5843
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2775 | Total: -1.5844
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2774 | Total: -1.5842
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5845
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2773 | Total: -1.5841
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2775 | Total: -1.5844
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2775 | Total: -1.5844
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5845
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5844
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5844
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2775 | Total: -1.5844
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2775 | Total: -1.5844
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2775 | Total: -1.5844
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5844
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2775 | Total: -1.5844
# Epoch 8500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2775 | Total: -1.5844
# Epoch 9000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5844
# Epoch 9500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2775 | Total: -1.5844
# Epoch 10000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2777 | Total: -1.5845
# Run 7 | Accuracy: 0.6849 | Precision: 0.7063 | Recall: 0.9082 | F1: 0.7946 | LogLoss: 0.7473
#
# --- Run 8/10 ---
# Epoch    0 | DGI: 0.7120 | Reg: -0.2835 | λ*Reg: -2.2678 | Total: -1.5558
# Epoch  500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2773 | Total: -1.5841
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2775 | Total: -1.5843
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5845
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5844
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2775 | Total: -1.5843
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5844
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2775 | Total: -1.5843
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5845
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2775 | Total: -1.5843
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2775 | Total: -1.5844
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2777 | Total: -1.5845
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2775 | Total: -1.5844
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5844
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5844
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2775 | Total: -1.5844
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5844
# Epoch 8500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5844
# Epoch 9000 | DGI: 0.6931 | Reg: -0.2846 | λ*Reg: -2.2771 | Total: -1.5839
# Epoch 9500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5845
# Epoch 10000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2774 | Total: -1.5843
# Run 8 | Accuracy: 0.6849 | Precision: 0.7063 | Recall: 0.9082 | F1: 0.7946 | LogLoss: 0.7486
#
# --- Run 9/10 ---
# Epoch    0 | DGI: 0.7101 | Reg: -0.2841 | λ*Reg: -2.2725 | Total: -1.5624
# Epoch  500 | DGI: 0.6931 | Reg: -0.2846 | λ*Reg: -2.2771 | Total: -1.5840
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5844
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5844
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5844
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5845
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5845
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2777 | Total: -1.5845
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2777 | Total: -1.5845
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2775 | Total: -1.5844
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2773 | Total: -1.5842
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5844
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5844
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2775 | Total: -1.5844
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5844
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2775 | Total: -1.5843
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5845
# Epoch 8500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2775 | Total: -1.5844
# Epoch 9000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5845
# Epoch 9500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5844
# Epoch 10000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5845
# Run 9 | Accuracy: 0.6849 | Precision: 0.7063 | Recall: 0.9082 | F1: 0.7946 | LogLoss: 0.7599
#
# --- Run 10/10 ---
# Epoch    0 | DGI: 0.7064 | Reg: -0.2838 | λ*Reg: -2.2707 | Total: -1.5643
# Epoch  500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5845
# Epoch 1000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5845
# Epoch 1500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2777 | Total: -1.5845
# Epoch 2000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2777 | Total: -1.5845
# Epoch 2500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5845
# Epoch 3000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2777 | Total: -1.5845
# Epoch 3500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2777 | Total: -1.5845
# Epoch 4000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5845
# Epoch 4500 | DGI: 0.6931 | Reg: -0.2846 | λ*Reg: -2.2770 | Total: -1.5838
# Epoch 5000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5845
# Epoch 5500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2775 | Total: -1.5844
# Epoch 6000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2776 | Total: -1.5845
# Epoch 6500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2777 | Total: -1.5846
# Epoch 7000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2777 | Total: -1.5845
# Epoch 7500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2777 | Total: -1.5846
# Epoch 8000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2777 | Total: -1.5845
# Epoch 8500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2777 | Total: -1.5845
# Epoch 9000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2777 | Total: -1.5846
# Epoch 9500 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2773 | Total: -1.5842
# Epoch 10000 | DGI: 0.6931 | Reg: -0.2847 | λ*Reg: -2.2775 | Total: -1.5844
# Run 10 | Accuracy: 0.6849 | Precision: 0.7063 | Recall: 0.9082 | F1: 0.7946 | LogLoss: 0.7541
#
# --- RESULTS FOR LAMBDA = 8 ---
# Accuracy : 0.6849 ± 0.0000
# Precision: 0.7063 ± 0.0000
# Recall   : 0.9082 ± 0.0000
# F1 Score : 0.7946 ± 0.0000
# Log Loss : 0.7554 ± 0.0052
#
# ================ FINAL SUMMARY FOR ALL LAMBDAS ================
#
#   Lambda |           Accuracy |          Precision |             Recall |           F1 Score |           Log Loss
# ------------------------------------------------------------------------------------------------------------
#    0.001 | 0.6699 ± 0.0091 | 0.6738 ± 0.0081 | 0.9857 ± 0.0220 | 0.8003 ± 0.0060 | 0.6901 ± 0.0021
#    0.005 | 0.6685 ± 0.0093 | 0.6751 ± 0.0078 | 0.9765 ± 0.0281 | 0.7981 ± 0.0077 | 0.6913 ± 0.0017
#    0.009 | 0.6692 ± 0.0144 | 0.6761 ± 0.0097 | 0.9745 ± 0.0297 | 0.7980 ± 0.0103 | 0.6918 ± 0.0014
#     0.01 | 0.6692 ± 0.0144 | 0.6761 ± 0.0097 | 0.9745 ± 0.0297 | 0.7980 ± 0.0103 | 0.6919 ± 0.0013
#     0.05 | 0.6726 ± 0.0167 | 0.6896 ± 0.0122 | 0.9327 ± 0.0210 | 0.7927 ± 0.0099 | 0.6926 ± 0.0010
#     0.09 | 0.6692 ± 0.0147 | 0.6917 ± 0.0130 | 0.9163 ± 0.0127 | 0.7881 ± 0.0065 | 0.6920 ± 0.0008
#      0.1 | 0.6692 ± 0.0147 | 0.6917 ± 0.0130 | 0.9163 ± 0.0127 | 0.7881 ± 0.0065 | 0.6919 ± 0.0008
#      0.3 | 0.6808 ± 0.0034 | 0.7015 ± 0.0041 | 0.9133 ± 0.0051 | 0.7934 ± 0.0011 | 0.6876 ± 0.0044
#      0.5 | 0.6808 ± 0.0045 | 0.7018 ± 0.0046 | 0.9122 ± 0.0050 | 0.7933 ± 0.0020 | 0.6818 ± 0.0062
#      0.9 | 0.6849 ± 0.0000 | 0.7063 ± 0.0000 | 0.9082 ± 0.0000 | 0.7946 ± 0.0000 | 0.6780 ± 0.0079
#        1 | 0.6849 ± 0.0000 | 0.7063 ± 0.0000 | 0.9082 ± 0.0000 | 0.7946 ± 0.0000 | 0.6799 ± 0.0086
#        2 | 0.6849 ± 0.0000 | 0.7063 ± 0.0000 | 0.9082 ± 0.0000 | 0.7946 ± 0.0000 | 0.7046 ± 0.0146
#        5 | 0.6849 ± 0.0000 | 0.7063 ± 0.0000 | 0.9082 ± 0.0000 | 0.7946 ± 0.0000 | 0.7432 ± 0.0070
#        8 | 0.6849 ± 0.0000 | 0.7063 ± 0.0000 | 0.9082 ± 0.0000 | 0.7946 ± 0.0000 | 0.7554 ± 0.0052
