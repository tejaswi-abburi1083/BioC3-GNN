# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import torch
os.environ['TORCH'] = torch.__version__
print(torch.__version__)
# Out:
# 2.6.0+cu124

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset, TensorDataset, Subset
import numpy as np
import random
from sklearn.neighbors import NearestNeighbors
from sklearn.cluster import KMeans
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score, log_loss
from munkres import Munkres
from torchvision import models

# %%
def set_seed(seed=42):
    torch.manual_seed(seed)
    np.random.seed(seed)
    random.seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)

set_seed(42)

# %%
class PairDataset(Dataset):
    def __init__(self, pairs, labels):
        self.pairs = pairs
        self.labels = labels

    def __len__(self):
        return len(self.pairs)

    def __getitem__(self, idx):
        return self.pairs[idx][0], self.pairs[idx][1], self.labels[idx]

# %%
class SiameseNet(nn.Module):
    def __init__(self, input_dim, hidden_dim=256):
        super().__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim)
        self.fc3 = nn.Linear(hidden_dim, hidden_dim)

    def forward_once(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        return self.fc3(x)

    def forward(self, x1, x2):
        out1 = self.forward_once(x1)
        out2 = self.forward_once(x2)
        dist = F.pairwise_distance(out1, out2)
        return dist, out1, out2

# %%
class OrthoLinear(nn.Module):
    def __init__(self, in_dim, out_dim, eps=1e-4):
        super().__init__()
        self.fc = nn.Linear(in_dim, out_dim)
        self.eps = eps

    def forward(self, x):
        Y_tilde = self.fc(x)
        gram = Y_tilde.T @ Y_tilde + self.eps * torch.eye(Y_tilde.shape[1], device=x.device)
        L = torch.linalg.cholesky(gram)
        L_inv = torch.inverse(L)
        return Y_tilde @ L_inv.T

# %%
class SpectralNet(nn.Module):
    def __init__(self, input_dim, n_clusters, hidden_dim=256):
        super().__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim)
        self.ortho = OrthoLinear(hidden_dim, n_clusters)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        return self.ortho(x)

# %%
def contrastive_loss(distance, label, margin=1.0):
    pos = label * torch.pow(distance, 2)
    neg = (1 - label) * torch.pow(torch.clamp(margin - distance, min=0.0), 2)
    return torch.mean(pos + neg)

def spectral_loss(Y, W):
    D = torch.diag(W.sum(axis=1))
    L = D - W
    num = torch.trace(Y.T @ L @ Y)
    denom = torch.trace(Y.T @ D @ Y)
    return num / (denom + 1e-12)

# %%
def compute_affinity(X, scale, n_neighbors=20):
    nbrs = NearestNeighbors(n_neighbors=n_neighbors + 1).fit(X)
    distances, indices = nbrs.kneighbors(X)
    distances, indices = distances[:, 1:], indices[:, 1:]
    W = np.zeros((len(X), len(X)))
    for i in range(len(X)):
        for j in range(n_neighbors):
            W[i, indices[i, j]] = np.exp(-distances[i, j] ** 2 / (2 * scale ** 2))
            W[indices[i, j], i] = W[i, indices[i, j]]
    return W

def compute_scale(X, n_neighbors=20):
    nbrs = NearestNeighbors(n_neighbors=n_neighbors + 1).fit(X)
    distances, _ = nbrs.kneighbors(X)
    return np.median(distances[:, -1])

def calculate_accuracy(y_pred, y_true, n_clusters):
    cm = confusion_matrix(y_true, y_pred)
    cost = np.zeros((n_clusters, n_clusters))
    for i in range(n_clusters):
        for j in range(n_clusters):
            cost[i, j] = cm[:, j].sum() - cm[i, j]
    m = Munkres()
    mapping = m.compute(cost.tolist())
    new_labels = np.zeros_like(y_pred)
    for row, col in mapping:
        new_labels[y_pred == row] = col
    return (new_labels == y_true).mean()

# %%
def train_siamese(siamese_net, dataloader, epochs=50, lr=1e-3, device='cpu'):
    siamese_net.to(device)
    opt = optim.Adam(siamese_net.parameters(), lr=lr)
    for ep in range(epochs):
        siamese_net.train()
        total_loss = 0.0
        for x1, x2, labels in dataloader:
            x1 = x1.to(device).float()
            x2 = x2.to(device).float()
            labels = labels.to(device).float()
            dist, _, _ = siamese_net(x1, x2)
            loss = contrastive_loss(dist, labels)
            opt.zero_grad()
            loss.backward()
            opt.step()
            total_loss += loss.item() * x1.size(0)
        avg_loss = total_loss / len(dataloader.dataset)
        print(f"[Siamese] Epoch {ep + 1}/{epochs}, Avg Loss={avg_loss:.6f}")
    siamese_net.to('cpu')
    return siamese_net

def train_spectral(spectral_net, X_train, W, epochs=50, lr=1e-3, tol=1e-6, device='cpu'):
    spectral_net.to(device)
    opt = optim.Adam([
        {'params': spectral_net.fc1.parameters()},
        {'params': spectral_net.fc2.parameters()},
        {'params': spectral_net.ortho.fc.parameters()}
    ], lr=lr)

    X_tensor = torch.tensor(X_train, dtype=torch.float32, device=device)
    W_tensor = torch.tensor(W, dtype=torch.float32, device=device)

    prev_loss = float('inf')
    for ep in range(epochs):
        spectral_net.train()
        Y = spectral_net(X_tensor)  # (n_samples, n_clusters)
        loss = spectral_loss(Y, W_tensor)
        opt.zero_grad()
        loss.backward()
        opt.step()

        loss_item = loss.item()
        print(f"[SpectralNet] Epoch {ep + 1}/{epochs}, Loss={loss_item:.8f}")

        if abs(prev_loss - loss_item) < tol:
            print("SpectralNet converged (tol reached).")
            break
        prev_loss = loss_item
    spectral_net.to('cpu')
    return spectral_net

# %%
def main():
    device = "cuda" if torch.cuda.is_available() else "cpu"

    # ====== Load PneumoniaMNIST ======
    data = np.load('/home/snu/Downloads/pneumoniamnist_224.npz', allow_pickle=True)
    all_images = np.concatenate([data['train_images'], data['val_images'], data['test_images']], axis=0)
    all_labels = np.concatenate([data['train_labels'], data['val_labels'], data['test_labels']], axis=0).squeeze()

    images = all_images.astype(np.float32) / 255.0
    images = np.repeat(images[:, None, :, :], 3, axis=1)  # (N, 3, 224, 224)
    labels = all_labels.astype(np.int64)

    # ====== Select 2000 samples per class ======
    selected_indices = []
    num_per_class = 2000
    classes = np.unique(labels)
    for c in classes:
        class_idx = np.where(labels == c)[0]
        chosen = np.random.choice(class_idx, size=min(num_per_class, len(class_idx)), replace=False)
        selected_indices.extend(chosen)

    selected_indices = np.array(selected_indices)
    images = images[selected_indices]
    labels = labels[selected_indices]

    # ====== Create dataset ======
    dataset = TensorDataset(torch.tensor(images), torch.tensor(labels))
    loader = DataLoader(dataset, batch_size=64, shuffle=False)

    # ====== Load ResNet-18 (pretrained) ======
    resnet = models.resnet18(pretrained=True)
    resnet.fc = nn.Identity()  # remove final classification layer
    resnet = resnet.to(device)
    resnet.eval()

    # ====== Extract ResNet features ======
    feats, y_list = [], []
    with torch.no_grad():
        for imgs, lbls in loader:
            imgs = imgs.to(device).float()
            f = resnet(imgs)
            feats.append(f.cpu())
            y_list.append(lbls)

    X = torch.cat(feats, dim=0).numpy().astype(np.float32)
    y = torch.cat(y_list, dim=0).numpy().astype(np.int64)

    # Shuffle
    perm = np.random.permutation(len(X))
    X, y = X[perm], y[perm]
    print("Balanced subset:", X.shape, y.shape)

    num_nodes, num_feats = X.shape
    n_clusters = 2
    hidden_dim = 256
    batch_size = 16
    n_neighbors = 20

    # ====== Build siamese pairs ======
    pairs, labels_pairs = [], []
    nbrs = NearestNeighbors(n_neighbors=n_neighbors + 1).fit(X)
    distances, indices = nbrs.kneighbors(X)
    for i in range(len(X)):
        for j in indices[i, 1:]:
            pairs.append([X[i], X[j]])
            labels_pairs.append(1)
        all_indices = set(range(len(X)))
        neighbor_set = set(indices[i, 1:])
        non_neighbors = list(all_indices - neighbor_set - {i})
        j = np.random.choice(non_neighbors)
        pairs.append([X[i], X[j]])
        labels_pairs.append(0)

    dataset_pairs = PairDataset(pairs, labels_pairs)
    dataloader_pairs = DataLoader(dataset_pairs, batch_size=batch_size, shuffle=True)

    # ====== Train Siamese ======
    siamese = SiameseNet(num_feats, hidden_dim)
    siamese = train_siamese(siamese, dataloader_pairs, epochs=50, device=device)

    with torch.no_grad():
        X_embed = siamese.forward_once(torch.tensor(X, dtype=torch.float32)).numpy()

    # ====== Train SpectralNet ======
    scale = compute_scale(X_embed, n_neighbors=n_neighbors)
    W = compute_affinity(X_embed, scale, n_neighbors=n_neighbors)
    spectral = SpectralNet(num_feats, n_clusters, hidden_dim)
    spectral = train_spectral(spectral, X, W, epochs=50, device=device)

    with torch.no_grad():
        Y = spectral(torch.tensor(X, dtype=torch.float32)).numpy()
        y_pred_proba = F.softmax(torch.tensor(Y), dim=1).numpy()

    kmeans = KMeans(n_clusters=n_clusters, n_init=20)
    y_pred = kmeans.fit_predict(Y)

    acc_score = calculate_accuracy(y_pred, y, n_clusters)
    acc_score_inverted = calculate_accuracy(1 - y_pred, y, n_clusters)
    if acc_score_inverted > acc_score:
        acc_score = acc_score_inverted
        y_pred = 1 - y_pred

    prec = precision_score(y, y_pred)
    rec = recall_score(y, y_pred)
    f1 = f1_score(y, y_pred)
    ll = log_loss(y, y_pred_proba)

    print("Final clustering accuracy:", acc_score)
    print("Precision:", prec)
    print("Recall:", rec)
    print("F1 Score:", f1)
    print("Log Loss:", ll)

    return {"accuracy": acc_score, "precision": prec, "recall": rec, "f1": f1, "log_loss": ll}


# --------------------------
# Multi-runs
# --------------------------
if __name__ == "__main__":
    num_runs = 10
    all_results = {"accuracy": [], "precision": [], "recall": [], "f1": [], "log_loss": []}
    for run in range(num_runs):
        print(f"\n--- Run {run+1}/{num_runs} ---")
        set_seed(run)
        res = main()
        for k in all_results.keys():
            all_results[k].append(res[k])

    print("\n=== FINAL SUMMARY ===")
    for metric, vals in all_results.items():
        print(f"{metric:>10} | mean={np.mean(vals):.4f} ± {np.std(vals):.4f}")
# Out:
# --- Run 1/10 ---
# /home/snu/anaconda3/envs/torch_env/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/snu/anaconda3/envs/torch_env/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Balanced subset: (3583, 512) (3583,)
# [Siamese] Epoch 1/50, Avg Loss=0.029973
# [Siamese] Epoch 2/50, Avg Loss=0.029008
# [Siamese] Epoch 3/50, Avg Loss=0.028685
# [Siamese] Epoch 4/50, Avg Loss=0.028501
# [Siamese] Epoch 5/50, Avg Loss=0.028510
# [Siamese] Epoch 6/50, Avg Loss=0.028595
# [Siamese] Epoch 7/50, Avg Loss=0.028478
# [Siamese] Epoch 8/50, Avg Loss=0.028447
# [Siamese] Epoch 9/50, Avg Loss=0.028396
# [Siamese] Epoch 10/50, Avg Loss=0.028256
# [Siamese] Epoch 11/50, Avg Loss=0.028247
# [Siamese] Epoch 12/50, Avg Loss=0.028211
# [Siamese] Epoch 13/50, Avg Loss=0.028168
# [Siamese] Epoch 14/50, Avg Loss=0.028111
# [Siamese] Epoch 15/50, Avg Loss=0.028082
# [SpectralNet] Epoch 20/50, Loss=0.00745575
# [SpectralNet] Epoch 21/50, Loss=0.00717404
# [SpectralNet] Epoch 22/50, Loss=0.00692758
# [SpectralNet] Epoch 23/50, Loss=0.00669795
# [SpectralNet] Epoch 24/50, Loss=0.00647199
# [SpectralNet] Epoch 25/50, Loss=0.00626487
# [SpectralNet] Epoch 26/50, Loss=0.00607613
# [SpectralNet] Epoch 27/50, Loss=0.00589891
# [SpectralNet] Epoch 28/50, Loss=0.00571780
# [SpectralNet] Epoch 29/50, Loss=0.00553878
# [SpectralNet] Epoch 30/50, Loss=0.00537012
# [SpectralNet] Epoch 31/50, Loss=0.00521230
# [SpectralNet] Epoch 32/50, Loss=0.00506578
# [SpectralNet] Epoch 33/50, Loss=0.00491252
# [SpectralNet] Epoch 34/50, Loss=0.00477484
# [SpectralNet] Epoch 35/50, Loss=0.00462749
# [SpectralNet] Epoch 36/50, Loss=0.00449337
# [SpectralNet] Epoch 37/50, Loss=0.00435327
# [SpectralNet] Epoch 38/50, Loss=0.00421804
# [SpectralNet] Epoch 39/50, Loss=0.00409084
# [SpectralNet] Epoch 40/50, Loss=0.00396936
# [SpectralNet] Epoch 41/50, Loss=0.00385119
# [SpectralNet] Epoch 42/50, Loss=0.00374275
# [SpectralNet] Epoch 43/50, Loss=0.00363659
# [SpectralNet] Epoch 44/50, Loss=0.00353922
# [SpectralNet] Epoch 45/50, Loss=0.00344565
# [SpectralNet] Epoch 46/50, Loss=0.00335546
# [SpectralNet] Epoch 47/50, Loss=0.00326786
# [SpectralNet] Epoch 48/50, Loss=0.00318724
# [SpectralNet] Epoch 49/50, Loss=0.00310488
# [SpectralNet] Epoch 50/50, Loss=0.00303217
# Final clustering accuracy: 0.8981300586101033
# Precision: 0.943089430894309
# Recall: 0.87
# F1 Score: 0.9050715214564369
# Log Loss: 0.6859318091681106
#
# --- Run 2/10 ---
# /home/snu/anaconda3/envs/torch_env/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/snu/anaconda3/envs/torch_env/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Balanced subset: (3583, 512) (3583,)
# [Siamese] Epoch 1/50, Avg Loss=0.029306
# [Siamese] Epoch 2/50, Avg Loss=0.028232
# [Siamese] Epoch 3/50, Avg Loss=0.027841
# [Siamese] Epoch 4/50, Avg Loss=0.027758
# [Siamese] Epoch 5/50, Avg Loss=0.027663
# [Siamese] Epoch 6/50, Avg Loss=0.027607
# [Siamese] Epoch 7/50, Avg Loss=0.027919
# [Siamese] Epoch 8/50, Avg Loss=0.027846
# [Siamese] Epoch 9/50, Avg Loss=0.027773
# [Siamese] Epoch 10/50, Avg Loss=0.027685
# [Siamese] Epoch 11/50, Avg Loss=0.027591
# [Siamese] Epoch 12/50, Avg Loss=0.027590
# [Siamese] Epoch 13/50, Avg Loss=0.027597
# [Siamese] Epoch 14/50, Avg Loss=0.027491
# [Siamese] Epoch 15/50, Avg Loss=0.027485
# [Siamese] Epoch 16/50, Avg Loss=0.027463
# [Siamese] Epoch 17/50, Avg Loss=0.027460
# [Siamese] Epoch 18/50, Avg Loss=0.027403
# [Siamese] Epoch 19/50, Avg Loss=0.027469
# [Siamese] Epoch 20/50, Avg Loss=0.027402
# [SpectralNet] Epoch 25/50, Loss=0.00522951
# [SpectralNet] Epoch 26/50, Loss=0.00503095
# [SpectralNet] Epoch 27/50, Loss=0.00483452
# [SpectralNet] Epoch 28/50, Loss=0.00464381
# [SpectralNet] Epoch 29/50, Loss=0.00446761
# [SpectralNet] Epoch 30/50, Loss=0.00430259
# [SpectralNet] Epoch 31/50, Loss=0.00414231
# [SpectralNet] Epoch 32/50, Loss=0.00398159
# [SpectralNet] Epoch 33/50, Loss=0.00382264
# [SpectralNet] Epoch 34/50, Loss=0.00366653
# [SpectralNet] Epoch 35/50, Loss=0.00352254
# [SpectralNet] Epoch 36/50, Loss=0.00339073
# [SpectralNet] Epoch 37/50, Loss=0.00326978
# [SpectralNet] Epoch 38/50, Loss=0.00315822
# [SpectralNet] Epoch 39/50, Loss=0.00305268
# [SpectralNet] Epoch 40/50, Loss=0.00295035
# [SpectralNet] Epoch 41/50, Loss=0.00285347
# [SpectralNet] Epoch 42/50, Loss=0.00276219
# [SpectralNet] Epoch 43/50, Loss=0.00267636
# [SpectralNet] Epoch 44/50, Loss=0.00259333
# [SpectralNet] Epoch 45/50, Loss=0.00251092
# [SpectralNet] Epoch 46/50, Loss=0.00243384
# [SpectralNet] Epoch 47/50, Loss=0.00236059
# [SpectralNet] Epoch 48/50, Loss=0.00228822
# [SpectralNet] Epoch 49/50, Loss=0.00221840
# [SpectralNet] Epoch 50/50, Loss=0.00215247
# Final clustering accuracy: 0.7636059168294725
# Precision: 0.3432708688245315
# Recall: 0.403
# F1 Score: 0.37074517019319225
# Log Loss: 0.7012458358087535
#
# --- Run 3/10 ---
# /home/snu/anaconda3/envs/torch_env/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/snu/anaconda3/envs/torch_env/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Balanced subset: (3583, 512) (3583,)
# [Siamese] Epoch 1/50, Avg Loss=0.029421
# [Siamese] Epoch 2/50, Avg Loss=0.028094
# [Siamese] Epoch 3/50, Avg Loss=0.027782
# [Siamese] Epoch 4/50, Avg Loss=0.027677
# [Siamese] Epoch 5/50, Avg Loss=0.027621
# [Siamese] Epoch 6/50, Avg Loss=0.027426
# [Siamese] Epoch 7/50, Avg Loss=0.027334
# [Siamese] Epoch 8/50, Avg Loss=0.027316
# [Siamese] Epoch 9/50, Avg Loss=0.027160
# [Siamese] Epoch 10/50, Avg Loss=0.027444
# [Siamese] Epoch 11/50, Avg Loss=0.027450
# [Siamese] Epoch 12/50, Avg Loss=0.027359
# [Siamese] Epoch 13/50, Avg Loss=0.027384
# [Siamese] Epoch 14/50, Avg Loss=0.027383
# [Siamese] Epoch 15/50, Avg Loss=0.027309
# [Siamese] Epoch 16/50, Avg Loss=0.027303
# [Siamese] Epoch 17/50, Avg Loss=0.027296
# [Siamese] Epoch 18/50, Avg Loss=0.027246
# [Siamese] Epoch 19/50, Avg Loss=0.027267
# [Siamese] Epoch 20/50, Avg Loss=0.027247
# [Siamese] Epoch 21/50, Avg Loss=0.027184
# [Siamese] Epoch 22/50, Avg Loss=0.027195
# [Siamese] Epoch 23/50, Avg Loss=0.027206
# [Siamese] Epoch 24/50, Avg Loss=0.027152
# [Siamese] Epoch 25/50, Avg Loss=0.027174
# [Siamese] Epoch 26/50, Avg Loss=0.027139
# [Siamese] Epoch 27/50, Avg Loss=0.027161
# [Siamese] Epoch 28/50, Avg Loss=0.027142
# [Siamese] Epoch 29/50, Avg Loss=0.027120
# [Siamese] Epoch 30/50, Avg Loss=0.027153
# [Siamese] Epoch 31/50, Avg Loss=0.027084
# [Siamese] Epoch 32/50, Avg Loss=0.027091
# [Siamese] Epoch 33/50, Avg Loss=0.027103
# [Siamese] Epoch 34/50, Avg Loss=0.027077
# [Siamese] Epoch 35/50, Avg Loss=0.027029
# [Siamese] Epoch 36/50, Avg Loss=0.027081
# [Siamese] Epoch 37/50, Avg Loss=0.027022
# [Siamese] Epoch 38/50, Avg Loss=0.027049
# [Siamese] Epoch 39/50, Avg Loss=0.027018
# [Siamese] Epoch 40/50, Avg Loss=0.027002
# [Siamese] Epoch 41/50, Avg Loss=0.027008
# [Siamese] Epoch 42/50, Avg Loss=0.027005
# [Siamese] Epoch 43/50, Avg Loss=0.027009
# [Siamese] Epoch 44/50, Avg Loss=0.026998
# [Siamese] Epoch 45/50, Avg Loss=0.027016
# [Siamese] Epoch 46/50, Avg Loss=0.026984
# [Siamese] Epoch 47/50, Avg Loss=0.026973
# [Siamese] Epoch 48/50, Avg Loss=0.026949
# [Siamese] Epoch 49/50, Avg Loss=0.026968
# [Siamese] Epoch 50/50, Avg Loss=0.026967
# [SpectralNet] Epoch 1/50, Loss=0.37268379
# [SpectralNet] Epoch 2/50, Loss=0.05811626
# [SpectralNet] Epoch 3/50, Loss=0.03130355
# [SpectralNet] Epoch 4/50, Loss=0.02174957
# [SpectralNet] Epoch 5/50, Loss=0.01878959
# [SpectralNet] Epoch 6/50, Loss=0.01640606
# [SpectralNet] Epoch 7/50, Loss=0.01445471
# [SpectralNet] Epoch 8/50, Loss=0.01311527
# [SpectralNet] Epoch 9/50, Loss=0.01216927
# [SpectralNet] Epoch 10/50, Loss=0.01144398
# [SpectralNet] Epoch 11/50, Loss=0.01085684
# [SpectralNet] Epoch 12/50, Loss=0.01040886
# [SpectralNet] Epoch 13/50, Loss=0.01003430
# [SpectralNet] Epoch 14/50, Loss=0.00968895
# [SpectralNet] Epoch 15/50, Loss=0.00934961
# [SpectralNet] Epoch 16/50, Loss=0.00909659
# [SpectralNet] Epoch 17/50, Loss=0.00876916
# [SpectralNet] Epoch 18/50, Loss=0.00852441
# [SpectralNet] Epoch 19/50, Loss=0.00831501
# [SpectralNet] Epoch 20/50, Loss=0.00813594
# [SpectralNet] Epoch 21/50, Loss=0.00796698
# [SpectralNet] Epoch 22/50, Loss=0.00778682
# [SpectralNet] Epoch 23/50, Loss=0.00759670
# [SpectralNet] Epoch 24/50, Loss=0.00741554
# [SpectralNet] Epoch 25/50, Loss=0.00725020
# [SpectralNet] Epoch 26/50, Loss=0.00710507
# [SpectralNet] Epoch 27/50, Loss=0.00698873
# [SpectralNet] Epoch 28/50, Loss=0.00682765
# [SpectralNet] Epoch 29/50, Loss=0.00665786
# [SpectralNet] Epoch 30/50, Loss=0.00651092
# [SpectralNet] Epoch 31/50, Loss=0.00637455
# [SpectralNet] Epoch 32/50, Loss=0.00625240
# [SpectralNet] Epoch 33/50, Loss=0.00613063
# [SpectralNet] Epoch 34/50, Loss=0.00600263
# [SpectralNet] Epoch 35/50, Loss=0.00587304
# [SpectralNet] Epoch 36/50, Loss=0.00574417
# [SpectralNet] Epoch 37/50, Loss=0.00561952
# [SpectralNet] Epoch 38/50, Loss=0.00550322
# [SpectralNet] Epoch 39/50, Loss=0.00538755
# [SpectralNet] Epoch 40/50, Loss=0.00527323
# [SpectralNet] Epoch 41/50, Loss=0.00516478
# [SpectralNet] Epoch 42/50, Loss=0.00505998
# [SpectralNet] Epoch 43/50, Loss=0.00495452
# [SpectralNet] Epoch 44/50, Loss=0.00485324
# [SpectralNet] Epoch 45/50, Loss=0.00474870
# [SpectralNet] Epoch 46/50, Loss=0.00464783
# [SpectralNet] Epoch 47/50, Loss=0.00455497
# [SpectralNet] Epoch 48/50, Loss=0.00446322
# [SpectralNet] Epoch 49/50, Loss=0.00437079
# [SpectralNet] Epoch 50/50, Loss=0.00428146
# Final clustering accuracy: 0.7566285235835891
# Precision: 0.9585365853658536
# Recall: 0.5895
# F1 Score: 0.730030959752322
# Log Loss: 0.6874802000845635
#
# --- Run 4/10 ---
# /home/snu/anaconda3/envs/torch_env/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/snu/anaconda3/envs/torch_env/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Balanced subset: (3583, 512) (3583,)
# [Siamese] Epoch 1/50, Avg Loss=0.029304
# [Siamese] Epoch 2/50, Avg Loss=0.028125
# [Siamese] Epoch 3/50, Avg Loss=0.027816
# [Siamese] Epoch 4/50, Avg Loss=0.027675
# [Siamese] Epoch 5/50, Avg Loss=0.027515
# [Siamese] Epoch 6/50, Avg Loss=0.027414
# [Siamese] Epoch 7/50, Avg Loss=0.027368
# [Siamese] Epoch 8/50, Avg Loss=0.027296
# [Siamese] Epoch 9/50, Avg Loss=0.027179
# [Siamese] Epoch 10/50, Avg Loss=0.027082
# [Siamese] Epoch 11/50, Avg Loss=0.026987
# [Siamese] Epoch 12/50, Avg Loss=0.026918
# [Siamese] Epoch 13/50, Avg Loss=0.026961
# [Siamese] Epoch 14/50, Avg Loss=0.026918
# [Siamese] Epoch 15/50, Avg Loss=0.026913
# [Siamese] Epoch 16/50, Avg Loss=0.026847
# [Siamese] Epoch 17/50, Avg Loss=0.026853
# [Siamese] Epoch 18/50, Avg Loss=0.026817
# [Siamese] Epoch 19/50, Avg Loss=0.026828
# [Siamese] Epoch 20/50, Avg Loss=0.026850
# [Siamese] Epoch 21/50, Avg Loss=0.026761
# [Siamese] Epoch 22/50, Avg Loss=0.026802
# [Siamese] Epoch 23/50, Avg Loss=0.026723
# [Siamese] Epoch 24/50, Avg Loss=0.026742
# [Siamese] Epoch 25/50, Avg Loss=0.026689
# [Siamese] Epoch 26/50, Avg Loss=0.026689
# [Siamese] Epoch 27/50, Avg Loss=0.026669
# [Siamese] Epoch 28/50, Avg Loss=0.026648
# [Siamese] Epoch 29/50, Avg Loss=0.026656
# [Siamese] Epoch 30/50, Avg Loss=0.026654
# [Siamese] Epoch 31/50, Avg Loss=0.026956
# [Siamese] Epoch 32/50, Avg Loss=0.026982
# [Siamese] Epoch 33/50, Avg Loss=0.026954
# [Siamese] Epoch 34/50, Avg Loss=0.026965
# [Siamese] Epoch 35/50, Avg Loss=0.026945
# [Siamese] Epoch 36/50, Avg Loss=0.026883
# [Siamese] Epoch 37/50, Avg Loss=0.026887
# [Siamese] Epoch 38/50, Avg Loss=0.026858
# [Siamese] Epoch 39/50, Avg Loss=0.026886
# [Siamese] Epoch 40/50, Avg Loss=0.026892
# [Siamese] Epoch 41/50, Avg Loss=0.026785
# [Siamese] Epoch 42/50, Avg Loss=0.026822
# [Siamese] Epoch 43/50, Avg Loss=0.026865
# [Siamese] Epoch 44/50, Avg Loss=0.026803
# [Siamese] Epoch 45/50, Avg Loss=0.026800
# [Siamese] Epoch 46/50, Avg Loss=0.026828
# [Siamese] Epoch 47/50, Avg Loss=0.026843
# [Siamese] Epoch 48/50, Avg Loss=0.026879
# [Siamese] Epoch 49/50, Avg Loss=0.026805
# [Siamese] Epoch 50/50, Avg Loss=0.026797
# [SpectralNet] Epoch 1/50, Loss=0.43929988
# [SpectralNet] Epoch 2/50, Loss=0.03487306
# [SpectralNet] Epoch 3/50, Loss=0.02484458
# [SpectralNet] Epoch 4/50, Loss=0.02038833
# [SpectralNet] Epoch 5/50, Loss=0.01783880
# [SpectralNet] Epoch 6/50, Loss=0.01618994
# [SpectralNet] Epoch 7/50, Loss=0.01476248
# [SpectralNet] Epoch 8/50, Loss=0.01339688
# [SpectralNet] Epoch 9/50, Loss=0.01220473
# [SpectralNet] Epoch 10/50, Loss=0.01118928
# [SpectralNet] Epoch 11/50, Loss=0.01038091
# [SpectralNet] Epoch 12/50, Loss=0.00971088
# [SpectralNet] Epoch 13/50, Loss=0.00913852
# [SpectralNet] Epoch 14/50, Loss=0.00865075
# [SpectralNet] Epoch 15/50, Loss=0.00823918
# [SpectralNet] Epoch 16/50, Loss=0.00788440
# [SpectralNet] Epoch 17/50, Loss=0.00756240
# [SpectralNet] Epoch 18/50, Loss=0.00726766
# [SpectralNet] Epoch 19/50, Loss=0.00698759
# [SpectralNet] Epoch 20/50, Loss=0.00671620
# [SpectralNet] Epoch 21/50, Loss=0.00646973
# [SpectralNet] Epoch 22/50, Loss=0.00624445
# [SpectralNet] Epoch 23/50, Loss=0.00602206
# [SpectralNet] Epoch 24/50, Loss=0.00581590
# [SpectralNet] Epoch 25/50, Loss=0.00562291
# [SpectralNet] Epoch 26/50, Loss=0.00542832
# [SpectralNet] Epoch 27/50, Loss=0.00523163
# [SpectralNet] Epoch 28/50, Loss=0.00503922
# [SpectralNet] Epoch 29/50, Loss=0.00486211
# [SpectralNet] Epoch 30/50, Loss=0.00468396
# [SpectralNet] Epoch 31/50, Loss=0.00452448
# [SpectralNet] Epoch 32/50, Loss=0.00437164
# [SpectralNet] Epoch 33/50, Loss=0.00422470
# [SpectralNet] Epoch 34/50, Loss=0.00408445
# [Siamese] Epoch 36/50, Avg Loss=0.027005
# [Siamese] Epoch 37/50, Avg Loss=0.026985
# [Siamese] Epoch 38/50, Avg Loss=0.027014
# [Siamese] Epoch 39/50, Avg Loss=0.026936
# [Siamese] Epoch 40/50, Avg Loss=0.026976
# [Siamese] Epoch 41/50, Avg Loss=0.026947
# [Siamese] Epoch 42/50, Avg Loss=0.026928
# [Siamese] Epoch 43/50, Avg Loss=0.026947
# [Siamese] Epoch 44/50, Avg Loss=0.026953
# [Siamese] Epoch 45/50, Avg Loss=0.026943
# [Siamese] Epoch 46/50, Avg Loss=0.026941
# [Siamese] Epoch 47/50, Avg Loss=0.026900
# [Siamese] Epoch 48/50, Avg Loss=0.026907
# [Siamese] Epoch 49/50, Avg Loss=0.026963
# [Siamese] Epoch 50/50, Avg Loss=0.026934
# [SpectralNet] Epoch 1/50, Loss=0.40086806
# [SpectralNet] Epoch 2/50, Loss=0.03311095
# [SpectralNet] Epoch 3/50, Loss=0.02286640
# [SpectralNet] Epoch 4/50, Loss=0.01786898
# [SpectralNet] Epoch 5/50, Loss=0.01476833
# [SpectralNet] Epoch 6/50, Loss=0.01258421
# [SpectralNet] Epoch 7/50, Loss=0.01108068
# [SpectralNet] Epoch 8/50, Loss=0.01013759
# [SpectralNet] Epoch 9/50, Loss=0.00940297
# [SpectralNet] Epoch 10/50, Loss=0.00874774
# [SpectralNet] Epoch 11/50, Loss=0.00817785
# [SpectralNet] Epoch 12/50, Loss=0.00765438
# [SpectralNet] Epoch 13/50, Loss=0.00720436
# [SpectralNet] Epoch 14/50, Loss=0.00683828
# [SpectralNet] Epoch 15/50, Loss=0.00652537
# [SpectralNet] Epoch 16/50, Loss=0.00623951
# [SpectralNet] Epoch 17/50, Loss=0.00597224
# [SpectralNet] Epoch 18/50, Loss=0.00573668
# [SpectralNet] Epoch 19/50, Loss=0.00553078
# [SpectralNet] Epoch 20/50, Loss=0.00534083
# [SpectralNet] Epoch 21/50, Loss=0.00515833
# [SpectralNet] Epoch 22/50, Loss=0.00498650
# [SpectralNet] Epoch 23/50, Loss=0.00481358
# [SpectralNet] Epoch 24/50, Loss=0.00464148
# [SpectralNet] Epoch 25/50, Loss=0.00448076
# [SpectralNet] Epoch 26/50, Loss=0.00433836
# [SpectralNet] Epoch 27/50, Loss=0.00421649
# [SpectralNet] Epoch 28/50, Loss=0.00410640
# [SpectralNet] Epoch 29/50, Loss=0.00400347
# [SpectralNet] Epoch 30/50, Loss=0.00390460
# [SpectralNet] Epoch 31/50, Loss=0.00379730
# [SpectralNet] Epoch 32/50, Loss=0.00368940
# [SpectralNet] Epoch 33/50, Loss=0.00358292
# [SpectralNet] Epoch 34/50, Loss=0.00347818
# [SpectralNet] Epoch 35/50, Loss=0.00338122
# [SpectralNet] Epoch 36/50, Loss=0.00329110
# [SpectralNet] Epoch 37/50, Loss=0.00320761
# [SpectralNet] Epoch 38/50, Loss=0.00312294
# [SpectralNet] Epoch 39/50, Loss=0.00303757
# [Siamese] Epoch 41/50, Avg Loss=0.027440
# [Siamese] Epoch 42/50, Avg Loss=0.027455
# [Siamese] Epoch 43/50, Avg Loss=0.027416
# [Siamese] Epoch 44/50, Avg Loss=0.027445
# [Siamese] Epoch 45/50, Avg Loss=0.027426
# [Siamese] Epoch 46/50, Avg Loss=0.027371
# [Siamese] Epoch 47/50, Avg Loss=0.027453
# [Siamese] Epoch 48/50, Avg Loss=0.027388
# [Siamese] Epoch 49/50, Avg Loss=0.027356
# [Siamese] Epoch 50/50, Avg Loss=0.027378
# [SpectralNet] Epoch 1/50, Loss=0.36783129
# [SpectralNet] Epoch 2/50, Loss=0.06323940
# [SpectralNet] Epoch 3/50, Loss=0.03239056
# [SpectralNet] Epoch 4/50, Loss=0.02347530
# [SpectralNet] Epoch 5/50, Loss=0.01919813
# [SpectralNet] Epoch 6/50, Loss=0.01679062
# [SpectralNet] Epoch 7/50, Loss=0.01501959
# [SpectralNet] Epoch 8/50, Loss=0.01365273
# [SpectralNet] Epoch 9/50, Loss=0.01255376
# [SpectralNet] Epoch 10/50, Loss=0.01163616
# [SpectralNet] Epoch 11/50, Loss=0.01091063
# [SpectralNet] Epoch 12/50, Loss=0.01024625
# [SpectralNet] Epoch 13/50, Loss=0.00963537
# [SpectralNet] Epoch 14/50, Loss=0.00912814
# [SpectralNet] Epoch 15/50, Loss=0.00866061
# [SpectralNet] Epoch 16/50, Loss=0.00821503
# [SpectralNet] Epoch 17/50, Loss=0.00782194
# [SpectralNet] Epoch 18/50, Loss=0.00746941
# [SpectralNet] Epoch 19/50, Loss=0.00711513
# [SpectralNet] Epoch 20/50, Loss=0.00677224
# [SpectralNet] Epoch 21/50, Loss=0.00646459
# [SpectralNet] Epoch 22/50, Loss=0.00618582
# [SpectralNet] Epoch 23/50, Loss=0.00592843
# [SpectralNet] Epoch 24/50, Loss=0.00570050
# [SpectralNet] Epoch 25/50, Loss=0.00548730
# [SpectralNet] Epoch 26/50, Loss=0.00529181
# [SpectralNet] Epoch 27/50, Loss=0.00510585
# [SpectralNet] Epoch 28/50, Loss=0.00492268
# [SpectralNet] Epoch 29/50, Loss=0.00474482
# [SpectralNet] Epoch 30/50, Loss=0.00456917
# [SpectralNet] Epoch 31/50, Loss=0.00439644
# [SpectralNet] Epoch 32/50, Loss=0.00422456
# [SpectralNet] Epoch 33/50, Loss=0.00405372
# [SpectralNet] Epoch 34/50, Loss=0.00389437
# [SpectralNet] Epoch 35/50, Loss=0.00375091
# [SpectralNet] Epoch 36/50, Loss=0.00361565
# [SpectralNet] Epoch 37/50, Loss=0.00349426
# [SpectralNet] Epoch 38/50, Loss=0.00338003
# [SpectralNet] Epoch 39/50, Loss=0.00327256
# [SpectralNet] Epoch 40/50, Loss=0.00317736
# [SpectralNet] Epoch 41/50, Loss=0.00308255
# [SpectralNet] Epoch 42/50, Loss=0.00298959
# [SpectralNet] Epoch 43/50, Loss=0.00290621
# [SpectralNet] Epoch 44/50, Loss=0.00282247
# [Siamese] Epoch 46/50, Avg Loss=0.027336
# [Siamese] Epoch 47/50, Avg Loss=0.027370
# [Siamese] Epoch 48/50, Avg Loss=0.027343
# [Siamese] Epoch 49/50, Avg Loss=0.027346
# [Siamese] Epoch 50/50, Avg Loss=0.027334
# [SpectralNet] Epoch 1/50, Loss=0.51048857
# [SpectralNet] Epoch 2/50, Loss=0.04979008
# [SpectralNet] Epoch 3/50, Loss=0.02646868
# [SpectralNet] Epoch 4/50, Loss=0.02067603
# [SpectralNet] Epoch 5/50, Loss=0.01654047
# [SpectralNet] Epoch 6/50, Loss=0.01358079
# [SpectralNet] Epoch 7/50, Loss=0.01190251
# [SpectralNet] Epoch 8/50, Loss=0.01076864
# [SpectralNet] Epoch 9/50, Loss=0.00987083
# [SpectralNet] Epoch 10/50, Loss=0.00917516
# [SpectralNet] Epoch 11/50, Loss=0.00859312
# [SpectralNet] Epoch 12/50, Loss=0.00809186
# [SpectralNet] Epoch 13/50, Loss=0.00769717
# [SpectralNet] Epoch 14/50, Loss=0.00736252
# [SpectralNet] Epoch 15/50, Loss=0.00703659
# [SpectralNet] Epoch 16/50, Loss=0.00670830
# [SpectralNet] Epoch 17/50, Loss=0.00637769
# [SpectralNet] Epoch 18/50, Loss=0.00606006
# [SpectralNet] Epoch 19/50, Loss=0.00577543
# [SpectralNet] Epoch 20/50, Loss=0.00552273
# [SpectralNet] Epoch 21/50, Loss=0.00528720
# [SpectralNet] Epoch 22/50, Loss=0.00505733
# [SpectralNet] Epoch 23/50, Loss=0.00483711
# [SpectralNet] Epoch 24/50, Loss=0.00463832
# [SpectralNet] Epoch 25/50, Loss=0.00446513
# [SpectralNet] Epoch 26/50, Loss=0.00429384
# [SpectralNet] Epoch 27/50, Loss=0.00413256
# [SpectralNet] Epoch 28/50, Loss=0.00398247
# [SpectralNet] Epoch 29/50, Loss=0.00382922
# [SpectralNet] Epoch 30/50, Loss=0.00368149
# [SpectralNet] Epoch 31/50, Loss=0.00354991
# [SpectralNet] Epoch 32/50, Loss=0.00342252
# [SpectralNet] Epoch 33/50, Loss=0.00329781
# [SpectralNet] Epoch 34/50, Loss=0.00318504
# [SpectralNet] Epoch 35/50, Loss=0.00307190
# [SpectralNet] Epoch 36/50, Loss=0.00295762
# [SpectralNet] Epoch 37/50, Loss=0.00285665
# [SpectralNet] Epoch 38/50, Loss=0.00276736
# [SpectralNet] Epoch 39/50, Loss=0.00268249
# [SpectralNet] Epoch 40/50, Loss=0.00260307
# [SpectralNet] Epoch 41/50, Loss=0.00252952
# [SpectralNet] Epoch 42/50, Loss=0.00245724
# [SpectralNet] Epoch 43/50, Loss=0.00238973
# [SpectralNet] Epoch 44/50, Loss=0.00232632
# [SpectralNet] Epoch 45/50, Loss=0.00226545
# [SpectralNet] Epoch 46/50, Loss=0.00220851
# [SpectralNet] Epoch 47/50, Loss=0.00215238
# [SpectralNet] Epoch 48/50, Loss=0.00209663
# [SpectralNet] Epoch 49/50, Loss=0.00204381
# [SpectralNet] Epoch 50/50, Loss=0.00199354
# Final clustering accuracy: 0.7437901200111638
# Precision: 0.3624327678940836
# Recall: 0.438
# F1 Score: 0.3966493094860765
# Log Loss: 0.700339110142619
#
# --- Run 8/10 ---
# /home/snu/anaconda3/envs/torch_env/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/snu/anaconda3/envs/torch_env/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Balanced subset: (3583, 512) (3583,)
# [Siamese] Epoch 1/50, Avg Loss=0.
# [SpectralNet] Epoch 1/50, Loss=0.49244660
# [SpectralNet] Epoch 2/50, Loss=0.06020903
# [SpectralNet] Epoch 3/50, Loss=0.03489510
# [SpectralNet] Epoch 4/50, Loss=0.02089656
# [SpectralNet] Epoch 5/50, Loss=0.01705671
# [SpectralNet] Epoch 6/50, Loss=0.01494493
# [SpectralNet] Epoch 7/50, Loss=0.01310153
# [SpectralNet] Epoch 8/50, Loss=0.01171336
# [SpectralNet] Epoch 9/50, Loss=0.01091200
# [SpectralNet] Epoch 10/50, Loss=0.01031069
# [SpectralNet] Epoch 11/50, Loss=0.00966852
# [SpectralNet] Epoch 12/50, Loss=0.00905984
# [SpectralNet] Epoch 13/50, Loss=0.00856434
# [SpectralNet] Epoch 14/50, Loss=0.00817417
# [SpectralNet] Epoch 15/50, Loss=0.00783756
# [SpectralNet] Epoch 16/50, Loss=0.00752369
# [SpectralNet] Epoch 17/50, Loss=0.00721817
# [SpectralNet] Epoch 18/50, Loss=0.00692627
# [SpectralNet] Epoch 19/50, Loss=0.00666536
# [SpectralNet] Epoch 20/50, Loss=0.00643639
# [SpectralNet] Epoch 21/50, Loss=0.00622349
# [SpectralNet] Epoch 22/50, Loss=0.00600704
# [SpectralNet] Epoch 23/50, Loss=0.00579246
# [SpectralNet] Epoch 24/50, Loss=0.00559493
# [SpectralNet] Epoch 25/50, Loss=0.00541564
# [SpectralNet] Epoch 26/50, Loss=0.00526144
# [SpectralNet] Epoch 27/50, Loss=0.00510954
# [SpectralNet] Epoch 28/50, Loss=0.00495011
# [SpectralNet] Epoch 29/50, Loss=0.00478921
# [SpectralNet] Epoch 30/50, Loss=0.00463621
# [SpectralNet] Epoch 31/50, Loss=0.00449401
# [SpectralNet] Epoch 32/50, Loss=0.00435768
# [SpectralNet] Epoch 33/50, Loss=0.00422351
# [SpectralNet] Epoch 34/50, Loss=0.00409278
# [SpectralNet] Epoch 35/50, Loss=0.00397046
# [SpectralNet] Epoch 36/50, Loss=0.00385659
# [SpectralNet] Epoch 37/50, Loss=0.00374538
# [SpectralNet] Epoch 38/50, Loss=0.00363790
# [SpectralNet] Epoch 39/50, Loss=0.00353647
# [SpectralNet] Epoch 40/50, Loss=0.00343431
# [SpectralNet] Epoch 41/50, Loss=0.00333337
# [SpectralNet] Epoch 42/50, Loss=0.00324033
# [SpectralNet] Epoch 43/50, Loss=0.00315211
# [SpectralNet] Epoch 44/50, Loss=0.00306572
# [SpectralNet] Epoch 45/50, Loss=0.00298328
# [SpectralNet] Epoch 46/50, Loss=0.00290586
# [SpectralNet] Epoch 47/50, Loss=0.00282913
# [SpectralNet] Epoch 48/50, Loss=0.00275506
# [SpectralNet] Epoch 49/50, Loss=0.00268411
# [SpectralNet] Epoch 50/50, Loss=0.00261435
# Final clustering accuracy: 0.8554284119452973
# Precision: 0.2242361470740549
# Recall: 0.2165
# F1 Score: 0.22030017807173746
# Log Loss: 0.6856211161798117
#
# --- Run 9/10 ---
# /home/snu/anaconda3/envs/torch_env/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/snu/anaconda3/envs/torch_env/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Balanced subset: (3583, 512) (3583,)
# [Siamese] Epoch 1/50, Avg Loss=0.
# [SpectralNet] Epoch 6/50, Loss=0.03232291
# [SpectralNet] Epoch 7/50, Loss=0.02725533
# [SpectralNet] Epoch 8/50, Loss=0.02381109
# [SpectralNet] Epoch 9/50, Loss=0.02127212
# [SpectralNet] Epoch 10/50, Loss=0.01937048
# [SpectralNet] Epoch 11/50, Loss=0.01795799
# [SpectralNet] Epoch 12/50, Loss=0.01687987
# [SpectralNet] Epoch 13/50, Loss=0.01603684
# [SpectralNet] Epoch 14/50, Loss=0.01536487
# [SpectralNet] Epoch 15/50, Loss=0.01481324
# [SpectralNet] Epoch 16/50, Loss=0.01433085
# [SpectralNet] Epoch 17/50, Loss=0.01386013
# [SpectralNet] Epoch 18/50, Loss=0.01337245
# [SpectralNet] Epoch 19/50, Loss=0.01291304
# [SpectralNet] Epoch 20/50, Loss=0.01248053
# [SpectralNet] Epoch 21/50, Loss=0.01204515
# [SpectralNet] Epoch 22/50, Loss=0.01168017
# [SpectralNet] Epoch 23/50, Loss=0.01129504
# [SpectralNet] Epoch 24/50, Loss=0.01090864
# [SpectralNet] Epoch 25/50, Loss=0.01056824
# [SpectralNet] Epoch 26/50, Loss=0.01028219
# [SpectralNet] Epoch 27/50, Loss=0.01001590
# [SpectralNet] Epoch 28/50, Loss=0.00975511
# [SpectralNet] Epoch 29/50, Loss=0.00950318
# [SpectralNet] Epoch 30/50, Loss=0.00925511
# [SpectralNet] Epoch 31/50, Loss=0.00902766
# [SpectralNet] Epoch 32/50, Loss=0.00880260
# [SpectralNet] Epoch 33/50, Loss=0.00857686
# [SpectralNet] Epoch 34/50, Loss=0.00835803
# [SpectralNet] Epoch 35/50, Loss=0.00815116
# [SpectralNet] Epoch 36/50, Loss=0.00794844
# [SpectralNet] Epoch 37/50, Loss=0.00775339
# [SpectralNet] Epoch 38/50, Loss=0.00757628
# [SpectralNet] Epoch 39/50, Loss=0.00741530
# [SpectralNet] Epoch 40/50, Loss=0.00726011
# [SpectralNet] Epoch 41/50, Loss=0.00710027
# [SpectralNet] Epoch 42/50, Loss=0.00694178
# [SpectralNet] Epoch 43/50, Loss=0.00678963
# [SpectralNet] Epoch 44/50, Loss=0.00664267
# [SpectralNet] Epoch 45/50, Loss=0.00650033
# [SpectralNet] Epoch 46/50, Loss=0.00636737
# [SpectralNet] Epoch 47/50, Loss=0.00623689
# [SpectralNet] Epoch 48/50, Loss=0.00610353
# [SpectralNet] Epoch 49/50, Loss=0.00597024
# [SpectralNet] Epoch 50/50, Loss=0.00583487
# Final clustering accuracy: 0.9014792073681273
# Precision: 0.9111333000499251
# Recall: 0.9125
# F1 Score: 0.9118161378965776
# Log Loss: 0.7003263049717409
#
# --- Run 10/10 ---
# /home/snu/anaconda3/envs/torch_env/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/snu/anaconda3/envs/torch_env/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Balanced subset:
# [SpectralNet] Epoch 9/50, Loss=0.01261851
# [SpectralNet] Epoch 10/50, Loss=0.01148271
# [SpectralNet] Epoch 11/50, Loss=0.01051830
# [SpectralNet] Epoch 12/50, Loss=0.00977867
# [SpectralNet] Epoch 13/50, Loss=0.00917665
# [SpectralNet] Epoch 14/50, Loss=0.00865717
# [SpectralNet] Epoch 15/50, Loss=0.00817246
# [SpectralNet] Epoch 16/50, Loss=0.00770872
# [SpectralNet] Epoch 17/50, Loss=0.00725332
# [SpectralNet] Epoch 18/50, Loss=0.00680769
# [SpectralNet] Epoch 19/50, Loss=0.00644852
# [SpectralNet] Epoch 20/50, Loss=0.00614492
# [SpectralNet] Epoch 21/50, Loss=0.00588027
# [SpectralNet] Epoch 22/50, Loss=0.00560607
# [SpectralNet] Epoch 23/50, Loss=0.00534266
# [SpectralNet] Epoch 24/50, Loss=0.00512195
# [SpectralNet] Epoch 25/50, Loss=0.00492373
# [SpectralNet] Epoch 26/50, Loss=0.00470525
# [SpectralNet] Epoch 27/50, Loss=0.00451382
# [SpectralNet] Epoch 28/50, Loss=0.00434444
# [SpectralNet] Epoch 29/50, Loss=0.00416918
# [SpectralNet] Epoch 30/50, Loss=0.00401313
# [SpectralNet] Epoch 31/50, Loss=0.00388291
# [SpectralNet] Epoch 32/50, Loss=0.00375221
# [SpectralNet] Epoch 33/50, Loss=0.00362058
# [SpectralNet] Epoch 34/50, Loss=0.00351128
# [SpectralNet] Epoch 35/50, Loss=0.00339663
# [SpectralNet] Epoch 36/50, Loss=0.00327929
# [SpectralNet] Epoch 37/50, Loss=0.00318779
# [SpectralNet] Epoch 38/50, Loss=0.00309019
# [SpectralNet] Epoch 39/50, Loss=0.00300646
# [SpectralNet] Epoch 40/50, Loss=0.00292511
# [SpectralNet] Epoch 41/50, Loss=0.00283998
# [SpectralNet] Epoch 42/50, Loss=0.00277037
# [SpectralNet] Epoch 43/50, Loss=0.00269437
# [SpectralNet] Epoch 44/50, Loss=0.00263290
# [SpectralNet] Epoch 45/50, Loss=0.00256965
# [SpectralNet] Epoch 46/50, Loss=0.00250692
# [SpectralNet] Epoch 47/50, Loss=0.00244788
# [SpectralNet] Epoch 48/50, Loss=0.00239071
# [SpectralNet] Epoch 49/50, Loss=0.00233617
# [SpectralNet] Epoch 50/50, Loss=0.00228093
# Final clustering accuracy: 0.8872453251465252
# Precision: 0.9483146067415731
# Recall: 0.844
# F1 Score: 0.8931216931216931
# Log Loss: 0.6956797873147701
#
# === FINAL SUMMARY ===
#   accuracy | mean=0.8366 ± 0.0574
#  precision | mean=0.6808 ± 0.3242
#     recall | mean=0.6029 ± 0.2557
#         f1 | mean=0.6345 ± 0.2818
#   log_loss | mean=0.6920 ± 0.0064

# %% [markdown]
# === FINAL SUMMARY ===
#   accuracy | mean=0.9032 ± 0.0126
#  precision | mean=0.4878 ± 0.4007
#     recall | mean=0.4239 ± 0.3377
#         f1 | mean=0.4533 ± 0.3663
#   log_loss | mean=0.6941 ± 0.0080
